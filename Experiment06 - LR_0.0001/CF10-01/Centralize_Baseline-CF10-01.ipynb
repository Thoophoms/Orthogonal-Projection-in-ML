# %% [markdown]
# # Centralize Baseline
# ### ResNet18 on CIFAR-10

# %%
# =============================================================================
# Centralize Baseline: ResNet18 on CIFAR-10
# - Single-model, end-to-end training on union of all data
# - Logs acc_train, acc_test, round_time_sec, mean_FgT_loss (per epoch)
# - Saves CSV + for comparison plots
# ============================================================================

import copy
import math  # Cosine learning-rate schedule to stabilize training
import os
import random
import time  # Measuring wall-clock time per epoch to compare efficiency

# ============================================================================
#                               Matplotlib
# ============================================================================
import matplotlib

# ============================================================================
#                                Third-party
# ============================================================================
import numpy as np
import pandas as pd
import torch  # Core deep learning tensor library (GPU/CPU compute)
import torch.nn.functional as F  # Functional ops like softmax
from torch import nn  # Neural network layers/losses
from torch.utils.data import DataLoader, Dataset  # Batching datasets
from torchvision import (  # CIFAR datasets + transforms + ResNet
    datasets,
    models,
    transforms,
)

matplotlib.use("Agg")
import matplotlib.pyplot as plt


# ============================================================================
#                         Colored terminal output
# ============================================================================
# To print in color -------test/train of the client side
def prRed(skk):
    print("\033[91m {}\033[00m".format(skk))


def prGreen(skk):
    print("\033[92m {}\033[00m".format(skk))


def _sync_cuda():
    """
    Synchronize CUDA to get accurate timing.
    Compare wall time across methods.
    """
    if torch.cuda.is_available():
        torch.cuda.synchronize()


# ============================================================================
#                         Configuration
# ============================================================================
PROGRAM_NAME = "Centralize Baseline - CIFAR-10"
DATASET_NAME = "CIFAR10"  # Set toggle between CIFAR-10 and CIFAR-100
DATA_ROOT = "data"  # Set where torchvision stores CIFAR data
EPOCHS = 200
BATCH_SIZE = 256
LR = 0.0001
MOMENTUM = 0.9  # Smoothing/Accelerating SGD undates
WEIGHT_DECAY = 5e-4  # L2 Regularization
LABEL_SMOOTH = 0.0
NUM_WORKERS = 4
SEED = 1234
WARMUP_EPOCHS = 0


# ============================================================================
#                             Toggle Cosine
# ============================================================================
cosine_schedule = False       # False = use a constant LR
if cosine_schedule:
    SCHEDULER = "cosine"


# ============================================================================
#                             Reproduce
# ============================================================================
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)  # Seed CPU RNG for Pytorch ops
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)  # Seed all GPUs for DataParallel)
    torch.backends.cudnn.deterministic = True  # Pick deterministic algorithms
    torch.backends.cudnn.benchmark = False  # Turn off autotuner for derterminism


# ============================================================================
#                           Device Selection
# ============================================================================
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))

print(f"---------{PROGRAM_NAME}----------")


# ============================================================================
#                           Data & Transforms
#               Setting mean/std between CIFAR-10 & CIFAR-100
#    Normallizing inpits accelerates convergence and stabilizes training
# ============================================================================
CIFAR_MEAN = {
    "CIFAR10": [0.4914, 0.4822, 0.4465],
    "CIFAR100": [0.5071, 0.4867, 0.4408],
}[DATASET_NAME]
CIFAR_STD = {
    "CIFAR10": [0.2470, 0.2435, 0.2616],
    "CIFAR100": [0.2675, 0.2565, 0.2761],
}[DATASET_NAME]


# Training time
train_tfms = transforms.Compose(
    [
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),  # Convert PIL Image -> torch.FloatTensor in [0,1]
        transforms.Normalize(
            CIFAR_MEAN, CIFAR_STD
        ),  # Normalize to zero-mean/unit-var per channel
    ]
)

# Test-time we only normalize, no random, to get stable evaluation.
test_tfms = transforms.Compose(
    [
        transforms.ToTensor(),
        transforms.Normalize(CIFAR_MEAN, CIFAR_STD),
    ]
)


# ============================================================================
#                               DataLoders
# ============================================================================
# Download CIFAR datasets
if DATASET_NAME == "CIFAR10":
    train_set = datasets.CIFAR10(
        root=DATA_ROOT, train=True, download=True, transform=train_tfms
    )
    test_set = datasets.CIFAR10(
        root=DATA_ROOT, train=False, download=True, transform=test_tfms
    )
    NUM_CLASSES = 10
else:
    train_set = datasets.CIFAR100(
        root=DATA_ROOT, train=True, download=True, transform=train_tfms
    )
    test_set = datasets.CIFAR100(
        root=DATA_ROOT, train=False, download=True, transform=test_tfms
    )
    NUM_CLASSES = 100


# Shuffling, batching, perfetching
train_loader = DataLoader(
    train_set,
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=NUM_WORKERS,
    pin_memory=True,
)

test_loader = DataLoader(
    test_set,
    batch_size=BATCH_SIZE,
    shuffle=False,  # No shuffle at test time
    num_workers=NUM_WORKERS,
    pin_memory=True,
)


# ============================================================================
#                      Model (CIFAR ResNet-18 - 32 x 32)
#                    3 x 3, stride-1 conv, removing maxpool
# ============================================================================
def build_cifar_resnet18(num_classes: int) -> nn.Module:
    m = models.resnet18(weights=None)
    m.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
    m.maxpool = nn.Identity()  # Remove large downsampling for 32x32 inputs
    m.fc = nn.Linear(m.fc.in_features, num_classes)
    return m


model = build_cifar_resnet18(NUM_CLASSES).to(device)  # Move model to GPU/CPU


# If multiple GPUs are visible, DataParallel distributes batches across them.
if torch.cuda.device_count() > 1:
    print(f"We use {torch.cuda.device_count()} GPUs")
    model = nn.DataParallel(model)

# Cross-entropy - LABEL_SMOOTHING is now set to 0.0 to match SL/SFLV2
criterion = nn.CrossEntropyLoss(label_smoothing=LABEL_SMOOTH).to(device)

# SGD with momentum + weight decay
optimizer = torch.optim.SGD(
    model.parameters(), lr=LR, momentum=MOMENTUM, weight_decay=WEIGHT_DECAY
)


# =============================================================================
#                 Schedule: warmup (epoches) + cosine
#             if cosine_schedule = True will trigger below
#                   False = use the constant LR
# =============================================================================
if cosine_schedule:
    if WARMUP_EPOCHS >= EPOCHS:
        raise ValueError("WARMUP_EPOCHS must be less than (<) EPOCHS")
    
    # Linear warmup for first WARMUP_EPOCHS epochs
    warmup = torch.optim.lr_scheduler.LinearLR(
        optimizer,
        start_factor=1e-8,  # (LinearLR doesn't allow start_factor=0.0 change it to 1e-8 (0.000000001))
        end_factor=1.0,
        total_iters=WARMUP_EPOCHS,
    )
    
    # Cosine for the remaining epochs
    cosine = torch.optim.lr_scheduler.CosineAnnealingLR(
        optimizer,
        T_max=EPOCHS - WARMUP_EPOCHS,  # number of cosine steps after warmup
        eta_min=0.0,
    )
    
    # Chain: warmup -> cosine
    scheduler = torch.optim.lr_scheduler.SequentialLR(
        optimizer, schedulers=[warmup, cosine], milestones=[WARMUP_EPOCHS]
    )


# =============================================================================
#                 Matrix for train/test accuracy logging
# =============================================================================
def top1_accuracy(logits: torch.Tensor, y: torch.Tensor) -> float:
    pred = logits.argmax(dim=1)
    return (pred == y).float().mean().item() * 100.0


# Evaluation loop
# Disable grad for speed
# Aggregate loss and accuracy
@torch.no_grad()
def evaluate(model: nn.Module, loader: DataLoader):
    model.eval()
    total, correct, loss_sum = 0, 0, 0.0
    for x, y in loader:
        x, y = x.to(device, non_blocking=True), y.to(device, non_blocking=True)
        logits = model(x)
        loss = criterion(logits, y).item()
        loss_sum += loss * y.size(0)
        correct += (logits.argmax(1) == y).sum().item()
        total += y.size(0)
    return (loss_sum / max(1, total), 100.0 * correct / max(1, total))


# Training epoch over the training set.
def train_one_epoch(
    model: nn.Module, loader: DataLoader, optimizer: torch.optim.Optimizer
):
    model.train()
    total, correct, loss_sum = 0, 0, 0.0
    for x, y in loader:
        x, y = x.to(device, non_blocking=True), y.to(device, non_blocking=True)
        optimizer.zero_grad(set_to_none=True)  # set_to_none; avoids writing zeros
        logits = model(x)  # Forward pass
        loss = criterion(logits, y)  # Compute supervised loss
        loss.backward()  # Backprop to compute gradients
        optimizer.step()  # Update parameters
        loss_sum += loss.item() * y.size(0)
        correct += (logits.argmax(1) == y).sum().item()
        total += y.size(0)
    return (loss_sum / max(1, total), 100.0 * correct / max(1, total))


# =============================================================================
#                         Windowed forgetting metric
# Splitting the test set into EPOCHS disjoint windows.
# (1) - After each epoch e, update the best-so-far loss on window e.
# (2) - Measuring how much the loss on all past windows has risen vs there historical minimum.
# =============================================================================
class DatasetSplit(Dataset):
    def __init__(self, base: Dataset, idxs):
        self.base, self.idxs = base, list(idxs)

    def __len__(self):
        return len(self.idxs)

    def __getitem__(self, i: int):
        return self.base[self.idxs[i]]


# Build disjoint validation loaders per epoch index (round-robin partitioning).
val_loaders = {}
idx_all = np.arange(len(test_set))
for t in range(EPOCHS):
    idxs = idx_all[t::EPOCHS]  # window t gets items t, t+EPOCHS, t+2*EPOCHS, ...
    val = DatasetSplit(test_set, idxs)
    val_loaders[t] = DataLoader(
        val,
        batch_size=BATCH_SIZE,
        shuffle=False,
        num_workers=NUM_WORKERS,
        pin_memory=True,
    )


best_loss_per_window = [
    float("inf")
] * EPOCHS  # Track each window's best (min) loss so far
forgetting_log = []  # Store per-epoch mean_FgT_loss values for saving/plotting


assert all(len(ld.dataset) > 0 for ld in val_loaders.values())


# Evaluate average loss on a particular window.
@torch.no_grad()
def eval_loss_on_window(model: nn.Module, t: int) -> float:
    loader = val_loaders[t]
    if len(loader.dataset) == 0:
        return 0.0

    model.eval()

    total = 0
    loss_sum = 0.0

    for x, y in loader:
        x, y = x.to(device, non_blocking=True), y.to(device, non_blocking=True)
        logits = model(x)
        loss = criterion(logits, y).item()  # <--- use global criterion

        # Skip non-finite losses to avoid poisoning FgT
        if not math.isfinite(loss):
            continue

        loss_sum += loss * y.size(0)
        total += y.size(0)

    if total == 0:
        # No valid batches for this window; treat as "no signal"
        return float("nan")

    return loss_sum / total


# =============================================================================
#                         Training loop
# =============================================================================
# Plotting accuracy vs epoch
acc_train_hist = []
acc_test_hist = []

round_time_hist = []  # Efficiency
mean_fgt_hist = []  # Forgetting


for epoch in range(EPOCHS):
    _sync_cuda()
    t0 = time.perf_counter()  # Start accurate timer (after syncing GPU)


    # ================= Cosine Toggle  =====================================
    if cosine_schedule:
        train_loss, train_acc = train_one_epoch(model, train_loader, optimizer)  # Train one epoch
        test_loss, test_acc = evaluate(model, test_loader)  # Evaluate on test

        scheduler.step()  # epoch-level step
    else:                 # Use constant LR
        train_loss, train_acc = train_one_epoch(model, train_loader, optimizer)
        test_loss, test_acc = evaluate(model, test_loader) # Evaluate on test
    

    _sync_cuda()
    dt = time.perf_counter() - t0  # Stop timer

    # Pretty console logs help when scanning SLURM outputs
    cur_lr = optimizer.param_groups[0]["lr"]

    if cosine_schedule:
        prRed(
            f"Train => Epoch {epoch:03d}  Acc: {train_acc:6.3f}  Loss: {train_loss:7.4f}  LR: {scheduler.get_last_lr()[0]:.5f}"
        )
        prGreen(
            f"Test  => Epoch {epoch:03d}  Acc: {test_acc:6.3f}  Loss: {test_loss:7.4f}  Time(s): {dt:7.2f}"
        )
    else:
        prRed(
            f"Train => Epoch {epoch:03d}  Acc: {train_acc:6.3f}  Loss: {train_loss:7.4f}  LR: {cur_lr:.5f}"
        )
        prGreen(
            f"Test  => Epoch {epoch:03d}  Acc: {test_acc:6.3f}  Loss: {test_loss:7.4f}  Time(s): {dt:7.2f}"
        )

    
    # --- forgetting statistic (No NaN/Inf) ---
    t = epoch  # current window id (0-based)

    # 1) update historical minimum for the *current* window,
    #    but only if the loss is finite.
    L_cur_t = eval_loss_on_window(model, t)
    if math.isfinite(L_cur_t):
        if L_cur_t < best_loss_per_window[t]:
            best_loss_per_window[t] = L_cur_t
    # else: skip update; this window still has no valid baseline

    # 2) forgetting on all PAST windows vs their minima
    per_win_fgt = []
    for t0 in range(t):
        L_now = eval_loss_on_window(model, t0)
        best = best_loss_per_window[t0]

        # only use windows where both current and best are finite
        if not (math.isfinite(L_now) and math.isfinite(best)):
            continue

        Fgt = L_now - best  # allow negatives
        per_win_fgt.append(Fgt)

    mean_fgt = float(np.mean(per_win_fgt)) if per_win_fgt else 0.0

    # --- Log history vectors ---
    acc_train_hist.append(train_acc)
    acc_test_hist.append(test_acc)
    round_time_hist.append(dt)
    mean_fgt_hist.append(mean_fgt)

    print(f"Forgetting : Epoch {epoch}, mean_FgT_loss = {mean_fgt:.6f}")
    print("==========================================================")

print("Training and Evaluation completed!")


# =============================================================================
#                                  Save logs
# =============================================================================
# Keep lengths aligned (paranoia)
n = min(
    len(acc_train_hist), len(acc_test_hist), len(round_time_hist), len(mean_fgt_hist)
)
round_idx = list(range(1, n + 1))

df = pd.DataFrame(
    {
        "round": round_idx,
        "acc_train": acc_train_hist[:n],
        "acc_test": acc_test_hist[:n],
        "round_time_sec": round_time_hist[:n],
        "mean_FgT_loss": mean_fgt_hist[:n],
    }
)

csv_name = f"{PROGRAM_NAME}.csv"
df.to_csv(csv_name, index=False)
print("Saved:", csv_name)

# =============================================================================
#                         Program Completed
# =============================================================================
# Out:
# NVIDIA H200
# ---------Centralize Baseline - CIFAR-10----------
#  Train => Epoch 000  Acc: 37.666  Loss:  1.6775  LR: 0.01000
#  Test  => Epoch 000  Acc: 48.060  Loss:  1.4012  Time(s):    7.82
# Forgetting : Epoch 0, mean_FgT_loss = 0.000000
# ==========================================================
#  Train => Epoch 001  Acc: 55.072  Loss:  1.2381  LR: 0.01000
#  Test  => Epoch 001  Acc: 54.160  Loss:  1.3100  Time(s):    7.23
# Forgetting : Epoch 1, mean_FgT_loss = -0.183742
# ==========================================================
#  Train => Epoch 002  Acc: 63.442  Loss:  1.0161  LR: 0.01000
#  Test  => Epoch 002  Acc: 65.180  Loss:  0.9807  Time(s):    7.18
# Forgetting : Epoch 2, mean_FgT_loss = -0.326255
# ==========================================================
#  Train => Epoch 003  Acc: 68.594  Loss:  0.8820  LR: 0.01000
#  Test  => Epoch 003  Acc: 66.800  Loss:  0.9908  Time(s):    7.18
# Forgetting : Epoch 3, mean_FgT_loss = -0.147438
# ==========================================================
#  Train => Epoch 004  Acc: 72.694  Loss:  0.7688  LR: 0.01000
#  Test  => Epoch 004  Acc: 71.690  Loss:  0.8268  Time(s):    7.24
# Forgetting : Epoch 4, mean_FgT_loss = -0.289879
# ==========================================================
#  Train => Epoch 005  Acc: 76.122  Loss:  0.6808  LR: 0.01000
#  Test  => Epoch 005  Acc: 73.460  Loss:  0.7873  Time(s):    7.80
# Forgetting : Epoch 5, mean_FgT_loss = -0.287071
# ==========================================================
#  Train => Epoch 006  Acc: 78.568  Loss:  0.6098  LR: 0.01000
#  Test  => Epoch 006  Acc: 78.320  Loss:  0.6459  Time(s):   10.92
# Forgetting : Epoch 6, mean_FgT_loss = -0.409143
# ==========================================================
#  Train => Epoch 007  Acc: 80.512  Loss:  0.5567  LR: 0.01000
#  Test  => Epoch 007  Acc: 77.750  Loss:  0.6742  Time(s):   10.85
# Forgetting : Epoch 7, mean_FgT_loss = -0.322389
# ==========================================================
#  Train => Epoch 008  Acc: 81.946  Loss:  0.5185  LR: 0.01000
#  Test  => Epoch 008  Acc: 80.250  Loss:  0.5726  Time(s):   10.82
# Forgetting : Epoch 8, mean_FgT_loss = -0.376206
# ==========================================================
#  Train => Epoch 009  Acc: 83.148  Loss:  0.4786  LR: 0.01000
#  Test  => Epoch 009  Acc: 81.870  Loss:  0.5455  Time(s):   10.79
# Forgetting : Epoch 9, mean_FgT_loss = -0.331471
# ==========================================================
#  Train => Epoch 010  Acc: 84.130  Loss:  0.4538  LR: 0.01000
#  Test  => Epoch 010  Acc: 81.070  Loss:  0.5967  Time(s):   10.72
# Forgetting : Epoch 10, mean_FgT_loss = -0.283526
# ==========================================================
#  Train => Epoch 011  Acc: 85.260  Loss:  0.4217  LR: 0.01000
#  Test  => Epoch 011  Acc: 82.550  Loss:  0.5463  Time(s):   10.79
# Forgetting : Epoch 11, mean_FgT_loss = -0.273805
# ==========================================================
#  Train => Epoch 012  Acc: 86.114  Loss:  0.3954  LR: 0.01000
#  Test  => Epoch 012  Acc: 83.370  Loss:  0.5079  Time(s):   10.78
# Forgetting : Epoch 12, mean_FgT_loss = -0.309220
# ==========================================================
#  Train => Epoch 013  Acc: 87.040  Loss:  0.3748  LR: 0.01000
#  Test  => Epoch 013  Acc: 80.810  Loss:  0.5731  Time(s):   10.78
# Forgetting : Epoch 13, mean_FgT_loss = -0.243913
# ==========================================================
#  Train => Epoch 014  Acc: 87.758  Loss:  0.3515  LR: 0.01000
#  Test  => Epoch 014  Acc: 83.750  Loss:  0.4942  Time(s):   10.76
# Forgetting : Epoch 14, mean_FgT_loss = -0.261587
# ==========================================================
#  Train => Epoch 015  Acc: 88.452  Loss:  0.3307  LR: 0.01000
#  Test  => Epoch 015  Acc: 82.440  Loss:  0.5554  Time(s):   10.50
# Forgetting : Epoch 15, mean_FgT_loss = -0.155769
# ==========================================================
#  Train => Epoch 016  Acc: 88.986  Loss:  0.3141  LR: 0.01000
#  Test  => Epoch 016  Acc: 80.520  Loss:  0.6488  Time(s):   10.79
# Forgetting : Epoch 16, mean_FgT_loss = -0.131585
# ==========================================================
#  Train => Epoch 017  Acc: 89.538  Loss:  0.2964  LR: 0.01000
#  Test  => Epoch 017  Acc: 84.710  Loss:  0.4709  Time(s):   10.80
# Forgetting : Epoch 17, mean_FgT_loss = -0.267679
# ==========================================================
#  Train => Epoch 018  Acc: 90.034  Loss:  0.2828  LR: 0.01000
#  Test  => Epoch 018  Acc: 85.750  Loss:  0.4432  Time(s):   10.79
# Forgetting : Epoch 18, mean_FgT_loss = -0.287490
# ==========================================================
#  Train => Epoch 019  Acc: 90.548  Loss:  0.2658  LR: 0.01000
#  Test  => Epoch 019  Acc: 83.120  Loss:  0.5651  Time(s):   10.82
# Forgetting : Epoch 19, mean_FgT_loss = -0.132021
# ==========================================================
#  Train => Epoch 020  Acc: 90.938  Loss:  0.2568  LR: 0.01000
#  Test  => Epoch 020  Acc: 85.690  Loss:  0.4548  Time(s):   10.80
# Forgetting : Epoch 20, mean_FgT_loss = -0.231505
# ==========================================================
#  Train => Epoch 021  Acc: 91.426  Loss:  0.2440  LR: 0.01000
#  Test  => Epoch 021  Acc: 85.810  Loss:  0.4588  Time(s):   10.84
# Forgetting : Epoch 21, mean_FgT_loss = -0.204949
# ==========================================================
#  Train => Epoch 022  Acc: 91.820  Loss:  0.2361  LR: 0.01000
#  Test  => Epoch 022  Acc: 84.950  Loss:  0.4879  Time(s):   10.80
# Forgetting : Epoch 22, mean_FgT_loss = -0.187848
# ==========================================================
#  Train => Epoch 023  Acc: 92.320  Loss:  0.2199  LR: 0.01000
#  Test  => Epoch 023  Acc: 85.290  Loss:  0.4833  Time(s):   10.82
# Forgetting : Epoch 23, mean_FgT_loss = -0.175827
# ==========================================================
#  Train => Epoch 024  Acc: 92.516  Loss:  0.2095  LR: 0.01000
#  Test  => Epoch 024  Acc: 86.210  Loss:  0.4672  Time(s):   10.81
# Forgetting : Epoch 24, mean_FgT_loss = -0.199699
# ==========================================================
#  Train => Epoch 025  Acc: 92.870  Loss:  0.2024  LR: 0.01000
#  Test  => Epoch 025  Acc: 84.940  Loss:  0.5255  Time(s):   10.77
# Forgetting : Epoch 25, mean_FgT_loss = -0.126523
# ==========================================================
#  Train => Epoch 026  Acc: 93.224  Loss:  0.1947  LR: 0.01000
#  Test  => Epoch 026  Acc: 87.310  Loss:  0.4265  Time(s):   10.78
# Forgetting : Epoch 26, mean_FgT_loss = -0.218680
# ==========================================================
#  Train => Epoch 027  Acc: 93.362  Loss:  0.1870  LR: 0.01000
#  Test  => Epoch 027  Acc: 85.850  Loss:  0.5016  Time(s):   10.80
# Forgetting : Epoch 27, mean_FgT_loss = -0.147527
# ==========================================================
#  Train => Epoch 028  Acc: 93.956  Loss:  0.1751  LR: 0.01000
#  Test  => Epoch 028  Acc: 86.210  Loss:  0.4715  Time(s):   10.78
# Forgetting : Epoch 28, mean_FgT_loss = -0.192112
# ==========================================================
#  Train => Epoch 029  Acc: 94.162  Loss:  0.1686  LR: 0.01000
#  Test  => Epoch 029  Acc: 88.000  Loss:  0.4142  Time(s):   10.77
# Forgetting : Epoch 29, mean_FgT_loss = -0.214188
# ==========================================================
#  Train => Epoch 030  Acc: 94.100  Loss:  0.1645  LR: 0.01000
#  Test  => Epoch 030  Acc: 85.470  Loss:  0.4996  Time(s):   10.43
# Forgetting : Epoch 30, mean_FgT_loss = -0.146000
# ==========================================================
#  Train => Epoch 031  Acc: 94.376  Loss:  0.1579  LR: 0.01000
#  Test  => Epoch 031  Acc: 88.260  Loss:  0.3937  Time(s):   10.79
# Forgetting : Epoch 31, mean_FgT_loss = -0.231692
# ==========================================================
#  Train => Epoch 032  Acc: 94.856  Loss:  0.1492  LR: 0.01000
#  Test  => Epoch 032  Acc: 87.220  Loss:  0.4502  Time(s):   10.93
# Forgetting : Epoch 32, mean_FgT_loss = -0.163645
# ==========================================================
#  Train => Epoch 033  Acc: 95.232  Loss:  0.1351  LR: 0.01000
#  Test  => Epoch 033  Acc: 86.270  Loss:  0.4887  Time(s):   10.79
# Forgetting : Epoch 33, mean_FgT_loss = -0.134058
# ==========================================================
#  Train => Epoch 034  Acc: 95.322  Loss:  0.1333  LR: 0.01000
#  Test  => Epoch 034  Acc: 87.280  Loss:  0.4570  Time(s):   10.79
# Forgetting : Epoch 34, mean_FgT_loss = -0.145123
# ==========================================================
#  Train => Epoch 035  Acc: 95.566  Loss:  0.1265  LR: 0.01000
#  Test  => Epoch 035  Acc: 88.850  Loss:  0.3962  Time(s):   10.81
# Forgetting : Epoch 35, mean_FgT_loss = -0.227382
# ==========================================================
#  Train => Epoch 036  Acc: 95.528  Loss:  0.1233  LR: 0.01000
#  Test  => Epoch 036  Acc: 87.920  Loss:  0.4427  Time(s):   10.79
# Forgetting : Epoch 36, mean_FgT_loss = -0.155463
# ==========================================================
#  Train => Epoch 037  Acc: 95.922  Loss:  0.1129  LR: 0.01000
#  Test  => Epoch 037  Acc: 87.840  Loss:  0.4530  Time(s):   10.79
# Forgetting : Epoch 37, mean_FgT_loss = -0.126227
# ==========================================================
#  Train => Epoch 038  Acc: 96.156  Loss:  0.1085  LR: 0.01000
#  Test  => Epoch 038  Acc: 88.360  Loss:  0.4288  Time(s):   10.81
# Forgetting : Epoch 38, mean_FgT_loss = -0.162913
# ==========================================================
#  Train => Epoch 039  Acc: 96.280  Loss:  0.1051  LR: 0.01000
#  Test  => Epoch 039  Acc: 88.550  Loss:  0.4431  Time(s):   10.78
# Forgetting : Epoch 39, mean_FgT_loss = -0.149554
# ==========================================================
#  Train => Epoch 040  Acc: 96.184  Loss:  0.1092  LR: 0.01000
#  Test  => Epoch 040  Acc: 88.810  Loss:  0.4137  Time(s):   10.83
# Forgetting : Epoch 40, mean_FgT_loss = -0.162817
# ==========================================================
#  Train => Epoch 041  Acc: 96.330  Loss:  0.1012  LR: 0.01000
#  Test  => Epoch 041  Acc: 88.900  Loss:  0.4217  Time(s):   10.79
# Forgetting : Epoch 41, mean_FgT_loss = -0.154565
# ==========================================================
#  Train => Epoch 042  Acc: 96.560  Loss:  0.0989  LR: 0.01000
#  Test  => Epoch 042  Acc: 87.490  Loss:  0.4943  Time(s):   10.78
# Forgetting : Epoch 42, mean_FgT_loss = -0.090312
# ==========================================================
#  Train => Epoch 043  Acc: 96.680  Loss:  0.0953  LR: 0.01000
#  Test  => Epoch 043  Acc: 86.610  Loss:  0.5564  Time(s):   10.77
# Forgetting : Epoch 43, mean_FgT_loss = -0.004400
# ==========================================================
#  Train => Epoch 044  Acc: 96.890  Loss:  0.0888  LR: 0.01000
#  Test  => Epoch 044  Acc: 87.690  Loss:  0.4768  Time(s):   10.76
# Forgetting : Epoch 44, mean_FgT_loss = -0.110556
# ==========================================================
#  Train => Epoch 045  Acc: 96.920  Loss:  0.0893  LR: 0.01000
#  Test  => Epoch 045  Acc: 88.450  Loss:  0.4564  Time(s):   10.81
# Forgetting : Epoch 45, mean_FgT_loss = -0.141651
# ==========================================================
#  Train => Epoch 046  Acc: 97.130  Loss:  0.0827  LR: 0.01000
#  Test  => Epoch 046  Acc: 88.270  Loss:  0.4437  Time(s):   10.72
# Forgetting : Epoch 46, mean_FgT_loss = -0.137541
# ==========================================================
#  Train => Epoch 047  Acc: 97.056  Loss:  0.0833  LR: 0.01000
#  Test  => Epoch 047  Acc: 89.020  Loss:  0.4272  Time(s):   10.79
# Forgetting : Epoch 47, mean_FgT_loss = -0.159221
# ==========================================================
#  Train => Epoch 048  Acc: 97.410  Loss:  0.0744  LR: 0.01000
#  Test  => Epoch 048  Acc: 84.820  Loss:  0.6527  Time(s):   10.80
# Forgetting : Epoch 48, mean_FgT_loss = 0.070641
# ==========================================================
#  Train => Epoch 049  Acc: 97.180  Loss:  0.0809  LR: 0.01000
#  Test  => Epoch 049  Acc: 88.880  Loss:  0.4485  Time(s):   10.78
# Forgetting : Epoch 49, mean_FgT_loss = -0.125658
# ==========================================================
#  Train => Epoch 050  Acc: 97.552  Loss:  0.0687  LR: 0.01000
#  Test  => Epoch 050  Acc: 89.380  Loss:  0.4147  Time(s):   10.79
# Forgetting : Epoch 50, mean_FgT_loss = -0.152813
# ==========================================================
#  Train => Epoch 051  Acc: 97.488  Loss:  0.0697  LR: 0.01000
#  Test  => Epoch 051  Acc: 88.010  Loss:  0.4879  Time(s):   10.92
# Forgetting : Epoch 51, mean_FgT_loss = -0.069128
# ==========================================================
#  Train => Epoch 052  Acc: 97.614  Loss:  0.0683  LR: 0.01000
#  Test  => Epoch 052  Acc: 88.790  Loss:  0.4511  Time(s):   10.76
# Forgetting : Epoch 52, mean_FgT_loss = -0.115321
# ==========================================================
#  Train => Epoch 053  Acc: 97.566  Loss:  0.0689  LR: 0.01000
#  Test  => Epoch 053  Acc: 89.260  Loss:  0.4191  Time(s):   10.80
# Forgetting : Epoch 53, mean_FgT_loss = -0.142644
# ==========================================================
#  Train => Epoch 054  Acc: 97.484  Loss:  0.0689  LR: 0.01000
#  Test  => Epoch 054  Acc: 88.730  Loss:  0.4677  Time(s):   10.45
# Forgetting : Epoch 54, mean_FgT_loss = -0.092126
# ==========================================================
#  Train => Epoch 055  Acc: 97.590  Loss:  0.0691  LR: 0.01000
#  Test  => Epoch 055  Acc: 89.600  Loss:  0.4129  Time(s):   10.79
# Forgetting : Epoch 55, mean_FgT_loss = -0.164344
# ==========================================================
#  Train => Epoch 056  Acc: 97.690  Loss:  0.0648  LR: 0.01000
#  Test  => Epoch 056  Acc: 88.550  Loss:  0.4484  Time(s):   10.78
# Forgetting : Epoch 56, mean_FgT_loss = -0.105312
# ==========================================================
#  Train => Epoch 057  Acc: 98.058  Loss:  0.0567  LR: 0.01000
#  Test  => Epoch 057  Acc: 88.940  Loss:  0.4625  Time(s):   10.77
# Forgetting : Epoch 57, mean_FgT_loss = -0.093847
# ==========================================================
#  Train => Epoch 058  Acc: 97.798  Loss:  0.0633  LR: 0.01000
#  Test  => Epoch 058  Acc: 89.980  Loss:  0.4100  Time(s):   10.80
# Forgetting : Epoch 58, mean_FgT_loss = -0.133946
# ==========================================================
#  Train => Epoch 059  Acc: 98.066  Loss:  0.0555  LR: 0.01000
#  Test  => Epoch 059  Acc: 87.610  Loss:  0.5108  Time(s):   10.77
# Forgetting : Epoch 59, mean_FgT_loss = -0.039154
# ==========================================================
#  Train => Epoch 060  Acc: 98.064  Loss:  0.0562  LR: 0.01000
#  Test  => Epoch 060  Acc: 90.460  Loss:  0.3940  Time(s):   10.78
# Forgetting : Epoch 60, mean_FgT_loss = -0.154873
# ==========================================================
#  Train => Epoch 061  Acc: 98.332  Loss:  0.0511  LR: 0.01000
#  Test  => Epoch 061  Acc: 89.220  Loss:  0.4377  Time(s):   10.85
# Forgetting : Epoch 61, mean_FgT_loss = -0.112861
# ==========================================================
#  Train => Epoch 062  Acc: 98.532  Loss:  0.0440  LR: 0.01000
#  Test  => Epoch 062  Acc: 89.360  Loss:  0.4539  Time(s):   10.77
# Forgetting : Epoch 62, mean_FgT_loss = -0.093297
# ==========================================================
#  Train => Epoch 063  Acc: 98.262  Loss:  0.0511  LR: 0.01000
#  Test  => Epoch 063  Acc: 88.470  Loss:  0.4680  Time(s):   10.76
# Forgetting : Epoch 63, mean_FgT_loss = -0.077053
# ==========================================================
#  Train => Epoch 064  Acc: 98.252  Loss:  0.0512  LR: 0.01000
#  Test  => Epoch 064  Acc: 90.690  Loss:  0.3810  Time(s):   10.80
# Forgetting : Epoch 64, mean_FgT_loss = -0.163640
# ==========================================================
#  Train => Epoch 065  Acc: 98.346  Loss:  0.0484  LR: 0.01000
#  Test  => Epoch 065  Acc: 89.010  Loss:  0.4731  Time(s):   10.78
# Forgetting : Epoch 65, mean_FgT_loss = -0.071622
# ==========================================================
#  Train => Epoch 066  Acc: 97.972  Loss:  0.0569  LR: 0.01000
#  Test  => Epoch 066  Acc: 88.870  Loss:  0.4588  Time(s):   10.79
# Forgetting : Epoch 66, mean_FgT_loss = -0.091832
# ==========================================================
#  Train => Epoch 067  Acc: 98.190  Loss:  0.0530  LR: 0.01000
#  Test  => Epoch 067  Acc: 89.680  Loss:  0.4242  Time(s):   10.79
# Forgetting : Epoch 67, mean_FgT_loss = -0.114984
# ==========================================================
#  Train => Epoch 068  Acc: 98.746  Loss:  0.0395  LR: 0.01000
#  Test  => Epoch 068  Acc: 90.290  Loss:  0.3971  Time(s):   10.79
# Forgetting : Epoch 68, mean_FgT_loss = -0.142198
# ==========================================================
#  Train => Epoch 069  Acc: 98.472  Loss:  0.0444  LR: 0.01000
#  Test  => Epoch 069  Acc: 90.260  Loss:  0.3951  Time(s):   10.77
# Forgetting : Epoch 69, mean_FgT_loss = -0.140091
# ==========================================================
#  Train => Epoch 070  Acc: 98.448  Loss:  0.0454  LR: 0.01000
#  Test  => Epoch 070  Acc: 89.570  Loss:  0.4188  Time(s):   10.78
# Forgetting : Epoch 70, mean_FgT_loss = -0.118982
# ==========================================================
#  Train => Epoch 071  Acc: 98.512  Loss:  0.0430  LR: 0.01000
#  Test  => Epoch 071  Acc: 89.350  Loss:  0.4441  Time(s):   10.78
# Forgetting : Epoch 71, mean_FgT_loss = -0.099510
# ==========================================================
#  Train => Epoch 072  Acc: 98.286  Loss:  0.0488  LR: 0.01000
#  Test  => Epoch 072  Acc: 88.950  Loss:  0.4682  Time(s):   10.83
# Forgetting : Epoch 72, mean_FgT_loss = -0.060423
# ==========================================================
#  Train => Epoch 073  Acc: 98.704  Loss:  0.0397  LR: 0.01000
#  Test  => Epoch 073  Acc: 87.590  Loss:  0.5337  Time(s):   10.80
# Forgetting : Epoch 73, mean_FgT_loss = -0.011721
# ==========================================================
#  Train => Epoch 074  Acc: 98.476  Loss:  0.0440  LR: 0.01000
#  Test  => Epoch 074  Acc: 89.520  Loss:  0.4514  Time(s):   10.48
# Forgetting : Epoch 74, mean_FgT_loss = -0.076376
# ==========================================================
#  Train => Epoch 075  Acc: 98.722  Loss:  0.0395  LR: 0.01000
#  Test  => Epoch 075  Acc: 89.660  Loss:  0.4379  Time(s):   10.80
# Forgetting : Epoch 75, mean_FgT_loss = -0.088915
# ==========================================================
#  Train => Epoch 076  Acc: 98.618  Loss:  0.0410  LR: 0.01000
#  Test  => Epoch 076  Acc: 89.760  Loss:  0.4075  Time(s):   10.78
# Forgetting : Epoch 76, mean_FgT_loss = -0.117878
# ==========================================================
#  Train => Epoch 077  Acc: 98.654  Loss:  0.0396  LR: 0.01000
#  Test  => Epoch 077  Acc: 90.440  Loss:  0.3876  Time(s):   10.79
# Forgetting : Epoch 77, mean_FgT_loss = -0.146020
# ==========================================================
#  Train => Epoch 078  Acc: 98.538  Loss:  0.0448  LR: 0.01000
#  Test  => Epoch 078  Acc: 88.860  Loss:  0.4649  Time(s):   10.78
# Forgetting : Epoch 78, mean_FgT_loss = -0.059551
# ==========================================================
#  Train => Epoch 079  Acc: 98.454  Loss:  0.0449  LR: 0.01000
#  Test  => Epoch 079  Acc: 89.310  Loss:  0.4487  Time(s):   10.80
# Forgetting : Epoch 79, mean_FgT_loss = -0.084624
# ==========================================================
#  Train => Epoch 080  Acc: 98.684  Loss:  0.0391  LR: 0.01000
#  Test  => Epoch 080  Acc: 89.690  Loss:  0.4268  Time(s):   10.80
# Forgetting : Epoch 80, mean_FgT_loss = -0.088804
# ==========================================================
#  Train => Epoch 081  Acc: 98.900  Loss:  0.0358  LR: 0.01000
#  Test  => Epoch 081  Acc: 89.550  Loss:  0.4112  Time(s):   10.79
# Forgetting : Epoch 81, mean_FgT_loss = -0.104393
# ==========================================================
#  Train => Epoch 082  Acc: 98.942  Loss:  0.0328  LR: 0.01000
#  Test  => Epoch 082  Acc: 89.290  Loss:  0.4733  Time(s):   10.82
# Forgetting : Epoch 82, mean_FgT_loss = -0.050585
# ==========================================================
#  Train => Epoch 083  Acc: 98.630  Loss:  0.0410  LR: 0.01000
#  Test  => Epoch 083  Acc: 90.580  Loss:  0.3935  Time(s):   10.79
# Forgetting : Epoch 83, mean_FgT_loss = -0.124515
# ==========================================================
#  Train => Epoch 084  Acc: 98.768  Loss:  0.0369  LR: 0.01000
#  Test  => Epoch 084  Acc: 89.110  Loss:  0.4436  Time(s):   10.76
# Forgetting : Epoch 84, mean_FgT_loss = -0.074928
# ==========================================================
#  Train => Epoch 085  Acc: 99.006  Loss:  0.0323  LR: 0.01000
#  Test  => Epoch 085  Acc: 91.160  Loss:  0.3625  Time(s):   10.81
# Forgetting : Epoch 85, mean_FgT_loss = -0.152090
# ==========================================================
#  Train => Epoch 086  Acc: 98.838  Loss:  0.0353  LR: 0.01000
#  Test  => Epoch 086  Acc: 90.250  Loss:  0.3915  Time(s):   10.77
# Forgetting : Epoch 86, mean_FgT_loss = -0.122479
# ==========================================================
#  Train => Epoch 087  Acc: 98.516  Loss:  0.0426  LR: 0.01000
#  Test  => Epoch 087  Acc: 89.950  Loss:  0.4254  Time(s):   10.78
# Forgetting : Epoch 87, mean_FgT_loss = -0.084937
# ==========================================================
#  Train => Epoch 088  Acc: 98.738  Loss:  0.0369  LR: 0.01000
#  Test  => Epoch 088  Acc: 89.570  Loss:  0.4330  Time(s):   10.95
# Forgetting : Epoch 88, mean_FgT_loss = -0.074002
# ==========================================================
#  Train => Epoch 089  Acc: 98.542  Loss:  0.0438  LR: 0.01000
#  Test  => Epoch 089  Acc: 89.820  Loss:  0.4320  Time(s):   10.51
# Forgetting : Epoch 89, mean_FgT_loss = -0.074382
# ==========================================================
#  Train => Epoch 090  Acc: 98.838  Loss:  0.0348  LR: 0.01000
#  Test  => Epoch 090  Acc: 89.820  Loss:  0.4330  Time(s):   10.94
# Forgetting : Epoch 90, mean_FgT_loss = -0.075479
# ==========================================================
#  Train => Epoch 091  Acc: 98.792  Loss:  0.0346  LR: 0.01000
#  Test  => Epoch 091  Acc: 89.970  Loss:  0.4201  Time(s):   10.45
# Forgetting : Epoch 91, mean_FgT_loss = -0.084796
# ==========================================================
#  Train => Epoch 092  Acc: 98.864  Loss:  0.0347  LR: 0.01000
#  Test  => Epoch 092  Acc: 90.080  Loss:  0.4028  Time(s):   10.51
# Forgetting : Epoch 92, mean_FgT_loss = -0.101972
# ==========================================================
#  Train => Epoch 093  Acc: 99.078  Loss:  0.0300  LR: 0.01000
#  Test  => Epoch 093  Acc: 90.390  Loss:  0.3917  Time(s):   10.79
# Forgetting : Epoch 93, mean_FgT_loss = -0.110570
# ==========================================================
#  Train => Epoch 094  Acc: 98.720  Loss:  0.0379  LR: 0.01000
#  Test  => Epoch 094  Acc: 90.670  Loss:  0.3743  Time(s):   10.78
# Forgetting : Epoch 94, mean_FgT_loss = -0.127572
# ==========================================================
#  Train => Epoch 095  Acc: 98.878  Loss:  0.0336  LR: 0.01000
#  Test  => Epoch 095  Acc: 90.710  Loss:  0.3718  Time(s):   12.84
# Forgetting : Epoch 95, mean_FgT_loss = -0.128652
# ==========================================================
#  Train => Epoch 096  Acc: 98.846  Loss:  0.0348  LR: 0.01000
#  Test  => Epoch 096  Acc: 89.980  Loss:  0.3883  Time(s):   12.78
# Forgetting : Epoch 96, mean_FgT_loss = -0.109915
# ==========================================================
#  Train => Epoch 097  Acc: 98.764  Loss:  0.0372  LR: 0.01000
#  Test  => Epoch 097  Acc: 90.480  Loss:  0.3891  Time(s):   12.93
# Forgetting : Epoch 97, mean_FgT_loss = -0.110741
# ==========================================================
#  Train => Epoch 098  Acc: 99.088  Loss:  0.0294  LR: 0.01000
#  Test  => Epoch 098  Acc: 90.520  Loss:  0.3807  Time(s):   10.79
# Forgetting : Epoch 98, mean_FgT_loss = -0.117280
# ==========================================================
#  Train => Epoch 099  Acc: 98.876  Loss:  0.0341  LR: 0.01000
#  Test  => Epoch 099  Acc: 90.610  Loss:  0.3791  Time(s):   10.80
# Forgetting : Epoch 99, mean_FgT_loss = -0.116431
# ==========================================================
# Training and Evaluation completed!
# Saved: Centralize Baseline - CIFAR-10.csv
