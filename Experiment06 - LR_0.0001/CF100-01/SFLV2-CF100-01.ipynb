# %% [markdown]
# # Split Federated Learning V2:
# ### ResNet18 on CIFAR-10 + α = 0.1

# %%
#=============================================================================
# SplitfedV2 (SFLV2) learning: ResNet18 on CIFAR-10
# Version2: with using socket but no DP+PixelDP
# ==============================================================================
import torch
from torch import nn
from torchvision import transforms
from torch.utils.data import DataLoader, Dataset
import torch.nn.functional as F
import math
import os.path
import pandas as pd
from sklearn.model_selection import train_test_split
from PIL import Image
from glob import glob
from pandas import DataFrame
import random
import numpy as np
import os


import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import copy
import time


#====================Parameters Change===============================
program = "SFLV2 - CIFAR-100 α=0.1"
DATASET_NAME = "CIFAR100"            # Set toggle between CIFAR-10 and CIFAR-100
ALPHA = 0.1   # requested alpha


DATA_ROOT = "data"                  # Set where torchvision stores CIFAR data
print(f"---------{program}----------")              # this is to identify the program in the slurm outputs files


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
pin = torch.cuda.is_available()


# To print in color -------test/train of the client side
def prRed(skk): print("\033[91m {}\033[00m" .format(skk)) 
def prGreen(skk): print("\033[92m {}\033[00m" .format(skk))     


#===================================================================
# No. of users
NUM_CLIENTS = 10
EPOCHS = 200
LOCAL_EPOCHS = 5
FRAC = 1        # participation of clients; if 1 then 100% clients participate in SFLV2



# ----------------------------- Optimization ------------------------------ #
BATCH_SIZE = 256
LR_BASE = 0.0001  
WARMUP_ROUNDS = 0
MOMENTUM = 0.9                     # Smoothing/Accelerating SGD undates
WEIGHT_DECAY = 5e-4                # L2 Regularization
LABEL_SMOOTH = 0.0
NUM_WORKERS = 4
SEED = 1234



def _sync_cuda():
    if torch.cuda.is_available():
        torch.cuda.synchronize()


SEED = 1234
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
if torch.cuda.is_available():
    torch.backends.cudnn.deterministic = True
    print(torch.cuda.get_device_name(0))    




#=====================================================================================================
#                                  Baseblock
#=====================================================================================================
class Baseblock(nn.Module):
    expansion = 1
    def __init__(self, input_planes, planes, stride = 1, dim_change = None):
        super(Baseblock, self).__init__()
        self.conv1 = nn.Conv2d(input_planes, planes, stride =  stride, kernel_size = 3, padding = 1)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, stride = 1, kernel_size = 3, padding = 1)
        self.bn2 = nn.BatchNorm2d(planes)
        self.dim_change = dim_change
        
    def forward(self, x):
        res = x
        output = F.relu(self.bn1(self.conv1(x)))
        output = self.bn2(self.conv2(output))
        
        if self.dim_change is not None:
            res =self.dim_change(res)
            
        output += res
        output = F.relu(output)
        
        return output
        
#=====================================================================================================
#                           Client-side Model definition
#=====================================================================================================
# Model at client side
class ResNet18_client_side(nn.Module):
    def __init__(self, block, num_layers):
        super().__init__()
        self.layer1 = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False),  # 3x3 s=1
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            # no maxpool for 32x32
        )
        self.layer2 = nn.Sequential(
            nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(64),
        )

        # add layer 3-6 + avg-pool (copied from Client)
        self.layer3 = nn.Sequential (
                nn.Conv2d(64, 64, kernel_size = 3, stride = 1, padding = 1),
                nn.BatchNorm2d(64),
                nn.ReLU (inplace = True),
                nn.Conv2d(64, 64, kernel_size = 3, stride = 1, padding = 1),
                nn.BatchNorm2d(64),       
                )   

        self.input_planes = 64
        
        self.layer4 = self._layer(block, 128, num_layers[0], stride = 2)
        self.layer5 = self._layer(block, 256, num_layers[1], stride = 2)
        self.layer6 = self._layer(block, 512, num_layers[2], stride = 2)
        
        # self. averagePool = nn.AvgPool2d(kernel_size = 7, stride = 1)
        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))


        # Weights into loop (the same thing as SERVER)
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                m.weight.data.normal_(0, math.sqrt(2. / n))
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()

        
        
        
    def _layer(self, block, planes, num_layers, stride = 2):
        dim_change = None
        if stride != 1 or planes != self.input_planes * block.expansion:
            dim_change = nn.Sequential(nn.Conv2d(self.input_planes, planes*block.expansion, kernel_size = 1, stride = stride),
                                       nn.BatchNorm2d(planes*block.expansion))
        netLayers = []
        netLayers.append(block(self.input_planes, planes, stride = stride, dim_change = dim_change))
        self.input_planes = planes * block.expansion
        for i in range(1, num_layers):
            netLayers.append(block(self.input_planes, planes))
            self.input_planes = planes * block.expansion
            
        return nn.Sequential(*netLayers)
        
        
    def forward(self, x):
        resudial1 = F.relu(self.layer1(x))
        out1 = self.layer2(resudial1)
        out1 = out1 + resudial1 # adding the resudial inputs -- downsampling not required in this layer
        x = F.relu(out1)

        out2 = self.layer3(x)
        out2 = out2 + x
        x = F.relu(out2)

        x = self.layer4(x)
        x = self.layer5(x)
        x = self.layer6(x)

        x = self.avgpool(x)                   # shape [B, 512, 1, 1]
        return x
 

net_glob_client = ResNet18_client_side(Baseblock, [2, 2, 2])
if torch.cuda.device_count() > 1:
    print("We use",torch.cuda.device_count(), "GPUs")
    net_glob_client = nn.DataParallel(net_glob_client)   # to use the multiple GPUs; later we can change this to CPUs only 

net_glob_client.to(device)
print(net_glob_client)    

#=====================================================================================================
#                           Server-side Model definition
#=====================================================================================================
# Model at server side
class ResNet18_server_side(nn.Module):
    def __init__(self, block, classes):
        super(ResNet18_server_side, self).__init__()
        self.fc = nn.Linear(512 * block.expansion, classes)
        
    
    def forward(self, x):
        # x = [B, 512, 1, 1] from the Client side
        x = x.view(x.size(0), -1)     # [B, 512] 
        y_hat =self.fc(x)
        
        return y_hat
        

if DATASET_NAME == "CIFAR10":
    net_glob_server = ResNet18_server_side(Baseblock, 10) #10 CIFAR-10
else:
    net_glob_server = ResNet18_server_side(Baseblock, 100) #100 CIFAR-100
    

if torch.cuda.device_count() > 1:
    print("We use",torch.cuda.device_count(), "GPUs")
    net_glob_server = nn.DataParallel(net_glob_server)   # to use the multiple GPUs 


net_glob_server.to(device)
print(net_glob_server)      

#===================================================================================
# For Server Side Loss and Accuracy 
loss_train_collect = []
acc_train_collect = []
loss_test_collect = []
acc_test_collect = []
batch_acc_train = []
batch_loss_train = []
batch_acc_test = []
batch_loss_test = []
round_time_collect = [] # Stores seconds per global round

criterion = nn.CrossEntropyLoss()
count1 = 0
count2 = 0

#====================================================================================================
#                                  Server Side Programs
#====================================================================================================
# Federated averaging: FedAvg
def FedAvg(w):
    w_avg = copy.deepcopy(w[0])
    for k in w_avg.keys():
        for i in range(1, len(w)):
            w_avg[k] += w[i][k]
        w_avg[k] = torch.div(w_avg[k], len(w))
    return w_avg

def calculate_accuracy(fx, y):
    preds = fx.max(1, keepdim=True)[1]
    correct = preds.eq(y.view_as(preds)).sum()
    acc = 100.00 *correct.float()/preds.shape[0]
    return acc

# to print train - test together in each round-- these are made global
acc_avg_all_user_train = 0
loss_avg_all_user_train = 0
loss_train_collect_user = []
acc_train_collect_user = []
loss_test_collect_user = []
acc_test_collect_user = []


#client idx collector
idx_collect = []
l_epoch_check = False
fed_check = False

# Server-side function associated with Training 
def train_server(fx_client, y, l_epoch_count, l_epoch, idx, len_batch):
    global net_glob_server, criterion, device, batch_acc_train, batch_loss_train, l_epoch_check, fed_check
    global loss_train_collect, acc_train_collect, count1, acc_avg_all_user_train, loss_avg_all_user_train, idx_collect
    global loss_train_collect_user, acc_train_collect_user, LR_BASE
    
    net_glob_server.train()
    optimizer_server = torch.optim.SGD(
        net_glob_server.parameters(), 
        lr = LR_BASE,
        momentum=MOMENTUM,
        weight_decay=WEIGHT_DECAY
    )

    
    # train and update
    optimizer_server.zero_grad()
    
    fx_client = fx_client.to(device)
    y = y.to(device)
    
    #---------forward prop-------------
    fx_server = net_glob_server(fx_client)
    
    # calculate loss
    loss = criterion(fx_server, y)
    # calculate accuracy
    acc = calculate_accuracy(fx_server, y)
    
    #--------backward prop--------------
    loss.backward()
    dfx_client = fx_client.grad.clone().detach()
    optimizer_server.step()
    
    batch_loss_train.append(loss.item())
    batch_acc_train.append(acc.item())
    
    
    # server-side model net_glob_server is global so it is updated automatically in each pass to this function
    # count1: to track the completion of the local batch associated with one client
    count1 += 1
    if count1 == len_batch:
        acc_avg_train = sum(batch_acc_train)/len(batch_acc_train)           # it has accuracy for one batch
        loss_avg_train = sum(batch_loss_train)/len(batch_loss_train)
        
        batch_acc_train = []
        batch_loss_train = []
        count1 = 0
        
        prRed('Client{} Train => Local Epoch: {} \tAcc: {:.3f} \tLoss: {:.4f}'.format(idx, l_epoch_count, acc_avg_train, loss_avg_train))
        
                
        # If one local epoch is completed, after this a new client will come
        if l_epoch_count == l_epoch-1:
            
            l_epoch_check = True                # to evaluate_server function - to check local epoch has completed or not
                       
            # we store the last accuracy in the last batch of the epoch and it is not the average of all local epochs
            # this is because we work on the last trained model and its accuracy (not earlier cases)
            
            #print("accuracy = ", acc_avg_train)
            acc_avg_train_all = acc_avg_train
            loss_avg_train_all = loss_avg_train
                        
            # accumulate accuracy and loss for each new user
            loss_train_collect_user.append(loss_avg_train_all)
            acc_train_collect_user.append(acc_avg_train_all)
            
            # collect the id of each new user                        
            if idx not in idx_collect:
                idx_collect.append(idx) 
                #print(idx_collect)
        
        # This is to check if all users are served for one round --------------------
        if len(idx_collect) == NUM_CLIENTS:
            fed_check = True                                                  # to evaluate_server function  - to check fed check has hitted
            # all users served for one round ------------------------- output print and update is done in evaluate_server()
            # for nicer display 
                        
            idx_collect = []
            
            acc_avg_all_user_train = sum(acc_train_collect_user)/len(acc_train_collect_user)
            loss_avg_all_user_train = sum(loss_train_collect_user)/len(loss_train_collect_user)
            
            loss_train_collect.append(loss_avg_all_user_train)
            acc_train_collect.append(acc_avg_all_user_train)
            
            acc_train_collect_user = []
            loss_train_collect_user = []
            
    # send gradients to the client               
    return dfx_client

# Server-side functions associated with Testing
def evaluate_server(fx_client, y, idx, len_batch, ell):
    global net_glob_server, criterion, batch_acc_test, batch_loss_test
    global loss_test_collect, acc_test_collect, count2, NUM_CLIENTS, acc_avg_train_all, loss_avg_train_all, l_epoch_check, fed_check
    global loss_test_collect_user, acc_test_collect_user, acc_avg_all_user_train, loss_avg_all_user_train
    
    net_glob_server.eval()
  
    with torch.no_grad():
        fx_client = fx_client.to(device)
        y = y.to(device) 
        #---------forward prop-------------
        fx_server = net_glob_server(fx_client)
        
        # calculate loss
        loss = criterion(fx_server, y)
        # calculate accuracy
        acc = calculate_accuracy(fx_server, y)
        
        
        batch_loss_test.append(loss.item())
        batch_acc_test.append(acc.item())
        
               
        count2 += 1
        if count2 == len_batch:
            acc_avg_test = sum(batch_acc_test)/len(batch_acc_test)
            loss_avg_test = sum(batch_loss_test)/len(batch_loss_test)
            
            batch_acc_test = []
            batch_loss_test = []
            count2 = 0
            
            prGreen('Client{} Test =>                   \tAcc: {:.3f} \tLoss: {:.4f}'.format(idx, acc_avg_test, loss_avg_test))
            
            # if a local epoch is completed   
            if l_epoch_check:
                l_epoch_check = False
                
                # Store the last accuracy and loss
                acc_avg_test_all = acc_avg_test
                loss_avg_test_all = loss_avg_test
                        
                loss_test_collect_user.append(loss_avg_test_all)
                acc_test_collect_user.append(acc_avg_test_all)
                
            # if all users are served for one round ----------                    
            if fed_check:
                fed_check = False
                                
                acc_avg_all_user = sum(acc_test_collect_user)/len(acc_test_collect_user)
                loss_avg_all_user = sum(loss_test_collect_user)/len(loss_test_collect_user)
            
                loss_test_collect.append(loss_avg_all_user)
                acc_test_collect.append(acc_avg_all_user)
                acc_test_collect_user = []
                loss_test_collect_user= []
                              
                print("====================== SERVER V1==========================")
                print(' Train: Round {:3d}, Avg Accuracy {:.3f} | Avg Loss {:.3f}'.format(ell, acc_avg_all_user_train, loss_avg_all_user_train))
                print(' Test: Round {:3d}, Avg Accuracy {:.3f} | Avg Loss {:.3f}'.format(ell, acc_avg_all_user, loss_avg_all_user))
                # print("==========================================================")
         
    return 

#==============================================================================================================
#                                       Clients Side Program
#==============================================================================================================
class DatasetSplit(Dataset):
    def __init__(self, dataset, idxs):
        self.dataset = dataset
        self.idxs = list(idxs)

    def __len__(self):
        return len(self.idxs)

    def __getitem__(self, item):
        image, label = self.dataset[self.idxs[item]]
        return image, label

# Client-side functions associated with Training and Testing
class Client(object):
    def __init__(self, net_client_model, idx, LR_BASE, device, dataset_train = None, dataset_test = None, idxs = None, idxs_test = None):
        self.idx = idx
        self.device = device
        self.LR_BASE = LR_BASE
        self.local_ep = LOCAL_EPOCHS
        #self.selected_clients = []
        self.ldr_train = DataLoader(
            DatasetSplit(
                dataset_train, 
                idxs), 
            batch_size = BATCH_SIZE, 
            shuffle = True,
            num_workers=NUM_WORKERS,
            pin_memory=pin
        )
        self.ldr_test = DataLoader(
            DatasetSplit(
                dataset_test, 
                idxs_test), 
            batch_size = BATCH_SIZE, 
            shuffle = True,
            num_workers=NUM_WORKERS,
            pin_memory=pin
        )
        

    def train(self, net):
        net.train()
        optimizer_client = torch.optim.SGD(
            net.parameters(),
            lr = self.LR_BASE,
            momentum=MOMENTUM,
            weight_decay=WEIGHT_DECAY
        ) 
        
        for iter in range(self.local_ep):
            len_batch = len(self.ldr_train)
            for batch_idx, (images, labels) in enumerate(self.ldr_train):
                images, labels = images.to(self.device), labels.to(self.device)
                optimizer_client.zero_grad()
                #---------forward prop-------------
                fx = net(images)
                client_fx = fx.clone().detach().requires_grad_(True)
                
                # Sending activations to server and receiving gradients from server
                dfx = train_server(client_fx, labels, iter, self.local_ep, self.idx, len_batch)
                
                #--------backward prop -------------
                fx.backward(dfx)
                optimizer_client.step()
                            
            
            #prRed('Client{} Train => Epoch: {}'.format(self.idx, ell))
           
        return net.state_dict() 
    
    def evaluate(self, net, ell):
        net.eval()
           
        with torch.no_grad():
            len_batch = len(self.ldr_test)
            for batch_idx, (images, labels) in enumerate(self.ldr_test):
                images, labels = images.to(self.device), labels.to(self.device)
                #---------forward prop-------------
                fx = net(images)
                
                # Sending activations to server 
                evaluate_server(fx, labels, self.idx, len_batch, ell)
            
            #prRed('Client{} Test => Epoch: {}'.format(self.idx, ell))
            
        return          

#=====================================================================================================
# dataset_iid() will create a dictionary to collect the indices of the data samples randomly for each client
def dataset_iid(dataset, NUM_CLIENTS):
    
    num_items = int(len(dataset)/NUM_CLIENTS)
    dict_users, all_idxs = {}, [i for i in range(len(dataset))]
    for i in range(NUM_CLIENTS):
        dict_users[i] = set(np.random.choice(all_idxs, num_items, replace = False))
        all_idxs = list(set(all_idxs) - dict_users[i])
    return dict_users   

# Non-IID partition using Dirichlet distribution
def dataset_noniid_dirichlet(dataset, NUM_CLIENTS, alpha=0.1, seed=SEED):
    """
    Return dict_users: {client_id -> set(sample_indices)} using Dirichlet(α).
    Lower α → higher imbalance across clients.
    """
    rng = np.random.default_rng(seed)
    # CIFAR-10 and other torchvision datasets store labels in .targets
    labels = np.array(dataset.targets if hasattr(dataset, 'targets') else dataset.df['target'].values)
    n_classes = len(np.unique(labels))
    dict_users = {i: set() for i in range(NUM_CLIENTS)}

    for c in range(n_classes):
        idxs = np.where(labels == c)[0]
        rng.shuffle(idxs)

        # Draw class proportions for each client
        proportions = rng.dirichlet([alpha] * NUM_CLIENTS)

        # Compute index splits
        cuts = (np.cumsum(proportions) * len(idxs)).astype(int)[:-1]
        splits = np.split(idxs, cuts)

        for client_id, split in enumerate(splits):
            dict_users[client_id].update(split.tolist())

    return dict_users

#=============================================================================
#                         Data loading 
#============================================================================= 
from torchvision import datasets, transforms

# CIFAR-10 transforms
CIFAR_MEAN = {
    "CIFAR10":  [0.4914, 0.4822, 0.4465],
    "CIFAR100": [0.5071, 0.4867, 0.4408],
}[DATASET_NAME]
CIFAR_STD = {
    "CIFAR10":  [0.2470, 0.2435, 0.2616],
    "CIFAR100": [0.2675, 0.2565, 0.2761],
}[DATASET_NAME]
    

train_transforms = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(32, padding=4),
    transforms.ToTensor(),
    transforms.Normalize(CIFAR_MEAN, CIFAR_STD)
])

test_transforms = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(CIFAR_MEAN, CIFAR_STD)
])

# Download CIFAR datasets
if DATASET_NAME == "CIFAR10":
    dataset_train = datasets.CIFAR10(root=DATA_ROOT, train=True,  download=True, transform=train_transforms)
    dataset_test  = datasets.CIFAR10(root=DATA_ROOT, train=False, download=True, transform=test_transforms)
    NUM_CLASSES = 10
else:
    dataset_train = datasets.CIFAR100(root=DATA_ROOT, train=True,  download=True, transform=train_transforms)
    dataset_test  = datasets.CIFAR100(root=DATA_ROOT, train=False, download=True, transform=test_transforms)
    NUM_CLASSES = 100



print("Train samples:", len(dataset_train), " Test samples:", len(dataset_test))
print("Example train label:", dataset_train.targets[0])

#=============================================================================
#                         Forgetting metric setup 
#============================================================================= 

from collections import defaultdict

# Treat each global round as a window (quick baseline).
# If you want true distribution shifts, predefine your own windows and fill `val_loaders`.
T = EPOCHS
class DatasetSplit(Dataset):  # (you already have this in both scripts; keep just one copy)
    def __init__(self, dataset, idxs):
        self.dataset, self.idxs = dataset, list(idxs)
    def __len__(self): return len(self.idxs)
    def __getitem__(self, i): return self.dataset[self.idxs[i]]

val_loaders = {}
# Deterministic, disjoint slices of the test set: window t gets items t, t+T, t+2T, ...
rng_idx = np.arange(len(dataset_test))
for t in range(T):
    idxs = rng_idx[t::T]
    val_loaders[t] = DataLoader(
        DatasetSplit(
            dataset_test, 
            idxs),
        batch_size=BATCH_SIZE, 
        shuffle=False, 
        drop_last=False,
        num_workers=NUM_WORKERS,
        pin_memory=pin
    )

best_loss_per_window = defaultdict(lambda: float('inf'))  # stores min historical loss per window
forgetting_log = []  # per round dicts: {"round": t, "mean_forgetting": x, "per_window": {...}}
# ============================================================================

def _eval_loss_on_loader(model_client, model_server, loader, device, criterion):
    """Evaluate mean loss on a loader using split models."""
    # Handle DataParallel transparently
    mc = model_client.module if isinstance(model_client, nn.DataParallel) else model_client
    ms = model_server.module if isinstance(model_server, nn.DataParallel) else model_server
    mc.eval(); ms.eval()
    loss_sum, n = 0.0, 0
    with torch.no_grad():
        for images, labels in loader:
            images, labels = images.to(device), labels.to(device)
            fx = mc(images)
            logits = ms(fx)
            loss = criterion(logits, labels)
            bs = labels.size(0)
            loss_sum += loss.item() * bs
            n += bs
    return loss_sum / max(1, n)


#=============================================================================
#                         Dirichlet non-IID partition
#=============================================================================
dict_users = dataset_noniid_dirichlet(dataset_train, NUM_CLIENTS, alpha=ALPHA, seed=SEED)
dict_users_test = dataset_iid(dataset_test, NUM_CLIENTS)  # keep test IID


#------------ Training And Testing -----------------
net_glob_client.train()
#copy weights
w_glob_client = net_glob_client.state_dict()

#=============================================================================

# Federation takes place after certain local epochs in train() client-side
# this epoch is global epoch, also known as rounds
for iter in range(EPOCHS):
    # ---- START TIMER (train + test + FedAvg only) ----
    _sync_cuda()
    t_start = time.perf_counter()
    # --------------------------------------------------

    m = max(int(FRAC * NUM_CLIENTS), 1)
    idxs_users = np.random.choice(range(NUM_CLIENTS), m, replace=False)
    w_locals_client = []

    for idx in idxs_users:
        local = Client(net_glob_client, idx, LR_BASE, device,
                       dataset_train=dataset_train, dataset_test=dataset_test,
                       idxs=dict_users[idx], idxs_test=dict_users_test[idx])
        # Training
        w_client = local.train(net=copy.deepcopy(net_glob_client).to(device))
        w_locals_client.append(copy.deepcopy(w_client))

        # Testing
        local.evaluate(net=copy.deepcopy(net_glob_client).to(device), ell=iter)

    # ---------- Federation at client side ----------
    print("------------------------------------------------------------")
    print("------ Fed Server: Federation process at Client-Side -------")
    print("------------------------------------------------------------")
    w_glob_client = FedAvg(w_locals_client)
    net_glob_client.load_state_dict(w_glob_client)

    # ---- STOP TIMER & LOG ----
    _sync_cuda()
    dt = time.perf_counter() - t_start
    round_time_collect.append(dt)
    # ---------------------------

    # === Forgetting update at end of round `iter` (post-FedAvg, not timed) ===
    t = iter  # current window id

    # 1) Update the "best so far" for the CURRENT window using the current model
    L_cur_t = _eval_loss_on_loader(net_glob_client, net_glob_server,
                                   val_loaders[t], device, criterion)
    best_loss_per_window[t] = min(best_loss_per_window[t], L_cur_t)

    # 2) Compute forgetting on all PAST windows t_prev < t
    per_win_fgt = {}
    for t_prev in range(t):
        L_now = _eval_loss_on_loader(net_glob_client, net_glob_server,
                                     val_loaders[t_prev], device, criterion)
        Fgt = L_now - best_loss_per_window[t_prev]
        per_win_fgt[t_prev] = Fgt

    mean_fgt = float(np.mean(list(per_win_fgt.values()))) if per_win_fgt else 0.0
    forgetting_log.append({"round": t, "mean_forgetting": mean_fgt, "per_window": per_win_fgt})
    print(f"Forgetting : Round {t}, mean_forgetting : {mean_fgt:.3f}")
    print("==========================================================")

    
#===================================================================================     

print("Training and Evaluation completed!")    

#===============================================================================
# Save output data to .excel file (we use for comparision plots)
n = min(len(acc_train_collect), len(acc_test_collect), len(round_time_collect), len(forgetting_log))
round_process = [i for i in range(1, len(acc_train_collect)+1)]
mean_fgt_series = [d["mean_forgetting"] for d in forgetting_log[:n]]

df = DataFrame({
    'round': round_process,
    'acc_train': acc_train_collect[:n],
    'acc_test':  acc_test_collect[:n],
    'round_time_sec': round_time_collect[:n],
    'mean_FgT_loss': mean_fgt_series,
})


# write CSV — easier for scripting/comparison tools
file_name_csv = program + ".csv"
df.to_csv(file_name_csv, index=False)

print("Saved:", file_name_csv)

#=============================================================================
#                         Program Completed
#=============================================================================
# Out:
# ---------SFLV2 - CIFAR-10 α=0.1----------
# NVIDIA H200
# ResNet18_client_side(
#   (layer1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (layer2): Sequential(
#     (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (layer3): Sequential(
#     (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (layer4): Sequential(
#     (0): Baseblock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dim_change): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2))
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Baseblock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer5): Sequential(
#     (0): Baseblock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dim_change): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2))
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Baseblock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer6): Sequential(
#     (0): Baseblock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dim_change): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2))
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Baseblock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
# )
# ResNet18_server_side(
#   (fc): Linear(in_features=512, out_features=10, bias=True)
# )
# Train samples: 50000  Test samples: 10000
# Example train label: 6
#  Client3 Train => Local Epoch: 0 	Acc: 78.897 	Loss: 0.8435
#  Client3 Train => Local Epoch: 1 	Acc: 89.832 	Loss: 0.5118
#  Client3 Train => Local Epoch: 2 	Acc: 90.109 	Loss: 0.4704
#  Client3 Train => Local Epoch: 3 	Acc: 90.194 	Loss: 0.4375
#  Client3 Train => Local Epoch: 4 	Acc: 90.662 	Loss: 0.4178
#  Client3 Test =>                   	Acc: 9.540 	Loss: 4.1747
#  Client1 Train => Local Epoch: 0 	Acc: 78.448 	Loss: 0.6331
#  Client1 Train => Local Epoch: 1 	Acc: 89.502 	Loss: 0.2712
#  Client1 Train => Local Epoch: 2 	Acc: 91.625 	Loss: 0.2112
#  Client1 Train => Local Epoch: 3 	Acc: 93.486 	Loss: 0.1875
#  Client1 Train => Local Epoch: 4 	Acc: 93.705 	Loss: 0.1718
#  Client1 Test =>                   	Acc: 9.489 	Loss: 6.2348
#  Client2 Train => Local Epoch: 0 	Acc: 78.186 	Loss: 0.9277
#  Client2 Train => Local Epoch: 1 	Acc: 90.334 	Loss: 0.4087
#  Client2 Train => Local Epoch: 2 	Acc: 91.237 	Loss: 0.3500
#  Client2 Train => Local Epoch: 3 	Acc: 91.996 	Loss: 0.3114
#  Client2 Train => Local Epoch: 4 	Acc: 92.291 	Loss: 0.2969
#  Client2 Test =>                   	Acc: 9.479 	Loss: 5.8508
#  Client1 Train => Local Epoch: 4 	Acc: 94.714 	Loss: 0.1477
#  Client1 Test =>                   	Acc: 10.331 	Loss: 5.0694
#  Client8 Train => Local Epoch: 0 	Acc: 73.214 	Loss: 0.9679
#  Client8 Train => Local Epoch: 1 	Acc: 80.446 	Loss: 0.5706
#  Client8 Train => Local Epoch: 2 	Acc: 81.818 	Loss: 0.5343
#  Client8 Train => Local Epoch: 3 	Acc: 82.525 	Loss: 0.5068
#  Client8 Train => Local Epoch: 4 	Acc: 83.388 	Loss: 0.4854
#  Client8 Test =>                   	Acc: 15.911 	Loss: 3.5402
#  Client0 Train => Local Epoch: 0 	Acc: 56.728 	Loss: 1.3129
#  Client0 Train => Local Epoch: 1 	Acc: 76.633 	Loss: 0.7521
#  Client0 Train => Local Epoch: 2 	Acc: 77.999 	Loss: 0.6852
#  Client0 Train => Local Epoch: 3 	Acc: 80.441 	Loss: 0.6315
#  Client0 Train => Local Epoch: 4 	Acc: 79.329 	Loss: 0.6047
#  Client0 Test =>                   	Acc: 17.181 	Loss: 3.0751
#  Client6 Train => Local Epoch: 0 	Acc: 75.426 	Loss: 0.7001
#  Client6 Train => Local Epoch: 1 	Acc: 83.330 	Loss: 0.4866
#  Client6 Train => Local Epoch: 2 	Acc: 85.309 	Loss: 0.4287
#  Client6 Train => Local Epoch: 3 	Acc: 86.840 	Loss: 0.3977
#  Client6 Train => Local Epoch: 4 	Acc: 87.391 	Loss: 0.3736
#  Client6 Test =>                   	Acc: 18.989 	Loss: 3.3918
#  Client7 Train => Local Epoch: 0 	Acc: 81.743 	Loss: 0.7016
#  Client7 Train => Local Epoch: 1 	Acc: 91.449 	Loss: 0.2275
#  Client7 Train => Local Epoch: 2 	Acc: 93.056 	Loss: 0.1877
#  Client7 Train => Local Epoch: 3 	Acc: 93.856 	Loss: 0.1681
#  Client7 Train => Local Epoch: 4 	Acc: 94.799 	Loss: 0.1505
#  Client7 Test =>                   	Acc: 13.628 	Loss: 4.0653
# ====================== SERVER V1==========================
#  Train: Round   1, Avg Accuracy 84.904 | Avg Loss 0.444
#  Test: Round   1, Avg Accuracy 13.274 | Avg Loss 3.641
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Forgetting : Round 1, mean_forgetting : 0.538
# ==========================================================
#  Client0 Train => Local Epoch: 0 	Acc: 54.678 	Loss: 1.7030
#  Client0 Train => Local Epoch: 1 	Acc: 79.583 	Loss: 0.6607
#  Client0 Train => Local Epoch: 2 	Acc: 80.636 	Loss: 0.6009
#  Client0 Train => Local Epoch: 3 	Acc: 82.532 	Loss: 0.5477
#  Client0 Train => Local Epoch: 4 	Acc: 82.298 	Loss: 0.5206
#  Client0 Test =>                   	Acc: 18.861 	Loss: 3.1938
#  Client2 Train => Local Epoch: 0 	Acc: 84.911 	Loss: 0.6051
#  Client2 Train => Local Epoch: 1 	Acc: 92.386 	Loss: 0.2966
#  Client2 Train => Local Epoch: 2 	Acc: 92.778 	Loss: 0.2770
#  Client2 Train => Local Epoch: 3 	Acc: 93.092 	Loss: 0.2621
#  Client2 Train => Local Epoch: 4 	Acc: 92.976 	Loss: 0.2540
#  Client3 Train => Local Epoch: 2 	Acc: 92.185 	Loss: 0.3269
#  Client3 Train => Local Epoch: 3 	Acc: 92.049 	Loss: 0.3090
#  Client3 Train => Local Epoch: 4 	Acc: 92.294 	Loss: 0.2868
#  Client3 Test =>                   	Acc: 13.241 	Loss: 3.6384
#  Client9 Train => Local Epoch: 0 	Acc: 65.557 	Loss: 0.9905
#  Client9 Train => Local Epoch: 1 	Acc: 71.810 	Loss: 0.7386
#  Client9 Train => Local Epoch: 2 	Acc: 73.532 	Loss: 0.6873
#  Client9 Train => Local Epoch: 3 	Acc: 74.195 	Loss: 0.6554
#  Client9 Train => Local Epoch: 4 	Acc: 75.675 	Loss: 0.6165
#  Client9 Test =>                   	Acc: 16.319 	Loss: 3.0499
#  Client8 Train => Local Epoch: 0 	Acc: 76.946 	Loss: 0.7894
#  Client8 Train => Local Epoch: 1 	Acc: 83.049 	Loss: 0.5037
#  Client8 Train => Local Epoch: 2 	Acc: 83.687 	Loss: 0.4726
#  Client8 Train => Local Epoch: 3 	Acc: 84.305 	Loss: 0.4466
#  Client8 Train => Local Epoch: 4 	Acc: 84.950 	Loss: 0.4291
#  Client8 Test =>                   	Acc: 19.060 	Loss: 3.6118
#  Client0 Train => Local Epoch: 0 	Acc: 64.700 	Loss: 1.1011
#  Client0 Train => Local Epoch: 1 	Acc: 81.711 	Loss: 0.6031
#  Client0 Train => Local Epoch: 2 	Acc: 84.271 	Loss: 0.5323
#  Client0 Train => Local Epoch: 3 	Acc: 84.623 	Loss: 0.5074
#  Client0 Train => Local Epoch: 4 	Acc: 84.191 	Loss: 0.4627
#  Client0 Test =>                   	Acc: 22.929 	Loss: 3.1069
#  Client2 Train => Local Epoch: 0 	Acc: 84.154 	Loss: 0.7023
#  Client2 Train => Local Epoch: 1 	Acc: 92.584 	Loss: 0.2909
#  Client2 Train => Local Epoch: 2 	Acc: 93.272 	Loss: 0.2675
#  Client2 Train => Local Epoch: 3 	Acc: 93.456 	Loss: 0.2497
#  Client2 Train => Local Epoch: 4 	Acc: 93.574 	Loss: 0.2319
#  Client2 Test =>                   	Acc: 18.629 	Loss: 2.6952
#  Client6 Train => Local Epoch: 0 	Acc: 80.505 	Loss: 0.6558
#  Client6 Train => Local Epoch: 1 	Acc: 86.115 	Loss: 0.4144
#  Client6 Train => Local Epoch: 2 	Acc: 88.131 	Loss: 0.3676
#  Client6 Train => Local Epoch: 3 	Acc: 88.216 	Loss: 0.3591
#  Client6 Train => Local Epoch: 4 	Acc: 89.591 	Loss: 0.3163
#  Client6 Test =>                   	Acc: 26.007 	Loss: 2.9033
# ====================== SERVER V1==========================
#  Train: Round   3, Avg Accuracy 87.108 | Avg Loss 0.373
#  Test: Round   3, Avg Accuracy 18.204 | Avg Loss 3.421
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Forgetting : Round 3, mean_forgetting : -0.669
# ==========================================================
#  Client2 Train => Local Epoch: 0 	Acc: 85.325 	Loss: 0.6077
#  Client2 Train => Local Epoch: 1 	Acc: 92.765 	Loss: 0.2680
#  Client2 Train => Local Epoch: 2 	Acc: 93.683 	Loss: 0.2489
#  Client2 Train => Local Epoch: 3 	Acc: 94.129 	Loss: 0.2285
#  Client2 Train => Local Epoch: 4 	Acc: 93.924 	Loss: 0.2206
#  Client2 Test =>                   	Acc: 18.568 	Loss: 2.8855
#  Client8 Train => Local Epoch: 0 	Acc: 77.596 	Loss: 0.7632
#  Client8 Train => Local Epoch: 1 	Acc: 83.856 	Loss: 0.4730
#  Client8 Train => Local Epoch: 2 	Acc: 84.723 	Loss: 0.4480
#  Client8 Train => Local Epoch: 3 	Acc: 85.467 	Loss: 0.4213
#  Client8 Train => Local Epoch: 4 	Acc: 85.789 	Loss: 0.4004
#  Client8 Test =>                   	Acc: 20.700 	Loss: 3.5399
#  Client5 Train => Local Epoch: 0 	Acc: 64.251 	Loss: 1.2010
#  Client5 Train => Local Epoch: 1 	Acc: 75.780 	Loss: 0.6673
#  Client5 Train => Local Epoch: 2 	Acc: 78.661 	Loss: 0.5851
#  Client5 Train => Local Epoch: 3 	Acc: 79.968 	Loss: 0.5447
#  Client5 Train => Local Epoch: 4 	Acc: 81.999 	Loss: 0.4973
#  Client5 Test =>                   	Acc: 29.873 	Loss: 2.2472
#  Client0 Train => Local Epoch: 0 	Acc: 70.053 	Loss: 1.0053
#  Client0 Train => Local Epoch: 1 	Acc: 81.730 	Loss: 0.5963
#  Client0 Train => Local Epoch: 2 	Acc: 82.963 	Loss: 0.5078
#  Client0 Train => Local Epoch: 3 	Acc: 85.051 	Loss: 0.4612
#  Client0 Train => Local Epoch: 4 	Acc: 86.206 	Loss: 0.4179
#  Client0 Test =>                   	Acc: 23.603 	Loss: 2.6653
#  Client6 Train => Local Epoch: 0 	Acc: 83.709 	Loss: 0.5283
#  Client6 Train => Local Epoch: 1 	Acc: 88.084 	Loss: 0.3640
#  Client6 Train => Local Epoch: 2 	Acc: 89.091 	Loss: 0.3344
#  Client6 Train => Local Epoch: 3 	Acc: 90.226 	Loss: 0.3079
#  Client6 Train => Local Epoch: 4 	Acc: 90.479 	Loss: 0.2957
#  Client6 Test =>                   	Acc: 25.771 	Loss: 2.9444
#  Client4 Train => Local Epoch: 0 	Acc: 66.343 	Loss: 1.2723
#  Client4 Train => Local Epoch: 1 	Acc: 78.331 	Loss: 0.6730
#  Client4 Train => Local Epoch: 2 	Acc: 79.694 	Loss: 0.6047
#  Client4 Train => Local Epoch: 3 	Acc: 79.598 	Loss: 0.5948
#  Client4 Train => Local Epoch: 4 	Acc: 80.723 	Loss: 0.5628
#  Client4 Test =>                   	Acc: 21.798 	Loss: 2.6869
#  Client3 Train => Local Epoch: 0 	Acc: 75.615 	Loss: 1.1033
#  Client3 Train => Local Epoch: 1 	Acc: 92.142 	Loss: 0.3270
#  Client3 Train => Local Epoch: 2 	Acc: 92.191 	Loss: 0.3045
#  Client3 Train => Local Epoch: 3 	Acc: 92.273 	Loss: 0.2924
#  Client3 Train => Local Epoch: 4 	Acc: 92.666 	Loss: 0.2699
#  Client3 Test =>                   	Acc: 12.833 	Loss: 3.5456
#  Client3 Train => Local Epoch: 1 	Acc: 92.306 	Loss: 0.3272
#  Client3 Train => Local Epoch: 2 	Acc: 92.843 	Loss: 0.3003
#  Client3 Train => Local Epoch: 3 	Acc: 93.326 	Loss: 0.2691
#  Client3 Train => Local Epoch: 4 	Acc: 93.136 	Loss: 0.2652
#  Client3 Test =>                   	Acc: 13.978 	Loss: 3.4416
#  Client8 Train => Local Epoch: 0 	Acc: 79.415 	Loss: 0.7052
#  Client8 Train => Local Epoch: 1 	Acc: 84.513 	Loss: 0.4498
#  Client8 Train => Local Epoch: 2 	Acc: 85.831 	Loss: 0.4145
#  Client8 Train => Local Epoch: 3 	Acc: 86.204 	Loss: 0.3887
#  Client8 Train => Local Epoch: 4 	Acc: 86.734 	Loss: 0.3833
#  Client8 Test =>                   	Acc: 20.376 	Loss: 3.3307
#  Client9 Train => Local Epoch: 0 	Acc: 67.000 	Loss: 0.9778
#  Client9 Train => Local Epoch: 1 	Acc: 74.951 	Loss: 0.6473
#  Client9 Train => Local Epoch: 2 	Acc: 76.342 	Loss: 0.6049
#  Client9 Train => Local Epoch: 3 	Acc: 77.864 	Loss: 0.5739
#  Client9 Train => Local Epoch: 4 	Acc: 78.469 	Loss: 0.5551
#  Client9 Test =>                   	Acc: 20.531 	Loss: 3.1421
#  Client4 Train => Local Epoch: 0 	Acc: 68.712 	Loss: 1.1679
#  Client4 Train => Local Epoch: 1 	Acc: 79.530 	Loss: 0.6203
#  Client4 Train => Local Epoch: 2 	Acc: 80.259 	Loss: 0.5610
#  Client4 Train => Local Epoch: 3 	Acc: 81.281 	Loss: 0.5477
#  Client4 Train => Local Epoch: 4 	Acc: 82.502 	Loss: 0.5150
#  Client4 Test =>                   	Acc: 19.050 	Loss: 2.8123
#  Client5 Train => Local Epoch: 0 	Acc: 73.042 	Loss: 0.7743
#  Client5 Train => Local Epoch: 1 	Acc: 77.763 	Loss: 0.5981
#  Client5 Train => Local Epoch: 2 	Acc: 80.361 	Loss: 0.5395
#  Client5 Train => Local Epoch: 3 	Acc: 82.206 	Loss: 0.4898
#  Client5 Train => Local Epoch: 4 	Acc: 82.826 	Loss: 0.4682
#  Client5 Test =>                   	Acc: 28.260 	Loss: 2.4017
#  Client0 Train => Local Epoch: 0 	Acc: 65.129 	Loss: 1.2231
#  Client0 Train => Local Epoch: 1 	Acc: 82.982 	Loss: 0.5752
#  Client0 Train => Local Epoch: 2 	Acc: 84.408 	Loss: 0.4971
#  Client0 Train => Local Epoch: 3 	Acc: 86.850 	Loss: 0.4243
#  Client0 Train => Local Epoch: 4 	Acc: 86.968 	Loss: 0.3934
#  Client0 Test =>                   	Acc: 27.960 	Loss: 2.3895
#  Client1 Train => Local Epoch: 0 	Acc: 90.785 	Loss: 0.3167
#  Client1 Train => Local Epoch: 1 	Acc: 95.475 	Loss: 0.1356
#  Client1 Train => Local Epoch: 2 	Acc: 95.764 	Loss: 0.1219
#  Client1 Train => Local Epoch: 3 	Acc: 95.962 	Loss: 0.1121
#  Client1 Train => Local Epoch: 4 	Acc: 96.591 	Loss: 0.1011
#  Client1 Test =>                   	Acc: 16.416 	Loss: 4.4995
# ====================== SERVER V1==========================
#  Train: Round   5, Avg Accuracy 88.806 | Avg Loss 0.329
#  Test: Round   5, Avg Accuracy 21.308 | Avg Loss 3.116
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Forgetting : Round
#  Client7 Test =>                   	Acc: 17.854 	Loss: 3.8000
#  Client9 Train => Local Epoch: 0 	Acc: 69.550 	Loss: 0.8857
#  Client9 Train => Local Epoch: 1 	Acc: 76.256 	Loss: 0.6138
#  Client9 Train => Local Epoch: 2 	Acc: 77.580 	Loss: 0.5756
#  Client9 Train => Local Epoch: 3 	Acc: 78.100 	Loss: 0.5530
#  Client9 Train => Local Epoch: 4 	Acc: 79.427 	Loss: 0.5262
#  Client9 Test =>                   	Acc: 20.026 	Loss: 2.9316
#  Client1 Train => Local Epoch: 0 	Acc: 87.084 	Loss: 0.5348
#  Client1 Train => Local Epoch: 1 	Acc: 95.619 	Loss: 0.1359
#  Client1 Train => Local Epoch: 2 	Acc: 96.447 	Loss: 0.1082
#  Client1 Train => Local Epoch: 3 	Acc: 96.695 	Loss: 0.1007
#  Client1 Train => Local Epoch: 4 	Acc: 96.842 	Loss: 0.0900
#  Client1 Test =>                   	Acc: 14.298 	Loss: 4.0231
#  Client8 Train => Local Epoch: 0 	Acc: 79.273 	Loss: 0.7113
#  Client8 Train => Local Epoch: 1 	Acc: 85.839 	Loss: 0.4138
#  Client8 Train => Local Epoch: 2 	Acc: 85.900 	Loss: 0.4022
#  Client8 Train => Local Epoch: 3 	Acc: 86.401 	Loss: 0.3862
#  Client8 Train => Local Epoch: 4 	Acc: 88.090 	Loss: 0.3429
#  Client8 Test =>                   	Acc: 21.835 	Loss: 3.1546
#  Client2 Train => Local Epoch: 0 	Acc: 83.325 	Loss: 0.7378
#  Client2 Train => Local Epoch: 1 	Acc: 93.719 	Loss: 0.2482
#  Client2 Train => Local Epoch: 2 	Acc: 93.657 	Loss: 0.2238
#  Client2 Train => Local Epoch: 3 	Acc: 94.264 	Loss: 0.2083
#  Client2 Train => Local Epoch: 4 	Acc: 94.724 	Loss: 0.1900
#  Client2 Test =>                   	Acc: 20.865 	Loss: 2.3931
# ====================== SERVER V1==========================
#  Train: Round   6, Avg Accuracy 89.673 | Avg Loss 0.304
#  Test: Round   6, Avg Accuracy 22.692 | Avg Loss 2.960
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Forgetting : Round 6, mean_forgetting : -1.398
# ==========================================================
#  Client4 Train => Local Epoch: 0 	Acc: 69.075 	Loss: 1.1570
#  Client4 Train => Local Epoch: 1 	Acc: 80.725 	Loss: 0.5697
#  Client4 Train => Local Epoch: 2 	Acc: 83.210 	Loss: 0.5068
#  Client4 Train => Local Epoch: 3 	Acc: 83.360 	Loss: 0.4911
#  Client4 Train => Local Epoch: 4 	Acc: 84.066 	Loss: 0.4647
#  Client4 Test =>                   	Acc: 23.141 	Loss: 2.3814
#  Client1 Train => Local Epoch: 0 	Acc: 90.942 	Loss: 0.2910
#  Client1 Train => Local Epoch: 1 	Acc: 95.955 	Loss: 0.1232
#  Client1 Train => Local Epoch: 2 	Acc: 96.145 	Loss: 0.1096
#  Client1 Train => Local Epoch: 3 	Acc: 97.124 	Loss: 0.0874
#  Client1 Train => Local Epoch: 4 	Acc: 97.585 	Loss: 0.0793
#  Client0 Train => Local Epoch: 2 	Acc: 87.573 	Loss: 0.4109
#  Client0 Train => Local Epoch: 3 	Acc: 90.387 	Loss: 0.3218
#  Client0 Train => Local Epoch: 4 	Acc: 90.446 	Loss: 0.3186
#  Client0 Test =>                   	Acc: 27.677 	Loss: 2.2560
#  Client8 Train => Local Epoch: 0 	Acc: 81.876 	Loss: 0.5507
#  Client8 Train => Local Epoch: 1 	Acc: 86.206 	Loss: 0.4080
#  Client8 Train => Local Epoch: 2 	Acc: 87.030 	Loss: 0.3726
#  Client8 Train => Local Epoch: 3 	Acc: 87.839 	Loss: 0.3457
#  Client8 Train => Local Epoch: 4 	Acc: 88.834 	Loss: 0.3199
#  Client8 Test =>                   	Acc: 24.815 	Loss: 3.1000
# ====================== SERVER V1==========================
#  Train: Round   7, Avg Accuracy 90.507 | Avg Loss 0.282
#  Test: Round   7, Avg Accuracy 23.554 | Avg Loss 2.847
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Forgetting : Round 7, mean_forgetting : -0.102
# ==========================================================
#  Client8 Train => Local Epoch: 0 	Acc: 86.400 	Loss: 0.3978
#  Client8 Train => Local Epoch: 1 	Acc: 87.455 	Loss: 0.3643
#  Client8 Train => Local Epoch: 2 	Acc: 88.053 	Loss: 0.3480
#  Client8 Train => Local Epoch: 3 	Acc: 88.073 	Loss: 0.3316
#  Client8 Train => Local Epoch: 4 	Acc: 88.404 	Loss: 0.3123
#  Client8 Test =>                   	Acc: 22.633 	Loss: 3.7873
#  Client9 Train => Local Epoch: 0 	Acc: 69.779 	Loss: 0.9497
#  Client9 Train => Local Epoch: 1 	Acc: 78.579 	Loss: 0.5690
#  Client9 Train => Local Epoch: 2 	Acc: 79.858 	Loss: 0.5219
#  Client9 Train => Local Epoch: 3 	Acc: 81.053 	Loss: 0.5018
#  Client9 Train => Local Epoch: 4 	Acc: 80.934 	Loss: 0.4887
#  Client9 Test =>                   	Acc: 27.438 	Loss: 2.9202
#  Client5 Train => Local Epoch: 0 	Acc: 74.588 	Loss: 0.7740
#  Client5 Train => Local Epoch: 1 	Acc: 83.122 	Loss: 0.4803
#  Client5 Train => Local Epoch: 2 	Acc: 84.367 	Loss: 0.4309
#  Client5 Train => Local Epoch: 3 	Acc: 85.484 	Loss: 0.4046
#  Client5 Train => Local Epoch: 4 	Acc: 86.697 	Loss: 0.3791
#  Client5 Test =>                   	Acc: 38.126 	Loss: 2.1311
#  Client6 Train => Local Epoch: 0 	Acc: 86.122 	Loss: 0.4575
#  Client6 Train => Local Epoch: 1 	Acc: 91.641 	Loss: 0.2781
#  Client6 Train => Local Epoch: 2 	Acc: 92.543 	Loss: 0.2455
#  Client6 Train => Local Epoch: 3 	Acc: 93.110 	Loss: 0.2288
#  Client6 Train => Local Epoch: 4 	Acc: 93.649 	Loss: 0.2164
#  Client6 Test =>                   	Acc: 31.139 	Loss: 2.5498
#  Client7 Train => Local Epoch: 0 	Acc: 87.430 	Loss: 0.5091
#  Client7 Train => Local Epoch: 1 	Acc: 95.114 	Loss: 0.1352
#  Client7 Train => Local Epoch: 2 	Acc: 95.828 	Loss: 0.1177
#  Client7 Train => Local Epoch: 3 	Acc: 96.046 	Loss: 0.1116
#  Client7 Train => Local Epoch: 4 	Acc: 96.545 	Loss: 0.1048
#  Client7 Test =>                   	Acc: 17.713 	Loss: 3.2191
#  Client4 Train => Local Epoch: 0 	Acc: 72.324 	Loss: 1.0253
#  Client4 Train => Local Epoch: 1 	Acc: 81.456 	Loss: 0.5452
#  Client4 Train => Local Epoch: 2 	Acc: 83.209 	Loss: 0.4926
#  Client4 Train => Local Epoch: 3 	Acc: 84.796 	Loss: 0.4525
#  Client4 Train => Local Epoch: 4 	Acc: 85.458 	Loss: 0.4348
#  Client4 Test =>                   	Acc: 27.495 	Loss: 2.2930
#  Client1 Train => Local Epoch: 0 	Acc: 90.620 	Loss: 0.3213
#  Client1 Train => Local Epoch: 1 	Acc: 96.342 	Loss: 0.1117
#  Client1 Train => Local Epoch: 2 	Acc: 96.596 	Loss: 0.0970
#  Client1 Train => Local Epoch: 3 	Acc: 96.992 	Loss: 0.0846
#  Client1 Train => Local Epoch: 4 	Acc: 97.710 	Loss: 0.0685
#  Client1 Test =>                   	Acc: 16.359 	Loss: 4.0526
#  Client3 Train => Local Epoch: 0 	Acc: 71.004 	Loss: 1.3695
#  Client3 Train => Local Epoch: 1 	Acc: 93.144 	Loss: 0.2778
#  Client3 Train => Local Epoch: 2 	Acc: 93.460 	Loss: 0.2438
#  Client3 Train => Local Epoch: 3 	Acc: 93.625 	Loss: 0.2343
#  Client3 Train => Local Epoch: 4 	Acc: 93.923 	Loss: 0.2284
#  Client3 Test =>                   	Acc: 18.208 	Loss: 3.0526
#  Client2 Train => Local Epoch: 0 	Acc: 84.509 	Loss: 0.6862
#  Client2 Train => Local Epoch: 1 	Acc: 93.965 	Loss: 0.2184
#  Client2 Train => Local Epoch: 2 	Acc: 94.683 	Loss: 0.1933
#  Client2 Train => Local Epoch: 3 	Acc: 95.110 	Loss: 0.1756
#  Client2 Train => Local Epoch: 4 	Acc: 95.313 	Loss: 0.1600
#  Client2 Test =>                   	Acc: 24.327 	Loss: 2.3586
#  Client0 Train => Local Epoch: 0 	Acc: 59.878 	Loss: 1.3411
#  Client0 Train => Local Epoch: 1 	Acc: 87.594 	Loss: 0.4452
#  Client0 Train => Local Epoch: 2 	Acc: 88.784 	Loss: 0.3978
#  Client0 Train => Local Epoch: 3 	Acc: 89.585 	Loss: 0.3559
#  Client0 Train => Local Epoch: 4 	Acc: 90.095 	Loss: 0.3064
#  Client0 Test =>                   	Acc: 33.853 	Loss: 1.9466
# ====================== SERVER V1==========================
#  Train: Round   8, Avg Accuracy 90.873 | Avg Loss 0.270
#  Test: Round   8, Avg Accuracy 25.729 | Avg Loss 2.831
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Forgetting : Round
#  Client8 Train => Local Epoch: 1 	Acc: 87.785 	Loss: 0.3499
#  Client8 Train => Local Epoch: 2 	Acc: 88.507 	Loss: 0.3299
#  Client8 Train => Local Epoch: 3 	Acc: 89.152 	Loss: 0.3092
#  Client8 Train => Local Epoch: 4 	Acc: 89.682 	Loss: 0.2907
#  Client8 Test =>                   	Acc: 28.283 	Loss: 2.8560
#  Client9 Train => Local Epoch: 0 	Acc: 71.975 	Loss: 0.8474
#  Client9 Train => Local Epoch: 1 	Acc: 79.315 	Loss: 0.5354
#  Client9 Train => Local Epoch: 2 	Acc: 80.465 	Loss: 0.5005
#  Client9 Train => Local Epoch: 3 	Acc: 81.581 	Loss: 0.4726
#  Client9 Train => Local Epoch: 4 	Acc: 83.121 	Loss: 0.4473
#  Client9 Test =>                   	Acc: 30.472 	Loss: 2.4967
#  Client7 Train => Local Epoch: 0 	Acc: 88.879 	Loss: 0.4473
#  Client7 Train => Local Epoch: 1 	Acc: 95.478 	Loss: 0.1258
#  Client7 Train => Local Epoch: 2 	Acc: 96.312 	Loss: 0.1018
#  Client7 Train => Local Epoch: 3 	Acc: 96.545 	Loss: 0.1021
#  Client7 Train => Local Epoch: 4 	Acc: 96.443 	Loss: 0.0987
#  Client7 Test =>                   	Acc: 19.262 	Loss: 3.2384
# ====================== SERVER V1==========================
#  Train: Round   9, Avg Accuracy 91.481 | Avg Loss 0.253
#  Test: Round   9, Avg Accuracy 28.702 | Avg Loss 2.597
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Forgetting : Round 9, mean_forgetting : -0.020
# ==========================================================
#  Client3 Train => Local Epoch: 0 	Acc: 74.667 	Loss: 1.0341
#  Client3 Train => Local Epoch: 1 	Acc: 93.321 	Loss: 0.2646
#  Client3 Train => Local Epoch: 2 	Acc: 93.704 	Loss: 0.2450
#  Client3 Train => Local Epoch: 3 	Acc: 94.010 	Loss: 0.2240
#  Client3 Train => Local Epoch: 4 	Acc: 94.493 	Loss: 0.2030
#  Client3 Test =>                   	Acc: 15.376 	Loss: 3.1173
#  Client1 Train => Local Epoch: 0 	Acc: 89.304 	Loss: 0.4542
#  Client1 Train => Local Epoch: 1 	Acc: 96.305 	Loss: 0.1082
#  Client1 Train => Local Epoch: 2 	Acc: 97.144 	Loss: 0.0792
#  Client1 Train => Local Epoch: 3 	Acc: 97.644 	Loss: 0.0662
#  Client1 Train => Local Epoch: 4 	Acc: 98.100 	Loss: 0.0558
#  Client1 Test =>                   	Acc: 16.447 	Loss: 3.5056
#  Client7 Train => Local Epoch: 0 	Acc: 89.731 	Loss: 0.3742
#  Client7 Train => Local Epoch: 1 	Acc: 96.016 	Loss: 0.1184
#  Client7 Train => Local Epoch: 2 	Acc: 96.560 	Loss: 0.1017
#  Client7 Train => Local Epoch: 3 	Acc: 97.074 	Loss: 0.0889
#  Client7 Train => Local Epoch: 4 	Acc: 96.508 	Loss: 0.0964
#  Client7 Test =>                   	Acc: 18.050 	Loss: 3.4947
#  Client9 Train => Local Epoch: 0 	Acc: 73.794 	Loss: 0.7754
#  Client2 Train => Local Epoch: 2 	Acc: 99.746 	Loss: 0.0090
#  Client2 Train => Local Epoch: 3 	Acc: 99.860 	Loss: 0.0078
#  Client2 Train => Local Epoch: 4 	Acc: 99.824 	Loss: 0.0084
#  Client2 Test =>                   	Acc: 69.555 	Loss: 0.8659
# ====================== SERVER V1==========================
#  Train: Round  96, Avg Accuracy 99.305 | Avg Loss 0.022
#  Test: Round  96, Avg Accuracy 67.253 | Avg Loss 0.887
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Forgetting : Round 96, mean_forgetting : -0.537
# ==========================================================
#  Client9 Train => Local Epoch: 0 	Acc: 97.493 	Loss: 0.0837
#  Client9 Train => Local Epoch: 1 	Acc: 98.489 	Loss: 0.0477
#  Client9 Train => Local Epoch: 2 	Acc: 98.435 	Loss: 0.0418
#  Client9 Train => Local Epoch: 3 	Acc: 98.328 	Loss: 0.0424
#  Client9 Train => Local Epoch: 4 	Acc: 97.852 	Loss: 0.0578
#  Client9 Test =>                   	Acc: 66.713 	Loss: 0.9421
#  Client1 Train => Local Epoch: 0 	Acc: 96.241 	Loss: 0.1158
#  Client1 Train => Local Epoch: 1 	Acc: 99.521 	Loss: 0.0190
#  Client1 Train => Local Epoch: 2 	Acc: 99.716 	Loss: 0.0096
#  Client1 Train => Local Epoch: 3 	Acc: 99.858 	Loss: 0.0073
#  Client1 Train => Local Epoch: 4 	Acc: 99.876 	Loss: 0.0039
#  Client1 Test =>                   	Acc: 65.460 	Loss: 1.0089
#  Client7 Train => Local Epoch: 0 	Acc: 98.727 	Loss: 0.0449
#  Client7 Train => Local Epoch: 1 	Acc: 99.669 	Loss: 0.0120
#  Client7 Train => Local Epoch: 2 	Acc: 99.669 	Loss: 0.0091
#  Client7 Train => Local Epoch: 3 	Acc: 99.775 	Loss: 0.0079
#  Client7 Train => Local Epoch: 4 	Acc: 99.910 	Loss: 0.0045
#  Client7 Test =>                   	Acc: 64.268 	Loss: 1.0483
#  Client6 Train => Local Epoch: 0 	Acc: 97.414 	Loss: 0.0904
#  Client6 Train => Local Epoch: 1 	Acc: 99.151 	Loss: 0.0283
#  Client6 Train => Local Epoch: 2 	Acc: 99.435 	Loss: 0.0193
#  Client6 Train => Local Epoch: 3 	Acc: 99.743 	Loss: 0.0116
#  Client6 Train => Local Epoch: 4 	Acc: 99.743 	Loss: 0.0113
#  Client6 Test =>                   	Acc: 66.575 	Loss: 0.9821
#  Client0 Train => Local Epoch: 0 	Acc: 95.527 	Loss: 0.1807
#  Client0 Train => Local Epoch: 1 	Acc: 99.355 	Loss: 0.0387
#  Client0 Train => Local Epoch: 2 	Acc: 99.199 	Loss: 0.0285
#  Client0 Train => Local Epoch: 3 	Acc: 99.902 	Loss: 0.0160
#  Client0 Train => Local Epoch: 4 	Acc: 99.590 	Loss: 0.0156
#  Client0 Test =>                   	Acc: 65.356 	Loss: 1.0276
#  Client2 Train => Local Epoch: 0 	Acc: 96.983 	Loss: 0.0962
#  Client2 Train => Local Epoch: 1 	Acc: 99.265 	Loss: 0.0233
#  Client2 Train => Local Epoch: 2 	Acc: 99.779 	Loss: 0.0112
#  Client2 Train => Local Epoch: 3 	Acc: 99.805 	Loss: 0.0071
#  Client2 Train => Local Epoch: 4 	Acc: 99.922 	Loss: 0.0055
#  Client2 Test =>                   	Acc: 67.777 	Loss: 0.9583
#  Client8 Train => Local Epoch: 0 	Acc: 95.331 	Loss: 0.1384
#  Client8 Train => Local Epoch: 1 	Acc: 98.273 	Loss: 0.0486
#  Client8 Train => Local Epoch: 2 	Acc: 98.866 	Loss: 0.0364
#  Client8 Train => Local Epoch: 3 	Acc: 98.999 	Loss: 0.0312
#  Client8 Train => Local Epoch: 4 	Acc: 99.183 	Loss: 0.0255
#  Client8 Test =>                   	Acc: 66.703 	Loss: 0.9971
#  Client5 Train => Local Epoch: 0 	Acc: 98.555 	Loss: 0.0564
#  Client5 Train => Local Epoch: 1 	Acc: 99.492 	Loss: 0.0206
#  Client5 Train => Local Epoch: 2 	Acc: 99.652 	Loss: 0.0128
#  Client5 Train => Local Epoch: 3 	Acc: 99.515 	Loss: 0.0127
#  Client5 Train => Local Epoch: 4 	Acc: 99.648 	Loss: 0.0138
#  Client5 Test =>                   	Acc: 65.180 	Loss: 0.9751
#  Client3 Train => Local Epoch: 0 	Acc: 89.268 	Loss: 0.3233
#  Client3 Train => Local Epoch: 1 	Acc: 96.708 	Loss: 0.0979
#  Client3 Train => Local Epoch: 2 	Acc: 98.101 	Loss: 0.0657
#  Client3 Train => Local Epoch: 3 	Acc: 98.846 	Loss: 0.0394
#  Client3 Train => Local Epoch: 4 	Acc: 99.548 	Loss: 0.0235
#  Client3 Test =>                   	Acc: 65.817 	Loss: 0.9676
#  Client4 Train => Local Epoch: 0 	Acc: 94.337 	Loss: 0.1875
#  Client4 Train => Local Epoch: 1 	Acc: 97.804 	Loss: 0.0655
#  Client4 Train => Local Epoch: 2 	Acc: 98.000 	Loss: 0.0591
#  Client4 Train => Local Epoch: 3 	Acc: 98.243 	Loss: 0.0513
#  Client4 Train => Local Epoch: 4 	Acc: 98.781 	Loss: 0.0390
#  Client4 Test =>                   	Acc: 68.167 	Loss: 0.9127
# ====================== SERVER V1==========================
#  Train: Round  97, Avg Accuracy 99.405 | Avg Loss 0.020
#  Test: Round  97, Avg Accuracy 66.202 | Avg Loss 0.982
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Forgetting : Round 97, mean_forgetting : -0.643
# ==========================================================
#  Client8 Train => Local Epoch: 0 	Acc: 97.516 	Loss: 0.0730
#  Client8 Train => Local Epoch: 1 	Acc: 98.975 	Loss: 0.0327
#  Client8 Train => Local Epoch: 2 	Acc: 99.042 	Loss: 0.0278
#  Client8 Train => Local Epoch: 3 	Acc: 99.177 	Loss: 0.0281
#  Client8 Train => Local Epoch: 4 	Acc: 99.133 	Loss: 0.0257
#  Client8 Test =>                   	Acc: 67.211 	Loss: 0.8962
#  Client3 Train => Local Epoch: 0 	Acc: 91.386 	Loss: 0.2596
#  Client3 Train => Local Epoch: 1 	Acc: 97.985 	Loss: 0.0503
#  Client3 Train => Local Epoch: 2 	Acc: 99.237 	Loss: 0.0375
#  Client3 Train => Local Epoch: 3 	Acc: 99.108 	Loss: 0.0236
#  Client3 Train => Local Epoch: 4 	Acc: 99.707 	Loss: 0.0179
#  Client3 Test =>                   	Acc: 66.214 	Loss: 0.9162
#  Client9 Train => Local Epoch: 0 	Acc: 94.621 	Loss: 0.1509
#  Client9 Train => Local Epoch: 1 	Acc: 97.492 	Loss: 0.0732
#  Client9 Train => Local Epoch: 2 	Acc: 98.046 	Loss: 0.0544
#  Client9 Train => Local Epoch: 3 	Acc: 98.180 	Loss: 0.0513
#  Client9 Train => Local Epoch: 4 	Acc: 98.220 	Loss: 0.0516
#  Client9 Test =>                   	Acc: 72.117 	Loss: 0.7938
#  Client0 Train => Local Epoch: 0 	Acc: 89.980 	Loss: 0.3322
#  Client0 Train => Local Epoch: 1 	Acc: 98.515 	Loss: 0.0531
#  Client0 Train => Local Epoch: 2 	Acc: 98.261 	Loss: 0.0577
#  Client0 Train => Local Epoch: 3 	Acc: 99.179 	Loss: 0.0305
#  Client0 Train => Local Epoch: 4 	Acc: 99.394 	Loss: 0.0218
#  Client0 Test =>                   	Acc: 70.548 	Loss: 0.8105
#  Client5 Train => Local Epoch: 0 	Acc: 97.972 	Loss: 0.0728
#  Client5 Train => Local Epoch: 1 	Acc: 98.839 	Loss: 0.0334
#  Client5 Train => Local Epoch: 2 	Acc: 99.128 	Loss: 0.0293
#  Client5 Train => Local Epoch: 3 	Acc: 98.992 	Loss: 0.0284
#  Client5 Train => Local Epoch: 4 	Acc: 99.183 	Loss: 0.0248
#  Client5 Test =>                   	Acc: 71.215 	Loss: 0.8132
#  Client1 Train => Local Epoch: 0 	Acc: 99.130 	Loss: 0.0409
#  Client1 Train => Local Epoch: 1 	Acc: 99.876 	Loss: 0.0060
#  Client1 Train => Local Epoch: 2 	Acc: 99.964 	Loss: 0.0040
#  Client1 Train => Local Epoch: 3 	Acc: 99.982 	Loss: 0.0029
#  Client1 Train => Local Epoch: 4 	Acc: 99.947 	Loss: 0.0031
#  Client1 Test =>                   	Acc: 64.867 	Loss: 0.9343
#  Client7 Train => Local Epoch: 0 	Acc: 97.525 	Loss: 0.0721
#  Client7 Train => Local Epoch: 1 	Acc: 99.114 	Loss: 0.0279
#  Client7 Train => Local Epoch: 2 	Acc: 99.549 	Loss: 0.0131
#  Client7 Train => Local Epoch: 3 	Acc: 99.700 	Loss: 0.0103
#  Client7 Train => Local Epoch: 4 	Acc: 99.801 	Loss: 0.0075
#  Client7 Test =>                   	Acc: 66.831 	Loss: 0.8538
#  Client4 Train => Local Epoch: 0 	Acc: 96.949 	Loss: 0.1199
#  Client4 Train => Local Epoch: 1 	Acc: 98.536 	Loss: 0.0442
#  Client4 Train => Local Epoch: 2 	Acc: 98.536 	Loss: 0.0437
#  Client4 Train => Local Epoch: 3 	Acc: 99.025 	Loss: 0.0345
#  Client4 Train => Local Epoch: 4 	Acc: 98.999 	Loss: 0.0402
#  Client4 Test =>                   	Acc: 68.780 	Loss: 0.8373
#  Client6 Train => Local Epoch: 0 	Acc: 96.824 	Loss: 0.1025
#  Client6 Train => Local Epoch: 1 	Acc: 98.979 	Loss: 0.0322
#  Client6 Train => Local Epoch: 2 	Acc: 99.202 	Loss: 0.0251
#  Client6 Train => Local Epoch: 3 	Acc: 99.474 	Loss: 0.0167
#  Client6 Train => Local Epoch: 4 	Acc: 99.522 	Loss: 0.0146
#  Client6 Test =>                   	Acc: 69.195 	Loss: 0.8634
#  Client2 Train => Local Epoch: 0 	Acc: 97.715 	Loss: 0.0772
#  Client2 Train => Local Epoch: 1 	Acc: 99.428 	Loss: 0.0200
#  Client2 Train => Local Epoch: 2 	Acc: 99.688 	Loss: 0.0126
#  Client2 Train => Local Epoch: 3 	Acc: 99.824 	Loss: 0.0089
#  Client2 Train => Local Epoch: 4 	Acc: 99.922 	Loss: 0.0062
#  Client2 Test =>                   	Acc: 70.013 	Loss: 0.8060
# ====================== SERVER V1==========================
#  Train: Round  98, Avg Accuracy 99.383 | Avg Loss 0.021
#  Test: Round  98, Avg Accuracy 68.699 | Avg Loss 0.852
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Forgetting : Round 98, mean_forgetting : -0.630
# ==========================================================
#  Client8 Train => Local Epoch: 0 	Acc: 95.863 	Loss: 0.1266
#  Client8 Train => Local Epoch: 1 	Acc: 98.242 	Loss: 0.0501
#  Client8 Train => Local Epoch: 2 	Acc: 98.816 	Loss: 0.0336
#  Client8 Train => Local Epoch: 3 	Acc: 99.067 	Loss: 0.0293
#  Client8 Train => Local Epoch: 4 	Acc: 99.018 	Loss: 0.0303
#  Client8 Test =>                   	Acc: 67.824 	Loss: 0.9468
#  Client2 Train => Local Epoch: 0 	Acc: 97.335 	Loss: 0.0786
#  Client2 Train => Local Epoch: 1 	Acc: 99.258 	Loss: 0.0220
#  Client2 Train => Local Epoch: 2 	Acc: 99.727 	Loss: 0.0107
#  Client2 Train => Local Epoch: 3 	Acc: 99.841 	Loss: 0.0073
#  Client2 Train => Local Epoch: 4 	Acc: 99.902 	Loss: 0.0051
#  Client2 Test =>                   	Acc: 72.697 	Loss: 0.8395
#  Client3 Train => Local Epoch: 0 	Acc: 90.366 	Loss: 0.3022
#  Client3 Train => Local Epoch: 1 	Acc: 96.996 	Loss: 0.0785
#  Client3 Train => Local Epoch: 2 	Acc: 98.522 	Loss: 0.0508
#  Client3 Train => Local Epoch: 3 	Acc: 99.286 	Loss: 0.0286
#  Client3 Train => Local Epoch: 4 	Acc: 99.450 	Loss: 0.0217
#  Client3 Test =>                   	Acc: 70.366 	Loss: 0.8393
#  Client0 Train => Local Epoch: 0 	Acc: 94.785 	Loss: 0.1954
#  Client0 Train => Local Epoch: 1 	Acc: 99.609 	Loss: 0.0386
#  Client0 Train => Local Epoch: 2 	Acc: 98.632 	Loss: 0.0404
#  Client0 Train => Local Epoch: 3 	Acc: 99.668 	Loss: 0.0191
#  Client0 Train => Local Epoch: 4 	Acc: 99.472 	Loss: 0.0201
#  Client0 Test =>                   	Acc: 70.410 	Loss: 0.8482
#  Client9 Train => Local Epoch: 0 	Acc: 97.142 	Loss: 0.0929
#  Client9 Train => Local Epoch: 1 	Acc: 98.542 	Loss: 0.0462
#  Client9 Train => Local Epoch: 2 	Acc: 97.815 	Loss: 0.0670
#  Client9 Train => Local Epoch: 3 	Acc: 98.113 	Loss: 0.0605
#  Client9 Train => Local Epoch: 4 	Acc: 97.868 	Loss: 0.0583
#  Client9 Test =>                   	Acc: 72.676 	Loss: 0.8187
#  Client4 Train => Local Epoch: 0 	Acc: 94.778 	Loss: 0.1685
#  Client4 Train => Local Epoch: 1 	Acc: 97.828 	Loss: 0.0565
#  Client4 Train => Local Epoch: 2 	Acc: 98.609 	Loss: 0.0400
#  Client4 Train => Local Epoch: 3 	Acc: 98.732 	Loss: 0.0381
#  Client4 Train => Local Epoch: 4 	Acc: 98.999 	Loss: 0.0355
#  Client4 Test =>                   	Acc: 70.653 	Loss: 0.8422
#  Client7 Train => Local Epoch: 0 	Acc: 98.978 	Loss: 0.0431
#  Client7 Train => Local Epoch: 1 	Acc: 99.474 	Loss: 0.0148
#  Client7 Train => Local Epoch: 2 	Acc: 99.730 	Loss: 0.0102
#  Client7 Train => Local Epoch: 3 	Acc: 99.741 	Loss: 0.0066
#  Client7 Train => Local Epoch: 4 	Acc: 99.775 	Loss: 0.0072
#  Client7 Test =>                   	Acc: 70.161 	Loss: 0.8670
#  Client1 Train => Local Epoch: 0 	Acc: 97.253 	Loss: 0.0825
#  Client1 Train => Local Epoch: 1 	Acc: 99.531 	Loss: 0.0140
#  Client1 Train => Local Epoch: 2 	Acc: 99.538 	Loss: 0.0185
#  Client1 Train => Local Epoch: 3 	Acc: 99.716 	Loss: 0.0105
#  Client1 Train => Local Epoch: 4 	Acc: 99.650 	Loss: 0.0123
#  Client1 Test =>                   	Acc: 70.966 	Loss: 0.8571
#  Client5 Train => Local Epoch: 0 	Acc: 98.605 	Loss: 0.0561
#  Client5 Train => Local Epoch: 1 	Acc: 99.395 	Loss: 0.0221
#  Client5 Train => Local Epoch: 2 	Acc: 99.008 	Loss: 0.0273
#  Client5 Train => Local Epoch: 3 	Acc: 99.164 	Loss: 0.0269
#  Client5 Train => Local Epoch: 4 	Acc: 99.258 	Loss: 0.0221
#  Client5 Test =>                   	Acc: 67.935 	Loss: 0.8685
#  Client6 Train => Local Epoch: 0 	Acc: 97.244 	Loss: 0.0848
#  Client6 Train => Local Epoch: 1 	Acc: 98.906 	Loss: 0.0307
#  Client6 Train => Local Epoch: 2 	Acc: 99.195 	Loss: 0.0242
#  Client6 Train => Local Epoch: 3 	Acc: 99.399 	Loss: 0.0187
#  Client6 Train => Local Epoch: 4 	Acc: 99.454 	Loss: 0.0184
#  Client6 Test =>                   	Acc: 71.222 	Loss: 0.8768
# ====================== SERVER V1==========================
#  Train: Round  99, Avg Accuracy 99.285 | Avg Loss 0.023
#  Test: Round  99, Avg Accuracy 70.491 | Avg Loss 0.860
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Forgetting : Round 99, mean_forgetting : -0.565
# ==========================================================
# Training and Evaluation completed!
# Saved: SFLV2 - CIFAR-10 α=0.1.csv
