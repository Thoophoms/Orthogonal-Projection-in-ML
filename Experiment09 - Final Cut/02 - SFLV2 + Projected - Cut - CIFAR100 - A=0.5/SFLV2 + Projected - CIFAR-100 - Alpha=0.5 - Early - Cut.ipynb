# %% [markdown]
# # Split Federated Learning V2 + Projected:
# ### CIFAR-100 + α = 0.5
# #### Experiment - Early Cut (Level 3)

# %%
# =============================================================================
# SFLV2 + Orthogonal Projection (Gated) on CIFAR-100 (Dirichlet α=0.5)
# - Warmup + alpha ramp + norm-preserving projection
# - Train-side feature reservoir (no test leakage)
# - Rebuild U every 5 rounds; clear buffer after rebuild
# - SGD + momentum + cosine LR (server); label smoothing
# - local_ep = 5; CIFAR-100 RandAug-lite; freeze client BN after warmup
# =============================================================================
import torch
from torch import nn
from torchvision import transforms
from torch.utils.data import DataLoader, Dataset
import torch.nn.functional as F
import math
import os.path
import pandas as pd
from sklearn.model_selection import train_test_split
from PIL import Image
from glob import glob
from pandas import DataFrame
import random
import numpy as np
import os


import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import copy
import time

# ----------------------------- Repro & Device --------------------------------
SEED = 1234
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
if torch.cuda.is_available():
    torch.backends.cudnn.deterministic = True
    print(torch.cuda.get_device_name(0))   
    

    
def _sync_cuda():
    if torch.cuda.is_available():
        torch.cuda.synchronize()

#===================================================================
program = "SFLV2 + Projected - CIFAR-100 α=0.5 - Early Cut"
DATASET_NAME = "CIFAR100"
DATA_ROOT = "data"


print(f"---------{program}----------")              # this is to identify the program in the slurm outputs files


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
pin = torch.cuda.is_available()


# To print in color -------test/train of the client side
def prRed(skk): print("\033[91m {}\033[00m" .format(skk)) 
def prGreen(skk): print("\033[92m {}\033[00m" .format(skk))     


#===================================================================
BATCH_SIZE = 256
LR_BASE = 0.001
MOMENTUM = 0.9
WEIGHT_DECAY = 5e-4
LABEL_SMOOTH = 0.0
NUM_WORKERS = 4


# No. of users
NUM_CLIENTS = 10
EPOCHS = 200
LOCAL_EPOCHS = 5
FRAC = 1        # participation of clients; if 1 then 100% clients participate in SFLV2
ALPHA = 0.5     # Non-IID split


#=====================================================================================================
#                           Orthogonal Config
#=====================================================================================================
# Orthogonal projection config deque
ORTH = True
TOP_R = 8 # Smaller r to avoid over-pruning
rebuild_every = 5         # rebuild subspace cadence (rounds)
WARMUP_ROUNDS = 10         # no projection before this
alpha_max = 0.1           # target projection strength
alpha_min = 0.0
alpha_warm_len = 10       # rounds to ramp alpha after warmup

# total samples for building U_old
# Feature reservoir (train-side only)
FEATURE_MEM_CAP = 4096    # train-side feature reservoir
FEATURE_MEM = []
_seen = 0


U_old = None              # D x r matrix of principal directions at the cut
ell_global = 0            # current round index (for alpha schedule)


# ====================== Confirm =======================================
cut_at = "Early-cut at Layer 3"
prRed(f"\tData:\t\t{DATASET_NAME}\n\tCut:\t\t{cut_at}\n\tGlobal Rounds:\t{EPOCHS}\n\tClients:\t{NUM_CLIENTS}\n\tLocal Epochs:\t{LOCAL_EPOCHS}\n\tα:\t\t{ALPHA}\n\tWarm-up:\t{WARMUP_ROUNDS}\n\tRebuild:\t{rebuild_every}")



#=====================================================================================================
#                       Round 4 New: Projection Gate
#=====================================================================================================

def proj_gate_strength(round_idx: int):
    """Alpha schedule for projection."""
    if round_idx < WARMUP_ROUNDS:
        return 0.0
    t = min(1.0, (round_idx - WARMUP_ROUNDS) / max(1, alpha_warm_len))
    return alpha_min + t * (alpha_max - alpha_min)

#=====================================================================================================
#                           Projection Help
#=====================================================================================================
def project_off_subspace_gated(grad_batch: torch.Tensor, U: torch.Tensor, alpha: float, preserve_norm=True):
    """g' = g - alpha * P_U(g), optionally rescale to preserve per-sample norm."""
    if (U is None) or (alpha <= 0.0):
        return grad_batch
    B = grad_batch.shape[0]
    g = grad_batch.view(B, -1)              # [B, D]
    comp = (g @ U) @ U.T                    # [B, D]
    if preserve_norm:
        n0 = g.norm(dim=1, keepdim=True).clamp_min(1e-12)
    g2 = g - alpha * comp
    if preserve_norm:
        n1 = g2.norm(dim=1, keepdim=True).clamp_min(1e-12)
        g2 = g2 * (n0 / n1)
    return g2.view_as(grad_batch)


def add_to_reservoir(rows_cpu_fp16: torch.Tensor):
    """Standard reservoir sampling to keep a fixed-size unbiased buffer."""
    global _seen, FEATURE_MEM
    for r in rows_cpu_fp16:
        _seen += 1
        if len(FEATURE_MEM) < FEATURE_MEM_CAP:
            FEATURE_MEM.append(r)
        else:
            j = np.random.randint(0, _seen)
            if j < FEATURE_MEM_CAP:
                FEATURE_MEM[j] = r

                
def collect_cut_feats_from_train(fx_client: torch.Tensor):
    """Collect a small subset of cut features from TRAIN forward passes only."""
    with torch.no_grad():
        feats = fx_client.detach().view(fx_client.shape[0], -1)  # [B, D]
        k = min(24, feats.shape[0])
        idx = torch.randperm(feats.shape[0], device=feats.device)[:k]
        add_to_reservoir(feats[idx].cpu().to(torch.float16))


#=====================================================================================================
#         Subspace builder (simple PCA/SVD on buffered features)
#=====================================================================================================
def build_U_old_from_memory(top_r=TOP_R, device='cpu'):
    """Build principal subspace from the reservoir via PCA (pca_lowrank)."""
    if len(FEATURE_MEM) == 0:
        return None
    X = torch.stack(FEATURE_MEM).to(torch.float32)     # [N, D]
    X = X - X.mean(dim=0, keepdim=True)
    U, S, V = torch.pca_lowrank(X.cpu(), q=min(top_r, X.shape[1]), center=False)
    return V[:, :top_r].to(device, dtype=torch.float32)

def clear_feature_mem():
    global FEATURE_MEM, _seen
    FEATURE_MEM.clear()
    _seen = 0


#=====================================================================================================
#                           Baseblock
#=====================================================================================================
# Model at server side
class Baseblock(nn.Module):
    expansion = 1
    def __init__(self, input_planes, planes, stride = 1, dim_change = None):
        # super(Baseblock, self).__init__()
        super().__init__()
        self.conv1 = nn.Conv2d(input_planes, planes, stride =  stride, kernel_size = 3, padding = 1)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, stride = 1, kernel_size = 3, padding = 1)
        self.bn2 = nn.BatchNorm2d(planes)
        self.dim_change = dim_change
        
        
    def forward(self, x):
        res = x
        output = F.relu(self.bn1(self.conv1(x)))
        output = self.bn2(self.conv2(output))
        
        if self.dim_change is not None:
            res =self.dim_change(res)
            
        output += res
        output = F.relu(output)
        
        return output

        
#=====================================================================================================
#                           Client-side Model definition
#=====================================================================================================
# Model at client side
class ResNet18_client_side(nn.Module):
    def __init__(self, block, num_layers):
        super().__init__()
        self.layer1 = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False),  # 3x3 s=1
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            # no maxpool for 32x32
        )
        self.layer2 = nn.Sequential(
            nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(64),
        )

        # add layer 3-6 + avg-pool (copied from Client)
        self.layer3 = nn.Sequential (
                nn.Conv2d(64, 64, kernel_size = 3, stride = 1, padding = 1),
                nn.BatchNorm2d(64),
                nn.ReLU (inplace = True),
                nn.Conv2d(64, 64, kernel_size = 3, stride = 1, padding = 1),
                nn.BatchNorm2d(64),       
                )   


        # Weights into loop (the same thing as SERVER)
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                m.weight.data.normal_(0, math.sqrt(2. / n))
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()
        
        
    def forward(self, x):
        resudial1 = F.relu(self.layer1(x))
        out1 = self.layer2(resudial1)
        out1 = out1 + resudial1 # adding the resudial inputs -- downsampling not required in this layer
        x = F.relu(out1)

        out2 = self.layer3(x)
        out2 = out2 + x
        x = F.relu(out2)

        
        return x            # [B, 64, H, W]

net_glob_client = ResNet18_client_side(Baseblock, [2, 2, 2])
if torch.cuda.device_count() > 1:
    print("We use",torch.cuda.device_count(), "GPUs")
    net_glob_client = nn.DataParallel(net_glob_client)   # to use the multiple GPUs; later we can change this to CPUs only 

net_glob_client.to(device)
print(net_glob_client)    
        

#=====================================================================================================
#                           Server-side Model definition
#=====================================================================================================
class ResNet18_server_side(nn.Module):
    def __init__(self, block, num_layers ,classes):
        super(ResNet18_server_side, self).__init__()
        self.fc = nn.Linear(512 * block.expansion, classes)

        # self.input_planes is only used inside _layer()
        self.input_planes = 64

        self.layer4 = self._layer(block, 128, num_layers[0], stride = 2)
        self.layer5 = self._layer(block, 256, num_layers[1], stride = 2)
        self.layer6 = self._layer(block, 512, num_layers[2], stride = 2)
        
        
        # self. averagePool = nn.AvgPool2d(kernel_size = 7, stride = 1)
        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))

        
        # Weights into loop
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                m.weight.data.normal_(0, math.sqrt(2. / n))
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()


    # a helper function to build deeper ResNet blocks (layer4–6) using Baseblock
    def _layer(self, block, planes, num_layers, stride = 2):
        dim_change = None
        if stride != 1 or planes != self.input_planes * block.expansion:
            dim_change = nn.Sequential(nn.Conv2d(self.input_planes, planes*block.expansion, kernel_size = 1, stride = stride),
                                       nn.BatchNorm2d(planes*block.expansion))
        netLayers = []
        netLayers.append(block(self.input_planes, planes, stride = stride, dim_change = dim_change))
        self.input_planes = planes * block.expansion
        for i in range(1, num_layers):
            netLayers.append(block(self.input_planes, planes))
            self.input_planes = planes * block.expansion
            
        return nn.Sequential(*netLayers)
    
        
    
    def forward(self, x):

        x = self.layer4(x)                    # shape [B, 64, H, W]
        x = self.layer5(x)
        x = self.layer6(x)

        x = self.avgpool(x)                   # shape [B, 512, 1, 1]
        
        # x = [B, 512, 1, 1] from the Client side
        x = x.view(x.size(0), -1)     # [B, 512] 
        y_hat =self.fc(x)
        
        return y_hat

    
# === INSTANTIATE MODELS ===
if DATASET_NAME == "CIFAR10":
    net_glob_server = ResNet18_server_side(Baseblock, [2, 2, 2], 10)
else:
    net_glob_server = ResNet18_server_side(Baseblock, [2, 2, 2], 100)
    

if torch.cuda.device_count() > 1:
    print("We use",torch.cuda.device_count(), "GPUs")
    net_glob_server = nn.DataParallel(net_glob_server)   # to use the multiple GPUs 


net_glob_server.to(device)
print(net_glob_server)    

#===================================================================================
# For Server Side Loss and Accuracy 
loss_train_collect = []
acc_train_collect = []
loss_test_collect = []
acc_test_collect = []
batch_acc_train = []
batch_loss_train = []
batch_acc_test = []
batch_loss_test = []
round_time_collect = [] # Stores seconds per global round

criterion = nn.CrossEntropyLoss(label_smoothing=LABEL_SMOOTH)


# Persistent server optimizer & scheduler (like SL)
optimizer_server = torch.optim.SGD(net_glob_server.parameters(), lr=LR_BASE, momentum=MOMENTUM, weight_decay=WEIGHT_DECAY)
server_sched = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer_server, T_max=EPOCHS, eta_min=5e-4)


#====================================================================================================
#                                  Server Side Programs
#====================================================================================================
def calculate_accuracy(fx, y):
    preds = fx.max(1, keepdim=True)[1]
    correct = preds.eq(y.view_as(preds)).sum()
    acc = 100.00 *correct.float()/preds.shape[0]
    return acc

# to print train - test together in each round-- these are made global
acc_avg_all_user_train = 0
loss_avg_all_user_train = 0
loss_train_collect_user = []
acc_train_collect_user = []
loss_test_collect_user = []
acc_test_collect_user = []


#client idx collector
idx_collect = []
l_epoch_check = False
fed_check = False

count1 = 0
count2 = 0


# Server-side function associated with Training 
def train_server(fx_client, y, l_epoch_count, l_epoch, idx, len_batch):
    global net_glob_server, criterion, device
    global batch_acc_train, batch_loss_train, l_epoch_check, fed_check
    global loss_train_collect, acc_train_collect, count1
    global acc_avg_all_user_train, loss_avg_all_user_train, idx_collect
    global loss_train_collect_user, acc_train_collect_user
    global U_old, ell_global, optimizer_server  

    net_glob_server.train()
    # train and update
    optimizer_server.zero_grad()
    
    
    fx_client = fx_client.to(device).detach().requires_grad_(True)
    y = y.to(device)

    fx_server = net_glob_server(fx_client)
    loss = criterion(fx_server, y)
    acc = calculate_accuracy(fx_server, y)

    loss.backward()

    dfx_client = fx_client.grad.detach()


    if ORTH and (U_old is not None):
        alpha = proj_gate_strength(ell_global)
        dfx_client = project_off_subspace_gated(dfx_client, U_old.to(dfx_client.dtype), alpha, preserve_norm=True)
    # -----------------------------------------------------------
    
    
    optimizer_server.step()
    
    batch_loss_train.append(loss.item())
    batch_acc_train.append(acc.item())
    
    # server-side model net_glob_server is global so it is updated automatically in each pass to this function
    
    # count1: to track the completion of the local batch associated with one client
    count1 += 1
    if count1 == len_batch:
        acc_avg_train = sum(batch_acc_train)/len(batch_acc_train)           # it has accuracy for one batch
        loss_avg_train = sum(batch_loss_train)/len(batch_loss_train)
        
        batch_acc_train = []
        batch_loss_train = []
        count1 = 0
        
        prRed('Client{} Train => Local Epoch: {} \tAcc: {:.3f} \tLoss: {:.4f}'.format(idx, l_epoch_count, acc_avg_train, loss_avg_train))
        
                
        # If one local epoch is completed, after this a new client will come
        if l_epoch_count == l_epoch-1:
            
            l_epoch_check = True                # to evaluate_server function - to check local epoch has completed or not
                       
            # we store the last accuracy in the last batch of the epoch and it is not the average of all local epochs
            # this is because we work on the last trained model and its accuracy (not earlier cases)
            
            #print("accuracy = ", acc_avg_train)
            acc_avg_train_all = acc_avg_train
            loss_avg_train_all = loss_avg_train
                        
            # accumulate accuracy and loss for each new user
            loss_train_collect_user.append(loss_avg_train_all)
            acc_train_collect_user.append(acc_avg_train_all)
            
            # collect the id of each new user                        
            if idx not in idx_collect:
                idx_collect.append(idx) 
                #print(idx_collect)
        
        # This is to check if all users are served for one round --------------------
        if len(idx_collect) == NUM_CLIENTS:
            fed_check = True                                                  # to evaluate_server function  - to check fed check has hitted
            # all users served for one round ------------------------- output print and update is done in evaluate_server()
            # for nicer display 
                        
            idx_collect = []
            
            acc_avg_all_user_train = sum(acc_train_collect_user)/len(acc_train_collect_user)
            loss_avg_all_user_train = sum(loss_train_collect_user)/len(loss_train_collect_user)
            
            loss_train_collect.append(loss_avg_all_user_train)
            acc_train_collect.append(acc_avg_all_user_train)
            
            acc_train_collect_user = []
            loss_train_collect_user = []
            
    # send gradients to the client               
    return dfx_client

# Server-side functions associated with Testing
def evaluate_server(fx_client, y, idx, len_batch, ell):
    global net_glob_server, criterion, batch_acc_test, batch_loss_test
    global loss_test_collect, acc_test_collect, count2, NUM_CLIENTS, acc_avg_train_all, loss_avg_train_all, l_epoch_check, fed_check
    global loss_test_collect_user, acc_test_collect_user, acc_avg_all_user_train, loss_avg_all_user_train
    
    net_glob_server.eval()
  
    with torch.no_grad():
        fx_client = fx_client.to(device)
        y = y.to(device) 
        #---------forward prop-------------
        fx_server = net_glob_server(fx_client)
        
        # calculate loss
        loss = criterion(fx_server, y)
        # calculate accuracy
        acc = calculate_accuracy(fx_server, y)
        
        
        batch_loss_test.append(loss.item())
        batch_acc_test.append(acc.item())
        
               
        count2 += 1
        if count2 == len_batch:
            acc_avg_test = sum(batch_acc_test)/len(batch_acc_test)
            loss_avg_test = sum(batch_loss_test)/len(batch_loss_test)
            
            batch_acc_test = []
            batch_loss_test = []
            count2 = 0
            
            prGreen('Client{} Test =>                   \tAcc: {:.3f} \tLoss: {:.4f}'.format(idx, acc_avg_test, loss_avg_test))
            
            # if a local epoch is completed   
            if l_epoch_check:
                l_epoch_check = False
                
                # Store the last accuracy and loss
                acc_avg_test_all = acc_avg_test
                loss_avg_test_all = loss_avg_test
                        
                loss_test_collect_user.append(loss_avg_test_all)
                acc_test_collect_user.append(acc_avg_test_all)
                
            # if all users are served for one round ----------                    
            if fed_check:
                fed_check = False
                                
                acc_avg_all_user = sum(acc_test_collect_user)/len(acc_test_collect_user)
                loss_avg_all_user = sum(loss_test_collect_user)/len(loss_test_collect_user)
            
                loss_test_collect.append(loss_avg_all_user)
                acc_test_collect.append(acc_avg_all_user)
                acc_test_collect_user = []
                loss_test_collect_user= []
                              
                print("====================== SERVER V1==========================")
                print(' Train: Round {:3d}, Avg Accuracy {:.3f} | Avg Loss {:.3f}'.format(ell, acc_avg_all_user_train, loss_avg_all_user_train))
                print(' Test: Round {:3d}, Avg Accuracy {:.3f} | Avg Loss {:.3f}'.format(ell, acc_avg_all_user, loss_avg_all_user))
                # print("==========================================================")
                
                
            # Rebuild U on cadence (no feature collection here)
            if ORTH and (ell % rebuild_every == 1):
                global U_old
                U_old = build_U_old_from_memory(top_r=TOP_R, device=device)
                clear_feature_mem()
         
    return 


# ----------------------------- FedAvg (client) -------------------------------
def FedAvg(w_list):
    w_avg = copy.deepcopy(w_list[0])
    for k in w_avg.keys():
        for i in range(1, len(w_list)):
            w_avg[k] += w_list[i][k]
        w_avg[k] = torch.div(w_avg[k], len(w_list))
    return w_avg

#=============================================================================
#                         Data loading 
#============================================================================= 
from torchvision import datasets, transforms

# CIFAR-10 & CIFAR-100 transforms
cifar_mean = {
    "CIFAR10":  [0.4914, 0.4822, 0.4465],
    "CIFAR100": [0.5071, 0.4867, 0.4408],
}[DATASET_NAME]
cifar_std = {
    "CIFAR10":  [0.2470, 0.2435, 0.2616],
    "CIFAR100": [0.2675, 0.2565, 0.2761],
}[DATASET_NAME]

# Try RandAugment if available
try:
    from torchvision.transforms import RandAugment
    ra = [RandAugment(num_ops=2, magnitude=9)]
except Exception:
    ra = []

train_transforms = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(32, padding=4),
] + ra + [
    transforms.ToTensor(),
    transforms.Normalize(cifar_mean, cifar_std),
])

test_transforms = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(cifar_mean, cifar_std),
])

if DATASET_NAME == "CIFAR10":
    dataset_train = datasets.CIFAR10(root=DATA_ROOT, train=True,  download=True, transform=train_transforms)
    dataset_test  = datasets.CIFAR10(root=DATA_ROOT, train=False, download=True, transform=test_transforms)
else:
    dataset_train = datasets.CIFAR100(root=DATA_ROOT, train=True,  download=True, transform=train_transforms)
    dataset_test  = datasets.CIFAR100(root=DATA_ROOT, train=False, download=True, transform=test_transforms)

print("Train samples:", len(dataset_train), " Test samples:", len(dataset_test))
print("Example train label:", dataset_train.targets[0])

# ----------------------------- Partitions -----------------------------------
class DatasetSplit(Dataset):
    def __init__(self, dataset, idxs):
        self.dataset = dataset; self.idxs = list(idxs)
    def __len__(self): return len(self.idxs)
    def __getitem__(self, item): return self.dataset[self.idxs[item]]

def dataset_iid(dataset, NUM_CLIENTS):
    num_items = int(len(dataset)/NUM_CLIENTS)
    dict_users, all_idxs = {}, [i for i in range(len(dataset))]
    for i in range(NUM_CLIENTS):
        dict_users[i] = set(np.random.choice(all_idxs, num_items, replace=False))
        all_idxs = list(set(all_idxs) - dict_users[i])
    return dict_users

def dataset_noniid_dirichlet(dataset, NUM_CLIENTS, alpha=ALPHA, seed=SEED):
    rng = np.random.default_rng(seed)
    labels = np.array(dataset.targets)
    n_classes = len(np.unique(labels))
    dict_users = {i: set() for i in range(NUM_CLIENTS)}
    for c in range(n_classes):
        idxs = np.where(labels == c)[0]
        rng.shuffle(idxs)
        p = rng.dirichlet([alpha]*NUM_CLIENTS)
        cuts = (np.cumsum(p)*len(idxs)).astype(int)[:-1]
        splits = np.split(idxs, cuts)
        for client_id, split in enumerate(splits):
            dict_users[client_id].update(split.tolist())
    return dict_users

dict_users      = dataset_noniid_dirichlet(dataset_train, NUM_CLIENTS, alpha=ALPHA, seed=SEED)
dict_users_test = dataset_iid(dataset_test, NUM_CLIENTS)


#=============================================================================
#                         Forgetting metric setup 
#============================================================================= 

from collections import defaultdict

# Treat each global round as a window (quick baseline).
# If you want true distribution shifts, predefine your own windows and fill `val_loaders`.
T = EPOCHS

val_loaders = {}
# Deterministic, disjoint slices of the test set: window t gets items t, t+T, t+2T, ...
rng_idx = np.arange(len(dataset_test))
for t in range(T):
    idxs = rng_idx[t::T]
    val_loaders[t] = DataLoader(
        DatasetSplit(
            dataset_test, 
            idxs), 
        batch_size=BATCH_SIZE, 
        shuffle=False, 
        drop_last=False,
        num_workers=NUM_WORKERS,
        pin_memory=pin
    )

best_loss_per_window = defaultdict(lambda: float('inf'))  # stores min historical loss per window
forgetting_log = []  # per round dicts: {"round": t, "mean_forgetting": x, "per_window": {...}}
# ============================================================================

def _eval_loss_on_loader(model_client, model_server, loader, device, criterion):
    """Evaluate mean loss on a loader using split models."""
    # Handle DataParallel transparently
    mc = model_client.module if isinstance(model_client, nn.DataParallel) else model_client
    ms = model_server.module if isinstance(model_server, nn.DataParallel) else model_server
    mc.eval(); ms.eval()
    loss_sum, n = 0.0, 0
    with torch.no_grad():
        for images, labels in loader:
            images, labels = images.to(device), labels.to(device)
            fx = mc(images)
            logits = ms(fx)
            loss = criterion(logits, labels)
            bs = labels.size(0)
            loss_sum += loss.item() * bs
            n += bs
    return loss_sum / max(1, n)


# ------------------------------- Client --------------------------------------
def freeze_client_bn(net):
    for m in net.modules():
        if isinstance(m, nn.BatchNorm2d):
            m.eval()

class Client(object):
    def __init__(self, net_client_model, idx, lr, device,
                 dataset_train=None, dataset_test=None, idxs=None, idxs_test=None):
        self.idx = idx
        self.device = device
        self.lr = LR_BASE
        self.local_ep = LOCAL_EPOCHS
        self.ldr_train = DataLoader(
            DatasetSplit(
                dataset_train, 
                idxs), 
            batch_size=BATCH_SIZE, 
            shuffle=True, 
            drop_last=False,
            num_workers=NUM_WORKERS,
            pin_memory=pin
        )
        self.ldr_test  = DataLoader(
            DatasetSplit(
                dataset_test,  
                idxs_test), 
            batch_size=BATCH_SIZE, 
            shuffle=False, 
            drop_last=False,
            num_workers=NUM_WORKERS,
            pin_memory=pin
        )

    def train(self, net):
        net.train()
        optimizer_client = torch.optim.SGD(net.parameters(), lr=self.lr, momentum=MOMENTUM, weight_decay=WEIGHT_DECAY)
        for ep in range(self.local_ep):
            len_batch = len(self.ldr_train)
            for batch_idx, (images, labels) in enumerate(self.ldr_train):
                images, labels = images.to(self.device), labels.to(self.device)
                optimizer_client.zero_grad()
                fx = net(images)
                # collect train-side cut features into reservoir
                if ORTH:
                    collect_cut_feats_from_train(fx)
                client_fx = fx.clone().detach().requires_grad_(True)
                dfx = train_server(client_fx, labels, ep, self.local_ep, self.idx, len_batch)
                fx.backward(dfx)
                optimizer_client.step()
        return net.state_dict()

    def evaluate(self, net, ell):
        net.eval()
        with torch.no_grad():
            len_batch = len(self.ldr_test)
            for batch_idx, (images, labels) in enumerate(self.ldr_test):
                images, labels = images.to(self.device), labels.to(self.device)
                fx = net(images)
                evaluate_server(fx, labels, self.idx, len_batch, ell)
        return

# ------------------------------- Training ------------------------------------
net_glob_client.train()
w_glob_client = net_glob_client.state_dict()  # initial global client weights

acc_train_collect.clear(); loss_train_collect.clear()
acc_test_collect.clear();  loss_test_collect.clear()
round_time_collect.clear()

for iter in range(EPOCHS):
    ell_global = iter

    # Freeze BN (not timed)
    if iter == WARMUP_ROUNDS:
        if isinstance(net_glob_client, nn.DataParallel):
            freeze_client_bn(net_glob_client.module)
        else:
            freeze_client_bn(net_glob_client)

    # ---- START TIMER (training+testing+FedAvg only) ----
    _sync_cuda()
    t_start = time.perf_counter()
    # ----------------------------------------------------

    m = max(int(FRAC * NUM_CLIENTS), 1)
    idxs_users = np.random.choice(range(NUM_CLIENTS), m, replace=False)

    w_locals_client = []
    for idx in idxs_users:
        local = Client(net_glob_client, idx, LR_BASE, device,
                       dataset_train=dataset_train, dataset_test=dataset_test,
                       idxs=dict_users[idx], idxs_test=dict_users_test[idx])
        local_model = copy.deepcopy(net_glob_client).to(device)
        w_client = local.train(net=local_model)
        w_locals_client.append(copy.deepcopy(w_client))
        local.evaluate(net=local_model, ell=iter)

    # FedAvg
    w_glob_client = FedAvg(w_locals_client)
    net_glob_client.load_state_dict(w_glob_client)

    # ---- STOP TIMER & LOG ----
    _sync_cuda()
    dt = time.perf_counter() - t_start
    round_time_collect.append(dt)
    # --------------------------

    # === Forgetting metric update at end of round (not counted in time) ===
    t = iter
    L_cur_t = _eval_loss_on_loader(net_glob_client, net_glob_server, val_loaders[t], device, criterion)
    best_loss_per_window[t] = min(best_loss_per_window[t], L_cur_t)

    per_win_fgt = {}
    for t_prev in range(t):
        L_now = _eval_loss_on_loader(net_glob_client, net_glob_server, val_loaders[t_prev], device, criterion)
        Fgt = L_now - best_loss_per_window[t_prev]
        per_win_fgt[t_prev] = Fgt

    mean_fgt = float(np.mean(list(per_win_fgt.values()))) if per_win_fgt else 0.0
    forgetting_log.append({"round": t, "mean_forgetting": mean_fgt, "per_window": per_win_fgt})
    print(f"Forgetting : Round {t}, mean_forgetting : {mean_fgt:.3f}")
    print("==========================================================")


    # LR schedule (also outside timing)
    server_sched.step()

print("Training and Evaluation completed!")

# ----------------------------- Save outputs ----------------------------------
n = min(len(acc_train_collect), len(acc_test_collect), len(round_time_collect), len(forgetting_log))
if n == 0:
    # Safeguard: if per-round aggregates weren’t populated (e.g., single-user path),
    # still produce a minimal log so the files exist.
    n = len(round_time_collect)
round_process = list(range(1, n+1))
mean_fgt_series = [d["mean_forgetting"] for d in forgetting_log[:n]] if forgetting_log else [0.0]*n

df = DataFrame({
    'round': round_process,
    'acc_train': acc_train_collect[:n],
    'acc_test':  acc_test_collect[:n],
    'round_time_sec': round_time_collect[:n],
    'mean_FgT_loss': mean_fgt_series,
})

file_name_csv  = program + ".csv"
df.to_csv(file_name_csv, index=False)
print("Saved:", file_name_csv)

#=============================================================================
#                         Program Completed
#=============================================================================
# Out:
# NVIDIA H200
# ---------SFLV2 + Projected - CIFAR-100 α=0.1 - Early Cut----------
#  	Data:		CIFAR100
# 	Cut:		Early-cut at Layer 3
# 	Global Rounds:	100
# 	Clients:	10
# 	Local Epochs:	5
# 	α:		0.1
# 	Warm-up:	5
# 	Rebuild:	3
# ResNet18_client_side(
#   (layer1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (layer2): Sequential(
#     (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (layer3): Sequential(
#     (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# ResNet18_server_side(
#   (fc): Linear(in_features=512, out_features=100, bias=True)
#   (layer4): Sequential(
#     (0): Baseblock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dim_change): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2))
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Baseblock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer5): Sequential(
#     (0): Baseblock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dim_change): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2))
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Baseblock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer6): Sequential(
#     (0): Baseblock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dim_change): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2))
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Baseblock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
# )
# Train samples: 50000  Test samples: 10000
# Example train label: 19
#  Client3 Train => Local Epoch: 0 	Acc: 9.688 	Loss: 3.7904
#  Client3 Train => Local Epoch: 1 	Acc: 15.052 	Loss: 3.4343
#  Client3 Train => Local Epoch: 2 	Acc: 17.057 	Loss: 3.2259
#  Client3 Train => Local Epoch: 3 	Acc: 23.203 	Loss: 3.0991
#  Client3 Train => Local Epoch: 4 	Acc: 23.438 	Loss: 2.9225
#  Client3 Test =>                   	Acc: 0.801 	Loss: 7.1577
#  Client1 Train => Local Epoch: 0 	Acc: 11.444 	Loss: 4.3505
#  Client1 Train => Local Epoch: 1 	Acc: 21.859 	Loss: 3.1374
#  Client1 Train => Local Epoch: 2 	Acc: 25.252 	Loss: 2.9590
#  Client1 Train => Local Epoch: 3 	Acc: 26.764 	Loss: 2.8654
#  Client1 Train => Local Epoch: 4 	Acc: 29.689 	Loss: 2.7719
#  Client1 Test =>                   	Acc: 1.074 	Loss: 6.8449
#  Client2 Train => Local Epoch: 0 	Acc: 16.721 	Loss: 3.8890
#  Client2 Train => Local Epoch: 1 	Acc: 30.644 	Loss: 2.8431
#  Client2 Train => Local Epoch: 2 	Acc: 34.224 	Loss: 2.6305
#  Client2 Train => Local Epoch: 3 	Acc: 36.105 	Loss: 2.5441
#  Client2 Train => Local Epoch: 4 	Acc: 39.433 	Loss: 2.4620
#  Client2 Test =>                   	Acc: 1.300 	Loss: 6.8505
#  Client0 Train => Local Epoch: 0 	Acc: 9.722 	Loss: 4.1740
#  Client0 Train => Local Epoch: 1 	Acc: 21.747 	Loss: 3.0766
#  Client0 Train => Local Epoch: 2 	Acc: 24.497 	Loss: 2.8700
#  Client0 Train => Local Epoch: 3 	Acc: 29.346 	Loss: 2.7576
#  Client0 Train => Local Epoch: 4 	Acc: 31.218 	Loss: 2.6658
#  Client0 Test =>                   	Acc: 1.310 	Loss: 6.9119
#  Client8 Train => Local Epoch: 0 	Acc: 9.758 	Loss: 4.2630
#  Client8 Train => Local Epoch: 1 	Acc: 18.277 	Loss: 3.1251
#  Client8 Train => Local Epoch: 2 	Acc: 20.658 	Loss: 2.9785
#  Client8 Train => Local Epoch: 3 	Acc: 23.046 	Loss: 2.8953
#  Client8 Train => Local Epoch: 4 	Acc: 23.865 	Loss: 2.8491
#  Client8 Test =>                   	Acc: 1.906 	Loss: 6.7416
#  Client7 Train => Local Epoch: 0 	Acc: 8.220 	Loss: 4.5361
#  Client7 Train => Local Epoch: 1 	Acc: 18.157 	Loss: 3.3239
#  Client7 Train => Local Epoch: 2 	Acc: 21.753 	Loss: 3.0170
#  Client7 Train => Local Epoch: 3 	Acc: 24.754 	Loss: 2.9196
#  Client7 Train => Local Epoch: 4 	Acc: 26.446 	Loss: 2.8417
#  Client7 Test =>                   	Acc: 0.987 	Loss: 6.3682
#  Client6 Train => Local Epoch: 0 	Acc: 5.569 	Loss: 4.5556
#  Client6 Train => Local Epoch: 1 	Acc: 19.010 	Loss: 3.2563
#  Client6 Train => Local Epoch: 2 	Acc: 22.728 	Loss: 3.0115
#  Client6 Train => Local Epoch: 3 	Acc: 26.141 	Loss: 2.8694
#  Client6 Train => Local Epoch: 4 	Acc: 29.786 	Loss: 2.7780
#  Client6 Test =>                   	Acc: 2.462 	Loss: 7.4511
#  Client9 Train => Local Epoch: 0 	Acc: 7.077 	Loss: 4.4341
#  Client9 Train => Local Epoch: 1 	Acc: 22.796 	Loss: 3.1240
#  Client9 Train => Local Epoch: 2 	Acc: 25.978 	Loss: 2.8773
#  Client9 Train => Local Epoch: 3 	Acc: 28.874 	Loss: 2.7731
#  Client9 Train => Local Epoch: 4 	Acc: 30.196 	Loss: 2.7089
#  Client9 Test =>                   	Acc: 1.788 	Loss: 6.7785
#  Client5 Train => Local Epoch: 0 	Acc: 2.963 	Loss: 4.8318
#  Client5 Train => Local Epoch: 1 	Acc: 18.294 	Loss: 3.3830
#  Client5 Train => Local Epoch: 2 	Acc: 25.344 	Loss: 2.9264
#  Client5 Train => Local Epoch: 3 	Acc: 26.299 	Loss: 2.7859
#  Client5 Train => Local Epoch: 4 	Acc: 29.025 	Loss: 2.6820
#  Client5 Test =>                   	Acc: 1.505 	Loss: 6.6780
#  Client4 Train => Local Epoch: 0 	Acc: 4.583 	Loss: 4.5563
#  Client4 Train => Local Epoch: 1 	Acc: 20.105 	Loss: 3.5406
#  Client4 Train => Local Epoch: 2 	Acc: 25.064 	Loss: 3.1040
#  Client4 Train => Local Epoch: 3 	Acc: 28.570 	Loss: 2.9182
#  Client4 Train => Local Epoch: 4 	Acc: 28.990 	Loss: 2.8353
#  Client4 Test =>                   	Acc: 2.121 	Loss: 7.1809
# ====================== SERVER V1==========================
#  Train: Round   0, Avg Accuracy 29.208 | Avg Loss 2.752
#  Test: Round   0, Avg Accuracy 1.525 | Avg Loss 6.896
# Forgetting : Round 0, mean_forgetting : 0.000
# ==========================================================
#  Client9 Train => Local Epoch: 0 	Acc: 12.651 	Loss: 4.0705
#  Client9 Train => Local Epoch: 1 	Acc: 28.761 	Loss: 2.8626
#  Client9 Train => Local Epoch: 2 	Acc: 31.045 	Loss: 2.7081
#  Client9 Train => Local Epoch: 3 	Acc: 32.877 	Loss: 2.6358
#  Client9 Train => Local Epoch: 4 	Acc: 34.504 	Loss: 2.5841
#  Client9 Test =>                   	Acc: 2.805 	Loss: 6.5744
#  Client7 Train => Local Epoch: 0 	Acc: 3.066 	Loss: 4.6318
#  Client7 Train => Local Epoch: 1 	Acc: 21.192 	Loss: 3.4166
#  Client7 Train => Local Epoch: 2 	Acc: 26.886 	Loss: 2.9064
#  Client7 Train => Local Epoch: 3 	Acc: 28.310 	Loss: 2.7785
#  Client7 Train => Local Epoch: 4 	Acc: 30.622 	Loss: 2.7142
#  Client7 Test =>                   	Acc: 2.893 	Loss: 6.7310
#  Client4 Train => Local Epoch: 0 	Acc: 11.024 	Loss: 4.1099
#  Client4 Train => Local Epoch: 1 	Acc: 27.689 	Loss: 3.0762
#  Client4 Train => Local Epoch: 2 	Acc: 30.416 	Loss: 2.8238
#  Client4 Train => Local Epoch: 3 	Acc: 32.981 	Loss: 2.7357
#  Client4 Train => Local Epoch: 4 	Acc: 32.743 	Loss: 2.6649
#  Client4 Test =>                   	Acc: 4.223 	Loss: 6.4813
#  Client3 Train => Local Epoch: 0 	Acc: 12.969 	Loss: 4.2283
#  Client3 Train => Local Epoch: 1 	Acc: 24.141 	Loss: 3.1966
#  Client3 Train => Local Epoch: 2 	Acc: 25.755 	Loss: 2.9927
#  Client3 Train => Local Epoch: 3 	Acc: 27.969 	Loss: 2.8448
#  Client3 Train => Local Epoch: 4 	Acc: 30.495 	Loss: 2.7301
#  Client3 Test =>                   	Acc: 3.078 	Loss: 6.1017
#  Client2 Train => Local Epoch: 0 	Acc: 5.022 	Loss: 4.7313
#  Client2 Train => Local Epoch: 1 	Acc: 28.284 	Loss: 3.4860
#  Client2 Train => Local Epoch: 2 	Acc: 36.484 	Loss: 2.8106
#  Client2 Train => Local Epoch: 3 	Acc: 40.621 	Loss: 2.5398
#  Client2 Train => Local Epoch: 4 	Acc: 42.598 	Loss: 2.3780
#  Client2 Test =>                   	Acc: 3.293 	Loss: 6.6085
#  Client5 Train => Local Epoch: 0 	Acc: 0.593 	Loss: 4.6927
#  Client5 Train => Local Epoch: 1 	Acc: 13.876 	Loss: 3.7753
#  Client5 Train => Local Epoch: 2 	Acc: 26.037 	Loss: 2.9779
#  Client5 Train => Local Epoch: 3 	Acc: 30.843 	Loss: 2.7126
#  Client5 Train => Local Epoch: 4 	Acc: 33.778 	Loss: 2.5897
#  Client5 Test =>                   	Acc: 2.374 	Loss: 7.7147
#  Client8 Train => Local Epoch: 0 	Acc: 2.786 	Loss: 4.5960
#  Client8 Train => Local Epoch: 1 	Acc: 19.798 	Loss: 3.5836
#  Client8 Train => Local Epoch: 2 	Acc: 25.940 	Loss: 2.8909
#  Client8 Train => Local Epoch: 3 	Acc: 29.790 	Loss: 2.7267
#  Client8 Train => Local Epoch: 4 	Acc: 30.717 	Loss: 2.6702
#  Client8 Test =>                   	Acc: 2.610 	Loss: 6.7266
#  Client1 Train => Local Epoch: 0 	Acc: 2.791 	Loss: 4.6378
#  Client1 Train => Local Epoch: 1 	Acc: 20.408 	Loss: 3.5509
#  Client1 Train => Local Epoch: 2 	Acc: 31.492 	Loss: 2.8705
#  Client1 Train => Local Epoch: 3 	Acc: 34.867 	Loss: 2.6321
#  Client1 Train => Local Epoch: 4 	Acc: 36.994 	Loss: 2.5309
#  Client1 Test =>                   	Acc: 4.270 	Loss: 6.9382
#  Client6 Train => Local Epoch: 0 	Acc: 5.549 	Loss: 4.4465
#  Client6 Train => Local Epoch: 1 	Acc: 24.520 	Loss: 3.3527
#  Client6 Train => Local Epoch: 2 	Acc: 35.002 	Loss: 2.7457
#  Client6 Train => Local Epoch: 3 	Acc: 37.139 	Loss: 2.5647
#  Client6 Train => Local Epoch: 4 	Acc: 39.633 	Loss: 2.4804
#  Client6 Test =>                   	Acc: 4.017 	Loss: 6.2955
#  Client0 Train => Local Epoch: 0 	Acc: 9.391 	Loss: 4.2033
#  Client0 Train => Local Epoch: 1 	Acc: 27.526 	Loss: 3.0934
#  Client0 Train => Local Epoch: 2 	Acc: 35.173 	Loss: 2.5891
#  Client0 Train => Local Epoch: 3 	Acc: 39.496 	Loss: 2.4004
#  Client0 Train => Local Epoch: 4 	Acc: 41.313 	Loss: 2.3458
#  Client0 Test =>                   	Acc: 5.112 	Loss: 6.7090
# ====================== SERVER V1==========================
#  Train: Round   1, Avg Accuracy 35.340 | Avg Loss 2.569
#  Test: Round   1, Avg Accuracy 3.467 | Avg Loss 6.688
# Forgetting : Round 1, mean_forgetting : 0.358
# ==========================================================
#  Client5 Train => Local Epoch: 0 	Acc: 3.511 	Loss: 4.6227
#  Client5 Train => Local Epoch: 1 	Acc: 23.976 	Loss: 3.3891
#  Client5 Train => Local Epoch: 2 	Acc: 30.263 	Loss: 2.8018
#  Client5 Train => Local Epoch: 3 	Acc: 34.784 	Loss: 2.5681
#  Client5 Train => Local Epoch: 4 	Acc: 37.762 	Loss: 2.4618
#  Client5 Test =>                   	Acc: 2.785 	Loss: 7.4198
#  Client1 Train => Local Epoch: 0 	Acc: 4.761 	Loss: 4.4408
#  Client1 Train => Local Epoch: 1 	Acc: 29.553 	Loss: 3.0366
#  Client1 Train => Local Epoch: 2 	Acc: 35.588 	Loss: 2.6131
#  Client1 Train => Local Epoch: 3 	Acc: 38.605 	Loss: 2.4665
#  Client1 Train => Local Epoch: 4 	Acc: 41.164 	Loss: 2.3969
#  Client1 Test =>                   	Acc: 5.031 	Loss: 6.8748
#  Client6 Train => Local Epoch: 0 	Acc: 12.674 	Loss: 3.9569
#  Client6 Train => Local Epoch: 1 	Acc: 36.126 	Loss: 2.7562
#  Client6 Train => Local Epoch: 2 	Acc: 42.727 	Loss: 2.4114
#  Client6 Train => Local Epoch: 3 	Acc: 43.644 	Loss: 2.3366
#  Client6 Train => Local Epoch: 4 	Acc: 46.130 	Loss: 2.2581
#  Client6 Test =>                   	Acc: 7.496 	Loss: 5.8380
#  Client4 Train => Local Epoch: 0 	Acc: 11.087 	Loss: 4.2791
#  Client4 Train => Local Epoch: 1 	Acc: 26.406 	Loss: 3.2740
#  Client4 Train => Local Epoch: 2 	Acc: 35.448 	Loss: 2.7492
#  Client4 Train => Local Epoch: 3 	Acc: 37.678 	Loss: 2.6025
#  Client4 Train => Local Epoch: 4 	Acc: 38.604 	Loss: 2.5080
#  Client4 Test =>                   	Acc: 8.493 	Loss: 5.6130
#  Client9 Train => Local Epoch: 0 	Acc: 12.456 	Loss: 4.0516
#  Client9 Train => Local Epoch: 1 	Acc: 34.665 	Loss: 2.7029
#  Client9 Train => Local Epoch: 2 	Acc: 37.392 	Loss: 2.4850
#  Client9 Train => Local Epoch: 3 	Acc: 40.664 	Loss: 2.3748
#  Client9 Train => Local Epoch: 4 	Acc: 42.106 	Loss: 2.3352
#  Client9 Test =>                   	Acc: 6.971 	Loss: 10.3121
#  Client0 Train => Local Epoch: 0 	Acc: 12.714 	Loss: 3.8263
#  Client0 Train => Local Epoch: 1 	Acc: 38.072 	Loss: 2.6129
#  Client0 Train => Local Epoch: 2 	Acc: 43.638 	Loss: 2.3108
#  Client0 Train => Local Epoch: 3 	Acc: 45.528 	Loss: 2.2111
#  Client0 Train => Local Epoch: 4 	Acc: 47.747 	Loss: 2.1343
#  Client0 Test =>                   	Acc: 8.728 	Loss: 5.9260
#  Client3 Train => Local Epoch: 0 	Acc: 14.818 	Loss: 4.0216
#  Client3 Train => Local Epoch: 1 	Acc: 31.849 	Loss: 3.2926
#  Client3 Train => Local Epoch: 2 	Acc: 33.828 	Loss: 2.8555
#  Client3 Train => Local Epoch: 3 	Acc: 36.094 	Loss: 2.7023
#  Client3 Train => Local Epoch: 4 	Acc: 36.875 	Loss: 2.6593
#  Client3 Test =>                   	Acc: 5.688 	Loss: 5.9527
#  Client8 Train => Local Epoch: 0 	Acc: 4.962 	Loss: 4.5375
#  Client8 Train => Local Epoch: 1 	Acc: 21.461 	Loss: 3.3510
#  Client8 Train => Local Epoch: 2 	Acc: 31.413 	Loss: 2.7505
#  Client8 Train => Local Epoch: 3 	Acc: 32.715 	Loss: 2.6107
#  Client8 Train => Local Epoch: 4 	Acc: 35.017 	Loss: 2.5128
#  Client8 Test =>                   	Acc: 3.431 	Loss: 11.8933
#  Client2 Train => Local Epoch: 0 	Acc: 10.120 	Loss: 4.1898
#  Client2 Train => Local Epoch: 1 	Acc: 33.582 	Loss: 3.0101
#  Client2 Train => Local Epoch: 2 	Acc: 46.632 	Loss: 2.4233
#  Client2 Train => Local Epoch: 3 	Acc: 49.526 	Loss: 2.1895
#  Client2 Train => Local Epoch: 4 	Acc: 52.220 	Loss: 2.0935
#  Client2 Test =>                   	Acc: 6.001 	Loss: 5.9430
#  Client7 Train => Local Epoch: 0 	Acc: 4.305 	Loss: 4.4322
#  Client7 Train => Local Epoch: 1 	Acc: 23.444 	Loss: 3.3821
#  Client7 Train => Local Epoch: 2 	Acc: 34.962 	Loss: 2.7216
#  Client7 Train => Local Epoch: 3 	Acc: 37.349 	Loss: 2.5339
#  Client7 Train => Local Epoch: 4 	Acc: 39.240 	Loss: 2.4210
#  Client7 Test =>                   	Acc: 6.206 	Loss: 9.0362
# ====================== SERVER V1==========================
#  Train: Round   2, Avg Accuracy 41.686 | Avg Loss 2.378
#  Test: Round   2, Avg Accuracy 6.083 | Avg Loss 7.481
# Forgetting : Round 2, mean_forgetting : -0.460
# ==========================================================
#  Client0 Train => Local Epoch: 0 	Acc: 17.357 	Loss: 3.7352
#  Client0 Train => Local Epoch: 1 	Acc: 40.445 	Loss: 2.5493
#  Client0 Train => Local Epoch: 2 	Acc: 44.952 	Loss: 2.2571
#  Client0 Train => Local Epoch: 3 	Acc: 48.394 	Loss: 2.1390
#  Client0 Train => Local Epoch: 4 	Acc: 49.953 	Loss: 2.0577
#  Client0 Test =>                   	Acc: 10.419 	Loss: 5.6276
#  Client5 Train => Local Epoch: 0 	Acc: 4.297 	Loss: 4.6216
#  Client5 Train => Local Epoch: 1 	Acc: 28.780 	Loss: 3.2222
#  Client5 Train => Local Epoch: 2 	Acc: 37.652 	Loss: 2.5972
#  Client5 Train => Local Epoch: 3 	Acc: 40.328 	Loss: 2.4031
#  Client5 Train => Local Epoch: 4 	Acc: 43.619 	Loss: 2.2702
#  Client5 Test =>                   	Acc: 4.260 	Loss: 6.5063
#  Client4 Train => Local Epoch: 0 	Acc: 11.460 	Loss: 4.1604
#  Client4 Train => Local Epoch: 1 	Acc: 35.171 	Loss: 2.8360
#  Client4 Train => Local Epoch: 2 	Acc: 41.045 	Loss: 2.4694
#  Client4 Train => Local Epoch: 3 	Acc: 43.331 	Loss: 2.3158
#  Client4 Train => Local Epoch: 4 	Acc: 45.793 	Loss: 2.2277
#  Client4 Test =>                   	Acc: 10.163 	Loss: 5.5599
#  Client9 Train => Local Epoch: 0 	Acc: 16.193 	Loss: 3.8191
#  Client9 Train => Local Epoch: 1 	Acc: 38.215 	Loss: 2.6087
#  Client9 Train => Local Epoch: 2 	Acc: 43.380 	Loss: 2.3030
#  Client9 Train => Local Epoch: 3 	Acc: 46.174 	Loss: 2.2168
#  Client9 Train => Local Epoch: 4 	Acc: 47.793 	Loss: 2.1474
#  Client9 Test =>                   	Acc: 9.267 	Loss: 5.3806
#  Client7 Train => Local Epoch: 0 	Acc: 8.472 	Loss: 4.2344
#  Client7 Train => Local Epoch: 1 	Acc: 33.080 	Loss: 2.9100
#  Client7 Train => Local Epoch: 2 	Acc: 39.492 	Loss: 2.4192
#  Client7 Train => Local Epoch: 3 	Acc: 44.207 	Loss: 2.2811
#  Client7 Train => Local Epoch: 4 	Acc: 46.624 	Loss: 2.1920
#  Client7 Test =>                   	Acc: 6.540 	Loss: 7.2255
#  Client8 Train => Local Epoch: 0 	Acc: 10.769 	Loss: 4.1512
#  Client8 Train => Local Epoch: 1 	Acc: 34.098 	Loss: 2.7980
#  Client8 Train => Local Epoch: 2 	Acc: 38.220 	Loss: 2.4586
#  Client8 Train => Local Epoch: 3 	Acc: 40.940 	Loss: 2.3561
#  Client8 Train => Local Epoch: 4 	Acc: 42.302 	Loss: 2.2774
#  Client8 Test =>                   	Acc: 5.795 	Loss: 6.2835
#  Client2 Train => Local Epoch: 0 	Acc: 15.561 	Loss: 3.8345
#  Client2 Train => Local Epoch: 1 	Acc: 46.632 	Loss: 2.5303
#  Client2 Train => Local Epoch: 2 	Acc: 53.831 	Loss: 2.1061
#  Client2 Train => Local Epoch: 3 	Acc: 55.170 	Loss: 1.9864
#  Client2 Train => Local Epoch: 4 	Acc: 55.656 	Loss: 1.9010
#  Client2 Test =>                   	Acc: 8.395 	Loss: 5.4613
#  Client3 Train => Local Epoch: 0 	Acc: 11.953 	Loss: 4.1124
#  Client3 Train => Local Epoch: 1 	Acc: 35.573 	Loss: 2.8428
#  Client3 Train => Local Epoch: 2 	Acc: 43.646 	Loss: 2.4045
#  Client3 Train => Local Epoch: 3 	Acc: 48.594 	Loss: 2.1654
#  Client3 Train => Local Epoch: 4 	Acc: 48.021 	Loss: 2.1683
#  Client3 Test =>                   	Acc: 7.974 	Loss: 5.6940
#  Client1 Train => Local Epoch: 0 	Acc: 9.228 	Loss: 4.0699
#  Client1 Train => Local Epoch: 1 	Acc: 33.174 	Loss: 2.8943
#  Client1 Train => Local Epoch: 2 	Acc: 42.352 	Loss: 2.3995
#  Client1 Train => Local Epoch: 3 	Acc: 47.098 	Loss: 2.2144
#  Client1 Train => Local Epoch: 4 	Acc: 49.541 	Loss: 2.1138
#  Client1 Test =>                   	Acc: 8.139 	Loss: 5.7016
#  Client6 Train => Local Epoch: 0 	Acc: 14.892 	Loss: 3.8919
#  Client6 Train => Local Epoch: 1 	Acc: 42.716 	Loss: 2.5152
#  Client6 Train => Local Epoch: 2 	Acc: 49.469 	Loss: 2.1652
#  Client6 Train => Local Epoch: 3 	Acc: 52.307 	Loss: 2.0412
#  Client6 Train => Local Epoch: 4 	Acc: 53.551 	Loss: 1.9914
#  Client6 Test =>                   	Acc: 11.951 	Loss: 5.4276
# ====================== SERVER V1==========================
#  Train: Round   3, Avg Accuracy 48.285 | Avg Loss 2.135
#  Test: Round   3, Avg Accuracy 8.290 | Avg Loss 5.887
# Forgetting : Round 3, mean_forgetting : -1.001
# ==========================================================
#  Client5 Train => Local Epoch: 0 	Acc: 14.769 	Loss: 3.9695
#  Client5 Train => Local Epoch: 1 	Acc: 39.080 	Loss: 2.5518
#  Client5 Train => Local Epoch: 2 	Acc: 46.148 	Loss: 2.2186
#  Client5 Train => Local Epoch: 3 	Acc: 49.858 	Loss: 2.0603
#  Client5 Train => Local Epoch: 4 	Acc: 52.276 	Loss: 1.9809
#  Client5 Test =>                   	Acc: 7.846 	Loss: 5.5309
#  Client7 Train => Local Epoch: 0 	Acc: 11.158 	Loss: 4.1514
#  Client7 Train => Local Epoch: 1 	Acc: 40.914 	Loss: 2.5837
#  Client7 Train => Local Epoch: 2 	Acc: 45.834 	Loss: 2.2230
#  Client7 Train => Local Epoch: 3 	Acc: 51.410 	Loss: 2.0460
#  Client7 Train => Local Epoch: 4 	Acc: 51.379 	Loss: 1.9967
#  Client7 Test =>                   	Acc: 8.914 	Loss: 6.5326
#  Client1 Train => Local Epoch: 0 	Acc: 18.676 	Loss: 3.7874
#  Client1 Train => Local Epoch: 1 	Acc: 41.655 	Loss: 2.6024
#  Client1 Train => Local Epoch: 2 	Acc: 50.683 	Loss: 2.1622
#  Client1 Train => Local Epoch: 3 	Acc: 53.232 	Loss: 2.0217
#  Client1 Train => Local Epoch: 4 	Acc: 54.113 	Loss: 1.9477
#  Client1 Test =>                   	Acc: 10.368 	Loss: 4.9633
#  Client3 Train => Local Epoch: 0 	Acc: 16.146 	Loss: 3.6673
#  Client3 Train => Local Epoch: 1 	Acc: 39.766 	Loss: 2.6719
#  Client3 Train => Local Epoch: 2 	Acc: 37.630 	Loss: 2.7005
#  Client3 Train => Local Epoch: 3 	Acc: 42.760 	Loss: 2.3635
#  Client3 Train => Local Epoch: 4 	Acc: 45.599 	Loss: 2.2982
#  Client3 Test =>                   	Acc: 8.765 	Loss: 5.3651
#  Client0 Train => Local Epoch: 0 	Acc: 19.100 	Loss: 3.7901
#  Client0 Train => Local Epoch: 1 	Acc: 42.690 	Loss: 2.4500
#  Client0 Train => Local Epoch: 2 	Acc: 50.641 	Loss: 2.0974
#  Client0 Train => Local Epoch: 3 	Acc: 52.707 	Loss: 1.9708
#  Client0 Train => Local Epoch: 4 	Acc: 54.744 	Loss: 1.9064
#  Client0 Test =>                   	Acc: 10.321 	Loss: 6.0279
#  Client9 Train => Local Epoch: 0 	Acc: 18.019 	Loss: 3.7239
#  Client9 Train => Local Epoch: 1 	Acc: 44.376 	Loss: 2.3478
#  Client9 Train => Local Epoch: 2 	Acc: 49.908 	Loss: 2.0925
#  Client9 Train => Local Epoch: 3 	Acc: 53.766 	Loss: 1.9641
#  Client9 Train => Local Epoch: 4 	Acc: 54.986 	Loss: 1.9232
#  Client9 Test =>                   	Acc: 11.281 	Loss: 5.3740
#  Client2 Train => Local Epoch: 0 	Acc: 7.458 	Loss: 4.1455
#  Client2 Train => Local Epoch: 1 	Acc: 45.572 	Loss: 2.6668
#  Client2 Train => Local Epoch: 2 	Acc: 54.799 	Loss: 2.0682
#  Client2 Train => Local Epoch: 3 	Acc: 57.769 	Loss: 1.8884
#  Client2 Train => Local Epoch: 4 	Acc: 61.109 	Loss: 1.7716
#  Client2 Test =>                   	Acc: 10.604 	Loss: 4.9707
#  Client4 Train => Local Epoch: 0 	Acc: 12.404 	Loss: 3.9399
#  Client4 Train => Local Epoch: 1 	Acc: 42.292 	Loss: 2.5209
#  Client4 Train => Local Epoch: 2 	Acc: 49.961 	Loss: 2.1464
#  Client4 Train => Local Epoch: 3 	Acc: 52.200 	Loss: 2.0217
#  Client4 Train => Local Epoch: 4 	Acc: 54.333 	Loss: 1.9316
#  Client4 Test =>                   	Acc: 14.756 	Loss: 5.5270
#  Client8 Train => Local Epoch: 0 	Acc: 7.823 	Loss: 4.0543
#  Client8 Train => Local Epoch: 1 	Acc: 35.947 	Loss: 2.8179
#  Client8 Train => Local Epoch: 2 	Acc: 44.336 	Loss: 2.2876
#  Client8 Train => Local Epoch: 3 	Acc: 47.063 	Loss: 2.1549
#  Client8 Train => Local Epoch: 4 	Acc: 48.733 	Loss: 2.0850
#  Client8 Test =>                   	Acc: 9.284 	Loss: 4.9013
#  Client6 Train => Local Epoch: 0 	Acc: 25.495 	Loss: 3.3824
#  Client6 Train => Local Epoch: 1 	Acc: 53.295 	Loss: 2.0748
#  Client6 Train => Local Epoch: 2 	Acc: 57.754 	Loss: 1.8793
#  Client6 Train => Local Epoch: 3 	Acc: 60.137 	Loss: 1.7906
#  Client6 Train => Local Epoch: 4 	Acc: 60.822 	Loss: 1.7582
#  Client6 Test =>                   	Acc: 14.170 	Loss: 4.8012
# ====================== SERVER V1==========================
#  Train: Round   4, Avg Accuracy 53.810 | Avg Loss 1.960
#  Test: Round   4, Avg Accuracy 10.631 | Avg Loss 5.399
# Forgetting : Round 4, mean_forgetting : -0.799
# ==========================================================
#  Client0 Train => Local Epoch: 0 	Acc: 26.568 	Loss: 3.1893
#  Client0 Train => Local Epoch: 1 	Acc: 53.776 	Loss: 2.0163
#  Client0 Train => Local Epoch: 2 	Acc: 57.310 	Loss: 1.8291
#  Client0 Train => Local Epoch: 3 	Acc: 58.452 	Loss: 1.7672
#  Client0 Train => Local Epoch: 4 	Acc: 60.787 	Loss: 1.7092
#  Client0 Test =>                   	Acc: 13.830 	Loss: 4.7036
#  Client9 Train => Local Epoch: 0 	Acc: 27.792 	Loss: 3.2793
#  Client9 Train => Local Epoch: 1 	Acc: 52.725 	Loss: 2.0556
#  Client9 Train => Local Epoch: 2 	Acc: 56.684 	Loss: 1.8547
#  Client9 Train => Local Epoch: 3 	Acc: 58.791 	Loss: 1.7863
#  Client9 Train => Local Epoch: 4 	Acc: 60.564 	Loss: 1.7251
#  Client9 Test =>                   	Acc: 12.588 	Loss: 5.0737
#  Client4 Train => Local Epoch: 0 	Acc: 24.658 	Loss: 3.3084
#  Client4 Train => Local Epoch: 1 	Acc: 51.803 	Loss: 2.1262
#  Client4 Train => Local Epoch: 2 	Acc: 57.125 	Loss: 1.8690
#  Client4 Train => Local Epoch: 3 	Acc: 59.188 	Loss: 1.7844
#  Client4 Train => Local Epoch: 4 	Acc: 60.752 	Loss: 1.7221
#  Client4 Test =>                   	Acc: 15.420 	Loss: 4.9425
#  Client8 Train => Local Epoch: 0 	Acc: 17.026 	Loss: 3.6676
#  Client8 Train => Local Epoch: 1 	Acc: 44.210 	Loss: 2.3595
#  Client8 Train => Local Epoch: 2 	Acc: 49.474 	Loss: 2.0842
#  Client8 Train => Local Epoch: 3 	Acc: 53.391 	Loss: 1.9585
#  Client8 Train => Local Epoch: 4 	Acc: 53.108 	Loss: 1.9261
#  Client8 Test =>                   	Acc: 9.587 	Loss: 5.3993
#  Client2 Train => Local Epoch: 0 	Acc: 23.800 	Loss: 3.4318
#  Client2 Train => Local Epoch: 1 	Acc: 56.453 	Loss: 2.1219
#  Client2 Train => Local Epoch: 2 	Acc: 61.631 	Loss: 1.8141
#  Client2 Train => Local Epoch: 3 	Acc: 63.684 	Loss: 1.6804
#  Client2 Train => Local Epoch: 4 	Acc: 66.063 	Loss: 1.5791
#  Client2 Test =>                   	Acc: 10.301 	Loss: 5.2966
#  Client1 Train => Local Epoch: 0 	Acc: 29.821 	Loss: 3.1877
#  Client1 Train => Local Epoch: 1 	Acc: 52.361 	Loss: 2.1178
#  Client1 Train => Local Epoch: 2 	Acc: 58.013 	Loss: 1.8399
#  Client1 Train => Local Epoch: 3 	Acc: 60.422 	Loss: 1.7337
#  Client1 Train => Local Epoch: 4 	Acc: 62.452 	Loss: 1.6690
#  Client1 Test =>                   	Acc: 12.362 	Loss: 5.8939
#  Client6 Train => Local Epoch: 0 	Acc: 29.670 	Loss: 3.1434
#  Client6 Train => Local Epoch: 1 	Acc: 59.041 	Loss: 1.8712
#  Client6 Train => Local Epoch: 2 	Acc: 62.778 	Loss: 1.7047
#  Client6 Train => Local Epoch: 3 	Acc: 64.460 	Loss: 1.6346
#  Client6 Train => Local Epoch: 4 	Acc: 65.994 	Loss: 1.5860
#  Client6 Test =>                   	Acc: 15.585 	Loss: 4.9238
#  Client7 Train => Local Epoch: 0 	Acc: 15.933 	Loss: 3.6589
#  Client7 Train => Local Epoch: 1 	Acc: 47.923 	Loss: 2.2870
#  Client7 Train => Local Epoch: 2 	Acc: 54.778 	Loss: 1.9028
#  Client7 Train => Local Epoch: 3 	Acc: 58.557 	Loss: 1.7663
#  Client7 Train => Local Epoch: 4 	Acc: 61.639 	Loss: 1.6791
#  Client7 Test =>                   	Acc: 11.523 	Loss: 4.9698
#  Client5 Train => Local Epoch: 0 	Acc: 12.659 	Loss: 3.8316
#  Client5 Train => Local Epoch: 1 	Acc: 46.495 	Loss: 2.3902
#  Client5 Train => Local Epoch: 2 	Acc: 55.816 	Loss: 1.8950
#  Client5 Train => Local Epoch: 3 	Acc: 60.032 	Loss: 1.7578
#  Client5 Train => Local Epoch: 4 	Acc: 61.552 	Loss: 1.6688
#  Client5 Test =>                   	Acc: 8.833 	Loss: 8.5405
#  Client3 Train => Local Epoch: 0 	Acc: 25.026 	Loss: 3.2444
#  Client3 Train => Local Epoch: 1 	Acc: 55.573 	Loss: 2.0157
#  Client3 Train => Local Epoch: 2 	Acc: 59.271 	Loss: 1.7954
#  Client3 Train => Local Epoch: 3 	Acc: 50.651 	Loss: 2.0325
#  Client3 Train => Local Epoch: 4 	Acc: 49.844 	Loss: 2.0080
#  Client3 Test =>                   	Acc: 9.264 	Loss: 5.0454
# ====================== SERVER V1==========================
#  Train: Round   5, Avg Accuracy 60.276 | Avg Loss 1.727
#  Test: Round   5, Avg Accuracy 11.929 | Avg Loss 5.479
# Forgetting : Round 5, mean_forgetting : -1.002
# ==========================================================
#  Client0 Train => Local Epoch: 0 	Acc: 21.567 	Loss: 3.4753
#  Client0 Train => Local Epoch: 1 	Acc: 52.880 	Loss: 2.1151
#  Client0 Train => Local Epoch: 2 	Acc: 58.718 	Loss: 1.8006
#  Client0 Train => Local Epoch: 3 	Acc: 61.394 	Loss: 1.6831
#  Client0 Train => Local Epoch: 4 	Acc: 63.371 	Loss: 1.6321
#  Client0 Test =>                   	Acc: 11.426 	Loss: 6.1904
#  Client4 Train => Local Epoch: 0 	Acc: 22.382 	Loss: 3.3418
#  Client4 Train => Local Epoch: 1 	Acc: 54.694 	Loss: 2.0470
#  Client4 Train => Local Epoch: 2 	Acc: 60.534 	Loss: 1.7566
#  Client4 Train => Local Epoch: 3 	Acc: 63.972 	Loss: 1.6382
#  Client4 Train => Local Epoch: 4 	Acc: 64.574 	Loss: 1.6072
#  Client4 Test =>                   	Acc: 20.865 	Loss: 4.1595
#  Client2 Train => Local Epoch: 0 	Acc: 19.794 	Loss: 3.5441
#  Client2 Train => Local Epoch: 1 	Acc: 55.226 	Loss: 2.2187
#  Client2 Train => Local Epoch: 2 	Acc: 61.615 	Loss: 1.8043
#  Client2 Train => Local Epoch: 3 	Acc: 65.968 	Loss: 1.6051
#  Client2 Train => Local Epoch: 4 	Acc: 68.451 	Loss: 1.5087
#  Client2 Test =>                   	Acc: 11.806 	Loss: 4.7917
#  Client5 Train => Local Epoch: 0 	Acc: 16.962 	Loss: 3.7039
#  Client5 Train => Local Epoch: 1 	Acc: 53.626 	Loss: 2.0608
#  Client5 Train => Local Epoch: 2 	Acc: 60.403 	Loss: 1.7386
#  Client5 Train => Local Epoch: 3 	Acc: 63.417 	Loss: 1.6104
#  Client5 Train => Local Epoch: 4 	Acc: 66.063 	Loss: 1.5362
#  Client5 Test =>                   	Acc: 9.722 	Loss: 11.1941
#  Client3 Train => Local Epoch: 0 	Acc: 26.953 	Loss: 3.0205
#  Client3 Train => Local Epoch: 1 	Acc: 57.109 	Loss: 1.9673
#  Client3 Train => Local Epoch: 2 	Acc: 60.911 	Loss: 1.7513
#  Client3 Train => Local Epoch: 3 	Acc: 61.510 	Loss: 1.6560
#  Client3 Train => Local Epoch: 4 	Acc: 60.964 	Loss: 1.7291
#  Client3 Test =>                   	Acc: 11.678 	Loss: 4.9418
#  Client9 Train => Local Epoch: 0 	Acc: 23.176 	Loss: 3.3747
#  Client9 Train => Local Epoch: 1 	Acc: 54.183 	Loss: 2.0197
#  Client9 Train => Local Epoch: 2 	Acc: 60.651 	Loss: 1.7451
#  Client9 Train => Local Epoch: 3 	Acc: 63.006 	Loss: 1.6597
#  Client9 Train => Local Epoch: 4 	Acc: 65.383 	Loss: 1.5949
#  Client9 Test =>                   	Acc: 14.534 	Loss: 4.6860
#  Client1 Train => Local Epoch: 0 	Acc: 23.080 	Loss: 3.2772
#  Client1 Train => Local Epoch: 1 	Acc: 54.191 	Loss: 2.0635
#  Client1 Train => Local Epoch: 2 	Acc: 61.914 	Loss: 1.7410
#  Client1 Train => Local Epoch: 3 	Acc: 64.414 	Loss: 1.6312
#  Client1 Train => Local Epoch: 4 	Acc: 66.305 	Loss: 1.5484
#  Client1 Test =>                   	Acc: 13.524 	Loss: 4.6985
#  Client7 Train => Local Epoch: 0 	Acc: 28.975 	Loss: 3.1957
#  Client7 Train => Local Epoch: 1 	Acc: 54.076 	Loss: 2.0491
#  Client7 Train => Local Epoch: 2 	Acc: 61.132 	Loss: 1.7249
#  Client7 Train => Local Epoch: 3 	Acc: 63.625 	Loss: 1.6270
#  Client7 Train => Local Epoch: 4 	Acc: 65.231 	Loss: 1.5526
#  Client7 Test =>                   	Acc: 15.440 	Loss: 4.4931
#  Client6 Train => Local Epoch: 0 	Acc: 29.467 	Loss: 3.0841
#  Client6 Train => Local Epoch: 1 	Acc: 60.792 	Loss: 1.8262
#  Client6 Train => Local Epoch: 2 	Acc: 65.419 	Loss: 1.6068
#  Client6 Train => Local Epoch: 3 	Acc: 68.172 	Loss: 1.5266
#  Client6 Train => Local Epoch: 4 	Acc: 70.267 	Loss: 1.4491
#  Client6 Test =>                   	Acc: 18.497 	Loss: 4.0802
#  Client8 Train => Local Epoch: 0 	Acc: 20.114 	Loss: 3.4231
#  Client8 Train => Local Epoch: 1 	Acc: 50.032 	Loss: 2.1736
#  Client8 Train => Local Epoch: 2 	Acc: 56.292 	Loss: 1.8803
#  Client8 Train => Local Epoch: 3 	Acc: 58.893 	Loss: 1.7688
#  Client8 Train => Local Epoch: 4 	Acc: 61.512 	Loss: 1.6942
#  Client8 Test =>                   	Acc: 13.173 	Loss: 4.6270
# ====================== SERVER V1==========================
#  Train: Round   6, Avg Accuracy 65.212 | Avg Loss 1.585
#  Test: Round   6, Avg Accuracy 14.067 | Avg Loss 5.386
# Forgetting : Round 6, mean_forgetting : -1.194
# ==========================================================
#  Client6 Train => Local Epoch: 0 	Acc: 45.320 	Loss: 2.3793
#  Client6 Train => Local Epoch: 1 	Acc: 68.043 	Loss: 1.5227
#  Client6 Train => Local Epoch: 2 	Acc: 70.519 	Loss: 1.4295
#  Client6 Train => Local Epoch: 3 	Acc: 72.080 	Loss: 1.3665
#  Client6 Train => Local Epoch: 4 	Acc: 73.988 	Loss: 1.3311
#  Client6 Test =>                   	Acc: 19.807 	Loss: 4.1560
#  Client7 Train => Local Epoch: 0 	Acc: 25.723 	Loss: 3.0979
#  Client7 Train => Local Epoch: 1 	Acc: 60.236 	Loss: 1.8294
#  Client7 Train => Local Epoch: 2 	Acc: 64.886 	Loss: 1.6118
#  Client7 Train => Local Epoch: 3 	Acc: 68.541 	Loss: 1.4893
#  Client7 Train => Local Epoch: 4 	Acc: 70.420 	Loss: 1.4057
#  Client7 Test =>                   	Acc: 15.618 	Loss: 4.8927
#  Client4 Train => Local Epoch: 0 	Acc: 35.372 	Loss: 2.8584
#  Client4 Train => Local Epoch: 1 	Acc: 60.246 	Loss: 1.8294
#  Client4 Train => Local Epoch: 2 	Acc: 66.250 	Loss: 1.5779
#  Client4 Train => Local Epoch: 3 	Acc: 66.255 	Loss: 1.5143
#  Client4 Train => Local Epoch: 4 	Acc: 69.249 	Loss: 1.4356
#  Client4 Test =>                   	Acc: 21.491 	Loss: 3.9335
#  Client3 Train => Local Epoch: 0 	Acc: 37.344 	Loss: 2.5416
#  Client3 Train => Local Epoch: 1 	Acc: 64.714 	Loss: 1.7178
#  Client3 Train => Local Epoch: 2 	Acc: 68.073 	Loss: 1.5940
#  Client3 Train => Local Epoch: 3 	Acc: 67.865 	Loss: 1.5050
#  Client3 Train => Local Epoch: 4 	Acc: 67.734 	Loss: 1.4985
#  Client3 Test =>                   	Acc: 15.723 	Loss: 4.1675
#  Client0 Train => Local Epoch: 0 	Acc: 35.316 	Loss: 2.9310
#  Client0 Train => Local Epoch: 1 	Acc: 59.186 	Loss: 1.8223
#  Client0 Train => Local Epoch: 2 	Acc: 64.449 	Loss: 1.6044
#  Client0 Train => Local Epoch: 3 	Acc: 67.918 	Loss: 1.4821
#  Client0 Train => Local Epoch: 4 	Acc: 68.715 	Loss: 1.4439
#  Client0 Test =>                   	Acc: 15.921 	Loss: 4.2537
#  Client8 Train => Local Epoch: 0 	Acc: 25.764 	Loss: 3.3102
#  Client8 Train => Local Epoch: 1 	Acc: 54.693 	Loss: 2.0028
#  Client8 Train => Local Epoch: 2 	Acc: 59.473 	Loss: 1.7451
#  Client8 Train => Local Epoch: 3 	Acc: 62.036 	Loss: 1.6589
#  Client8 Train => Local Epoch: 4 	Acc: 64.522 	Loss: 1.5798
#  Client8 Test =>                   	Acc: 12.793 	Loss: 6.6398
#  Client2 Train => Local Epoch: 0 	Acc: 25.299 	Loss: 3.0832
#  Client2 Train => Local Epoch: 1 	Acc: 61.065 	Loss: 1.8821
#  Client2 Train => Local Epoch: 2 	Acc: 68.009 	Loss: 1.5702
#  Client2 Train => Local Epoch: 3 	Acc: 71.508 	Loss: 1.4253
#  Client2 Train => Local Epoch: 4 	Acc: 72.118 	Loss: 1.3630
#  Client2 Test =>                   	Acc: 12.187 	Loss: 5.1433
#  Client5 Train => Local Epoch: 0 	Acc: 19.486 	Loss: 3.3472
#  Client5 Train => Local Epoch: 1 	Acc: 58.426 	Loss: 1.8804
#  Client5 Train => Local Epoch: 2 	Acc: 65.897 	Loss: 1.5558
#  Client5 Train => Local Epoch: 3 	Acc: 68.905 	Loss: 1.4597
#  Client5 Train => Local Epoch: 4 	Acc: 70.375 	Loss: 1.3985
#  Client5 Test =>                   	Acc: 14.062 	Loss: 4.8285
#  Client1 Train => Local Epoch: 0 	Acc: 21.983 	Loss: 3.2125
#  Client1 Train => Local Epoch: 1 	Acc: 59.221 	Loss: 1.8666
#  Client1 Train => Local Epoch: 2 	Acc: 65.600 	Loss: 1.5886
#  Client1 Train => Local Epoch: 3 	Acc: 69.336 	Loss: 1.4718
#  Client1 Train => Local Epoch: 4 	Acc: 71.477 	Loss: 1.3952
#  Client1 Test =>                   	Acc: 16.524 	Loss: 4.1489
#  Client9 Train => Local Epoch: 0 	Acc: 30.313 	Loss: 2.9822
#  Client9 Train => Local Epoch: 1 	Acc: 61.605 	Loss: 1.7379
#  Client9 Train => Local Epoch: 2 	Acc: 66.848 	Loss: 1.5479
#  Client9 Train => Local Epoch: 3 	Acc: 68.858 	Loss: 1.4601
#  Client9 Train => Local Epoch: 4 	Acc: 70.469 	Loss: 1.4086
#  Client9 Test =>                   	Acc: 18.167 	Loss: 4.7635
# ====================== SERVER V1==========================
#  Train: Round   7, Avg Accuracy 69.907 | Avg Loss 1.426
#  Test: Round   7, Avg Accuracy 16.229 | Avg Loss 4.693
# Forgetting : Round 7, mean_forgetting : -1.486
# ==========================================================
#  Client1 Train => Local Epoch: 0 	Acc: 41.749 	Loss: 2.4393
#  Client1 Train => Local Epoch: 1 	Acc: 68.160 	Loss: 1.5172
#  Client1 Train => Local Epoch: 2 	Acc: 72.246 	Loss: 1.3584
#  Client1 Train => Local Epoch: 3 	Acc: 74.297 	Loss: 1.2810
#  Client1 Train => Local Epoch: 4 	Acc: 75.774 	Loss: 1.2361
#  Client1 Test =>                   	Acc: 19.282 	Loss: 3.8341
#  Client0 Train => Local Epoch: 0 	Acc: 42.126 	Loss: 2.5795
#  Client0 Train => Local Epoch: 1 	Acc: 66.315 	Loss: 1.5438
#  Client0 Train => Local Epoch: 2 	Acc: 69.970 	Loss: 1.4063
#  Client0 Train => Local Epoch: 3 	Acc: 72.115 	Loss: 1.3334
#  Client0 Train => Local Epoch: 4 	Acc: 73.843 	Loss: 1.2887
#  Client0 Test =>                   	Acc: 21.424 	Loss: 3.9115
#  Client6 Train => Local Epoch: 0 	Acc: 44.672 	Loss: 2.4820
#  Client6 Train => Local Epoch: 1 	Acc: 69.824 	Loss: 1.5030
#  Client6 Train => Local Epoch: 2 	Acc: 72.686 	Loss: 1.3684
#  Client6 Train => Local Epoch: 3 	Acc: 74.217 	Loss: 1.3124
#  Client6 Train => Local Epoch: 4 	Acc: 75.833 	Loss: 1.2588
#  Client6 Test =>                   	Acc: 23.188 	Loss: 3.7090
#  Client7 Train => Local Epoch: 0 	Acc: 29.941 	Loss: 3.0558
#  Client7 Train => Local Epoch: 1 	Acc: 60.239 	Loss: 1.8273
#  Client7 Train => Local Epoch: 2 	Acc: 68.516 	Loss: 1.4966
#  Client7 Train => Local Epoch: 3 	Acc: 71.514 	Loss: 1.4031
#  Client7 Train => Local Epoch: 4 	Acc: 70.870 	Loss: 1.3809
#  Client7 Test =>                   	Acc: 17.767 	Loss: 4.0116
#  Client2 Train => Local Epoch: 0 	Acc: 27.073 	Loss: 3.2026
#  Client2 Train => Local Epoch: 1 	Acc: 64.433 	Loss: 1.8194
#  Client2 Train => Local Epoch: 2 	Acc: 70.117 	Loss: 1.4939
#  Client2 Train => Local Epoch: 3 	Acc: 72.744 	Loss: 1.3643
#  Client2 Train => Local Epoch: 4 	Acc: 75.239 	Loss: 1.2764
#  Client2 Test =>                   	Acc: 15.403 	Loss: 4.0383
#  Client8 Train => Local Epoch: 0 	Acc: 27.197 	Loss: 3.1580
#  Client8 Train => Local Epoch: 1 	Acc: 58.908 	Loss: 1.8036
#  Client8 Train => Local Epoch: 2 	Acc: 63.915 	Loss: 1.5948
#  Client8 Train => Local Epoch: 3 	Acc: 67.051 	Loss: 1.5077
#  Client8 Train => Local Epoch: 4 	Acc: 67.684 	Loss: 1.4613
#  Client8 Test =>                   	Acc: 13.322 	Loss: 5.3587
#  Client9 Train => Local Epoch: 0 	Acc: 32.969 	Loss: 2.8877
#  Client9 Train => Local Epoch: 1 	Acc: 64.167 	Loss: 1.6929
#  Client9 Train => Local Epoch: 2 	Acc: 69.981 	Loss: 1.4444
#  Client9 Train => Local Epoch: 3 	Acc: 72.621 	Loss: 1.3603
#  Client9 Train => Local Epoch: 4 	Acc: 73.425 	Loss: 1.3106
#  Client9 Test =>                   	Acc: 19.477 	Loss: 3.9183
#  Client3 Train => Local Epoch: 0 	Acc: 26.224 	Loss: 3.1836
#  Client3 Train => Local Epoch: 1 	Acc: 59.740 	Loss: 1.8674
#  Client3 Train => Local Epoch: 2 	Acc: 65.964 	Loss: 1.6132
#  Client3 Train => Local Epoch: 3 	Acc: 71.458 	Loss: 1.3821
#  Client3 Train => Local Epoch: 4 	Acc: 71.224 	Loss: 1.3366
#  Client3 Test =>                   	Acc: 16.251 	Loss: 4.0523
#  Client4 Train => Local Epoch: 0 	Acc: 32.904 	Loss: 2.9164
#  Client4 Train => Local Epoch: 1 	Acc: 63.098 	Loss: 1.7050
#  Client4 Train => Local Epoch: 2 	Acc: 68.533 	Loss: 1.4832
#  Client4 Train => Local Epoch: 3 	Acc: 70.884 	Loss: 1.3896
#  Client4 Train => Local Epoch: 4 	Acc: 72.568 	Loss: 1.3389
#  Client4 Test =>                   	Acc: 23.259 	Loss: 3.8675
#  Client5 Train => Local Epoch: 0 	Acc: 27.289 	Loss: 3.0156
#  Client5 Train => Local Epoch: 1 	Acc: 64.424 	Loss: 1.7060
#  Client5 Train => Local Epoch: 2 	Acc: 69.806 	Loss: 1.4393
#  Client5 Train => Local Epoch: 3 	Acc: 72.952 	Loss: 1.3358
#  Client5 Train => Local Epoch: 4 	Acc: 74.984 	Loss: 1.2646
#  Client5 Test =>                   	Acc: 15.420 	Loss: 4.4559
# ====================== SERVER V1==========================
#  Train: Round   8, Avg Accuracy 73.144 | Avg Loss 1.315
#  Test: Round   8, Avg Accuracy 18.479 | Avg Loss 4.116
# Forgetting : Round 8, mean_forgetting : -1.325
# ==========================================================
#  Client9 Train => Local Epoch: 0 	Acc: 44.173 	Loss: 2.4300
#  Client9 Train => Local Epoch: 1 	Acc: 69.962 	Loss: 1.4922
#  Client9 Train => Local Epoch: 2 	Acc: 72.449 	Loss: 1.3519
#  Client9 Train => Local Epoch: 3 	Acc: 74.206 	Loss: 1.2859
#  Client9 Train => Local Epoch: 4 	Acc: 76.287 	Loss: 1.2342
#  Client9 Test =>                   	Acc: 22.195 	Loss: 3.6972
#  Client3 Train => Local Epoch: 0 	Acc: 31.224 	Loss: 2.8129
#  Client3 Train => Local Epoch: 1 	Acc: 62.266 	Loss: 1.7948
#  Client3 Train => Local Epoch: 2 	Acc: 61.094 	Loss: 1.6828
#  Client3 Train => Local Epoch: 3 	Acc: 66.172 	Loss: 1.5709
#  Client3 Train => Local Epoch: 4 	Acc: 66.250 	Loss: 1.4493
#  Client3 Test =>                   	Acc: 16.447 	Loss: 3.9951
#  Client1 Train => Local Epoch: 0 	Acc: 26.726 	Loss: 3.2659
#  Client1 Train => Local Epoch: 1 	Acc: 60.121 	Loss: 1.8938
#  Client1 Train => Local Epoch: 2 	Acc: 69.394 	Loss: 1.5148
#  Client1 Train => Local Epoch: 3 	Acc: 72.469 	Loss: 1.3792
#  Client1 Train => Local Epoch: 4 	Acc: 74.285 	Loss: 1.3006
#  Client1 Test =>                   	Acc: 15.214 	Loss: 3.9662
#  Client0 Train => Local Epoch: 0 	Acc: 36.481 	Loss: 2.7513
#  Client0 Train => Local Epoch: 1 	Acc: 66.808 	Loss: 1.5396
#  Client0 Train => Local Epoch: 2 	Acc: 71.947 	Loss: 1.3605
#  Client0 Train => Local Epoch: 3 	Acc: 73.588 	Loss: 1.2885
#  Client0 Train => Local Epoch: 4 	Acc: 75.220 	Loss: 1.2366
#  Client0 Test =>                   	Acc: 22.205 	Loss: 3.7383
#  Client6 Train => Local Epoch: 0 	Acc: 42.860 	Loss: 2.5023
#  Client6 Train => Local Epoch: 1 	Acc: 71.308 	Loss: 1.4520
#  Client6 Train => Local Epoch: 2 	Acc: 75.052 	Loss: 1.2986
#  Client6 Train => Local Epoch: 3 	Acc: 75.796 	Loss: 1.2481
#  Client6 Train => Local Epoch: 4 	Acc: 78.529 	Loss: 1.1863
#  Client6 Test =>                   	Acc: 24.421 	Loss: 3.4765
#  Client4 Train => Local Epoch: 0 	Acc: 40.525 	Loss: 2.6135
#  Client4 Train => Local Epoch: 1 	Acc: 67.920 	Loss: 1.5590
#  Client4 Train => Local Epoch: 2 	Acc: 72.856 	Loss: 1.3723
#  Client4 Train => Local Epoch: 3 	Acc: 74.412 	Loss: 1.2840
#  Client4 Train => Local Epoch: 4 	Acc: 75.576 	Loss: 1.2635
#  Client4 Test =>                   	Acc: 24.589 	Loss: 3.5941
#  Client7 Train => Local Epoch: 0 	Acc: 33.535 	Loss: 2.8593
#  Client7 Train => Local Epoch: 1 	Acc: 66.498 	Loss: 1.6138
#  Client7 Train => Local Epoch: 2 	Acc: 72.249 	Loss: 1.3788
#  Client7 Train => Local Epoch: 3 	Acc: 73.849 	Loss: 1.2980
#  Client7 Train => Local Epoch: 4 	Acc: 74.655 	Loss: 1.2655
#  Client7 Test =>                   	Acc: 20.249 	Loss: 3.7975
#  Client5 Train => Local Epoch: 0 	Acc: 25.237 	Loss: 3.1834
#  Client5 Train => Local Epoch: 1 	Acc: 64.759 	Loss: 1.8072
#  Client5 Train => Local Epoch: 2 	Acc: 71.278 	Loss: 1.4487
#  Client5 Train => Local Epoch: 3 	Acc: 73.319 	Loss: 1.3292
#  Client5 Train => Local Epoch: 4 	Acc: 75.917 	Loss: 1.2478
#  Client5 Test =>                   	Acc: 15.409 	Loss: 4.9519
#  Client2 Train => Local Epoch: 0 	Acc: 17.140 	Loss: 3.3686
#  Client2 Train => Local Epoch: 1 	Acc: 62.787 	Loss: 1.7960
#  Client2 Train => Local Epoch: 2 	Acc: 71.460 	Loss: 1.3932
#  Client2 Train => Local Epoch: 3 	Acc: 76.068 	Loss: 1.2587
#  Client2 Train => Local Epoch: 4 	Acc: 78.125 	Loss: 1.1761
#  Client2 Test =>                   	Acc: 14.729 	Loss: 4.9023
#  Client8 Train => Local Epoch: 0 	Acc: 27.755 	Loss: 3.0806
#  Client8 Train => Local Epoch: 1 	Acc: 61.802 	Loss: 1.7233
#  Client8 Train => Local Epoch: 2 	Acc: 66.162 	Loss: 1.5066
#  Client8 Train => Local Epoch: 3 	Acc: 69.149 	Loss: 1.4146
#  Client8 Train => Local Epoch: 4 	Acc: 70.079 	Loss: 1.3660
#  Client8 Test =>                   	Acc: 18.619 	Loss: 4.0595
# ====================== SERVER V1==========================
#  Train: Round   9, Avg Accuracy 74.492 | Avg Loss 1.273
#  Test: Round   9, Avg Accuracy 19.408 | Avg Loss 4.018
# Forgetting : Round 9, mean_forgetting : -1.287
# ==========================================================
#  Client3 Train => Local Epoch: 0 	Acc: 31.328 	Loss: 2.9159
#  Client3 Train => Local Epoch: 1 	Acc: 65.339 	Loss: 1.7415
#  Client3 Train => Local Epoch: 2 	Acc: 64.609 	Loss: 1.7275
#  Client3 Train => Local Epoch: 3 	Acc: 68.542 	Loss: 1.4889
#  Client3 Train => Local Epoch: 4 	Acc: 68.906 	Loss: 1.5102
#  Client3 Test =>                   	Acc: 14.766 	Loss: 4.7837
#  Client7 Train => Local Epoch: 0 	Acc: 36.870 	Loss: 2.6946
#  Client7 Train => Local Epoch: 1 	Acc: 65.751 	Loss: 1.5908
#  Client7 Train => Local Epoch: 2 	Acc: 72.422 	Loss: 1.3628
#  Client7 Train => Local Epoch: 3 	Acc: 76.771 	Loss: 1.2428
#  Client7 Train => Local Epoch: 4 	Acc: 78.008 	Loss: 1.1852
#  Client7 Test =>                   	Acc: 20.834 	Loss: 3.7948
#  Client8 Train => Local Epoch: 0 	Acc: 36.133 	Loss: 2.7044
#  Client8 Train => Local Epoch: 1 	Acc: 64.380 	Loss: 1.6304
#  Client8 Train => Local Epoch: 2 	Acc: 69.733 	Loss: 1.4212
#  Client8 Train => Local Epoch: 3 	Acc: 72.114 	Loss: 1.3354
#  Client8 Train => Local Epoch: 4 	Acc: 73.502 	Loss: 1.2893
#  Client8 Test =>                   	Acc: 18.726 	Loss: 4.2431
#  Client1 Train => Local Epoch: 0 	Acc: 32.938 	Loss: 2.8502
#  Client1 Train => Local Epoch: 1 	Acc: 68.381 	Loss: 1.6083
#  Client1 Train => Local Epoch: 2 	Acc: 73.854 	Loss: 1.3496
#  Client1 Train => Local Epoch: 3 	Acc: 76.085 	Loss: 1.2557
#  Client1 Train => Local Epoch: 4 	Acc: 77.547 	Loss: 1.1891
#  Client1 Test =>                   	Acc: 18.753 	Loss: 3.9971
#  Client0 Train => Local Epoch: 0 	Acc: 39.412 	Loss: 2.6235
#  Client0 Train => Local Epoch: 1 	Acc: 69.650 	Loss: 1.4692
#  Client0 Train => Local Epoch: 2 	Acc: 74.124 	Loss: 1.2989
#  Client0 Train => Local Epoch: 3 	Acc: 76.584 	Loss: 1.2114
#  Client0 Train => Local Epoch: 4 	Acc: 77.410 	Loss: 1.1738
#  Client0 Test =>                   	Acc: 22.966 	Loss: 3.6279
#  Client9 Train => Local Epoch: 0 	Acc: 42.246 	Loss: 2.5828
#  Client9 Train => Local Epoch: 1 	Acc: 69.222 	Loss: 1.5049
#  Client9 Train => Local Epoch: 2 	Acc: 73.959 	Loss: 1.3172
#  Client9 Train => Local Epoch: 3 	Acc: 76.235 	Loss: 1.2425
#  Client9 Train => Local Epoch: 4 	Acc: 77.384 	Loss: 1.1880
#  Client9 Test =>                   	Acc: 23.603 	Loss: 3.6059
#  Client6 Train => Local Epoch: 0 	Acc: 47.704 	Loss: 2.3161
#  Client6 Train => Local Epoch: 1 	Acc: 73.880 	Loss: 1.3484
#  Client6 Train => Local Epoch: 2 	Acc: 78.196 	Loss: 1.2068
#  Client6 Train => Local Epoch: 3 	Acc: 78.647 	Loss: 1.1655
#  Client6 Train => Local Epoch: 4 	Acc: 80.410 	Loss: 1.1136
#  Client6 Test =>                   	Acc: 26.825 	Loss: 3.3729
#  Client4 Train => Local Epoch: 0 	Acc: 41.129 	Loss: 2.5300
#  Client4 Train => Local Epoch: 1 	Acc: 69.889 	Loss: 1.4812
#  Client4 Train => Local Epoch: 2 	Acc: 74.836 	Loss: 1.2966
#  Client4 Train => Local Epoch: 3 	Acc: 76.113 	Loss: 1.2375
#  Client4 Train => Local Epoch: 4 	Acc: 77.932 	Loss: 1.1720
#  Client4 Test =>                   	Acc: 23.017 	Loss: 4.0932
#  Client5 Train => Local Epoch: 0 	Acc: 33.967 	Loss: 2.7981
#  Client5 Train => Local Epoch: 1 	Acc: 68.192 	Loss: 1.5917
#  Client5 Train => Local Epoch: 2 	Acc: 73.816 	Loss: 1.3242
#  Client5 Train => Local Epoch: 3 	Acc: 77.844 	Loss: 1.2004
#  Client5 Train => Local Epoch: 4 	Acc: 79.436 	Loss: 1.1412
#  Client5 Test =>                   	Acc: 16.591 	Loss: 4.1492
#  Client2 Train => Local Epoch: 0 	Acc: 21.584 	Loss: 3.0948
#  Client2 Train => Local Epoch: 1 	Acc: 66.677 	Loss: 1.6897
#  Client2 Train => Local Epoch: 2 	Acc: 76.028 	Loss: 1.3112
#  Client2 Train => Local Epoch: 3 	Acc: 78.544 	Loss: 1.1851
#  Client2 Train => Local Epoch: 4 	Acc: 80.329 	Loss: 1.1096
#  Client2 Test =>                   	Acc: 17.386 	Loss: 4.2712
# ====================== SERVER V1==========================
#  Train: Round  10, Avg Accuracy 77.087 | Avg Loss 1.207
#  Test: Round  10, Avg Accuracy 20.347 | Avg Loss 3.994
# Forgetting : Round 10, mean_forgetting : -1.132
# ==========================================================
#  Client8 Train => Local Epoch: 0 	Acc: 33.878 	Loss: 2.8263
#  Client8 Train => Local Epoch: 1 	Acc: 67.084 	Loss: 1.5498
#  Client8 Train => Local Epoch: 2 	Acc: 71.764 	Loss: 1.3475
#  Client8 Train => Local Epoch: 3 	Acc: 74.450 	Loss: 1.2436
#  Client8 Train => Local Epoch: 4 	Acc: 75.533 	Loss: 1.2200
#  Client8 Test =>                   	Acc: 21.676 	Loss: 3.6186
#  Client0 Train => Local Epoch: 0 	Acc: 39.155 	Loss: 2.5690
#  Client0 Train => Local Epoch: 1 	Acc: 72.291 	Loss: 1.3681
#  Client0 Train => Local Epoch: 2 	Acc: 76.831 	Loss: 1.2204
#  Client0 Train => Local Epoch: 3 	Acc: 78.412 	Loss: 1.1380
#  Client0 Train => Local Epoch: 4 	Acc: 80.300 	Loss: 1.0945
#  Client0 Test =>                   	Acc: 23.074 	Loss: 3.7756
#  Client1 Train => Local Epoch: 0 	Acc: 40.193 	Loss: 2.5626
# ...
# ====================== SERVER V1==========================
#  Train: Round  95, Avg Accuracy 99.404 | Avg Loss 0.480
#  Test: Round  95, Avg Accuracy 59.707 | Avg Loss 1.959
# Forgetting : Round 95, mean_forgetting : -0.964
# ==========================================================
#  Client3 Train => Local Epoch: 0 	Acc: 96.380 	Loss: 0.6012
#  Client3 Train => Local Epoch: 1 	Acc: 97.604 	Loss: 0.5680
#  Client3 Train => Local Epoch: 2 	Acc: 98.828 	Loss: 0.5339
#  Client3 Train => Local Epoch: 3 	Acc: 98.932 	Loss: 0.5037
#  Client3 Train => Local Epoch: 4 	Acc: 99.141 	Loss: 0.5510
#  Client3 Test =>                   	Acc: 60.429 	Loss: 1.9447
#  Client9 Train => Local Epoch: 0 	Acc: 98.212 	Loss: 0.5234
#  Client9 Train => Local Epoch: 1 	Acc: 99.444 	Loss: 0.4796
#  Client9 Train => Local Epoch: 2 	Acc: 99.542 	Loss: 0.4727
#  Client9 Train => Local Epoch: 3 	Acc: 99.568 	Loss: 0.4718
#  Client9 Train => Local Epoch: 4 	Acc: 99.598 	Loss: 0.4677
#  Client9 Test =>                   	Acc: 60.075 	Loss: 1.9253
#  Client8 Train => Local Epoch: 0 	Acc: 98.917 	Loss: 0.5117
#  Client8 Train => Local Epoch: 1 	Acc: 99.289 	Loss: 0.4860
#  Client8 Train => Local Epoch: 2 	Acc: 99.479 	Loss: 0.4746
#  Client8 Train => Local Epoch: 3 	Acc: 99.565 	Loss: 0.4725
#  Client8 Train => Local Epoch: 4 	Acc: 99.293 	Loss: 0.4808
#  Client8 Test =>                   	Acc: 50.576 	Loss: 2.3352
#  Client2 Train => Local Epoch: 0 	Acc: 98.653 	Loss: 0.5321
#  Client2 Train => Local Epoch: 1 	Acc: 99.099 	Loss: 0.5003
#  Client2 Train => Local Epoch: 2 	Acc: 99.546 	Loss: 0.4836
#  Client2 Train => Local Epoch: 3 	Acc: 99.601 	Loss: 0.4757
#  Client2 Train => Local Epoch: 4 	Acc: 99.657 	Loss: 0.4727
#  Client2 Test =>                   	Acc: 58.570 	Loss: 2.0121
#  Client6 Train => Local Epoch: 0 	Acc: 98.930 	Loss: 0.5129
#  Client6 Train => Local Epoch: 1 	Acc: 99.425 	Loss: 0.4750
#  Client6 Train => Local Epoch: 2 	Acc: 99.579 	Loss: 0.4718
#  Client6 Train => Local Epoch: 3 	Acc: 99.384 	Loss: 0.4716
#  Client6 Train => Local Epoch: 4 	Acc: 99.576 	Loss: 0.4694
#  Client6 Test =>                   	Acc: 59.860 	Loss: 1.9642
#  Client1 Train => Local Epoch: 0 	Acc: 98.730 	Loss: 0.5174
#  Client1 Train => Local Epoch: 1 	Acc: 99.281 	Loss: 0.4908
#  Client1 Train => Local Epoch: 2 	Acc: 99.557 	Loss: 0.4788
#  Client1 Train => Local Epoch: 3 	Acc: 99.672 	Loss: 0.4727
#  Client1 Train => Local Epoch: 4 	Acc: 99.557 	Loss: 0.4742
#  Client1 Test =>                   	Acc: 60.587 	Loss: 1.8921
#  Client5 Train => Local Epoch: 0 	Acc: 98.190 	Loss: 0.5324
#  Client5 Train => Local Epoch: 1 	Acc: 99.392 	Loss: 0.4853
#  Client5 Train => Local Epoch: 2 	Acc: 99.497 	Loss: 0.4778
#  Client5 Train => Local Epoch: 3 	Acc: 99.584 	Loss: 0.4765
#  Client5 Train => Local Epoch: 4 	Acc: 99.586 	Loss: 0.4711
#  Client5 Test =>                   	Acc: 56.371 	Loss: 2.0333
#  Client0 Train => Local Epoch: 0 	Acc: 98.119 	Loss: 0.5437
#  Client0 Train => Local Epoch: 1 	Acc: 99.450 	Loss: 0.4880
#  Client0 Train => Local Epoch: 2 	Acc: 99.433 	Loss: 0.4782
#  Client0 Train => Local Epoch: 3 	Acc: 99.541 	Loss: 0.4754
#  Client0 Train => Local Epoch: 4 	Acc: 99.541 	Loss: 0.4776
#  Client0 Test =>                   	Acc: 63.581 	Loss: 1.8136
#  Client7 Train => Local Epoch: 0 	Acc: 97.385 	Loss: 0.5574
#  Client7 Train => Local Epoch: 1 	Acc: 99.306 	Loss: 0.4922
#  Client7 Train => Local Epoch: 2 	Acc: 99.414 	Loss: 0.4825
#  Client7 Train => Local Epoch: 3 	Acc: 99.281 	Loss: 0.4890
#  Client7 Train => Local Epoch: 4 	Acc: 98.950 	Loss: 0.4893
#  Client7 Test =>                   	Acc: 59.355 	Loss: 1.9451
#  Client4 Train => Local Epoch: 0 	Acc: 98.081 	Loss: 0.5352
#  Client4 Train => Local Epoch: 1 	Acc: 99.202 	Loss: 0.4908
#  Client4 Train => Local Epoch: 2 	Acc: 99.389 	Loss: 0.4784
#  Client4 Train => Local Epoch: 3 	Acc: 99.558 	Loss: 0.4772
#  Client4 Train => Local Epoch: 4 	Acc: 99.558 	Loss: 0.4722
#  Client4 Test =>                   	Acc: 63.332 	Loss: 1.7923
# ====================== SERVER V1==========================
#  Train: Round  96, Avg Accuracy 99.446 | Avg Loss 0.483
#  Test: Round  96, Avg Accuracy 59.274 | Avg Loss 1.966
# Forgetting : Round 96, mean_forgetting : -0.938
# ==========================================================
#  Client1 Train => Local Epoch: 0 	Acc: 99.075 	Loss: 0.5012
#  Client1 Train => Local Epoch: 1 	Acc: 99.603 	Loss: 0.4850
#  Client1 Train => Local Epoch: 2 	Acc: 99.678 	Loss: 0.4720
#  Client1 Train => Local Epoch: 3 	Acc: 99.505 	Loss: 0.4756
#  Client1 Train => Local Epoch: 4 	Acc: 99.586 	Loss: 0.4708
#  Client1 Test =>                   	Acc: 61.348 	Loss: 1.8410
#  Client5 Train => Local Epoch: 0 	Acc: 98.738 	Loss: 0.5113
#  Client5 Train => Local Epoch: 1 	Acc: 99.564 	Loss: 0.4800
#  Client5 Train => Local Epoch: 2 	Acc: 99.477 	Loss: 0.4755
#  Client5 Train => Local Epoch: 3 	Acc: 99.714 	Loss: 0.4715
#  Client5 Train => Local Epoch: 4 	Acc: 99.651 	Loss: 0.4686
#  Client5 Test =>                   	Acc: 56.674 	Loss: 2.0474
#  Client4 Train => Local Epoch: 0 	Acc: 99.010 	Loss: 0.5025
#  Client4 Train => Local Epoch: 1 	Acc: 99.418 	Loss: 0.4781
#  Client4 Train => Local Epoch: 2 	Acc: 99.490 	Loss: 0.4762
#  Client4 Train => Local Epoch: 3 	Acc: 99.558 	Loss: 0.4716
#  Client4 Train => Local Epoch: 4 	Acc: 99.541 	Loss: 0.4695
#  Client4 Test =>                   	Acc: 63.204 	Loss: 1.8073
#  Client9 Train => Local Epoch: 0 	Acc: 98.933 	Loss: 0.5058
#  Client9 Train => Local Epoch: 1 	Acc: 99.508 	Loss: 0.4808
#  Client9 Train => Local Epoch: 2 	Acc: 99.602 	Loss: 0.4713
#  Client9 Train => Local Epoch: 3 	Acc: 99.643 	Loss: 0.4722
#  Client9 Train => Local Epoch: 4 	Acc: 99.508 	Loss: 0.4694
#  Client9 Test =>                   	Acc: 62.392 	Loss: 1.9033
#  Client6 Train => Local Epoch: 0 	Acc: 99.065 	Loss: 0.5036
#  Client6 Train => Local Epoch: 1 	Acc: 99.501 	Loss: 0.4738
#  Client6 Train => Local Epoch: 2 	Acc: 99.609 	Loss: 0.4697
#  Client6 Train => Local Epoch: 3 	Acc: 99.715 	Loss: 0.4628
#  Client6 Train => Local Epoch: 4 	Acc: 99.609 	Loss: 0.4668
#  Client6 Test =>                   	Acc: 58.668 	Loss: 2.0202
#  Client0 Train => Local Epoch: 0 	Acc: 98.448 	Loss: 0.5287
#  Client0 Train => Local Epoch: 1 	Acc: 99.328 	Loss: 0.4880
#  Client0 Train => Local Epoch: 2 	Acc: 99.552 	Loss: 0.4770
#  Client0 Train => Local Epoch: 3 	Acc: 99.617 	Loss: 0.4702
#  Client0 Train => Local Epoch: 4 	Acc: 99.572 	Loss: 0.4707
#  Client0 Test =>                   	Acc: 64.022 	Loss: 1.7928
#  Client3 Train => Local Epoch: 0 	Acc: 95.260 	Loss: 0.6063
#  Client3 Train => Local Epoch: 1 	Acc: 97.474 	Loss: 0.6129
#  Client3 Train => Local Epoch: 2 	Acc: 96.901 	Loss: 0.5936
#  Client3 Train => Local Epoch: 3 	Acc: 98.880 	Loss: 0.5325
#  Client3 Train => Local Epoch: 4 	Acc: 97.500 	Loss: 0.5260
#  Client3 Test =>                   	Acc: 60.096 	Loss: 1.9118
#  Client2 Train => Local Epoch: 0 	Acc: 98.422 	Loss: 0.5351
#  Client2 Train => Local Epoch: 1 	Acc: 99.111 	Loss: 0.5058
#  Client2 Train => Local Epoch: 2 	Acc: 99.442 	Loss: 0.4890
#  Client2 Train => Local Epoch: 3 	Acc: 99.581 	Loss: 0.4752
#  Client2 Train => Local Epoch: 4 	Acc: 99.601 	Loss: 0.4739
#  Client2 Test =>                   	Acc: 58.308 	Loss: 2.0176
#  Client7 Train => Local Epoch: 0 	Acc: 98.611 	Loss: 0.5252
#  Client7 Train => Local Epoch: 1 	Acc: 99.173 	Loss: 0.4981
#  Client7 Train => Local Epoch: 2 	Acc: 99.411 	Loss: 0.4795
#  Client7 Train => Local Epoch: 3 	Acc: 99.457 	Loss: 0.4775
#  Client7 Train => Local Epoch: 4 	Acc: 99.544 	Loss: 0.4798
#  Client7 Test =>                   	Acc: 62.648 	Loss: 1.8559
#  Client8 Train => Local Epoch: 0 	Acc: 98.940 	Loss: 0.5019
#  Client8 Train => Local Epoch: 1 	Acc: 99.461 	Loss: 0.4807
#  Client8 Train => Local Epoch: 2 	Acc: 99.740 	Loss: 0.4676
#  Client8 Train => Local Epoch: 3 	Acc: 99.416 	Loss: 0.4738
#  Client8 Train => Local Epoch: 4 	Acc: 99.758 	Loss: 0.4664
#  Client8 Test =>                   	Acc: 48.485 	Loss: 2.4255
# ====================== SERVER V1==========================
#  Train: Round  97, Avg Accuracy 99.387 | Avg Loss 0.476
#  Test: Round  97, Avg Accuracy 59.584 | Avg Loss 1.962
# Forgetting : Round 97, mean_forgetting : -0.296
# ==========================================================
#  Client4 Train => Local Epoch: 0 	Acc: 98.896 	Loss: 0.5140
#  Client4 Train => Local Epoch: 1 	Acc: 99.474 	Loss: 0.4809
#  Client4 Train => Local Epoch: 2 	Acc: 99.592 	Loss: 0.4743
#  Client4 Train => Local Epoch: 3 	Acc: 99.592 	Loss: 0.4719
#  Client4 Train => Local Epoch: 4 	Acc: 99.592 	Loss: 0.4720
#  Client4 Test =>                   	Acc: 63.830 	Loss: 1.7848
#  Client6 Train => Local Epoch: 0 	Acc: 99.279 	Loss: 0.4988
#  Client6 Train => Local Epoch: 1 	Acc: 99.501 	Loss: 0.4722
#  Client6 Train => Local Epoch: 2 	Acc: 99.553 	Loss: 0.4701
#  Client6 Train => Local Epoch: 3 	Acc: 99.820 	Loss: 0.4628
#  Client6 Train => Local Epoch: 4 	Acc: 99.639 	Loss: 0.4650
#  Client6 Test =>                   	Acc: 59.038 	Loss: 2.0162
#  Client2 Train => Local Epoch: 0 	Acc: 98.980 	Loss: 0.5175
#  Client2 Train => Local Epoch: 1 	Acc: 99.637 	Loss: 0.4852
#  Client2 Train => Local Epoch: 2 	Acc: 99.314 	Loss: 0.4803
#  Client2 Train => Local Epoch: 3 	Acc: 99.581 	Loss: 0.4772
#  Client2 Train => Local Epoch: 4 	Acc: 99.574 	Loss: 0.4732
#  Client2 Test =>                   	Acc: 59.654 	Loss: 1.9619
#  Client3 Train => Local Epoch: 0 	Acc: 97.552 	Loss: 0.5785
#  Client3 Train => Local Epoch: 1 	Acc: 99.349 	Loss: 0.5071
#  Client3 Train => Local Epoch: 2 	Acc: 99.219 	Loss: 0.4949
#  Client3 Train => Local Epoch: 3 	Acc: 97.995 	Loss: 0.5787
#  Client3 Train => Local Epoch: 4 	Acc: 97.865 	Loss: 0.5462
#  Client3 Test =>                   	Acc: 61.631 	Loss: 1.8641
#  Client1 Train => Local Epoch: 0 	Acc: 98.780 	Loss: 0.5152
#  Client1 Train => Local Epoch: 1 	Acc: 99.609 	Loss: 0.4862
#  Client1 Train => Local Epoch: 2 	Acc: 99.494 	Loss: 0.4798
#  Client1 Train => Local Epoch: 3 	Acc: 99.511 	Loss: 0.4787
#  Client1 Train => Local Epoch: 4 	Acc: 99.718 	Loss: 0.4708
#  Client1 Test =>                   	Acc: 61.769 	Loss: 1.9042
#  Client5 Train => Local Epoch: 0 	Acc: 97.461 	Loss: 0.5539
#  Client5 Train => Local Epoch: 1 	Acc: 99.257 	Loss: 0.4919
#  Client5 Train => Local Epoch: 2 	Acc: 99.564 	Loss: 0.4765
#  Client5 Train => Local Epoch: 3 	Acc: 99.566 	Loss: 0.4732
#  Client5 Train => Local Epoch: 4 	Acc: 99.651 	Loss: 0.4706
#  Client5 Test =>                   	Acc: 56.684 	Loss: 2.0597
#  Client0 Train => Local Epoch: 0 	Acc: 98.210 	Loss: 0.5349
#  Client0 Train => Local Epoch: 1 	Acc: 99.338 	Loss: 0.4891
#  Client0 Train => Local Epoch: 2 	Acc: 99.368 	Loss: 0.4809
#  Client0 Train => Local Epoch: 3 	Acc: 99.654 	Loss: 0.4737
#  Client0 Train => Local Epoch: 4 	Acc: 99.572 	Loss: 0.4713
#  Client0 Test =>                   	Acc: 63.904 	Loss: 1.8208
#  Client9 Train => Local Epoch: 0 	Acc: 98.775 	Loss: 0.5138
#  Client9 Train => Local Epoch: 1 	Acc: 99.583 	Loss: 0.4773
#  Client9 Train => Local Epoch: 2 	Acc: 99.478 	Loss: 0.4729
#  Client9 Train => Local Epoch: 3 	Acc: 99.760 	Loss: 0.4685
#  Client9 Train => Local Epoch: 4 	Acc: 99.587 	Loss: 0.4670
#  Client9 Test =>                   	Acc: 63.584 	Loss: 1.8639
#  Client8 Train => Local Epoch: 0 	Acc: 99.163 	Loss: 0.4966
#  Client8 Train => Local Epoch: 1 	Acc: 99.516 	Loss: 0.4733
#  Client8 Train => Local Epoch: 2 	Acc: 99.606 	Loss: 0.4723
#  Client8 Train => Local Epoch: 3 	Acc: 99.680 	Loss: 0.4674
#  Client8 Train => Local Epoch: 4 	Acc: 99.665 	Loss: 0.4660
#  Client8 Test =>                   	Acc: 49.980 	Loss: 2.4045
#  Client7 Train => Local Epoch: 0 	Acc: 99.021 	Loss: 0.5164
#  Client7 Train => Local Epoch: 1 	Acc: 99.327 	Loss: 0.4874
#  Client7 Train => Local Epoch: 2 	Acc: 99.501 	Loss: 0.4815
#  Client7 Train => Local Epoch: 3 	Acc: 99.718 	Loss: 0.4752
#  Client7 Train => Local Epoch: 4 	Acc: 99.476 	Loss: 0.4741
#  Client7 Test =>                   	Acc: 60.948 	Loss: 1.8800
# ====================== SERVER V1==========================
#  Train: Round  98, Avg Accuracy 99.434 | Avg Loss 0.478
#  Test: Round  98, Avg Accuracy 60.102 | Avg Loss 1.956
# Forgetting : Round 98, mean_forgetting : -0.869
# ==========================================================
#  Client9 Train => Local Epoch: 0 	Acc: 99.489 	Loss: 0.4825
#  Client9 Train => Local Epoch: 1 	Acc: 99.602 	Loss: 0.4710
#  Client9 Train => Local Epoch: 2 	Acc: 99.594 	Loss: 0.4697
#  Client9 Train => Local Epoch: 3 	Acc: 99.579 	Loss: 0.4677
#  Client9 Train => Local Epoch: 4 	Acc: 99.534 	Loss: 0.4704
#  Client9 Test =>                   	Acc: 62.655 	Loss: 1.8888
#  Client6 Train => Local Epoch: 0 	Acc: 99.095 	Loss: 0.4986
#  Client6 Train => Local Epoch: 1 	Acc: 99.546 	Loss: 0.4750
#  Client6 Train => Local Epoch: 2 	Acc: 99.609 	Loss: 0.4686
#  Client6 Train => Local Epoch: 3 	Acc: 99.715 	Loss: 0.4655
#  Client6 Train => Local Epoch: 4 	Acc: 99.745 	Loss: 0.4625
#  Client6 Test =>                   	Acc: 58.863 	Loss: 2.0270
#  Client3 Train => Local Epoch: 0 	Acc: 97.292 	Loss: 0.5685
#  Client3 Train => Local Epoch: 1 	Acc: 97.344 	Loss: 0.5964
#  Client3 Train => Local Epoch: 2 	Acc: 97.526 	Loss: 0.5766
#  Client3 Train => Local Epoch: 3 	Acc: 99.297 	Loss: 0.5360
#  Client3 Train => Local Epoch: 4 	Acc: 95.938 	Loss: 0.6088
#  Client3 Test =>                   	Acc: 59.567 	Loss: 1.9442
#  Client4 Train => Local Epoch: 0 	Acc: 98.016 	Loss: 0.5390
#  Client4 Train => Local Epoch: 1 	Acc: 99.333 	Loss: 0.4887
#  Client4 Train => Local Epoch: 2 	Acc: 99.265 	Loss: 0.4830
#  Client4 Train => Local Epoch: 3 	Acc: 99.440 	Loss: 0.4795
#  Client4 Train => Local Epoch: 4 	Acc: 99.507 	Loss: 0.4764
#  Client4 Test =>                   	Acc: 61.298 	Loss: 1.8441
#  Client8 Train => Local Epoch: 0 	Acc: 99.386 	Loss: 0.4932
#  Client8 Train => Local Epoch: 1 	Acc: 99.401 	Loss: 0.4792
#  Client8 Train => Local Epoch: 2 	Acc: 99.494 	Loss: 0.4704
#  Client8 Train => Local Epoch: 3 	Acc: 99.702 	Loss: 0.4674
#  Client8 Train => Local Epoch: 4 	Acc: 99.494 	Loss: 0.4692
#  Client8 Test =>                   	Acc: 47.421 	Loss: 2.4626
#  Client1 Train => Local Epoch: 0 	Acc: 98.918 	Loss: 0.5135
#  Client1 Train => Local Epoch: 1 	Acc: 99.632 	Loss: 0.4823
#  Client1 Train => Local Epoch: 2 	Acc: 99.724 	Loss: 0.4768
#  Client1 Train => Local Epoch: 3 	Acc: 99.417 	Loss: 0.4780
#  Client1 Train => Local Epoch: 4 	Acc: 99.643 	Loss: 0.4733
#  Client1 Test =>                   	Acc: 60.234 	Loss: 1.8694
#  Client2 Train => Local Epoch: 0 	Acc: 98.414 	Loss: 0.5359
#  Client2 Train => Local Epoch: 1 	Acc: 99.294 	Loss: 0.4926
#  Client2 Train => Local Epoch: 2 	Acc: 99.637 	Loss: 0.4802
#  Client2 Train => Local Epoch: 3 	Acc: 99.574 	Loss: 0.4780
#  Client2 Train => Local Epoch: 4 	Acc: 99.621 	Loss: 0.4737
#  Client2 Test =>                   	Acc: 58.590 	Loss: 1.9928
#  Client0 Train => Local Epoch: 0 	Acc: 98.550 	Loss: 0.5286
#  Client0 Train => Local Epoch: 1 	Acc: 99.263 	Loss: 0.4910
#  Client0 Train => Local Epoch: 2 	Acc: 99.490 	Loss: 0.4782
#  Client0 Train => Local Epoch: 3 	Acc: 99.609 	Loss: 0.4740
#  Client0 Train => Local Epoch: 4 	Acc: 99.549 	Loss: 0.4701
#  Client0 Test =>                   	Acc: 63.992 	Loss: 1.8077
#  Client5 Train => Local Epoch: 0 	Acc: 98.434 	Loss: 0.5309
#  Client5 Train => Local Epoch: 1 	Acc: 99.521 	Loss: 0.4831
#  Client5 Train => Local Epoch: 2 	Acc: 99.562 	Loss: 0.4763
#  Client5 Train => Local Epoch: 3 	Acc: 99.586 	Loss: 0.4760
#  Client5 Train => Local Epoch: 4 	Acc: 99.562 	Loss: 0.4719
#  Client5 Test =>                   	Acc: 55.590 	Loss: 2.0739
#  Client7 Train => Local Epoch: 0 	Acc: 98.872 	Loss: 0.5234
#  Client7 Train => Local Epoch: 1 	Acc: 99.436 	Loss: 0.4849
#  Client7 Train => Local Epoch: 2 	Acc: 99.674 	Loss: 0.4743
#  Client7 Train => Local Epoch: 3 	Acc: 98.993 	Loss: 0.4829
#  Client7 Train => Local Epoch: 4 	Acc: 99.674 	Loss: 0.4779
#  Client7 Test =>                   	Acc: 60.537 	Loss: 1.8985
# ====================== SERVER V1==========================
#  Train: Round  99, Avg Accuracy 99.227 | Avg Loss 0.485
#  Test: Round  99, Avg Accuracy 58.875 | Avg Loss 1.981
# Forgetting : Round 99, mean_forgetting : -0.845
# ==========================================================
# Training and Evaluation completed!
# Saved: SFLV2 + Projected - CIFAR-100 α=0.1 - Early Cut.csv
