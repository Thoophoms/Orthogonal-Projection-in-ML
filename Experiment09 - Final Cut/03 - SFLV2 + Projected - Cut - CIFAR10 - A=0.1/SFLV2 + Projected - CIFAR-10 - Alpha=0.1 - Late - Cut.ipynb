# %% [markdown]
# # Split Federated Learning V2 + Projected:
# ### CIFAR-10 + α = 0.1
# #### Experiment - Late Cut (at Layer 6 + Activation)

# %%
# =============================================================================
# SFLV2 + Orthogonal Projection (Gated) on CIFAR-10 (Dirichlet α=0.1)
# - Warmup + alpha ramp + norm-preserving projection
# - Train-side feature reservoir (no test leakage)
# - Rebuild U every 5 rounds; clear buffer after rebuild
# - SGD + momentum + cosine LR (server); label smoothing
# - local_ep = 5; CIFAR-100 RandAug-lite; freeze client BN after warmup
# =============================================================================
import torch
from torch import nn
from torchvision import transforms
from torch.utils.data import DataLoader, Dataset
import torch.nn.functional as F
import math
import os.path
import pandas as pd
from sklearn.model_selection import train_test_split
from PIL import Image
from glob import glob
from pandas import DataFrame
import random
import numpy as np
import os


import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import copy
import time

# ----------------------------- Repro & Device --------------------------------
SEED = 1234
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
if torch.cuda.is_available():
    torch.backends.cudnn.deterministic = True
    print(torch.cuda.get_device_name(0))   
    

    
def _sync_cuda():
    if torch.cuda.is_available():
        torch.cuda.synchronize()

#===================================================================
program = "SFLV2 + Projected - CIFAR-10 α=0.1 - Late Cut"
DATASET_NAME = "CIFAR10"
DATA_ROOT = "data"


print(f"---------{program}----------")              # this is to identify the program in the slurm outputs files


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
pin = torch.cuda.is_available()


# To print in color -------test/train of the client side
def prRed(skk): print("\033[91m {}\033[00m" .format(skk)) 
def prGreen(skk): print("\033[92m {}\033[00m" .format(skk))     


#===================================================================
BATCH_SIZE = 256
LR_BASE = 0.001
MOMENTUM = 0.9
WEIGHT_DECAY = 5e-4
LABEL_SMOOTH = 0.0
NUM_WORKERS = 4


# No. of users
NUM_CLIENTS = 10
EPOCHS = 200
LOCAL_EPOCHS = 5
FRAC = 1        # participation of clients; if 1 then 100% clients participate in SFLV2
ALPHA = 0.1     # Non-IID split


#=====================================================================================================
#                           Orthogonal Config
#=====================================================================================================
# Orthogonal projection config deque
ORTH = True
TOP_R = 8 # Smaller r to avoid over-pruning
rebuild_every = 5         # rebuild subspace cadence (rounds)
WARMUP_ROUNDS = 10         # no projection before this
alpha_max = 0.1           # target projection strength
alpha_min = 0.0
alpha_warm_len = 10       # rounds to ramp alpha after warmup

# total samples for building U_old
# Feature reservoir (train-side only)
FEATURE_MEM_CAP = 4096    # train-side feature reservoir
FEATURE_MEM = []
_seen = 0


U_old = None              # D x r matrix of principal directions at the cut
ell_global = 0            # current round index (for alpha schedule)


# ====================== Confirm =======================================
cut_at = "Late-cut at Layer 6 + Activation"
prRed(f"\tData:\t\t{DATASET_NAME}\n\tCut:\t\t{cut_at}\n\tGlobal Rounds:\t{EPOCHS}\n\tClients:\t{NUM_CLIENTS}\n\tLocal Epochs:\t{LOCAL_EPOCHS}\n\tα:\t\t{ALPHA}\n\tWarm-up:\t{WARMUP_ROUNDS}\n\tRebuild:\t{rebuild_every}")


#=====================================================================================================
#                       Round 4 New: Projection Gate
#=====================================================================================================

def proj_gate_strength(round_idx: int):
    """Alpha schedule for projection."""
    if round_idx < WARMUP_ROUNDS:
        return 0.0
    t = min(1.0, (round_idx - WARMUP_ROUNDS) / max(1, alpha_warm_len))
    return alpha_min + t * (alpha_max - alpha_min)

#=====================================================================================================
#                           Projection Help
#=====================================================================================================
def project_off_subspace_gated(grad_batch: torch.Tensor, U: torch.Tensor, alpha: float, preserve_norm=True):
    """g' = g - alpha * P_U(g), optionally rescale to preserve per-sample norm."""
    if (U is None) or (alpha <= 0.0):
        return grad_batch
    B = grad_batch.shape[0]
    g = grad_batch.view(B, -1)              # [B, D]
    comp = (g @ U) @ U.T                    # [B, D]
    if preserve_norm:
        n0 = g.norm(dim=1, keepdim=True).clamp_min(1e-12)
    g2 = g - alpha * comp
    if preserve_norm:
        n1 = g2.norm(dim=1, keepdim=True).clamp_min(1e-12)
        g2 = g2 * (n0 / n1)
    return g2.view_as(grad_batch)


def add_to_reservoir(rows_cpu_fp16: torch.Tensor):
    """Standard reservoir sampling to keep a fixed-size unbiased buffer."""
    global _seen, FEATURE_MEM
    for r in rows_cpu_fp16:
        _seen += 1
        if len(FEATURE_MEM) < FEATURE_MEM_CAP:
            FEATURE_MEM.append(r)
        else:
            j = np.random.randint(0, _seen)
            if j < FEATURE_MEM_CAP:
                FEATURE_MEM[j] = r

                
def collect_cut_feats_from_train(fx_client: torch.Tensor):
    """Collect a small subset of cut features from TRAIN forward passes only."""
    with torch.no_grad():
        feats = fx_client.detach().view(fx_client.shape[0], -1)  # [B, D]
        k = min(24, feats.shape[0])
        idx = torch.randperm(feats.shape[0], device=feats.device)[:k]
        add_to_reservoir(feats[idx].cpu().to(torch.float16))


#=====================================================================================================
#         Subspace builder (simple PCA/SVD on buffered features)
#=====================================================================================================
def build_U_old_from_memory(top_r=TOP_R, device='cpu'):
    """Build principal subspace from the reservoir via PCA (pca_lowrank)."""
    if len(FEATURE_MEM) == 0:
        return None
    X = torch.stack(FEATURE_MEM).to(torch.float32)     # [N, D]
    X = X - X.mean(dim=0, keepdim=True)
    U, S, V = torch.pca_lowrank(X.cpu(), q=min(top_r, X.shape[1]), center=False)
    return V[:, :top_r].to(device, dtype=torch.float32)

def clear_feature_mem():
    global FEATURE_MEM, _seen
    FEATURE_MEM.clear()
    _seen = 0



#=====================================================================================================
#                           Baseblock
#=====================================================================================================
class Baseblock(nn.Module):
    expansion = 1
    def __init__(self, input_planes, planes, stride = 1, dim_change = None):
        # super(Baseblock, self).__init__()
        super().__init__()
        self.conv1 = nn.Conv2d(input_planes, planes, stride =  stride, kernel_size = 3, padding = 1)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, stride = 1, kernel_size = 3, padding = 1)
        self.bn2 = nn.BatchNorm2d(planes)
        self.dim_change = dim_change
        
        
    def forward(self, x):
        res = x
        output = F.relu(self.bn1(self.conv1(x)))
        output = self.bn2(self.conv2(output))
        
        if self.dim_change is not None:
            res =self.dim_change(res)
            
        output += res
        output = F.relu(output)
        
        return output
        
    
#=====================================================================================================
#                           Client-side Model definition
#=====================================================================================================
# Model at client side
class ResNet18_client_side(nn.Module):
    def __init__(self, block, num_layers):
        super().__init__()
        self.layer1 = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False),  # 3x3 s=1
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            # no maxpool for 32x32
        )
        self.layer2 = nn.Sequential(
            nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(64),
        )

        # add layer 3-6 + avg-pool (copied from Client)
        self.layer3 = nn.Sequential (
                nn.Conv2d(64, 64, kernel_size = 3, stride = 1, padding = 1),
                nn.BatchNorm2d(64),
                nn.ReLU (inplace = True),
                nn.Conv2d(64, 64, kernel_size = 3, stride = 1, padding = 1),
                nn.BatchNorm2d(64),       
                )   


        # self.input_planes is only used inside _layer()
        self.input_planes = 64

        self.layer4 = self._layer(block, 128, num_layers[0], stride = 2)
        self.layer5 = self._layer(block, 256, num_layers[1], stride = 2)
        self.layer6 = self._layer(block, 512, num_layers[2], stride = 2)
        
        
        # self. averagePool = nn.AvgPool2d(kernel_size = 7, stride = 1)
        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))
        

        # Weights into loop (the same thing as SERVER)
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                m.weight.data.normal_(0, math.sqrt(2. / n))
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()
        

    # a helper function to build deeper ResNet blocks (layer4–6) using Baseblock
    def _layer(self, block, planes, num_layers, stride = 2):
        dim_change = None
        if stride != 1 or planes != self.input_planes * block.expansion:
            dim_change = nn.Sequential(nn.Conv2d(self.input_planes, planes*block.expansion, kernel_size = 1, stride = stride),
                                       nn.BatchNorm2d(planes*block.expansion))
        netLayers = []
        netLayers.append(block(self.input_planes, planes, stride = stride, dim_change = dim_change))
        self.input_planes = planes * block.expansion
        for i in range(1, num_layers):
            netLayers.append(block(self.input_planes, planes))
            self.input_planes = planes * block.expansion
            
        return nn.Sequential(*netLayers)

        
    def forward(self, x):
        resudial1 = F.relu(self.layer1(x))
        out1 = self.layer2(resudial1)
        out1 = out1 + resudial1 # adding the resudial inputs -- downsampling not required in this layer
        x = F.relu(out1)

        out2 = self.layer3(x)
        out2 = out2 + x
        x = F.relu(out2)

        x = self.layer4(x)                    # channels = 128
        x = self.layer5(x)                    # channels = 256
        x = self.layer6(x)                    # Channels = 512
        x = self.avgpool(x)                   # shape [B, 512, H', W']

        # MID-Cut: Send x to server
        return x            # [B, 512, H', W']


net_glob_client = ResNet18_client_side(Baseblock, [2, 2, 2])
if torch.cuda.device_count() > 1:
    print("We use",torch.cuda.device_count(), "GPUs")
    net_glob_client = nn.DataParallel(net_glob_client)   # to use the multiple GPUs; later we can change this to CPUs only 

net_glob_client.to(device)
print(net_glob_client)    


#=====================================================================================================
#                           Server-side Model definition
#=====================================================================================================
# Model at client side
# Server-side (Late cut): only classifier head
class ResNet18_server_side(nn.Module):
    def __init__(self, classes):
        super().__init__()
        self.fc = nn.Linear(512, classes)

        # Optional: init fc like common practice
        nn.init.normal_(self.fc.weight, mean=0.0, std=0.01)
        nn.init.zeros_(self.fc.bias)

    def forward(self, x):
        x = x.view(x.size(0), -1)  # [B, 512]
        return self.fc(x)

    
# === INSTANTIATE MODELS ===
if DATASET_NAME == "CIFAR10":
    net_glob_server = ResNet18_server_side(10)
else:
    net_glob_server = ResNet18_server_side(100)

    

if torch.cuda.device_count() > 1:
    print("We use",torch.cuda.device_count(), "GPUs")
    net_glob_server = nn.DataParallel(net_glob_server)   # to use the multiple GPUs 


net_glob_server.to(device)
print(net_glob_server)  


#===================================================================================
# For Server Side Loss and Accuracy 
loss_train_collect = []
acc_train_collect = []
loss_test_collect = []
acc_test_collect = []
batch_acc_train = []
batch_loss_train = []
batch_acc_test = []
batch_loss_test = []
round_time_collect = [] # Stores seconds per global round

criterion = nn.CrossEntropyLoss(label_smoothing=LABEL_SMOOTH)


# Persistent server optimizer & scheduler (like SL)
optimizer_server = torch.optim.SGD(net_glob_server.parameters(), lr=LR_BASE, momentum=MOMENTUM, weight_decay=WEIGHT_DECAY)
server_sched = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer_server, T_max=EPOCHS, eta_min=5e-4)


#====================================================================================================
#                                  Server Side Programs
#====================================================================================================
def calculate_accuracy(fx, y):
    preds = fx.max(1, keepdim=True)[1]
    correct = preds.eq(y.view_as(preds)).sum()
    acc = 100.00 *correct.float()/preds.shape[0]
    return acc

# to print train - test together in each round-- these are made global
acc_avg_all_user_train = 0
loss_avg_all_user_train = 0
loss_train_collect_user = []
acc_train_collect_user = []
loss_test_collect_user = []
acc_test_collect_user = []


#client idx collector
idx_collect = []
l_epoch_check = False
fed_check = False

count1 = 0
count2 = 0


# Server-side function associated with Training 
def train_server(fx_client, y, l_epoch_count, l_epoch, idx, len_batch):
    global net_glob_server, criterion, device
    global batch_acc_train, batch_loss_train, l_epoch_check, fed_check
    global loss_train_collect, acc_train_collect, count1
    global acc_avg_all_user_train, loss_avg_all_user_train, idx_collect
    global loss_train_collect_user, acc_train_collect_user
    global U_old, ell_global, optimizer_server  

    net_glob_server.train()
    # train and update
    optimizer_server.zero_grad()
    
    fx_client = fx_client.to(device).detach().requires_grad_(True)
    y = y.to(device)

    fx_server = net_glob_server(fx_client)
    loss = criterion(fx_server, y)
    acc = calculate_accuracy(fx_server, y)

    loss.backward()

    dfx_client = fx_client.grad.detach()

    if ORTH and (U_old is not None):
        alpha = proj_gate_strength(ell_global)
        dfx_client = project_off_subspace_gated(dfx_client, U_old.to(dfx_client.dtype), alpha, preserve_norm=True)
    # -----------------------------------------------------------
    
    
    optimizer_server.step()
    
    batch_loss_train.append(loss.item())
    batch_acc_train.append(acc.item())
    
    # server-side model net_glob_server is global so it is updated automatically in each pass to this function
    
    # count1: to track the completion of the local batch associated with one client
    count1 += 1
    if count1 == len_batch:
        acc_avg_train = sum(batch_acc_train)/len(batch_acc_train)           # it has accuracy for one batch
        loss_avg_train = sum(batch_loss_train)/len(batch_loss_train)
        
        batch_acc_train = []
        batch_loss_train = []
        count1 = 0
        
        prRed('Client{} Train => Local Epoch: {} \tAcc: {:.3f} \tLoss: {:.4f}'.format(idx, l_epoch_count, acc_avg_train, loss_avg_train))
        
                
        # If one local epoch is completed, after this a new client will come
        if l_epoch_count == l_epoch-1:
            
            l_epoch_check = True                # to evaluate_server function - to check local epoch has completed or not
                       
            # we store the last accuracy in the last batch of the epoch and it is not the average of all local epochs
            # this is because we work on the last trained model and its accuracy (not earlier cases)
            
            #print("accuracy = ", acc_avg_train)
            acc_avg_train_all = acc_avg_train
            loss_avg_train_all = loss_avg_train
                        
            # accumulate accuracy and loss for each new user
            loss_train_collect_user.append(loss_avg_train_all)
            acc_train_collect_user.append(acc_avg_train_all)
            
            # collect the id of each new user                        
            if idx not in idx_collect:
                idx_collect.append(idx) 
                #print(idx_collect)
        
        # This is to check if all users are served for one round --------------------
        if len(idx_collect) == NUM_CLIENTS:
            fed_check = True                                                  # to evaluate_server function  - to check fed check has hitted
            # all users served for one round ------------------------- output print and update is done in evaluate_server()
            # for nicer display 
                        
            idx_collect = []
            
            acc_avg_all_user_train = sum(acc_train_collect_user)/len(acc_train_collect_user)
            loss_avg_all_user_train = sum(loss_train_collect_user)/len(loss_train_collect_user)
            
            loss_train_collect.append(loss_avg_all_user_train)
            acc_train_collect.append(acc_avg_all_user_train)
            
            acc_train_collect_user = []
            loss_train_collect_user = []
            
    # send gradients to the client               
    return dfx_client

# Server-side functions associated with Testing
def evaluate_server(fx_client, y, idx, len_batch, ell):
    global net_glob_server, criterion, batch_acc_test, batch_loss_test
    global loss_test_collect, acc_test_collect, count2, NUM_CLIENTS, acc_avg_train_all, loss_avg_train_all, l_epoch_check, fed_check
    global loss_test_collect_user, acc_test_collect_user, acc_avg_all_user_train, loss_avg_all_user_train
    
    net_glob_server.eval()
  
    with torch.no_grad():
        fx_client = fx_client.to(device)
        y = y.to(device) 
        #---------forward prop-------------
        fx_server = net_glob_server(fx_client)
        
        # calculate loss
        loss = criterion(fx_server, y)
        # calculate accuracy
        acc = calculate_accuracy(fx_server, y)
        
        
        batch_loss_test.append(loss.item())
        batch_acc_test.append(acc.item())
        
               
        count2 += 1
        if count2 == len_batch:
            acc_avg_test = sum(batch_acc_test)/len(batch_acc_test)
            loss_avg_test = sum(batch_loss_test)/len(batch_loss_test)
            
            batch_acc_test = []
            batch_loss_test = []
            count2 = 0
            
            prGreen('Client{} Test =>                   \tAcc: {:.3f} \tLoss: {:.4f}'.format(idx, acc_avg_test, loss_avg_test))
            
            # if a local epoch is completed   
            if l_epoch_check:
                l_epoch_check = False
                
                # Store the last accuracy and loss
                acc_avg_test_all = acc_avg_test
                loss_avg_test_all = loss_avg_test
                        
                loss_test_collect_user.append(loss_avg_test_all)
                acc_test_collect_user.append(acc_avg_test_all)
                
            # if all users are served for one round ----------                    
            if fed_check:
                fed_check = False
                                
                acc_avg_all_user = sum(acc_test_collect_user)/len(acc_test_collect_user)
                loss_avg_all_user = sum(loss_test_collect_user)/len(loss_test_collect_user)
            
                loss_test_collect.append(loss_avg_all_user)
                acc_test_collect.append(acc_avg_all_user)
                acc_test_collect_user = []
                loss_test_collect_user= []
                              
                print("====================== SERVER V1==========================")
                print(' Train: Round {:3d}, Avg Accuracy {:.3f} | Avg Loss {:.3f}'.format(ell, acc_avg_all_user_train, loss_avg_all_user_train))
                print(' Test: Round {:3d}, Avg Accuracy {:.3f} | Avg Loss {:.3f}'.format(ell, acc_avg_all_user, loss_avg_all_user))
                # print("==========================================================")
                
                
            # Rebuild U on cadence (no feature collection here)
            if ORTH and (ell % rebuild_every == 0) and (ell >= WARMUP_ROUNDS) and (len(FEATURE_MEM) >= 512):
                global U_old
                U_old = build_U_old_from_memory(top_r=TOP_R, device=device)
                clear_feature_mem()
         
    return 


# ----------------------------- FedAvg (client) -------------------------------
def FedAvg(w_list):
    w_avg = copy.deepcopy(w_list[0])
    for k in w_avg.keys():
        for i in range(1, len(w_list)):
            w_avg[k] += w_list[i][k]
        w_avg[k] = torch.div(w_avg[k], len(w_list))
    return w_avg

#=============================================================================
#                         Data loading 
#============================================================================= 
from torchvision import datasets, transforms

# CIFAR-10 & CIFAR-100 transforms
cifar_mean = {
    "CIFAR10":  [0.4914, 0.4822, 0.4465],
    "CIFAR100": [0.5071, 0.4867, 0.4408],
}[DATASET_NAME]
cifar_std = {
    "CIFAR10":  [0.2470, 0.2435, 0.2616],
    "CIFAR100": [0.2675, 0.2565, 0.2761],
}[DATASET_NAME]

# Try RandAugment if available
try:
    from torchvision.transforms import RandAugment
    ra = [RandAugment(num_ops=2, magnitude=9)]
except Exception:
    ra = []

train_transforms = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(32, padding=4),
] + ra + [
    transforms.ToTensor(),
    transforms.Normalize(cifar_mean, cifar_std),
])

test_transforms = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(cifar_mean, cifar_std),
])

if DATASET_NAME == "CIFAR10":
    dataset_train = datasets.CIFAR10(root=DATA_ROOT, train=True,  download=True, transform=train_transforms)
    dataset_test  = datasets.CIFAR10(root=DATA_ROOT, train=False, download=True, transform=test_transforms)
else:
    dataset_train = datasets.CIFAR100(root=DATA_ROOT, train=True,  download=True, transform=train_transforms)
    dataset_test  = datasets.CIFAR100(root=DATA_ROOT, train=False, download=True, transform=test_transforms)

print("Train samples:", len(dataset_train), " Test samples:", len(dataset_test))
print("Example train label:", dataset_train.targets[0])

# ----------------------------- Partitions -----------------------------------
class DatasetSplit(Dataset):
    def __init__(self, dataset, idxs):
        self.dataset = dataset; self.idxs = list(idxs)
    def __len__(self): return len(self.idxs)
    def __getitem__(self, item): return self.dataset[self.idxs[item]]

def dataset_iid(dataset, NUM_CLIENTS):
    num_items = int(len(dataset)/NUM_CLIENTS)
    dict_users, all_idxs = {}, [i for i in range(len(dataset))]
    for i in range(NUM_CLIENTS):
        dict_users[i] = set(np.random.choice(all_idxs, num_items, replace=False))
        all_idxs = list(set(all_idxs) - dict_users[i])
    return dict_users

def dataset_noniid_dirichlet(dataset, NUM_CLIENTS, alpha=ALPHA, seed=SEED):
    rng = np.random.default_rng(seed)
    labels = np.array(dataset.targets)
    n_classes = len(np.unique(labels))
    dict_users = {i: set() for i in range(NUM_CLIENTS)}
    for c in range(n_classes):
        idxs = np.where(labels == c)[0]
        rng.shuffle(idxs)
        p = rng.dirichlet([alpha]*NUM_CLIENTS)
        cuts = (np.cumsum(p)*len(idxs)).astype(int)[:-1]
        splits = np.split(idxs, cuts)
        for client_id, split in enumerate(splits):
            dict_users[client_id].update(split.tolist())
    return dict_users

dict_users      = dataset_noniid_dirichlet(dataset_train, NUM_CLIENTS, alpha=ALPHA, seed=SEED)
dict_users_test = dataset_iid(dataset_test, NUM_CLIENTS)


#=============================================================================
#                         Forgetting metric setup 
#============================================================================= 

from collections import defaultdict

# Treat each global round as a window (quick baseline).
# If you want true distribution shifts, predefine your own windows and fill `val_loaders`.
T = EPOCHS

val_loaders = {}
# Deterministic, disjoint slices of the test set: window t gets items t, t+T, t+2T, ...
rng_idx = np.arange(len(dataset_test))
for t in range(T):
    idxs = rng_idx[t::T]
    val_loaders[t] = DataLoader(
        DatasetSplit(
            dataset_test, 
            idxs), 
        batch_size=BATCH_SIZE, 
        shuffle=False, 
        drop_last=False,
        num_workers=NUM_WORKERS,
        pin_memory=pin
    )

best_loss_per_window = defaultdict(lambda: float('inf'))  # stores min historical loss per window
forgetting_log = []  # per round dicts: {"round": t, "mean_forgetting": x, "per_window": {...}}
# ============================================================================

def _eval_loss_on_loader(model_client, model_server, loader, device, criterion):
    """Evaluate mean loss on a loader using split models."""
    # Handle DataParallel transparently
    mc = model_client.module if isinstance(model_client, nn.DataParallel) else model_client
    ms = model_server.module if isinstance(model_server, nn.DataParallel) else model_server
    mc.eval(); ms.eval()
    loss_sum, n = 0.0, 0
    with torch.no_grad():
        for images, labels in loader:
            images, labels = images.to(device), labels.to(device)
            fx = mc(images)
            logits = ms(fx)
            loss = criterion(logits, labels)
            bs = labels.size(0)
            loss_sum += loss.item() * bs
            n += bs
    return loss_sum / max(1, n)


# ------------------------------- Client --------------------------------------
def freeze_client_bn(net):
    for m in net.modules():
        if isinstance(m, nn.BatchNorm2d):
            m.eval()

class Client(object):
    def __init__(self, net_client_model, idx, lr, device,
                 dataset_train=None, dataset_test=None, idxs=None, idxs_test=None):
        self.idx = idx
        self.device = device
        self.lr = LR_BASE
        self.local_ep = LOCAL_EPOCHS
        self.ldr_train = DataLoader(
            DatasetSplit(
                dataset_train, 
                idxs), 
            batch_size=BATCH_SIZE, 
            shuffle=True, 
            drop_last=False,
            num_workers=NUM_WORKERS,
            pin_memory=pin
        )
        self.ldr_test  = DataLoader(
            DatasetSplit(
                dataset_test,  
                idxs_test), 
            batch_size=BATCH_SIZE, 
            shuffle=False, 
            drop_last=False,
            num_workers=NUM_WORKERS,
            pin_memory=pin
        )

    def train(self, net):
        net.train()
        optimizer_client = torch.optim.SGD(net.parameters(), lr=self.lr, momentum=MOMENTUM, weight_decay=WEIGHT_DECAY)
        for ep in range(self.local_ep):
            len_batch = len(self.ldr_train)
            for batch_idx, (images, labels) in enumerate(self.ldr_train):
                images, labels = images.to(self.device), labels.to(self.device)
                optimizer_client.zero_grad()
                fx = net(images)
                # collect train-side cut features into reservoir
                if ORTH:
                    collect_cut_feats_from_train(fx)
                client_fx = fx.clone().detach().requires_grad_(True)
                dfx = train_server(client_fx, labels, ep, self.local_ep, self.idx, len_batch)
                fx.backward(dfx)
                optimizer_client.step()
        return net.state_dict()

    def evaluate(self, net, ell):
        net.eval()
        with torch.no_grad():
            len_batch = len(self.ldr_test)
            for batch_idx, (images, labels) in enumerate(self.ldr_test):
                images, labels = images.to(self.device), labels.to(self.device)
                fx = net(images)
                evaluate_server(fx, labels, self.idx, len_batch, ell)
        return

# ------------------------------- Training ------------------------------------
net_glob_client.train()
w_glob_client = net_glob_client.state_dict()  # initial global client weights

acc_train_collect.clear(); loss_train_collect.clear()
acc_test_collect.clear();  loss_test_collect.clear()
round_time_collect.clear()

for iter in range(EPOCHS):
    ell_global = iter

    # Freeze BN (not timed)
    if iter == WARMUP_ROUNDS:
        if isinstance(net_glob_client, nn.DataParallel):
            freeze_client_bn(net_glob_client.module)
        else:
            freeze_client_bn(net_glob_client)

    # ---- START TIMER (training+testing+FedAvg only) ----
    _sync_cuda()
    t_start = time.perf_counter()
    # ----------------------------------------------------

    m = max(int(FRAC * NUM_CLIENTS), 1)
    idxs_users = np.random.choice(range(NUM_CLIENTS), m, replace=False)

    w_locals_client = []
    for idx in idxs_users:
        local = Client(net_glob_client, idx, LR_BASE, device,
                       dataset_train=dataset_train, dataset_test=dataset_test,
                       idxs=dict_users[idx], idxs_test=dict_users_test[idx])
        
        local_model = copy.deepcopy(net_glob_client).to(device)
        w_client = local.train(net=local_model)
        w_locals_client.append(copy.deepcopy(w_client))
        local.evaluate(net=local_model, ell=iter)

        

    # FedAvg
    w_glob_client = FedAvg(w_locals_client)
    net_glob_client.load_state_dict(w_glob_client)

    # ---- STOP TIMER & LOG ----
    _sync_cuda()
    dt = time.perf_counter() - t_start
    round_time_collect.append(dt)
    # --------------------------

    # === Forgetting metric update at end of round (not counted in time) ===
    t = iter
    L_cur_t = _eval_loss_on_loader(net_glob_client, net_glob_server, val_loaders[t], device, criterion)
    best_loss_per_window[t] = min(best_loss_per_window[t], L_cur_t)

    per_win_fgt = {}
    for t_prev in range(t):
        L_now = _eval_loss_on_loader(net_glob_client, net_glob_server, val_loaders[t_prev], device, criterion)
        Fgt = L_now - best_loss_per_window[t_prev]
        per_win_fgt[t_prev] = Fgt

    mean_fgt = float(np.mean(list(per_win_fgt.values()))) if per_win_fgt else 0.0
    forgetting_log.append({"round": t, "mean_forgetting": mean_fgt, "per_window": per_win_fgt})
    print(f"Forgetting : Round {t}, mean_forgetting : {mean_fgt:.3f}")
    print("==========================================================")


    # LR schedule (also outside timing)
    server_sched.step()

print("Training and Evaluation completed!")

# ----------------------------- Save outputs ----------------------------------
n = min(len(acc_train_collect), len(acc_test_collect), len(round_time_collect), len(forgetting_log))
if n == 0:
    # Safeguard: if per-round aggregates weren’t populated (e.g., single-user path),
    # still produce a minimal log so the files exist.
    n = len(round_time_collect)
round_process = list(range(1, n+1))
mean_fgt_series = [d["mean_forgetting"] for d in forgetting_log[:n]] if forgetting_log else [0.0]*n

df = DataFrame({
    'round': round_process,
    'acc_train': acc_train_collect[:n],
    'acc_test':  acc_test_collect[:n],
    'round_time_sec': round_time_collect[:n],
    'mean_FgT_loss': mean_fgt_series,
})

file_name_csv  = program + ".csv"
df.to_csv(file_name_csv, index=False)
print("Saved:", file_name_csv)

#=============================================================================
#                         Program Completed
#=============================================================================
# Out:
# NVIDIA H200
# ---------SFLV2 + Projected - CIFAR-100 α=0.1 - Mid Cut----------
#  	Data:		CIFAR100
# 	Cut:		Mid-cut at Layer 5
# 	Global Rounds:	100
# 	Clients:	10
# 	Local Epochs:	5
# 	α:		0.1
# 	Warm-up:	5
# 	Rebuild:	3
# ResNet18_client_side(
#   (layer1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (layer2): Sequential(
#     (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (layer3): Sequential(
#     (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (layer4): Sequential(
#     (0): Baseblock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dim_change): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2))
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Baseblock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer5): Sequential(
#     (0): Baseblock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dim_change): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2))
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Baseblock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
# )
# ResNet18_server_side(
#   (fc): Linear(in_features=512, out_features=100, bias=True)
#   (layer6): Sequential(
#     (0): Baseblock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dim_change): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2))
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Baseblock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
# )
# Train samples: 50000  Test samples: 10000
# Example train label: 19
#  Client3 Train => Local Epoch: 0 	Acc: 8.958 	Loss: 3.7889
#  Client3 Train => Local Epoch: 1 	Acc: 14.922 	Loss: 3.4234
#  Client3 Train => Local Epoch: 2 	Acc: 17.578 	Loss: 3.2878
#  Client3 Train => Local Epoch: 3 	Acc: 21.745 	Loss: 3.1572
#  Client3 Train => Local Epoch: 4 	Acc: 21.328 	Loss: 2.9769
#  Client3 Test =>                   	Acc: 0.909 	Loss: 5.9392
#  Client1 Train => Local Epoch: 0 	Acc: 10.715 	Loss: 4.5814
#  Client1 Train => Local Epoch: 1 	Acc: 18.559 	Loss: 3.2001
#  Client1 Train => Local Epoch: 2 	Acc: 23.248 	Loss: 3.0165
#  Client1 Train => Local Epoch: 3 	Acc: 25.571 	Loss: 2.9312
#  Client1 Train => Local Epoch: 4 	Acc: 27.412 	Loss: 2.8478
#  Client1 Test =>                   	Acc: 1.192 	Loss: 6.3753
#  Client2 Train => Local Epoch: 0 	Acc: 16.143 	Loss: 4.0457
#  Client2 Train => Local Epoch: 1 	Acc: 24.486 	Loss: 2.9431
#  Client2 Train => Local Epoch: 2 	Acc: 30.592 	Loss: 2.7235
#  Client2 Train => Local Epoch: 3 	Acc: 33.422 	Loss: 2.6215
#  Client2 Train => Local Epoch: 4 	Acc: 37.081 	Loss: 2.5263
#  Client2 Test =>                   	Acc: 0.616 	Loss: 5.8440
#  Client0 Train => Local Epoch: 0 	Acc: 11.625 	Loss: 4.3528
#  Client0 Train => Local Epoch: 1 	Acc: 21.138 	Loss: 3.0853
#  Client0 Train => Local Epoch: 2 	Acc: 24.979 	Loss: 2.8879
#  Client0 Train => Local Epoch: 3 	Acc: 28.719 	Loss: 2.7776
#  Client0 Train => Local Epoch: 4 	Acc: 31.726 	Loss: 2.6768
#  Client0 Test =>                   	Acc: 0.997 	Loss: 6.0930
#  Client8 Train => Local Epoch: 0 	Acc: 10.974 	Loss: 4.4374
#  Client8 Train => Local Epoch: 1 	Acc: 16.606 	Loss: 3.1141
#  Client8 Train => Local Epoch: 2 	Acc: 19.694 	Loss: 3.0173
#  Client8 Train => Local Epoch: 3 	Acc: 22.030 	Loss: 2.9292
#  Client8 Train => Local Epoch: 4 	Acc: 22.968 	Loss: 2.8897
#  Client8 Test =>                   	Acc: 1.084 	Loss: 5.9927
#  Client7 Train => Local Epoch: 0 	Acc: 10.133 	Loss: 4.9105
#  Client7 Train => Local Epoch: 1 	Acc: 19.239 	Loss: 3.2853
#  Client7 Train => Local Epoch: 2 	Acc: 22.063 	Loss: 3.0368
#  Client7 Train => Local Epoch: 3 	Acc: 24.803 	Loss: 2.9866
#  Client7 Train => Local Epoch: 4 	Acc: 26.064 	Loss: 2.9080
#  Client7 Test =>                   	Acc: 0.596 	Loss: 5.8072
#  Client6 Train => Local Epoch: 0 	Acc: 5.904 	Loss: 4.8265
#  Client6 Train => Local Epoch: 1 	Acc: 16.933 	Loss: 3.2524
#  Client6 Train => Local Epoch: 2 	Acc: 19.953 	Loss: 3.0500
#  Client6 Train => Local Epoch: 3 	Acc: 23.306 	Loss: 2.9538
#  Client6 Train => Local Epoch: 4 	Acc: 25.065 	Loss: 2.8987
#  Client6 Test =>                   	Acc: 0.498 	Loss: 5.7058
#  Client9 Train => Local Epoch: 0 	Acc: 7.847 	Loss: 4.6361
#  Client9 Train => Local Epoch: 1 	Acc: 21.110 	Loss: 3.1534
#  Client9 Train => Local Epoch: 2 	Acc: 24.164 	Loss: 2.9412
#  Client9 Train => Local Epoch: 3 	Acc: 26.545 	Loss: 2.8492
#  Client9 Train => Local Epoch: 4 	Acc: 27.450 	Loss: 2.7877
#  Client9 Test =>                   	Acc: 0.997 	Loss: 5.6913
#  Client5 Train => Local Epoch: 0 	Acc: 5.174 	Loss: 5.1241
#  Client5 Train => Local Epoch: 1 	Acc: 16.680 	Loss: 3.3222
#  Client5 Train => Local Epoch: 2 	Acc: 23.120 	Loss: 3.0165
#  Client5 Train => Local Epoch: 3 	Acc: 24.111 	Loss: 2.8861
#  Client5 Train => Local Epoch: 4 	Acc: 26.400 	Loss: 2.7907
#  Client5 Test =>                   	Acc: 0.997 	Loss: 5.8055
#  Client4 Train => Local Epoch: 0 	Acc: 6.531 	Loss: 4.8924
#  Client4 Train => Local Epoch: 1 	Acc: 19.088 	Loss: 3.4233
#  Client4 Train => Local Epoch: 2 	Acc: 23.846 	Loss: 3.1021
#  Client4 Train => Local Epoch: 3 	Acc: 26.532 	Loss: 2.9627
#  Client4 Train => Local Epoch: 4 	Acc: 27.013 	Loss: 2.9048
#  Client4 Test =>                   	Acc: 1.212 	Loss: 5.4878
# ====================== SERVER V1==========================
#  Train: Round   0, Avg Accuracy 27.251 | Avg Loss 2.821
#  Test: Round   0, Avg Accuracy 0.910 | Avg Loss 5.874
# Forgetting : Round 0, mean_forgetting : 0.000
# ==========================================================
#  Client9 Train => Local Epoch: 0 	Acc: 10.664 	Loss: 4.1658
#  Client9 Train => Local Epoch: 1 	Acc: 25.264 	Loss: 3.0349
#  Client9 Train => Local Epoch: 2 	Acc: 27.811 	Loss: 2.8312
#  Client9 Train => Local Epoch: 3 	Acc: 29.035 	Loss: 2.7616
#  Client9 Train => Local Epoch: 4 	Acc: 31.000 	Loss: 2.6951
#  Client9 Test =>                   	Acc: 2.209 	Loss: 6.3004
#  Client7 Train => Local Epoch: 0 	Acc: 3.307 	Loss: 4.9125
#  Client7 Train => Local Epoch: 1 	Acc: 14.982 	Loss: 3.7273
#  Client7 Train => Local Epoch: 2 	Acc: 24.914 	Loss: 3.0755
#  Client7 Train => Local Epoch: 3 	Acc: 26.010 	Loss: 2.9335
#  Client7 Train => Local Epoch: 4 	Acc: 26.995 	Loss: 2.8596
#  Client7 Test =>                   	Acc: 1.017 	Loss: 6.2824
#  Client4 Train => Local Epoch: 0 	Acc: 8.562 	Loss: 4.2481
#  Client4 Train => Local Epoch: 1 	Acc: 25.479 	Loss: 3.2135
#  Client4 Train => Local Epoch: 2 	Acc: 27.873 	Loss: 2.9400
#  Client4 Train => Local Epoch: 3 	Acc: 28.876 	Loss: 2.8452
#  Client4 Train => Local Epoch: 4 	Acc: 29.917 	Loss: 2.7983
#  Client4 Test =>                   	Acc: 2.913 	Loss: 6.1914
#  Client3 Train => Local Epoch: 0 	Acc: 7.266 	Loss: 4.4207
#  Client3 Train => Local Epoch: 1 	Acc: 21.797 	Loss: 3.4830
#  Client3 Train => Local Epoch: 2 	Acc: 25.755 	Loss: 3.1649
#  Client3 Train => Local Epoch: 3 	Acc: 28.021 	Loss: 2.9769
#  Client3 Train => Local Epoch: 4 	Acc: 29.583 	Loss: 2.8433
#  Client3 Test =>                   	Acc: 2.081 	Loss: 6.0304
#  Client2 Train => Local Epoch: 0 	Acc: 3.882 	Loss: 4.8377
#  Client2 Train => Local Epoch: 1 	Acc: 21.229 	Loss: 3.9083
#  Client2 Train => Local Epoch: 2 	Acc: 30.293 	Loss: 3.1249
#  Client2 Train => Local Epoch: 3 	Acc: 35.312 	Loss: 2.7796
#  Client2 Train => Local Epoch: 4 	Acc: 36.878 	Loss: 2.6314
#  Client2 Test =>                   	Acc: 1.886 	Loss: 5.7230
#  Client5 Train => Local Epoch: 0 	Acc: 1.027 	Loss: 4.8653
#  Client5 Train => Local Epoch: 1 	Acc: 10.491 	Loss: 3.9871
#  Client5 Train => Local Epoch: 2 	Acc: 21.869 	Loss: 3.2103
#  Client5 Train => Local Epoch: 3 	Acc: 25.607 	Loss: 2.9174
#  Client5 Train => Local Epoch: 4 	Acc: 27.042 	Loss: 2.7925
#  Client5 Test =>                   	Acc: 1.280 	Loss: 6.1212
#  Client8 Train => Local Epoch: 0 	Acc: 2.529 	Loss: 4.6791
#  Client8 Train => Local Epoch: 1 	Acc: 13.615 	Loss: 3.9083
#  Client8 Train => Local Epoch: 2 	Acc: 20.070 	Loss: 3.2192
#  Client8 Train => Local Epoch: 3 	Acc: 23.306 	Loss: 2.9222
#  Client8 Train => Local Epoch: 4 	Acc: 24.125 	Loss: 2.8494
#  Client8 Test =>                   	Acc: 1.613 	Loss: 6.1648
#  Client1 Train => Local Epoch: 0 	Acc: 1.421 	Loss: 4.9048
#  Client1 Train => Local Epoch: 1 	Acc: 11.456 	Loss: 4.0192
#  Client1 Train => Local Epoch: 2 	Acc: 22.845 	Loss: 3.3341
#  Client1 Train => Local Epoch: 3 	Acc: 26.806 	Loss: 2.9864
#  Client1 Train => Local Epoch: 4 	Acc: 29.139 	Loss: 2.8238
#  Client1 Test =>                   	Acc: 2.384 	Loss: 5.7967
#  Client6 Train => Local Epoch: 0 	Acc: 2.906 	Loss: 4.7477
#  Client6 Train => Local Epoch: 1 	Acc: 12.908 	Loss: 3.8775
#  Client6 Train => Local Epoch: 2 	Acc: 21.287 	Loss: 3.2269
#  Client6 Train => Local Epoch: 3 	Acc: 25.550 	Loss: 2.9325
#  Client6 Train => Local Epoch: 4 	Acc: 30.401 	Loss: 2.7909
#  Client6 Test =>                   	Acc: 2.414 	Loss: 5.9060
#  Client0 Train => Local Epoch: 0 	Acc: 6.553 	Loss: 4.5016
#  Client0 Train => Local Epoch: 1 	Acc: 22.093 	Loss: 3.4075
#  Client0 Train => Local Epoch: 2 	Acc: 28.300 	Loss: 2.8572
#  Client0 Train => Local Epoch: 3 	Acc: 32.610 	Loss: 2.6403
#  Client0 Train => Local Epoch: 4 	Acc: 34.989 	Loss: 2.5510
#  Client0 Test =>                   	Acc: 1.182 	Loss: 5.7581
# ====================== SERVER V1==========================
#  Train: Round   1, Avg Accuracy 30.007 | Avg Loss 2.764
#  Test: Round   1, Avg Accuracy 1.898 | Avg Loss 6.027
# Forgetting : Round 1, mean_forgetting : 0.225
# ==========================================================
#  Client5 Train => Local Epoch: 0 	Acc: 0.950 	Loss: 4.8688
#  Client5 Train => Local Epoch: 1 	Acc: 14.915 	Loss: 3.8672
#  Client5 Train => Local Epoch: 2 	Acc: 24.049 	Loss: 3.1546
#  Client5 Train => Local Epoch: 3 	Acc: 26.212 	Loss: 2.8324
#  Client5 Train => Local Epoch: 4 	Acc: 29.451 	Loss: 2.7134
#  Client5 Test =>                   	Acc: 2.061 	Loss: 5.6673
#  Client1 Train => Local Epoch: 0 	Acc: 3.777 	Loss: 4.5267
#  Client1 Train => Local Epoch: 1 	Acc: 22.014 	Loss: 3.4507
#  Client1 Train => Local Epoch: 2 	Acc: 28.005 	Loss: 2.9496
#  Client1 Train => Local Epoch: 3 	Acc: 31.145 	Loss: 2.7634
#  Client1 Train => Local Epoch: 4 	Acc: 33.374 	Loss: 2.6637
#  Client1 Test =>                   	Acc: 2.795 	Loss: 5.3257
#  Client6 Train => Local Epoch: 0 	Acc: 5.547 	Loss: 4.3602
#  Client6 Train => Local Epoch: 1 	Acc: 22.477 	Loss: 3.3196
#  Client6 Train => Local Epoch: 2 	Acc: 30.416 	Loss: 2.8535
#  Client6 Train => Local Epoch: 3 	Acc: 33.234 	Loss: 2.6903
#  Client6 Train => Local Epoch: 4 	Acc: 35.621 	Loss: 2.5956
#  Client6 Test =>                   	Acc: 3.098 	Loss: 5.8336
#  Client4 Train => Local Epoch: 0 	Acc: 6.526 	Loss: 4.6013
#  Client4 Train => Local Epoch: 1 	Acc: 19.285 	Loss: 3.7814
#  Client4 Train => Local Epoch: 2 	Acc: 26.586 	Loss: 3.1587
#  Client4 Train => Local Epoch: 3 	Acc: 29.322 	Loss: 2.9212
#  Client4 Train => Local Epoch: 4 	Acc: 31.670 	Loss: 2.7850
#  Client4 Test =>                   	Acc: 5.590 	Loss: 5.1835
#  Client9 Train => Local Epoch: 0 	Acc: 7.092 	Loss: 4.3527
#  Client9 Train => Local Epoch: 1 	Acc: 24.114 	Loss: 3.2364
#  Client9 Train => Local Epoch: 2 	Acc: 29.580 	Loss: 2.8219
#  Client9 Train => Local Epoch: 3 	Acc: 31.717 	Loss: 2.6890
#  Client9 Train => Local Epoch: 4 	Acc: 32.618 	Loss: 2.6532
#  Client9 Test =>                   	Acc: 4.027 	Loss: 5.5866
#  Client0 Train => Local Epoch: 0 	Acc: 9.908 	Loss: 4.1357
#  Client0 Train => Local Epoch: 1 	Acc: 30.249 	Loss: 2.9574
#  Client0 Train => Local Epoch: 2 	Acc: 34.494 	Loss: 2.6562
#  Client0 Train => Local Epoch: 3 	Acc: 36.918 	Loss: 2.5349
#  Client0 Train => Local Epoch: 4 	Acc: 37.596 	Loss: 2.4586
#  Client0 Test =>                   	Acc: 5.492 	Loss: 5.5160
#  Client3 Train => Local Epoch: 0 	Acc: 9.401 	Loss: 4.4504
#  Client3 Train => Local Epoch: 1 	Acc: 25.078 	Loss: 3.5916
#  Client3 Train => Local Epoch: 2 	Acc: 25.964 	Loss: 3.1949
#  Client3 Train => Local Epoch: 3 	Acc: 31.615 	Loss: 2.8787
#  Client3 Train => Local Epoch: 4 	Acc: 29.609 	Loss: 2.9723
#  Client3 Test =>                   	Acc: 3.566 	Loss: 5.2629
#  Client8 Train => Local Epoch: 0 	Acc: 3.445 	Loss: 4.6442
#  Client8 Train => Local Epoch: 1 	Acc: 12.607 	Loss: 3.8507
#  Client8 Train => Local Epoch: 2 	Acc: 23.317 	Loss: 3.1306
#  Client8 Train => Local Epoch: 3 	Acc: 26.104 	Loss: 2.8973
#  Client8 Train => Local Epoch: 4 	Acc: 27.506 	Loss: 2.7822
#  Client8 Test =>                   	Acc: 3.293 	Loss: 5.9384
#  Client2 Train => Local Epoch: 0 	Acc: 7.482 	Loss: 4.5450
#  Client2 Train => Local Epoch: 1 	Acc: 22.242 	Loss: 3.5154
#  Client2 Train => Local Epoch: 2 	Acc: 33.733 	Loss: 2.9244
#  Client2 Train => Local Epoch: 3 	Acc: 38.038 	Loss: 2.6234
#  Client2 Train => Local Epoch: 4 	Acc: 38.441 	Loss: 2.5248
#  Client2 Test =>                   	Acc: 4.007 	Loss: 5.4754
#  Client7 Train => Local Epoch: 0 	Acc: 1.655 	Loss: 4.7251
#  Client7 Train => Local Epoch: 1 	Acc: 13.713 	Loss: 3.8913
#  Client7 Train => Local Epoch: 2 	Acc: 25.074 	Loss: 3.2263
#  Client7 Train => Local Epoch: 3 	Acc: 26.007 	Loss: 2.9757
#  Client7 Train => Local Epoch: 4 	Acc: 27.860 	Loss: 2.8350
#  Client7 Test =>                   	Acc: 3.596 	Loss: 5.4372
# ====================== SERVER V1==========================
#  Train: Round   2, Avg Accuracy 32.375 | Avg Loss 2.698
#  Test: Round   2, Avg Accuracy 3.753 | Avg Loss 5.523
# Forgetting : Round 2, mean_forgetting : -0.512
# ==========================================================
#  Client0 Train => Local Epoch: 0 	Acc: 12.200 	Loss: 4.0087
#  Client0 Train => Local Epoch: 1 	Acc: 33.388 	Loss: 2.7569
#  Client0 Train => Local Epoch: 2 	Acc: 37.477 	Loss: 2.5435
#  Client0 Train => Local Epoch: 3 	Acc: 39.062 	Loss: 2.4423
#  Client0 Train => Local Epoch: 4 	Acc: 39.810 	Loss: 2.3911
#  Client0 Test =>                   	Acc: 6.402 	Loss: 5.5855
#  Client5 Train => Local Epoch: 0 	Acc: 0.319 	Loss: 4.8262
#  Client5 Train => Local Epoch: 1 	Acc: 15.383 	Loss: 3.8139
#  Client5 Train => Local Epoch: 2 	Acc: 26.717 	Loss: 3.1264
#  Client5 Train => Local Epoch: 3 	Acc: 29.618 	Loss: 2.8059
#  Client5 Train => Local Epoch: 4 	Acc: 30.367 	Loss: 2.6700
#  Client5 Test =>                   	Acc: 2.647 	Loss: 5.5949
#  Client4 Train => Local Epoch: 0 	Acc: 4.723 	Loss: 4.4493
#  Client4 Train => Local Epoch: 1 	Acc: 25.030 	Loss: 3.3798
#  Client4 Train => Local Epoch: 2 	Acc: 31.268 	Loss: 2.8981
#  Client4 Train => Local Epoch: 3 	Acc: 34.254 	Loss: 2.7040
#  Client4 Train => Local Epoch: 4 	Acc: 36.224 	Loss: 2.6187
#  Client4 Test =>                   	Acc: 7.085 	Loss: 5.4703
#  Client9 Train => Local Epoch: 0 	Acc: 12.305 	Loss: 4.0741
#  Client9 Train => Local Epoch: 1 	Acc: 28.100 	Loss: 3.0091
#  Client9 Train => Local Epoch: 2 	Acc: 31.687 	Loss: 2.7139
#  Client9 Train => Local Epoch: 3 	Acc: 33.400 	Loss: 2.6320
#  Client9 Train => Local Epoch: 4 	Acc: 34.966 	Loss: 2.5620
#  Client9 Test =>                   	Acc: 5.455 	Loss: 5.4414
#  Client7 Train => Local Epoch: 0 	Acc: 4.169 	Loss: 4.6243
#  Client7 Train => Local Epoch: 1 	Acc: 18.873 	Loss: 3.5181
#  Client7 Train => Local Epoch: 2 	Acc: 28.557 	Loss: 2.9308
#  Client7 Train => Local Epoch: 3 	Acc: 29.032 	Loss: 2.7742
#  Client7 Train => Local Epoch: 4 	Acc: 30.790 	Loss: 2.7158
#  Client7 Test =>                   	Acc: 3.792 	Loss: 5.4271
#  Client8 Train => Local Epoch: 0 	Acc: 6.205 	Loss: 4.4323
#  Client8 Train => Local Epoch: 1 	Acc: 20.341 	Loss: 3.4362
#  Client8 Train => Local Epoch: 2 	Acc: 26.997 	Loss: 2.8981
#  Client8 Train => Local Epoch: 3 	Acc: 29.196 	Loss: 2.7647
#  Client8 Train => Local Epoch: 4 	Acc: 30.508 	Loss: 2.6939
#  Client8 Test =>                   	Acc: 3.509 	Loss: 6.0164
#  Client2 Train => Local Epoch: 0 	Acc: 9.654 	Loss: 4.2592
#  Client2 Train => Local Epoch: 1 	Acc: 30.628 	Loss: 3.1578
#  Client2 Train => Local Epoch: 2 	Acc: 38.508 	Loss: 2.6418
#  Client2 Train => Local Epoch: 3 	Acc: 40.095 	Loss: 2.4845
#  Client2 Train => Local Epoch: 4 	Acc: 42.311 	Loss: 2.3785
#  Client2 Test =>                   	Acc: 4.408 	Loss: 5.5448
#  Client3 Train => Local Epoch: 0 	Acc: 4.896 	Loss: 4.6203
#  Client3 Train => Local Epoch: 1 	Acc: 24.297 	Loss: 3.5638
#  Client3 Train => Local Epoch: 2 	Acc: 30.052 	Loss: 3.0135
#  Client3 Train => Local Epoch: 3 	Acc: 30.625 	Loss: 2.8229
#  Client3 Train => Local Epoch: 4 	Acc: 35.833 	Loss: 2.6027
#  Client3 Test =>                   	Acc: 6.109 	Loss: 5.0355
#  Client1 Train => Local Epoch: 0 	Acc: 5.603 	Loss: 4.4021
#  Client1 Train => Local Epoch: 1 	Acc: 24.233 	Loss: 3.3557
#  Client1 Train => Local Epoch: 2 	Acc: 30.623 	Loss: 2.8760
#  Client1 Train => Local Epoch: 3 	Acc: 33.992 	Loss: 2.6933
#  Client1 Train => Local Epoch: 4 	Acc: 36.499 	Loss: 2.5912
#  Client1 Test =>                   	Acc: 3.684 	Loss: 5.2591
#  Client6 Train => Local Epoch: 0 	Acc: 6.822 	Loss: 4.3625
#  Client6 Train => Local Epoch: 1 	Acc: 27.216 	Loss: 3.1641
#  Client6 Train => Local Epoch: 2 	Acc: 34.994 	Loss: 2.7072
#  Client6 Train => Local Epoch: 3 	Acc: 37.323 	Loss: 2.5476
#  Client6 Train => Local Epoch: 4 	Acc: 39.026 	Loss: 2.4820
#  Client6 Test =>                   	Acc: 4.927 	Loss: 5.9076
# ====================== SERVER V1==========================
#  Train: Round   3, Avg Accuracy 35.634 | Avg Loss 2.571
#  Test: Round   3, Avg Accuracy 4.802 | Avg Loss 5.528
# Forgetting : Round 3, mean_forgetting : -0.275
# ==========================================================
#  Client5 Train => Local Epoch: 0 	Acc: 7.050 	Loss: 4.4112
#  Client5 Train => Local Epoch: 1 	Acc: 24.906 	Loss: 3.1845
#  Client5 Train => Local Epoch: 2 	Acc: 31.279 	Loss: 2.7337
#  Client5 Train => Local Epoch: 3 	Acc: 34.326 	Loss: 2.5542
#  Client5 Train => Local Epoch: 4 	Acc: 35.035 	Loss: 2.4808
#  Client5 Test =>                   	Acc: 3.341 	Loss: 5.3132
#  Client7 Train => Local Epoch: 0 	Acc: 4.848 	Loss: 4.5382
#  Client7 Train => Local Epoch: 1 	Acc: 24.540 	Loss: 3.3549
#  Client7 Train => Local Epoch: 2 	Acc: 28.904 	Loss: 2.8919
#  Client7 Train => Local Epoch: 3 	Acc: 33.280 	Loss: 2.6649
#  Client7 Train => Local Epoch: 4 	Acc: 33.855 	Loss: 2.6049
#  Client7 Test =>                   	Acc: 4.994 	Loss: 5.4597
#  Client1 Train => Local Epoch: 0 	Acc: 14.402 	Loss: 4.1181
#  Client1 Train => Local Epoch: 1 	Acc: 29.250 	Loss: 2.9744
#  Client1 Train => Local Epoch: 2 	Acc: 33.372 	Loss: 2.6777
#  Client1 Train => Local Epoch: 3 	Acc: 34.851 	Loss: 2.5781
#  Client1 Train => Local Epoch: 4 	Acc: 38.350 	Loss: 2.4979
#  Client1 Test =>                   	Acc: 5.698 	Loss: 5.0901
#  Client3 Train => Local Epoch: 0 	Acc: 11.302 	Loss: 4.2084
#  Client3 Train => Local Epoch: 1 	Acc: 23.802 	Loss: 3.3983
#  Client3 Train => Local Epoch: 2 	Acc: 30.495 	Loss: 2.8232
#  Client3 Train => Local Epoch: 3 	Acc: 30.182 	Loss: 2.7931
#  Client3 Train => Local Epoch: 4 	Acc: 32.500 	Loss: 2.6903
#  Client3 Test =>                   	Acc: 5.883 	Loss: 5.3146
#  Client0 Train => Local Epoch: 0 	Acc: 15.865 	Loss: 3.9202
#  Client0 Train => Local Epoch: 1 	Acc: 33.387 	Loss: 2.8215
#  Client0 Train => Local Epoch: 2 	Acc: 38.508 	Loss: 2.5099
#  Client0 Train => Local Epoch: 3 	Acc: 40.660 	Loss: 2.3943
#  Client0 Train => Local Epoch: 4 	Acc: 42.037 	Loss: 2.3289
#  Client0 Test =>                   	Acc: 7.516 	Loss: 5.3882
#  Client9 Train => Local Epoch: 0 	Acc: 12.655 	Loss: 4.1147
#  Client9 Train => Local Epoch: 1 	Acc: 29.283 	Loss: 2.9249
#  Client9 Train => Local Epoch: 2 	Acc: 33.835 	Loss: 2.6500
#  Client9 Train => Local Epoch: 3 	Acc: 36.563 	Loss: 2.5228
#  Client9 Train => Local Epoch: 4 	Acc: 37.858 	Loss: 2.4883
#  Client9 Test =>                   	Acc: 6.822 	Loss: 5.3239
#  Client2 Train => Local Epoch: 0 	Acc: 5.533 	Loss: 4.6202
#  Client2 Train => Local Epoch: 1 	Acc: 33.745 	Loss: 3.0791
#  Client2 Train => Local Epoch: 2 	Acc: 41.207 	Loss: 2.5188
#  Client2 Train => Local Epoch: 3 	Acc: 43.969 	Loss: 2.3479
#  Client2 Train => Local Epoch: 4 	Acc: 45.316 	Loss: 2.2466
#  Client2 Test =>                   	Acc: 5.307 	Loss: 5.4432
#  Client4 Train => Local Epoch: 0 	Acc: 6.516 	Loss: 4.3874
#  Client4 Train => Local Epoch: 1 	Acc: 25.809 	Loss: 3.2741
#  Client4 Train => Local Epoch: 2 	Acc: 35.019 	Loss: 2.7486
#  Client4 Train => Local Epoch: 3 	Acc: 36.214 	Loss: 2.5978
#  Client4 Train => Local Epoch: 4 	Acc: 38.677 	Loss: 2.5130
#  Client4 Test =>                   	Acc: 7.994 	Loss: 5.2150
#  Client8 Train => Local Epoch: 0 	Acc: 5.766 	Loss: 4.4188
#  Client8 Train => Local Epoch: 1 	Acc: 24.006 	Loss: 3.3019
#  Client8 Train => Local Epoch: 2 	Acc: 29.835 	Loss: 2.7601
#  Client8 Train => Local Epoch: 3 	Acc: 31.498 	Loss: 2.6851
#  Client8 Train => Local Epoch: 4 	Acc: 32.815 	Loss: 2.6081
#  Client8 Test =>                   	Acc: 5.004 	Loss: 5.6485
#  Client6 Train => Local Epoch: 0 	Acc: 14.195 	Loss: 4.0318
#  Client6 Train => Local Epoch: 1 	Acc: 35.407 	Loss: 2.7660
#  Client6 Train => Local Epoch: 2 	Acc: 39.873 	Loss: 2.4751
#  Client6 Train => Local Epoch: 3 	Acc: 42.284 	Loss: 2.3902
#  Client6 Train => Local Epoch: 4 	Acc: 43.058 	Loss: 2.3493
#  Client6 Test =>                   	Acc: 8.112 	Loss: 5.3340
# ====================== SERVER V1==========================
#  Train: Round   4, Avg Accuracy 37.950 | Avg Loss 2.481
#  Test: Round   4, Avg Accuracy 6.067 | Avg Loss 5.353
# Forgetting : Round 4, mean_forgetting : -0.433
# ==========================================================
#  Client0 Train => Local Epoch: 0 	Acc: 21.143 	Loss: 3.5623
#  Client0 Train => Local Epoch: 1 	Acc: 39.937 	Loss: 2.4690
#  Client0 Train => Local Epoch: 2 	Acc: 42.330 	Loss: 2.3238
#  Client0 Train => Local Epoch: 3 	Acc: 43.574 	Loss: 2.2555
#  Client0 Train => Local Epoch: 4 	Acc: 44.911 	Loss: 2.2187
#  Client0 Test =>                   	Acc: 9.432 	Loss: 4.8457
#  Client9 Train => Local Epoch: 0 	Acc: 18.883 	Loss: 3.7905
#  Client9 Train => Local Epoch: 1 	Acc: 34.098 	Loss: 2.6415
#  Client9 Train => Local Epoch: 2 	Acc: 37.626 	Loss: 2.4885
#  Client9 Train => Local Epoch: 3 	Acc: 40.115 	Loss: 2.4023
#  Client9 Train => Local Epoch: 4 	Acc: 40.893 	Loss: 2.3702
#  Client9 Test =>                   	Acc: 6.206 	Loss: 5.1665
#  Client4 Train => Local Epoch: 0 	Acc: 14.969 	Loss: 3.9492
#  Client4 Train => Local Epoch: 1 	Acc: 33.859 	Loss: 2.8092
#  Client4 Train => Local Epoch: 2 	Acc: 38.076 	Loss: 2.5292
#  Client4 Train => Local Epoch: 3 	Acc: 40.264 	Loss: 2.4412
#  Client4 Train => Local Epoch: 4 	Acc: 41.569 	Loss: 2.3823
#  Client4 Test =>                   	Acc: 8.718 	Loss: 5.0585
#  Client8 Train => Local Epoch: 0 	Acc: 12.004 	Loss: 4.0543
#  Client8 Train => Local Epoch: 1 	Acc: 30.043 	Loss: 2.8535
#  Client8 Train => Local Epoch: 2 	Acc: 31.554 	Loss: 2.6555
#  Client8 Train => Local Epoch: 3 	Acc: 34.165 	Loss: 2.5475
#  Client8 Train => Local Epoch: 4 	Acc: 36.267 	Loss: 2.4980
#  Client8 Test =>                   	Acc: 5.580 	Loss: 5.5702
#  Client2 Train => Local Epoch: 0 	Acc: 15.765 	Loss: 3.9973
#  Client2 Train => Local Epoch: 1 	Acc: 41.614 	Loss: 2.5965
#  Client2 Train => Local Epoch: 2 	Acc: 46.700 	Loss: 2.3008
#  Client2 Train => Local Epoch: 3 	Acc: 47.784 	Loss: 2.2043
#  Client2 Train => Local Epoch: 4 	Acc: 49.115 	Loss: 2.1263
#  Client2 Test =>                   	Acc: 5.395 	Loss: 5.5181
#  Client1 Train => Local Epoch: 0 	Acc: 18.595 	Loss: 3.6765
#  Client1 Train => Local Epoch: 1 	Acc: 34.792 	Loss: 2.7057
#  Client1 Train => Local Epoch: 2 	Acc: 38.880 	Loss: 2.5088
#  Client1 Train => Local Epoch: 3 	Acc: 41.690 	Loss: 2.3974
#  Client1 Train => Local Epoch: 4 	Acc: 43.299 	Loss: 2.3208
#  Client1 Test =>                   	Acc: 6.361 	Loss: 5.0162
#  Client6 Train => Local Epoch: 0 	Acc: 19.799 	Loss: 3.7071
#  Client6 Train => Local Epoch: 1 	Acc: 39.873 	Loss: 2.5144
#  Client6 Train => Local Epoch: 2 	Acc: 43.753 	Loss: 2.3472
#  Client6 Train => Local Epoch: 3 	Acc: 45.640 	Loss: 2.2755
#  Client6 Train => Local Epoch: 4 	Acc: 47.648 	Loss: 2.2046
#  Client6 Test =>                   	Acc: 9.304 	Loss: 5.2081
#  Client7 Train => Local Epoch: 0 	Acc: 8.782 	Loss: 4.3474
#  Client7 Train => Local Epoch: 1 	Acc: 27.119 	Loss: 3.1728
#  Client7 Train => Local Epoch: 2 	Acc: 32.911 	Loss: 2.7079
#  Client7 Train => Local Epoch: 3 	Acc: 36.524 	Loss: 2.5160
#  Client7 Train => Local Epoch: 4 	Acc: 36.757 	Loss: 2.4648
#  Client7 Test =>                   	Acc: 5.748 	Loss: 5.2627
#  Client5 Train => Local Epoch: 0 	Acc: 6.120 	Loss: 4.4291
#  Client5 Train => Local Epoch: 1 	Acc: 30.499 	Loss: 2.9793
#  Client5 Train => Local Epoch: 2 	Acc: 35.261 	Loss: 2.5194
#  Client5 Train => Local Epoch: 3 	Acc: 39.743 	Loss: 2.3800
#  Client5 Train => Local Epoch: 4 	Acc: 41.255 	Loss: 2.3079
#  Client5 Test =>                   	Acc: 4.543 	Loss: 5.7212
#  Client3 Train => Local Epoch: 0 	Acc: 16.510 	Loss: 3.9396
#  Client3 Train => Local Epoch: 1 	Acc: 32.578 	Loss: 2.9059
#  Client3 Train => Local Epoch: 2 	Acc: 36.589 	Loss: 2.5968
#  Client3 Train => Local Epoch: 3 	Acc: 31.536 	Loss: 2.7617
#  Client3 Train => Local Epoch: 4 	Acc: 32.292 	Loss: 2.7618
#  Client3 Test =>                   	Acc: 6.479 	Loss: 5.1399
# ====================== SERVER V1==========================
#  Train: Round   5, Avg Accuracy 41.401 | Avg Loss 2.366
#  Test: Round   5, Avg Accuracy 6.777 | Avg Loss 5.251
# Forgetting : Round 5, mean_forgetting : -0.775
# ==========================================================
#  Client0 Train => Local Epoch: 0 	Acc: 18.524 	Loss: 3.7151
#  Client0 Train => Local Epoch: 1 	Acc: 39.936 	Loss: 2.5381
#  Client0 Train => Local Epoch: 2 	Acc: 44.563 	Loss: 2.2766
#  Client0 Train => Local Epoch: 3 	Acc: 46.442 	Loss: 2.1861
#  Client0 Train => Local Epoch: 4 	Acc: 47.991 	Loss: 2.1539
#  Client0 Test =>                   	Acc: 8.358 	Loss: 5.2523
#  Client4 Train => Local Epoch: 0 	Acc: 17.113 	Loss: 3.8170
#  Client4 Train => Local Epoch: 1 	Acc: 36.962 	Loss: 2.6579
#  Client4 Train => Local Epoch: 2 	Acc: 42.049 	Loss: 2.4089
#  Client4 Train => Local Epoch: 3 	Acc: 43.297 	Loss: 2.3270
#  Client4 Train => Local Epoch: 4 	Acc: 44.990 	Loss: 2.2670
#  Client4 Test =>                   	Acc: 10.193 	Loss: 4.7522
#  Client2 Train => Local Epoch: 0 	Acc: 15.326 	Loss: 4.0499
#  Client2 Train => Local Epoch: 1 	Acc: 44.272 	Loss: 2.5691
#  Client2 Train => Local Epoch: 2 	Acc: 48.390 	Loss: 2.2260
#  Client2 Train => Local Epoch: 3 	Acc: 50.865 	Loss: 2.1063
#  Client2 Train => Local Epoch: 4 	Acc: 52.974 	Loss: 2.0208
#  Client2 Test =>                   	Acc: 6.597 	Loss: 5.1785
#  Client5 Train => Local Epoch: 0 	Acc: 8.608 	Loss: 4.2088
#  Client5 Train => Local Epoch: 1 	Acc: 32.730 	Loss: 2.7861
#  Client5 Train => Local Epoch: 2 	Acc: 39.348 	Loss: 2.4105
#  Client5 Train => Local Epoch: 3 	Acc: 41.989 	Loss: 2.2935
#  Client5 Train => Local Epoch: 4 	Acc: 43.991 	Loss: 2.2160
#  Client5 Test =>                   	Acc: 6.125 	Loss: 5.0590
#  Client3 Train => Local Epoch: 0 	Acc: 20.312 	Loss: 3.5808
#  Client3 Train => Local Epoch: 1 	Acc: 37.708 	Loss: 2.6111
#  Client3 Train => Local Epoch: 2 	Acc: 34.245 	Loss: 2.7238
#  Client3 Train => Local Epoch: 3 	Acc: 38.255 	Loss: 2.5477
#  Client3 Train => Local Epoch: 4 	Acc: 36.875 	Loss: 2.5514
#  Client3 Test =>                   	Acc: 7.631 	Loss: 5.0543
#  Client9 Train => Local Epoch: 0 	Acc: 17.452 	Loss: 3.8211
#  Client9 Train => Local Epoch: 1 	Acc: 35.391 	Loss: 2.6500
#  Client9 Train => Local Epoch: 2 	Acc: 39.755 	Loss: 2.4139
#  Client9 Train => Local Epoch: 3 	Acc: 41.614 	Loss: 2.3488
#  Client9 Train => Local Epoch: 4 	Acc: 44.386 	Loss: 2.2838
#  Client9 Test =>                   	Acc: 8.789 	Loss: 5.2203
#  Client1 Train => Local Epoch: 0 	Acc: 15.110 	Loss: 4.0017
#  Client1 Train => Local Epoch: 1 	Acc: 35.628 	Loss: 2.7061
#  Client1 Train => Local Epoch: 2 	Acc: 40.560 	Loss: 2.4329
#  Client1 Train => Local Epoch: 3 	Acc: 42.824 	Loss: 2.3352
#  Client1 Train => Local Epoch: 4 	Acc: 44.809 	Loss: 2.2591
#  Client1 Test =>                   	Acc: 7.466 	Loss: 4.9048
#  Client7 Train => Local Epoch: 0 	Acc: 17.536 	Loss: 3.9067
#  Client7 Train => Local Epoch: 1 	Acc: 33.030 	Loss: 2.8785
#  Client7 Train => Local Epoch: 2 	Acc: 36.584 	Loss: 2.5427
#  Client7 Train => Local Epoch: 3 	Acc: 39.668 	Loss: 2.4159
#  Client7 Train => Local Epoch: 4 	Acc: 40.186 	Loss: 2.3690
#  Client7 Test =>                   	Acc: 7.223 	Loss: 5.2169
#  Client6 Train => Local Epoch: 0 	Acc: 21.447 	Loss: 3.6670
#  Client6 Train => Local Epoch: 1 	Acc: 42.717 	Loss: 2.4276
#  Client6 Train => Local Epoch: 2 	Acc: 45.792 	Loss: 2.2718
#  Client6 Train => Local Epoch: 3 	Acc: 48.545 	Loss: 2.1684
#  Client6 Train => Local Epoch: 4 	Acc: 49.746 	Loss: 2.1177
#  Client6 Test =>                   	Acc: 10.183 	Loss: 4.9537
#  Client8 Train => Local Epoch: 0 	Acc: 14.824 	Loss: 3.9511
#  Client8 Train => Local Epoch: 1 	Acc: 32.131 	Loss: 2.7725
#  Client8 Train => Local Epoch: 2 	Acc: 35.270 	Loss: 2.5320
#  Client8 Train => Local Epoch: 3 	Acc: 37.290 	Loss: 2.4294
#  Client8 Train => Local Epoch: 4 	Acc: 37.715 	Loss: 2.3930
#  Client8 Test =>                   	Acc: 6.674 	Loss: 5.0176
# ====================== SERVER V1==========================
#  Train: Round   6, Avg Accuracy 44.366 | Avg Loss 2.263
#  Test: Round   6, Avg Accuracy 7.924 | Avg Loss 5.061
# Forgetting : Round 6, mean_forgetting : -0.457
# ==========================================================
#  Client6 Train => Local Epoch: 0 	Acc: 33.261 	Loss: 2.9759
#  Client6 Train => Local Epoch: 1 	Acc: 47.917 	Loss: 2.1821
#  Client6 Train => Local Epoch: 2 	Acc: 50.175 	Loss: 2.1110
#  Client6 Train => Local Epoch: 3 	Acc: 51.840 	Loss: 2.0397
#  Client6 Train => Local Epoch: 4 	Acc: 52.680 	Loss: 2.0227
#  Client6 Test =>                   	Acc: 11.796 	Loss: 5.0267
#  Client7 Train => Local Epoch: 0 	Acc: 16.500 	Loss: 3.8157
#  Client7 Train => Local Epoch: 1 	Acc: 37.990 	Loss: 2.6267
#  Client7 Train => Local Epoch: 2 	Acc: 40.121 	Loss: 2.4123
#  Client7 Train => Local Epoch: 3 	Acc: 43.040 	Loss: 2.2896
#  Client7 Train => Local Epoch: 4 	Acc: 44.527 	Loss: 2.2364
#  Client7 Test =>                   	Acc: 8.446 	Loss: 5.1920
#  Client4 Train => Local Epoch: 0 	Acc: 25.457 	Loss: 3.3792
#  Client4 Train => Local Epoch: 1 	Acc: 41.992 	Loss: 2.4488
#  Client4 Train => Local Epoch: 2 	Acc: 45.315 	Loss: 2.2785
#  Client4 Train => Local Epoch: 3 	Acc: 47.368 	Loss: 2.1882
#  Client4 Train => Local Epoch: 4 	Acc: 49.296 	Loss: 2.1332
#  Client4 Test =>                   	Acc: 11.325 	Loss: 4.9108
#  Client3 Train => Local Epoch: 0 	Acc: 26.042 	Loss: 3.2467
#  Client3 Train => Local Epoch: 1 	Acc: 44.844 	Loss: 2.4349
#  Client3 Train => Local Epoch: 2 	Acc: 46.615 	Loss: 2.3607
#  Client3 Train => Local Epoch: 3 	Acc: 42.292 	Loss: 2.3271
#  Client3 Train => Local Epoch: 4 	Acc: 41.641 	Loss: 2.4221
#  Client3 Test =>                   	Acc: 8.345 	Loss: 4.9018
#  Client0 Train => Local Epoch: 0 	Acc: 23.728 	Loss: 3.4272
#  Client0 Train => Local Epoch: 1 	Acc: 43.458 	Loss: 2.3657
#  Client0 Train => Local Epoch: 2 	Acc: 46.995 	Loss: 2.1833
#  Client0 Train => Local Epoch: 3 	Acc: 49.571 	Loss: 2.0773
#  Client0 Train => Local Epoch: 4 	Acc: 51.245 	Loss: 2.0152
#  Client0 Test =>                   	Acc: 10.604 	Loss: 4.8527
#  Client8 Train => Local Epoch: 0 	Acc: 16.197 	Loss: 3.8960
#  Client8 Train => Local Epoch: 1 	Acc: 33.972 	Loss: 2.6761
#  Client8 Train => Local Epoch: 2 	Acc: 37.867 	Loss: 2.4438
#  Client8 Train => Local Epoch: 3 	Acc: 38.589 	Loss: 2.3738
#  Client8 Train => Local Epoch: 4 	Acc: 41.014 	Loss: 2.3183
#  Client8 Test =>                   	Acc: 7.594 	Loss: 5.1528
#  Client2 Train => Local Epoch: 0 	Acc: 18.523 	Loss: 3.6782
#  Client2 Train => Local Epoch: 1 	Acc: 48.952 	Loss: 2.3791
#  Client2 Train => Local Epoch: 2 	Acc: 52.041 	Loss: 2.0929
#  Client2 Train => Local Epoch: 3 	Acc: 54.572 	Loss: 1.9851
#  Client2 Train => Local Epoch: 4 	Acc: 55.457 	Loss: 1.9367
#  Client2 Test =>                   	Acc: 7.260 	Loss: 5.1481
#  Client5 Train => Local Epoch: 0 	Acc: 11.637 	Loss: 3.9834
#  Client5 Train => Local Epoch: 1 	Acc: 37.587 	Loss: 2.6122
#  Client5 Train => Local Epoch: 2 	Acc: 44.296 	Loss: 2.2600
#  Client5 Train => Local Epoch: 3 	Acc: 45.348 	Loss: 2.1885
#  Client5 Train => Local Epoch: 4 	Acc: 47.979 	Loss: 2.0908
#  Client5 Test =>                   	Acc: 7.398 	Loss: 4.9267
#  Client1 Train => Local Epoch: 0 	Acc: 17.527 	Loss: 3.7956
#  Client1 Train => Local Epoch: 1 	Acc: 39.716 	Loss: 2.5226
#  Client1 Train => Local Epoch: 2 	Acc: 43.305 	Loss: 2.3002
#  Client1 Train => Local Epoch: 3 	Acc: 47.347 	Loss: 2.1794
#  Client1 Train => Local Epoch: 4 	Acc: 48.843 	Loss: 2.1137
#  Client1 Test =>                   	Acc: 9.314 	Loss: 4.9375
#  Client9 Train => Local Epoch: 0 	Acc: 21.260 	Loss: 3.5433
#  Client9 Train => Local Epoch: 1 	Acc: 40.919 	Loss: 2.4112
#  Client9 Train => Local Epoch: 2 	Acc: 44.800 	Loss: 2.2461
#  Client9 Train => Local Epoch: 3 	Acc: 47.185 	Loss: 2.1712
#  Client9 Train => Local Epoch: 4 	Acc: 49.217 	Loss: 2.1266
#  Client9 Test =>                   	Acc: 10.587 	Loss: 4.8135
# ====================== SERVER V1==========================
#  Train: Round   7, Avg Accuracy 48.190 | Avg Loss 2.142
#  Test: Round   7, Avg Accuracy 9.267 | Avg Loss 4.986
# Forgetting : Round 7, mean_forgetting : -0.891
# ==========================================================
#  Client1 Train => Local Epoch: 0 	Acc: 28.465 	Loss: 3.0600
#  Client1 Train => Local Epoch: 1 	Acc: 46.056 	Loss: 2.2406
#  Client1 Train => Local Epoch: 2 	Acc: 49.505 	Loss: 2.0953
#  Client1 Train => Local Epoch: 3 	Acc: 51.446 	Loss: 2.0143
#  Client1 Train => Local Epoch: 4 	Acc: 53.566 	Loss: 1.9403
#  Client1 Test =>                   	Acc: 11.483 	Loss: 4.7486
#  Client0 Train => Local Epoch: 0 	Acc: 29.130 	Loss: 3.1367
#  Client0 Train => Local Epoch: 1 	Acc: 48.729 	Loss: 2.1283
#  Client0 Train => Local Epoch: 2 	Acc: 52.329 	Loss: 2.0038
#  Client0 Train => Local Epoch: 3 	Acc: 54.198 	Loss: 1.9142
#  Client0 Train => Local Epoch: 4 	Acc: 55.007 	Loss: 1.8831
#  Client0 Test =>                   	Acc: 12.069 	Loss: 4.6750
#  Client6 Train => Local Epoch: 0 	Acc: 30.593 	Loss: 3.1081
#  Client6 Train => Local Epoch: 1 	Acc: 49.795 	Loss: 2.1582
#  Client6 Train => Local Epoch: 2 	Acc: 52.499 	Loss: 2.0360
#  Client6 Train => Local Epoch: 3 	Acc: 53.554 	Loss: 1.9593
#  Client6 Train => Local Epoch: 4 	Acc: 55.800 	Loss: 1.9256
#  Client6 Test =>                   	Acc: 14.376 	Loss: 4.6641
#  Client7 Train => Local Epoch: 0 	Acc: 17.034 	Loss: 3.8873
#  Client7 Train => Local Epoch: 1 	Acc: 38.893 	Loss: 2.6077
#  Client7 Train => Local Epoch: 2 	Acc: 43.871 	Loss: 2.3055
#  Client7 Train => Local Epoch: 3 	Acc: 45.438 	Loss: 2.2037
#  Client7 Train => Local Epoch: 4 	Acc: 46.919 	Loss: 2.1644
#  Client7 Test =>                   	Acc: 9.335 	Loss: 4.6987
#  Client2 Train => Local Epoch: 0 	Acc: 19.196 	Loss: 3.7137
#  Client2 Train => Local Epoch: 1 	Acc: 50.749 	Loss: 2.2653
#  Client2 Train => Local Epoch: 2 	Acc: 53.763 	Loss: 1.9926
#  Client2 Train => Local Epoch: 3 	Acc: 56.501 	Loss: 1.8929
#  Client2 Train => Local Epoch: 4 	Acc: 58.677 	Loss: 1.8155
#  Client2 Test =>                   	Acc: 7.456 	Loss: 4.9996
#  Client8 Train => Local Epoch: 0 	Acc: 17.633 	Loss: 3.6887
#  Client8 Train => Local Epoch: 1 	Acc: 36.230 	Loss: 2.5802
#  Client8 Train => Local Epoch: 2 	Acc: 41.145 	Loss: 2.3308
#  Client8 Train => Local Epoch: 3 	Acc: 43.689 	Loss: 2.2412
#  Client8 Train => Local Epoch: 4 	Acc: 44.400 	Loss: 2.2217
#  Client8 Test =>                   	Acc: 8.776 	Loss: 4.8933
#  Client9 Train => Local Epoch: 0 	Acc: 22.413 	Loss: 3.6173
#  Client9 Train => Local Epoch: 1 	Acc: 44.232 	Loss: 2.3158
#  Client9 Train => Local Epoch: 2 	Acc: 47.609 	Loss: 2.1358
#  Client9 Train => Local Epoch: 3 	Acc: 50.603 	Loss: 2.0552
#  Client9 Train => Local Epoch: 4 	Acc: 52.338 	Loss: 2.0028
#  Client9 Test =>                   	Acc: 12.423 	Loss: 4.6111
#  Client3 Train => Local Epoch: 0 	Acc: 21.172 	Loss: 3.6544
#  Client3 Train => Local Epoch: 1 	Acc: 40.755 	Loss: 2.4831
#  Client3 Train => Local Epoch: 2 	Acc: 43.802 	Loss: 2.3092
#  Client3 Train => Local Epoch: 3 	Acc: 50.182 	Loss: 2.1032
#  Client3 Train => Local Epoch: 4 	Acc: 46.510 	Loss: 2.1751
#  Client3 Test =>                   	Acc: 10.702 	Loss: 4.5434
#  Client4 Train => Local Epoch: 0 	Acc: 23.851 	Loss: 3.4268
#  Client4 Train => Local Epoch: 1 	Acc: 44.071 	Loss: 2.3967
#  Client4 Train => Local Epoch: 2 	Acc: 46.604 	Loss: 2.2055
#  Client4 Train => Local Epoch: 3 	Acc: 50.825 	Loss: 2.0694
#  Client4 Train => Local Epoch: 4 	Acc: 51.769 	Loss: 2.0223
#  Client4 Test =>                   	Acc: 13.908 	Loss: 4.6278
#  Client5 Train => Local Epoch: 0 	Acc: 20.575 	Loss: 3.6393
#  Client5 Train => Local Epoch: 1 	Acc: 43.911 	Loss: 2.3205
#  Client5 Train => Local Epoch: 2 	Acc: 48.140 	Loss: 2.1105
#  Client5 Train => Local Epoch: 3 	Acc: 51.540 	Loss: 2.0147
#  Client5 Train => Local Epoch: 4 	Acc: 53.739 	Loss: 1.9292
#  Client5 Test =>                   	Acc: 11.227 	Loss: 4.6612
# ====================== SERVER V1==========================
#  Train: Round   8, Avg Accuracy 51.873 | Avg Loss 2.008
#  Test: Round   8, Avg Accuracy 11.175 | Avg Loss 4.712
# Forgetting : Round 8, mean_forgetting : -1.000
# ==========================================================
#  Client9 Train => Local Epoch: 0 	Acc: 29.084 	Loss: 3.1187
#  Client9 Train => Local Epoch: 1 	Acc: 49.202 	Loss: 2.1272
#  Client9 Train => Local Epoch: 2 	Acc: 52.015 	Loss: 2.0217
#  Client9 Train => Local Epoch: 3 	Acc: 53.998 	Loss: 1.9580
#  Client9 Train => Local Epoch: 4 	Acc: 55.204 	Loss: 1.8995
#  Client9 Test =>                   	Acc: 15.042 	Loss: 4.4091
#  Client3 Train => Local Epoch: 0 	Acc: 24.297 	Loss: 3.3546
#  Client3 Train => Local Epoch: 1 	Acc: 44.922 	Loss: 2.3946
#  Client3 Train => Local Epoch: 2 	Acc: 44.479 	Loss: 2.3004
#  Client3 Train => Local Epoch: 3 	Acc: 49.141 	Loss: 2.1166
#  Client3 Train => Local Epoch: 4 	Acc: 48.411 	Loss: 2.2315
#  Client3 Test =>                   	Acc: 11.941 	Loss: 4.5441
#  Client1 Train => Local Epoch: 0 	Acc: 20.659 	Loss: 3.6667
#  Client1 Train => Local Epoch: 1 	Acc: 44.838 	Loss: 2.3951
#  Client1 Train => Local Epoch: 2 	Acc: 51.166 	Loss: 2.1049
#  Client1 Train => Local Epoch: 3 	Acc: 53.478 	Loss: 1.9879
#  Client1 Train => Local Epoch: 4 	Acc: 55.241 	Loss: 1.9245
#  Client1 Test =>                   	Acc: 11.082 	Loss: 4.6699
#  Client0 Train => Local Epoch: 0 	Acc: 29.411 	Loss: 3.2234
#  Client0 Train => Local Epoch: 1 	Acc: 51.571 	Loss: 2.0435
#  Client0 Train => Local Epoch: 2 	Acc: 54.673 	Loss: 1.9061
#  Client0 Train => Local Epoch: 3 	Acc: 56.298 	Loss: 1.8349
#  Client0 Train => Local Epoch: 4 	Acc: 56.863 	Loss: 1.8100
#  Client0 Test =>                   	Acc: 13.497 	Loss: 4.3460
#  Client6 Train => Local Epoch: 0 	Acc: 33.961 	Loss: 2.9792
#  Client6 Train => Local Epoch: 1 	Acc: 52.342 	Loss: 2.0629
#  Client6 Train => Local Epoch: 2 	Acc: 55.535 	Loss: 1.9293
#  Client6 Train => Local Epoch: 3 	Acc: 57.190 	Loss: 1.8693
#  Client6 Train => Local Epoch: 4 	Acc: 58.584 	Loss: 1.8148
#  Client6 Test =>                   	Acc: 15.891 	Loss: 4.6339
#  Client4 Train => Local Epoch: 0 	Acc: 27.087 	Loss: 3.3018
#  Client4 Train => Local Epoch: 1 	Acc: 49.464 	Loss: 2.1842
#  Client4 Train => Local Epoch: 2 	Acc: 51.994 	Loss: 2.0199
#  Client4 Train => Local Epoch: 3 	Acc: 53.967 	Loss: 1.9482
#  Client4 Train => Local Epoch: 4 	Acc: 54.202 	Loss: 1.9331
#  Client4 Test =>                   	Acc: 17.346 	Loss: 4.4575
#  Client7 Train => Local Epoch: 0 	Acc: 22.177 	Loss: 3.5979
#  Client7 Train => Local Epoch: 1 	Acc: 44.918 	Loss: 2.3618
#  Client7 Train => Local Epoch: 2 	Acc: 49.451 	Loss: 2.1194
#  Client7 Train => Local Epoch: 3 	Acc: 50.812 	Loss: 2.0336
#  Client7 Train => Local Epoch: 4 	Acc: 51.111 	Loss: 2.0028
#  Client7 Test =>                   	Acc: 11.857 	Loss: 4.5014
#  Client5 Train => Local Epoch: 0 	Acc: 20.153 	Loss: 3.6666
#  Client5 Train => Local Epoch: 1 	Acc: 48.061 	Loss: 2.1948
#  Client5 Train => Local Epoch: 2 	Acc: 52.426 	Loss: 1.9851
#  Client5 Train => Local Epoch: 3 	Acc: 53.628 	Loss: 1.9165
#  Client5 Train => Local Epoch: 4 	Acc: 56.286 	Loss: 1.8448
#  Client5 Test =>                   	Acc: 11.140 	Loss: 4.6976
#  Client2 Train => Local Epoch: 0 	Acc: 13.819 	Loss: 3.9204
#  Client2 Train => Local Epoch: 1 	Acc: 49.570 	Loss: 2.3707
#  Client2 Train => Local Epoch: 2 	Acc: 55.505 	Loss: 1.9601
#  Client2 Train => Local Epoch: 3 	Acc: 58.502 	Loss: 1.7996
#  Client2 Train => Local Epoch: 4 	Acc: 59.578 	Loss: 1.7398
#  Client2 Test =>                   	Acc: 8.853 	Loss: 4.7479
#  Client8 Train => Local Epoch: 0 	Acc: 20.066 	Loss: 3.6178
#  Client8 Train => Local Epoch: 1 	Acc: 41.620 	Loss: 2.4250
#  Client8 Train => Local Epoch: 2 	Acc: 44.786 	Loss: 2.1963
#  Client8 Train => Local Epoch: 3 	Acc: 48.335 	Loss: 2.0914
#  Client8 Train => Local Epoch: 4 	Acc: 49.574 	Loss: 2.0557
#  Client8 Test =>                   	Acc: 10.389 	Loss: 4.9112
# ====================== SERVER V1==========================
#  Train: Round   9, Avg Accuracy 54.505 | Avg Loss 1.926
#  Test: Round   9, Avg Accuracy 12.704 | Avg Loss 4.592
# Forgetting : Round 9, mean_forgetting : -0.710
# ==========================================================
#  Client3 Train => Local Epoch: 0 	Acc: 24.375 	Loss: 3.5323
#  Client3 Train => Local Epoch: 1 	Acc: 47.630 	Loss: 2.2886
#  Client3 Train => Local Epoch: 2 	Acc: 44.062 	Loss: 2.4720
#  Client3 Train => Local Epoch: 3 	Acc: 44.948 	Loss: 2.2895
#  Client3 Train => Local Epoch: 4 	Acc: 48.021 	Loss: 2.1816
#  Client3 Test =>                   	Acc: 11.247 	Loss: 4.5353
#  Client7 Train => Local Epoch: 0 	Acc: 25.978 	Loss: 3.2119
#  Client7 Train => Local Epoch: 1 	Acc: 47.015 	Loss: 2.2151
#  Client7 Train => Local Epoch: 2 	Acc: 51.667 	Loss: 1.9922
#  Client7 Train => Local Epoch: 3 	Acc: 53.110 	Loss: 1.9519
#  Client7 Train => Local Epoch: 4 	Acc: 53.435 	Loss: 1.8868
#  Client7 Test =>                   	Acc: 13.224 	Loss: 4.6459
#  Client8 Train => Local Epoch: 0 	Acc: 26.635 	Loss: 3.2026
#  Client8 Train => Local Epoch: 1 	Acc: 44.916 	Loss: 2.2195
#  Client8 Train => Local Epoch: 2 	Acc: 48.662 	Loss: 2.0743
#  Client8 Train => Local Epoch: 3 	Acc: 50.794 	Loss: 2.0089
#  Client8 Train => Local Epoch: 4 	Acc: 52.926 	Loss: 1.9611
#  Client8 Test =>                   	Acc: 11.406 	Loss: 4.8163
#  Client1 Train => Local Epoch: 0 	Acc: 24.081 	Loss: 3.4030
#  Client1 Train => Local Epoch: 1 	Acc: 48.774 	Loss: 2.1822
#  Client1 Train => Local Epoch: 2 	Acc: 55.045 	Loss: 1.9434
#  Client1 Train => Local Epoch: 3 	Acc: 57.004 	Loss: 1.8706
#  Client1 Train => Local Epoch: 4 	Acc: 59.026 	Loss: 1.8011
#  Client1 Test =>                   	Acc: 13.194 	Loss: 4.4992
#  Client0 Train => Local Epoch: 0 	Acc: 31.975 	Loss: 3.0583
#  Client0 Train => Local Epoch: 1 	Acc: 54.283 	Loss: 1.9623
#  Client0 Train => Local Epoch: 2 	Acc: 56.737 	Loss: 1.8385
#  Client0 Train => Local Epoch: 3 	Acc: 58.624 	Loss: 1.7596
#  Client0 Train => Local Epoch: 4 	Acc: 60.062 	Loss: 1.7164
#  Client0 Test =>                   	Acc: 15.315 	Loss: 4.3159
#  Client9 Train => Local Epoch: 0 	Acc: 28.969 	Loss: 3.2371
#  Client9 Train => Local Epoch: 1 	Acc: 51.459 	Loss: 2.0967
#  Client9 Train => Local Epoch: 2 	Acc: 53.886 	Loss: 1.9394
#  Client9 Train => Local Epoch: 3 	Acc: 56.124 	Loss: 1.8675
#  Client9 Train => Local Epoch: 4 	Acc: 58.449 	Loss: 1.8068
#  Client9 Test =>                   	Acc: 15.012 	Loss: 4.4126
#  Client6 Train => Local Epoch: 0 	Acc: 36.127 	Loss: 2.8669
#  Client6 Train => Local Epoch: 1 	Acc: 55.493 	Loss: 1.9399
#  Client6 Train => Local Epoch: 2 	Acc: 58.738 	Loss: 1.8162
#  Client6 Train => Local Epoch: 3 	Acc: 60.901 	Loss: 1.7580
#  Client6 Train => Local Epoch: 4 	Acc: 62.718 	Loss: 1.7048
#  Client6 Test =>                   	Acc: 18.070 	Loss: 4.1567
#  Client4 Train => Local Epoch: 0 	Acc: 29.443 	Loss: 3.0870
#  Client4 Train => Local Epoch: 1 	Acc: 52.681 	Loss: 2.0619
#  Client4 Train => Local Epoch: 2 	Acc: 55.517 	Loss: 1.9276
#  Client4 Train => Local Epoch: 3 	Acc: 55.913 	Loss: 1.8649
#  Client4 Train => Local Epoch: 4 	Acc: 57.114 	Loss: 1.8202
#  Client4 Test =>                   	Acc: 20.121 	Loss: 4.2527
#  Client5 Train => Local Epoch: 0 	Acc: 28.835 	Loss: 3.2446
#  Client5 Train => Local Epoch: 1 	Acc: 51.730 	Loss: 2.0416
#  Client5 Train => Local Epoch: 2 	Acc: 54.981 	Loss: 1.8736
#  Client5 Train => Local Epoch: 3 	Acc: 57.821 	Loss: 1.7837
#  Client5 Train => Local Epoch: 4 	Acc: 59.152 	Loss: 1.7283
#  Client5 Test =>                   	Acc: 12.753 	Loss: 4.3796
#  Client2 Train => Local Epoch: 0 	Acc: 18.670 	Loss: 3.6096
#  Client2 Train => Local Epoch: 1 	Acc: 53.440 	Loss: 2.2059
#  Client2 Train => Local Epoch: 2 	Acc: 57.924 	Loss: 1.8792
#  Client2 Train => Local Epoch: 3 	Acc: 60.631 	Loss: 1.7494
#  Client2 Train => Local Epoch: 4 	Acc: 63.768 	Loss: 1.6472
#  Client2 Test =>                   	Acc: 9.850 	Loss: 4.5740
# ====================== SERVER V1==========================
#  Train: Round  10, Avg Accuracy 57.467 | Avg Loss 1.825
#  Test: Round  10, Avg Accuracy 14.019 | Avg Loss 4.459
# Forgetting : Round 10, mean_forgetting : -0.741
# ==========================================================
#  Client8 Train => Local Epoch: 0 	Acc: 25.519 	Loss: 3.3276
#  Client8 Train => Local Epoch: 1 	Acc: 47.297 	Loss: 2.1913
#  Client8 Train => Local Epoch: 2 	Acc: 50.668 	Loss: 2.0078
#  Client8 Train => Local Epoch: 3 	Acc: 53.785 	Loss: 1.9070
#  Client8 Train => Local Epoch: 4 	Acc: 54.764 	Loss: 1.8844
#  Client8 Test =>                   	Acc: 12.187 	Loss: 4.4909
#  Client0 Train => Local Epoch: 0 	Acc: 34.786 	Loss: 2.9414
#  Client0 Train => Local Epoch: 1 	Acc: 56.132 	Loss: 1.8758
#  Client0 Train => Local Epoch: 2 	Acc: 58.552 	Loss: 1.7560
#  Client0 Train => Local Epoch: 3 	Acc: 61.578 	Loss: 1.6643
#  Client0 Train => Local Epoch: 4 	Acc: 62.038 	Loss: 1.6540
#  Client0 Test =>                   	Acc: 15.854 	Loss: 4.1445
#  Client1 Train => Local Epoch: 0 	Acc: 29.817 	Loss: 3.0306
#  Client1 Train => Local Epoch: 1 	Acc: 53.035 	Loss: 2.0284
# ...
# ====================== SERVER V1==========================
#  Train: Round  95, Avg Accuracy 98.501 | Avg Loss 0.532
#  Test: Round  95, Avg Accuracy 47.126 | Avg Loss 2.394
# Forgetting : Round 95, mean_forgetting : -0.619
# ==========================================================
#  Client3 Train => Local Epoch: 0 	Acc: 98.333 	Loss: 0.6161
#  Client3 Train => Local Epoch: 1 	Acc: 93.151 	Loss: 0.6326
#  Client3 Train => Local Epoch: 2 	Acc: 96.797 	Loss: 0.6294
#  Client3 Train => Local Epoch: 3 	Acc: 96.901 	Loss: 0.6155
#  Client3 Train => Local Epoch: 4 	Acc: 94.922 	Loss: 0.6716
#  Client3 Test =>                   	Acc: 50.751 	Loss: 2.2781
#  Client9 Train => Local Epoch: 0 	Acc: 98.092 	Loss: 0.5617
#  Client9 Train => Local Epoch: 1 	Acc: 98.903 	Loss: 0.5176
#  Client9 Train => Local Epoch: 2 	Acc: 99.230 	Loss: 0.5075
#  Client9 Train => Local Epoch: 3 	Acc: 99.020 	Loss: 0.5129
#  Client9 Train => Local Epoch: 4 	Acc: 99.301 	Loss: 0.5036
#  Client9 Test =>                   	Acc: 48.906 	Loss: 2.3859
#  Client8 Train => Local Epoch: 0 	Acc: 98.226 	Loss: 0.5938
#  Client8 Train => Local Epoch: 1 	Acc: 98.862 	Loss: 0.5348
#  Client8 Train => Local Epoch: 2 	Acc: 98.977 	Loss: 0.5220
#  Client8 Train => Local Epoch: 3 	Acc: 98.854 	Loss: 0.5267
#  Client8 Train => Local Epoch: 4 	Acc: 99.144 	Loss: 0.5202
#  Client8 Test =>                   	Acc: 42.642 	Loss: 2.5936
#  Client2 Train => Local Epoch: 0 	Acc: 94.898 	Loss: 0.6941
#  Client2 Train => Local Epoch: 1 	Acc: 99.023 	Loss: 0.5340
#  Client2 Train => Local Epoch: 2 	Acc: 98.908 	Loss: 0.5282
#  Client2 Train => Local Epoch: 3 	Acc: 99.015 	Loss: 0.5170
#  Client2 Train => Local Epoch: 4 	Acc: 99.322 	Loss: 0.5114
#  Client2 Test =>                   	Acc: 47.865 	Loss: 2.3331
#  Client6 Train => Local Epoch: 0 	Acc: 97.653 	Loss: 0.5820
#  Client6 Train => Local Epoch: 1 	Acc: 98.986 	Loss: 0.5171
#  Client6 Train => Local Epoch: 2 	Acc: 99.061 	Loss: 0.5140
#  Client6 Train => Local Epoch: 3 	Acc: 99.189 	Loss: 0.5102
#  Client6 Train => Local Epoch: 4 	Acc: 99.257 	Loss: 0.5058
#  Client6 Test =>                   	Acc: 49.219 	Loss: 2.3744
#  Client1 Train => Local Epoch: 0 	Acc: 97.096 	Loss: 0.6193
#  Client1 Train => Local Epoch: 1 	Acc: 99.068 	Loss: 0.5303
#  Client1 Train => Local Epoch: 2 	Acc: 99.098 	Loss: 0.5156
#  Client1 Train => Local Epoch: 3 	Acc: 99.229 	Loss: 0.5076
#  Client1 Train => Local Epoch: 4 	Acc: 99.275 	Loss: 0.5110
#  Client1 Test =>                   	Acc: 44.919 	Loss: 2.4789
#  Client5 Train => Local Epoch: 0 	Acc: 96.432 	Loss: 0.6200
#  Client5 Train => Local Epoch: 1 	Acc: 99.125 	Loss: 0.5217
#  Client5 Train => Local Epoch: 2 	Acc: 99.235 	Loss: 0.5134
#  Client5 Train => Local Epoch: 3 	Acc: 98.975 	Loss: 0.5170
#  Client5 Train => Local Epoch: 4 	Acc: 99.476 	Loss: 0.5073
#  Client5 Test =>                   	Acc: 44.966 	Loss: 2.4476
#  Client0 Train => Local Epoch: 0 	Acc: 97.468 	Loss: 0.6008
#  Client0 Train => Local Epoch: 1 	Acc: 98.958 	Loss: 0.5227
#  Client0 Train => Local Epoch: 2 	Acc: 99.297 	Loss: 0.5153
#  Client0 Train => Local Epoch: 3 	Acc: 98.887 	Loss: 0.5206
#  Client0 Train => Local Epoch: 4 	Acc: 98.819 	Loss: 0.5197
#  Client0 Test =>                   	Acc: 50.781 	Loss: 2.2938
#  Client7 Train => Local Epoch: 0 	Acc: 96.674 	Loss: 0.6133
#  Client7 Train => Local Epoch: 1 	Acc: 98.937 	Loss: 0.5419
#  Client7 Train => Local Epoch: 2 	Acc: 98.980 	Loss: 0.5271
#  Client7 Train => Local Epoch: 3 	Acc: 98.627 	Loss: 0.5373
#  Client7 Train => Local Epoch: 4 	Acc: 99.067 	Loss: 0.5264
#  Client7 Test =>                   	Acc: 49.902 	Loss: 2.2051
#  Client4 Train => Local Epoch: 0 	Acc: 98.093 	Loss: 0.5624
#  Client4 Train => Local Epoch: 1 	Acc: 98.755 	Loss: 0.5226
#  Client4 Train => Local Epoch: 2 	Acc: 98.843 	Loss: 0.5176
#  Client4 Train => Local Epoch: 3 	Acc: 98.930 	Loss: 0.5179
#  Client4 Train => Local Epoch: 4 	Acc: 99.168 	Loss: 0.5117
#  Client4 Test =>                   	Acc: 45.663 	Loss: 2.5014
# ====================== SERVER V1==========================
#  Train: Round  96, Avg Accuracy 98.775 | Avg Loss 0.529
#  Test: Round  96, Avg Accuracy 47.561 | Avg Loss 2.389
# Forgetting : Round 96, mean_forgetting : -0.688
# ==========================================================
#  Client1 Train => Local Epoch: 0 	Acc: 98.678 	Loss: 0.5530
#  Client1 Train => Local Epoch: 1 	Acc: 99.022 	Loss: 0.5148
#  Client1 Train => Local Epoch: 2 	Acc: 99.229 	Loss: 0.5065
#  Client1 Train => Local Epoch: 3 	Acc: 99.258 	Loss: 0.5099
#  Client1 Train => Local Epoch: 4 	Acc: 99.246 	Loss: 0.5060
#  Client1 Test =>                   	Acc: 43.891 	Loss: 2.4864
#  Client5 Train => Local Epoch: 0 	Acc: 98.253 	Loss: 0.5684
#  Client5 Train => Local Epoch: 1 	Acc: 98.911 	Loss: 0.5176
#  Client5 Train => Local Epoch: 2 	Acc: 99.434 	Loss: 0.5097
#  Client5 Train => Local Epoch: 3 	Acc: 99.257 	Loss: 0.5101
#  Client5 Train => Local Epoch: 4 	Acc: 99.302 	Loss: 0.5057
#  Client5 Test =>                   	Acc: 44.360 	Loss: 2.4332
#  Client4 Train => Local Epoch: 0 	Acc: 95.140 	Loss: 0.6671
#  Client4 Train => Local Epoch: 1 	Acc: 98.552 	Loss: 0.5288
#  Client4 Train => Local Epoch: 2 	Acc: 99.010 	Loss: 0.5201
#  Client4 Train => Local Epoch: 3 	Acc: 99.236 	Loss: 0.5115
#  Client4 Train => Local Epoch: 4 	Acc: 99.168 	Loss: 0.5099
#  Client4 Test =>                   	Acc: 44.754 	Loss: 2.5472
#  Client9 Train => Local Epoch: 0 	Acc: 96.109 	Loss: 0.6311
#  Client9 Train => Local Epoch: 1 	Acc: 98.873 	Loss: 0.5244
#  Client9 Train => Local Epoch: 2 	Acc: 99.023 	Loss: 0.5141
#  Client9 Train => Local Epoch: 3 	Acc: 98.974 	Loss: 0.5152
#  Client9 Train => Local Epoch: 4 	Acc: 99.001 	Loss: 0.5134
#  Client9 Test =>                   	Acc: 48.084 	Loss: 2.4306
#  Client6 Train => Local Epoch: 0 	Acc: 98.242 	Loss: 0.5682
#  Client6 Train => Local Epoch: 1 	Acc: 99.065 	Loss: 0.5131
#  Client6 Train => Local Epoch: 2 	Acc: 99.215 	Loss: 0.5062
#  Client6 Train => Local Epoch: 3 	Acc: 99.260 	Loss: 0.5051
#  Client6 Train => Local Epoch: 4 	Acc: 99.053 	Loss: 0.5095
#  Client6 Test =>                   	Acc: 47.077 	Loss: 2.4482
#  Client0 Train => Local Epoch: 0 	Acc: 96.801 	Loss: 0.6111
#  Client0 Train => Local Epoch: 1 	Acc: 98.588 	Loss: 0.5321
#  Client0 Train => Local Epoch: 2 	Acc: 99.026 	Loss: 0.5218
#  Client0 Train => Local Epoch: 3 	Acc: 99.158 	Loss: 0.5148
#  Client0 Train => Local Epoch: 4 	Acc: 98.975 	Loss: 0.5143
#  Client0 Test =>                   	Acc: 49.481 	Loss: 2.3554
#  Client3 Train => Local Epoch: 0 	Acc: 95.599 	Loss: 0.6548
#  Client3 Train => Local Epoch: 1 	Acc: 94.375 	Loss: 0.6486
#  Client3 Train => Local Epoch: 2 	Acc: 94.297 	Loss: 0.6838
#  Client3 Train => Local Epoch: 3 	Acc: 97.370 	Loss: 0.5958
#  Client3 Train => Local Epoch: 4 	Acc: 96.068 	Loss: 0.6419
#  Client3 Test =>                   	Acc: 51.913 	Loss: 2.2700
#  Client2 Train => Local Epoch: 0 	Acc: 97.138 	Loss: 0.6179
#  Client2 Train => Local Epoch: 1 	Acc: 99.007 	Loss: 0.5296
#  Client2 Train => Local Epoch: 2 	Acc: 98.960 	Loss: 0.5156
#  Client2 Train => Local Epoch: 3 	Acc: 99.275 	Loss: 0.5088
#  Client2 Train => Local Epoch: 4 	Acc: 99.203 	Loss: 0.5065
#  Client2 Test =>                   	Acc: 50.104 	Loss: 2.2434
#  Client7 Train => Local Epoch: 0 	Acc: 98.134 	Loss: 0.5771
#  Client7 Train => Local Epoch: 1 	Acc: 98.893 	Loss: 0.5356
#  Client7 Train => Local Epoch: 2 	Acc: 98.934 	Loss: 0.5274
#  Client7 Train => Local Epoch: 3 	Acc: 98.872 	Loss: 0.5275
#  Client7 Train => Local Epoch: 4 	Acc: 98.915 	Loss: 0.5282
#  Client7 Test =>                   	Acc: 51.360 	Loss: 2.1704
#  Client8 Train => Local Epoch: 0 	Acc: 98.493 	Loss: 0.5723
#  Client8 Train => Local Epoch: 1 	Acc: 98.951 	Loss: 0.5257
#  Client8 Train => Local Epoch: 2 	Acc: 99.234 	Loss: 0.5217
#  Client8 Train => Local Epoch: 3 	Acc: 98.910 	Loss: 0.5252
#  Client8 Train => Local Epoch: 4 	Acc: 99.070 	Loss: 0.5189
#  Client8 Test =>                   	Acc: 42.319 	Loss: 2.6041
# ====================== SERVER V1==========================
#  Train: Round  97, Avg Accuracy 98.800 | Avg Loss 0.525
#  Test: Round  97, Avg Accuracy 47.334 | Avg Loss 2.399
# Forgetting : Round 97, mean_forgetting : -0.559
# ==========================================================
#  Client4 Train => Local Epoch: 0 	Acc: 97.770 	Loss: 0.5780
#  Client4 Train => Local Epoch: 1 	Acc: 98.976 	Loss: 0.5142
#  Client4 Train => Local Epoch: 2 	Acc: 99.221 	Loss: 0.5111
#  Client4 Train => Local Epoch: 3 	Acc: 99.100 	Loss: 0.5132
#  Client4 Train => Local Epoch: 4 	Acc: 99.146 	Loss: 0.5124
#  Client4 Test =>                   	Acc: 44.461 	Loss: 2.5737
#  Client6 Train => Local Epoch: 0 	Acc: 98.295 	Loss: 0.5537
#  Client6 Train => Local Epoch: 1 	Acc: 99.234 	Loss: 0.5077
#  Client6 Train => Local Epoch: 2 	Acc: 99.189 	Loss: 0.5057
#  Client6 Train => Local Epoch: 3 	Acc: 99.196 	Loss: 0.5075
#  Client6 Train => Local Epoch: 4 	Acc: 99.429 	Loss: 0.5025
#  Client6 Test =>                   	Acc: 48.700 	Loss: 2.4127
#  Client2 Train => Local Epoch: 0 	Acc: 96.891 	Loss: 0.6352
#  Client2 Train => Local Epoch: 1 	Acc: 98.856 	Loss: 0.5241
#  Client2 Train => Local Epoch: 2 	Acc: 99.007 	Loss: 0.5167
#  Client2 Train => Local Epoch: 3 	Acc: 99.386 	Loss: 0.5084
#  Client2 Train => Local Epoch: 4 	Acc: 99.442 	Loss: 0.5017
#  Client2 Test =>                   	Acc: 48.552 	Loss: 2.2996
#  Client3 Train => Local Epoch: 0 	Acc: 96.406 	Loss: 0.6137
#  Client3 Train => Local Epoch: 1 	Acc: 96.953 	Loss: 0.5817
#  Client3 Train => Local Epoch: 2 	Acc: 95.703 	Loss: 0.6271
#  Client3 Train => Local Epoch: 3 	Acc: 97.083 	Loss: 0.6777
#  Client3 Train => Local Epoch: 4 	Acc: 92.943 	Loss: 0.7075
#  Client3 Test =>                   	Acc: 49.879 	Loss: 2.2766
#  Client1 Train => Local Epoch: 0 	Acc: 97.201 	Loss: 0.6139
#  Client1 Train => Local Epoch: 1 	Acc: 98.862 	Loss: 0.5247
#  Client1 Train => Local Epoch: 2 	Acc: 99.173 	Loss: 0.5144
#  Client1 Train => Local Epoch: 3 	Acc: 99.252 	Loss: 0.5086
#  Client1 Train => Local Epoch: 4 	Acc: 99.114 	Loss: 0.5096
#  Client1 Test =>                   	Acc: 44.292 	Loss: 2.4592
#  Client5 Train => Local Epoch: 0 	Acc: 95.776 	Loss: 0.6420
#  Client5 Train => Local Epoch: 1 	Acc: 98.872 	Loss: 0.5306
#  Client5 Train => Local Epoch: 2 	Acc: 98.843 	Loss: 0.5204
#  Client5 Train => Local Epoch: 3 	Acc: 98.957 	Loss: 0.5197
#  Client5 Train => Local Epoch: 4 	Acc: 99.279 	Loss: 0.5091
#  Client5 Test =>                   	Acc: 44.838 	Loss: 2.4357
#  Client0 Train => Local Epoch: 0 	Acc: 97.698 	Loss: 0.5834
#  Client0 Train => Local Epoch: 1 	Acc: 98.975 	Loss: 0.5270
#  Client0 Train => Local Epoch: 2 	Acc: 98.723 	Loss: 0.5227
#  Client0 Train => Local Epoch: 3 	Acc: 98.887 	Loss: 0.5201
#  Client0 Train => Local Epoch: 4 	Acc: 99.053 	Loss: 0.5141
#  Client0 Test =>                   	Acc: 50.195 	Loss: 2.3080
#  Client9 Train => Local Epoch: 0 	Acc: 97.393 	Loss: 0.5854
#  Client9 Train => Local Epoch: 1 	Acc: 99.031 	Loss: 0.5191
#  Client9 Train => Local Epoch: 2 	Acc: 99.038 	Loss: 0.5149
#  Client9 Train => Local Epoch: 3 	Acc: 99.046 	Loss: 0.5137
#  Client9 Train => Local Epoch: 4 	Acc: 99.102 	Loss: 0.5108
#  Client9 Test =>                   	Acc: 48.202 	Loss: 2.4188
#  Client8 Train => Local Epoch: 0 	Acc: 98.121 	Loss: 0.5840
#  Client8 Train => Local Epoch: 1 	Acc: 99.256 	Loss: 0.5201
#  Client8 Train => Local Epoch: 2 	Acc: 99.085 	Loss: 0.5254
#  Client8 Train => Local Epoch: 3 	Acc: 99.178 	Loss: 0.5176
#  Client8 Train => Local Epoch: 4 	Acc: 99.107 	Loss: 0.5206
#  Client8 Test =>                   	Acc: 43.002 	Loss: 2.6140
#  Client7 Train => Local Epoch: 0 	Acc: 97.214 	Loss: 0.6067
#  Client7 Train => Local Epoch: 1 	Acc: 99.067 	Loss: 0.5228
#  Client7 Train => Local Epoch: 2 	Acc: 98.562 	Loss: 0.5341
#  Client7 Train => Local Epoch: 3 	Acc: 98.692 	Loss: 0.5341
#  Client7 Train => Local Epoch: 4 	Acc: 98.692 	Loss: 0.5252
#  Client7 Test =>                   	Acc: 50.589 	Loss: 2.1733
# ====================== SERVER V1==========================
#  Train: Round  98, Avg Accuracy 98.531 | Avg Loss 0.531
#  Test: Round  98, Avg Accuracy 47.271 | Avg Loss 2.397
# Forgetting : Round 98, mean_forgetting : -1.022
# ==========================================================
#  Client9 Train => Local Epoch: 0 	Acc: 97.859 	Loss: 0.5720
#  Client9 Train => Local Epoch: 1 	Acc: 98.821 	Loss: 0.5171
#  Client9 Train => Local Epoch: 2 	Acc: 99.249 	Loss: 0.5115
#  Client9 Train => Local Epoch: 3 	Acc: 99.230 	Loss: 0.5044
#  Client9 Train => Local Epoch: 4 	Acc: 99.102 	Loss: 0.5097
#  Client9 Test =>                   	Acc: 47.498 	Loss: 2.4629
#  Client6 Train => Local Epoch: 0 	Acc: 98.163 	Loss: 0.5677
#  Client6 Train => Local Epoch: 1 	Acc: 98.986 	Loss: 0.5147
#  Client6 Train => Local Epoch: 2 	Acc: 99.335 	Loss: 0.5031
#  Client6 Train => Local Epoch: 3 	Acc: 99.215 	Loss: 0.5073
#  Client6 Train => Local Epoch: 4 	Acc: 99.399 	Loss: 0.5015
#  Client6 Test =>                   	Acc: 48.192 	Loss: 2.4284
#  Client3 Train => Local Epoch: 0 	Acc: 96.536 	Loss: 0.6629
#  Client3 Train => Local Epoch: 1 	Acc: 94.193 	Loss: 0.7483
#  Client3 Train => Local Epoch: 2 	Acc: 92.005 	Loss: 0.7425
#  Client3 Train => Local Epoch: 3 	Acc: 91.042 	Loss: 0.8005
#  Client3 Train => Local Epoch: 4 	Acc: 88.021 	Loss: 0.9074
#  Client3 Test =>                   	Acc: 50.273 	Loss: 2.2616
#  Client4 Train => Local Epoch: 0 	Acc: 97.727 	Loss: 0.5780
#  Client4 Train => Local Epoch: 1 	Acc: 98.903 	Loss: 0.5230
#  Client4 Train => Local Epoch: 2 	Acc: 98.869 	Loss: 0.5187
#  Client4 Train => Local Epoch: 3 	Acc: 98.823 	Loss: 0.5218
#  Client4 Train => Local Epoch: 4 	Acc: 99.066 	Loss: 0.5159
#  Client4 Test =>                   	Acc: 43.151 	Loss: 2.5963
#  Client8 Train => Local Epoch: 0 	Acc: 98.482 	Loss: 0.5589
#  Client8 Train => Local Epoch: 1 	Acc: 99.029 	Loss: 0.5266
#  Client8 Train => Local Epoch: 2 	Acc: 98.914 	Loss: 0.5260
#  Client8 Train => Local Epoch: 3 	Acc: 98.992 	Loss: 0.5204
#  Client8 Train => Local Epoch: 4 	Acc: 99.275 	Loss: 0.5171
#  Client8 Test =>                   	Acc: 41.342 	Loss: 2.6072
#  Client1 Train => Local Epoch: 0 	Acc: 98.314 	Loss: 0.5710
#  Client1 Train => Local Epoch: 1 	Acc: 99.022 	Loss: 0.5196
#  Client1 Train => Local Epoch: 2 	Acc: 99.304 	Loss: 0.5129
#  Client1 Train => Local Epoch: 3 	Acc: 99.632 	Loss: 0.5025
#  Client1 Train => Local Epoch: 4 	Acc: 99.235 	Loss: 0.5061
#  Client1 Test =>                   	Acc: 45.808 	Loss: 2.4311
#  Client2 Train => Local Epoch: 0 	Acc: 96.835 	Loss: 0.6346
#  Client2 Train => Local Epoch: 1 	Acc: 98.884 	Loss: 0.5240
#  Client2 Train => Local Epoch: 2 	Acc: 98.988 	Loss: 0.5263
#  Client2 Train => Local Epoch: 3 	Acc: 99.350 	Loss: 0.5114
#  Client2 Train => Local Epoch: 4 	Acc: 99.498 	Loss: 0.5026
#  Client2 Test =>                   	Acc: 49.273 	Loss: 2.3042
#  Client0 Train => Local Epoch: 0 	Acc: 96.845 	Loss: 0.6088
#  Client0 Train => Local Epoch: 1 	Acc: 99.012 	Loss: 0.5256
#  Client0 Train => Local Epoch: 2 	Acc: 98.893 	Loss: 0.5202
#  Client0 Train => Local Epoch: 3 	Acc: 99.100 	Loss: 0.5168
#  Client0 Train => Local Epoch: 4 	Acc: 99.039 	Loss: 0.5124
#  Client0 Test =>                   	Acc: 49.872 	Loss: 2.3337
#  Client5 Train => Local Epoch: 0 	Acc: 97.673 	Loss: 0.5934
#  Client5 Train => Local Epoch: 1 	Acc: 99.217 	Loss: 0.5204
#  Client5 Train => Local Epoch: 2 	Acc: 99.148 	Loss: 0.5172
#  Client5 Train => Local Epoch: 3 	Acc: 99.063 	Loss: 0.5179
#  Client5 Train => Local Epoch: 4 	Acc: 99.412 	Loss: 0.5078
#  Client5 Test =>                   	Acc: 45.572 	Loss: 2.4153
#  Client7 Train => Local Epoch: 0 	Acc: 98.394 	Loss: 0.5808
#  Client7 Train => Local Epoch: 1 	Acc: 98.608 	Loss: 0.5287
#  Client7 Train => Local Epoch: 2 	Acc: 98.890 	Loss: 0.5199
#  Client7 Train => Local Epoch: 3 	Acc: 98.847 	Loss: 0.5262
#  Client7 Train => Local Epoch: 4 	Acc: 99.045 	Loss: 0.5248
#  Client7 Test =>                   	Acc: 51.839 	Loss: 2.1349
# ====================== SERVER V1==========================
#  Train: Round  99, Avg Accuracy 98.109 | Avg Loss 0.551
#  Test: Round  99, Avg Accuracy 47.282 | Avg Loss 2.398
# Forgetting : Round 99, mean_forgetting : -1.044
# ==========================================================
# Training and Evaluation completed!
# Saved: SFLV2 + Projected - CIFAR-100 α=0.1 - Mid Cut.csv
