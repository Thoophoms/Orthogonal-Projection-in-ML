# %% [markdown]
# # Federated Orthogonal Training (FOT)
# ### ResNet18 on CIFAR-10 (Dirichlet α = 0.1)

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Federated (optionally Orthogonal) Training on CIFAR-10 with ResNet-18.

Settings:
    - NUM_CLIENTS = 5
    - Dirichlet non-IID with ALPHA = 0.1
    - EPOCHS (global rounds) = 200
    - LOCAL_EPOCHS = 5
    - WARMUP_ROUNDS = 10 (for orthogonal/FOT)
    - ORTH = True: FOT-style update projection
    - ORTH = False: plain FedAvg

Logs per round:
    - acc_train (global on union of all client train data)
    - acc_test
    - round_time_sec
    - mean_FgT_loss (window-based forgetting)
"""

import math
import random
import time
from copy import deepcopy

import numpy as np
import pandas as pd
import torch
from torch import nn
from torch.utils.data import DataLoader, Subset
from torchvision import datasets, transforms, models

# ============================= Parameters ============================== #

PROGRAM_NAME = "FOT - CIFAR-10 α=0.1"
DATASET_NAME = "CIFAR10"
DATA_ROOT = "data"

EPOCHS = 200                # Global communication rounds
LOCAL_EPOCHS = 5            # Local SGD epochs per client per round
NUM_CLIENTS = 10
FRAC = 1.0                  # Fraction of clients per round
ALPHA = 0.1                 # Dirichlet non-IID concentration

# --------------------------- Optimization ----------------------------- #

BATCH_SIZE = 256
LR_BASE = 0.001
MOMENTUM = 0.9
WEIGHT_DECAY = 5e-4
LABEL_SMOOTH = 0.0          # 0.0 → standard CE
NUM_WORKERS = 4
SEED = 1234

# Turn off cosine. Only use constant LR 
cosine_schedule = False
if cosine_schedule:
    SCHEDULER = "cosine"               # Making it the same shape across runs
else:
    print(f"Using constant LR = {LR_BASE} (cosine_schedule={cosine_schedule})")


# ---------------------------- Orthogonal ------------------------------ #

ORTH = True                 # True → FOT-style projection, False → plain FedAvg
TOP_R = 8                   # Max basis rank per layer
WARMUP_ROUNDS = 10           # No projection during warmup; only build basis
REBUILD_EVERY = 0           # For logging only (kept to match your CSV schema)

# ---------------------------- Forgetting ------------------------------ #

NUM_FGT_WINDOWS = 5         # Number of windows over test set for forgetting


# ============================================================================
#                         Colored terminal output
# ============================================================================
# To print in color -------test/train of the client side

# After printing color it has to reset back to default text color
#RESET = '\033[0m'
BRIGHT_YELLOW = '\033[93m'
RESET = '\033[0m'
RED = '\033[31m'
GREEN = '\033[32m'
BLUE = '\033[34m'
MAGENTA = '\033[35m'
CYAN = '\033[36m'

def prRed(skk): 
    print("\033[91m {}\033[00m" .format(skk)) 
def prGreen(skk): 
    print("\033[92m {}\033[00m" .format(skk))   
def prMAGENTA(skk):
    print("\033[35m {}\033[00m" .format(skk)) 
def prYellow(skk):
    print("\033[93m {}\033[00m" .format(skk))   

    
# ====================================================================== #
#                         Utility / Setup
# ====================================================================== #

def set_seed(seed: int):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False


def get_device():
    return torch.device("cuda" if torch.cuda.is_available() else "cpu")


# ============================================================================
#                           Data & Transforms
#               Setting mean/std between CIFAR-10 & CIFAR-100
#    Normallizing inpits accelerates convergence and stabilizes training
# ============================================================================
CIFAR_MEAN = {
    "CIFAR10":  [0.4914, 0.4822, 0.4465],
    "CIFAR100": [0.5071, 0.4867, 0.4408],
}[DATASET_NAME]
CIFAR_STD = {
    "CIFAR10":  [0.2470, 0.2435, 0.2616],
    "CIFAR100": [0.2675, 0.2565, 0.2761],
}[DATASET_NAME]


# ====================================================================== #
#                    CIFAR-10 Dirichlet Partition
# ====================================================================== #

def dirichlet_partition(
    targets: np.ndarray,
    num_clients: int,
    alpha: float
):
    """
    Returns a list of index lists: indices_per_client[i] are the sample indices
    owned by client i, using a Dirichlet(alpha) distribution over clients
    for each class.
    """
    num_classes = int(targets.max()) + 1
    indices_per_client = [[] for _ in range(num_clients)]
    all_indices = np.arange(len(targets))

    for c in range(num_classes):
        class_idx = all_indices[targets == c]
        np.random.shuffle(class_idx)

        # Dirichlet over clients for this class
        proportions = np.random.dirichlet(alpha * np.ones(num_clients))
        proportions = (np.cumsum(proportions) * len(class_idx)).astype(int)
        splits = np.split(class_idx, proportions[:-1])

        for client_id, split in enumerate(splits):
            indices_per_client[client_id].extend(split.tolist())

    for cid in range(num_clients):
        np.random.shuffle(indices_per_client[cid])

    return indices_per_client


def build_dataloaders_cifar10_dirichlet(
    num_clients: int,
    alpha: float,
    batch_size: int,
    num_workers: int
):
    """
    Download CIFAR-10, create non-IID Dirichlet splits, return:
        - client_train_loaders: list[DataLoader]
        - test_loader: DataLoader
        - num_samples_per_client: list[int]
    """
    transform_train = transforms.Compose([
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize(CIFAR_MEAN, CIFAR_STD),
    ])

    transform_test = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize(CIFAR_MEAN, CIFAR_STD),
    ])

    # ============================================================================
    #                               DataLoders
    # ============================================================================
    # Download CIFAR datasets
    if DATASET_NAME == "CIFAR10":
        train_dataset = datasets.CIFAR10(root=DATA_ROOT, train=True,  download=True, transform=transform_train)
        test_dataset  = datasets.CIFAR10(root=DATA_ROOT, train=False, download=True, transform=transform_test)
        NUM_CLASSES = 10
    else:
        train_dataset = datasets.CIFAR100(root=DATA_ROOT, train=True,  download=True, transform=transform_train)
        test_dataset  = datasets.CIFAR100(root=DATA_ROOT, train=False, download=True, transform=transform_test)
        NUM_CLASSES = 100



    targets = np.array(train_dataset.targets)
    indices_per_client = dirichlet_partition(targets, num_clients, alpha)

    client_loaders = []
    num_samples_per_client = []
    for cid in range(num_clients):
        subset = Subset(train_dataset, indices_per_client[cid])
        loader = DataLoader(
            subset,
            batch_size=BATCH_SIZE,
            shuffle=True,
            num_workers=NUM_WORKERS,
            pin_memory=True,
        )
        client_loaders.append(loader)
        num_samples_per_client.append(len(subset))

    test_loader = DataLoader(
        test_dataset,
        batch_size=BATCH_SIZE,
        shuffle=False,
        num_workers=NUM_WORKERS,
        pin_memory=True,
    )

    return client_loaders, test_loader, num_samples_per_client


# ====================================================================== #
#                             Model
# ====================================================================== #

def get_resnet18_cifar10():
    """
    Standard ResNet-18 for CIFAR-10 using torchvision's ImageNet variant.
    We just override the final FC layer to 10 classes.
    """
    model = models.resnet18(weights=None)
    if DATASET_NAME == "CIFAR10":
        model.fc = nn.Linear(model.fc.in_features, 10)
    else:
        model.fc = nn.Linear(model.fc.in_features, 100)
    return model


# ====================================================================== #
#                      Orthogonal Subspace Utilities
# ====================================================================== #

def init_orth_basis(model: nn.Module):
    """
    Create a map: param_name -> basis matrix (or None)

    We track only trainable parameters with dim > 1:
    (weights, BN weights, etc.; biases and running stats are ignored).
    """
    basis = {}
    for name, p in model.named_parameters():
        if p.requires_grad and p.dim() > 1:
            basis[name] = None
    return basis


def update_basis_from_delta(
    basis_map: dict,
    delta_state: dict,
    model: nn.Module,
    top_r: int,
    device: torch.device,
    eps: float = 1e-8,
):
    """
    Warm-up phase: update orth basis O_ℓ per layer using global update δ_ℓ.

    For each tracked param:
        - Orthogonalize new direction against existing basis (Gram–Schmidt)
        - Add direction up to TOP_R
    """
    with torch.no_grad():
        for name, p in model.named_parameters():
            if not (p.requires_grad and p.dim() > 1):
                continue
            if name not in delta_state:
                continue

            delta = delta_state[name].detach().to("cpu")
            v = delta.view(-1)

            if v.norm() < eps:
                continue

            B = basis_map[name]
            
            if B is None:
                v_norm = v / (v.norm() + eps)
                basis_map[name] = v_norm.view(-1, 1)  # stored on CPU
                continue

            B = B.to("cpu")

            proj_coeffs = B.t().matmul(v)   # (k)
            proj = B.matmul(proj_coeffs)    # (d)
            v_perp = v - proj


            
            if v_perp.norm() < eps:
                continue

            v_perp = v_perp / (v_perp.norm() + eps)

            
            new_basis = torch.cat([B, v_perp.view(-1, 1)], dim=1)
            if new_basis.size(1) > top_r:
                new_basis = new_basis[:, 1:]  # drop oldest

            
            q, _ = torch.linalg.qr(new_basis, mode="reduced")
            basis_map[name] = q


def project_delta_with_basis(
    delta_state: dict,
    basis_map: dict,
    model: nn.Module,
    device: torch.device,
    eps: float = 1e-8,
):
    """
    For each tracked param, project δ_ℓ onto orthogonal complement of O_ℓ:

        δ_ℓ^⊥ = (I - O_ℓ O_ℓ^T) δ_ℓ

    Returns a new state dict of projected deltas.
    """
    projected = {}
    with torch.no_grad():
        # Clones - Keep original device for non-FOT tensors
        for key, tensor in delta_state.items():
            projected[key] = tensor.clone()

        for name, p in model.named_parameters():
            if not (p.requires_grad and p.dim() > 1):
                continue
            if name not in delta_state:
                continue

                
            B = basis_map.get(name, None)
            if B is None:
                continue

            # delta is whatever device it's currently on (either GPU or CPU)
            delta = delta_state[name]
            org_device = delta.device


            # Move to CPU for projection
            v = delta.detach().to("cpu").view(-1)
            B_cpu = B.to("cpu")

            if v.norm() < eps:
                continue

            coeffs = B_cpu.t().matmul(v)        # (k)
            proj = B_cpu.matmul(coeffs)         # (d)
            v_perp = v - proj                   # orthogonal component

            v_perp = v_perp.view_as(delta.cpu())

            # Move back to original device to stay with the rest of state
            projected[name] = v_perp.to(org_device)

    return projected


# ====================================================================== #
#                       Local Client Training
# ====================================================================== #

def get_cosine_lr(base_lr: float, cur_round: int, total_rounds: int):
    if SCHEDULER.lower() != "cosine":
        return base_lr
    if total_rounds <= 0:
        return base_lr
    return base_lr * 0.5 * (1.0 + math.cos(math.pi * cur_round / total_rounds))


def make_criterion():
    if LABEL_SMOOTH > 0.0:
        return nn.CrossEntropyLoss(label_smoothing=LABEL_SMOOTH)
    return nn.CrossEntropyLoss()


def local_train(
    model: nn.Module,
    train_loader: DataLoader,
    device: torch.device,
    lr: float,
    local_epochs: int,
    momentum=MOMENTUM, 
    weight_decay=WEIGHT_DECAY,
    client_id=None
):
    """
    One client's local SGD. Returns the updated model (in-place) and
    the number of training samples.
    """
    model.to(device)
    model.train()

    criterion = make_criterion().to(device)
    optimizer = torch.optim.SGD(
        model.parameters(),
        lr=lr,
        momentum=MOMENTUM,
        weight_decay=WEIGHT_DECAY,
    )

    total_loss, total_cnt, correct = 0.0, 0, 0

    num_samples = 0
    for ep in range(LOCAL_EPOCHS):
        # per-local-epoch accumulators
        ep_loss, ep_cnt, ep_correct = 0.0, 0, 0
        
        for x, y in train_loader:
            x = x.to(device, non_blocking=True)
            y = y.to(device, non_blocking=True)

            optimizer.zero_grad()
            logits = model(x)
            loss = criterion(logits, y)
            loss.backward()
            optimizer.step()

            num_samples += x.size(0)

            bs = y.size(0)
            total_loss += loss.item() * bs
            total_cnt  += bs
            correct    += (logits.argmax(1) == y).sum().item()

            ep_loss    += loss.item() * bs
            ep_cnt     += bs
            ep_correct += (logits.argmax(1) == y).sum().item()

        acc_avg_train  = 100.0 * ep_correct / max(1, ep_cnt)
        loss_avg_train = ep_loss / max(1, ep_cnt)
        
        
        prRed(" Client{} Train => Local Epoch: {} \tAcc: {:.3f} \tLoss: {:.4f}".format(
            (client_id if client_id is not None else "?"), ep, acc_avg_train, loss_avg_train
        ))

        
    return model, num_samples


# ====================================================================== #
#                        FedAvg Aggregation
# ====================================================================== #

def fedavg_aggregate(
    global_state: dict,
    local_states: list,
    sample_counts: list,
    device: torch.device,
):
    """
    Standard FedAvg: weighted average of local models by number of samples.

    We only average *floating-point* tensors (parameters/buffers).
    Non-floating tensors (like num_batches_tracked) are copied from the
    global_state and their delta is set to zero.
    """
    assert len(local_states) == len(sample_counts)
    total_samples = float(sum(sample_counts))

    new_state = {}

    # Initialize new_state: floats -> zeros, others -> copy global
    for key, g_tensor in global_state.items():
        if g_tensor.dtype.is_floating_point:
            new_state[key] = torch.zeros_like(g_tensor, device=device)
        else:
            new_state[key] = g_tensor.to(device)

    # Weighted aggregation for floats only
    for state, n_i in zip(local_states, sample_counts):
        w = n_i / total_samples
        for key, local_tensor in state.items():
            g_tensor = global_state[key]
            if not g_tensor.dtype.is_floating_point:
                continue
            new_state[key] += local_tensor.to(device) * w

    # Compute delta only for floats; others set to zero
    delta_state = {}
    for key, g_tensor in global_state.items():
        if g_tensor.dtype.is_floating_point:
            delta_state[key] = new_state[key] - g_tensor.to(device)
        else:
            delta_state[key] = torch.zeros_like(g_tensor, device=device)

    return new_state, delta_state


# ====================================================================== #
#                           Evaluation
# ====================================================================== #

def evaluate(model: nn.Module, test_loader: DataLoader, device: torch.device):
    model.to(device)
    model.eval()
    correct = 0
    total = 0
    loss_sum = 0.0
    criterion = nn.CrossEntropyLoss().to(device)

    with torch.no_grad():
        for x, y in test_loader:
            x = x.to(device, non_blocking=True)
            y = y.to(device, non_blocking=True)
            logits = model(x)
            loss = criterion(logits, y)
            loss_sum += loss.item() * x.size(0)
            preds = logits.argmax(dim=1)
            correct += (preds == y).sum().item()
            total += x.size(0)

    acc = correct / total * 100.0
    loss_mean = loss_sum / total
    
    return acc, loss_mean


def evaluate_train_global(model: nn.Module, client_loaders, device: torch.device):
    """
    Evaluate global model on union of all client training data.
    Returns (acc_percent, mean_loss).
    """
    model.to(device)
    model.eval()
    correct = 0
    total = 0
    loss_sum = 0.0
    criterion = nn.CrossEntropyLoss().to(device)

    with torch.no_grad():
        for loader in client_loaders:
            for x, y in loader:
                x = x.to(device, non_blocking=True)
                y = y.to(device, non_blocking=True)
                logits = model(x)
                loss = criterion(logits, y)
                loss_sum += loss.item() * x.size(0)

                preds = logits.argmax(dim=1)
                correct += (preds == y).sum().item()
                total += x.size(0)

    acc = correct / total * 100.0
    mean_loss = loss_sum / total
    return acc, mean_loss


def make_fgt_windows(test_loader, num_windows: int):
    """
    Split the test dataset into num_windows contiguous windows and return
    a list of DataLoaders (one per window).
    """
    test_dataset = test_loader.dataset
    N = len(test_dataset)
    indices = np.arange(N)
    windows = np.array_split(indices, num_windows)

    window_loaders = []
    for w_idx in windows:
        subset = Subset(test_dataset, w_idx.tolist())
        loader = DataLoader(
            subset,
            batch_size=BATCH_SIZE,
            shuffle=False,
            num_workers=NUM_WORKERS,
            pin_memory=True,
        )
        window_loaders.append(loader)
    return window_loaders


def eval_loss_on_window(model: nn.Module, loader: DataLoader, device: torch.device):
    """
    Mean CE loss on a single window (DataLoader).
    """
    model.to(device)
    model.eval()
    ce = nn.CrossEntropyLoss(reduction="sum").to(device)
    total = 0
    loss_sum = 0.0

    with torch.no_grad():
        for x, y in loader:
            x = x.to(device, non_blocking=True)
            y = y.to(device, non_blocking=True)
            logits = model(x)
            loss = ce(logits, y)
            loss_sum += loss.item()
            total += x.size(0)

    if total == 0:
        return 0.0
    return loss_sum / total


# ====================================================================== #
#                               Main
# ====================================================================== #
set_seed(SEED)
device = get_device()
print(f"Using device: {device}")

print("Preparing CIFAR-10 loaders (Dirichlet non-IID, alpha = {:.3f})...".format(ALPHA))
client_loaders, test_loader, num_samples_per_client = build_dataloaders_cifar10_dirichlet(
    NUM_CLIENTS, ALPHA, BATCH_SIZE, NUM_WORKERS
)
print("Client sample counts:", num_samples_per_client)

# Create forgetting windows over the test set
fgt_window_loaders = make_fgt_windows(test_loader, NUM_FGT_WINDOWS)
# Historical best loss per window (initialized to +inf)
best_loss_per_window = [float("inf")] * NUM_FGT_WINDOWS

print("Building ResNet-18 model...")
global_model = get_resnet18_cifar10().to(device)
global_state = deepcopy(global_model.state_dict())

# Orthogonal basis map
orth_basis = init_orth_basis(global_model)

# ---------------------- History logs ---------------------- #
acc_train_hist = []
acc_test_hist = []
round_time_hist = []
mean_fgt_hist = []      # window-based forgetting per round

num_clients_per_round = max(1, int(FRAC * NUM_CLIENTS))
print(f"Clients per round: {num_clients_per_round} / {NUM_CLIENTS}")
print(f"EPOCHS (global rounds): {EPOCHS}, LOCAL_EPOCHS: {LOCAL_EPOCHS}")
print(f"ORTH = {ORTH}, TOP_R = {TOP_R}, WARMUP_ROUNDS = {WARMUP_ROUNDS}")
print(f"NUM_FGT_WINDOWS = {NUM_FGT_WINDOWS}")
print("-" * 80)

for rnd in range(EPOCHS):
    round_start = time.time()

    if cosine_schedule:
        lr = get_cosine_lr(LR_BASE, rnd, EPOCHS - 1)
    else:
        lr = LR_BASE
    
    print(f"\n=== Round {rnd+1}/{EPOCHS} | LR = {lr:.4f} ===")
    m = max(1, int(np.ceil(FRAC * NUM_CLIENTS)))
    selected = np.random.choice(NUM_CLIENTS, m, replace=False)

    # # Sample clients (FRAC=1.0 → all, but kept general)
    # all_client_ids = list(range(NUM_CLIENTS))
    # random.shuffle(all_client_ids)
    # selected = all_client_ids[:num_clients_per_round]
    # print(f"Selected clients: {selected}")

    local_states = []
    sample_counts = []
    

    # Local training
    for cid in selected:
        prGreen(f" Client {cid}")
        client_model = deepcopy(global_model)
        client_loader = client_loaders[cid]
        client_model, n_i = local_train(
            client_model,
            client_loader,
            device,
            lr,
            LOCAL_EPOCHS,
            MOMENTUM,
            WEIGHT_DECAY,
            int(cid)
        )
        local_states.append(deepcopy(client_model.state_dict()))
        sample_counts.append(n_i)


    # FedAvg aggregation
    new_state, delta_state = fedavg_aggregate(
        global_state,
        local_states,
        sample_counts,
        device,
    )

    # FOT-style orthogonal processing of the global update
    if ORTH:
        if rnd < WARMUP_ROUNDS:
            print("Warm-up phase: updating orth basis (no projection yet).")
            update_basis_from_delta(
                orth_basis,
                delta_state,
                global_model,
                top_r=TOP_R,
                device=device,
            )
            effective_delta = delta_state
        else:
            print("FOT phase: projecting global update onto orthogonal complement.")
            projected_delta = project_delta_with_basis(
                delta_state,
                orth_basis,
                global_model,
                device=device,
            )
            effective_delta = projected_delta
            for key in new_state.keys():
                new_state[key] = global_state[key].to(device) + effective_delta[key]
    else:
        effective_delta = delta_state
    

    # Update global model
    global_state = {k: v.clone().detach() for k, v in new_state.items()}
    global_model.load_state_dict(global_state)

    # ----------------- Evaluate on train & test ----------------- #
    train_acc, train_loss = evaluate_train_global(global_model, client_loaders, device)
    acc_train_hist.append(train_acc)

    test_acc, test_loss = evaluate(global_model, test_loader, device)
    acc_test_hist.append(test_acc)

    round_time = time.time() - round_start
    round_time_hist.append(round_time)

    
    # ----------------- Window-based forgetting (signed) ----------------- #
    # Implements the definition from your slide:
    #   FgT_t^(τ) = L_now - best_loss_per_window[τ]
    #   negative  => improvement
    #   positive  => forgetting
    fgt_list = []

    for w_idx, loader_w in enumerate(fgt_window_loaders):
        L_cur = eval_loss_on_window(global_model, loader_w, device)
        if not math.isfinite(L_cur):
            continue

        # First time we see this window: initialize baseline, no forgetting yet
        if best_loss_per_window[w_idx] == float("inf"):
            best_loss_per_window[w_idx] = L_cur
            fgt = 0.0
        else:
            # FgT_t^(τ) = L_now - best_loss_per_window[τ]
            fgt = L_cur - best_loss_per_window[w_idx]

            # Update historical best if we just improved
            if L_cur < best_loss_per_window[w_idx]:
                best_loss_per_window[w_idx] = L_cur

        fgt_list.append(fgt)

    # Per-round mean forgetting over all windows
    mean_fgt = float(np.mean(fgt_list)) if len(fgt_list) > 0 else 0.0
    mean_fgt_hist.append(mean_fgt)


    print(
        f"Round {rnd+1:02d}: "
        f"Train Acc = {train_acc:.2f}% | "
        f"Test Acc = {test_acc:.2f}% | "
        f"Test Loss = {test_loss:.4f} | "
        f"Mean FgT = {mean_fgt:.4f} | "
        f"Time = {round_time:.2f}s"
    )

print("\nTraining finished.")
final_acc, final_loss = evaluate(global_model, test_loader, device)
print(f"Final Test Accuracy: {final_acc:.2f}% | Loss: {final_loss:.4f}")

# =================================================================
#                              Save logs
# =================================================================
n = min(
    len(acc_train_hist),
    len(acc_test_hist),
    len(round_time_hist),
    len(mean_fgt_hist),
)
round_idx = list(range(1, n + 1))

df = pd.DataFrame({
    "round":          round_idx,
    "acc_train":      acc_train_hist[:n],
    "acc_test":       acc_test_hist[:n],
    "round_time_sec": round_time_hist[:n],
    "mean_FgT_loss":  mean_fgt_hist[:n],
    "projection":     [ORTH] * n,
    "alpha":          [ALPHA] * n,
    "warmup_rounds":  [WARMUP_ROUNDS] * n,
    "rebuild_every":  [REBUILD_EVERY] * n,
    "top_r":          [TOP_R] * n,
})

csv_name = f"{PROGRAM_NAME}.csv"
df.to_csv(csv_name, index=False)
print("Saved:", csv_name)
# Out:
# Using constant LR = 0.01 (cosine_schedule=False)
# Using device: cuda
# Preparing CIFAR-10 loaders (Dirichlet non-IID, alpha = 0.100)...
# Client sample counts: [10189, 3792, 1379, 963, 4550, 10060, 1627, 2506, 9203, 5731]
# Building ResNet-18 model...
# Clients per round: 10 / 10
# EPOCHS (global rounds): 100, LOCAL_EPOCHS: 5
# ORTH = True, TOP_R = 8, WARMUP_ROUNDS = 5
# NUM_FGT_WINDOWS = 5
# --------------------------------------------------------------------------------
#
# === Round 1/100 | LR = 0.0100 ===
#   Client 5
#   Client5 Train => Local Epoch: 0 	Acc: 64.374 	Loss: 0.9588
#   Client5 Train => Local Epoch: 1 	Acc: 73.827 	Loss: 0.6537
#   Client5 Train => Local Epoch: 2 	Acc: 77.396 	Loss: 0.5700
#   Client5 Train => Local Epoch: 3 	Acc: 79.344 	Loss: 0.5333
#   Client5 Train => Local Epoch: 4 	Acc: 80.089 	Loss: 0.5148
#   Client 7
#   Client7 Train => Local Epoch: 0 	Acc: 58.340 	Loss: 1.4978
#   Client7 Train => Local Epoch: 1 	Acc: 68.795 	Loss: 0.9094
#   Client7 Train => Local Epoch: 2 	Acc: 74.222 	Loss: 0.7352
#   Client7 Train => Local Epoch: 3 	Acc: 75.379 	Loss: 0.6528
#   Client7 Train => Local Epoch: 4 	Acc: 77.574 	Loss: 0.5902
#   Client 4
#   Client4 Train => Local Epoch: 0 	Acc: 72.198 	Loss: 0.9156
#   Client4 Train => Local Epoch: 1 	Acc: 77.934 	Loss: 0.6181
#   Client4 Train => Local Epoch: 2 	Acc: 78.945 	Loss: 0.5314
#   Client4 Train => Local Epoch: 3 	Acc: 80.945 	Loss: 0.4832
#   Client4 Train => Local Epoch: 4 	Acc: 81.363 	Loss: 0.4639
#   Client 0
#   Client0 Train => Local Epoch: 0 	Acc: 62.734 	Loss: 1.0206
#   Client0 Train => Local Epoch: 1 	Acc: 76.288 	Loss: 0.6739
#   Client0 Train => Local Epoch: 2 	Acc: 80.047 	Loss: 0.5656
#   Client0 Train => Local Epoch: 3 	Acc: 80.459 	Loss: 0.5322
#   Client0 Train => Local Epoch: 4 	Acc: 82.000 	Loss: 0.4882
#   Client 1
#   Client1 Train => Local Epoch: 0 	Acc: 37.131 	Loss: 1.5200
#   Client1 Train => Local Epoch: 1 	Acc: 47.073 	Loss: 1.2153
#   Client1 Train => Local Epoch: 2 	Acc: 49.921 	Loss: 1.1589
#   Client1 Train => Local Epoch: 3 	Acc: 54.299 	Loss: 1.0429
#   Client1 Train => Local Epoch: 4 	Acc: 57.147 	Loss: 1.0003
#   Client 6
#   Client6 Train => Local Epoch: 0 	Acc: 59.312 	Loss: 1.3450
#   Client6 Train => Local Epoch: 1 	Acc: 71.789 	Loss: 0.8851
#   Client6 Train => Local Epoch: 2 	Acc: 76.460 	Loss: 0.6837
#   Client6 Train => Local Epoch: 3 	Acc: 80.824 	Loss: 0.5739
#   Client6 Train => Local Epoch: 4 	Acc: 83.712 	Loss: 0.5045
#   Client 3
#   Client3 Train => Local Epoch: 0 	Acc: 36.760 	Loss: 1.7463
#   Client3 Train => Local Epoch: 1 	Acc: 58.359 	Loss: 1.1695
#   Client3 Train => Local Epoch: 2 	Acc: 62.513 	Loss: 1.1311
#   Client3 Train => Local Epoch: 3 	Acc: 62.617 	Loss: 1.0189
#   Client3 Train => Local Epoch: 4 	Acc: 65.213 	Loss: 0.9071
#   Client 9
#   Client9 Train => Local Epoch: 0 	Acc: 76.758 	Loss: 0.7710
#   Client9 Train => Local Epoch: 1 	Acc: 86.617 	Loss: 0.4720
#   Client9 Train => Local Epoch: 2 	Acc: 89.915 	Loss: 0.3454
#   Client9 Train => Local Epoch: 3 	Acc: 90.508 	Loss: 0.3136
#   Client9 Train => Local Epoch: 4 	Acc: 91.276 	Loss: 0.2716
#   Client 8
#   Client8 Train => Local Epoch: 0 	Acc: 42.617 	Loss: 1.4338
#   Client8 Train => Local Epoch: 1 	Acc: 47.463 	Loss: 1.2596
#   Client8 Train => Local Epoch: 2 	Acc: 51.070 	Loss: 1.1782
#   Client8 Train => Local Epoch: 3 	Acc: 52.950 	Loss: 1.1309
#   Client8 Train => Local Epoch: 4 	Acc: 55.428 	Loss: 1.0966
#   Client 2
#   Client2 Train => Local Epoch: 0 	Acc: 75.997 	Loss: 1.1502
#   Client2 Train => Local Epoch: 1 	Acc: 92.458 	Loss: 1.0007
#   Client2 Train => Local Epoch: 2 	Acc: 90.428 	Loss: 0.5429
#   Client2 Train => Local Epoch: 3 	Acc: 90.935 	Loss: 0.4283
#   Client2 Train => Local Epoch: 4 	Acc: 92.458 	Loss: 0.3605
# Warm-up phase: updating orth basis (no projection yet).
# Round 01: Train Acc = 13.04% | Test Acc = 12.96% | Test Loss = 2.9846 | Mean FgT = 0.0000 | Time = 33.30s
#
# === Round 2/100 | LR = 0.0100 ===
#   Client 9
#   Client9 Train => Local Epoch: 0 	Acc: 79.253 	Loss: 1.0103
#   Client9 Train => Local Epoch: 1 	Acc: 87.664 	Loss: 0.6636
#   Client9 Train => Local Epoch: 2 	Acc: 89.356 	Loss: 0.4627
#   Client9 Train => Local Epoch: 3 	Acc: 90.229 	Loss: 0.3652
#   Client9 Train => Local Epoch: 4 	Acc: 90.717 	Loss: 0.3067
#   Client 1
#   Client1 Train => Local Epoch: 0 	Acc: 39.188 	Loss: 1.9179
#   Client1 Train => Local Epoch: 1 	Acc: 48.365 	Loss: 1.3805
#   Client1 Train => Local Epoch: 2 	Acc: 53.085 	Loss: 1.1693
#   Client1 Train => Local Epoch: 3 	Acc: 55.564 	Loss: 1.0914
#   Client1 Train => Local Epoch: 4 	Acc: 56.382 	Loss: 1.0412
#   Client 5
#   Client5 Train => Local Epoch: 0 	Acc: 67.107 	Loss: 1.0199
#   Client5 Train => Local Epoch: 1 	Acc: 75.437 	Loss: 0.6024
#   Client5 Train => Local Epoch: 2 	Acc: 78.926 	Loss: 0.5255
#   Client5 Train => Local Epoch: 3 	Acc: 80.000 	Loss: 0.5224
#   Client5 Train => Local Epoch: 4 	Acc: 82.465 	Loss: 0.4584
#   Client 6
#   Client6 Train => Local Epoch: 0 	Acc: 54.948 	Loss: 2.3653
#   Client6 Train => Local Epoch: 1 	Acc: 77.873 	Loss: 0.9568
#   Client6 Train => Local Epoch: 2 	Acc: 81.807 	Loss: 0.6304
#   Client6 Train => Local Epoch: 3 	Acc: 82.913 	Loss: 0.4910
#   Client6 Train => Local Epoch: 4 	Acc: 84.696 	Loss: 0.4457
#   Client 7
#   Client7 Train => Local Epoch: 0 	Acc: 63.009 	Loss: 1.1855
#   Client7 Train => Local Epoch: 1 	Acc: 73.344 	Loss: 0.7116
#   Client7 Train => Local Epoch: 2 	Acc: 78.412 	Loss: 0.5851
#   Client7 Train => Local Epoch: 3 	Acc: 78.093 	Loss: 0.5659
#   Client7 Train => Local Epoch: 4 	Acc: 81.085 	Loss: 0.4990
#   Client 0
#   Client0 Train => Local Epoch: 0 	Acc: 68.682 	Loss: 1.1152
#   Client0 Train => Local Epoch: 1 	Acc: 78.516 	Loss: 0.6165
#   Client0 Train => Local Epoch: 2 	Acc: 80.626 	Loss: 0.5475
#   Client0 Train => Local Epoch: 3 	Acc: 81.460 	Loss: 0.5093
#   Client0 Train => Local Epoch: 4 	Acc: 82.177 	Loss: 0.4935
#   Client 2
#   Client2 Train => Local Epoch: 0 	Acc: 87.527 	Loss: 0.7560
#   Client2 Train => Local Epoch: 1 	Acc: 90.645 	Loss: 0.4200
#   Client2 Train => Local Epoch: 2 	Acc: 91.443 	Loss: 0.3202
#   Client2 Train => Local Epoch: 3 	Acc: 92.458 	Loss: 0.3095
#   Client2 Train => Local Epoch: 4 	Acc: 92.821 	Loss: 0.2731
#   Client 8
#   Client8 Train => Local Epoch: 0 	Acc: 42.812 	Loss: 1.6548
#   Client8 Train => Local Epoch: 1 	Acc: 50.701 	Loss: 1.1762
#   Client8 Train => Local Epoch: 2 	Acc: 54.145 	Loss: 1.1047
#   Client8 Train => Local Epoch: 3 	Acc: 56.134 	Loss: 1.0700
#   Client8 Train => Local Epoch: 4 	Acc: 57.938 	Loss: 1.0403
#   Client 3
#   Client3 Train => Local Epoch: 0 	Acc: 34.060 	Loss: 2.6023
#   Client3 Train => Local Epoch: 1 	Acc: 58.152 	Loss: 1.3413
#   Client3 Train => Local Epoch: 2 	Acc: 63.863 	Loss: 1.2121
#   Client3 Train => Local Epoch: 3 	Acc: 63.759 	Loss: 0.9646
#   Client3 Train => Local Epoch: 4 	Acc: 68.328 	Loss: 0.8693
#   Client 4
#   Client4 Train => Local Epoch: 0 	Acc: 67.121 	Loss: 1.3936
#   Client4 Train => Local Epoch: 1 	Acc: 80.022 	Loss: 0.6349
#   Client4 Train => Local Epoch: 2 	Acc: 80.066 	Loss: 0.5269
#   Client4 Train => Local Epoch: 3 	Acc: 81.429 	Loss: 0.4671
#   Client4 Train => Local Epoch: 4 	Acc: 82.813 	Loss: 0.4201
# Warm-up phase: updating orth basis (no projection yet).
# Round 02: Train Acc = 22.34% | Test Acc = 22.11% | Test Loss = 2.2752 | Mean FgT = -0.7094 | Time = 32.83s
#
# === Round 3/100 | LR = 0.0100 ===
#   Client 3
#   Client3 Train => Local Epoch: 0 	Acc: 51.298 	Loss: 1.4495
#   Client3 Train => Local Epoch: 1 	Acc: 69.678 	Loss: 0.9546
#   Client3 Train => Local Epoch: 2 	Acc: 72.482 	Loss: 0.9279
#   Client3 Train => Local Epoch: 3 	Acc: 75.286 	Loss: 0.8159
#   Client3 Train => Local Epoch: 4 	Acc: 76.739 	Loss: 0.6872
#   Client 0
#   Client0 Train => Local Epoch: 0 	Acc: 76.769 	Loss: 0.6812
#   Client0 Train => Local Epoch: 1 	Acc: 80.135 	Loss: 0.5505
#   Client0 Train => Local Epoch: 2 	Acc: 81.460 	Loss: 0.5042
#   Client0 Train => Local Epoch: 3 	Acc: 82.962 	Loss: 0.4620
#   Client0 Train => Local Epoch: 4 	Acc: 82.373 	Loss: 0.4721
#   Client 7
#   Client7 Train => Local Epoch: 0 	Acc: 57.582 	Loss: 1.9956
#   Client7 Train => Local Epoch: 1 	Acc: 73.703 	Loss: 0.8226
#   Client7 Train => Local Epoch: 2 	Acc: 78.571 	Loss: 0.5903
#   Client7 Train => Local Epoch: 3 	Acc: 80.247 	Loss: 0.5284
#   Client7 Train => Local Epoch: 4 	Acc: 81.764 	Loss: 0.4672
#   Client 6
#   Client6 Train => Local Epoch: 0 	Acc: 57.037 	Loss: 1.4487
#   Client6 Train => Local Epoch: 1 	Acc: 84.204 	Loss: 0.7031
#   Client6 Train => Local Epoch: 2 	Acc: 85.003 	Loss: 0.5501
#   Client6 Train => Local Epoch: 3 	Acc: 85.310 	Loss: 0.4840
#   Client6 Train => Local Epoch: 4 	Acc: 87.216 	Loss: 0.3831
#   Client 4
#   Client4 Train => Local Epoch: 0 	Acc: 70.396 	Loss: 1.1363
#   Client4 Train => Local Epoch: 1 	Acc: 79.824 	Loss: 0.5646
#   Client4 Train => Local Epoch: 2 	Acc: 81.473 	Loss: 0.4563
#   Client4 Train => Local Epoch: 3 	Acc: 83.011 	Loss: 0.4169
#   Client4 Train => Local Epoch: 4 	Acc: 85.121 	Loss: 0.3784
#   Client 8
#   Client8 Train => Local Epoch: 0 	Acc: 46.050 	Loss: 1.4689
#   Client8 Train => Local Epoch: 1 	Acc: 53.787 	Loss: 1.1195
#   Client8 Train => Local Epoch: 2 	Acc: 57.047 	Loss: 1.0450
#   Client8 Train => Local Epoch: 3 	Acc: 58.992 	Loss: 1.0204
#   Client8 Train => Local Epoch: 4 	Acc: 61.067 	Loss: 0.9790
#   Client 1
#   Client1 Train => Local Epoch: 0 	Acc: 48.576 	Loss: 1.2714
#   Client1 Train => Local Epoch: 1 	Acc: 55.011 	Loss: 1.0454
#   Client1 Train => Local Epoch: 2 	Acc: 58.782 	Loss: 0.9786
#   Client1 Train => Local Epoch: 3 	Acc: 62.236 	Loss: 0.9158
#   Client1 Train => Local Epoch: 4 	Acc: 61.419 	Loss: 0.9034
#   Client 9
#   Client9 Train => Local Epoch: 0 	Acc: 85.971 	Loss: 0.5681
#   Client9 Train => Local Epoch: 1 	Acc: 90.089 	Loss: 0.3550
#   Client9 Train => Local Epoch: 2 	Acc: 91.276 	Loss: 0.2963
#   Client9 Train => Local Epoch: 3 	Acc: 91.747 	Loss: 0.2637
#   Client9 Train => Local Epoch: 4 	Acc: 92.637 	Loss: 0.2436
#   Client 2
#   Client2 Train => Local Epoch: 0 	Acc: 58.738 	Loss: 2.1735
#   Client2 Train => Local Epoch: 1 	Acc: 92.458 	Loss: 1.0468
#   Client2 Train => Local Epoch: 2 	Acc: 92.458 	Loss: 0.7017
#   Client2 Train => Local Epoch: 3 	Acc: 92.458 	Loss: 0.4301
#   Client2 Train => Local Epoch: 4 	Acc: 90.645 	Loss: 0.3313
#   Client 5
#   Client5 Train => Local Epoch: 0 	Acc: 69.503 	Loss: 0.9606
#   Client5 Train => Local Epoch: 1 	Acc: 79.135 	Loss: 0.5377
#   Client5 Train => Local Epoch: 2 	Acc: 81.392 	Loss: 0.4832
#   Client5 Train => Local Epoch: 3 	Acc: 83.042 	Loss: 0.4373
#   Client5 Train => Local Epoch: 4 	Acc: 84.195 	Loss: 0.4144
# Warm-up phase: updating orth basis (no projection yet).
# Round 03: Train Acc = 15.60% | Test Acc = 16.41% | Test Loss = 2.9124 | Mean FgT = 0.6373 | Time = 33.36s
#
# === Round 4/100 | LR = 0.0100 ===
#   Client 8
#   Client8 Train => Local Epoch: 0 	Acc: 52.831 	Loss: 1.2372
#   Client8 Train => Local Epoch: 1 	Acc: 58.025 	Loss: 1.0546
#   Client8 Train => Local Epoch: 2 	Acc: 60.480 	Loss: 0.9977
#   Client8 Train => Local Epoch: 3 	Acc: 62.132 	Loss: 0.9498
#   Client8 Train => Local Epoch: 4 	Acc: 64.403 	Loss: 0.9234
#   Client 1
#   Client1 Train => Local Epoch: 0 	Acc: 51.951 	Loss: 1.3180
#   Client1 Train => Local Epoch: 1 	Acc: 60.390 	Loss: 1.0633
#   Client1 Train => Local Epoch: 2 	Acc: 62.685 	Loss: 0.9838
#   Client1 Train => Local Epoch: 3 	Acc: 64.742 	Loss: 0.9200
#   Client1 Train => Local Epoch: 4 	Acc: 65.612 	Loss: 0.8907
#   Client 3
#   Client3 Train => Local Epoch: 0 	Acc: 31.049 	Loss: 2.4501
#   Client3 Train => Local Epoch: 1 	Acc: 70.093 	Loss: 0.9658
#   Client3 Train => Local Epoch: 2 	Acc: 72.897 	Loss: 0.9002
#   Client3 Train => Local Epoch: 3 	Acc: 75.701 	Loss: 0.7425
#   Client3 Train => Local Epoch: 4 	Acc: 76.116 	Loss: 0.6528
#   Client 2
#   Client2 Train => Local Epoch: 0 	Acc: 87.310 	Loss: 0.5187
#   Client2 Train => Local Epoch: 1 	Acc: 92.531 	Loss: 0.3263
#   Client2 Train => Local Epoch: 2 	Acc: 91.153 	Loss: 0.2970
#   Client2 Train => Local Epoch: 3 	Acc: 92.748 	Loss: 0.2537
#   Client2 Train => Local Epoch: 4 	Acc: 92.313 	Loss: 0.2364
#   Client 7
#   Client7 Train => Local Epoch: 0 	Acc: 61.652 	Loss: 1.5240
#   Client7 Train => Local Epoch: 1 	Acc: 79.968 	Loss: 0.6053
#   Client7 Train => Local Epoch: 2 	Acc: 81.644 	Loss: 0.5059
#   Client7 Train => Local Epoch: 3 	Acc: 84.757 	Loss: 0.4097
#   Client7 Train => Local Epoch: 4 	Acc: 86.073 	Loss: 0.3937
#   Client 5
#   Client5 Train => Local Epoch: 0 	Acc: 74.066 	Loss: 0.7932
#   Client5 Train => Local Epoch: 1 	Acc: 81.680 	Loss: 0.4780
#   Client5 Train => Local Epoch: 2 	Acc: 83.966 	Loss: 0.4300
#   Client5 Train => Local Epoch: 3 	Acc: 84.980 	Loss: 0.3959
#   Client5 Train => Local Epoch: 4 	Acc: 85.775 	Loss: 0.3784
#   Client 9
#   Client9 Train => Local Epoch: 0 	Acc: 82.342 	Loss: 0.7371
#   Client9 Train => Local Epoch: 1 	Acc: 91.136 	Loss: 0.4150
#   Client9 Train => Local Epoch: 2 	Acc: 91.328 	Loss: 0.3442
#   Client9 Train => Local Epoch: 3 	Acc: 91.398 	Loss: 0.2950
#   Client9 Train => Local Epoch: 4 	Acc: 92.218 	Loss: 0.2678
#   Client 6
#   Client6 Train => Local Epoch: 0 	Acc: 61.340 	Loss: 1.2984
#   Client6 Train => Local Epoch: 1 	Acc: 85.925 	Loss: 0.5614
#   Client6 Train => Local Epoch: 2 	Acc: 87.339 	Loss: 0.4320
#   Client6 Train => Local Epoch: 3 	Acc: 88.937 	Loss: 0.3786
#   Client6 Train => Local Epoch: 4 	Acc: 89.244 	Loss: 0.3341
#   Client 0
#   Client0 Train => Local Epoch: 0 	Acc: 71.901 	Loss: 1.1607
#   Client0 Train => Local Epoch: 1 	Acc: 81.068 	Loss: 0.5575
#   Client0 Train => Local Epoch: 2 	Acc: 82.255 	Loss: 0.4936
#   Client0 Train => Local Epoch: 3 	Acc: 82.933 	Loss: 0.4629
#   Client0 Train => Local Epoch: 4 	Acc: 84.827 	Loss: 0.4282
#   Client 4
#   Client4 Train => Local Epoch: 0 	Acc: 68.088 	Loss: 1.3432
#   Client4 Train => Local Epoch: 1 	Acc: 80.374 	Loss: 0.5335
#   Client4 Train => Local Epoch: 2 	Acc: 82.571 	Loss: 0.4366
#   Client4 Train => Local Epoch: 3 	Acc: 82.725 	Loss: 0.4115
#   Client4 Train => Local Epoch: 4 	Acc: 84.440 	Loss: 0.3845
# Warm-up phase: updating orth basis (no projection yet).
# Round 04: Train Acc = 28.30% | Test Acc = 28.39% | Test Loss = 2.0153 | Mean FgT = -0.2599 | Time = 33.84s
#
# === Round 5/100 | LR = 0.0100 ===
#   Client 2
#   Client2 Train => Local Epoch: 0 	Acc: 46.701 	Loss: 2.5115
#   Client2 Train => Local Epoch: 1 	Acc: 92.458 	Loss: 0.7280
#   Client2 Train => Local Epoch: 2 	Acc: 92.458 	Loss: 0.7319
#   Client2 Train => Local Epoch: 3 	Acc: 92.458 	Loss: 0.4668
#   Client2 Train => Local Epoch: 4 	Acc: 92.458 	Loss: 0.3465
#   Client 7
#   Client7 Train => Local Epoch: 0 	Acc: 58.699 	Loss: 1.3315
#   Client7 Train => Local Epoch: 1 	Acc: 80.646 	Loss: 0.6099
#   Client7 Train => Local Epoch: 2 	Acc: 82.243 	Loss: 0.4862
#   Client7 Train => Local Epoch: 3 	Acc: 85.036 	Loss: 0.4103
#   Client7 Train => Local Epoch: 4 	Acc: 86.911 	Loss: 0.3750
#   Client 5
#   Client5 Train => Local Epoch: 0 	Acc: 76.213 	Loss: 0.7141
#   Client5 Train => Local Epoch: 1 	Acc: 83.549 	Loss: 0.4294
#   Client5 Train => Local Epoch: 2 	Acc: 85.368 	Loss: 0.3867
#   Client5 Train => Local Epoch: 3 	Acc: 86.093 	Loss: 0.3755
#   Client5 Train => Local Epoch: 4 	Acc: 87.783 	Loss: 0.3406
#   Client 6
#   Client6 Train => Local Epoch: 0 	Acc: 59.926 	Loss: 1.3728
#   Client6 Train => Local Epoch: 1 	Acc: 87.707 	Loss: 0.5543
#   Client6 Train => Local Epoch: 2 	Acc: 88.629 	Loss: 0.4594
#   Client6 Train => Local Epoch: 3 	Acc: 88.506 	Loss: 0.3763
#   Client6 Train => Local Epoch: 4 	Acc: 89.183 	Loss: 0.3300
#   Client 0
#   Client0 Train => Local Epoch: 0 	Acc: 79.409 	Loss: 0.6040
#   Client0 Train => Local Epoch: 1 	Acc: 83.443 	Loss: 0.4667
#   Client0 Train => Local Epoch: 2 	Acc: 84.228 	Loss: 0.4277
#   Client0 Train => Local Epoch: 3 	Acc: 84.738 	Loss: 0.4150
#   Client0 Train => Local Epoch: 4 	Acc: 85.494 	Loss: 0.3945
#   Client 9
#   Client9 Train => Local Epoch: 0 	Acc: 86.896 	Loss: 0.4776
#   Client9 Train => Local Epoch: 1 	Acc: 91.502 	Loss: 0.3004
#   Client9 Train => Local Epoch: 2 	Acc: 92.584 	Loss: 0.2368
#   Client9 Train => Local Epoch: 3 	Acc: 93.160 	Loss: 0.2185
#   Client9 Train => Local Epoch: 4 	Acc: 93.509 	Loss: 0.2062
#   Client 4
#   Client4 Train => Local Epoch: 0 	Acc: 71.648 	Loss: 0.9347
#   Client4 Train => Local Epoch: 1 	Acc: 80.593 	Loss: 0.5660
#   Client4 Train => Local Epoch: 2 	Acc: 83.055 	Loss: 0.4184
#   Client4 Train => Local Epoch: 3 	Acc: 84.879 	Loss: 0.3694
#   Client4 Train => Local Epoch: 4 	Acc: 85.758 	Loss: 0.3384
#   Client 1
#   Client1 Train => Local Epoch: 0 	Acc: 54.536 	Loss: 1.1751
#   Client1 Train => Local Epoch: 1 	Acc: 63.107 	Loss: 0.9229
#   Client1 Train => Local Epoch: 2 	Acc: 66.561 	Loss: 0.8341
#   Client1 Train => Local Epoch: 3 	Acc: 68.565 	Loss: 0.7903
#   Client1 Train => Local Epoch: 4 	Acc: 69.225 	Loss: 0.7584
#   Client 3
#   Client3 Train => Local Epoch: 0 	Acc: 56.698 	Loss: 1.3185
#   Client3 Train => Local Epoch: 1 	Acc: 71.547 	Loss: 0.8250
#   Client3 Train => Local Epoch: 2 	Acc: 76.532 	Loss: 0.7332
#   Client3 Train => Local Epoch: 3 	Acc: 78.297 	Loss: 0.6584
#   Client3 Train => Local Epoch: 4 	Acc: 77.985 	Loss: 0.6029
#   Client 8
#   Client8 Train => Local Epoch: 0 	Acc: 52.722 	Loss: 1.3167
#   Client8 Train => Local Epoch: 1 	Acc: 61.523 	Loss: 0.9865
#   Client8 Train => Local Epoch: 2 	Acc: 63.925 	Loss: 0.9312
#   Client8 Train => Local Epoch: 3 	Acc: 64.664 	Loss: 0.9054
#   Client8 Train => Local Epoch: 4 	Acc: 67.098 	Loss: 0.8552
# Warm-up phase: updating orth basis (no projection yet).
# Round 05: Train Acc = 18.87% | Test Acc = 19.51% | Test Loss = 2.2300 | Mean FgT = 0.2147 | Time = 34.69s
#
# === Round 6/100 | LR = 0.0100 ===
#   Client 6
#   Client6 Train => Local Epoch: 0 	Acc: 67.548 	Loss: 1.0357
#   Client6 Train => Local Epoch: 1 	Acc: 87.277 	Loss: 0.4874
#   Client6 Train => Local Epoch: 2 	Acc: 87.769 	Loss: 0.4214
#   Client6 Train => Local Epoch: 3 	Acc: 90.166 	Loss: 0.3034
#   Client6 Train => Local Epoch: 4 	Acc: 91.211 	Loss: 0.2802
#   Client 2
#   Client2 Train => Local Epoch: 0 	Acc: 79.913 	Loss: 0.7511
#   Client2 Train => Local Epoch: 1 	Acc: 92.458 	Loss: 0.4274
#   Client2 Train => Local Epoch: 2 	Acc: 91.661 	Loss: 0.2791
#   Client2 Train => Local Epoch: 3 	Acc: 92.748 	Loss: 0.2440
#   Client2 Train => Local Epoch: 4 	Acc: 92.893 	Loss: 0.2399
#   Client 7
#   Client7 Train => Local Epoch: 0 	Acc: 69.234 	Loss: 0.9845
#   Client7 Train => Local Epoch: 1 	Acc: 84.278 	Loss: 0.4848
#   Client7 Train => Local Epoch: 2 	Acc: 86.512 	Loss: 0.4037
#   Client7 Train => Local Epoch: 3 	Acc: 88.707 	Loss: 0.3336
#   Client7 Train => Local Epoch: 4 	Acc: 88.907 	Loss: 0.3151
#   Client 0
#   Client0 Train => Local Epoch: 0 	Acc: 76.926 	Loss: 0.7462
#   Client0 Train => Local Epoch: 1 	Acc: 83.678 	Loss: 0.4473
#   Client0 Train => Local Epoch: 2 	Acc: 85.278 	Loss: 0.4175
#   Client0 Train => Local Epoch: 3 	Acc: 85.494 	Loss: 0.3995
#   Client0 Train => Local Epoch: 4 	Acc: 85.867 	Loss: 0.3735
#   Client 3
#   Client3 Train => Local Epoch: 0 	Acc: 28.453 	Loss: 2.1628
#   Client3 Train => Local Epoch: 1 	Acc: 73.624 	Loss: 0.7760
#   Client3 Train => Local Epoch: 2 	Acc: 78.297 	Loss: 0.6846
#   Client3 Train => Local Epoch: 3 	Acc: 77.985 	Loss: 0.6317
#   Client3 Train => Local Epoch: 4 	Acc: 79.855 	Loss: 0.5446
#   Client 1
#   Client1 Train => Local Epoch: 0 	Acc: 54.905 	Loss: 1.2103
#   Client1 Train => Local Epoch: 1 	Acc: 67.590 	Loss: 0.8875
#   Client1 Train => Local Epoch: 2 	Acc: 69.673 	Loss: 0.8075
#   Client1 Train => Local Epoch: 3 	Acc: 71.018 	Loss: 0.7684
#   Client1 Train => Local Epoch: 4 	Acc: 73.602 	Loss: 0.7137
#   Client 4
#   Client4 Train => Local Epoch: 0 	Acc: 69.538 	Loss: 0.9807
#   Client4 Train => Local Epoch: 1 	Acc: 82.044 	Loss: 0.4749
#   Client4 Train => Local Epoch: 2 	Acc: 84.374 	Loss: 0.3742
#   Client4 Train => Local Epoch: 3 	Acc: 85.670 	Loss: 0.3499
#   Client4 Train => Local Epoch: 4 	Acc: 86.505 	Loss: 0.3172
#   Client 8
#   Client8 Train => Local Epoch: 0 	Acc: 58.198 	Loss: 1.1258
#   Client8 Train => Local Epoch: 1 	Acc: 65.240 	Loss: 0.9124
#   Client8 Train => Local Epoch: 2 	Acc: 65.957 	Loss: 0.8782
#   Client8 Train => Local Epoch: 3 	Acc: 67.598 	Loss: 0.8416
#   Client8 Train => Local Epoch: 4 	Acc: 68.510 	Loss: 0.8177
#   Client 9
#   Client9 Train => Local Epoch: 0 	Acc: 84.156 	Loss: 0.5603
#   Client9 Train => Local Epoch: 1 	Acc: 91.869 	Loss: 0.3204
#   Client9 Train => Local Epoch: 2 	Acc: 92.253 	Loss: 0.2730
#   Client9 Train => Local Epoch: 3 	Acc: 93.631 	Loss: 0.2248
#   Client9 Train => Local Epoch: 4 	Acc: 94.259 	Loss: 0.1932
#   Client 5
#   Client5 Train => Local Epoch: 0 	Acc: 80.497 	Loss: 0.5680
#   Client5 Train => Local Epoch: 1 	Acc: 84.930 	Loss: 0.3952
#   Client5 Train => Local Epoch: 2 	Acc: 86.750 	Loss: 0.3537
#   Client5 Train => Local Epoch: 3 	Acc: 87.624 	Loss: 0.3323
#   Client5 Train => Local Epoch: 4 	Acc: 88.101 	Loss: 0.3206
# FOT phase: projecting global update onto orthogonal complement.
# Round 06: Train Acc = 18.12% | Test Acc = 20.37% | Test Loss = 2.1651 | Mean FgT = 0.1498 | Time = 33.85s
#
# === Round 7/100 | LR = 0.0100 ===
#   Client 2
#   Client2 Train => Local Epoch: 0 	Acc: 86.875 	Loss: 0.5553
#   Client2 Train => Local Epoch: 1 	Acc: 92.458 	Loss: 0.3670
#   Client2 Train => Local Epoch: 2 	Acc: 91.878 	Loss: 0.2755
#   Client2 Train => Local Epoch: 3 	Acc: 92.748 	Loss: 0.2295
#   Client2 Train => Local Epoch: 4 	Acc: 93.691 	Loss: 0.2040
#   Client 6
#   Client6 Train => Local Epoch: 0 	Acc: 68.715 	Loss: 0.9997
#   Client6 Train => Local Epoch: 1 	Acc: 87.154 	Loss: 0.4924
#   Client6 Train => Local Epoch: 2 	Acc: 88.998 	Loss: 0.3623
#   Client6 Train => Local Epoch: 3 	Acc: 90.043 	Loss: 0.3389
#   Client6 Train => Local Epoch: 4 	Acc: 90.227 	Loss: 0.2904
#   Client 0
#   Client0 Train => Local Epoch: 0 	Acc: 78.428 	Loss: 0.6636
#   Client0 Train => Local Epoch: 1 	Acc: 84.856 	Loss: 0.4203
#   Client0 Train => Local Epoch: 2 	Acc: 85.170 	Loss: 0.4060
#   Client0 Train => Local Epoch: 3 	Acc: 86.112 	Loss: 0.3738
#   Client0 Train => Local Epoch: 4 	Acc: 86.957 	Loss: 0.3591
#   Client 7
#   Client7 Train => Local Epoch: 0 	Acc: 67.957 	Loss: 0.9502
#   Client7 Train => Local Epoch: 1 	Acc: 85.834 	Loss: 0.4476
#   Client7 Train => Local Epoch: 2 	Acc: 86.433 	Loss: 0.3811
#   Client7 Train => Local Epoch: 3 	Acc: 86.951 	Loss: 0.3477
#   Client7 Train => Local Epoch: 4 	Acc: 89.425 	Loss: 0.3084
#   Client 8
#   Client8 Train => Local Epoch: 0 	Acc: 60.448 	Loss: 1.0502
#   Client8 Train => Local Epoch: 1 	Acc: 65.424 	Loss: 0.8907
#   Client8 Train => Local Epoch: 2 	Acc: 66.609 	Loss: 0.8599
#   Client8 Train => Local Epoch: 3 	Acc: 68.641 	Loss: 0.8276
#   Client8 Train => Local Epoch: 4 	Acc: 68.988 	Loss: 0.7953
#   Client 4
#   Client4 Train => Local Epoch: 0 	Acc: 71.473 	Loss: 0.9109
#   Client4 Train => Local Epoch: 1 	Acc: 82.835 	Loss: 0.4115
#   Client4 Train => Local Epoch: 2 	Acc: 85.275 	Loss: 0.3520
#   Client4 Train => Local Epoch: 3 	Acc: 86.769 	Loss: 0.3284
#   Client4 Train => Local Epoch: 4 	Acc: 87.341 	Loss: 0.3130
#   Client 3
#   Client3 Train => Local Epoch: 0 	Acc: 44.964 	Loss: 1.6236
#   Client3 Train => Local Epoch: 1 	Acc: 77.362 	Loss: 0.7154
#   Client3 Train => Local Epoch: 2 	Acc: 78.609 	Loss: 0.6387
#   Client3 Train => Local Epoch: 3 	Acc: 79.543 	Loss: 0.5413
#   Client3 Train => Local Epoch: 4 	Acc: 82.035 	Loss: 0.4923
#   Client 1
#   Client1 Train => Local Epoch: 0 	Acc: 58.914 	Loss: 1.0704
#   Client1 Train => Local Epoch: 1 	Acc: 68.750 	Loss: 0.8524
#   Client1 Train => Local Epoch: 2 	Acc: 69.515 	Loss: 0.8019
#   Client1 Train => Local Epoch: 3 	Acc: 72.521 	Loss: 0.7413
#   Client1 Train => Local Epoch: 4 	Acc: 73.602 	Loss: 0.6988
#   Client 9
#   Client9 Train => Local Epoch: 0 	Acc: 85.011 	Loss: 0.5342
#   Client9 Train => Local Epoch: 1 	Acc: 91.973 	Loss: 0.2962
#   Client9 Train => Local Epoch: 2 	Acc: 93.108 	Loss: 0.2304
#   Client9 Train => Local Epoch: 3 	Acc: 93.509 	Loss: 0.2180
#   Client9 Train => Local Epoch: 4 	Acc: 93.753 	Loss: 0.1935
#   Client 5
#   Client5 Train => Local Epoch: 0 	Acc: 80.338 	Loss: 0.5874
#   Client5 Train => Local Epoch: 1 	Acc: 85.457 	Loss: 0.3887
#   Client5 Train => Local Epoch: 2 	Acc: 86.978 	Loss: 0.3495
#   Client5 Train => Local Epoch: 3 	Acc: 87.793 	Loss: 0.3238
#   Client5 Train => Local Epoch: 4 	Acc: 89.076 	Loss: 0.2965
# FOT phase: projecting global update onto orthogonal complement.
# Round 07: Train Acc = 21.26% | Test Acc = 22.69% | Test Loss = 2.0113 | Mean FgT = -0.0040 | Time = 34.40s
#
# === Round 8/100 | LR = 0.0100 ===
#   Client 8
#   Client8 Train => Local Epoch: 0 	Acc: 61.187 	Loss: 1.0593
#   Client8 Train => Local Epoch: 1 	Acc: 65.946 	Loss: 0.8711
#   Client8 Train => Local Epoch: 2 	Acc: 67.858 	Loss: 0.8365
#   Client8 Train => Local Epoch: 3 	Acc: 69.532 	Loss: 0.7974
#   Client8 Train => Local Epoch: 4 	Acc: 70.510 	Loss: 0.7724
#   Client 6
#   Client6 Train => Local Epoch: 0 	Acc: 69.576 	Loss: 0.9989
#   Client6 Train => Local Epoch: 1 	Acc: 88.199 	Loss: 0.4434
#   Client6 Train => Local Epoch: 2 	Acc: 89.551 	Loss: 0.3515
#   Client6 Train => Local Epoch: 3 	Acc: 89.920 	Loss: 0.3222
#   Client6 Train => Local Epoch: 4 	Acc: 89.367 	Loss: 0.3205
#   Client 1
#   Client1 Train => Local Epoch: 0 	Acc: 59.705 	Loss: 1.0605
#   Client1 Train => Local Epoch: 1 	Acc: 71.466 	Loss: 0.7896
#   Client1 Train => Local Epoch: 2 	Acc: 71.018 	Loss: 0.7683
#   Client1 Train => Local Epoch: 3 	Acc: 72.020 	Loss: 0.7138
#   Client1 Train => Local Epoch: 4 	Acc: 73.945 	Loss: 0.6756
#   Client 0
#   Client0 Train => Local Epoch: 0 	Acc: 79.988 	Loss: 0.6073
#   Client0 Train => Local Epoch: 1 	Acc: 85.219 	Loss: 0.4138
#   Client0 Train => Local Epoch: 2 	Acc: 86.152 	Loss: 0.3841
#   Client0 Train => Local Epoch: 3 	Acc: 86.819 	Loss: 0.3646
#   Client0 Train => Local Epoch: 4 	Acc: 87.732 	Loss: 0.3382
#   Client 5
#   Client5 Train => Local Epoch: 0 	Acc: 83.022 	Loss: 0.4950
#   Client5 Train => Local Epoch: 1 	Acc: 86.809 	Loss: 0.3531
#   Client5 Train => Local Epoch: 2 	Acc: 88.121 	Loss: 0.3120
#   Client5 Train => Local Epoch: 3 	Acc: 88.410 	Loss: 0.3020
#   Client5 Train => Local Epoch: 4 	Acc: 89.175 	Loss: 0.2922
#   Client 4
#   Client4 Train => Local Epoch: 0 	Acc: 72.440 	Loss: 0.8531
#   Client4 Train => Local Epoch: 1 	Acc: 83.802 	Loss: 0.3938
#   Client4 Train => Local Epoch: 2 	Acc: 86.066 	Loss: 0.3419
#   Client4 Train => Local Epoch: 3 	Acc: 87.319 	Loss: 0.3190
#   Client4 Train => Local Epoch: 4 	Acc: 88.725 	Loss: 0.3043
#   Client 3
#   Client3 Train => Local Epoch: 0 	Acc: 38.110 	Loss: 1.6825
#   Client3 Train => Local Epoch: 1 	Acc: 78.401 	Loss: 0.6834
#   Client3 Train => Local Epoch: 2 	Acc: 80.374 	Loss: 0.6033
#   Client3 Train => Local Epoch: 3 	Acc: 82.762 	Loss: 0.5141
#   Client3 Train => Local Epoch: 4 	Acc: 82.139 	Loss: 0.4947
#   Client 9
#   Client9 Train => Local Epoch: 0 	Acc: 86.093 	Loss: 0.5355
#   Client9 Train => Local Epoch: 1 	Acc: 93.038 	Loss: 0.2808
#   Client9 Train => Local Epoch: 2 	Acc: 93.736 	Loss: 0.2200
#   Client9 Train => Local Epoch: 3 	Acc: 93.701 	Loss: 0.2099
#   Client9 Train => Local Epoch: 4 	Acc: 93.910 	Loss: 0.1899
#   Client 7
#   Client7 Train => Local Epoch: 0 	Acc: 76.935 	Loss: 0.7510
#   Client7 Train => Local Epoch: 1 	Acc: 86.193 	Loss: 0.4195
#   Client7 Train => Local Epoch: 2 	Acc: 88.029 	Loss: 0.3379
#   Client7 Train => Local Epoch: 3 	Acc: 88.428 	Loss: 0.3201
#   Client7 Train => Local Epoch: 4 	Acc: 89.226 	Loss: 0.2863
#   Client 2
#   Client2 Train => Local Epoch: 0 	Acc: 75.562 	Loss: 0.9889
#   Client2 Train => Local Epoch: 1 	Acc: 92.458 	Loss: 0.5448
#   Client2 Train => Local Epoch: 2 	Acc: 91.661 	Loss: 0.2880
#   Client2 Train => Local Epoch: 3 	Acc: 92.458 	Loss: 0.2335
#   Client2 Train => Local Epoch: 4 	Acc: 93.038 	Loss: 0.2357
# FOT phase: projecting global update onto orthogonal complement.
# Round 08: Train Acc = 19.51% | Test Acc = 22.16% | Test Loss = 2.1562 | Mean FgT = 0.1492 | Time = 33.19s
#
# === Round 9/100 | LR = 0.0100 ===
#   Client 7
#   Client7 Train => Local Epoch: 0 	Acc: 67.239 	Loss: 1.0330
#   Client7 Train => Local Epoch: 1 	Acc: 85.874 	Loss: 0.4480
#   Client7 Train => Local Epoch: 2 	Acc: 86.872 	Loss: 0.3862
#   Client7 Train => Local Epoch: 3 	Acc: 88.747 	Loss: 0.3341
#   Client7 Train => Local Epoch: 4 	Acc: 89.944 	Loss: 0.2994
#   Client 4
#   Client4 Train => Local Epoch: 0 	Acc: 72.132 	Loss: 0.8862
#   Client4 Train => Local Epoch: 1 	Acc: 84.110 	Loss: 0.3923
#   Client4 Train => Local Epoch: 2 	Acc: 86.066 	Loss: 0.3346
#   Client4 Train => Local Epoch: 3 	Acc: 87.121 	Loss: 0.3147
#   Client4 Train => Local Epoch: 4 	Acc: 88.132 	Loss: 0.2874
#   Client 3
#   Client3 Train => Local Epoch: 0 	Acc: 50.987 	Loss: 1.4737
#   Client3 Train => Local Epoch: 1 	Acc: 78.193 	Loss: 0.6864
#   Client3 Train => Local Epoch: 2 	Acc: 80.997 	Loss: 0.6126
#   Client3 Train => Local Epoch: 3 	Acc: 80.789 	Loss: 0.5593
#   Client3 Train => Local Epoch: 4 	Acc: 84.320 	Loss: 0.4697
#   Client 2
#   Client2 Train => Local Epoch: 0 	Acc: 87.092 	Loss: 0.5299
#   Client2 Train => Local Epoch: 1 	Acc: 92.023 	Loss: 0.3332
#   Client2 Train => Local Epoch: 2 	Acc: 92.966 	Loss: 0.2429
#   Client2 Train => Local Epoch: 3 	Acc: 93.981 	Loss: 0.2128
#   Client2 Train => Local Epoch: 4 	Acc: 94.344 	Loss: 0.1930
#   Client 9
#   Client9 Train => Local Epoch: 0 	Acc: 86.442 	Loss: 0.4892
#   Client9 Train => Local Epoch: 1 	Acc: 93.073 	Loss: 0.2624
#   Client9 Train => Local Epoch: 2 	Acc: 93.718 	Loss: 0.2279
#   Client9 Train => Local Epoch: 3 	Acc: 94.469 	Loss: 0.1952
#   Client9 Train => Local Epoch: 4 	Acc: 94.538 	Loss: 0.1827
#   Client 8
#   Client8 Train => Local Epoch: 0 	Acc: 62.838 	Loss: 1.0028
#   Client8 Train => Local Epoch: 1 	Acc: 66.565 	Loss: 0.8578
#   Client8 Train => Local Epoch: 2 	Acc: 69.564 	Loss: 0.8036
#   Client8 Train => Local Epoch: 3 	Acc: 70.325 	Loss: 0.7840
#   Client8 Train => Local Epoch: 4 	Acc: 71.585 	Loss: 0.7545
#   Client 6
#   Client6 Train => Local Epoch: 0 	Acc: 64.905 	Loss: 1.1394
#   Client6 Train => Local Epoch: 1 	Acc: 87.892 	Loss: 0.4617
#   Client6 Train => Local Epoch: 2 	Acc: 89.367 	Loss: 0.3682
#   Client6 Train => Local Epoch: 3 	Acc: 89.736 	Loss: 0.3587
#   Client6 Train => Local Epoch: 4 	Acc: 89.428 	Loss: 0.3572
#   Client 1
#   Client1 Train => Local Epoch: 0 	Acc: 63.107 	Loss: 1.0095
#   Client1 Train => Local Epoch: 1 	Acc: 71.440 	Loss: 0.7952
#   Client1 Train => Local Epoch: 2 	Acc: 72.442 	Loss: 0.7506
#   Client1 Train => Local Epoch: 3 	Acc: 74.815 	Loss: 0.6869
#   Client1 Train => Local Epoch: 4 	Acc: 75.659 	Loss: 0.6495
#   Client 0
#   Client0 Train => Local Epoch: 0 	Acc: 81.038 	Loss: 0.5941
#   Client0 Train => Local Epoch: 1 	Acc: 86.005 	Loss: 0.3933
#   Client0 Train => Local Epoch: 2 	Acc: 86.642 	Loss: 0.3683
#   Client0 Train => Local Epoch: 3 	Acc: 86.770 	Loss: 0.3494
#   Client0 Train => Local Epoch: 4 	Acc: 87.212 	Loss: 0.3435
#   Client 5
#   Client5 Train => Local Epoch: 0 	Acc: 80.716 	Loss: 0.5936
#   Client5 Train => Local Epoch: 1 	Acc: 86.193 	Loss: 0.3763
#   Client5 Train => Local Epoch: 2 	Acc: 87.584 	Loss: 0.3307
#   Client5 Train => Local Epoch: 3 	Acc: 88.698 	Loss: 0.3054
#   Client5 Train => Local Epoch: 4 	Acc: 89.195 	Loss: 0.2871
# FOT phase: projecting global update onto orthogonal complement.
# Round 09: Train Acc = 24.18% | Test Acc = 25.66% | Test Loss = 2.0245 | Mean FgT = 0.0175 | Time = 33.76s
#
# === Round 10/100 | LR = 0.0100 ===
#   Client 1
#   Client1 Train => Local Epoch: 0 	Acc: 61.788 	Loss: 1.0356
#   Client1 Train => Local Epoch: 1 	Acc: 71.809 	Loss: 0.7527
#   Client1 Train => Local Epoch: 2 	Acc: 73.629 	Loss: 0.6935
#   Client1 Train => Local Epoch: 3 	Acc: 74.156 	Loss: 0.6691
#   Client1 Train => Local Epoch: 4 	Acc: 76.319 	Loss: 0.6299
#   Client 5
#   Client5 Train => Local Epoch: 0 	Acc: 84.264 	Loss: 0.4405
#   Client5 Train => Local Epoch: 1 	Acc: 86.551 	Loss: 0.3503
#   Client5 Train => Local Epoch: 2 	Acc: 88.618 	Loss: 0.2994
#   Client5 Train => Local Epoch: 3 	Acc: 88.897 	Loss: 0.2912
#   Client5 Train => Local Epoch: 4 	Acc: 89.791 	Loss: 0.2694
#   Client 9
#   Client9 Train => Local Epoch: 0 	Acc: 86.111 	Loss: 0.4643
#   Client9 Train => Local Epoch: 1 	Acc: 93.300 	Loss: 0.2677
#   Client9 Train => Local Epoch: 2 	Acc: 93.317 	Loss: 0.2173
#   Client9 Train => Local Epoch: 3 	Acc: 94.556 	Loss: 0.1840
#   Client9 Train => Local Epoch: 4 	Acc: 94.643 	Loss: 0.1710
#   Client 0
#   Client0 Train => Local Epoch: 0 	Acc: 80.881 	Loss: 0.5815
#   Client0 Train => Local Epoch: 1 	Acc: 86.368 	Loss: 0.3774
#   Client0 Train => Local Epoch: 2 	Acc: 87.418 	Loss: 0.3531
#   Client0 Train => Local Epoch: 3 	Acc: 87.693 	Loss: 0.3448
#   Client0 Train => Local Epoch: 4 	Acc: 88.527 	Loss: 0.3175
#   Client 3
#   Client3 Train => Local Epoch: 0 	Acc: 40.602 	Loss: 1.7087
#   Client3 Train => Local Epoch: 1 	Acc: 79.232 	Loss: 0.6457
#   Client3 Train => Local Epoch: 2 	Acc: 81.828 	Loss: 0.5790
#   Client3 Train => Local Epoch: 3 	Acc: 83.178 	Loss: 0.5096
#   Client3 Train => Local Epoch: 4 	Acc: 84.008 	Loss: 0.4490
#   Client 4
#   Client4 Train => Local Epoch: 0 	Acc: 72.769 	Loss: 0.8592
#   Client4 Train => Local Epoch: 1 	Acc: 83.495 	Loss: 0.4025
#   Client4 Train => Local Epoch: 2 	Acc: 86.571 	Loss: 0.3240
#   Client4 Train => Local Epoch: 3 	Acc: 87.516 	Loss: 0.3082
#   Client4 Train => Local Epoch: 4 	Acc: 87.934 	Loss: 0.2909
#   Client 6
#   Client6 Train => Local Epoch: 0 	Acc: 67.978 	Loss: 1.0870
#   Client6 Train => Local Epoch: 1 	Acc: 88.752 	Loss: 0.4259
#   Client6 Train => Local Epoch: 2 	Acc: 89.920 	Loss: 0.3292
#   Client6 Train => Local Epoch: 3 	Acc: 90.350 	Loss: 0.2909
#   Client6 Train => Local Epoch: 4 	Acc: 90.719 	Loss: 0.2727
#   Client 8
#   Client8 Train => Local Epoch: 0 	Acc: 62.849 	Loss: 1.0688
#   Client8 Train => Local Epoch: 1 	Acc: 68.010 	Loss: 0.8446
#   Client8 Train => Local Epoch: 2 	Acc: 69.966 	Loss: 0.7937
#   Client8 Train => Local Epoch: 3 	Acc: 71.107 	Loss: 0.7629
#   Client8 Train => Local Epoch: 4 	Acc: 72.868 	Loss: 0.7177
#   Client 2
#   Client2 Train => Local Epoch: 0 	Acc: 68.020 	Loss: 1.4148
#   Client2 Train => Local Epoch: 1 	Acc: 92.458 	Loss: 0.6359
#   Client2 Train => Local Epoch: 2 	Acc: 92.676 	Loss: 0.3042
#   Client2 Train => Local Epoch: 3 	Acc: 92.893 	Loss: 0.2350
#   Client2 Train => Local Epoch: 4 	Acc: 92.603 	Loss: 0.2262
#   Client 7
#   Client7 Train => Local Epoch: 0 	Acc: 79.529 	Loss: 0.6916
#   Client7 Train => Local Epoch: 1 	Acc: 87.071 	Loss: 0.3974
#   Client7 Train => Local Epoch: 2 	Acc: 88.388 	Loss: 0.3159
#   Client7 Train => Local Epoch: 3 	Acc: 89.625 	Loss: 0.2873
#   Client7 Train => Local Epoch: 4 	Acc: 91.580 	Loss: 0.2479
# FOT phase: projecting global update onto orthogonal complement.
# Round 10: Train Acc = 21.15% | Test Acc = 22.84% | Test Loss = 2.1691 | Mean FgT = 0.1622 | Time = 33.62s
#
# === Round 11/100 | LR = 0.0100 ===
#   Client 6
#   Client6 Train => Local Epoch: 0 	Acc: 68.162 	Loss: 1.0196
#   Client6 Train => Local Epoch: 1 	Acc: 88.076 	Loss: 0.4305
#   Client6 Train => Local Epoch: 2 	Acc: 89.982 	Loss: 0.3617
#   Client6 Train => Local Epoch: 3 	Acc: 90.965 	Loss: 0.3173
#   Client6 Train => Local Epoch: 4 	Acc: 90.412 	Loss: 0.2718
#   Client 0
#   Client0 Train => Local Epoch: 0 	Acc: 82.314 	Loss: 0.5359
#   Client0 Train => Local Epoch: 1 	Acc: 86.790 	Loss: 0.3601
#   Client0 Train => Local Epoch: 2 	Acc: 88.016 	Loss: 0.3345
#   Client0 Train => Local Epoch: 3 	Acc: 88.870 	Loss: 0.3099
#   Client0 Train => Local Epoch: 4 	Acc: 88.684 	Loss: 0.3029
#   Client 2
#   Client2 Train => Local Epoch: 0 	Acc: 84.554 	Loss: 0.5342
#   Client2 Train => Local Epoch: 1 	Acc: 92.313 	Loss: 0.2922
#   Client2 Train => Local Epoch: 2 	Acc: 92.168 	Loss: 0.2710
#   Client2 Train => Local Epoch: 3 	Acc: 93.328 	Loss: 0.2512
#   Client2 Train => Local Epoch: 4 	Acc: 94.199 	Loss: 0.2021
#   Client 9
#   Client9 Train => Local Epoch: 0 	Acc: 85.797 	Loss: 0.4848
#   Client9 Train => Local Epoch: 1 	Acc: 93.317 	Loss: 0.2532
#   Client9 Train => Local Epoch: 2 	Acc: 93.841 	Loss: 0.2165
#   Client9 Train => Local Epoch: 3 	Acc: 94.294 	Loss: 0.1865
#   Client9 Train => Local Epoch: 4 	Acc: 94.643 	Loss: 0.1781
#   Client 4
#   Client4 Train => Local Epoch: 0 	Acc: 72.505 	Loss: 0.8592
#   Client4 Train => Local Epoch: 1 	Acc: 84.418 	Loss: 0.3888
#   Client4 Train => Local Epoch: 2 	Acc: 87.011 	Loss: 0.3255
#   Client4 Train => Local Epoch: 3 	Acc: 87.692 	Loss: 0.3037
#   Client4 Train => Local Epoch: 4 	Acc: 88.264 	Loss: 0.2926
#   Client 7
#   Client7 Train => Local Epoch: 0 	Acc: 67.398 	Loss: 1.0725
#   Client7 Train => Local Epoch: 1 	Acc: 87.031 	Loss: 0.4776
#   Client7 Train => Local Epoch: 2 	Acc: 87.590 	Loss: 0.3744
#   Client7 Train => Local Epoch: 3 	Acc: 89.705 	Loss: 0.3054
#   Client7 Train => Local Epoch: 4 	Acc: 90.343 	Loss: 0.2686
#   Client 3
#   Client3 Train => Local Epoch: 0 	Acc: 51.090 	Loss: 1.4217
#   Client3 Train => Local Epoch: 1 	Acc: 80.685 	Loss: 0.6445
#   Client3 Train => Local Epoch: 2 	Acc: 80.997 	Loss: 0.6562
#   Client3 Train => Local Epoch: 3 	Acc: 82.035 	Loss: 0.5489
#   Client3 Train => Local Epoch: 4 	Acc: 83.904 	Loss: 0.4448
#   Client 1
#   Client1 Train => Local Epoch: 0 	Acc: 62.896 	Loss: 0.9842
#   Client1 Train => Local Epoch: 1 	Acc: 71.203 	Loss: 0.8005
#   Client1 Train => Local Epoch: 2 	Acc: 73.945 	Loss: 0.7135
#   Client1 Train => Local Epoch: 3 	Acc: 75.158 	Loss: 0.6890
#   Client1 Train => Local Epoch: 4 	Acc: 76.108 	Loss: 0.6261
#   Client 5
#   Client5 Train => Local Epoch: 0 	Acc: 81.541 	Loss: 0.5841
#   Client5 Train => Local Epoch: 1 	Acc: 87.634 	Loss: 0.3395
#   Client5 Train => Local Epoch: 2 	Acc: 89.175 	Loss: 0.2924
#   Client5 Train => Local Epoch: 3 	Acc: 89.423 	Loss: 0.2835
#   Client5 Train => Local Epoch: 4 	Acc: 89.861 	Loss: 0.2664
#   Client 8
#   Client8 Train => Local Epoch: 0 	Acc: 64.979 	Loss: 0.9619
#   Client8 Train => Local Epoch: 1 	Acc: 69.162 	Loss: 0.8168
#   Client8 Train => Local Epoch: 2 	Acc: 70.151 	Loss: 0.7823
#   Client8 Train => Local Epoch: 3 	Acc: 72.531 	Loss: 0.7284
#   Client8 Train => Local Epoch: 4 	Acc: 72.585 	Loss: 0.7190
# FOT phase: projecting global update onto orthogonal complement.
# Round 11: Train Acc = 30.83% | Test Acc = 31.60% | Test Loss = 1.9160 | Mean FgT = -0.0909 | Time = 33.95s
#
# === Round 12/100 | LR = 0.0100 ===
#   Client 8
#   Client8 Train => Local Epoch: 0 	Acc: 63.827 	Loss: 1.0188
#   Client8 Train => Local Epoch: 1 	Acc: 71.020 	Loss: 0.7894
#   Client8 Train => Local Epoch: 2 	Acc: 71.651 	Loss: 0.7611
#   Client8 Train => Local Epoch: 3 	Acc: 73.682 	Loss: 0.7198
#   Client8 Train => Local Epoch: 4 	Acc: 74.063 	Loss: 0.6953
#   Client 7
#   Client7 Train => Local Epoch: 0 	Acc: 79.290 	Loss: 0.7159
#   Client7 Train => Local Epoch: 1 	Acc: 87.989 	Loss: 0.3862
#   Client7 Train => Local Epoch: 2 	Acc: 89.465 	Loss: 0.2967
#   Client7 Train => Local Epoch: 3 	Acc: 90.463 	Loss: 0.2704
#   Client7 Train => Local Epoch: 4 	Acc: 92.099 	Loss: 0.2368
#   Client 9
#   Client9 Train => Local Epoch: 0 	Acc: 87.995 	Loss: 0.4060
#   Client9 Train => Local Epoch: 1 	Acc: 93.352 	Loss: 0.2324
#   Client9 Train => Local Epoch: 2 	Acc: 94.381 	Loss: 0.1896
#   Client9 Train => Local Epoch: 3 	Acc: 95.132 	Loss: 0.1707
#   Client9 Train => Local Epoch: 4 	Acc: 95.184 	Loss: 0.1523
#   Client 4
#   Client4 Train => Local Epoch: 0 	Acc: 72.879 	Loss: 0.8634
#   Client4 Train => Local Epoch: 1 	Acc: 85.275 	Loss: 0.3561
#   Client4 Train => Local Epoch: 2 	Acc: 87.253 	Loss: 0.3087
#   Client4 Train => Local Epoch: 3 	Acc: 88.462 	Loss: 0.2841
#   Client4 Train => Local Epoch: 4 	Acc: 89.231 	Loss: 0.2676
#   Client 1
#   Client1 Train => Local Epoch: 0 	Acc: 64.241 	Loss: 0.9838
#   Client1 Train => Local Epoch: 1 	Acc: 73.523 	Loss: 0.7172
#   Client1 Train => Local Epoch: 2 	Acc: 75.422 	Loss: 0.6604
#   Client1 Train => Local Epoch: 3 	Acc: 75.211 	Loss: 0.6387
#   Client1 Train => Local Epoch: 4 	Acc: 77.268 	Loss: 0.6068
#   Client 2
#   Client2 Train => Local Epoch: 0 	Acc: 65.410 	Loss: 1.3179
#   Client2 Train => Local Epoch: 1 	Acc: 92.458 	Loss: 0.6212
#   Client2 Train => Local Epoch: 2 	Acc: 92.893 	Loss: 0.3132
#   Client2 Train => Local Epoch: 3 	Acc: 91.661 	Loss: 0.2478
#   Client2 Train => Local Epoch: 4 	Acc: 93.256 	Loss: 0.2122
#   Client 5
#   Client5 Train => Local Epoch: 0 	Acc: 86.531 	Loss: 0.3984
#   Client5 Train => Local Epoch: 1 	Acc: 88.360 	Loss: 0.3132
#   Client5 Train => Local Epoch: 2 	Acc: 89.354 	Loss: 0.2816
#   Client5 Train => Local Epoch: 3 	Acc: 90.328 	Loss: 0.2664
#   Client5 Train => Local Epoch: 4 	Acc: 90.785 	Loss: 0.2482
#   Client 0
#   Client0 Train => Local Epoch: 0 	Acc: 82.030 	Loss: 0.5363
#   Client0 Train => Local Epoch: 1 	Acc: 86.986 	Loss: 0.3574
#   Client0 Train => Local Epoch: 2 	Acc: 88.537 	Loss: 0.3252
#   Client0 Train => Local Epoch: 3 	Acc: 88.880 	Loss: 0.3106
#   Client0 Train => Local Epoch: 4 	Acc: 88.841 	Loss: 0.3004
#   Client 6
#   Client6 Train => Local Epoch: 0 	Acc: 67.425 	Loss: 1.1291
#   Client6 Train => Local Epoch: 1 	Acc: 88.629 	Loss: 0.4209
#   Client6 Train => Local Epoch: 2 	Acc: 89.613 	Loss: 0.3376
#   Client6 Train => Local Epoch: 3 	Acc: 89.920 	Loss: 0.3035
#   Client6 Train => Local Epoch: 4 	Acc: 91.334 	Loss: 0.2736
#   Client 3
#   Client3 Train => Local Epoch: 0 	Acc: 42.368 	Loss: 1.6345
#   Client3 Train => Local Epoch: 1 	Acc: 77.778 	Loss: 0.6972
#   Client3 Train => Local Epoch: 2 	Acc: 83.178 	Loss: 0.5135
#   Client3 Train => Local Epoch: 3 	Acc: 82.347 	Loss: 0.4892
#   Client3 Train => Local Epoch: 4 	Acc: 84.424 	Loss: 0.4485
# FOT phase: projecting global update onto orthogonal complement.
# Round 12: Train Acc = 24.75% | Test Acc = 26.82% | Test Loss = 2.0506 | Mean FgT = 0.1346 | Time = 33.90s
#
# === Round 13/100 | LR = 0.0100 ===
#   Client 9
#   Client9 Train => Local Epoch: 0 	Acc: 85.500 	Loss: 0.5187
#   Client9 Train => Local Epoch: 1 	Acc: 93.631 	Loss: 0.2502
#   Client9 Train => Local Epoch: 2 	Acc: 94.434 	Loss: 0.1913
#   Client9 Train => Local Epoch: 3 	Acc: 94.870 	Loss: 0.1694
#   Client9 Train => Local Epoch: 4 	Acc: 95.149 	Loss: 0.1606
#   Client 4
#   Client4 Train => Local Epoch: 0 	Acc: 75.516 	Loss: 0.7245
#   Client4 Train => Local Epoch: 1 	Acc: 87.099 	Loss: 0.3260
#   Client4 Train => Local Epoch: 2 	Acc: 88.791 	Loss: 0.2872
#   Client4 Train => Local Epoch: 3 	Acc: 89.912 	Loss: 0.2536
#   Client4 Train => Local Epoch: 4 	Acc: 90.022 	Loss: 0.2482
#   Client 7
#   Client7 Train => Local Epoch: 0 	Acc: 70.391 	Loss: 0.9621
#   Client7 Train => Local Epoch: 1 	Acc: 87.789 	Loss: 0.4308
#   Client7 Train => Local Epoch: 2 	Acc: 89.585 	Loss: 0.3116
#   Client7 Train => Local Epoch: 3 	Acc: 90.024 	Loss: 0.2691
#   Client7 Train => Local Epoch: 4 	Acc: 90.503 	Loss: 0.2594
#   Client 8
#   Client8 Train => Local Epoch: 0 	Acc: 67.130 	Loss: 0.8779
#   Client8 Train => Local Epoch: 1 	Acc: 70.814 	Loss: 0.7605
#   Client8 Train => Local Epoch: 2 	Acc: 71.651 	Loss: 0.7469
#   Client8 Train => Local Epoch: 3 	Acc: 73.172 	Loss: 0.7035
#   Client8 Train => Local Epoch: 4 	Acc: 74.552 	Loss: 0.6755
#   Client 5
#   Client5 Train => Local Epoch: 0 	Acc: 82.525 	Loss: 0.5489
#   Client5 Train => Local Epoch: 1 	Acc: 88.340 	Loss: 0.3194
#   Client5 Train => Local Epoch: 2 	Acc: 88.807 	Loss: 0.2959
#   Client5 Train => Local Epoch: 3 	Acc: 90.815 	Loss: 0.2543
#   Client5 Train => Local Epoch: 4 	Acc: 90.825 	Loss: 0.2458
#   Client 1
#   Client1 Train => Local Epoch: 0 	Acc: 65.796 	Loss: 0.9416
#   Client1 Train => Local Epoch: 1 	Acc: 75.316 	Loss: 0.7238
#   Client1 Train => Local Epoch: 2 	Acc: 75.976 	Loss: 0.6612
#   Client1 Train => Local Epoch: 3 	Acc: 77.901 	Loss: 0.6182
#   Client1 Train => Local Epoch: 4 	Acc: 77.479 	Loss: 0.5927
#   Client 3
#   Client3 Train => Local Epoch: 0 	Acc: 51.921 	Loss: 1.4720
#   Client3 Train => Local Epoch: 1 	Acc: 79.543 	Loss: 0.6700
#   Client3 Train => Local Epoch: 2 	Acc: 82.762 	Loss: 0.6643
#   Client3 Train => Local Epoch: 3 	Acc: 84.943 	Loss: 0.5428
#   Client3 Train => Local Epoch: 4 	Acc: 84.528 	Loss: 0.4700
#   Client 2
#   Client2 Train => Local Epoch: 0 	Acc: 81.653 	Loss: 0.6001
#   Client2 Train => Local Epoch: 1 	Acc: 92.458 	Loss: 0.3638
#   Client2 Train => Local Epoch: 2 	Acc: 93.401 	Loss: 0.2477
#   Client2 Train => Local Epoch: 3 	Acc: 93.474 	Loss: 0.2196
#   Client2 Train => Local Epoch: 4 	Acc: 93.546 	Loss: 0.1999
#   Client 0
#   Client0 Train => Local Epoch: 0 	Acc: 84.385 	Loss: 0.4630
#   Client0 Train => Local Epoch: 1 	Acc: 88.085 	Loss: 0.3285
#   Client0 Train => Local Epoch: 2 	Acc: 88.350 	Loss: 0.3177
#   Client0 Train => Local Epoch: 3 	Acc: 89.175 	Loss: 0.2949
#   Client0 Train => Local Epoch: 4 	Acc: 90.048 	Loss: 0.2756
#   Client 6
#   Client6 Train => Local Epoch: 0 	Acc: 70.313 	Loss: 0.8730
#   Client6 Train => Local Epoch: 1 	Acc: 89.060 	Loss: 0.4237
#   Client6 Train => Local Epoch: 2 	Acc: 90.535 	Loss: 0.3083
#   Client6 Train => Local Epoch: 3 	Acc: 92.440 	Loss: 0.2650
#   Client6 Train => Local Epoch: 4 	Acc: 92.809 	Loss: 0.2206
# FOT phase: projecting global update onto orthogonal complement.
# Round 13: Train Acc = 36.62% | Test Acc = 37.06% | Test Loss = 1.9073 | Mean FgT = -0.0087 | Time = 34.44s
#
# === Round 14/100 | LR = 0.0100 ===
#   Client 9
#   Client9 Train => Local Epoch: 0 	Acc: 90.473 	Loss: 0.3188
#   Client9 Train => Local Epoch: 1 	Acc: 94.451 	Loss: 0.1958
#   Client9 Train => Local Epoch: 2 	Acc: 94.591 	Loss: 0.1903
#   Client9 Train => Local Epoch: 3 	Acc: 95.027 	Loss: 0.1569
#   Client9 Train => Local Epoch: 4 	Acc: 95.882 	Loss: 0.1267
#   Client 2
#   Client2 Train => Local Epoch: 0 	Acc: 67.078 	Loss: 1.2246
#   Client2 Train => Local Epoch: 1 	Acc: 92.458 	Loss: 0.6110
#   Client2 Train => Local Epoch: 2 	Acc: 92.096 	Loss: 0.3304
#   Client2 Train => Local Epoch: 3 	Acc: 92.676 	Loss: 0.2534
#   Client2 Train => Local Epoch: 4 	Acc: 93.619 	Loss: 0.2158
#   Client 1
#   Client1 Train => Local Epoch: 0 	Acc: 65.796 	Loss: 0.9963
#   Client1 Train => Local Epoch: 1 	Acc: 74.921 	Loss: 0.6778
#   Client1 Train => Local Epoch: 2 	Acc: 75.264 	Loss: 0.6400
#   Client1 Train => Local Epoch: 3 	Acc: 78.217 	Loss: 0.5883
#   Client1 Train => Local Epoch: 4 	Acc: 78.850 	Loss: 0.5655
#   Client 5
#   Client5 Train => Local Epoch: 0 	Acc: 87.535 	Loss: 0.3583
#   Client5 Train => Local Epoch: 1 	Acc: 88.748 	Loss: 0.3019
#   Client5 Train => Local Epoch: 2 	Acc: 90.417 	Loss: 0.2620
#   Client5 Train => Local Epoch: 3 	Acc: 90.765 	Loss: 0.2428
#   Client5 Train => Local Epoch: 4 	Acc: 91.600 	Loss: 0.2249
#   Client 3
#   Client3 Train => Local Epoch: 0 	Acc: 47.352 	Loss: 1.6332
#   Client3 Train => Local Epoch: 1 	Acc: 78.816 	Loss: 0.6643
#   Client3 Train => Local Epoch: 2 	Acc: 82.243 	Loss: 0.5429
#   Client3 Train => Local Epoch: 3 	Acc: 82.866 	Loss: 0.5076
#   Client3 Train => Local Epoch: 4 	Acc: 86.604 	Loss: 0.4267
#   Client 4
#   Client4 Train => Local Epoch: 0 	Acc: 72.835 	Loss: 0.8598
#   Client4 Train => Local Epoch: 1 	Acc: 86.549 	Loss: 0.3378
#   Client4 Train => Local Epoch: 2 	Acc: 88.374 	Loss: 0.2941
#   Client4 Train => Local Epoch: 3 	Acc: 88.549 	Loss: 0.2784
#   Client4 Train => Local Epoch: 4 	Acc: 89.692 	Loss: 0.2574
#   Client 7
#   Client7 Train => Local Epoch: 0 	Acc: 75.818 	Loss: 0.8014
#   Client7 Train => Local Epoch: 1 	Acc: 88.707 	Loss: 0.3612
#   Client7 Train => Local Epoch: 2 	Acc: 88.388 	Loss: 0.3293
#   Client7 Train => Local Epoch: 3 	Acc: 91.620 	Loss: 0.2571
#   Client7 Train => Local Epoch: 4 	Acc: 91.899 	Loss: 0.2255
#   Client 8
#   Client8 Train => Local Epoch: 0 	Acc: 64.631 	Loss: 1.0006
#   Client8 Train => Local Epoch: 1 	Acc: 71.846 	Loss: 0.7612
#   Client8 Train => Local Epoch: 2 	Acc: 73.204 	Loss: 0.7155
#   Client8 Train => Local Epoch: 3 	Acc: 73.998 	Loss: 0.6900
#   Client8 Train => Local Epoch: 4 	Acc: 75.508 	Loss: 0.6572
#   Client 0
#   Client0 Train => Local Epoch: 0 	Acc: 82.648 	Loss: 0.5215
#   Client0 Train => Local Epoch: 1 	Acc: 88.458 	Loss: 0.3265
#   Client0 Train => Local Epoch: 2 	Acc: 88.645 	Loss: 0.3230
#   Client0 Train => Local Epoch: 3 	Acc: 89.155 	Loss: 0.2912
#   Client0 Train => Local Epoch: 4 	Acc: 89.685 	Loss: 0.2796
#   Client 6
#   Client6 Train => Local Epoch: 0 	Acc: 64.659 	Loss: 1.2167
#   Client6 Train => Local Epoch: 1 	Acc: 88.752 	Loss: 0.4121
#   Client6 Train => Local Epoch: 2 	Acc: 90.043 	Loss: 0.3272
#   Client6 Train => Local Epoch: 3 	Acc: 91.334 	Loss: 0.2720
#   Client6 Train => Local Epoch: 4 	Acc: 91.887 	Loss: 0.2348
# FOT phase: projecting global update onto orthogonal complement.
# Round 14: Train Acc = 28.58% | Test Acc = 30.15% | Test Loss = 1.9761 | Mean FgT = 0.0688 | Time = 34.41s
#
# === Round 15/100 | LR = 0.0100 ===
#   Client 9
#   Client9 Train => Local Epoch: 0 	Acc: 82.900 	Loss: 0.6661
#   Client9 Train => Local Epoch: 1 	Acc: 93.317 	Loss: 0.2455
#   Client9 Train => Local Epoch: 2 	Acc: 93.998 	Loss: 0.2036
#   Client9 Train => Local Epoch: 3 	Acc: 94.521 	Loss: 0.1733
#   Client9 Train => Local Epoch: 4 	Acc: 94.835 	Loss: 0.1685
#   Client 6
#   Client6 Train => Local Epoch: 0 	Acc: 71.911 	Loss: 0.8437
# ...
#   Client 6
#   Client6 Train => Local Epoch: 0 	Acc: 79.471 	Loss: 0.6146
#   Client6 Train => Local Epoch: 1 	Acc: 95.821 	Loss: 0.1215
#   Client6 Train => Local Epoch: 2 	Acc: 97.173 	Loss: 0.0858
#   Client6 Train => Local Epoch: 3 	Acc: 97.664 	Loss: 0.0667
#   Client6 Train => Local Epoch: 4 	Acc: 98.033 	Loss: 0.0515
#   Client 1
#   Client1 Train => Local Epoch: 0 	Acc: 90.427 	Loss: 0.3039
#   Client1 Train => Local Epoch: 1 	Acc: 93.486 	Loss: 0.1824
#   Client1 Train => Local Epoch: 2 	Acc: 94.277 	Loss: 0.1555
#   Client1 Train => Local Epoch: 3 	Acc: 94.225 	Loss: 0.1609
#   Client1 Train => Local Epoch: 4 	Acc: 94.726 	Loss: 0.1440
#   Client 0
#   Client0 Train => Local Epoch: 0 	Acc: 98.871 	Loss: 0.0445
#   Client0 Train => Local Epoch: 1 	Acc: 98.901 	Loss: 0.0316
#   Client0 Train => Local Epoch: 2 	Acc: 98.518 	Loss: 0.0419
#   Client0 Train => Local Epoch: 3 	Acc: 97.968 	Loss: 0.0571
#   Client0 Train => Local Epoch: 4 	Acc: 98.106 	Loss: 0.0527
#   Client 3
#   Client3 Train => Local Epoch: 0 	Acc: 73.624 	Loss: 0.8906
#   Client3 Train => Local Epoch: 1 	Acc: 92.004 	Loss: 0.2562
#   Client3 Train => Local Epoch: 2 	Acc: 94.289 	Loss: 0.1914
#   Client3 Train => Local Epoch: 3 	Acc: 95.639 	Loss: 0.1477
#   Client3 Train => Local Epoch: 4 	Acc: 96.158 	Loss: 0.1176
#   Client 9
#   Client9 Train => Local Epoch: 0 	Acc: 95.481 	Loss: 0.1458
#   Client9 Train => Local Epoch: 1 	Acc: 98.691 	Loss: 0.0437
#   Client9 Train => Local Epoch: 2 	Acc: 99.128 	Loss: 0.0259
#   Client9 Train => Local Epoch: 3 	Acc: 99.005 	Loss: 0.0275
#   Client9 Train => Local Epoch: 4 	Acc: 99.319 	Loss: 0.0221
#   Client 2
#   Client2 Train => Local Epoch: 0 	Acc: 63.887 	Loss: 1.2824
#   Client2 Train => Local Epoch: 1 	Acc: 95.504 	Loss: 0.1934
#   Client2 Train => Local Epoch: 2 	Acc: 96.519 	Loss: 0.1239
#   Client2 Train => Local Epoch: 3 	Acc: 97.317 	Loss: 0.0851
#   Client2 Train => Local Epoch: 4 	Acc: 97.970 	Loss: 0.0660
#   Client 4
#   Client4 Train => Local Epoch: 0 	Acc: 91.165 	Loss: 0.2536
#   Client4 Train => Local Epoch: 1 	Acc: 96.637 	Loss: 0.0835
#   Client4 Train => Local Epoch: 2 	Acc: 97.385 	Loss: 0.0723
#   Client4 Train => Local Epoch: 3 	Acc: 97.297 	Loss: 0.0711
#   Client4 Train => Local Epoch: 4 	Acc: 97.802 	Loss: 0.0650
# FOT phase: projecting global update onto orthogonal complement.
# Round 96: Train Acc = 70.15% | Test Acc = 64.05% | Test Loss = 1.0561 | Mean FgT = 0.0110 | Time = 35.05s
#
# === Round 97/100 | LR = 0.0100 ===
#   Client 4
#   Client4 Train => Local Epoch: 0 	Acc: 91.341 	Loss: 0.2491
#   Client4 Train => Local Epoch: 1 	Acc: 96.352 	Loss: 0.0941
#   Client4 Train => Local Epoch: 2 	Acc: 97.121 	Loss: 0.0794
#   Client4 Train => Local Epoch: 3 	Acc: 97.736 	Loss: 0.0618
#   Client4 Train => Local Epoch: 4 	Acc: 97.429 	Loss: 0.0736
#   Client 6
#   Client6 Train => Local Epoch: 0 	Acc: 80.701 	Loss: 0.6012
#   Client6 Train => Local Epoch: 1 	Acc: 95.267 	Loss: 0.1375
#   Client6 Train => Local Epoch: 2 	Acc: 97.234 	Loss: 0.0803
#   Client6 Train => Local Epoch: 3 	Acc: 97.603 	Loss: 0.0759
#   Client6 Train => Local Epoch: 4 	Acc: 97.910 	Loss: 0.0584
#   Client 2
#   Client2 Train => Local Epoch: 0 	Acc: 66.570 	Loss: 1.2534
#   Client2 Train => Local Epoch: 1 	Acc: 95.286 	Loss: 0.1901
#   Client2 Train => Local Epoch: 2 	Acc: 96.374 	Loss: 0.1350
#   Client2 Train => Local Epoch: 3 	Acc: 97.027 	Loss: 0.0909
#   Client2 Train => Local Epoch: 4 	Acc: 97.607 	Loss: 0.0755
#   Client 1
#   Client1 Train => Local Epoch: 0 	Acc: 90.216 	Loss: 0.2908
#   Client1 Train => Local Epoch: 1 	Acc: 93.987 	Loss: 0.1641
#   Client1 Train => Local Epoch: 2 	Acc: 94.752 	Loss: 0.1476
#   Client1 Train => Local Epoch: 3 	Acc: 94.805 	Loss: 0.1394
#   Client1 Train => Local Epoch: 4 	Acc: 94.884 	Loss: 0.1391
#   Client 0
#   Client0 Train => Local Epoch: 0 	Acc: 98.763 	Loss: 0.0485
#   Client0 Train => Local Epoch: 1 	Acc: 99.038 	Loss: 0.0279
#   Client0 Train => Local Epoch: 2 	Acc: 98.655 	Loss: 0.0395
#   Client0 Train => Local Epoch: 3 	Acc: 98.322 	Loss: 0.0459
#   Client0 Train => Local Epoch: 4 	Acc: 98.204 	Loss: 0.0522
#   Client 7
#   Client7 Train => Local Epoch: 0 	Acc: 86.393 	Loss: 0.4745
#   Client7 Train => Local Epoch: 1 	Acc: 95.451 	Loss: 0.1452
#   Client7 Train => Local Epoch: 2 	Acc: 96.369 	Loss: 0.1056
#   Client7 Train => Local Epoch: 3 	Acc: 97.326 	Loss: 0.0736
#   Client7 Train => Local Epoch: 4 	Acc: 97.805 	Loss: 0.0682
#   Client 8
#   Client8 Train => Local Epoch: 0 	Acc: 97.338 	Loss: 0.0928
#   Client8 Train => Local Epoch: 1 	Acc: 96.979 	Loss: 0.0885
#   Client8 Train => Local Epoch: 2 	Acc: 96.414 	Loss: 0.1060
#   Client8 Train => Local Epoch: 3 	Acc: 95.154 	Loss: 0.1329
#   Client8 Train => Local Epoch: 4 	Acc: 94.263 	Loss: 0.1613
#   Client 5
#   Client5 Train => Local Epoch: 0 	Acc: 98.250 	Loss: 0.0580
#   Client5 Train => Local Epoch: 1 	Acc: 98.648 	Loss: 0.0393
#   Client5 Train => Local Epoch: 2 	Acc: 98.579 	Loss: 0.0430
#   Client5 Train => Local Epoch: 3 	Acc: 98.449 	Loss: 0.0422
#   Client5 Train => Local Epoch: 4 	Acc: 98.529 	Loss: 0.0430
#   Client 9
#   Client9 Train => Local Epoch: 0 	Acc: 96.004 	Loss: 0.1245
#   Client9 Train => Local Epoch: 1 	Acc: 98.796 	Loss: 0.0348
#   Client9 Train => Local Epoch: 2 	Acc: 99.145 	Loss: 0.0271
#   Client9 Train => Local Epoch: 3 	Acc: 99.197 	Loss: 0.0258
#   Client9 Train => Local Epoch: 4 	Acc: 98.691 	Loss: 0.0422
#   Client 3
#   Client3 Train => Local Epoch: 0 	Acc: 70.924 	Loss: 0.9163
#   Client3 Train => Local Epoch: 1 	Acc: 91.796 	Loss: 0.2741
#   Client3 Train => Local Epoch: 2 	Acc: 91.485 	Loss: 0.2330
#   Client3 Train => Local Epoch: 3 	Acc: 94.704 	Loss: 0.1443
#   Client3 Train => Local Epoch: 4 	Acc: 94.393 	Loss: 0.1535
# FOT phase: projecting global update onto orthogonal complement.
# Round 97: Train Acc = 70.40% | Test Acc = 64.31% | Test Loss = 1.0568 | Mean FgT = 0.0119 | Time = 34.68s
#
# === Round 98/100 | LR = 0.0100 ===
#   Client 2
#   Client2 Train => Local Epoch: 0 	Acc: 63.959 	Loss: 1.3133
#   Client2 Train => Local Epoch: 1 	Acc: 95.649 	Loss: 0.1864
#   Client2 Train => Local Epoch: 2 	Acc: 96.519 	Loss: 0.1307
#   Client2 Train => Local Epoch: 3 	Acc: 96.882 	Loss: 0.0910
#   Client2 Train => Local Epoch: 4 	Acc: 97.172 	Loss: 0.0663
#   Client 4
#   Client4 Train => Local Epoch: 0 	Acc: 91.473 	Loss: 0.2474
#   Client4 Train => Local Epoch: 1 	Acc: 96.835 	Loss: 0.0859
#   Client4 Train => Local Epoch: 2 	Acc: 96.813 	Loss: 0.0848
#   Client4 Train => Local Epoch: 3 	Acc: 97.451 	Loss: 0.0646
#   Client4 Train => Local Epoch: 4 	Acc: 97.538 	Loss: 0.0657
#   Client 7
#   Client7 Train => Local Epoch: 0 	Acc: 86.552 	Loss: 0.4640
#   Client7 Train => Local Epoch: 1 	Acc: 95.491 	Loss: 0.1335
#   Client7 Train => Local Epoch: 2 	Acc: 97.326 	Loss: 0.0774
#   Client7 Train => Local Epoch: 3 	Acc: 97.127 	Loss: 0.0762
#   Client7 Train => Local Epoch: 4 	Acc: 97.925 	Loss: 0.0533
#   Client 3
#   Client3 Train => Local Epoch: 0 	Acc: 71.443 	Loss: 0.8866
#   Client3 Train => Local Epoch: 1 	Acc: 91.173 	Loss: 0.2886
#   Client3 Train => Local Epoch: 2 	Acc: 93.146 	Loss: 0.1931
#   Client3 Train => Local Epoch: 3 	Acc: 94.912 	Loss: 0.1542
#   Client3 Train => Local Epoch: 4 	Acc: 95.431 	Loss: 0.1410
#   Client 0
#   Client0 Train => Local Epoch: 0 	Acc: 99.058 	Loss: 0.0412
#   Client0 Train => Local Epoch: 1 	Acc: 98.920 	Loss: 0.0316
#   Client0 Train => Local Epoch: 2 	Acc: 98.763 	Loss: 0.0364
#   Client0 Train => Local Epoch: 3 	Acc: 98.410 	Loss: 0.0442
#   Client0 Train => Local Epoch: 4 	Acc: 98.116 	Loss: 0.0504
#   Client 8
#   Client8 Train => Local Epoch: 0 	Acc: 96.914 	Loss: 0.1049
#   Client8 Train => Local Epoch: 1 	Acc: 97.066 	Loss: 0.0890
#   Client8 Train => Local Epoch: 2 	Acc: 96.555 	Loss: 0.0978
#   Client8 Train => Local Epoch: 3 	Acc: 94.926 	Loss: 0.1405
#   Client8 Train => Local Epoch: 4 	Acc: 93.252 	Loss: 0.1856
#   Client 9
#   Client9 Train => Local Epoch: 0 	Acc: 95.655 	Loss: 0.1291
#   Client9 Train => Local Epoch: 1 	Acc: 98.587 	Loss: 0.0398
#   Client9 Train => Local Epoch: 2 	Acc: 99.093 	Loss: 0.0278
#   Client9 Train => Local Epoch: 3 	Acc: 98.761 	Loss: 0.0338
#   Client9 Train => Local Epoch: 4 	Acc: 99.145 	Loss: 0.0246
#   Client 5
#   Client5 Train => Local Epoch: 0 	Acc: 98.449 	Loss: 0.0561
#   Client5 Train => Local Epoch: 1 	Acc: 98.917 	Loss: 0.0315
#   Client5 Train => Local Epoch: 2 	Acc: 99.095 	Loss: 0.0273
#   Client5 Train => Local Epoch: 3 	Acc: 98.618 	Loss: 0.0365
#   Client5 Train => Local Epoch: 4 	Acc: 98.231 	Loss: 0.0472
#   Client 1
#   Client1 Train => Local Epoch: 0 	Acc: 90.559 	Loss: 0.2809
#   Client1 Train => Local Epoch: 1 	Acc: 93.697 	Loss: 0.1739
#   Client1 Train => Local Epoch: 2 	Acc: 94.568 	Loss: 0.1493
#   Client1 Train => Local Epoch: 3 	Acc: 94.699 	Loss: 0.1438
#   Client1 Train => Local Epoch: 4 	Acc: 94.699 	Loss: 0.1486
#   Client 6
#   Client6 Train => Local Epoch: 0 	Acc: 81.438 	Loss: 0.5742
#   Client6 Train => Local Epoch: 1 	Acc: 96.128 	Loss: 0.1091
#   Client6 Train => Local Epoch: 2 	Acc: 97.050 	Loss: 0.0898
#   Client6 Train => Local Epoch: 3 	Acc: 97.972 	Loss: 0.0638
#   Client6 Train => Local Epoch: 4 	Acc: 98.156 	Loss: 0.0493
# FOT phase: projecting global update onto orthogonal complement.
# Round 98: Train Acc = 70.23% | Test Acc = 64.00% | Test Loss = 1.0605 | Mean FgT = 0.0156 | Time = 35.28s
#
# === Round 99/100 | LR = 0.0100 ===
#   Client 3
#   Client3 Train => Local Epoch: 0 	Acc: 72.793 	Loss: 0.8567
#   Client3 Train => Local Epoch: 1 	Acc: 91.589 	Loss: 0.2669
#   Client3 Train => Local Epoch: 2 	Acc: 93.873 	Loss: 0.2026
#   Client3 Train => Local Epoch: 3 	Acc: 95.119 	Loss: 0.1584
#   Client3 Train => Local Epoch: 4 	Acc: 95.950 	Loss: 0.1243
#   Client 9
#   Client9 Train => Local Epoch: 0 	Acc: 95.708 	Loss: 0.1313
#   Client9 Train => Local Epoch: 1 	Acc: 98.604 	Loss: 0.0424
#   Client9 Train => Local Epoch: 2 	Acc: 99.058 	Loss: 0.0300
#   Client9 Train => Local Epoch: 3 	Acc: 99.075 	Loss: 0.0301
#   Client9 Train => Local Epoch: 4 	Acc: 99.267 	Loss: 0.0211
#   Client 8
#   Client8 Train => Local Epoch: 0 	Acc: 97.055 	Loss: 0.0995
#   Client8 Train => Local Epoch: 1 	Acc: 97.240 	Loss: 0.0778
#   Client8 Train => Local Epoch: 2 	Acc: 96.599 	Loss: 0.1013
#   Client8 Train => Local Epoch: 3 	Acc: 95.219 	Loss: 0.1323
#   Client8 Train => Local Epoch: 4 	Acc: 94.991 	Loss: 0.1399
#   Client 5
#   Client5 Train => Local Epoch: 0 	Acc: 98.807 	Loss: 0.0476
#   Client5 Train => Local Epoch: 1 	Acc: 99.016 	Loss: 0.0283
#   Client5 Train => Local Epoch: 2 	Acc: 98.827 	Loss: 0.0358
#   Client5 Train => Local Epoch: 3 	Acc: 98.250 	Loss: 0.0500
#   Client5 Train => Local Epoch: 4 	Acc: 97.992 	Loss: 0.0590
#   Client 1
#   Client1 Train => Local Epoch: 0 	Acc: 91.640 	Loss: 0.2810
#   Client1 Train => Local Epoch: 1 	Acc: 94.198 	Loss: 0.1626
#   Client1 Train => Local Epoch: 2 	Acc: 94.937 	Loss: 0.1453
#   Client1 Train => Local Epoch: 3 	Acc: 95.095 	Loss: 0.1426
#   Client1 Train => Local Epoch: 4 	Acc: 95.148 	Loss: 0.1411
#   Client 6
#   Client6 Train => Local Epoch: 0 	Acc: 81.438 	Loss: 0.5734
#   Client6 Train => Local Epoch: 1 	Acc: 95.575 	Loss: 0.1067
#   Client6 Train => Local Epoch: 2 	Acc: 97.480 	Loss: 0.0787
#   Client6 Train => Local Epoch: 3 	Acc: 97.664 	Loss: 0.0573
#   Client6 Train => Local Epoch: 4 	Acc: 98.402 	Loss: 0.0481
#   Client 0
#   Client0 Train => Local Epoch: 0 	Acc: 98.842 	Loss: 0.0444
#   Client0 Train => Local Epoch: 1 	Acc: 98.862 	Loss: 0.0326
#   Client0 Train => Local Epoch: 2 	Acc: 98.734 	Loss: 0.0325
#   Client0 Train => Local Epoch: 3 	Acc: 98.273 	Loss: 0.0469
#   Client0 Train => Local Epoch: 4 	Acc: 97.988 	Loss: 0.0529
#   Client 4
#   Client4 Train => Local Epoch: 0 	Acc: 91.780 	Loss: 0.2405
#   Client4 Train => Local Epoch: 1 	Acc: 96.967 	Loss: 0.0780
#   Client4 Train => Local Epoch: 2 	Acc: 96.505 	Loss: 0.0918
#   Client4 Train => Local Epoch: 3 	Acc: 97.736 	Loss: 0.0698
#   Client4 Train => Local Epoch: 4 	Acc: 97.846 	Loss: 0.0583
#   Client 2
#   Client2 Train => Local Epoch: 0 	Acc: 64.612 	Loss: 1.2853
#   Client2 Train => Local Epoch: 1 	Acc: 95.141 	Loss: 0.1684
#   Client2 Train => Local Epoch: 2 	Acc: 96.447 	Loss: 0.1177
#   Client2 Train => Local Epoch: 3 	Acc: 96.954 	Loss: 0.1012
#   Client2 Train => Local Epoch: 4 	Acc: 97.752 	Loss: 0.0660
#   Client 7
#   Client7 Train => Local Epoch: 0 	Acc: 86.792 	Loss: 0.4464
#   Client7 Train => Local Epoch: 1 	Acc: 95.571 	Loss: 0.1447
#   Client7 Train => Local Epoch: 2 	Acc: 96.169 	Loss: 0.1343
#   Client7 Train => Local Epoch: 3 	Acc: 97.446 	Loss: 0.0770
#   Client7 Train => Local Epoch: 4 	Acc: 97.207 	Loss: 0.0758
# FOT phase: projecting global update onto orthogonal complement.
# Round 99: Train Acc = 70.53% | Test Acc = 64.09% | Test Loss = 1.0478 | Mean FgT = 0.0028 | Time = 34.87s
#
# === Round 100/100 | LR = 0.0100 ===
#   Client 3
#   Client3 Train => Local Epoch: 0 	Acc: 73.313 	Loss: 0.8769
#   Client3 Train => Local Epoch: 1 	Acc: 90.862 	Loss: 0.3030
#   Client3 Train => Local Epoch: 2 	Acc: 92.523 	Loss: 0.2236
#   Client3 Train => Local Epoch: 3 	Acc: 94.081 	Loss: 0.1722
#   Client3 Train => Local Epoch: 4 	Acc: 94.704 	Loss: 0.1429
#   Client 0
#   Client0 Train => Local Epoch: 0 	Acc: 98.783 	Loss: 0.0496
#   Client0 Train => Local Epoch: 1 	Acc: 98.783 	Loss: 0.0350
#   Client0 Train => Local Epoch: 2 	Acc: 98.714 	Loss: 0.0373
#   Client0 Train => Local Epoch: 3 	Acc: 98.528 	Loss: 0.0428
#   Client0 Train => Local Epoch: 4 	Acc: 98.430 	Loss: 0.0445
#   Client 7
#   Client7 Train => Local Epoch: 0 	Acc: 87.271 	Loss: 0.4312
#   Client7 Train => Local Epoch: 1 	Acc: 96.049 	Loss: 0.1258
#   Client7 Train => Local Epoch: 2 	Acc: 97.007 	Loss: 0.0978
#   Client7 Train => Local Epoch: 3 	Acc: 96.728 	Loss: 0.0923
#   Client7 Train => Local Epoch: 4 	Acc: 97.486 	Loss: 0.0713
#   Client 5
#   Client5 Train => Local Epoch: 0 	Acc: 98.638 	Loss: 0.0535
#   Client5 Train => Local Epoch: 1 	Acc: 99.076 	Loss: 0.0271
#   Client5 Train => Local Epoch: 2 	Acc: 98.926 	Loss: 0.0294
#   Client5 Train => Local Epoch: 3 	Acc: 98.241 	Loss: 0.0479
#   Client5 Train => Local Epoch: 4 	Acc: 98.410 	Loss: 0.0438
#   Client 6
#   Client6 Train => Local Epoch: 0 	Acc: 81.254 	Loss: 0.5714
#   Client6 Train => Local Epoch: 1 	Acc: 96.620 	Loss: 0.1047
#   Client6 Train => Local Epoch: 2 	Acc: 97.357 	Loss: 0.0775
#   Client6 Train => Local Epoch: 3 	Acc: 97.357 	Loss: 0.0787
#   Client6 Train => Local Epoch: 4 	Acc: 97.910 	Loss: 0.0624
#   Client 4
#   Client4 Train => Local Epoch: 0 	Acc: 91.890 	Loss: 0.2381
#   Client4 Train => Local Epoch: 1 	Acc: 96.198 	Loss: 0.1034
#   Client4 Train => Local Epoch: 2 	Acc: 96.286 	Loss: 0.0916
#   Client4 Train => Local Epoch: 3 	Acc: 96.967 	Loss: 0.0747
#   Client4 Train => Local Epoch: 4 	Acc: 97.780 	Loss: 0.0560
#   Client 8
#   Client8 Train => Local Epoch: 0 	Acc: 97.653 	Loss: 0.0887
#   Client8 Train => Local Epoch: 1 	Acc: 97.479 	Loss: 0.0782
#   Client8 Train => Local Epoch: 2 	Acc: 96.077 	Loss: 0.1122
#   Client8 Train => Local Epoch: 3 	Acc: 95.469 	Loss: 0.1278
#   Client8 Train => Local Epoch: 4 	Acc: 94.654 	Loss: 0.1501
#   Client 1
#   Client1 Train => Local Epoch: 0 	Acc: 91.060 	Loss: 0.2762
#   Client1 Train => Local Epoch: 1 	Acc: 94.304 	Loss: 0.1640
#   Client1 Train => Local Epoch: 2 	Acc: 94.752 	Loss: 0.1394
#   Client1 Train => Local Epoch: 3 	Acc: 94.277 	Loss: 0.1474
#   Client1 Train => Local Epoch: 4 	Acc: 95.280 	Loss: 0.1371
#   Client 2
#   Client2 Train => Local Epoch: 0 	Acc: 65.917 	Loss: 1.2821
#   Client2 Train => Local Epoch: 1 	Acc: 95.286 	Loss: 0.1656
#   Client2 Train => Local Epoch: 2 	Acc: 96.519 	Loss: 0.1120
#   Client2 Train => Local Epoch: 3 	Acc: 97.244 	Loss: 0.0772
#   Client2 Train => Local Epoch: 4 	Acc: 97.679 	Loss: 0.0748
#   Client 9
#   Client9 Train => Local Epoch: 0 	Acc: 96.039 	Loss: 0.1227
#   Client9 Train => Local Epoch: 1 	Acc: 98.552 	Loss: 0.0478
#   Client9 Train => Local Epoch: 2 	Acc: 99.285 	Loss: 0.0239
#   Client9 Train => Local Epoch: 3 	Acc: 99.180 	Loss: 0.0248
#   Client9 Train => Local Epoch: 4 	Acc: 99.058 	Loss: 0.0243
# FOT phase: projecting global update onto orthogonal complement.
# Round 100: Train Acc = 70.97% | Test Acc = 65.01% | Test Loss = 1.0368 | Mean FgT = -0.0078 | Time = 34.59s
#
# Training finished.
# Final Test Accuracy: 65.01% | Loss: 1.0368
# Saved: FOT - CIFAR-10 α=0.1.csv
