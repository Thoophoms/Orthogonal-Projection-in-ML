# %% [markdown]
# # Split learning
# ### ResNet18 on CIFAR-100 + α = 0.5

# %%
#=============================================================================
# Split learning: ResNet18 on CIFAR-100
# This program is Version1: Single program simulation 
# ============================================================================
import torch
from torch import nn
from torchvision import transforms
from torchvision import datasets
from torch.utils.data import DataLoader, Dataset
import torch.nn.functional as F
import math
import os.path
import pandas as pd

from sklearn.model_selection import train_test_split
from PIL import Image
from glob import glob 
from pandas import DataFrame
import random
import numpy as np
import os


import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import copy
import time

def _sync_cuda():
    if torch.cuda.is_available():
        torch.cuda.synchronize()


SEED = 1234
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
if torch.cuda.is_available():
    torch.backends.cudnn.deterministic = True
    print(torch.cuda.get_device_name(0))    

#===================================================================  
ALPHA = 0.5   # requested alpha
DATASET_NAME = "CIFAR100"
program = "SL - CIFAR-100 α=0.5"



print(f"---------{program}----------")              # this is to identify the program in the slurm outputs files

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# To print in color -------test/train of the client side
def prRed(skk): print("\033[91m {}\033[00m" .format(skk)) 
def prGreen(skk): print("\033[92m {}\033[00m" .format(skk))     

#===================================================================  
# No. of users
DATA_ROOT = "./data"
NUM_CLIENTS = 10
EPOCHS = 200
frac = 1   # participation of clients; if 1 then 100% clients participate in SL
BASE_LR = 0.001
LOCAL_EPOCHS = 5
NUM_WORKERS = 4
BATCH_SIZE = 256
MOMENTUM = 0.9
WEIGHT_DECAY = 5e-4


CIFAR_MEAN = {
    "CIFAR10": [0.4914, 0.4822, 0.4465],
    "CIFAR100": [0.5071, 0.4867, 0.4408],
}[DATASET_NAME]
CIFAR_STD = {
    "CIFAR10": [0.2470, 0.2435, 0.2616],
    "CIFAR100": [0.2675, 0.2565, 0.2761],
}[DATASET_NAME]



# ====================== Confirm =======================================
cut_at = "Original at 2"
prRed(f"\tData:\t\t{DATASET_NAME}\n\tCut:\t\t{cut_at}\n\tGlobal Rounds:\t{EPOCHS}\n\tClients:\t{NUM_CLIENTS}\n\tLocal Epochs:\t{LOCAL_EPOCHS}\n\tα:\t\t{ALPHA}\n\tWarm-up:\t0\n\tRebuild:\t0")


#=====================================================================================================
#                           Client-side Model definition
#=====================================================================================================
# Model at client side
class ResNet18_client_side(nn.Module):
    def __init__(self):
        super(ResNet18_client_side, self).__init__()
        self.layer1 = nn.Sequential (
                nn.Conv2d(3, 64, kernel_size = 7, stride = 2, padding = 3, bias = False),
                nn.BatchNorm2d(64),
                nn.ReLU (inplace = True),
                nn.MaxPool2d(kernel_size = 3, stride = 2, padding =1),
            )
        self.layer2 = nn.Sequential  (
                nn.Conv2d(64, 64, kernel_size = 3, stride = 1, padding = 1, bias = False),
                nn.BatchNorm2d(64),
                nn.ReLU (inplace = True),
                nn.Conv2d(64, 64, kernel_size = 3, stride = 1, padding = 1),
                nn.BatchNorm2d(64),              
            )
        
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                m.weight.data.normal_(0, math.sqrt(2. / n))
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()
        
        
    def forward(self, x):
        resudial1 = F.relu(self.layer1(x))
        out1 = self.layer2(resudial1)
        out1 = out1 + resudial1 # adding the resudial inputs -- downsampling not required in this layer
        resudial2 = F.relu(out1)
        return resudial2
 
 
           

net_glob_client = ResNet18_client_side()
if torch.cuda.device_count() > 1:
    print("We use",torch.cuda.device_count(), "GPUs")
    net_glob_client = nn.DataParallel(net_glob_client)   # to use the multiple GPUs; later we can change this to CPUs only 

net_glob_client.to(device)
print(net_glob_client)     


#=====================================================================================================
#                           Server-side Model definition
#=====================================================================================================
# Model at server side
class Baseblock(nn.Module):
    expansion = 1
    def __init__(self, input_planes, planes, stride = 1, dim_change = None):
        super(Baseblock, self).__init__()
        self.conv1 = nn.Conv2d(input_planes, planes, stride =  stride, kernel_size = 3, padding = 1)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, stride = 1, kernel_size = 3, padding = 1)
        self.bn2 = nn.BatchNorm2d(planes)
        self.dim_change = dim_change
        
    def forward(self, x):
        res = x
        output = F.relu(self.bn1(self.conv1(x)))
        output = self.bn2(self.conv2(output))
        
        if self.dim_change is not None:
            res =self.dim_change(res)
            
        output += res
        output = F.relu(output)
        
        return output


class ResNet18_server_side(nn.Module):
    def __init__(self, block, num_layers, classes):
        super(ResNet18_server_side, self).__init__()
        self.input_planes = 64
        self.layer3 = nn.Sequential (
                nn.Conv2d(64, 64, kernel_size = 3, stride = 1, padding = 1),
                nn.BatchNorm2d(64),
                nn.ReLU (inplace = True),
                nn.Conv2d(64, 64, kernel_size = 3, stride = 1, padding = 1),
                nn.BatchNorm2d(64),       
                )   
        
        self.layer4 = self._layer(block, 128, num_layers[0], stride = 2)
        self.layer5 = self._layer(block, 256, num_layers[1], stride = 2)
        self.layer6 = self._layer(block, 512, num_layers[2], stride = 2)
        self. averagePool = nn.AvgPool2d(kernel_size = 7, stride = 1)
        self.fc = nn.Linear(512 * block.expansion, classes)
        
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                m.weight.data.normal_(0, math.sqrt(2. / n))
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()
        
        
    def _layer(self, block, planes, num_layers, stride = 2):
        dim_change = None
        if stride != 1 or planes != self.input_planes * block.expansion:
            dim_change = nn.Sequential(nn.Conv2d(self.input_planes, planes*block.expansion, kernel_size = 1, stride = stride),
                                       nn.BatchNorm2d(planes*block.expansion))
        netLayers = []
        netLayers.append(block(self.input_planes, planes, stride = stride, dim_change = dim_change))
        self.input_planes = planes * block.expansion
        for i in range(1, num_layers):
            netLayers.append(block(self.input_planes, planes))
            self.input_planes = planes * block.expansion
            
        return nn.Sequential(*netLayers)
        
    
    def forward(self, x):
        out2 = self.layer3(x)
        out2 = out2 + x          # adding the resudial inputs -- downsampling not required in this layer
        x3 = F.relu(out2)
        
        x4 = self. layer4(x3)
        x5 = self.layer5(x4)
        x6 = self.layer6(x5)
        
        # x7 = F.avg_pool2d(x6, 7)
        x7 = F.adaptive_avg_pool2d(x6, 1) 
        x8 = x7.view(x7.size(0), -1) 
        y_hat =self.fc(x8)
        
        return y_hat

# net_glob_server = ResNet18_server_side(Baseblock, [2,2,2], 7) #7 is my numbr of classes
if DATASET_NAME == "CIFAR10":
    net_glob_server = ResNet18_server_side(Baseblock, [2,2,2], 10)  # 10 classes for CIFAR-10
else:
    net_glob_server = ResNet18_server_side(Baseblock, [2,2,2], 100)


if torch.cuda.device_count() > 1:
    print("We use",torch.cuda.device_count(), "GPUs")
    net_glob_server = nn.DataParallel(net_glob_server)   # to use the multiple GPUs 

net_glob_server.to(device)
print(net_glob_server)      

#===================================================================================
# For Server Side Loss and Accuracy 
loss_train_collect = []
acc_train_collect = []
loss_test_collect = []
acc_test_collect = []
batch_acc_train = []
batch_loss_train = []
batch_acc_test = []
batch_loss_test = []
round_time_collect = [] # Stores seconds per global round

criterion = nn.CrossEntropyLoss()
count1 = 0
count2 = 0

#====================================================================================================
#                                  Server Side Program
#====================================================================================================
def calculate_accuracy(fx, y):
    preds = fx.max(1, keepdim=True)[1]
    correct = preds.eq(y.view_as(preds)).sum()
    acc = 100.00 *correct.float()/preds.shape[0]
    return acc

# to print train - test together in each round-- these are made global
acc_avg_all_user_train = 0
loss_avg_all_user_train = 0
loss_train_collect_user = []
acc_train_collect_user = []
loss_test_collect_user = []
acc_test_collect_user = []


#client idx collector
idx_collect = []
l_epoch_check = False
fed_check = False


optimizer_server = torch.optim.SGD(net_glob_server.parameters(), lr = BASE_LR, momentum=MOMENTUM, weight_decay=WEIGHT_DECAY)

# Server-side function associated with Training 
def train_server(fx_client, y, l_epoch_count, l_epoch, idx, len_batch):
    global optimizer_server
    global net_glob_server, criterion, device, batch_acc_train, batch_loss_train, l_epoch_check, fed_check
    global loss_train_collect, acc_train_collect, count1, acc_avg_all_user_train, loss_avg_all_user_train, idx_collect
    global loss_train_collect_user, acc_train_collect_user
    
    net_glob_server.train()
    
    # Clear gradient
    optimizer_server.zero_grad() 
    
    fx_client = fx_client.to(device)
    y = y.to(device)
    
    #---------forward prop-------------
    fx_server = net_glob_server(fx_client)
    
    # calculate loss
    loss = criterion(fx_server, y)
    # calculate accuracy
    acc = calculate_accuracy(fx_server, y)
    
    #--------backward prop--------------
    loss.backward()
    dfx_client = fx_client.grad.clone().detach()
    optimizer_server.step()
    
    batch_loss_train.append(loss.item())
    batch_acc_train.append(acc.item())
    
    # server-side model net_glob_server is global so it is updated automatically in each pass to this function
        # count1: to track the completion of the local batch associated with one client
    count1 += 1
    if count1 == len_batch:
        acc_avg_train = sum(batch_acc_train)/len(batch_acc_train)           # it has accuracy for one batch
        loss_avg_train = sum(batch_loss_train)/len(batch_loss_train)
        
        batch_acc_train = []
        batch_loss_train = []
        count1 = 0
        
        prRed('Client{} Train => Local Epoch: {} \tAcc: {:.3f} \tLoss: {:.4f}'.format(idx, l_epoch_count, acc_avg_train, loss_avg_train))
        
                
        # If one local epoch is completed, after this a new client will come
        if l_epoch_count == l_epoch-1:
            
            l_epoch_check = True                # for evaluate_server function - to check local epoch has hitted 
                       
            # we store the last accuracy in the last batch of the epoch and it is not the average of all local epochs
            # this is because we work on the last trained model and its accuracy (not earlier cases)
            
            #print("accuracy = ", acc_avg_train)
            acc_avg_train_all = acc_avg_train
            loss_avg_train_all = loss_avg_train
                        
            # accumulate accuracy and loss for each new user
            loss_train_collect_user.append(loss_avg_train_all)
            acc_train_collect_user.append(acc_avg_train_all)
            
            # collect the id of each new user                        
            if idx not in idx_collect:
                idx_collect.append(idx) 
                #print(idx_collect)
        
        # This is to check if all users are served for one round --------------------
        if len(idx_collect) == NUM_CLIENTS:
            fed_check = True                                                  # for evaluate_server function  - to check fed check has hitted
            # all users served for one round ------------------------- output print and update is done in evaluate_server()
            # for nicer display 
                        
            idx_collect = []
            
            acc_avg_all_user_train = sum(acc_train_collect_user)/len(acc_train_collect_user)
            loss_avg_all_user_train = sum(loss_train_collect_user)/len(loss_train_collect_user)
            
            loss_train_collect.append(loss_avg_all_user_train)
            acc_train_collect.append(acc_avg_all_user_train)
            
            acc_train_collect_user = []
            loss_train_collect_user = []
            
    # send gradients to the client               
    return dfx_client

# Server-side functions associated with Testing
def evaluate_server(fx_client, y, idx, len_batch, ell):
    global net_glob_server, criterion, batch_acc_test, batch_loss_test
    global loss_test_collect, acc_test_collect, count2, num_users, acc_avg_train_all, loss_avg_train_all, l_epoch_check, fed_check
    global loss_test_collect_user, acc_test_collect_user, acc_avg_all_user_train, loss_avg_all_user_train
    
    net_glob_server.eval()
  
    with torch.no_grad():
        fx_client = fx_client.to(device)
        y = y.to(device) 
        #---------forward prop-------------
        fx_server = net_glob_server(fx_client)
        
        # calculate loss
        loss = criterion(fx_server, y)
        # calculate accuracy
        acc = calculate_accuracy(fx_server, y)
        
        
        batch_loss_test.append(loss.item())
        batch_acc_test.append(acc.item())
        
               
        count2 += 1
        if count2 == len_batch:
            acc_avg_test = sum(batch_acc_test)/len(batch_acc_test)
            loss_avg_test = sum(batch_loss_test)/len(batch_loss_test)
            
            batch_acc_test = []
            batch_loss_test = []
            count2 = 0
            
            prGreen('Client{} Test =>                   \tAcc: {:.3f} \tLoss: {:.4f}'.format(idx, acc_avg_test, loss_avg_test))
            
            # if a local epoch is completed   
            if l_epoch_check:
                l_epoch_check = False
                
                # Store the last accuracy and loss
                acc_avg_test_all = acc_avg_test
                loss_avg_test_all = loss_avg_test
                        
                loss_test_collect_user.append(loss_avg_test_all)
                acc_test_collect_user.append(acc_avg_test_all)
                
            # if all users are served for one round ----------                    
            if fed_check:
                fed_check = False
                                
                acc_avg_all_user = sum(acc_test_collect_user)/len(acc_test_collect_user)
                loss_avg_all_user = sum(loss_test_collect_user)/len(loss_test_collect_user)
            
                loss_test_collect.append(loss_avg_all_user)
                acc_test_collect.append(acc_avg_all_user)
                acc_test_collect_user = []
                loss_test_collect_user= []
                              
                print("====================== SERVER V1==========================")
                print(' Train: Round {:3d}, Avg Accuracy {:.3f} | Avg Loss {:.3f}'.format(ell, acc_avg_all_user_train, loss_avg_all_user_train))
                print(' Test: Round {:3d}, Avg Accuracy {:.3f} | Avg Loss {:.3f}'.format(ell, acc_avg_all_user, loss_avg_all_user))
                # print("==========================================================")
         
    return 

#==============================================================================================================
#                                       Clients Side Program
#==============================================================================================================
class DatasetSplit(Dataset):
    def __init__(self, dataset, idxs):
        self.dataset = dataset
        self.idxs = list(idxs)

    def __len__(self):
        return len(self.idxs)

    def __getitem__(self, item):
        image, label = self.dataset[self.idxs[item]]
        return image, label

# Client-side functions associated with Training and Testing
class Client(object):
    def __init__(self, net_client_model, idx, lr, device, dataset_train = None, dataset_test = None, idxs = None, idxs_test = None):
        self.idx = idx
        self.device = device
        self.lr = lr
        self.local_ep = LOCAL_EPOCHS 
        #self.selected_clients = []
        self.ldr_train = DataLoader(DatasetSplit(dataset_train, idxs), batch_size = BATCH_SIZE, shuffle = True, num_workers=NUM_WORKERS)
        self.ldr_test = DataLoader(DatasetSplit(dataset_test, idxs_test), batch_size = BATCH_SIZE, shuffle = False, num_workers=NUM_WORKERS)
        

    def train(self, net):
        net.train()
        optimizer_client = torch.optim.SGD(net.parameters(), lr = self.lr, momentum=MOMENTUM, weight_decay=WEIGHT_DECAY) 
        
        for iter in range(self.local_ep):
            len_batch = len(self.ldr_train)
            for batch_idx, (images, labels) in enumerate(self.ldr_train):
                images, labels = images.to(self.device), labels.to(self.device)
                optimizer_client.zero_grad()
                #---------forward prop-------------
                fx = net(images)
                client_fx = fx.clone().detach().requires_grad_(True)
                
                # Sending activations to server and receiving gradients from server
                dfx = train_server(client_fx, labels, iter, self.local_ep, self.idx, len_batch)
                
                #--------backward prop -------------
                fx.backward(dfx)
                optimizer_client.step()
                            
            
            #prRed('Client{} Train => Epoch: {}'.format(self.idx, ell))
           
        return net.state_dict() 
    
    def evaluate(self, net, ell):
        net.eval()
           
        with torch.no_grad():
            len_batch = len(self.ldr_test)
            for batch_idx, (images, labels) in enumerate(self.ldr_test):
                images, labels = images.to(self.device), labels.to(self.device)
                #---------forward prop-------------
                fx = net(images)
                
                # Sending activations to server 
                evaluate_server(fx, labels, self.idx, len_batch, ell)
            
            #prRed('Client{} Test => Epoch: {}'.format(self.idx, ell))
            
        return          
#=====================================================================================================
# dataset_iid() will create a dictionary to collect the indices of the data samples randomly for each client
# IID HAM10000 datasets will be created based on this
def dataset_iid(dataset, num_users):
    
    num_items = int(len(dataset)/num_users)
    dict_users, all_idxs = {}, [i for i in range(len(dataset))]
    for i in range(num_users):
        dict_users[i] = set(np.random.choice(all_idxs, num_items, replace = False))
        all_idxs = list(set(all_idxs) - dict_users[i])
    return dict_users    

def dataset_noniid_dirichlet(dataset, num_users, alpha=ALPHA, seed=SEED):
    """Return dict_users: {client_id -> set(sample_indices)} using Dirichlet(α)."""
    rng = np.random.default_rng(seed)
    labels = np.array(dataset.targets)  # CIFAR-10 stores labels here
    n_classes = len(np.unique(labels))
    dict_users = {i: set() for i in range(num_users)}

    for c in range(n_classes):
        idxs = np.where(labels == c)[0]
        rng.shuffle(idxs)
        
        # draw proportions for this class
        p = rng.dirichlet([alpha] * num_users)
        
        # split indices by cumulative proportions
        cuts = (np.cumsum(p) * len(idxs)).astype(int)[:-1]
        
        splits = np.split(idxs, cuts)
        for client_id, split in enumerate(splits):
            dict_users[client_id].update(split.tolist())
    return dict_users




#=============================================================================
#                         Data loading 
#============================================================================= 

# CIFAR-10 normalization
train_transforms = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(32, padding=4),
    transforms.ToTensor(),
    transforms.Normalize(mean=CIFAR_MEAN, std=CIFAR_STD),
])

test_transforms = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=CIFAR_MEAN, std=CIFAR_STD),
])

if DATASET_NAME == "CIFAR10":
    dataset_train = datasets.CIFAR10(
        root=DATA_ROOT, train=True, download=True, transform=train_transforms
    )
    dataset_test = datasets.CIFAR10(
        root=DATA_ROOT, train=False, download=True, transform=test_transforms
    )
    NUM_CLASSES = 10
else:
    dataset_train = datasets.CIFAR100(
        root=DATA_ROOT, train=True, download=True, transform=train_transforms
    )
    dataset_test = datasets.CIFAR100(
        root=DATA_ROOT, train=False, download=True, transform=test_transforms
    )
    NUM_CLASSES = 100



#=============================================================================
#                         Forgetting metric setup 
#============================================================================= 

from collections import defaultdict

# Treat each global round as a window (quick baseline).
# If you want true distribution shifts, predefine your own windows and fill `val_loaders`.
T = EPOCHS

val_loaders = {}
# Deterministic, disjoint slices of the test set: window t gets items t, t+T, t+2T, ...
rng_idx = np.arange(len(dataset_test))
for t in range(T):
    idxs = rng_idx[t::T]
    val_loaders[t] = DataLoader(DatasetSplit(dataset_test, idxs),
                                batch_size=BATCH_SIZE, shuffle=False, num_workers=NUM_WORKERS,drop_last=False)

best_loss_per_window = defaultdict(lambda: float('inf'))  # stores min historical loss per window
forgetting_log = []  # per round dicts: {"round": t, "mean_forgetting": x, "per_window": {...}}
# ============================================================================

def _eval_loss_on_loader(model_client, model_server, loader, device, criterion):
    """Evaluate mean loss on a loader using split models."""
    # Handle DataParallel transparently
    mc = model_client.module if isinstance(model_client, nn.DataParallel) else model_client
    ms = model_server.module if isinstance(model_server, nn.DataParallel) else model_server
    mc.eval(); ms.eval()
    loss_sum, n = 0.0, 0
    with torch.no_grad():
        for images, labels in loader:
            images, labels = images.to(device), labels.to(device)
            fx = mc(images)
            logits = ms(fx)
            loss = criterion(logits, labels)
            bs = labels.size(0)
            loss_sum += loss.item() * bs
            n += bs
    return loss_sum / max(1, n)

#----------------------------------------------------------------
# dict_users = dataset_iid(dataset_train, num_users)
# dict_users_test = dataset_iid(dataset_test, num_users)

dict_users      = dataset_noniid_dirichlet(dataset_train, num_users=NUM_CLIENTS, alpha=ALPHA)
dict_users_test = dataset_iid(dataset_test, num_users=NUM_CLIENTS)  



#net_glob_client.train()
# this epoch is global epoch, also known as rounds
# this epoch is global epoch, also known as rounds
for iter in range(EPOCHS):
    # ---- START TIMER ----
    _sync_cuda()
    t0 = time.perf_counter()
    # ---------------------

    m = max(int(frac * NUM_CLIENTS), 1)
    idxs_users = np.random.choice(range(NUM_CLIENTS), m, replace=False)

    # Sequential training/testing among clients
    for idx in idxs_users:
        local = Client(net_glob_client, idx, BASE_LR, device,
                       dataset_train=dataset_train, dataset_test=dataset_test,
                       idxs=dict_users[idx], idxs_test=dict_users_test[idx])

        # Training
        w_client = local.train(net=copy.deepcopy(net_glob_client).to(device))

        # Testing
        local.evaluate(net=copy.deepcopy(net_glob_client).to(device), ell=iter)

        # Update client weights for next client
         # copy weight to net_glob_client -- use to update the client-side model of the next client to be trained
        net_glob_client.load_state_dict(w_client)

    # ---- STOP TIMER & LOG ----
    _sync_cuda()
    dt = time.perf_counter() - t0
    
    # === Forgetting update at end of round `iter` ================================
    t = iter  # current window id

    # 1) Update the "best so far" for the CURRENT window using the current model
    L_cur_t = _eval_loss_on_loader(net_glob_client, net_glob_server, val_loaders[t], device, criterion)
    if math.isfinite(L_cur_t):
        best_loss_per_window[t] = min(best_loss_per_window[t], L_cur_t)

    # 2) Compute forgetting on all PAST windows t0 < t
    per_win_fgt = {}
    for t0 in range(t):
        L_now = _eval_loss_on_loader(net_glob_client, net_glob_server, val_loaders[t0], device, criterion)
        best = best_loss_per_window[t0]
        if not (math.isfinite(L_now) and math.isfinite(best)):
            continue
        Fgt = L_now - best
        per_win_fgt[t0] = Fgt
        
    mean_fgt = float(np.mean(list(per_win_fgt.values()))) if per_win_fgt else 0.0
    forgetting_log.append({"round": t, "mean_forgetting": mean_fgt, "per_window": per_win_fgt})
    print(f"Forgetting : Round {t}, mean_forgetting : {mean_fgt:.3f}")
    print("==========================================================")
    # =============================================================================
    
    round_time_collect.append(dt)
    # -------------------------- 
    



print("Training and Evaluation completed!")    

#===============================================================================
# Save output data to .excel file (we use for comparision plots)
# Align lengths safely (in case of early stop or mismatch)
n = min(len(acc_train_collect), len(acc_test_collect), len(round_time_collect), len(forgetting_log))
round_process = list(range(1, n+1))
mean_fgt_series = [d["mean_forgetting"] for d in forgetting_log[:n]]

df = DataFrame({
    'round': round_process,
    'acc_train': acc_train_collect[:n],
    'acc_test':  acc_test_collect[:n],
    'round_time_sec': round_time_collect[:n],   # time
    'mean_FgT_loss': mean_fgt_series, 
})

# write CSV — easier for scripting/comparison tools
file_name_csv = program + ".csv"
df.to_csv(file_name_csv, index=False)

print("Saved:", file_name_csv)

#=============================================================================
#                         Program Completed
#=============================================================================
# Out:
# NVIDIA H200
# ---------SL - CIFAR-10 α=0.5----------
# ResNet18_client_side(
#   (layer1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (layer2): Sequential(
#     (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# ResNet18_server_side(
#   (layer3): Sequential(
#     (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (layer4): Sequential(
#     (0): Baseblock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dim_change): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2))
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Baseblock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer5): Sequential(
#     (0): Baseblock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dim_change): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2))
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Baseblock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer6): Sequential(
#     (0): Baseblock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dim_change): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2))
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Baseblock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (averagePool): AvgPool2d(kernel_size=7, stride=1, padding=0)
#   (fc): Linear(in_features=512, out_features=10, bias=True)
# )
#  Client3 Train => Local Epoch: 0 	Acc: 44.008 	Loss: 1.7715
#  Client3 Train => Local Epoch: 1 	Acc: 50.445 	Loss: 1.4965
#  Client3 Train => Local Epoch: 2 	Acc: 52.032 	Loss: 1.4297
#  Client3 Train => Local Epoch: 3 	Acc: 55.133 	Loss: 1.3262
#  Client3 Train => Local Epoch: 4 	Acc: 57.681 	Loss: 1.2393
#  Client3 Test =>                   	Acc: 12.951 	Loss: 4.0993
#  Client1 Train => Local Epoch: 0 	Acc: 53.575 	Loss: 1.7948
#  Client1 Train => Local Epoch: 1 	Acc: 66.649 	Loss: 1.1462
#  Client1 Train => Local Epoch: 2 	Acc: 68.136 	Loss: 0.9514
#  Client1 Train => Local Epoch: 3 	Acc: 70.797 	Loss: 0.8965
#  Client1 Train => Local Epoch: 4 	Acc: 70.976 	Loss: 0.8791
#  Client1 Test =>                   	Acc: 26.761 	Loss: 3.1452
#  Client2 Train => Local Epoch: 0 	Acc: 53.424 	Loss: 1.4438
#  Client2 Train => Local Epoch: 1 	Acc: 61.041 	Loss: 1.1297
#  Client2 Train => Local Epoch: 2 	Acc: 63.524 	Loss: 1.0534
#  Client2 Train => Local Epoch: 3 	Acc: 64.990 	Loss: 1.0049
#  Client2 Train => Local Epoch: 4 	Acc: 66.267 	Loss: 0.9613
#  Client2 Test =>                   	Acc: 40.537 	Loss: 2.1634
#  Client0 Train => Local Epoch: 0 	Acc: 47.390 	Loss: 1.6621
#  Client0 Train => Local Epoch: 1 	Acc: 54.378 	Loss: 1.2799
#  Client0 Train => Local Epoch: 2 	Acc: 58.064 	Loss: 1.1729
#  Client0 Train => Local Epoch: 3 	Acc: 60.855 	Loss: 1.1047
#  Client0 Train => Local Epoch: 4 	Acc: 63.966 	Loss: 1.0238
#  Client0 Test =>                   	Acc: 42.161 	Loss: 1.8134
#  Client8 Train => Local Epoch: 0 	Acc: 51.854 	Loss: 1.5175
#  Client8 Train => Local Epoch: 1 	Acc: 60.455 	Loss: 1.1527
#  Client8 Train => Local Epoch: 2 	Acc: 63.561 	Loss: 0.9710
#  Client8 Train => Local Epoch: 3 	Acc: 65.646 	Loss: 0.9227
#  Client8 Train => Local Epoch: 4 	Acc: 67.057 	Loss: 0.8725
#  Client8 Test =>                   	Acc: 35.476 	Loss: 3.0552
#  Client7 Train => Local Epoch: 0 	Acc: 56.764 	Loss: 1.5112
#  Client7 Train => Local Epoch: 1 	Acc: 67.030 	Loss: 1.0052
#  Client7 Train => Local Epoch: 2 	Acc: 68.847 	Loss: 0.9094
#  Client7 Train => Local Epoch: 3 	Acc: 71.115 	Loss: 0.8385
#  Client7 Train => Local Epoch: 4 	Acc: 71.861 	Loss: 0.8036
#  Client7 Test =>                   	Acc: 35.964 	Loss: 2.5046
#  Client6 Train => Local Epoch: 0 	Acc: 50.388 	Loss: 1.7148
#  Client6 Train => Local Epoch: 1 	Acc: 62.695 	Loss: 1.0982
#  Client6 Train => Local Epoch: 2 	Acc: 64.566 	Loss: 1.0128
#  Client6 Train => Local Epoch: 3 	Acc: 65.900 	Loss: 0.9747
#  Client6 Train => Local Epoch: 4 	Acc: 66.399 	Loss: 0.9552
#  Client6 Test =>                   	Acc: 39.888 	Loss: 2.1141
#  Client9 Train => Local Epoch: 0 	Acc: 56.150 	Loss: 1.3273
#  Client9 Train => Local Epoch: 1 	Acc: 60.779 	Loss: 1.1140
#  Client9 Train => Local Epoch: 2 	Acc: 61.680 	Loss: 1.0727
#  Client9 Train => Local Epoch: 3 	Acc: 64.119 	Loss: 1.0031
#  Client9 Train => Local Epoch: 4 	Acc: 64.858 	Loss: 0.9806
#  Client9 Test =>                   	Acc: 44.646 	Loss: 1.7083
#  Client5 Train => Local Epoch: 0 	Acc: 51.979 	Loss: 1.3893
#  Client5 Train => Local Epoch: 1 	Acc: 59.362 	Loss: 1.1444
#  Client5 Train => Local Epoch: 2 	Acc: 62.898 	Loss: 1.0620
#  Client5 Train => Local Epoch: 3 	Acc: 63.849 	Loss: 1.0247
#  Client5 Train => Local Epoch: 4 	Acc: 65.185 	Loss: 1.0013
#  Client5 Test =>                   	Acc: 50.195 	Loss: 1.3696
#  Client4 Train => Local Epoch: 0 	Acc: 61.935 	Loss: 1.2009
#  Client4 Train => Local Epoch: 1 	Acc: 67.892 	Loss: 0.9783
#  Client4 Train => Local Epoch: 2 	Acc: 70.528 	Loss: 0.8752
#  Client4 Train => Local Epoch: 3 	Acc: 71.968 	Loss: 0.8288
#  Client4 Train => Local Epoch: 4 	Acc: 73.295 	Loss: 0.7843
#  Client4 Test =>                   	Acc: 46.414 	Loss: 2.1166
# ====================== SERVER V1==========================
#  Train: Round   0, Avg Accuracy 66.754 | Avg Loss 0.950
#  Test: Round   0, Avg Accuracy 37.499 | Avg Loss 2.409
# Forgetting : Round 0, mean_forgetting : 0.000
# ==========================================================
#  Client3 Train => Local Epoch: 0 	Acc: 55.710 	Loss: 1.3870
#  Client3 Train => Local Epoch: 1 	Acc: 64.837 	Loss: 1.0319
#  Client3 Train => Local Epoch: 2 	Acc: 66.736 	Loss: 0.9659
#  Client3 Train => Local Epoch: 3 	Acc: 68.494 	Loss: 0.9140
#  Client3 Train => Local Epoch: 4 	Acc: 69.457 	Loss: 0.8720
#  Client0 Train => Local Epoch: 2 	Acc: 65.621 	Loss: 1.0411
#  Client0 Train => Local Epoch: 3 	Acc: 68.298 	Loss: 0.9214
#  Client0 Train => Local Epoch: 4 	Acc: 71.238 	Loss: 0.8590
#  Client0 Test =>                   	Acc: 50.360 	Loss: 1.5869
#  Client6 Train => Local Epoch: 0 	Acc: 58.287 	Loss: 1.2915
#  Client6 Train => Local Epoch: 1 	Acc: 69.583 	Loss: 0.8810
#  Client6 Train => Local Epoch: 2 	Acc: 72.516 	Loss: 0.7960
#  Client6 Train => Local Epoch: 3 	Acc: 72.904 	Loss: 0.7717
#  Client6 Train => Local Epoch: 4 	Acc: 74.247 	Loss: 0.7465
#  Client6 Test =>                   	Acc: 49.131 	Loss: 1.9353
#  Client7 Train => Local Epoch: 0 	Acc: 62.315 	Loss: 1.2787
#  Client7 Train => Local Epoch: 1 	Acc: 74.570 	Loss: 0.7563
#  Client7 Train => Local Epoch: 2 	Acc: 77.345 	Loss: 0.6756
#  Client7 Train => Local Epoch: 3 	Acc: 78.869 	Loss: 0.6471
#  Client7 Train => Local Epoch: 4 	Acc: 78.782 	Loss: 0.6170
#  Client7 Test =>                   	Acc: 43.922 	Loss: 2.1716
# ====================== SERVER V1==========================
#  Train: Round   1, Avg Accuracy 73.001 | Avg Loss 0.779
#  Test: Round   1, Avg Accuracy 48.049 | Avg Loss 1.865
# Forgetting : Round 1, mean_forgetting : 0.218
# ==========================================================
#  Client0 Train => Local Epoch: 0 	Acc: 54.008 	Loss: 1.4986
#  Client0 Train => Local Epoch: 1 	Acc: 69.548 	Loss: 0.9264
#  Client0 Train => Local Epoch: 2 	Acc: 72.374 	Loss: 0.8626
#  Client0 Train => Local Epoch: 3 	Acc: 74.022 	Loss: 0.7664
#  Client0 Train => Local Epoch: 4 	Acc: 76.926 	Loss: 0.6929
#  Client0 Test =>                   	Acc: 54.435 	Loss: 1.3302
#  Client2 Train => Local Epoch: 0 	Acc: 70.492 	Loss: 0.9054
#  Client2 Train => Local Epoch: 1 	Acc: 76.622 	Loss: 0.6761
#  Client2 Train => Local Epoch: 2 	Acc: 77.914 	Loss: 0.6397
#  Client2 Train => Local Epoch: 3 	Acc: 79.347 	Loss: 0.6008
#  Client2 Train => Local Epoch: 4 	Acc: 79.798 	Loss: 0.5741
#  Client2 Test =>                   	Acc: 61.483 	Loss: 1.6559
#  Client5 Train => Local Epoch: 0 	Acc: 63.008 	Loss: 1.1951
#  Client5 Train => Local Epoch: 1 	Acc: 70.017 	Loss: 0.8594
#  Client5 Train => Local Epoch: 2 	Acc: 72.698 	Loss: 0.7789
#  Client5 Train => Local Epoch: 3 	Acc: 73.644 	Loss: 0.7570
#  Client5 Train => Local Epoch: 4 	Acc: 74.964 	Loss: 0.7158
#  Client5 Test =>                   	Acc: 60.402 	Loss: 1.1630
#  Client7 Train => Local Epoch: 0 	Acc: 67.964 	Loss: 1.0729
#  Client7 Train => Local Epoch: 1 	Acc: 78.414 	Loss: 0.6359
#  Client9 Test =>                   	Acc: 58.395 	Loss: 1.6451
#  Client8 Train => Local Epoch: 0 	Acc: 65.904 	Loss: 1.0254
#  Client8 Train => Local Epoch: 1 	Acc: 73.984 	Loss: 0.7268
#  Client8 Train => Local Epoch: 2 	Acc: 75.191 	Loss: 0.6806
#  Client8 Train => Local Epoch: 3 	Acc: 75.997 	Loss: 0.6318
#  Client8 Train => Local Epoch: 4 	Acc: 77.551 	Loss: 0.6122
#  Client8 Test =>                   	Acc: 46.100 	Loss: 2.0061
#  Client0 Train => Local Epoch: 0 	Acc: 51.245 	Loss: 1.7173
#  Client0 Train => Local Epoch: 1 	Acc: 70.989 	Loss: 0.9683
#  Client0 Train => Local Epoch: 2 	Acc: 73.674 	Loss: 0.8195
#  Client0 Train => Local Epoch: 3 	Acc: 76.848 	Loss: 0.7117
#  Client0 Train => Local Epoch: 4 	Acc: 79.192 	Loss: 0.6559
#  Client0 Test =>                   	Acc: 59.008 	Loss: 1.3016
#  Client2 Train => Local Epoch: 0 	Acc: 72.039 	Loss: 0.8481
#  Client2 Train => Local Epoch: 1 	Acc: 80.213 	Loss: 0.5904
#  Client2 Train => Local Epoch: 2 	Acc: 81.043 	Loss: 0.5485
#  Client2 Train => Local Epoch: 3 	Acc: 82.144 	Loss: 0.5097
#  Client2 Train => Local Epoch: 4 	Acc: 82.872 	Loss: 0.4851
#  Client2 Test =>                   	Acc: 65.952 	Loss: 1.1159
#  Client6 Train => Local Epoch: 0 	Acc: 67.343 	Loss: 1.0213
#  Client6 Train => Local Epoch: 1 	Acc: 75.647 	Loss: 0.7127
#  Client6 Train => Local Epoch: 2 	Acc: 78.313 	Loss: 0.6391
#  Client6 Train => Local Epoch: 3 	Acc: 79.096 	Loss: 0.6114
#  Client6 Train => Local Epoch: 4 	Acc: 79.571 	Loss: 0.5850
#  Client6 Test =>                   	Acc: 59.392 	Loss: 1.3020
# ====================== SERVER V1==========================
#  Train: Round   3, Avg Accuracy 79.990 | Avg Loss 0.584
#  Test: Round   3, Avg Accuracy 56.386 | Avg Loss 1.494
# Forgetting : Round 3, mean_forgetting : -0.378
# ==========================================================
#  Client2 Train => Local Epoch: 0 	Acc: 71.760 	Loss: 0.8905
#  Client2 Train => Local Epoch: 1 	Acc: 82.372 	Loss: 0.5182
#  Client2 Train => Local Epoch: 2 	Acc: 84.194 	Loss: 0.4707
#  Client2 Train => Local Epoch: 3 	Acc: 84.952 	Loss: 0.4370
#  Client2 Train => Local Epoch: 4 	Acc: 85.385 	Loss: 0.4168
#  Client2 Test =>                   	Acc: 66.487 	Loss: 1.1402
#  Client8 Train => Local Epoch: 0 	Acc: 61.438 	Loss: 1.2263
#  Client8 Train => Local Epoch: 1 	Acc: 75.748 	Loss: 0.6691
#  Client8 Train => Local Epoch: 2 	Acc: 78.479 	Loss: 0.5839
#  Client8 Train => Local Epoch: 3 	Acc: 80.988 	Loss: 0.5256
#  Client8 Train => Local Epoch: 4 	Acc: 81.360 	Loss: 0.5123
#  Client8 Train => Local Epoch: 2 	Acc: 79.680 	Loss: 0.5750
#  Client8 Train => Local Epoch: 3 	Acc: 80.838 	Loss: 0.5224
#  Client8 Train => Local Epoch: 4 	Acc: 83.117 	Loss: 0.4757
#  Client8 Test =>                   	Acc: 52.159 	Loss: 1.7124
#  Client9 Train => Local Epoch: 0 	Acc: 73.066 	Loss: 0.8673
#  Client9 Train => Local Epoch: 1 	Acc: 79.241 	Loss: 0.6073
#  Client9 Train => Local Epoch: 2 	Acc: 81.090 	Loss: 0.5250
#  Client9 Train => Local Epoch: 3 	Acc: 81.259 	Loss: 0.5488
#  Client9 Train => Local Epoch: 4 	Acc: 76.439 	Loss: 0.6833
#  Client9 Test =>                   	Acc: 68.598 	Loss: 0.9493
#  Client4 Train => Local Epoch: 0 	Acc: 58.393 	Loss: 1.3640
#  Client4 Train => Local Epoch: 1 	Acc: 77.684 	Loss: 0.6879
#  Client4 Train => Local Epoch: 2 	Acc: 81.698 	Loss: 0.5808
#  Client4 Train => Local Epoch: 3 	Acc: 83.007 	Loss: 0.5120
#  Client4 Train => Local Epoch: 4 	Acc: 83.854 	Loss: 0.4692
#  Client4 Test =>                   	Acc: 59.665 	Loss: 1.4387
#  Client5 Train => Local Epoch: 0 	Acc: 63.625 	Loss: 1.1824
#  Client5 Train => Local Epoch: 1 	Acc: 76.156 	Loss: 0.7254
#  Client5 Train => Local Epoch: 2 	Acc: 78.109 	Loss: 0.6397
#  Client5 Train => Local Epoch: 3 	Acc: 80.064 	Loss: 0.5750
#  Client5 Train => Local Epoch: 4 	Acc: 81.477 	Loss: 0.5455
#  Client5 Test =>                   	Acc: 71.521 	Loss: 0.8571
#  Client0 Train => Local Epoch: 0 	Acc: 75.470 	Loss: 0.7540
#  Client0 Train => Local Epoch: 1 	Acc: 80.420 	Loss: 0.5814
#  Client0 Train => Local Epoch: 2 	Acc: 83.282 	Loss: 0.5256
#  Client0 Train => Local Epoch: 3 	Acc: 83.950 	Loss: 0.4875
#  Client0 Train => Local Epoch: 4 	Acc: 84.490 	Loss: 0.4727
#  Client0 Test =>                   	Acc: 68.713 	Loss: 0.9377
#  Client1 Train => Local Epoch: 0 	Acc: 69.760 	Loss: 0.9836
#  Client1 Train => Local Epoch: 1 	Acc: 86.654 	Loss: 0.4690
#  Client1 Train => Local Epoch: 2 	Acc: 88.352 	Loss: 0.3809
#  Client1 Train => Local Epoch: 3 	Acc: 88.784 	Loss: 0.3413
#  Client1 Train => Local Epoch: 4 	Acc: 89.977 	Loss: 0.3150
#  Client1 Test =>                   	Acc: 52.219 	Loss: 1.4310
# ====================== SERVER V1==========================
#  Train: Round   5, Avg Accuracy 83.753 | Avg Loss 0.478
#  Test: Round   5, Avg Accuracy 61.652 | Avg Loss 1.271
# Forgetting : Round 5, mean_forgetting : -0.219
# ==========================================================
#  Client6 Train => Local Epoch: 0 	Acc: 64.857 	Loss: 1.1326
#  Client6 Train => Local Epoch: 1 	Acc: 80.099 	Loss: 0.6025
#  Client9 Train => Local Epoch: 4 	Acc: 82.756 	Loss: 0.4972
#  Client9 Test =>                   	Acc: 70.942 	Loss: 0.9268
#  Client1 Train => Local Epoch: 0 	Acc: 55.063 	Loss: 1.5892
#  Client1 Train => Local Epoch: 1 	Acc: 86.218 	Loss: 0.4822
#  Client1 Train => Local Epoch: 2 	Acc: 88.368 	Loss: 0.3904
#  Client1 Train => Local Epoch: 3 	Acc: 89.283 	Loss: 0.3457
#  Client1 Train => Local Epoch: 4 	Acc: 90.856 	Loss: 0.2983
#  Client1 Test =>                   	Acc: 54.290 	Loss: 1.5649
#  Client8 Train => Local Epoch: 0 	Acc: 52.508 	Loss: 1.6173
#  Client8 Train => Local Epoch: 1 	Acc: 77.300 	Loss: 0.6705
#  Client8 Train => Local Epoch: 2 	Acc: 79.323 	Loss: 0.5747
#  Client8 Train => Local Epoch: 3 	Acc: 81.658 	Loss: 0.5156
#  Client8 Train => Local Epoch: 4 	Acc: 82.653 	Loss: 0.4752
#  Client8 Test =>                   	Acc: 51.933 	Loss: 1.6909
#  Client2 Train => Local Epoch: 0 	Acc: 59.848 	Loss: 1.3485
#  Client2 Train => Local Epoch: 1 	Acc: 81.191 	Loss: 0.5789
#  Client2 Train => Local Epoch: 2 	Acc: 85.132 	Loss: 0.4443
#  Client2 Train => Local Epoch: 3 	Acc: 86.390 	Loss: 0.3989
#  Client2 Train => Local Epoch: 4 	Acc: 87.289 	Loss: 0.3658
#  Client2 Test =>                   	Acc: 70.515 	Loss: 0.9345
# ====================== SERVER V1==========================
#  Train: Round   6, Avg Accuracy 85.608 | Avg Loss 0.422
#  Test: Round   6, Avg Accuracy 63.110 | Avg Loss 1.194
# Forgetting : Round 6, mean_forgetting : -0.535
# ==========================================================
#  Client4 Train => Local Epoch: 0 	Acc: 75.109 	Loss: 0.8369
#  Client4 Train => Local Epoch: 1 	Acc: 83.640 	Loss: 0.5143
#  Client4 Train => Local Epoch: 2 	Acc: 86.082 	Loss: 0.4312
#  Client4 Train => Local Epoch: 3 	Acc: 87.797 	Loss: 0.3767
#  Client4 Train => Local Epoch: 4 	Acc: 88.613 	Loss: 0.3480
#  Client4 Test =>                   	Acc: 65.676 	Loss: 1.0790
#  Client1 Train => Local Epoch: 0 	Acc: 81.576 	Loss: 0.5590
#  Client1 Train => Local Epoch: 1 	Acc: 89.709 	Loss: 0.3354
#  Client1 Train => Local Epoch: 2 	Acc: 90.669 	Loss: 0.2948
#  Client1 Train => Local Epoch: 3 	Acc: 91.526 	Loss: 0.2501
#  Client1 Train => Local Epoch: 4 	Acc: 92.503 	Loss: 0.2376
#  Client1 Test =>                   	Acc: 59.729 	Loss: 1.2694
#  Client2 Train => Local Epoch: 0 	Acc: 79.225 	Loss: 0.6882
#  Client2 Train => Local Epoch: 1 	Acc: 87.014 	Loss: 0.3891
#  Client2 Train => Local Epoch: 2 	Acc: 88.676 	Loss: 0.3439
#  Client2 Train => Local Epoch: 3 	Acc: 89.328 	Loss: 0.3129
#  Client4 Train => Local Epoch: 1 	Acc: 81.813 	Loss: 0.6034
#  Client4 Train => Local Epoch: 2 	Acc: 84.219 	Loss: 0.5022
#  Client4 Train => Local Epoch: 3 	Acc: 86.532 	Loss: 0.4240
#  Client4 Train => Local Epoch: 4 	Acc: 87.033 	Loss: 0.4073
#  Client4 Test =>                   	Acc: 61.944 	Loss: 1.1314
#  Client1 Train => Local Epoch: 0 	Acc: 80.537 	Loss: 0.6408
#  Client1 Train => Local Epoch: 1 	Acc: 88.290 	Loss: 0.3757
#  Client1 Train => Local Epoch: 2 	Acc: 89.814 	Loss: 0.3260
#  Client1 Train => Local Epoch: 3 	Acc: 91.325 	Loss: 0.2661
#  Client1 Train => Local Epoch: 4 	Acc: 91.670 	Loss: 0.2519
#  Client1 Test =>                   	Acc: 58.132 	Loss: 1.2650
#  Client3 Train => Local Epoch: 0 	Acc: 66.434 	Loss: 1.1310
#  Client3 Train => Local Epoch: 1 	Acc: 80.606 	Loss: 0.5832
#  Client3 Train => Local Epoch: 2 	Acc: 84.037 	Loss: 0.4719
#  Client3 Train => Local Epoch: 3 	Acc: 84.983 	Loss: 0.4431
#  Client3 Train => Local Epoch: 4 	Acc: 85.357 	Loss: 0.4241
#  Client3 Test =>                   	Acc: 69.450 	Loss: 0.9596
#  Client2 Train => Local Epoch: 0 	Acc: 73.164 	Loss: 0.9217
#  Client2 Train => Local Epoch: 1 	Acc: 85.993 	Loss: 0.4209
#  Client2 Train => Local Epoch: 2 	Acc: 88.463 	Loss: 0.3469
#  Client2 Train => Local Epoch: 3 	Acc: 89.002 	Loss: 0.3197
#  Client2 Train => Local Epoch: 4 	Acc: 89.921 	Loss: 0.2927
#  Client2 Test =>                   	Acc: 71.666 	Loss: 0.9022
#  Client0 Train => Local Epoch: 0 	Acc: 71.869 	Loss: 0.8779
#  Client0 Train => Local Epoch: 1 	Acc: 82.480 	Loss: 0.5165
#  Client0 Train => Local Epoch: 2 	Acc: 85.889 	Loss: 0.4255
#  Client0 Train => Local Epoch: 3 	Acc: 87.316 	Loss: 0.3813
#  Client0 Train => Local Epoch: 4 	Acc: 88.708 	Loss: 0.3416
#  Client0 Test =>                   	Acc: 71.683 	Loss: 0.7886
# ====================== SERVER V1==========================
#  Train: Round   8, Avg Accuracy 87.645 | Avg Loss 0.363
#  Test: Round   8, Avg Accuracy 66.768 | Avg Loss 1.064
# Forgetting : Round 8, mean_forgetting : -0.581
# ==========================================================
#  Client2 Train => Local Epoch: 0 	Acc: 83.694 	Loss: 0.4798
#  Client2 Train => Local Epoch: 1 	Acc: 90.157 	Loss: 0.3031
#  Client2 Train => Local Epoch: 2 	Acc: 91.361 	Loss: 0.2583
#  Client2 Train => Local Epoch: 3 	Acc: 91.848 	Loss: 0.2394
#  Client2 Train => Local Epoch: 4 	Acc: 92.683 	Loss: 0.2200
#  Client2 Test =>                   	Acc: 74.522 	Loss: 0.8184
#  Client5 Train => Local Epoch: 0 	Acc: 76.323 	Loss: 0.7514
#  Client9 Train => Local Epoch: 4 	Acc: 85.691 	Loss: 0.4177
#  Client9 Test =>                   	Acc: 73.855 	Loss: 0.7754
#  Client4 Train => Local Epoch: 0 	Acc: 62.137 	Loss: 1.2178
#  Client4 Train => Local Epoch: 1 	Acc: 83.958 	Loss: 0.5192
#  Client4 Train => Local Epoch: 2 	Acc: 86.985 	Loss: 0.3991
#  Client4 Train => Local Epoch: 3 	Acc: 88.060 	Loss: 0.3615
#  Client4 Train => Local Epoch: 4 	Acc: 90.193 	Loss: 0.3177
#  Client4 Test =>                   	Acc: 66.672 	Loss: 1.0647
#  Client5 Train => Local Epoch: 0 	Acc: 70.257 	Loss: 0.9675
#  Client5 Train => Local Epoch: 1 	Acc: 81.727 	Loss: 0.5219
#  Client5 Train => Local Epoch: 2 	Acc: 85.121 	Loss: 0.4326
#  Client5 Train => Local Epoch: 3 	Acc: 86.607 	Loss: 0.3941
#  Client5 Train => Local Epoch: 4 	Acc: 87.676 	Loss: 0.3724
#  Client5 Test =>                   	Acc: 76.212 	Loss: 0.7509
#  Client2 Train => Local Epoch: 0 	Acc: 82.827 	Loss: 0.5235
#  Client2 Train => Local Epoch: 1 	Acc: 88.755 	Loss: 0.3329
#  Client2 Train => Local Epoch: 2 	Acc: 90.704 	Loss: 0.2784
#  Client2 Train => Local Epoch: 3 	Acc: 91.120 	Loss: 0.2588
#  Client2 Train => Local Epoch: 4 	Acc: 92.189 	Loss: 0.2411
#  Client2 Test =>                   	Acc: 74.953 	Loss: 0.8006
#  Client0 Train => Local Epoch: 0 	Acc: 73.645 	Loss: 0.8118
#  Client0 Train => Local Epoch: 1 	Acc: 84.568 	Loss: 0.4582
#  Client0 Train => Local Epoch: 2 	Acc: 87.274 	Loss: 0.3770
#  Client0 Train => Local Epoch: 3 	Acc: 89.035 	Loss: 0.3289
#  Client0 Train => Local Epoch: 4 	Acc: 90.370 	Loss: 0.3040
#  Client0 Test =>                   	Acc: 74.060 	Loss: 0.7805
#  Client6 Train => Local Epoch: 0 	Acc: 77.140 	Loss: 0.6946
#  Client6 Train => Local Epoch: 1 	Acc: 85.491 	Loss: 0.4230
#  Client6 Train => Local Epoch: 2 	Acc: 87.574 	Loss: 0.3657
#  Client6 Train => Local Epoch: 3 	Acc: 88.849 	Loss: 0.3334
#  Client6 Train => Local Epoch: 4 	Acc: 89.576 	Loss: 0.3068
#  Client6 Test =>                   	Acc: 69.636 	Loss: 1.0991
#  Client8 Train => Local Epoch: 0 	Acc: 81.678 	Loss: 0.5365
#  Client8 Train => Local Epoch: 1 	Acc: 85.140 	Loss: 0.3962
#  Client8 Train => Local Epoch: 2 	Acc: 87.132 	Loss: 0.3564
#  Client8 Train => Local Epoch: 3 	Acc: 88.401 	Loss: 0.3192
#  Client8 Train => Local Epoch: 4 	Acc: 89.165 	Loss: 0.2892
#  Client8 Test =>                   	Acc: 67.942 	Loss: 0.9839
# ====================== SERVER V1==========================
#  Train: Round  10, Avg Accuracy 89.854 | Avg Loss 0.306
#  Test: Round  10, Avg Accuracy 69.854 | Avg Loss 0.951
# Forgetting : Round 10, mean_forgetting : -0.238
# ==========================================================
#  Client9 Train => Local Epoch: 0 	Acc: 79.328 	Loss: 0.6714
#  Client9 Train => Local Epoch: 1 	Acc: 77.816 	Loss: 0.6288
#  Client9 Train => Local Epoch: 2 	Acc: 83.508 	Loss: 0.4869
#  Client9 Train => Local Epoch: 3 	Acc: 83.797 	Loss: 0.4633
#  Client9 Train => Local Epoch: 4 	Acc: 79.409 	Loss: 0.5974
#  Client9 Test =>                   	Acc: 75.040 	Loss: 0.7650
#  Client5 Train => Local Epoch: 0 	Acc: 74.781 	Loss: 0.7626
#  Client5 Train => Local Epoch: 1 	Acc: 80.456 	Loss: 0.5617
#  Client5 Train => Local Epoch: 2 	Acc: 83.848 	Loss: 0.4667
#  Client5 Train => Local Epoch: 3 	Acc: 85.639 	Loss: 0.4173
#  Client5 Train => Local Epoch: 4 	Acc: 86.686 	Loss: 0.3910
#  Client5 Test =>                   	Acc: 71.464 	Loss: 0.8554
#  Client0 Train => Local Epoch: 0 	Acc: 80.576 	Loss: 0.6018
#  Client0 Train => Local Epoch: 1 	Acc: 85.918 	Loss: 0.4192
# ...
#  Client7 Test =>                   	Acc: 72.498 	Loss: 0.9003
# ====================== SERVER V1==========================
#  Train: Round  95, Avg Accuracy 98.074 | Avg Loss 0.063
#  Test: Round  95, Avg Accuracy 76.804 | Avg Loss 0.790
# Forgetting : Round 95, mean_forgetting : 0.122
# ==========================================================
#  Client9 Train => Local Epoch: 0 	Acc: 87.759 	Loss: 0.4354
#  Client9 Train => Local Epoch: 1 	Acc: 95.577 	Loss: 0.1400
#  Client9 Train => Local Epoch: 2 	Acc: 97.421 	Loss: 0.1036
#  Client9 Train => Local Epoch: 3 	Acc: 95.648 	Loss: 0.1448
#  Client9 Train => Local Epoch: 4 	Acc: 92.309 	Loss: 0.2477
#  Client9 Test =>                   	Acc: 80.725 	Loss: 0.6652
#  Client4 Train => Local Epoch: 0 	Acc: 74.262 	Loss: 0.8015
#  Client4 Train => Local Epoch: 1 	Acc: 93.678 	Loss: 0.2060
#  Client4 Train => Local Epoch: 2 	Acc: 96.242 	Loss: 0.1223
#  Client4 Train => Local Epoch: 3 	Acc: 97.659 	Loss: 0.0863
#  Client4 Train => Local Epoch: 4 	Acc: 98.059 	Loss: 0.0693
#  Client4 Test =>                   	Acc: 67.592 	Loss: 1.1329
#  Client8 Train => Local Epoch: 0 	Acc: 81.010 	Loss: 0.6104
#  Client8 Train => Local Epoch: 1 	Acc: 93.699 	Loss: 0.1817
#  Client8 Train => Local Epoch: 2 	Acc: 96.318 	Loss: 0.1077
#  Client8 Train => Local Epoch: 3 	Acc: 97.603 	Loss: 0.0746
#  Client8 Train => Local Epoch: 4 	Acc: 97.907 	Loss: 0.0700
#  Client8 Test =>                   	Acc: 66.504 	Loss: 1.2111
#  Client6 Train => Local Epoch: 0 	Acc: 90.998 	Loss: 0.2894
#  Client2 Train => Local Epoch: 4 	Acc: 98.890 	Loss: 0.0402
#  Client2 Test =>                   	Acc: 79.906 	Loss: 0.6989
# ====================== SERVER V1==========================
#  Train: Round  96, Avg Accuracy 97.901 | Avg Loss 0.073
#  Test: Round  96, Avg Accuracy 75.074 | Avg Loss 0.861
# Forgetting : Round 96, mean_forgetting : -0.060
# ==========================================================
#  Client9 Train => Local Epoch: 0 	Acc: 90.247 	Loss: 0.3114
#  Client9 Train => Local Epoch: 1 	Acc: 93.953 	Loss: 0.1803
#  Client9 Train => Local Epoch: 2 	Acc: 93.016 	Loss: 0.2252
#  Client9 Train => Local Epoch: 3 	Acc: 95.360 	Loss: 0.1362
#  Client9 Train => Local Epoch: 4 	Acc: 93.086 	Loss: 0.1924
#  Client9 Test =>                   	Acc: 81.634 	Loss: 0.6372
#  Client1 Train => Local Epoch: 0 	Acc: 70.365 	Loss: 1.0070
#  Client1 Train => Local Epoch: 1 	Acc: 94.176 	Loss: 0.2016
#  Client1 Train => Local Epoch: 2 	Acc: 96.229 	Loss: 0.1184
#  Client1 Train => Local Epoch: 3 	Acc: 97.062 	Loss: 0.0893
#  Client1 Train => Local Epoch: 4 	Acc: 98.221 	Loss: 0.0635
#  Client1 Test =>                   	Acc: 64.955 	Loss: 1.1775
#  Client7 Train => Local Epoch: 0 	Acc: 74.689 	Loss: 0.8175
#  Client7 Train => Local Epoch: 1 	Acc: 94.770 	Loss: 0.1666
#  Client7 Train => Local Epoch: 2 	Acc: 97.125 	Loss: 0.0927
#  Client7 Train => Local Epoch: 3 	Acc: 98.318 	Loss: 0.0656
#  Client7 Train => Local Epoch: 4 	Acc: 98.265 	Loss: 0.0602
#  Client7 Test =>                   	Acc: 72.713 	Loss: 0.9641
#  Client6 Train => Local Epoch: 0 	Acc: 81.780 	Loss: 0.6036
#  Client6 Train => Local Epoch: 1 	Acc: 94.966 	Loss: 0.1509
#  Client6 Train => Local Epoch: 2 	Acc: 97.558 	Loss: 0.0891
#  Client6 Train => Local Epoch: 3 	Acc: 98.279 	Loss: 0.0627
#  Client6 Train => Local Epoch: 4 	Acc: 98.419 	Loss: 0.0555
#  Client6 Test =>                   	Acc: 75.286 	Loss: 0.8638
#  Client0 Train => Local Epoch: 0 	Acc: 82.330 	Loss: 0.5603
#  Client0 Train => Local Epoch: 1 	Acc: 95.057 	Loss: 0.1623
#  Client0 Train => Local Epoch: 2 	Acc: 95.782 	Loss: 0.1259
#  Client0 Train => Local Epoch: 3 	Acc: 97.891 	Loss: 0.0799
#  Client0 Train => Local Epoch: 4 	Acc: 98.274 	Loss: 0.0633
#  Client0 Test =>                   	Acc: 80.492 	Loss: 0.6014
#  Client2 Train => Local Epoch: 0 	Acc: 90.726 	Loss: 0.2892
#  Client2 Train => Local Epoch: 1 	Acc: 97.201 	Loss: 0.0928
#  Client2 Train => Local Epoch: 2 	Acc: 98.173 	Loss: 0.0613
#  Client2 Train => Local Epoch: 3 	Acc: 98.583 	Loss: 0.0499
#  Client2 Train => Local Epoch: 4 	Acc: 98.929 	Loss: 0.0370
#  Client2 Test =>                   	Acc: 80.991 	Loss: 0.6653
#  Client8 Train => Local Epoch: 0 	Acc: 83.136 	Loss: 0.5824
#  Client8 Train => Local Epoch: 1 	Acc: 94.623 	Loss: 0.1512
#  Client8 Train => Local Epoch: 2 	Acc: 97.039 	Loss: 0.0922
#  Client8 Train => Local Epoch: 3 	Acc: 97.911 	Loss: 0.0660
#  Client8 Train => Local Epoch: 4 	Acc: 98.501 	Loss: 0.0486
#  Client8 Test =>                   	Acc: 65.143 	Loss: 1.3996
#  Client5 Train => Local Epoch: 0 	Acc: 81.117 	Loss: 0.6198
#  Client5 Train => Local Epoch: 1 	Acc: 94.877 	Loss: 0.1606
#  Client5 Train => Local Epoch: 2 	Acc: 96.852 	Loss: 0.1006
#  Client5 Train => Local Epoch: 3 	Acc: 98.396 	Loss: 0.0681
#  Client5 Train => Local Epoch: 4 	Acc: 98.499 	Loss: 0.0540
#  Client5 Test =>                   	Acc: 81.442 	Loss: 0.6870
#  Client3 Train => Local Epoch: 0 	Acc: 85.272 	Loss: 0.4914
#  Client3 Train => Local Epoch: 1 	Acc: 95.218 	Loss: 0.1425
#  Client3 Train => Local Epoch: 2 	Acc: 97.077 	Loss: 0.0884
#  Client3 Train => Local Epoch: 3 	Acc: 97.750 	Loss: 0.0738
#  Client3 Train => Local Epoch: 4 	Acc: 98.296 	Loss: 0.0590
#  Client3 Test =>                   	Acc: 78.128 	Loss: 0.7853
#  Client4 Train => Local Epoch: 0 	Acc: 79.841 	Loss: 0.6689
#  Client4 Train => Local Epoch: 1 	Acc: 94.273 	Loss: 0.1648
#  Client4 Train => Local Epoch: 2 	Acc: 96.314 	Loss: 0.1135
#  Client4 Train => Local Epoch: 3 	Acc: 97.832 	Loss: 0.0753
#  Client4 Train => Local Epoch: 4 	Acc: 98.753 	Loss: 0.0523
#  Client4 Test =>                   	Acc: 78.704 	Loss: 0.6996
# ====================== SERVER V1==========================
#  Train: Round  97, Avg Accuracy 97.924 | Avg Loss 0.069
#  Test: Round  97, Avg Accuracy 75.949 | Avg Loss 0.848
# Forgetting : Round 97, mean_forgetting : -0.143
# ==========================================================
#  Client8 Train => Local Epoch: 0 	Acc: 82.827 	Loss: 0.5424
#  Client8 Train => Local Epoch: 1 	Acc: 96.521 	Loss: 0.1120
#  Client8 Train => Local Epoch: 2 	Acc: 97.573 	Loss: 0.0746
#  Client8 Train => Local Epoch: 3 	Acc: 98.595 	Loss: 0.0467
#  Client8 Train => Local Epoch: 4 	Acc: 98.865 	Loss: 0.0393
#  Client8 Test =>                   	Acc: 70.286 	Loss: 1.0570
#  Client3 Train => Local Epoch: 0 	Acc: 86.615 	Loss: 0.4149
#  Client3 Train => Local Epoch: 1 	Acc: 96.140 	Loss: 0.1229
#  Client3 Train => Local Epoch: 2 	Acc: 97.608 	Loss: 0.0804
#  Client3 Train => Local Epoch: 3 	Acc: 98.625 	Loss: 0.0556
#  Client6 Train => Local Epoch: 1 	Acc: 96.010 	Loss: 0.1260
#  Client6 Train => Local Epoch: 2 	Acc: 97.445 	Loss: 0.0783
#  Client6 Train => Local Epoch: 3 	Acc: 98.058 	Loss: 0.0678
#  Client6 Train => Local Epoch: 4 	Acc: 98.554 	Loss: 0.0519
#  Client6 Test =>                   	Acc: 77.677 	Loss: 0.8164
#  Client2 Train => Local Epoch: 0 	Acc: 89.468 	Loss: 0.3373
#  Client2 Train => Local Epoch: 1 	Acc: 97.081 	Loss: 0.0879
#  Client2 Train => Local Epoch: 2 	Acc: 98.156 	Loss: 0.0580
#  Client2 Train => Local Epoch: 3 	Acc: 98.867 	Loss: 0.0428
#  Client2 Train => Local Epoch: 4 	Acc: 98.950 	Loss: 0.0367
#  Client2 Test =>                   	Acc: 82.536 	Loss: 0.6319
# ====================== SERVER V1==========================
#  Train: Round  98, Avg Accuracy 98.275 | Avg Loss 0.058
#  Test: Round  98, Avg Accuracy 76.612 | Avg Loss 0.820
# Forgetting : Round 98, mean_forgetting : -0.152
# ==========================================================
#  Client8 Train => Local Epoch: 0 	Acc: 84.320 	Loss: 0.5198
#  Client8 Train => Local Epoch: 1 	Acc: 95.981 	Loss: 0.1220
#  Client8 Train => Local Epoch: 2 	Acc: 97.693 	Loss: 0.0724
#  Client8 Train => Local Epoch: 3 	Acc: 97.971 	Loss: 0.0584
#  Client8 Train => Local Epoch: 4 	Acc: 98.775 	Loss: 0.0423
#  Client8 Test =>                   	Acc: 68.646 	Loss: 1.1935
#  Client2 Train => Local Epoch: 0 	Acc: 85.323 	Loss: 0.4996
#  Client2 Train => Local Epoch: 1 	Acc: 97.521 	Loss: 0.0833
#  Client2 Train => Local Epoch: 2 	Acc: 98.987 	Loss: 0.0437
#  Client2 Train => Local Epoch: 3 	Acc: 99.152 	Loss: 0.0331
#  Client2 Train => Local Epoch: 4 	Acc: 99.313 	Loss: 0.0290
#  Client2 Test =>                   	Acc: 80.758 	Loss: 0.6818
#  Client3 Train => Local Epoch: 0 	Acc: 86.849 	Loss: 0.4423
#  Client3 Train => Local Epoch: 1 	Acc: 95.187 	Loss: 0.1509
#  Client3 Train => Local Epoch: 2 	Acc: 96.570 	Loss: 0.1043
#  Client3 Train => Local Epoch: 3 	Acc: 97.623 	Loss: 0.0854
#  Client3 Train => Local Epoch: 4 	Acc: 97.303 	Loss: 0.0810
#  Client3 Test =>                   	Acc: 78.078 	Loss: 0.8286
#  Client0 Train => Local Epoch: 0 	Acc: 80.008 	Loss: 0.6837
#  Client0 Train => Local Epoch: 1 	Acc: 93.175 	Loss: 0.1860
#  Client0 Train => Local Epoch: 2 	Acc: 96.215 	Loss: 0.1209
#  Client0 Train => Local Epoch: 3 	Acc: 97.870 	Loss: 0.0816
#  Client0 Train => Local Epoch: 4 	Acc: 98.083 	Loss: 0.0647
#  Client0 Test =>                   	Acc: 79.543 	Loss: 0.6514
#  Client9 Train => Local Epoch: 0 	Acc: 90.994 	Loss: 0.2844
#  Client9 Train => Local Epoch: 1 	Acc: 93.061 	Loss: 0.2136
#  Client9 Train => Local Epoch: 2 	Acc: 96.135 	Loss: 0.1146
#  Client9 Train => Local Epoch: 3 	Acc: 95.245 	Loss: 0.1430
#  Client9 Train => Local Epoch: 4 	Acc: 91.408 	Loss: 0.2562
#  Client9 Test =>                   	Acc: 79.415 	Loss: 0.6919
#  Client4 Train => Local Epoch: 0 	Acc: 74.463 	Loss: 0.8562
#  Client4 Train => Local Epoch: 1 	Acc: 92.263 	Loss: 0.2522
#  Client4 Train => Local Epoch: 2 	Acc: 93.878 	Loss: 0.1905
#  Client4 Train => Local Epoch: 3 	Acc: 96.014 	Loss: 0.1144
#  Client4 Train => Local Epoch: 4 	Acc: 96.680 	Loss: 0.1017
#  Client4 Test =>                   	Acc: 71.420 	Loss: 0.9897
#  Client7 Train => Local Epoch: 0 	Acc: 79.291 	Loss: 0.6789
#  Client7 Train => Local Epoch: 1 	Acc: 95.209 	Loss: 0.1510
#  Client7 Train => Local Epoch: 2 	Acc: 97.335 	Loss: 0.0926
#  Client7 Train => Local Epoch: 3 	Acc: 97.635 	Loss: 0.0773
#  Client7 Train => Local Epoch: 4 	Acc: 98.187 	Loss: 0.0617
#  Client7 Test =>                   	Acc: 73.232 	Loss: 0.9845
#  Client1 Train => Local Epoch: 0 	Acc: 67.934 	Loss: 1.1276
#  Client1 Train => Local Epoch: 1 	Acc: 95.207 	Loss: 0.1732
#  Client1 Train => Local Epoch: 2 	Acc: 95.817 	Loss: 0.1202
#  Client1 Train => Local Epoch: 3 	Acc: 97.122 	Loss: 0.0845
#  Client1 Train => Local Epoch: 4 	Acc: 97.941 	Loss: 0.0603
#  Client1 Test =>                   	Acc: 67.777 	Loss: 0.9975
#  Client5 Train => Local Epoch: 0 	Acc: 77.255 	Loss: 0.7952
#  Client5 Train => Local Epoch: 1 	Acc: 92.717 	Loss: 0.2261
#  Client5 Train => Local Epoch: 2 	Acc: 96.357 	Loss: 0.1214
#  Client5 Train => Local Epoch: 3 	Acc: 97.715 	Loss: 0.0863
#  Client5 Train => Local Epoch: 4 	Acc: 98.231 	Loss: 0.0677
#  Client5 Test =>                   	Acc: 80.630 	Loss: 0.6816
#  Client6 Train => Local Epoch: 0 	Acc: 88.388 	Loss: 0.3389
#  Client6 Train => Local Epoch: 1 	Acc: 96.363 	Loss: 0.1102
#  Client6 Train => Local Epoch: 2 	Acc: 97.734 	Loss: 0.0763
#  Client6 Train => Local Epoch: 3 	Acc: 98.204 	Loss: 0.0593
#  Client6 Train => Local Epoch: 4 	Acc: 98.291 	Loss: 0.0555
#  Client6 Test =>                   	Acc: 76.105 	Loss: 0.8603
# ====================== SERVER V1==========================
#  Train: Round  99, Avg Accuracy 97.421 | Avg Loss 0.082
#  Test: Round  99, Avg Accuracy 75.560 | Avg Loss 0.856
# Forgetting : Round 99, mean_forgetting : -0.043
# ==========================================================
# Training and Evaluation completed!
# Saved: SL - CIFAR-10 α=0.5.csv
