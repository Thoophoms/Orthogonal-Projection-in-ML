# %% [markdown]
# # Split learning + Projected
# ### ResNet18 on CIFAR-10 + α = 0.1

# %%
import torch

print("torch.cuda.is_available():", torch.cuda.is_available())
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("device:", device)
if torch.cuda.is_available():
    print("GPU name:", torch.cuda.get_device_name(0))
# Out:
# torch.cuda.is_available(): True
# device: cuda
# GPU name: NVIDIA H200

# %%
#=============================================================================
# Split Learning + Orthogonal Projection (Gated) on CIFAR-10
# - Warmup + alpha ramp + norm-preserving projection
# - Train-side feature reservoir (no test leakage)
# - Rebuild U every 3 rounds; clear buffer after rebuild
# - SGD + momentum + cosine LR; label smoothing
# - local_ep = 2; RandAugment; freeze client BN after warmup
# ============================================================================
import torch
from torch import nn
from torchvision import transforms
from torchvision import datasets
from torch.utils.data import DataLoader, Dataset
import torch.nn.functional as F
import math, time
import os.path
import pandas as pd

from sklearn.model_selection import train_test_split
from PIL import Image
from glob import glob 
from pandas import DataFrame
import random
import numpy as np
import os


import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import copy


#=====================================================================================================
#                           Repro & Device
#=====================================================================================================

SEED = 1234
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
if torch.cuda.is_available():
    torch.backends.cudnn.deterministic = True
    print(torch.cuda.get_device_name(0))    
    

def _sync_cuda():
    if torch.cuda.is_available():
        torch.cuda.synchronize()
        
        

ALPHA = 0.1
DATASET_NAME = "CIFAR10"
program = "SL_Projected-CF10-01-200EP-5WU-3RB-0-005-4096FM"
print(f"---------{program}----------")              # this is to identify the program in the slurm outputs files



device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')


# To print in color -------test/train of the client side
def prRed(skk): print("\033[91m {}\033[00m" .format(skk)) 
def prGreen(skk): print("\033[92m {}\033[00m" .format(skk))


#=====================================================================================================
#                            SL / Training Config
#===================================================================================================== 

DATA_ROOT = "./data"
NUM_CLIENTS = 10
EPOCHS = 200          # global rounds
frac   = 1.0         # fraction of clients per round
lr_srv = 0.005         # server LR (SGD)
lr_cli = 0.005        # client LR (SGD)
weight_decay = 5e-4
momentum = 0.9
BATCH_SIZE = 256
local_ep = 5
NUM_WORKERS = 4

#=====================================================================================================
#                           Orthogonal Config
#=====================================================================================================
# Orthogonal projection config deque
ORTH = True
TOP_R = 8 # Smaller r to avoid over-pruning
rebuild_every = 3         # rebuild subspace cadence (rounds)
WARMUP_ROUNDS = 5         # no projection before this
alpha_max = 0.7           # target projection strength
alpha_min = 0.0
alpha_warm_len = 10       # rounds to ramp alpha after warmup

# total samples for building U_old
# Feature reservoir (train-side only)
FEATURE_MEM_CAP = 4096
FEATURE_MEM = []
_seen = 0

# holding D x r matrix of principal directions at the cut
U_old = None


# ====================== Confirm =======================================
cut_at = "Original at 2"
prRed(f"\tData:\t\t{DATASET_NAME}\n\tCut:\t\t{cut_at}\n\tGlobal Rounds:\t{EPOCHS}\n\tClients:\t{NUM_CLIENTS}\n\tLocal Epochs:\t{local_ep}\n\tα:\t\t{ALPHA}\n\tWarm-up:\t{WARMUP_ROUNDS}\n\tRebuild:\t{rebuild_every}")


#=====================================================================================================
#                       Round 4 New: Projection Gate
#=====================================================================================================

def proj_gate_strength(round_idx: int):
    """Alpha schedule for projection."""
    if round_idx < WARMUP_ROUNDS:
        return 0.0
    t = min(1.0, (round_idx - WARMUP_ROUNDS) / max(1, alpha_warm_len))
    return alpha_min + t * (alpha_max - alpha_min)

#=====================================================================================================
#                           Projection Help
#=====================================================================================================
def project_off_subspace_gated(grad_batch: torch.Tensor, U: torch.Tensor, alpha: float, preserve_norm=True):
    """g' = g - alpha * P_U(g), optionally rescale to preserve per-sample norm."""
    if (U is None) or (alpha <= 0.0):
        return grad_batch
    B = grad_batch.shape[0]
    g = grad_batch.view(B, -1)              # [B, D]
    comp = (g @ U) @ U.T                    # [B, D]
    if preserve_norm:
        n0 = g.norm(dim=1, keepdim=True).clamp_min(1e-12)
    g2 = g - alpha * comp
    if preserve_norm:
        n1 = g2.norm(dim=1, keepdim=True).clamp_min(1e-12)
        g2 = g2 * (n0 / n1)
    return g2.view_as(grad_batch)

def add_to_reservoir(rows_cpu_fp16: torch.Tensor):
    """Standard reservoir sampling to keep a fixed-size unbiased buffer."""
    global _seen, FEATURE_MEM
    for r in rows_cpu_fp16:
        _seen += 1
        if len(FEATURE_MEM) < FEATURE_MEM_CAP:
            FEATURE_MEM.append(r)
        else:
            j = np.random.randint(0, _seen)
            if j < FEATURE_MEM_CAP:
                FEATURE_MEM[j] = r

def collect_cut_feats_from_train(fx_client: torch.Tensor):
    """Collect a small subset of cut features from TRAIN forward passes only."""
    with torch.no_grad():
        feats = fx_client.detach().view(fx_client.shape[0], -1)  # [B, D]
        k = min(24, feats.shape[0])
        idx = torch.randperm(feats.shape[0], device=feats.device)[:k]
        add_to_reservoir(feats[idx].cpu().to(torch.float16))


#=====================================================================================================
#         Subspace builder (simple PCA/SVD on buffered features)
#=====================================================================================================
def build_U_old_from_memory(top_r=TOP_R, device='cpu'):
    """Build principal subspace from the reservoir via PCA (pca_lowrank)."""
    if len(FEATURE_MEM) == 0:
        return None
    X = torch.stack(FEATURE_MEM).to(torch.float32)     # [N, D]
    X = X - X.mean(dim=0, keepdim=True)
    U, S, V = torch.pca_lowrank(X.cpu(), q=min(top_r, X.shape[1]), center=False)
    return V[:, :top_r].to(device, dtype=torch.float32)

def clear_feature_mem():
    global FEATURE_MEM, _seen
    FEATURE_MEM.clear()
    _seen = 0


    
#=====================================================================================================
#                                          DATA Loader
#=====================================================================================================

CIFAR_MEAN = {
    "CIFAR10": [0.4914, 0.4822, 0.4465],
    "CIFAR100": [0.5071, 0.4867, 0.4408],
}[DATASET_NAME]
CIFAR_STD = {
    "CIFAR10": [0.2470, 0.2435, 0.2616],
    "CIFAR100": [0.2675, 0.2565, 0.2761],
}[DATASET_NAME]



# RandAugment (fallback if old torchvision)
try:
    from torchvision.transforms import RandAugment
    ra = [RandAugment(num_ops=2, magnitude=9)]
except Exception:
    ra = []

train_transforms = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(32, padding=4),
    transforms.ToTensor(),
    transforms.Normalize(mean=CIFAR_MEAN, std=CIFAR_STD),
])

test_transforms = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=CIFAR_MEAN, std=CIFAR_STD),
])

if DATASET_NAME == "CIFAR10":
    dataset_train = datasets.CIFAR10(
        root=DATA_ROOT, train=True, download=True, transform=train_transforms
    )
    dataset_test = datasets.CIFAR10(
        root=DATA_ROOT, train=False, download=True, transform=test_transforms
    )
    NUM_CLASSES = 10
else:
    dataset_train = datasets.CIFAR100(
        root=DATA_ROOT, train=True, download=True, transform=train_transforms
    )
    dataset_test = datasets.CIFAR100(
        root=DATA_ROOT, train=False, download=True, transform=test_transforms
    )
    NUM_CLASSES = 100

#=============================================================================
#                         Forgetting metric setup 
#============================================================================= 

from collections import defaultdict

T = EPOCHS
class DatasetSplit(Dataset):  # (you already have this in both scripts; keep just one copy)
    def __init__(self, dataset, idxs):
        self.dataset, self.idxs = dataset, list(idxs)
    def __len__(self): return len(self.idxs)
    def __getitem__(self, i): return self.dataset[self.idxs[i]]

val_loaders = {}
# Deterministic, disjoint slices of the test set: window t gets items t, t+T, t+2T, ...
rng_idx = np.arange(len(dataset_test))
for t in range(T):
    idxs = rng_idx[t::T]
    val_loaders[t] = DataLoader(DatasetSplit(dataset_test, idxs),
                                batch_size=BATCH_SIZE, shuffle=False, drop_last=False, num_workers=NUM_WORKERS)

best_loss_per_window = defaultdict(lambda: float('inf'))  # stores min historical loss per window
forgetting_log = []  # per round dicts: {"round": t, "mean_forgetting": x, "per_window": {...}}
# ============================================================================

def _eval_loss_on_loader(model_client, model_server, loader, device, criterion):
    """Evaluate mean loss on a loader using split models."""
    # Handle DataParallel transparently
    mc = model_client.module if isinstance(model_client, nn.DataParallel) else model_client
    ms = model_server.module if isinstance(model_server, nn.DataParallel) else model_server
    mc.eval(); ms.eval()
    loss_sum, n = 0.0, 0
    with torch.no_grad():
        for images, labels in loader:
            images, labels = images.to(device), labels.to(device)
            fx = mc(images)
            logits = ms(fx)
            loss = criterion(logits, labels)
            bs = labels.size(0)
            loss_sum += loss.item() * bs
            n += bs
    return loss_sum / max(1, n)

#=====================================================================================================
#                           IID / Dirichlet partitioning
#=====================================================================================================

class DatasetSplit(Dataset):
    def __init__(self, dataset, idxs):
        self.dataset = dataset
        self.idxs = list(idxs)
    def __len__(self):
        return len(self.idxs)
    def __getitem__(self, item):
        image, label = self.dataset[self.idxs[item]]
        return image, label

def dataset_iid(dataset, num_users):
    num_items = int(len(dataset) / num_users)
    dict_users, all_idxs = {}, [i for i in range(len(dataset))]
    for i in range(num_users):
        dict_users[i] = set(np.random.choice(all_idxs, num_items, replace=False))
        all_idxs = list(set(all_idxs) - dict_users[i])
    return dict_users

def dataset_noniid_dirichlet(dataset, num_users, alpha=ALPHA, seed=SEED):
    rng = np.random.default_rng(seed)
    labels = np.array(dataset.targets)
    n_classes = len(np.unique(labels))
    dict_users = {i: set() for i in range(num_users)}
    for c in range(n_classes):
        idxs = np.where(labels == c)[0]
        rng.shuffle(idxs)
        p = rng.dirichlet([alpha] * num_users)
        cuts = (np.cumsum(p) * len(idxs)).astype(int)[:-1]
        splits = np.split(idxs, cuts)
        for client_id, split in enumerate(splits):
            dict_users[client_id].update(split.tolist())
    return dict_users

dict_users      = dataset_noniid_dirichlet(dataset_train, NUM_CLIENTS, alpha=ALPHA)
dict_users_test = dataset_iid(dataset_test, NUM_CLIENTS)



#=====================================================================================================
#                           Client-side Model definition
#=====================================================================================================
# Model at client side
class ResNet18_client_side(nn.Module):
    """Client side up to early residual stack (same as your original)."""
    def __init__(self):
        super().__init__()
        self.layer1 = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=7, stride=2, padding=3, bias=False),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2, padding=1),
        )
        self.layer2 = nn.Sequential(
            nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(64),
        )
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                m.weight.data.normal_(0, math.sqrt(2.0 / n))
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()

    def forward(self, x):
        residual1 = F.relu(self.layer1(x))
        out1 = self.layer2(residual1)
        out1 = out1 + residual1
        out1 = F.relu(out1)
        return out1
 
           
#=====================================================================================================
#                           Server-side Model definition
#=====================================================================================================
# Model at server side
class Baseblock(nn.Module):
    expansion = 1
    def __init__(self, in_planes, planes, stride=1, dim_change=None):
        super().__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1)
        self.bn1   = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1)
        self.bn2   = nn.BatchNorm2d(planes)
        self.dim_change = dim_change
    def forward(self, x):
        res = x
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        if self.dim_change is not None:
            res = self.dim_change(res)
        out += res
        out = F.relu(out)
        return out

class ResNet18_server_side(nn.Module):
    def __init__(self, block, num_layers, classes):
        super().__init__()
        self.input_planes = 64
        self.layer3 = nn.Sequential(
            nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(64),
        )
        self.layer4 = self._layer(block, 128, num_layers[0], stride=2)
        self.layer5 = self._layer(block, 256, num_layers[1], stride=2)
        self.layer6 = self._layer(block, 512, num_layers[2], stride=2)
        self.fc = nn.Linear(512 * block.expansion, classes)
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                m.weight.data.normal_(0, math.sqrt(2.0 / n))
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()

    def _layer(self, block, planes, num_layers, stride=2):
        dim_change = None
        if stride != 1 or planes != self.input_planes * block.expansion:
            dim_change = nn.Sequential(
                nn.Conv2d(self.input_planes, planes * block.expansion, kernel_size=1, stride=stride),
                nn.BatchNorm2d(planes * block.expansion),
            )
        layers = [block(self.input_planes, planes, stride=stride, dim_change=dim_change)]
        self.input_planes = planes * block.expansion
        for _ in range(1, num_layers):
            layers.append(block(self.input_planes, planes))
            self.input_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out2 = self.layer3(x)
        out2 = out2 + x
        x3 = F.relu(out2)
        x4 = self.layer4(x3)
        x5 = self.layer5(x4)
        x6 = self.layer6(x5)
        x7 = F.adaptive_avg_pool2d(x6, 1)
        x8 = x7.view(x7.size(0), -1)
        y_hat = self.fc(x8)
        return y_hat

net_glob_client = ResNet18_client_side().to(device)
net_glob_server = ResNet18_server_side(Baseblock, [2, 2, 2], NUM_CLASSES).to(device)

if torch.cuda.device_count() > 1:
    print("Using", torch.cuda.device_count(), "GPUs")
    net_glob_client = nn.DataParallel(net_glob_client)
    net_glob_server = nn.DataParallel(net_glob_server) 

#===================================================================================
# For Server Side Loss and Accuracy 
loss_train_collect = []
acc_train_collect = []
loss_test_collect = []
acc_test_collect = []
batch_acc_train = []
batch_loss_train = []
batch_acc_test = []
batch_loss_test = []
round_time_collect = [] # Stores seconds per global round

criterion = nn.CrossEntropyLoss(label_smoothing=0.05)

#====================================================================================================
#                                  Server Side Program
#====================================================================================================
def calculate_accuracy(fx, y):
    preds = fx.max(1, keepdim=True)[1]
    correct = preds.eq(y.view_as(preds)).sum()
    acc = 100.0 * correct.float() / preds.shape[0]
    return acc

# to print train - test together in each round-- these are made global
acc_avg_all_user_train = 0
loss_avg_all_user_train = 0
loss_train_collect_user = []
acc_train_collect_user = []
loss_test_collect_user = []
acc_test_collect_user = []


#client idx collector
idx_collect = []
l_epoch_check = False
fed_check = False
count1 = 0
count2 = 0
ell_global = 0  # set at each global round


# Persistent server optimizer + scheduler
optimizer_server = torch.optim.SGD(net_glob_server.parameters(), lr=lr_srv, momentum=momentum, weight_decay=weight_decay)
server_sched = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer_server, T_max=EPOCHS, eta_min=5e-4)



#====================================================================================================
#                                  Server Routines
#====================================================================================================

# Server-side function associated with Training 
def train_server(fx_client, y, l_epoch_count, l_epoch, idx, len_batch):
    global net_glob_server, optimizer_server, criterion
    global batch_acc_train, batch_loss_train, l_epoch_check, fed_check
    global loss_train_collect, acc_train_collect, count1
    global acc_avg_all_user_train, loss_avg_all_user_train, idx_collect
    global loss_train_collect_user, acc_train_collect_user, U_old, ell_global

    
    # train and update
    net_glob_server.train()
    optimizer_server.zero_grad()
    
    #---------forward prop-------------
    fx_client = fx_client.to(device)
    y = y.to(device)

    fx_server = net_glob_server(fx_client)
    loss = criterion(fx_server, y)
    acc  = calculate_accuracy(fx_server, y)
    
    #--------backward prop--------------
    loss.backward()

    # -------------- ORTH PROJECTION AT THE CUT GRADIENT --------------
    # OP at the cut
    dfx_client = fx_client.grad.clone().detach()
    if ORTH and (U_old is not None):
        alpha = proj_gate_strength(ell_global)
        dfx_client = project_off_subspace_gated(dfx_client, U_old.to(dfx_client.dtype), alpha)

    optimizer_server.step()

    batch_loss_train.append(loss.item())
    batch_acc_train.append(acc.item())
    # ---------------------------------------------------------------
# bookkeeping for per-client local epoch end
    count1 += 1
    if count1 == len_batch:
        acc_avg_train = sum(batch_acc_train) / len(batch_acc_train)
        loss_avg_train = sum(batch_loss_train) / len(batch_loss_train)
        batch_acc_train.clear()
        batch_loss_train.clear()
        count1 = 0
        print(f"\033[91m Client{idx} Train => Local Epoch: {l_epoch_count} \tAcc: {acc_avg_train:.3f} \tLoss: {loss_avg_train:.4f}\033[00m")

        if l_epoch_count == l_epoch - 1:
            l_epoch_check = True
            loss_train_collect_user.append(loss_avg_train)
            acc_train_collect_user.append(acc_avg_train)
            if idx not in idx_collect:
                idx_collect.append(idx)

        if len(idx_collect) == NUM_CLIENTS:
            fed_check = True
            idx_collect.clear()
            acc_avg_all_user_train = sum(acc_train_collect_user) / len(acc_train_collect_user)
            loss_avg_all_user_train = sum(loss_train_collect_user) / len(loss_train_collect_user)
            loss_train_collect.append(loss_avg_all_user_train)
            acc_train_collect.append(acc_avg_all_user_train)
            acc_train_collect_user.clear()
            loss_train_collect_user.clear()

    return dfx_client

def evaluate_server(fx_client, y, idx, len_batch, ell):
    global net_glob_server, criterion
    global batch_acc_test, batch_loss_test
    global loss_test_collect, acc_test_collect, count2
    global acc_avg_all_user_train, loss_avg_all_user_train, l_epoch_check, fed_check
    global loss_test_collect_user, acc_test_collect_user
    global U_old

    net_glob_server.eval()
    with torch.no_grad():
        fx_client = fx_client.to(device)
        y = y.to(device)
        fx_server = net_glob_server(fx_client)
        loss = criterion(fx_server, y)
        acc  = calculate_accuracy(fx_server, y)

        batch_loss_test.append(loss.item())
        batch_acc_test.append(acc.item())

        count2 += 1
        if count2 == len_batch:
            acc_avg_test = sum(batch_acc_test) / len(batch_acc_test)
            loss_avg_test = sum(batch_loss_test) / len(batch_loss_test)
            batch_acc_test.clear()
            batch_loss_test.clear()
            count2 = 0
            print(f"\033[92m Client{idx} Test  => \tAcc: {acc_avg_test:.3f} \tLoss: {loss_avg_test:.4f}\033[00m")

            if l_epoch_check:
                l_epoch_check = False
                loss_test_collect_user.append(loss_avg_test)
                acc_test_collect_user.append(acc_avg_test)

            if fed_check:
                fed_check = False
                acc_avg_all_user = sum(acc_test_collect_user) / len(acc_test_collect_user)
                loss_avg_all_user = sum(loss_test_collect_user) / len(loss_test_collect_user)
                loss_test_collect.append(loss_avg_all_user)
                acc_test_collect.append(acc_avg_all_user)
                acc_test_collect_user.clear()
                loss_test_collect_user.clear()

                print("====================== SERVER (OP-gated) ==========================")
                print(f" Train: Round {ell:3d}, Avg Acc {acc_avg_all_user_train:.3f} | Avg Loss {loss_avg_all_user_train:.3f}")
                print(f" Test : Round {ell:3d}, Avg Acc {acc_avg_all_user:.3f} | Avg Loss {loss_avg_all_user:.3f}")
                


# ------------------------------ Client Wrapper -------------------------------
class Client(object):
    def __init__(self, net_client_model, idx, lr, device, dataset_train=None, dataset_test=None, idxs=None, idxs_test=None):
        self.idx = idx
        self.device = device
        self.lr = lr
        self.local_ep = local_ep
        self.ldr_train = DataLoader(DatasetSplit(dataset_train, idxs), batch_size=BATCH_SIZE, shuffle=True, drop_last=False, num_workers=NUM_WORKERS)
        self.ldr_test  = DataLoader(DatasetSplit(dataset_test,  idxs_test), batch_size=BATCH_SIZE, shuffle=False, drop_last=False, num_workers=NUM_WORKERS)

    def train(self, net):
        net.train()
        optimizer_client = torch.optim.SGD(net.parameters(), lr=self.lr, momentum=momentum, weight_decay=weight_decay)
        for ep in range(self.local_ep):
            len_batch = len(self.ldr_train)
            for batch_idx, (images, labels) in enumerate(self.ldr_train):
                images, labels = images.to(self.device), labels.to(self.device)
                optimizer_client.zero_grad()
                # Forward through client
                fx = net(images)
                # Collect train-side features for U reservoir
                if ORTH:
                    collect_cut_feats_from_train(fx)
                client_fx = fx.clone().detach().requires_grad_(True)

                # Send to server => receive gradient wrt cut activations
                dfx = train_server(client_fx, labels, ep, self.local_ep, self.idx, len_batch)

                # Backprop to client
                fx.backward(dfx)
                optimizer_client.step()
        return net.state_dict()

    def evaluate(self, net, ell):
        net.eval()
        with torch.no_grad():
            len_batch = len(self.ldr_test)
            for batch_idx, (images, labels) in enumerate(self.ldr_test):
                images, labels = images.to(self.device), labels.to(self.device)
                fx = net(images)
                evaluate_server(fx, labels, self.idx, len_batch, ell)
        return

# ------------------------------ BN Freeze Helper -----------------------------
def freeze_client_bn(net):
    """Freeze client BN stats after warmup to stabilize cut gradients."""
    for m in net.modules():
        if isinstance(m, nn.BatchNorm2d):
            m.eval()

# --------------------------------- Training ----------------------------------
acc_train_collect.clear(); loss_train_collect.clear()
acc_test_collect.clear();  loss_test_collect.clear()
round_time_collect.clear()

for iter in range(EPOCHS):
    # set global round (for α schedule)
    ell_global = iter

    # optional: freeze client BN exactly at the end of warmup
    if iter == WARMUP_ROUNDS:
        if isinstance(net_glob_client, nn.DataParallel):
            freeze_client_bn(net_glob_client.module)
        else:
            freeze_client_bn(net_glob_client)

    _sync_cuda()
    t0 = time.perf_counter()

    m = max(int(frac * NUM_CLIENTS), 1)
    idxs_users = np.random.choice(range(NUM_CLIENTS), m, replace=False)

    for idx in idxs_users:
        local = Client(net_glob_client, idx, lr_cli, device,
                       dataset_train=dataset_train, dataset_test=dataset_test,
                       idxs=dict_users[idx], idxs_test=dict_users_test[idx])

        # Train
        w_client = local.train(net=copy.deepcopy(net_glob_client).to(device))
        # Test (uses current global client state)
        local.evaluate(net=copy.deepcopy(net_glob_client).to(device), ell=iter)
        # Update client weights for next client
        net_glob_client.load_state_dict(w_client)

    _sync_cuda()
    dt = time.perf_counter() - t0
    
    # === Forgetting update at end of round `iter` ================================
    t = iter  # current window id
    t1 = time.perf_counter()
    
    # 1) Update the "best so far" for the CURRENT window using the current model
    L_cur_t = _eval_loss_on_loader(net_glob_client, net_glob_server, val_loaders[t], device, criterion)
    best_loss_per_window[t] = min(best_loss_per_window[t], L_cur_t)

    # 2) Compute forgetting on all PAST windows t0 < t
    per_win_fgt = {}
    for t0 in range(t):
        L_now = _eval_loss_on_loader(net_glob_client, net_glob_server, val_loaders[t0], device, criterion)
        Fgt = L_now - best_loss_per_window[t0]
        per_win_fgt[t0] = Fgt

    mean_fgt = float(np.mean(list(per_win_fgt.values()))) if per_win_fgt else 0.0
    forgetting_log.append({"round": t, "mean_forgetting": mean_fgt, "per_window": per_win_fgt})
    print(f"Forgetting : Round {t}, mean_forgetting : {mean_fgt:.3f}")
    print("===================================================================")
   
    forget_dt = time.perf_counter() - t1
    # Rebuild U once per round, after we’ve collected features this round
    if ORTH and (iter % rebuild_every == 1):
        U_old = build_U_old_from_memory(top_r=TOP_R, device=device)
        clear_feature_mem()

    # Log training time ONLY (no forgetting, no PCA)
    round_time_collect.append(dt)

    server_sched.step()
    
print("Training and Evaluation completed!")    

#===============================================================================
# Save output data to .excel file (we use for comparision plots)
#================ Save outputs ================#
# Align lengths safely (in case of any mismatch)
n = min(len(acc_train_collect), len(acc_test_collect), len(round_time_collect), len(forgetting_log))
round_process = list(range(1, n + 1))
mean_fgt_series = [d["mean_forgetting"] for d in forgetting_log[:n]]

df = pd.DataFrame({
    'round': round_process,
    'acc_train': acc_train_collect[:n],
    'acc_test':  acc_test_collect[:n],
    'round_time_sec': round_time_collect[:n],
    'mean_FgT_loss': mean_fgt_series,
    'projection': [True]*n,
    'top_r': [TOP_R]*n,
    'feature_mem_cap': [FEATURE_MEM_CAP]*n,
    'alpha': [ALPHA]*n,
    'num_users': [NUM_CLIENTS]*n,
    'lr_server': [lr_srv]*n,
    'lr_client': [lr_cli]*n,
    'seed': [SEED]*n,
})


file_name_csv  = program + ".csv"
df.to_csv(file_name_csv, index=False)
print("Saved:", file_name_csv)


#=============================================================================
#                         Program Completed
#=============================================================================
# Out:
# NVIDIA H200
# ---------SL + Projected on CIFAR-10 α=0.1----------
#  	Data:		CIFAR10
# 	Cut:		Original at 2
# 	Global Rounds:	100
# 	Clients:	10
# 	Local Epochs:	5
# 	α:		0.1
# 	Warm-up:	5
# 	Rebuild:	3
#  Client3 Train => Local Epoch: 0 	Acc: 80.598 	Loss: 1.4271
#  Client3 Train => Local Epoch: 1 	Acc: 87.241 	Loss: 0.9585
#  Client3 Train => Local Epoch: 2 	Acc: 89.932 	Loss: 0.7685
#  Client3 Train => Local Epoch: 3 	Acc: 89.901 	Loss: 0.6692
#  Client3 Train => Local Epoch: 4 	Acc: 90.585 	Loss: 0.6319
#  Client3 Test  => 	Acc: 9.510 	Loss: 3.5756
#  Client1 Train => Local Epoch: 0 	Acc: 78.610 	Loss: 1.1144
#  Client1 Train => Local Epoch: 1 	Acc: 87.721 	Loss: 0.7059
#  Client1 Train => Local Epoch: 2 	Acc: 90.620 	Loss: 0.5846
#  Client1 Train => Local Epoch: 3 	Acc: 91.498 	Loss: 0.5484
#  Client1 Train => Local Epoch: 4 	Acc: 92.804 	Loss: 0.5080
#  Client1 Test  => 	Acc: 17.076 	Loss: 5.1655
#  Client2 Train => Local Epoch: 0 	Acc: 75.033 	Loss: 1.6265
#  Client2 Train => Local Epoch: 1 	Acc: 88.888 	Loss: 0.7731
#  Client2 Train => Local Epoch: 2 	Acc: 90.682 	Loss: 0.6145
#  Client2 Train => Local Epoch: 3 	Acc: 91.201 	Loss: 0.5850
#  Client2 Train => Local Epoch: 4 	Acc: 91.829 	Loss: 0.5518
#  Client2 Test  => 	Acc: 15.517 	Loss: 3.6296
#  Client0 Train => Local Epoch: 0 	Acc: 4.143 	Loss: 3.8614
#  Client0 Train => Local Epoch: 1 	Acc: 26.933 	Loss: 2.0833
#  Client0 Train => Local Epoch: 2 	Acc: 51.763 	Loss: 1.4468
#  Client0 Train => Local Epoch: 3 	Acc: 68.211 	Loss: 1.3143
#  Client0 Train => Local Epoch: 4 	Acc: 71.730 	Loss: 1.2801
#  Client0 Test  => 	Acc: 17.427 	Loss: 4.1194
#  Client8 Train => Local Epoch: 0 	Acc: 64.828 	Loss: 1.4444
#  Client8 Train => Local Epoch: 1 	Acc: 79.972 	Loss: 0.8763
#  Client8 Train => Local Epoch: 2 	Acc: 81.051 	Loss: 0.8188
#  Client8 Train => Local Epoch: 3 	Acc: 81.238 	Loss: 0.8011
#  Client8 Train => Local Epoch: 4 	Acc: 82.502 	Loss: 0.7585
#  Client8 Test  => 	Acc: 18.999 	Loss: 3.5392
#  Client7 Train => Local Epoch: 0 	Acc: 64.090 	Loss: 1.3783
#  Client7 Train => Local Epoch: 1 	Acc: 90.314 	Loss: 0.5425
#  Client7 Train => Local Epoch: 2 	Acc: 91.929 	Loss: 0.4920
#  Client7 Train => Local Epoch: 3 	Acc: 92.098 	Loss: 0.4727
#  Client7 Train => Local Epoch: 4 	Acc: 92.740 	Loss: 0.4633
#  Client7 Test  => 	Acc: 17.083 	Loss: 4.2624
#  Client6 Train => Local Epoch: 0 	Acc: 43.143 	Loss: 1.8968
#  Client6 Train => Local Epoch: 1 	Acc: 79.366 	Loss: 0.8318
#  Client6 Train => Local Epoch: 2 	Acc: 82.284 	Loss: 0.7643
#  Client6 Train => Local Epoch: 3 	Acc: 84.699 	Loss: 0.6988
#  Client6 Train => Local Epoch: 4 	Acc: 85.746 	Loss: 0.6680
#  Client6 Test  => 	Acc: 18.831 	Loss: 4.0965
#  Client9 Train => Local Epoch: 0 	Acc: 46.204 	Loss: 1.9333
#  Client9 Train => Local Epoch: 1 	Acc: 63.085 	Loss: 1.2401
#  Client9 Train => Local Epoch: 2 	Acc: 64.601 	Loss: 1.1281
#  Client9 Train => Local Epoch: 3 	Acc: 66.513 	Loss: 1.0661
#  Client9 Train => Local Epoch: 4 	Acc: 67.683 	Loss: 1.0333
#  Client9 Test  => 	Acc: 17.289 	Loss: 3.3577
#  Client5 Train => Local Epoch: 0 	Acc: 55.594 	Loss: 1.4162
#  Client5 Train => Local Epoch: 1 	Acc: 67.052 	Loss: 1.0653
#  Client5 Train => Local Epoch: 2 	Acc: 71.329 	Loss: 0.9811
#  Client5 Train => Local Epoch: 3 	Acc: 71.732 	Loss: 0.9434
#  Client5 Train => Local Epoch: 4 	Acc: 74.489 	Loss: 0.9086
#  Client5 Test  => 	Acc: 28.411 	Loss: 3.3189
#  Client4 Train => Local Epoch: 0 	Acc: 64.003 	Loss: 1.4379
#  Client4 Train => Local Epoch: 1 	Acc: 74.575 	Loss: 1.0134
#  Client4 Train => Local Epoch: 2 	Acc: 76.379 	Loss: 0.9314
#  Client4 Train => Local Epoch: 3 	Acc: 76.409 	Loss: 0.9125
#  Client4 Train => Local Epoch: 4 	Acc: 76.985 	Loss: 0.8947
#  Client4 Test  => 	Acc: 22.370 	Loss: 2.9966
# ====================== SERVER (OP-gated) ==========================
#  Train: Round   0, Avg Acc 82.709 | Avg Loss 0.770
#  Test : Round   0, Avg Acc 18.251 | Avg Loss 3.806
# Forgetting : Round 0, mean_forgetting : 0.000
# ===================================================================
#  Client7 Train => Local Epoch: 0 	Acc: 73.281 	Loss: 1.0666
#  Client7 Train => Local Epoch: 1 	Acc: 91.644 	Loss: 0.5049
#  Client7 Train => Local Epoch: 2 	Acc: 92.886 	Loss: 0.4669
#  Client7 Train => Local Epoch: 3 	Acc: 93.814 	Loss: 0.4479
#  Client7 Train => Local Epoch: 4 	Acc: 93.318 	Loss: 0.4541
#  Client7 Test  => 	Acc: 15.500 	Loss: 4.8275
#  Client1 Train => Local Epoch: 0 	Acc: 41.847 	Loss: 2.0134
#  Client1 Train => Local Epoch: 1 	Acc: 86.783 	Loss: 0.6164
#  Client1 Train => Local Epoch: 2 	Acc: 90.420 	Loss: 0.5393
#  Client1 Train => Local Epoch: 3 	Acc: 91.807 	Loss: 0.4956
#  Client1 Train => Local Epoch: 4 	Acc: 92.477 	Loss: 0.4731
#  Client1 Test  => 	Acc: 15.180 	Loss: 4.6276
#  Client4 Train => Local Epoch: 0 	Acc: 31.166 	Loss: 2.6300
#  Client4 Train => Local Epoch: 1 	Acc: 70.617 	Loss: 1.3948
#  Client4 Train => Local Epoch: 2 	Acc: 70.207 	Loss: 1.2123
#  Client4 Train => Local Epoch: 3 	Acc: 70.742 	Loss: 1.1312
#  Client4 Train => Local Epoch: 4 	Acc: 72.084 	Loss: 1.0727
#  Client4 Test  => 	Acc: 12.635 	Loss: 3.1104
#  Client8 Train => Local Epoch: 0 	Acc: 53.524 	Loss: 1.5383
#  Client8 Train => Local Epoch: 1 	Acc: 79.785 	Loss: 0.8547
#  Client8 Train => Local Epoch: 2 	Acc: 80.696 	Loss: 0.7967
#  Client8 Train => Local Epoch: 3 	Acc: 81.293 	Loss: 0.7756
#  Client8 Train => Local Epoch: 4 	Acc: 82.501 	Loss: 0.7439
#  Client8 Test  => 	Acc: 14.359 	Loss: 3.8095
#  Client2 Train => Local Epoch: 0 	Acc: 34.410 	Loss: 2.1981
#  Client2 Train => Local Epoch: 1 	Acc: 88.046 	Loss: 0.7472
#  Client2 Train => Local Epoch: 2 	Acc: 91.470 	Loss: 0.5892
#  Client2 Train => Local Epoch: 3 	Acc: 91.743 	Loss: 0.5592
#  Client2 Train => Local Epoch: 4 	Acc: 91.596 	Loss: 0.5493
#  Client2 Test  => 	Acc: 16.123 	Loss: 4.6673
#  Client9 Train => Local Epoch: 0 	Acc: 36.469 	Loss: 2.1922
#  Client9 Train => Local Epoch: 1 	Acc: 61.892 	Loss: 1.2756
#  Client9 Train => Local Epoch: 2 	Acc: 64.917 	Loss: 1.1177
#  Client9 Train => Local Epoch: 3 	Acc: 67.346 	Loss: 1.0358
#  Client9 Train => Local Epoch: 4 	Acc: 69.194 	Loss: 1.0019
#  Client9 Test  => 	Acc: 17.467 	Loss: 3.1397
#  Client6 Train => Local Epoch: 0 	Acc: 66.507 	Loss: 1.1943
#  Client6 Train => Local Epoch: 1 	Acc: 83.313 	Loss: 0.7162
#  Client6 Train => Local Epoch: 2 	Acc: 84.991 	Loss: 0.6767
#  Client6 Train => Local Epoch: 3 	Acc: 86.148 	Loss: 0.6450
#  Client6 Train => Local Epoch: 4 	Acc: 87.258 	Loss: 0.6149
#  Client6 Test  => 	Acc: 21.666 	Loss: 3.6842
#  Client5 Train => Local Epoch: 0 	Acc: 45.046 	Loss: 1.8868
#  Client5 Train => Local Epoch: 1 	Acc: 66.103 	Loss: 1.0800
#  Client5 Train => Local Epoch: 2 	Acc: 70.059 	Loss: 0.9617
#  Client5 Train => Local Epoch: 3 	Acc: 72.347 	Loss: 0.9206
#  Client5 Train => Local Epoch: 4 	Acc: 73.137 	Loss: 0.8959
#  Client5 Test  => 	Acc: 28.842 	Loss: 3.1069
#  Client3 Train => Local Epoch: 0 	Acc: 3.983 	Loss: 3.1342
#  Client3 Train => Local Epoch: 1 	Acc: 85.494 	Loss: 1.1950
#  Client3 Train => Local Epoch: 2 	Acc: 90.140 	Loss: 0.8206
#  Client3 Train => Local Epoch: 3 	Acc: 90.171 	Loss: 0.7480
#  Client3 Train => Local Epoch: 4 	Acc: 90.176 	Loss: 0.6486
#  Client3 Test  => 	Acc: 9.510 	Loss: 3.8560
#  Client0 Train => Local Epoch: 0 	Acc: 1.036 	Loss: 4.1484
#  Client0 Train => Local Epoch: 1 	Acc: 9.949 	Loss: 2.4748
#  Client0 Train => Local Epoch: 2 	Acc: 31.265 	Loss: 1.7787
#  Client0 Train => Local Epoch: 3 	Acc: 60.673 	Loss: 1.4811
#  Client0 Train => Local Epoch: 4 	Acc: 77.216 	Loss: 1.1378
#  Client0 Test  => 	Acc: 18.305 	Loss: 4.0495
# ====================== SERVER (OP-gated) ==========================
#  Train: Round   1, Avg Acc 82.896 | Avg Loss 0.759
#  Test : Round   1, Avg Acc 16.959 | Avg Loss 3.888
# Forgetting : Round 1, mean_forgetting : 0.113
# ===================================================================
#  Client4 Train => Local Epoch: 0 	Acc: 36.121 	Loss: 2.2227
#  Client4 Train => Local Epoch: 1 	Acc: 70.450 	Loss: 1.3192
#  Client4 Train => Local Epoch: 2 	Acc: 71.206 	Loss: 1.1226
#  Client4 Train => Local Epoch: 3 	Acc: 74.453 	Loss: 1.0099
#  Client4 Train => Local Epoch: 4 	Acc: 76.038 	Loss: 0.9432
#  Client4 Test  => 	Acc: 14.746 	Loss: 3.5116
#  Client9 Train => Local Epoch: 0 	Acc: 32.331 	Loss: 2.2104
#  Client9 Train => Local Epoch: 1 	Acc: 63.468 	Loss: 1.2409
#  Client9 Train => Local Epoch: 2 	Acc: 67.360 	Loss: 1.0576
#  Client9 Train => Local Epoch: 3 	Acc: 69.855 	Loss: 0.9768
#  Client9 Train => Local Epoch: 4 	Acc: 71.632 	Loss: 0.9316
#  Client9 Test  => 	Acc: 20.750 	Loss: 3.3058
#  Client6 Train => Local Epoch: 0 	Acc: 60.380 	Loss: 1.3885
#  Client6 Train => Local Epoch: 1 	Acc: 83.411 	Loss: 0.7250
#  Client6 Train => Local Epoch: 2 	Acc: 85.979 	Loss: 0.6593
#  Client6 Train => Local Epoch: 3 	Acc: 86.128 	Loss: 0.6402
#  Client6 Train => Local Epoch: 4 	Acc: 87.952 	Loss: 0.6101
#  Client6 Test  => 	Acc: 25.340 	Loss: 3.3763
#  Client8 Train => Local Epoch: 0 	Acc: 66.207 	Loss: 1.3050
#  Client8 Train => Local Epoch: 1 	Acc: 81.835 	Loss: 0.7763
#  Client8 Train => Local Epoch: 2 	Acc: 83.453 	Loss: 0.7243
#  Client8 Train => Local Epoch: 3 	Acc: 84.008 	Loss: 0.6957
#  Client8 Train => Local Epoch: 4 	Acc: 84.631 	Loss: 0.6849
#  Client8 Test  => 	Acc: 20.114 	Loss: 3.6264
#  Client5 Train => Local Epoch: 0 	Acc: 45.466 	Loss: 1.9907
#  Client5 Train => Local Epoch: 1 	Acc: 68.332 	Loss: 1.0994
#  Client5 Train => Local Epoch: 2 	Acc: 72.146 	Loss: 0.9489
#  Client5 Train => Local Epoch: 3 	Acc: 74.562 	Loss: 0.8968
#  Client5 Train => Local Epoch: 4 	Acc: 77.049 	Loss: 0.8350
#  Client5 Test  => 	Acc: 32.536 	Loss: 3.1509
#  Client3 Train => Local Epoch: 0 	Acc: 3.384 	Loss: 2.9714
#  Client3 Train => Local Epoch: 1 	Acc: 60.615 	Loss: 1.5306
#  Client3 Train => Local Epoch: 2 	Acc: 90.017 	Loss: 0.7824
#  Client3 Train => Local Epoch: 3 	Acc: 89.924 	Loss: 0.7304
#  Client3 Train => Local Epoch: 4 	Acc: 90.078 	Loss: 0.6837
#  Client3 Test  => 	Acc: 9.510 	Loss: 3.8020
#  Client1 Train => Local Epoch: 0 	Acc: 38.457 	Loss: 2.0090
#  Client1 Train => Local Epoch: 1 	Acc: 90.521 	Loss: 0.5457
#  Client1 Train => Local Epoch: 2 	Acc: 93.005 	Loss: 0.4744
#  Client1 Train => Local Epoch: 3 	Acc: 93.788 	Loss: 0.4459
#  Client1 Train => Local Epoch: 4 	Acc: 94.303 	Loss: 0.4345
#  Client1 Test  => 	Acc: 16.527 	Loss: 4.4845
#  Client7 Train => Local Epoch: 0 	Acc: 48.897 	Loss: 1.8431
#  Client7 Train => Local Epoch: 1 	Acc: 90.716 	Loss: 0.5448
#  Client7 Train => Local Epoch: 2 	Acc: 92.654 	Loss: 0.4852
#  Client7 Train => Local Epoch: 3 	Acc: 93.161 	Loss: 0.4603
#  Client7 Train => Local Epoch: 4 	Acc: 94.077 	Loss: 0.4411
#  Client7 Test  => 	Acc: 16.389 	Loss: 4.8958
#  Client0 Train => Local Epoch: 0 	Acc: 27.667 	Loss: 3.2392
#  Client0 Train => Local Epoch: 1 	Acc: 34.546 	Loss: 1.9194
#  Client0 Train => Local Epoch: 2 	Acc: 53.252 	Loss: 1.5177
#  Client0 Train => Local Epoch: 3 	Acc: 78.489 	Loss: 1.2981
#  Client0 Train => Local Epoch: 4 	Acc: 79.621 	Loss: 1.0839
#  Client0 Test  => 	Acc: 18.932 	Loss: 4.2457
#  Client2 Train => Local Epoch: 0 	Acc: 31.682 	Loss: 2.3523
#  Client2 Train => Local Epoch: 1 	Acc: 86.189 	Loss: 0.8618
#  Client2 Train => Local Epoch: 2 	Acc: 91.235 	Loss: 0.6535
#  Client2 Train => Local Epoch: 3 	Acc: 91.641 	Loss: 0.6055
#  Client2 Train => Local Epoch: 4 	Acc: 92.249 	Loss: 0.5654
#  Client2 Test  => 	Acc: 18.137 	Loss: 3.5287
# ====================== SERVER (OP-gated) ==========================
#  Train: Round   2, Avg Acc 84.763 | Avg Loss 0.721
#  Test : Round   2, Avg Acc 19.298 | Avg Loss 3.793
# Forgetting : Round 2, mean_forgetting : -0.436
# ===================================================================
#  Client2 Train => Local Epoch: 0 	Acc: 92.173 	Loss: 0.5536
#  Client2 Train => Local Epoch: 1 	Acc: 92.343 	Loss: 0.5409
#  Client2 Train => Local Epoch: 2 	Acc: 92.527 	Loss: 0.5287
#  Client2 Train => Local Epoch: 3 	Acc: 92.771 	Loss: 0.5210
#  Client2 Train => Local Epoch: 4 	Acc: 92.581 	Loss: 0.5215
#  Client2 Test  => 	Acc: 21.579 	Loss: 3.2838
#  Client1 Train => Local Epoch: 0 	Acc: 48.610 	Loss: 1.7126
#  Client1 Train => Local Epoch: 1 	Acc: 91.498 	Loss: 0.5362
#  Client1 Train => Local Epoch: 2 	Acc: 93.261 	Loss: 0.4676
#  Client1 Train => Local Epoch: 3 	Acc: 94.572 	Loss: 0.4384
#  Client1 Train => Local Epoch: 4 	Acc: 94.889 	Loss: 0.4216
#  Client1 Test  => 	Acc: 15.150 	Loss: 4.4609
#  Client3 Train => Local Epoch: 0 	Acc: 4.335 	Loss: 3.1174
#  Client3 Train => Local Epoch: 1 	Acc: 38.324 	Loss: 1.6984
#  Client3 Train => Local Epoch: 2 	Acc: 89.863 	Loss: 1.0851
#  Client3 Train => Local Epoch: 3 	Acc: 90.078 	Loss: 0.7318
#  Client3 Train => Local Epoch: 4 	Acc: 90.047 	Loss: 0.7324
#  Client3 Test  => 	Acc: 9.510 	Loss: 15.6110
#  Client7 Train => Local Epoch: 0 	Acc: 21.329 	Loss: 2.6540
#  Client7 Train => Local Epoch: 1 	Acc: 83.625 	Loss: 0.6760
#  Client7 Train => Local Epoch: 2 	Acc: 92.229 	Loss: 0.5007
#  Client7 Train => Local Epoch: 3 	Acc: 93.011 	Loss: 0.4663
#  Client7 Train => Local Epoch: 4 	Acc: 93.585 	Loss: 0.4435
#  Client7 Test  => 	Acc: 14.992 	Loss: 4.1753
#  Client5 Train => Local Epoch: 0 	Acc: 33.640 	Loss: 2.3918
#  Client5 Train => Local Epoch: 1 	Acc: 63.194 	Loss: 1.1969
#  Client5 Train => Local Epoch: 2 	Acc: 69.227 	Loss: 1.0323
#  Client5 Train => Local Epoch: 3 	Acc: 71.975 	Loss: 0.9603
#  Client5 Train => Local Epoch: 4 	Acc: 74.061 	Loss: 0.9019
#  Client5 Test  => 	Acc: 25.559 	Loss: 3.4302
#  Client4 Train => Local Epoch: 0 	Acc: 65.346 	Loss: 1.4323
#  Client4 Train => Local Epoch: 1 	Acc: 75.844 	Loss: 0.9920
#  Client4 Train => Local Epoch: 2 	Acc: 77.505 	Loss: 0.8961
#  Client4 Train => Local Epoch: 3 	Acc: 78.331 	Loss: 0.8491
#  Client4 Train => Local Epoch: 4 	Acc: 78.870 	Loss: 0.8337
#  Client4 Test  => 	Acc: 24.441 	Loss: 2.8173
#  Client8 Train => Local Epoch: 0 	Acc: 68.804 	Loss: 1.2297
#  Client8 Train => Local Epoch: 1 	Acc: 82.239 	Loss: 0.7600
#  Client8 Train => Local Epoch: 2 	Acc: 82.884 	Loss: 0.7285
#  Client8 Train => Local Epoch: 3 	Acc: 83.925 	Loss: 0.7039
#  Client8 Train => Local Epoch: 4 	Acc: 84.454 	Loss: 0.6826
#  Client8 Test  => 	Acc: 22.939 	Loss: 3.6397
#  Client9 Train => Local Epoch: 0 	Acc: 47.758 	Loss: 1.7454
#  Client9 Train => Local Epoch: 1 	Acc: 66.715 	Loss: 1.0929
#  Client9 Train => Local Epoch: 2 	Acc: 71.566 	Loss: 0.9657
#  Client9 Train => Local Epoch: 3 	Acc: 73.444 	Loss: 0.8898
#  Client9 Train => Local Epoch: 4 	Acc: 74.936 	Loss: 0.8663
#  Client9 Test  => 	Acc: 25.687 	Loss: 2.9977
#  Client6 Train => Local Epoch: 0 	Acc: 69.359 	Loss: 1.1924
#  Client6 Train => Local Epoch: 1 	Acc: 87.284 	Loss: 0.6334
#  Client6 Train => Local Epoch: 2 	Acc: 88.564 	Loss: 0.5897
#  Client6 Train => Local Epoch: 3 	Acc: 88.862 	Loss: 0.5719
#  Client6 Train => Local Epoch: 4 	Acc: 89.732 	Loss: 0.5551
#  Client6 Test  => 	Acc: 26.327 	Loss: 3.3260
#  Client0 Train => Local Epoch: 0 	Acc: 30.974 	Loss: 2.2944
#  Client0 Train => Local Epoch: 1 	Acc: 60.186 	Loss: 1.2596
#  Client0 Train => Local Epoch: 2 	Acc: 81.653 	Loss: 0.9949
#  Client0 Train => Local Epoch: 3 	Acc: 82.258 	Loss: 0.8506
#  Client0 Train => Local Epoch: 4 	Acc: 83.527 	Loss: 0.8021
#  Client0 Test  => 	Acc: 21.855 	Loss: 3.5672
# ====================== SERVER (OP-gated) ==========================
#  Train: Round   3, Avg Acc 85.668 | Avg Loss 0.676
#  Test : Round   3, Avg Acc 20.804 | Avg Loss 4.731
# Forgetting : Round 3, mean_forgetting : 0.462
# ===================================================================
#  Client9 Train => Local Epoch: 0 	Acc: 50.247 	Loss: 1.7500
#  Client9 Train => Local Epoch: 1 	Acc: 68.059 	Loss: 1.0565
#  Client9 Train => Local Epoch: 2 	Acc: 71.607 	Loss: 0.9484
#  Client9 Train => Local Epoch: 3 	Acc: 74.397 	Loss: 0.8810
#  Client9 Train => Local Epoch: 4 	Acc: 75.973 	Loss: 0.8474
#  Client9 Test  => 	Acc: 29.203 	Loss: 2.8440
#  Client3 Train => Local Epoch: 0 	Acc: 26.828 	Loss: 2.0049
#  Client3 Train => Local Epoch: 1 	Acc: 83.088 	Loss: 0.8334
#  Client3 Train => Local Epoch: 2 	Acc: 91.641 	Loss: 0.5918
#  Client3 Train => Local Epoch: 3 	Acc: 91.708 	Loss: 0.5812
#  Client3 Train => Local Epoch: 4 	Acc: 92.509 	Loss: 0.5595
#  Client3 Test  => 	Acc: 17.349 	Loss: 3.9398
#  Client8 Train => Local Epoch: 0 	Acc: 54.293 	Loss: 1.7547
#  Client8 Train => Local Epoch: 1 	Acc: 83.611 	Loss: 0.7337
#  Client8 Train => Local Epoch: 2 	Acc: 85.187 	Loss: 0.6634
#  Client8 Train => Local Epoch: 3 	Acc: 86.143 	Loss: 0.6374
#  Client8 Train => Local Epoch: 4 	Acc: 86.395 	Loss: 0.6236
#  Client8 Test  => 	Acc: 24.609 	Loss: 3.2392
#  Client4 Train => Local Epoch: 0 	Acc: 42.252 	Loss: 2.1660
#  Client4 Train => Local Epoch: 1 	Acc: 71.575 	Loss: 1.1246
#  Client4 Train => Local Epoch: 2 	Acc: 75.499 	Loss: 0.9674
#  Client4 Train => Local Epoch: 3 	Acc: 77.282 	Loss: 0.8937
#  Client4 Train => Local Epoch: 4 	Acc: 77.845 	Loss: 0.8537
#  Client4 Test  => 	Acc: 25.135 	Loss: 2.7958
#  Client1 Train => Local Epoch: 0 	Acc: 67.863 	Loss: 1.1147
#  Client1 Train => Local Epoch: 1 	Acc: 93.783 	Loss: 0.4637
#  Client1 Train => Local Epoch: 2 	Acc: 94.742 	Loss: 0.4317
#  Client1 Train => Local Epoch: 3 	Acc: 95.090 	Loss: 0.4171
#  Client1 Train => Local Epoch: 4 	Acc: 95.523 	Loss: 0.4017
#  Client1 Test  => 	Acc: 18.494 	Loss: 4.1450
#  Client6 Train => Local Epoch: 0 	Acc: 45.382 	Loss: 2.0061
#  Client6 Train => Local Epoch: 1 	Acc: 83.881 	Loss: 0.7302
#  Client6 Train => Local Epoch: 2 	Acc: 87.548 	Loss: 0.6194
#  Client6 Train => Local Epoch: 3 	Acc: 89.738 	Loss: 0.5731
#  Client6 Train => Local Epoch: 4 	Acc: 89.760 	Loss: 0.5638
#  Client6 Test  => 	Acc: 24.333 	Loss: 4.3253
#  Client2 Train => Local Epoch: 0 	Acc: 38.881 	Loss: 2.2718
#  Client2 Train => Local Epoch: 1 	Acc: 85.967 	Loss: 0.8138
#  Client2 Train => Local Epoch: 2 	Acc: 88.319 	Loss: 0.6624
#  Client2 Train => Local Epoch: 3 	Acc: 91.324 	Loss: 0.5887
#  Client2 Train => Local Epoch: 4 	Acc: 91.593 	Loss: 0.5606
#  Client2 Test  => 	Acc: 18.646 	Loss: 3.3675
#  Client5 Train => Local Epoch: 0 	Acc: 14.493 	Loss: 2.6561
#  Client5 Train => Local Epoch: 1 	Acc: 51.867 	Loss: 1.7409
#  Client5 Train => Local Epoch: 2 	Acc: 63.592 	Loss: 1.1976
#  Client5 Train => Local Epoch: 3 	Acc: 68.918 	Loss: 1.0085
#  Client5 Train => Local Epoch: 4 	Acc: 73.252 	Loss: 0.9197
#  Client5 Test  => 	Acc: 28.051 	Loss: 3.0661
#  Client0 Train => Local Epoch: 0 	Acc: 33.724 	Loss: 2.5451
#  Client0 Train => Local Epoch: 1 	Acc: 67.843 	Loss: 1.2807
#  Client0 Train => Local Epoch: 2 	Acc: 80.792 	Loss: 1.0323
#  Client0 Train => Local Epoch: 3 	Acc: 81.732 	Loss: 0.9442
#  Client0 Train => Local Epoch: 4 	Acc: 83.471 	Loss: 0.8071
#  Client0 Test  => 	Acc: 19.595 	Loss: 3.4020
#  Client7 Train => Local Epoch: 0 	Acc: 72.635 	Loss: 1.2114
#  Client7 Train => Local Epoch: 1 	Acc: 93.273 	Loss: 0.4783
#  Client7 Train => Local Epoch: 2 	Acc: 93.462 	Loss: 0.4540
#  Client7 Train => Local Epoch: 3 	Acc: 94.175 	Loss: 0.4305
#  Client7 Train => Local Epoch: 4 	Acc: 94.513 	Loss: 0.4195
#  Client7 Test  => 	Acc: 18.491 	Loss: 4.3761
# ====================== SERVER (OP-gated) ==========================
#  Train: Round   4, Avg Acc 86.083 | Avg Loss 0.656
#  Test : Round   4, Avg Acc 22.391 | Avg Loss 3.550
# Forgetting : Round 4, mean_forgetting : 0.428
# ===================================================================
#  Client9 Train => Local Epoch: 0 	Acc: 43.787 	Loss: 1.9329
#  Client9 Train => Local Epoch: 1 	Acc: 64.785 	Loss: 1.1625
#  Client9 Train => Local Epoch: 2 	Acc: 69.760 	Loss: 1.0028
#  Client9 Train => Local Epoch: 3 	Acc: 72.936 	Loss: 0.9212
#  Client9 Train => Local Epoch: 4 	Acc: 73.934 	Loss: 0.8896
#  Client9 Test  => 	Acc: 24.687 	Loss: 3.3050
#  Client5 Train => Local Epoch: 0 	Acc: 60.833 	Loss: 1.3026
#  Client5 Train => Local Epoch: 1 	Acc: 73.740 	Loss: 0.9227
#  Client5 Train => Local Epoch: 2 	Acc: 75.703 	Loss: 0.8538
#  Client5 Train => Local Epoch: 3 	Acc: 77.319 	Loss: 0.8147
#  Client5 Train => Local Epoch: 4 	Acc: 79.107 	Loss: 0.7923
#  Client5 Test  => 	Acc: 34.570 	Loss: 2.7323
#  Client7 Train => Local Epoch: 0 	Acc: 54.778 	Loss: 1.6478
#  Client7 Train => Local Epoch: 1 	Acc: 94.007 	Loss: 0.4624
#  Client7 Train => Local Epoch: 2 	Acc: 94.265 	Loss: 0.4325
#  Client7 Train => Local Epoch: 3 	Acc: 94.949 	Loss: 0.4175
#  Client7 Train => Local Epoch: 4 	Acc: 95.197 	Loss: 0.4078
#  Client7 Test  => 	Acc: 18.090 	Loss: 4.0325
#  Client3 Train => Local Epoch: 0 	Acc: 0.843 	Loss: 3.3229
#  Client3 Train => Local Epoch: 1 	Acc: 43.550 	Loss: 1.8072
#  Client3 Train => Local Epoch: 2 	Acc: 89.924 	Loss: 0.8856
#  Client3 Train => Local Epoch: 3 	Acc: 90.109 	Loss: 0.6922
#  Client3 Train => Local Epoch: 4 	Acc: 89.955 	Loss: 0.6646
#  Client3 Test  => 	Acc: 9.617 	Loss: 4.0119
#  Client8 Train => Local Epoch: 0 	Acc: 42.839 	Loss: 1.9687
#  Client8 Train => Local Epoch: 1 	Acc: 81.178 	Loss: 0.8109
#  Client8 Train => Local Epoch: 2 	Acc: 83.290 	Loss: 0.7142
#  Client8 Train => Local Epoch: 3 	Acc: 84.728 	Loss: 0.6717
#  Client8 Train => Local Epoch: 4 	Acc: 85.407 	Loss: 0.6534
#  Client8 Test  => 	Acc: 23.232 	Loss: 3.4026
#  Client2 Train => Local Epoch: 0 	Acc: 41.468 	Loss: 2.2977
#  Client2 Train => Local Epoch: 1 	Acc: 88.618 	Loss: 0.6886
#  Client2 Train => Local Epoch: 2 	Acc: 92.170 	Loss: 0.5559
#  Client2 Train => Local Epoch: 3 	Acc: 92.855 	Loss: 0.5219
#  Client2 Train => Local Epoch: 4 	Acc: 92.706 	Loss: 0.5110
#  Client2 Test  => 	Acc: 19.555 	Loss: 3.3244
#  Client0 Train => Local Epoch: 0 	Acc: 2.364 	Loss: 4.1394
#  Client0 Train => Local Epoch: 1 	Acc: 3.616 	Loss: 2.6205
#  Client0 Train => Local Epoch: 2 	Acc: 29.488 	Loss: 1.8629
#  Client0 Train => Local Epoch: 3 	Acc: 62.647 	Loss: 1.4361
#  Client0 Train => Local Epoch: 4 	Acc: 81.322 	Loss: 1.0734
#  Client0 Test  => 	Acc: 20.124 	Loss: 2.6355
#  Client6 Train => Local Epoch: 0 	Acc: 59.825 	Loss: 1.4158
#  Client6 Train => Local Epoch: 1 	Acc: 87.762 	Loss: 0.6519
#  Client6 Train => Local Epoch: 2 	Acc: 89.123 	Loss: 0.5827
#  Client6 Train => Local Epoch: 3 	Acc: 89.826 	Loss: 0.5654
#  Client6 Train => Local Epoch: 4 	Acc: 90.187 	Loss: 0.5470
#  Client6 Test  => 	Acc: 25.448 	Loss: 3.4302
#  Client1 Train => Local Epoch: 0 	Acc: 53.394 	Loss: 1.6295
#  Client1 Train => Local Epoch: 1 	Acc: 94.980 	Loss: 0.4659
#  Client1 Train => Local Epoch: 2 	Acc: 95.812 	Loss: 0.4087
#  Client1 Train => Local Epoch: 3 	Acc: 96.188 	Loss: 0.3937
#  Client1 Train => Local Epoch: 4 	Acc: 96.576 	Loss: 0.3936
#  Client1 Test  => 	Acc: 17.868 	Loss: 4.0570
#  Client4 Train => Local Epoch: 0 	Acc: 21.294 	Loss: 2.5406
#  Client4 Train => Local Epoch: 1 	Acc: 69.871 	Loss: 1.4786
#  Client4 Train => Local Epoch: 2 	Acc: 70.257 	Loss: 1.1970
#  Client4 Train => Local Epoch: 3 	Acc: 71.790 	Loss: 1.0603
#  Client4 Train => Local Epoch: 4 	Acc: 73.547 	Loss: 0.9868
#  Client4 Test  => 	Acc: 16.349 	Loss: 2.8667
# ====================== SERVER (OP-gated) ==========================
#  Train: Round   5, Avg Acc 85.794 | Avg Loss 0.692
#  Test : Round   5, Avg Acc 20.954 | Avg Loss 3.380
# Forgetting : Round 5, mean_forgetting : -1.175
# ===================================================================
#  Client2 Train => Local Epoch: 0 	Acc: 33.508 	Loss: 2.3221
#  Client2 Train => Local Epoch: 1 	Acc: 90.332 	Loss: 0.6703
#  Client2 Train => Local Epoch: 2 	Acc: 91.785 	Loss: 0.5608
#  Client2 Train => Local Epoch: 3 	Acc: 92.816 	Loss: 0.5298
#  Client2 Train => Local Epoch: 4 	Acc: 93.086 	Loss: 0.5165
#  Client2 Test  => 	Acc: 19.811 	Loss: 3.5241
#  Client5 Train => Local Epoch: 0 	Acc: 18.632 	Loss: 2.5778
#  Client5 Train => Local Epoch: 1 	Acc: 51.980 	Loss: 1.7103
#  Client5 Train => Local Epoch: 2 	Acc: 67.766 	Loss: 1.1562
#  Client5 Train => Local Epoch: 3 	Acc: 75.311 	Loss: 0.8729
#  Client5 Train => Local Epoch: 4 	Acc: 77.197 	Loss: 0.8211
#  Client5 Test  => 	Acc: 27.394 	Loss: 3.1327
#  Client8 Train => Local Epoch: 0 	Acc: 48.395 	Loss: 1.9043
#  Client8 Train => Local Epoch: 1 	Acc: 82.378 	Loss: 0.7834
#  Client8 Train => Local Epoch: 2 	Acc: 84.741 	Loss: 0.6806
#  Client8 Train => Local Epoch: 3 	Acc: 86.131 	Loss: 0.6390
#  Client8 Train => Local Epoch: 4 	Acc: 86.877 	Loss: 0.6192
#  Client8 Test  => 	Acc: 24.424 	Loss: 3.4185
#  Client3 Train => Local Epoch: 0 	Acc: 20.812 	Loss: 2.0878
#  Client3 Train => Local Epoch: 1 	Acc: 88.187 	Loss: 0.7946
#  Client3 Train => Local Epoch: 2 	Acc: 91.050 	Loss: 0.6268
#  Client3 Train => Local Epoch: 3 	Acc: 91.599 	Loss: 0.6049
#  Client3 Train => Local Epoch: 4 	Acc: 92.173 	Loss: 0.5754
#  Client3 Test  => 	Acc: 12.931 	Loss: 3.2443
#  Client0 Train => Local Epoch: 0 	Acc: 5.589 	Loss: 4.2197
#  Client0 Train => Local Epoch: 1 	Acc: 10.142 	Loss: 2.1048
#  Client0 Train => Local Epoch: 2 	Acc: 64.173 	Loss: 1.2915
#  Client0 Train => Local Epoch: 3 	Acc: 82.494 	Loss: 0.9442
#  Client0 Train => Local Epoch: 4 	Acc: 85.327 	Loss: 0.7525
#  Client0 Test  => 	Acc: 23.124 	Loss: 3.0389
#  Client7 Train => Local Epoch: 0 	Acc: 69.258 	Loss: 1.3221
#  Client7 Train => Local Epoch: 1 	Acc: 93.901 	Loss: 0.4824
#  Client7 Train => Local Epoch: 2 	Acc: 94.550 	Loss: 0.4373
#  Client7 Train => Local Epoch: 3 	Acc: 95.016 	Loss: 0.4154
#  Client7 Train => Local Epoch: 4 	Acc: 95.268 	Loss: 0.4061
#  Client7 Test  => 	Acc: 18.481 	Loss: 4.3659
#  Client6 Train => Local Epoch: 0 	Acc: 31.089 	Loss: 2.2846
#  Client6 Train => Local Epoch: 1 	Acc: 81.967 	Loss: 0.9256
#  Client6 Train => Local Epoch: 2 	Acc: 82.885 	Loss: 0.7374
#  Client6 Train => Local Epoch: 3 	Acc: 86.912 	Loss: 0.6449
#  Client6 Train => Local Epoch: 4 	Acc: 89.095 	Loss: 0.5982
#  Client6 Test  => 	Acc: 22.838 	Loss: 3.2940
#  Client1 Train => Local Epoch: 0 	Acc: 55.307 	Loss: 1.6419
#  Client1 Train => Local Epoch: 1 	Acc: 93.956 	Loss: 0.4948
#  Client1 Train => Local Epoch: 2 	Acc: 95.904 	Loss: 0.4161
#  Client1 Train => Local Epoch: 3 	Acc: 96.180 	Loss: 0.3993
#  Client1 Train => Local Epoch: 4 	Acc: 96.530 	Loss: 0.3832
#  Client1 Test  => 	Acc: 18.093 	Loss: 4.2765
#  Client9 Train => Local Epoch: 0 	Acc: 35.417 	Loss: 2.2623
#  Client9 Train => Local Epoch: 1 	Acc: 61.703 	Loss: 1.2472
#  Client9 Train => Local Epoch: 2 	Acc: 67.927 	Loss: 1.0582
#  Client9 Train => Local Epoch: 3 	Acc: 72.957 	Loss: 0.9296
#  Client9 Train => Local Epoch: 4 	Acc: 76.067 	Loss: 0.8594
#  Client9 Test  => 	Acc: 34.503 	Loss: 2.5649
#  Client4 Train => Local Epoch: 0 	Acc: 33.313 	Loss: 2.3247
#  Client4 Train => Local Epoch: 1 	Acc: 70.498 	Loss: 1.2503
#  Client4 Train => Local Epoch: 2 	Acc: 72.910 	Loss: 1.0565
#  Client4 Train => Local Epoch: 3 	Acc: 76.015 	Loss: 0.9433
#  Client4 Train => Local Epoch: 4 	Acc: 78.208 	Loss: 0.8604
#  Client4 Test  => 	Acc: 26.650 	Loss: 2.3224
# ====================== SERVER (OP-gated) ==========================
#  Train: Round   6, Avg Acc 86.983 | Avg Loss 0.639
#  Test : Round   6, Avg Acc 22.825 | Avg Loss 3.318
# Forgetting : Round 6, mean_forgetting : -1.503
# ===================================================================
#  Client4 Train => Local Epoch: 0 	Acc: 79.357 	Loss: 0.8174
#  Client4 Train => Local Epoch: 1 	Acc: 79.845 	Loss: 0.7980
#  Client4 Train => Local Epoch: 2 	Acc: 81.281 	Loss: 0.7618
#  Client4 Train => Local Epoch: 3 	Acc: 81.624 	Loss: 0.7468
#  Client4 Train => Local Epoch: 4 	Acc: 80.989 	Loss: 0.7513
#  Client4 Test  => 	Acc: 38.056 	Loss: 2.3288
#  Client3 Train => Local Epoch: 0 	Acc: 4.610 	Loss: 3.4054
#  Client3 Train => Local Epoch: 1 	Acc: 44.943 	Loss: 1.5251
#  Client3 Train => Local Epoch: 2 	Acc: 91.181 	Loss: 0.9502
#  Client3 Train => Local Epoch: 3 	Acc: 91.800 	Loss: 0.6636
#  Client3 Train => Local Epoch: 4 	Acc: 92.085 	Loss: 0.6134
#  Client3 Test  => 	Acc: 17.720 	Loss: 3.8102
#  Client0 Train => Local Epoch: 0 	Acc: 2.424 	Loss: 3.9705
#  Client0 Train => Local Epoch: 1 	Acc: 10.572 	Loss: 2.5976
#  Client0 Train => Local Epoch: 2 	Acc: 32.421 	Loss: 1.6047
#  Client0 Train => Local Epoch: 3 	Acc: 65.885 	Loss: 1.1932
#  Client0 Train => Local Epoch: 4 	Acc: 76.339 	Loss: 0.9680
#  Client0 Test  => 	Acc: 20.387 	Loss: 2.9805
#  Client7 Train => Local Epoch: 0 	Acc: 66.388 	Loss: 1.3708
#  Client7 Train => Local Epoch: 1 	Acc: 94.123 	Loss: 0.4812
#  Client7 Train => Local Epoch: 2 	Acc: 95.005 	Loss: 0.4191
#  Client7 Train => Local Epoch: 3 	Acc: 95.168 	Loss: 0.4054
#  Client7 Train => Local Epoch: 4 	Acc: 95.595 	Loss: 0.3969
#  Client7 Test  => 	Acc: 18.794 	Loss: 4.3577
#  Client8 Train => Local Epoch: 0 	Acc: 35.657 	Loss: 2.1648
