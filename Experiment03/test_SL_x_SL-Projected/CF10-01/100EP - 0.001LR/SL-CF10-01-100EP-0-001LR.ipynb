# %% [markdown]
# # Split learning
# ### ResNet18 on CIFAR-10 + α = 0.1

# %%
#=============================================================================
# Split learning: ResNet18 on CIFAR-10
# This program is Version1: Single program simulation 
# ============================================================================
import torch
from torch import nn
from torchvision import transforms
from torchvision import datasets
from torch.utils.data import DataLoader, Dataset
import torch.nn.functional as F
import math
import os.path
import pandas as pd

from sklearn.model_selection import train_test_split
from PIL import Image
from glob import glob 
from pandas import DataFrame
import random
import numpy as np
import os


import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import copy
import time

def _sync_cuda():
    if torch.cuda.is_available():
        torch.cuda.synchronize()


SEED = 1234
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
if torch.cuda.is_available():
    torch.backends.cudnn.deterministic = True
    print(torch.cuda.get_device_name(0))    

#===================================================================  
program = "SL-CF10-01-100EP-0-001LR"
DATASET_NAME = "CIFAR10"
ALPHA = 0.1   # requested alpha


print(f"---------{program}----------")              # this is to identify the program in the slurm outputs files

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# To print in color -------test/train of the client side
def prRed(skk): print("\033[91m {}\033[00m" .format(skk)) 
def prGreen(skk): print("\033[92m {}\033[00m" .format(skk))     

#===================================================================  
# No. of users
DATA_ROOT = "./data"
NUM_CLIENTS = 10
EPOCHS = 100
frac = 1   # participation of clients; if 1 then 100% clients participate in SL
BASE_LR = 0.001
LOCAL_EPOCHS = 5
NUM_WORKERS = 4
BATCH_SIZE = 256
MOMENTUM = 0.9
WEIGHT_DECAY = 5e-4


CIFAR_MEAN = {
    "CIFAR10": [0.4914, 0.4822, 0.4465],
    "CIFAR100": [0.5071, 0.4867, 0.4408],
}[DATASET_NAME]
CIFAR_STD = {
    "CIFAR10": [0.2470, 0.2435, 0.2616],
    "CIFAR100": [0.2675, 0.2565, 0.2761],
}[DATASET_NAME]

#=====================================================================================================
#                           Client-side Model definition
#=====================================================================================================
# Model at client side
class ResNet18_client_side(nn.Module):
    def __init__(self):
        super(ResNet18_client_side, self).__init__()
        self.layer1 = nn.Sequential (
                nn.Conv2d(3, 64, kernel_size = 7, stride = 2, padding = 3, bias = False),
                nn.BatchNorm2d(64),
                nn.ReLU (inplace = True),
                nn.MaxPool2d(kernel_size = 3, stride = 2, padding =1),
            )
        self.layer2 = nn.Sequential  (
                nn.Conv2d(64, 64, kernel_size = 3, stride = 1, padding = 1, bias = False),
                nn.BatchNorm2d(64),
                nn.ReLU (inplace = True),
                nn.Conv2d(64, 64, kernel_size = 3, stride = 1, padding = 1),
                nn.BatchNorm2d(64),              
            )
        
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                m.weight.data.normal_(0, math.sqrt(2. / n))
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()
        
        
    def forward(self, x):
        resudial1 = F.relu(self.layer1(x))
        out1 = self.layer2(resudial1)
        out1 = out1 + resudial1 # adding the resudial inputs -- downsampling not required in this layer
        resudial2 = F.relu(out1)
        return resudial2
 
 
           

net_glob_client = ResNet18_client_side()
if torch.cuda.device_count() > 1:
    print("We use",torch.cuda.device_count(), "GPUs")
    net_glob_client = nn.DataParallel(net_glob_client)   # to use the multiple GPUs; later we can change this to CPUs only 

net_glob_client.to(device)
print(net_glob_client)     


#=====================================================================================================
#                           Server-side Model definition
#=====================================================================================================
# Model at server side
class Baseblock(nn.Module):
    expansion = 1
    def __init__(self, input_planes, planes, stride = 1, dim_change = None):
        super(Baseblock, self).__init__()
        self.conv1 = nn.Conv2d(input_planes, planes, stride =  stride, kernel_size = 3, padding = 1)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, stride = 1, kernel_size = 3, padding = 1)
        self.bn2 = nn.BatchNorm2d(planes)
        self.dim_change = dim_change
        
    def forward(self, x):
        res = x
        output = F.relu(self.bn1(self.conv1(x)))
        output = self.bn2(self.conv2(output))
        
        if self.dim_change is not None:
            res =self.dim_change(res)
            
        output += res
        output = F.relu(output)
        
        return output


class ResNet18_server_side(nn.Module):
    def __init__(self, block, num_layers, classes):
        super(ResNet18_server_side, self).__init__()
        self.input_planes = 64
        self.layer3 = nn.Sequential (
                nn.Conv2d(64, 64, kernel_size = 3, stride = 1, padding = 1),
                nn.BatchNorm2d(64),
                nn.ReLU (inplace = True),
                nn.Conv2d(64, 64, kernel_size = 3, stride = 1, padding = 1),
                nn.BatchNorm2d(64),       
                )   
        
        self.layer4 = self._layer(block, 128, num_layers[0], stride = 2)
        self.layer5 = self._layer(block, 256, num_layers[1], stride = 2)
        self.layer6 = self._layer(block, 512, num_layers[2], stride = 2)
        self. averagePool = nn.AvgPool2d(kernel_size = 7, stride = 1)
        self.fc = nn.Linear(512 * block.expansion, classes)
        
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                m.weight.data.normal_(0, math.sqrt(2. / n))
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()
        
        
    def _layer(self, block, planes, num_layers, stride = 2):
        dim_change = None
        if stride != 1 or planes != self.input_planes * block.expansion:
            dim_change = nn.Sequential(nn.Conv2d(self.input_planes, planes*block.expansion, kernel_size = 1, stride = stride),
                                       nn.BatchNorm2d(planes*block.expansion))
        netLayers = []
        netLayers.append(block(self.input_planes, planes, stride = stride, dim_change = dim_change))
        self.input_planes = planes * block.expansion
        for i in range(1, num_layers):
            netLayers.append(block(self.input_planes, planes))
            self.input_planes = planes * block.expansion
            
        return nn.Sequential(*netLayers)
        
    
    def forward(self, x):
        out2 = self.layer3(x)
        out2 = out2 + x          # adding the resudial inputs -- downsampling not required in this layer
        x3 = F.relu(out2)
        
        x4 = self. layer4(x3)
        x5 = self.layer5(x4)
        x6 = self.layer6(x5)
        
        # x7 = F.avg_pool2d(x6, 7)
        x7 = F.adaptive_avg_pool2d(x6, 1) 
        x8 = x7.view(x7.size(0), -1) 
        y_hat =self.fc(x8)
        
        return y_hat

# net_glob_server = ResNet18_server_side(Baseblock, [2,2,2], 7) #7 is my numbr of classes
if DATASET_NAME == "CIFAR10":
    net_glob_server = ResNet18_server_side(Baseblock, [2,2,2], 10)  # 10 classes for CIFAR-10
else:
    net_glob_server = ResNet18_server_side(Baseblock, [2,2,2], 100)


if torch.cuda.device_count() > 1:
    print("We use",torch.cuda.device_count(), "GPUs")
    net_glob_server = nn.DataParallel(net_glob_server)   # to use the multiple GPUs 

net_glob_server.to(device)
print(net_glob_server)      

#===================================================================================
# For Server Side Loss and Accuracy 
loss_train_collect = []
acc_train_collect = []
loss_test_collect = []
acc_test_collect = []
batch_acc_train = []
batch_loss_train = []
batch_acc_test = []
batch_loss_test = []
round_time_collect = [] # Stores seconds per global round

criterion = nn.CrossEntropyLoss()
count1 = 0
count2 = 0

#====================================================================================================
#                                  Server Side Program
#====================================================================================================
def calculate_accuracy(fx, y):
    preds = fx.max(1, keepdim=True)[1]
    correct = preds.eq(y.view_as(preds)).sum()
    acc = 100.00 *correct.float()/preds.shape[0]
    return acc

# to print train - test together in each round-- these are made global
acc_avg_all_user_train = 0
loss_avg_all_user_train = 0
loss_train_collect_user = []
acc_train_collect_user = []
loss_test_collect_user = []
acc_test_collect_user = []


#client idx collector
idx_collect = []
l_epoch_check = False
fed_check = False


optimizer_server = torch.optim.SGD(net_glob_server.parameters(), lr = BASE_LR, momentum=MOMENTUM, weight_decay=WEIGHT_DECAY)

# Server-side function associated with Training 
def train_server(fx_client, y, l_epoch_count, l_epoch, idx, len_batch):
    global optimizer_server
    global net_glob_server, criterion, device, batch_acc_train, batch_loss_train, l_epoch_check, fed_check
    global loss_train_collect, acc_train_collect, count1, acc_avg_all_user_train, loss_avg_all_user_train, idx_collect
    global loss_train_collect_user, acc_train_collect_user
    
    net_glob_server.train()
    
    # Clear gradient
    optimizer_server.zero_grad() 
    
    fx_client = fx_client.to(device)
    y = y.to(device)
    
    #---------forward prop-------------
    fx_server = net_glob_server(fx_client)
    
    # calculate loss
    loss = criterion(fx_server, y)
    # calculate accuracy
    acc = calculate_accuracy(fx_server, y)
    
    #--------backward prop--------------
    loss.backward()
    dfx_client = fx_client.grad.clone().detach()
    optimizer_server.step()
    
    batch_loss_train.append(loss.item())
    batch_acc_train.append(acc.item())
    
    # server-side model net_glob_server is global so it is updated automatically in each pass to this function
        # count1: to track the completion of the local batch associated with one client
    count1 += 1
    if count1 == len_batch:
        acc_avg_train = sum(batch_acc_train)/len(batch_acc_train)           # it has accuracy for one batch
        loss_avg_train = sum(batch_loss_train)/len(batch_loss_train)
        
        batch_acc_train = []
        batch_loss_train = []
        count1 = 0
        
        prRed('Client{} Train => Local Epoch: {} \tAcc: {:.3f} \tLoss: {:.4f}'.format(idx, l_epoch_count, acc_avg_train, loss_avg_train))
        
                
        # If one local epoch is completed, after this a new client will come
        if l_epoch_count == l_epoch-1:
            
            l_epoch_check = True                # for evaluate_server function - to check local epoch has hitted 
                       
            # we store the last accuracy in the last batch of the epoch and it is not the average of all local epochs
            # this is because we work on the last trained model and its accuracy (not earlier cases)
            
            #print("accuracy = ", acc_avg_train)
            acc_avg_train_all = acc_avg_train
            loss_avg_train_all = loss_avg_train
                        
            # accumulate accuracy and loss for each new user
            loss_train_collect_user.append(loss_avg_train_all)
            acc_train_collect_user.append(acc_avg_train_all)
            
            # collect the id of each new user                        
            if idx not in idx_collect:
                idx_collect.append(idx) 
                #print(idx_collect)
        
        # This is to check if all users are served for one round --------------------
        if len(idx_collect) == NUM_CLIENTS:
            fed_check = True                                                  # for evaluate_server function  - to check fed check has hitted
            # all users served for one round ------------------------- output print and update is done in evaluate_server()
            # for nicer display 
                        
            idx_collect = []
            
            acc_avg_all_user_train = sum(acc_train_collect_user)/len(acc_train_collect_user)
            loss_avg_all_user_train = sum(loss_train_collect_user)/len(loss_train_collect_user)
            
            loss_train_collect.append(loss_avg_all_user_train)
            acc_train_collect.append(acc_avg_all_user_train)
            
            acc_train_collect_user = []
            loss_train_collect_user = []
            
    # send gradients to the client               
    return dfx_client

# Server-side functions associated with Testing
def evaluate_server(fx_client, y, idx, len_batch, ell):
    global net_glob_server, criterion, batch_acc_test, batch_loss_test
    global loss_test_collect, acc_test_collect, count2, num_users, acc_avg_train_all, loss_avg_train_all, l_epoch_check, fed_check
    global loss_test_collect_user, acc_test_collect_user, acc_avg_all_user_train, loss_avg_all_user_train
    
    net_glob_server.eval()
  
    with torch.no_grad():
        fx_client = fx_client.to(device)
        y = y.to(device) 
        #---------forward prop-------------
        fx_server = net_glob_server(fx_client)
        
        # calculate loss
        loss = criterion(fx_server, y)
        # calculate accuracy
        acc = calculate_accuracy(fx_server, y)
        
        
        batch_loss_test.append(loss.item())
        batch_acc_test.append(acc.item())
        
               
        count2 += 1
        if count2 == len_batch:
            acc_avg_test = sum(batch_acc_test)/len(batch_acc_test)
            loss_avg_test = sum(batch_loss_test)/len(batch_loss_test)
            
            batch_acc_test = []
            batch_loss_test = []
            count2 = 0
            
            prGreen('Client{} Test =>                   \tAcc: {:.3f} \tLoss: {:.4f}'.format(idx, acc_avg_test, loss_avg_test))
            
            # if a local epoch is completed   
            if l_epoch_check:
                l_epoch_check = False
                
                # Store the last accuracy and loss
                acc_avg_test_all = acc_avg_test
                loss_avg_test_all = loss_avg_test
                        
                loss_test_collect_user.append(loss_avg_test_all)
                acc_test_collect_user.append(acc_avg_test_all)
                
            # if all users are served for one round ----------                    
            if fed_check:
                fed_check = False
                                
                acc_avg_all_user = sum(acc_test_collect_user)/len(acc_test_collect_user)
                loss_avg_all_user = sum(loss_test_collect_user)/len(loss_test_collect_user)
            
                loss_test_collect.append(loss_avg_all_user)
                acc_test_collect.append(acc_avg_all_user)
                acc_test_collect_user = []
                loss_test_collect_user= []
                              
                print("====================== SERVER V1==========================")
                print(' Train: Round {:3d}, Avg Accuracy {:.3f} | Avg Loss {:.3f}'.format(ell, acc_avg_all_user_train, loss_avg_all_user_train))
                print(' Test: Round {:3d}, Avg Accuracy {:.3f} | Avg Loss {:.3f}'.format(ell, acc_avg_all_user, loss_avg_all_user))
                # print("==========================================================")
         
    return 

#==============================================================================================================
#                                       Clients Side Program
#==============================================================================================================
class DatasetSplit(Dataset):
    def __init__(self, dataset, idxs):
        self.dataset = dataset
        self.idxs = list(idxs)

    def __len__(self):
        return len(self.idxs)

    def __getitem__(self, item):
        image, label = self.dataset[self.idxs[item]]
        return image, label

# Client-side functions associated with Training and Testing
class Client(object):
    def __init__(self, net_client_model, idx, lr, device, dataset_train = None, dataset_test = None, idxs = None, idxs_test = None):
        self.idx = idx
        self.device = device
        self.lr = lr
        self.local_ep = LOCAL_EPOCHS 
        #self.selected_clients = []
        self.ldr_train = DataLoader(DatasetSplit(dataset_train, idxs), batch_size = BATCH_SIZE, shuffle = True, num_workers=NUM_WORKERS)
        self.ldr_test = DataLoader(DatasetSplit(dataset_test, idxs_test), batch_size = BATCH_SIZE, shuffle = False, num_workers=NUM_WORKERS)
        

    def train(self, net):
        net.train()
        optimizer_client = torch.optim.SGD(net.parameters(), lr = self.lr, momentum=MOMENTUM, weight_decay=WEIGHT_DECAY) 
        
        for iter in range(self.local_ep):
            len_batch = len(self.ldr_train)
            for batch_idx, (images, labels) in enumerate(self.ldr_train):
                images, labels = images.to(self.device), labels.to(self.device)
                optimizer_client.zero_grad()
                #---------forward prop-------------
                fx = net(images)
                client_fx = fx.clone().detach().requires_grad_(True)
                
                # Sending activations to server and receiving gradients from server
                dfx = train_server(client_fx, labels, iter, self.local_ep, self.idx, len_batch)
                
                #--------backward prop -------------
                fx.backward(dfx)
                optimizer_client.step()
                            
            
            #prRed('Client{} Train => Epoch: {}'.format(self.idx, ell))
           
        return net.state_dict() 
    
    def evaluate(self, net, ell):
        net.eval()
           
        with torch.no_grad():
            len_batch = len(self.ldr_test)
            for batch_idx, (images, labels) in enumerate(self.ldr_test):
                images, labels = images.to(self.device), labels.to(self.device)
                #---------forward prop-------------
                fx = net(images)
                
                # Sending activations to server 
                evaluate_server(fx, labels, self.idx, len_batch, ell)
            
            #prRed('Client{} Test => Epoch: {}'.format(self.idx, ell))
            
        return          
#=====================================================================================================
# dataset_iid() will create a dictionary to collect the indices of the data samples randomly for each client
# IID HAM10000 datasets will be created based on this
def dataset_iid(dataset, num_users):
    
    num_items = int(len(dataset)/num_users)
    dict_users, all_idxs = {}, [i for i in range(len(dataset))]
    for i in range(num_users):
        dict_users[i] = set(np.random.choice(all_idxs, num_items, replace = False))
        all_idxs = list(set(all_idxs) - dict_users[i])
    return dict_users    

def dataset_noniid_dirichlet(dataset, num_users, alpha=ALPHA, seed=SEED):
    """Return dict_users: {client_id -> set(sample_indices)} using Dirichlet(α)."""
    rng = np.random.default_rng(seed)
    labels = np.array(dataset.targets)  # CIFAR-10 stores labels here
    n_classes = len(np.unique(labels))
    dict_users = {i: set() for i in range(num_users)}

    for c in range(n_classes):
        idxs = np.where(labels == c)[0]
        rng.shuffle(idxs)
        
        # draw proportions for this class
        p = rng.dirichlet([alpha] * num_users)
        
        # split indices by cumulative proportions
        cuts = (np.cumsum(p) * len(idxs)).astype(int)[:-1]
        
        splits = np.split(idxs, cuts)
        for client_id, split in enumerate(splits):
            dict_users[client_id].update(split.tolist())
    return dict_users




#=============================================================================
#                         Data loading 
#============================================================================= 

# CIFAR-10 normalization

train_transforms = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(32, padding=4),
    transforms.ToTensor(),
    transforms.Normalize(mean=CIFAR_MEAN, std=CIFAR_STD),
])

test_transforms = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=CIFAR_MEAN, std=CIFAR_STD),
])

if DATASET_NAME == "CIFAR10":
    dataset_train = datasets.CIFAR10(
        root=DATA_ROOT, train=True, download=True, transform=train_transforms
    )
    dataset_test = datasets.CIFAR10(
        root=DATA_ROOT, train=False, download=True, transform=test_transforms
    )
    NUM_CLASSES = 10
else:
    dataset_train = datasets.CIFAR100(
        root=DATA_ROOT, train=True, download=True, transform=train_transforms
    )
    dataset_test = datasets.CIFAR100(
        root=DATA_ROOT, train=False, download=True, transform=test_transforms
    )
    NUM_CLASSES = 100



#=============================================================================
#                         Forgetting metric setup 
#============================================================================= 

from collections import defaultdict

# Treat each global round as a window (quick baseline).
# If you want true distribution shifts, predefine your own windows and fill `val_loaders`.
T = EPOCHS

val_loaders = {}
# Deterministic, disjoint slices of the test set: window t gets items t, t+T, t+2T, ...
rng_idx = np.arange(len(dataset_test))
for t in range(T):
    idxs = rng_idx[t::T]
    val_loaders[t] = DataLoader(DatasetSplit(dataset_test, idxs),
                                batch_size=BATCH_SIZE, shuffle=False, num_workers=NUM_WORKERS,drop_last=False)

best_loss_per_window = defaultdict(lambda: float('inf'))  # stores min historical loss per window
forgetting_log = []  # per round dicts: {"round": t, "mean_forgetting": x, "per_window": {...}}
# ============================================================================

def _eval_loss_on_loader(model_client, model_server, loader, device, criterion):
    """Evaluate mean loss on a loader using split models."""
    # Handle DataParallel transparently
    mc = model_client.module if isinstance(model_client, nn.DataParallel) else model_client
    ms = model_server.module if isinstance(model_server, nn.DataParallel) else model_server
    mc.eval(); ms.eval()
    loss_sum, n = 0.0, 0
    with torch.no_grad():
        for images, labels in loader:
            images, labels = images.to(device), labels.to(device)
            fx = mc(images)
            logits = ms(fx)
            loss = criterion(logits, labels)
            bs = labels.size(0)
            loss_sum += loss.item() * bs
            n += bs
    return loss_sum / max(1, n)

#----------------------------------------------------------------
# dict_users = dataset_iid(dataset_train, num_users)
# dict_users_test = dataset_iid(dataset_test, num_users)

dict_users      = dataset_noniid_dirichlet(dataset_train, num_users=NUM_CLIENTS, alpha=ALPHA)
dict_users_test = dataset_iid(dataset_test, num_users=NUM_CLIENTS)  



#net_glob_client.train()
# this epoch is global epoch, also known as rounds
# this epoch is global epoch, also known as rounds
for iter in range(EPOCHS):
    # ---- START TIMER ----
    _sync_cuda()
    t0 = time.perf_counter()
    # ---------------------

    m = max(int(frac * NUM_CLIENTS), 1)
    idxs_users = np.random.choice(range(NUM_CLIENTS), m, replace=False)

    # Sequential training/testing among clients
    for idx in idxs_users:
        local = Client(net_glob_client, idx, BASE_LR, device,
                       dataset_train=dataset_train, dataset_test=dataset_test,
                       idxs=dict_users[idx], idxs_test=dict_users_test[idx])

        # Training
        w_client = local.train(net=copy.deepcopy(net_glob_client).to(device))

        # Testing
        local.evaluate(net=copy.deepcopy(net_glob_client).to(device), ell=iter)

        # Update client weights for next client
         # copy weight to net_glob_client -- use to update the client-side model of the next client to be trained
        net_glob_client.load_state_dict(w_client)

    # ---- STOP TIMER & LOG ----
    _sync_cuda()
    dt = time.perf_counter() - t0
    
    # === Forgetting update at end of round `iter` ================================
    t = iter  # current window id

    # 1) Update the "best so far" for the CURRENT window using the current model
    L_cur_t = _eval_loss_on_loader(net_glob_client, net_glob_server, val_loaders[t], device, criterion)
    if math.isfinite(L_cur_t):
        best_loss_per_window[t] = min(best_loss_per_window[t], L_cur_t)

    # 2) Compute forgetting on all PAST windows t0 < t
    per_win_fgt = {}
    for t0 in range(t):
        L_now = _eval_loss_on_loader(net_glob_client, net_glob_server, val_loaders[t0], device, criterion)
        best = best_loss_per_window[t0]
        if not (math.isfinite(L_now) and math.isfinite(best)):
            continue
        Fgt = L_now - best
        per_win_fgt[t0] = Fgt
        
    mean_fgt = float(np.mean(list(per_win_fgt.values()))) if per_win_fgt else 0.0
    forgetting_log.append({"round": t, "mean_forgetting": mean_fgt, "per_window": per_win_fgt})
    print(f"Forgetting : Round {t}, mean_forgetting : {mean_fgt:.3f}")
    print("==========================================================")
    # =============================================================================
    
    round_time_collect.append(dt)
    # -------------------------- 
    



print("Training and Evaluation completed!")    

#===============================================================================
# Save output data to .excel file (we use for comparision plots)
# Align lengths safely (in case of early stop or mismatch)
n = min(len(acc_train_collect), len(acc_test_collect), len(round_time_collect), len(forgetting_log))
round_process = list(range(1, n+1))
mean_fgt_series = [d["mean_forgetting"] for d in forgetting_log[:n]]

df = DataFrame({
    'round': round_process,
    'acc_train': acc_train_collect[:n],
    'acc_test':  acc_test_collect[:n],
    'round_time_sec': round_time_collect[:n],   # time
    'mean_FgT_loss': mean_fgt_series, 
})

# write CSV — easier for scripting/comparison tools
file_name_csv = program + ".csv"
df.to_csv(file_name_csv, index=False)

print("Saved:", file_name_csv)

#=============================================================================
#                         Program Completed
#=============================================================================
# Out:
# NVIDIA H200
# ---------SL - CIFAR-10 α=0.1----------
# ResNet18_client_side(
#   (layer1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (layer2): Sequential(
#     (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# ResNet18_server_side(
#   (layer3): Sequential(
#     (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (layer4): Sequential(
#     (0): Baseblock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dim_change): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2))
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Baseblock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer5): Sequential(
#     (0): Baseblock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dim_change): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2))
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Baseblock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer6): Sequential(
#     (0): Baseblock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dim_change): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2))
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Baseblock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (averagePool): AvgPool2d(kernel_size=7, stride=1, padding=0)
#   (fc): Linear(in_features=512, out_features=10, bias=True)
# )
#  Client3 Train => Local Epoch: 0 	Acc: 80.598 	Loss: 1.1999
#  Client3 Train => Local Epoch: 1 	Acc: 88.293 	Loss: 0.8641
#  Client3 Train => Local Epoch: 2 	Acc: 89.803 	Loss: 0.5544
#  Client3 Train => Local Epoch: 3 	Acc: 89.706 	Loss: 0.4612
#  Client3 Train => Local Epoch: 4 	Acc: 89.906 	Loss: 0.4405
#  Client3 Test =>                   	Acc: 9.510 	Loss: 4.5433
#  Client1 Train => Local Epoch: 0 	Acc: 78.136 	Loss: 0.7147
#  Client1 Train => Local Epoch: 1 	Acc: 88.206 	Loss: 0.3208
#  Client1 Train => Local Epoch: 2 	Acc: 90.352 	Loss: 0.2630
#  Client1 Train => Local Epoch: 3 	Acc: 91.800 	Loss: 0.2200
#  Client1 Train => Local Epoch: 4 	Acc: 92.467 	Loss: 0.2056
#  Client1 Test =>                   	Acc: 16.773 	Loss: 15.9949
#  Client2 Train => Local Epoch: 0 	Acc: 69.596 	Loss: 3.3325
#  Client2 Train => Local Epoch: 1 	Acc: 87.331 	Loss: 0.5754
#  Client2 Train => Local Epoch: 2 	Acc: 89.876 	Loss: 0.4323
#  Client2 Train => Local Epoch: 3 	Acc: 90.634 	Loss: 0.3908
#  Client2 Train => Local Epoch: 4 	Acc: 91.408 	Loss: 0.3642
#  Client2 Test =>                   	Acc: 15.430 	Loss: 5.1016
#  Client0 Train => Local Epoch: 0 	Acc: 2.149 	Loss: 8.0736
#  Client0 Train => Local Epoch: 1 	Acc: 1.876 	Loss: 3.7128
#  Client0 Train => Local Epoch: 2 	Acc: 23.178 	Loss: 2.2916
#  Client0 Train => Local Epoch: 3 	Acc: 40.445 	Loss: 2.0650
#  Client0 Train => Local Epoch: 4 	Acc: 51.935 	Loss: 1.7444
#  Client0 Test =>                   	Acc: 11.375 	Loss: 2.5461
#  Client8 Train => Local Epoch: 0 	Acc: 50.186 	Loss: 2.3726
#  Client8 Train => Local Epoch: 1 	Acc: 71.285 	Loss: 1.0268
#  Client8 Train => Local Epoch: 2 	Acc: 74.954 	Loss: 0.7792
#  Client8 Train => Local Epoch: 3 	Acc: 77.236 	Loss: 0.7018
#  Client8 Train => Local Epoch: 4 	Acc: 78.665 	Loss: 0.6532
#  Client8 Test =>                   	Acc: 14.123 	Loss: 3.9582
#  Client7 Train => Local Epoch: 0 	Acc: 48.778 	Loss: 1.7964
#  Client7 Train => Local Epoch: 1 	Acc: 85.173 	Loss: 0.3454
#  Client7 Train => Local Epoch: 2 	Acc: 88.388 	Loss: 0.2826
#  Client7 Train => Local Epoch: 3 	Acc: 90.633 	Loss: 0.2386
#  Client7 Train => Local Epoch: 4 	Acc: 91.561 	Loss: 0.2243
#  Client7 Test =>                   	Acc: 16.898 	Loss: 7.0446
#  Client6 Train => Local Epoch: 0 	Acc: 24.144 	Loss: 2.8050
#  Client6 Train => Local Epoch: 1 	Acc: 68.428 	Loss: 0.9179
#  Client6 Train => Local Epoch: 2 	Acc: 75.440 	Loss: 0.7024
#  Client6 Train => Local Epoch: 3 	Acc: 79.110 	Loss: 0.6161
#  Client6 Train => Local Epoch: 4 	Acc: 81.430 	Loss: 0.5503
#  Client6 Test =>                   	Acc: 20.659 	Loss: 5.2488
#  Client7 Test =>                   	Acc: 17.592 	Loss: 6.5835
# ====================== SERVER V1==========================
#  Train: Round   1, Avg Accuracy 82.530 | Avg Loss 0.531
#  Test: Round   1, Avg Accuracy 19.131 | Avg Loss 5.010
# Forgetting : Round 1, mean_forgetting : 4.027
# ==========================================================
#  Client0 Train => Local Epoch: 0 	Acc: 25.754 	Loss: 6.8060
#  Client0 Train => Local Epoch: 1 	Acc: 32.652 	Loss: 3.0495
#  Client0 Train => Local Epoch: 2 	Acc: 54.676 	Loss: 1.5312
#  Client0 Train => Local Epoch: 3 	Acc: 76.065 	Loss: 1.1034
#  Client0 Train => Local Epoch: 4 	Acc: 77.766 	Loss: 0.8328
#  Client0 Test =>                   	Acc: 18.737 	Loss: 4.4315
#  Client2 Train => Local Epoch: 0 	Acc: 47.798 	Loss: 2.1145
#  Client2 Train => Local Epoch: 1 	Acc: 89.429 	Loss: 0.4929
#  Client2 Train => Local Epoch: 2 	Acc: 90.681 	Loss: 0.3757
#  Client2 Train => Local Epoch: 3 	Acc: 91.400 	Loss: 0.3438
#  Client2 Train => Local Epoch: 4 	Acc: 90.989 	Loss: 0.3327
#  Client2 Test =>                   	Acc: 14.824 	Loss: 4.4699
#  Client5 Train => Local Epoch: 0 	Acc: 29.962 	Loss: 2.4371
#  Client5 Train => Local Epoch: 1 	Acc: 58.694 	Loss: 1.3376
#  Client5 Train => Local Epoch: 2 	Acc: 61.973 	Loss: 1.0557
#  Client5 Train => Local Epoch: 3 	Acc: 64.417 	Loss: 0.9363
#  Client5 Train => Local Epoch: 4 	Acc: 66.191 	Loss: 0.8802
#  Client5 Test =>                   	Acc: 23.360 	Loss: 3.5836
#  Client7 Train => Local Epoch: 0 	Acc: 61.179 	Loss: 1.5137
#  Client7 Train => Local Epoch: 1 	Acc: 90.747 	Loss: 0.2720
#  Client7 Train => Local Epoch: 2 	Acc: 92.155 	Loss: 0.2214
#  Client7 Train => Local Epoch: 3 	Acc: 92.388 	Loss: 0.2005
#  Client7 Train => Local Epoch: 4 	Acc: 93.345 	Loss: 0.1882
#  Client7 Test =>                   	Acc: 17.309 	Loss: 6.5373
#  Client1 Train => Local Epoch: 0 	Acc: 26.518 	Loss: 3.2048
#  Client1 Train => Local Epoch: 1 	Acc: 84.819 	Loss: 0.4323
#  Client1 Train => Local Epoch: 2 	Acc: 90.390 	Loss: 0.2613
#  Client1 Train => Local Epoch: 3 	Acc: 92.769 	Loss: 0.2048
#  Client1 Train => Local Epoch: 4 	Acc: 93.007 	Loss: 0.1968
#  Client1 Test =>                   	Acc: 15.746 	Loss: 7.4653
#  Client8 Train => Local Epoch: 0 	Acc: 48.623 	Loss: 2.0847
#  Client8 Train => Local Epoch: 1 	Acc: 79.376 	Loss: 0.7491
#  Client8 Train => Local Epoch: 2 	Acc: 80.422 	Loss: 0.6381
#  Client8 Train => Local Epoch: 3 	Acc: 81.117 	Loss: 0.5822
#  Client8 Train => Local Epoch: 4 	Acc: 81.891 	Loss: 0.5473
#  Client8 Test =>                   	Acc: 22.117 	Loss: 4.2886
#  Client2 Test =>                   	Acc: 16.123 	Loss: 4.1146
#  Client6 Train => Local Epoch: 0 	Acc: 50.984 	Loss: 1.8624
#  Client6 Train => Local Epoch: 1 	Acc: 81.065 	Loss: 0.6664
#  Client6 Train => Local Epoch: 2 	Acc: 83.556 	Loss: 0.5179
#  Client6 Train => Local Epoch: 3 	Acc: 85.430 	Loss: 0.4510
#  Client6 Train => Local Epoch: 4 	Acc: 87.017 	Loss: 0.4158
#  Client6 Test =>                   	Acc: 23.875 	Loss: 4.0391
# ====================== SERVER V1==========================
#  Train: Round   3, Avg Accuracy 83.194 | Avg Loss 0.517
#  Test: Round   3, Avg Accuracy 19.341 | Avg Loss 4.814
# Forgetting : Round 3, mean_forgetting : -0.850
# ==========================================================
#  Client2 Train => Local Epoch: 0 	Acc: 35.976 	Loss: 2.5569
#  Client2 Train => Local Epoch: 1 	Acc: 88.931 	Loss: 0.5165
#  Client2 Train => Local Epoch: 2 	Acc: 91.573 	Loss: 0.3696
#  Client2 Train => Local Epoch: 3 	Acc: 91.674 	Loss: 0.3358
#  Client2 Train => Local Epoch: 4 	Acc: 92.439 	Loss: 0.3111
#  Client2 Test =>                   	Acc: 20.094 	Loss: 4.2689
#  Client8 Train => Local Epoch: 0 	Acc: 44.588 	Loss: 2.1946
#  Client8 Train => Local Epoch: 1 	Acc: 81.084 	Loss: 0.6923
#  Client8 Train => Local Epoch: 2 	Acc: 82.172 	Loss: 0.5841
#  Client8 Train => Local Epoch: 3 	Acc: 82.298 	Loss: 0.5326
#  Client8 Train => Local Epoch: 4 	Acc: 83.428 	Loss: 0.4944
#  Client8 Test =>                   	Acc: 19.548 	Loss: 4.3733
#  Client5 Train => Local Epoch: 0 	Acc: 34.525 	Loss: 2.4981
#  Client5 Train => Local Epoch: 1 	Acc: 63.554 	Loss: 1.1113
#  Client5 Train => Local Epoch: 2 	Acc: 66.063 	Loss: 0.9333
#  Client5 Train => Local Epoch: 3 	Acc: 68.131 	Loss: 0.8491
#  Client5 Train => Local Epoch: 4 	Acc: 70.031 	Loss: 0.7998
#  Client5 Test =>                   	Acc: 27.553 	Loss: 3.6031
#  Client0 Train => Local Epoch: 0 	Acc: 32.143 	Loss: 3.1163
#  Client0 Train => Local Epoch: 1 	Acc: 39.371 	Loss: 2.0772
#  Client0 Train => Local Epoch: 2 	Acc: 47.896 	Loss: 1.5916
#  Client0 Train => Local Epoch: 3 	Acc: 76.259 	Loss: 1.2515
#  Client0 Train => Local Epoch: 4 	Acc: 78.233 	Loss: 0.9796
#  Client0 Test =>                   	Acc: 19.107 	Loss: 3.6281
#  Client6 Train => Local Epoch: 0 	Acc: 52.455 	Loss: 1.4551
#  Client6 Train => Local Epoch: 1 	Acc: 82.545 	Loss: 0.5741
#  Client6 Train => Local Epoch: 2 	Acc: 85.957 	Loss: 0.4529
#  Client6 Train => Local Epoch: 3 	Acc: 87.625 	Loss: 0.4006
#  Client6 Train => Local Epoch: 4 	Acc: 88.153 	Loss: 0.3713
#  Client6 Test =>                   	Acc: 24.451 	Loss: 4.5090
#  Client4 Train => Local Epoch: 0 	Acc: 21.330 	Loss: 3.1359
#  Client4 Train => Local Epoch: 1 	Acc: 70.450 	Loss: 1.4156
#  Client4 Train => Local Epoch: 2 	Acc: 70.399 	Loss: 1.1435
#  Client4 Train => Local Epoch: 3 	Acc: 70.691 	Loss: 1.0397
#  Client4 Train => Local Epoch: 4 	Acc: 70.548 	Loss: 0.9586
#  Client4 Test =>                   	Acc: 11.443 	Loss: 2.8095
#  Client3 Train => Local Epoch: 0 	Acc: 2.454 	Loss: 3.2259
#  Client3 Train => Local Epoch: 1 	Acc: 36.740 	Loss: 1.5941
#  Client3 Train => Local Epoch: 2 	Acc: 89.986 	Loss: 0.7220
#  Client3 Train => Local Epoch: 3 	Acc: 90.109 	Loss: 0.5343
#  Client3 Train => Local Epoch: 4 	Acc: 90.047 	Loss: 0.5192
#  Client3 Test =>                   	Acc: 9.510 	Loss: 4.9331
#  Client7 Train => Local Epoch: 0 	Acc: 28.999 	Loss: 2.5602
#  Client7 Train => Local Epoch: 1 	Acc: 87.306 	Loss: 0.3556
#  Client7 Train => Local Epoch: 2 	Acc: 90.772 	Loss: 0.2435
#  Client7 Train => Local Epoch: 3 	Acc: 91.990 	Loss: 0.2165
#  Client7 Train => Local Epoch: 4 	Acc: 92.598 	Loss: 0.2029
#  Client7 Test =>                   	Acc: 15.285 	Loss: 6.2649
#  Client9 Train => Local Epoch: 0 	Acc: 30.307 	Loss: 2.7674
#  Client9 Train => Local Epoch: 1 	Acc: 60.991 	Loss: 1.2887
#  Client9 Train => Local Epoch: 2 	Acc: 61.902 	Loss: 1.1024
#  Client9 Train => Local Epoch: 3 	Acc: 64.664 	Loss: 1.0021
#  Client9 Train => Local Epoch: 4 	Acc: 66.890 	Loss: 0.9289
#  Client9 Test =>                   	Acc: 15.453 	Loss: 5.3391
#  Client1 Train => Local Epoch: 0 	Acc: 13.564 	Loss: 2.9548
#  Client1 Train => Local Epoch: 1 	Acc: 88.911 	Loss: 0.6128
#  Client1 Train => Local Epoch: 2 	Acc: 93.771 	Loss: 0.2017
#  Client1 Train => Local Epoch: 3 	Acc: 93.476 	Loss: 0.1890
#  Client1 Train => Local Epoch: 4 	Acc: 93.887 	Loss: 0.1745
#  Client1 Test =>                   	Acc: 17.272 	Loss: 5.6514
# ====================== SERVER V1==========================
#  Train: Round   4, Avg Accuracy 82.625 | Avg Loss 0.574
#  Test: Round   4, Avg Accuracy 17.971 | Avg Loss 4.538
# Forgetting : Round 4, mean_forgetting : 0.581
# ==========================================================
#  Client7 Train => Local Epoch: 0 	Acc: 25.192 	Loss: 2.8017
#  Client7 Train => Local Epoch: 1 	Acc: 78.780 	Loss: 0.5571
#  Client7 Train => Local Epoch: 2 	Acc: 90.130 	Loss: 0.2567
#  Client7 Train => Local Epoch: 3 	Acc: 92.008 	Loss: 0.2103
#  Client7 Train => Local Epoch: 4 	Acc: 92.872 	Loss: 0.1902
#  Client7 Test =>                   	Acc: 17.416 	Loss: 6.1734
#  Client2 Train => Local Epoch: 0 	Acc: 24.843 	Loss: 3.3564
#  Client2 Train => Local Epoch: 1 	Acc: 85.970 	Loss: 0.6969
#  Client2 Train => Local Epoch: 2 	Acc: 86.612 	Loss: 0.5195
#  Client2 Train => Local Epoch: 3 	Acc: 90.816 	Loss: 0.4000
#  Client2 Train => Local Epoch: 4 	Acc: 91.751 	Loss: 0.3589
#  Client2 Test =>                   	Acc: 17.922 	Loss: 3.8269
#  Client6 Train => Local Epoch: 0 	Acc: 12.775 	Loss: 2.8861
#  Client6 Train => Local Epoch: 1 	Acc: 79.322 	Loss: 1.0339
#  Client6 Train => Local Epoch: 2 	Acc: 81.113 	Loss: 0.6575
#  Client6 Train => Local Epoch: 3 	Acc: 82.258 	Loss: 0.5397
#  Client6 Train => Local Epoch: 4 	Acc: 85.343 	Loss: 0.4537
#  Client6 Test =>                   	Acc: 19.760 	Loss: 4.2689
#  Client3 Train => Local Epoch: 0 	Acc: 50.051 	Loss: 1.7923
#  Client3 Train => Local Epoch: 1 	Acc: 89.711 	Loss: 0.5910
#  Client3 Train => Local Epoch: 2 	Acc: 90.353 	Loss: 0.4849
#  Client3 Train => Local Epoch: 3 	Acc: 90.590 	Loss: 0.4623
#  Client3 Train => Local Epoch: 4 	Acc: 91.445 	Loss: 0.4398
#  Client3 Test =>                   	Acc: 12.843 	Loss: 4.1335
#  Client8 Train => Local Epoch: 0 	Acc: 51.984 	Loss: 1.8078
#  Client8 Train => Local Epoch: 1 	Acc: 81.902 	Loss: 0.6441
#  Client8 Train => Local Epoch: 2 	Acc: 82.940 	Loss: 0.5436
#  Client8 Train => Local Epoch: 3 	Acc: 83.090 	Loss: 0.5067
#  Client8 Train => Local Epoch: 4 	Acc: 83.897 	Loss: 0.4731
#  Client8 Test =>                   	Acc: 21.824 	Loss: 4.2286
#  Client9 Train => Local Epoch: 0 	Acc: 28.840 	Loss: 2.4474
#  Client9 Train => Local Epoch: 1 	Acc: 64.076 	Loss: 1.1094
#  Client9 Train => Local Epoch: 2 	Acc: 65.835 	Loss: 0.9353
#  Client9 Train => Local Epoch: 3 	Acc: 68.869 	Loss: 0.8472
#  Client9 Train => Local Epoch: 4 	Acc: 70.546 	Loss: 0.7778
#  Client9 Test =>                   	Acc: 26.222 	Loss: 2.8279
#  Client4 Train => Local Epoch: 0 	Acc: 36.125 	Loss: 2.2300
#  Client4 Train => Local Epoch: 1 	Acc: 71.009 	Loss: 1.0275
#  Client4 Train => Local Epoch: 2 	Acc: 75.279 	Loss: 0.8803
#  Client4 Train => Local Epoch: 3 	Acc: 76.596 	Loss: 0.7851
#  Client4 Train => Local Epoch: 4 	Acc: 77.304 	Loss: 0.7350
#  Client4 Test =>                   	Acc: 26.172 	Loss: 2.4612
#  Client5 Train => Local Epoch: 0 	Acc: 54.762 	Loss: 1.5156
#  Client5 Train => Local Epoch: 1 	Acc: 69.166 	Loss: 0.9240
#  Client5 Train => Local Epoch: 2 	Acc: 73.216 	Loss: 0.7575
#  Client5 Train => Local Epoch: 3 	Acc: 74.116 	Loss: 0.7026
#  Client5 Train => Local Epoch: 4 	Acc: 76.144 	Loss: 0.6589
#  Client5 Test =>                   	Acc: 29.977 	Loss: 3.2809
#  Client0 Train => Local Epoch: 0 	Acc: 30.033 	Loss: 3.1198
#  Client0 Train => Local Epoch: 1 	Acc: 41.540 	Loss: 1.9024
#  Client0 Train => Local Epoch: 2 	Acc: 64.170 	Loss: 1.2317
#  Client0 Train => Local Epoch: 3 	Acc: 77.432 	Loss: 0.8977
#  Client0 Train => Local Epoch: 4 	Acc: 79.131 	Loss: 0.7915
#  Client0 Test =>                   	Acc: 20.309 	Loss: 3.5209
#  Client1 Train => Local Epoch: 0 	Acc: 66.158 	Loss: 1.2835
#  Client1 Train => Local Epoch: 1 	Acc: 94.263 	Loss: 0.2063
#  Client1 Train => Local Epoch: 2 	Acc: 95.211 	Loss: 0.1484
#  Client1 Train => Local Epoch: 3 	Acc: 95.429 	Loss: 0.1354
#  Client1 Train => Local Epoch: 4 	Acc: 95.528 	Loss: 0.1305
#  Client1 Test =>                   	Acc: 17.076 	Loss: 6.9732
# ====================== SERVER V1==========================
#  Train: Round   5, Avg Accuracy 84.396 | Avg Loss 0.501
#  Test: Round   5, Avg Accuracy 20.952 | Avg Loss 4.170
# Forgetting : Round 5, mean_forgetting : 0.730
# ==========================================================
#  Client6 Train => Local Epoch: 0 	Acc: 40.451 	Loss: 2.5691
#  Client6 Train => Local Epoch: 1 	Acc: 79.493 	Loss: 0.7224
#  Client6 Train => Local Epoch: 2 	Acc: 85.540 	Loss: 0.4766
#  Client6 Train => Local Epoch: 3 	Acc: 87.114 	Loss: 0.4123
#  Client6 Train => Local Epoch: 4 	Acc: 87.474 	Loss: 0.3966
#  Client6 Test =>                   	Acc: 24.081 	Loss: 4.4132
#  Client0 Train => Local Epoch: 0 	Acc: 22.707 	Loss: 2.9873
#  Client0 Train => Local Epoch: 1 	Acc: 35.719 	Loss: 1.7305
#  Client0 Train => Local Epoch: 2 	Acc: 62.860 	Loss: 1.1665
#  Client0 Train => Local Epoch: 3 	Acc: 75.322 	Loss: 0.8981
#  Client0 Train => Local Epoch: 4 	Acc: 79.563 	Loss: 0.7692
#  Client0 Test =>                   	Acc: 20.144 	Loss: 4.1864
#  Client3 Train => Local Epoch: 0 	Acc: 5.681 	Loss: 3.0310
#  Client3 Train => Local Epoch: 1 	Acc: 75.875 	Loss: 1.2973
#  Client3 Train => Local Epoch: 2 	Acc: 90.047 	Loss: 0.7039
#  Client3 Train => Local Epoch: 3 	Acc: 90.042 	Loss: 0.5135
#  Client3 Train => Local Epoch: 4 	Acc: 89.619 	Loss: 0.4982
#  Client3 Test =>                   	Acc: 9.510 	Loss: 4.7580
#  Client4 Train => Local Epoch: 0 	Acc: 2.481 	Loss: 3.0464
#  Client4 Train => Local Epoch: 1 	Acc: 68.982 	Loss: 1.3646
#  Client4 Train => Local Epoch: 2 	Acc: 70.522 	Loss: 1.1651
#  Client4 Train => Local Epoch: 3 	Acc: 70.256 	Loss: 1.0738
#  Client4 Train => Local Epoch: 4 	Acc: 70.788 	Loss: 0.9758
#  Client4 Test =>                   	Acc: 11.237 	Loss: 3.0462
#  Client5 Train => Local Epoch: 0 	Acc: 46.328 	Loss: 1.7884
#  Client3 Train => Local Epoch: 0 	Acc: 54.057 	Loss: 1.7944
#  Client3 Train => Local Epoch: 1 	Acc: 90.896 	Loss: 0.4899
#  Client3 Train => Local Epoch: 2 	Acc: 91.104 	Loss: 0.4663
#  Client3 Train => Local Epoch: 3 	Acc: 91.733 	Loss: 0.4298
#  Client3 Train => Local Epoch: 4 	Acc: 92.116 	Loss: 0.3930
#  Client3 Test =>                   	Acc: 17.262 	Loss: 4.2442
#  Client0 Train => Local Epoch: 0 	Acc: 5.667 	Loss: 3.9282
#  Client0 Train => Local Epoch: 1 	Acc: 18.388 	Loss: 2.4122
#  Client0 Train => Local Epoch: 2 	Acc: 33.453 	Loss: 1.5549
#  Client0 Train => Local Epoch: 3 	Acc: 56.749 	Loss: 1.2935
#  Client0 Train => Local Epoch: 4 	Acc: 76.691 	Loss: 1.2249
#  Client0 Test =>                   	Acc: 24.239 	Loss: 3.0123
#  Client8 Train => Local Epoch: 0 	Acc: 41.299 	Loss: 1.7850
#  Client8 Train => Local Epoch: 1 	Acc: 82.032 	Loss: 0.6956
#  Client8 Train => Local Epoch: 2 	Acc: 83.374 	Loss: 0.5476
#  Client8 Train => Local Epoch: 3 	Acc: 84.756 	Loss: 0.4729
#  Client8 Train => Local Epoch: 4 	Acc: 84.920 	Loss: 0.4448
#  Client8 Test =>                   	Acc: 24.229 	Loss: 4.0961
# ====================== SERVER V1==========================
#  Train: Round   7, Avg Accuracy 84.363 | Avg Loss 0.549
#  Test: Round   7, Avg Accuracy 20.731 | Avg Loss 4.306
# Forgetting : Round 7, mean_forgetting : -0.705
# ==========================================================
#  Client8 Train => Local Epoch: 0 	Acc: 85.686 	Loss: 0.4151
#  Client8 Train => Local Epoch: 1 	Acc: 86.273 	Loss: 0.4005
#  Client8 Train => Local Epoch: 2 	Acc: 86.564 	Loss: 0.3844
#  Client8 Train => Local Epoch: 3 	Acc: 87.144 	Loss: 0.3768
#  Client8 Train => Local Epoch: 4 	Acc: 87.455 	Loss: 0.3727
#  Client8 Test =>                   	Acc: 27.357 	Loss: 4.5195
#  Client9 Train => Local Epoch: 0 	Acc: 40.240 	Loss: 2.3349
#  Client9 Train => Local Epoch: 1 	Acc: 68.035 	Loss: 0.9494
#  Client9 Train => Local Epoch: 2 	Acc: 71.417 	Loss: 0.7960
#  Client9 Train => Local Epoch: 3 	Acc: 74.846 	Loss: 0.6858
#  Client9 Train => Local Epoch: 4 	Acc: 75.972 	Loss: 0.6395
#  Client9 Test =>                   	Acc: 36.143 	Loss: 2.5970
#  Client5 Train => Local Epoch: 0 	Acc: 63.630 	Loss: 1.2143
#  Client5 Train => Local Epoch: 1 	Acc: 76.248 	Loss: 0.6614
#  Client5 Train => Local Epoch: 2 	Acc: 79.300 	Loss: 0.5703
#  Client5 Train => Local Epoch: 3 	Acc: 79.815 	Loss: 0.5554
#  Client5 Train => Local Epoch: 4 	Acc: 80.827 	Loss: 0.5220
#  Client5 Test =>                   	Acc: 33.621 	Loss: 3.5375
#  Client6 Train => Local Epoch: 0 	Acc: 63.786 	Loss: 1.3298
#  Client0 Test =>                   	Acc: 19.117 	Loss: 2.7544
# ====================== SERVER V1==========================
#  Train: Round   8, Avg Accuracy 86.298 | Avg Loss 0.464
#  Test: Round   8, Avg Accuracy 22.649 | Avg Loss 4.127
# Forgetting : Round 8, mean_forgetting : -1.798
# ==========================================================
#  Client2 Train => Local Epoch: 0 	Acc: 36.754 	Loss: 2.2246
#  Client2 Train => Local Epoch: 1 	Acc: 91.651 	Loss: 0.5729
#  Client2 Train => Local Epoch: 2 	Acc: 92.704 	Loss: 0.3482
#  Client2 Train => Local Epoch: 3 	Acc: 92.987 	Loss: 0.3073
#  Client2 Train => Local Epoch: 4 	Acc: 93.151 	Loss: 0.2905
#  Client2 Test =>                   	Acc: 19.339 	Loss: 3.9166
#  Client5 Train => Local Epoch: 0 	Acc: 10.596 	Loss: 3.0480
#  Client5 Train => Local Epoch: 1 	Acc: 54.856 	Loss: 1.4715
#  Client5 Train => Local Epoch: 2 	Acc: 66.951 	Loss: 0.9552
#  Client5 Train => Local Epoch: 3 	Acc: 73.709 	Loss: 0.7254
#  Client5 Train => Local Epoch: 4 	Acc: 76.937 	Loss: 0.6175
#  Client5 Test =>                   	Acc: 29.166 	Loss: 3.1133
#  Client1 Train => Local Epoch: 0 	Acc: 39.946 	Loss: 2.1132
#  Client1 Train => Local Epoch: 1 	Acc: 94.742 	Loss: 0.1944
#  Client1 Train => Local Epoch: 2 	Acc: 95.802 	Loss: 0.1359
#  Client1 Train => Local Epoch: 3 	Acc: 96.507 	Loss: 0.1123
#  Client1 Train => Local Epoch: 4 	Acc: 96.809 	Loss: 0.1011
#  Client1 Test =>                   	Acc: 18.191 	Loss: 6.0833
#  Client6 Train => Local Epoch: 0 	Acc: 31.671 	Loss: 2.9746
#  Client6 Train => Local Epoch: 1 	Acc: 74.617 	Loss: 0.8272
#  Client6 Train => Local Epoch: 2 	Acc: 86.609 	Loss: 0.4200
#  Client6 Train => Local Epoch: 3 	Acc: 89.008 	Loss: 0.3531
#  Client6 Train => Local Epoch: 4 	Acc: 90.137 	Loss: 0.3142
#  Client6 Test =>                   	Acc: 26.630 	Loss: 4.1177
#  Client4 Train => Local Epoch: 0 	Acc: 8.717 	Loss: 3.4297
#  Client4 Train => Local Epoch: 1 	Acc: 71.058 	Loss: 1.3517
#  Client4 Train => Local Epoch: 2 	Acc: 70.864 	Loss: 1.0732
#  Client4 Train => Local Epoch: 3 	Acc: 71.716 	Loss: 0.9596
#  Client4 Train => Local Epoch: 4 	Acc: 73.524 	Loss: 0.8881
#  Client4 Test =>                   	Acc: 17.181 	Loss: 2.5909
#  Client0 Train => Local Epoch: 0 	Acc: 5.139 	Loss: 3.6453
#  Client0 Train => Local Epoch: 1 	Acc: 13.230 	Loss: 2.6264
#  Client0 Train => Local Epoch: 2 	Acc: 28.940 	Loss: 1.8618
#  Client0 Train => Local Epoch: 3 	Acc: 51.116 	Loss: 1.4039
#  Client0 Train => Local Epoch: 4 	Acc: 69.579 	Loss: 1.0950
#  Client0 Test =>                   	Acc: 19.487 	Loss: 2.6517
#  Client6 Test =>                   	Acc: 23.249 	Loss: 4.2098
#  Client8 Train => Local Epoch: 0 	Acc: 52.730 	Loss: 1.7270
#  Client8 Train => Local Epoch: 1 	Acc: 83.125 	Loss: 0.5590
#  Client8 Train => Local Epoch: 2 	Acc: 85.309 	Loss: 0.4504
#  Client8 Train => Local Epoch: 3 	Acc: 86.648 	Loss: 0.4050
#  Client8 Train => Local Epoch: 4 	Acc: 87.061 	Loss: 0.3784
#  Client8 Test =>                   	Acc: 26.418 	Loss: 4.9045
# ====================== SERVER V1==========================
#  Train: Round  10, Avg Accuracy 85.768 | Avg Loss 0.463
#  Test: Round  10, Avg Accuracy 22.910 | Avg Loss 4.169
# Forgetting : Round 10, mean_forgetting : -0.526
# ==========================================================
#  Client9 Train => Local Epoch: 0 	Acc: 45.027 	Loss: 2.1141
#  Client9 Train => Local Epoch: 1 	Acc: 69.017 	Loss: 0.9502
#  Client9 Train => Local Epoch: 2 	Acc: 71.417 	Loss: 0.7776
#  Client9 Train => Local Epoch: 3 	Acc: 76.137 	Loss: 0.6591
#  Client9 Train => Local Epoch: 4 	Acc: 77.133 	Loss: 0.6076
#  Client9 Test =>                   	Acc: 41.194 	Loss: 2.3185
#  Client5 Train => Local Epoch: 0 	Acc: 61.445 	Loss: 1.2734
#  Client5 Train => Local Epoch: 1 	Acc: 79.306 	Loss: 0.6023
#  Client5 Train => Local Epoch: 2 	Acc: 81.655 	Loss: 0.5308
#  Client5 Train => Local Epoch: 3 	Acc: 82.585 	Loss: 0.4989
#  Client5 Train => Local Epoch: 4 	Acc: 83.524 	Loss: 0.4607
#  Client5 Test =>                   	Acc: 35.655 	Loss: 3.4614
#  Client0 Train => Local Epoch: 0 	Acc: 31.653 	Loss: 2.8456
#  Client0 Train => Local Epoch: 1 	Acc: 43.104 	Loss: 1.7562
# ...
#  Client7 Test =>                   	Acc: 20.387 	Loss: 4.6679
# ====================== SERVER V1==========================
#  Train: Round  95, Avg Accuracy 96.955 | Avg Loss 0.103
#  Test: Round  95, Avg Accuracy 37.655 | Avg Loss 2.986
# Forgetting : Round 95, mean_forgetting : 1.573
# ==========================================================
#  Client9 Train => Local Epoch: 0 	Acc: 74.130 	Loss: 0.9294
#  Client9 Train => Local Epoch: 1 	Acc: 94.313 	Loss: 0.1744
#  Client9 Train => Local Epoch: 2 	Acc: 95.996 	Loss: 0.1242
#  Client9 Train => Local Epoch: 3 	Acc: 96.279 	Loss: 0.1077
#  Client9 Train => Local Epoch: 4 	Acc: 96.887 	Loss: 0.0942
#  Client9 Test =>                   	Acc: 55.805 	Loss: 2.2477
#  Client4 Train => Local Epoch: 0 	Acc: 60.067 	Loss: 1.6206
#  Client4 Train => Local Epoch: 1 	Acc: 88.505 	Loss: 0.3845
#  Client4 Train => Local Epoch: 2 	Acc: 92.802 	Loss: 0.2280
#  Client4 Train => Local Epoch: 3 	Acc: 94.707 	Loss: 0.1696
#  Client4 Train => Local Epoch: 4 	Acc: 96.144 	Loss: 0.1261
#  Client4 Test =>                   	Acc: 57.415 	Loss: 1.7618
#  Client8 Train => Local Epoch: 0 	Acc: 81.710 	Loss: 0.6602
#  Client8 Train => Local Epoch: 1 	Acc: 95.461 	Loss: 0.1428
#  Client8 Train => Local Epoch: 2 	Acc: 97.028 	Loss: 0.0919
#  Client8 Train => Local Epoch: 3 	Acc: 97.626 	Loss: 0.0744
#  Client8 Train => Local Epoch: 4 	Acc: 97.774 	Loss: 0.0673
#  Client8 Test =>                   	Acc: 41.996 	Loss: 3.2459
#  Client6 Train => Local Epoch: 0 	Acc: 84.958 	Loss: 0.5730
#  Client6 Train => Local Epoch: 1 	Acc: 96.221 	Loss: 0.1348
#  Client6 Train => Local Epoch: 2 	Acc: 97.244 	Loss: 0.0902
#  Client6 Train => Local Epoch: 3 	Acc: 98.161 	Loss: 0.0649
#  Client6 Train => Local Epoch: 4 	Acc: 98.093 	Loss: 0.0651
#  Client6 Test =>                   	Acc: 36.618 	Loss: 2.8158
#  Client0 Train => Local Epoch: 0 	Acc: 45.296 	Loss: 1.9205
#  Client0 Train => Local Epoch: 1 	Acc: 71.652 	Loss: 0.7621
#  Client0 Train => Local Epoch: 2 	Acc: 89.274 	Loss: 0.4008
#  Client0 Train => Local Epoch: 3 	Acc: 92.478 	Loss: 0.2943
#  Client0 Train => Local Epoch: 4 	Acc: 93.435 	Loss: 0.2344
#  Client0 Test =>                   	Acc: 35.645 	Loss: 2.6816
#  Client3 Train => Local Epoch: 0 	Acc: 47.288 	Loss: 1.6389
#  Client3 Train => Local Epoch: 1 	Acc: 92.440 	Loss: 0.5224
#  Client3 Train => Local Epoch: 2 	Acc: 92.807 	Loss: 0.3871
#  Client3 Train => Local Epoch: 3 	Acc: 93.460 	Loss: 0.2928
#  Client3 Train => Local Epoch: 4 	Acc: 94.211 	Loss: 0.2481
#  Client3 Test =>                   	Acc: 28.714 	Loss: 3.4499
#  Client5 Train => Local Epoch: 0 	Acc: 76.671 	Loss: 0.7341
#  Client5 Train => Local Epoch: 1 	Acc: 93.282 	Loss: 0.1983
#  Client5 Train => Local Epoch: 2 	Acc: 95.308 	Loss: 0.1380
#  Client5 Train => Local Epoch: 3 	Acc: 96.799 	Loss: 0.1056
#  Client5 Train => Local Epoch: 4 	Acc: 97.179 	Loss: 0.0860
#  Client5 Test =>                   	Acc: 43.016 	Loss: 3.1862
#  Client1 Train => Local Epoch: 0 	Acc: 55.758 	Loss: 1.3786
#  Client1 Train => Local Epoch: 1 	Acc: 98.887 	Loss: 0.0818
#  Client1 Train => Local Epoch: 2 	Acc: 99.242 	Loss: 0.0262
#  Client1 Train => Local Epoch: 3 	Acc: 99.330 	Loss: 0.0269
#  Client1 Train => Local Epoch: 4 	Acc: 99.490 	Loss: 0.0210
#  Client1 Test =>                   	Acc: 26.987 	Loss: 4.4345
#  Client7 Train => Local Epoch: 0 	Acc: 68.705 	Loss: 1.2587
#  Client7 Train => Local Epoch: 1 	Acc: 97.769 	Loss: 0.0748
#  Client7 Train => Local Epoch: 2 	Acc: 98.524 	Loss: 0.0523
#  Client7 Train => Local Epoch: 3 	Acc: 98.892 	Loss: 0.0378
#  Client7 Train => Local Epoch: 4 	Acc: 98.963 	Loss: 0.0366
#  Client7 Test =>                   	Acc: 20.063 	Loss: 5.0458
#  Client2 Train => Local Epoch: 0 	Acc: 65.673 	Loss: 1.3441
#  Client2 Train => Local Epoch: 1 	Acc: 95.679 	Loss: 0.1744
#  Client2 Train => Local Epoch: 2 	Acc: 96.705 	Loss: 0.1044
#  Client2 Train => Local Epoch: 3 	Acc: 97.508 	Loss: 0.0777
#  Client2 Train => Local Epoch: 4 	Acc: 97.895 	Loss: 0.0682
#  Client2 Test =>                   	Acc: 36.503 	Loss: 2.5502
# ====================== SERVER V1==========================
#  Train: Round  96, Avg Accuracy 97.007 | Avg Loss 0.105
#  Test: Round  96, Avg Accuracy 38.276 | Avg Loss 3.142
# Forgetting : Round 96, mean_forgetting : -0.763
# ==========================================================
#  Client9 Train => Local Epoch: 0 	Acc: 72.740 	Loss: 0.9941
#  Client9 Train => Local Epoch: 1 	Acc: 93.288 	Loss: 0.1946
#  Client9 Train => Local Epoch: 2 	Acc: 95.724 	Loss: 0.1277
#  Client9 Train => Local Epoch: 3 	Acc: 96.159 	Loss: 0.1104
#  Client9 Train => Local Epoch: 4 	Acc: 96.698 	Loss: 0.0992
#  Client9 Test =>                   	Acc: 56.560 	Loss: 2.1675
#  Client1 Train => Local Epoch: 0 	Acc: 71.246 	Loss: 1.0664
#  Client1 Train => Local Epoch: 1 	Acc: 98.798 	Loss: 0.0767
#  Client1 Train => Local Epoch: 2 	Acc: 99.325 	Loss: 0.0304
#  Client1 Train => Local Epoch: 3 	Acc: 99.521 	Loss: 0.0249
#  Client1 Train => Local Epoch: 4 	Acc: 99.503 	Loss: 0.0217
#  Client1 Test =>                   	Acc: 26.293 	Loss: 4.2746
#  Client7 Train => Local Epoch: 0 	Acc: 72.258 	Loss: 0.9302
#  Client7 Train => Local Epoch: 1 	Acc: 98.494 	Loss: 0.0578
#  Client7 Train => Local Epoch: 2 	Acc: 98.768 	Loss: 0.0420
#  Client7 Train => Local Epoch: 3 	Acc: 99.046 	Loss: 0.0343
#  Client7 Train => Local Epoch: 4 	Acc: 99.023 	Loss: 0.0350
#  Client7 Test =>                   	Acc: 20.875 	Loss: 5.0999
#  Client6 Train => Local Epoch: 0 	Acc: 61.801 	Loss: 1.5386
#  Client6 Train => Local Epoch: 1 	Acc: 94.545 	Loss: 0.1896
#  Client6 Train => Local Epoch: 2 	Acc: 96.541 	Loss: 0.1253
#  Client6 Train => Local Epoch: 3 	Acc: 97.339 	Loss: 0.0986
#  Client6 Train => Local Epoch: 4 	Acc: 98.055 	Loss: 0.0795
#  Client6 Test =>                   	Acc: 35.924 	Loss: 2.6976
#  Client0 Train => Local Epoch: 0 	Acc: 36.131 	Loss: 2.3006
#  Client0 Train => Local Epoch: 1 	Acc: 60.443 	Loss: 1.1085
#  Client0 Train => Local Epoch: 2 	Acc: 87.887 	Loss: 0.4990
#  Client0 Train => Local Epoch: 3 	Acc: 90.991 	Loss: 0.3378
#  Client0 Train => Local Epoch: 4 	Acc: 91.423 	Loss: 0.2693
#  Client0 Test =>                   	Acc: 33.496 	Loss: 2.7587
#  Client2 Train => Local Epoch: 0 	Acc: 60.981 	Loss: 1.4569
#  Client2 Train => Local Epoch: 1 	Acc: 96.240 	Loss: 0.1438
#  Client2 Train => Local Epoch: 2 	Acc: 97.212 	Loss: 0.0977
#  Client2 Train => Local Epoch: 3 	Acc: 97.685 	Loss: 0.0788
#  Client2 Train => Local Epoch: 4 	Acc: 97.853 	Loss: 0.0658
#  Client2 Test =>                   	Acc: 39.807 	Loss: 2.3062
#  Client8 Train => Local Epoch: 0 	Acc: 59.814 	Loss: 1.3996
#  Client8 Train => Local Epoch: 1 	Acc: 93.789 	Loss: 0.2140
#  Client8 Train => Local Epoch: 2 	Acc: 96.065 	Loss: 0.1244
#  Client8 Train => Local Epoch: 3 	Acc: 96.802 	Loss: 0.1014
#  Client8 Train => Local Epoch: 4 	Acc: 97.383 	Loss: 0.0904
#  Client8 Test =>                   	Acc: 36.416 	Loss: 3.7190
#  Client5 Train => Local Epoch: 0 	Acc: 66.896 	Loss: 1.1900
#  Client5 Train => Local Epoch: 1 	Acc: 93.429 	Loss: 0.2089
#  Client5 Train => Local Epoch: 2 	Acc: 95.338 	Loss: 0.1419
#  Client5 Train => Local Epoch: 3 	Acc: 96.479 	Loss: 0.1058
#  Client5 Train => Local Epoch: 4 	Acc: 97.332 	Loss: 0.0862
#  Client5 Test =>                   	Acc: 48.148 	Loss: 2.4811
#  Client3 Train => Local Epoch: 0 	Acc: 41.400 	Loss: 2.2886
#  Client3 Train => Local Epoch: 1 	Acc: 91.245 	Loss: 0.6839
#  Client3 Train => Local Epoch: 2 	Acc: 92.355 	Loss: 0.5022
#  Client3 Train => Local Epoch: 3 	Acc: 92.730 	Loss: 0.3893
#  Client3 Train => Local Epoch: 4 	Acc: 92.923 	Loss: 0.3353
#  Client3 Test =>                   	Acc: 21.242 	Loss: 3.0477
#  Client4 Train => Local Epoch: 0 	Acc: 2.290 	Loss: 2.8835
#  Client4 Train => Local Epoch: 1 	Acc: 62.581 	Loss: 0.9697
#  Client4 Train => Local Epoch: 2 	Acc: 88.337 	Loss: 0.4100
#  Client4 Train => Local Epoch: 3 	Acc: 91.703 	Loss: 0.2689
#  Client4 Train => Local Epoch: 4 	Acc: 93.656 	Loss: 0.1985
#  Client4 Test =>                   	Acc: 47.720 	Loss: 1.8668
# ====================== SERVER V1==========================
#  Train: Round  97, Avg Accuracy 96.385 | Avg Loss 0.128
#  Test: Round  97, Avg Accuracy 36.648 | Avg Loss 3.042
# Forgetting : Round 97, mean_forgetting : -1.494
# ==========================================================
#  Client8 Train => Local Epoch: 0 	Acc: 75.376 	Loss: 0.8488
#  Client8 Train => Local Epoch: 1 	Acc: 95.649 	Loss: 0.1437
#  Client8 Train => Local Epoch: 2 	Acc: 96.645 	Loss: 0.1007
#  Client8 Train => Local Epoch: 3 	Acc: 97.284 	Loss: 0.0828
#  Client8 Train => Local Epoch: 4 	Acc: 97.804 	Loss: 0.0697
#  Client8 Test =>                   	Acc: 40.197 	Loss: 3.1131
#  Client3 Train => Local Epoch: 0 	Acc: 27.077 	Loss: 2.3867
#  Client4 Test =>                   	Acc: 51.296 	Loss: 2.0177
#  Client6 Train => Local Epoch: 0 	Acc: 64.282 	Loss: 1.4475
#  Client6 Train => Local Epoch: 1 	Acc: 94.675 	Loss: 0.1974
#  Client6 Train => Local Epoch: 2 	Acc: 96.199 	Loss: 0.1327
#  Client6 Train => Local Epoch: 3 	Acc: 97.072 	Loss: 0.1070
#  Client6 Train => Local Epoch: 4 	Acc: 97.395 	Loss: 0.0908
#  Client6 Test =>                   	Acc: 30.755 	Loss: 3.2274
#  Client2 Train => Local Epoch: 0 	Acc: 63.628 	Loss: 1.3401
#  Client2 Train => Local Epoch: 1 	Acc: 96.737 	Loss: 0.1303
#  Client2 Train => Local Epoch: 2 	Acc: 97.141 	Loss: 0.1022
#  Client2 Train => Local Epoch: 3 	Acc: 97.652 	Loss: 0.0756
#  Client2 Train => Local Epoch: 4 	Acc: 98.199 	Loss: 0.0642
#  Client2 Test =>                   	Acc: 43.248 	Loss: 2.0242
# ====================== SERVER V1==========================
#  Train: Round  98, Avg Accuracy 96.795 | Avg Loss 0.115
#  Test: Round  98, Avg Accuracy 38.418 | Avg Loss 2.953
# Forgetting : Round 98, mean_forgetting : -0.922
# ==========================================================
#  Client8 Train => Local Epoch: 0 	Acc: 74.590 	Loss: 0.8799
#  Client8 Train => Local Epoch: 1 	Acc: 95.711 	Loss: 0.1469
#  Client8 Train => Local Epoch: 2 	Acc: 96.913 	Loss: 0.0957
#  Client8 Train => Local Epoch: 3 	Acc: 97.121 	Loss: 0.0889
#  Client8 Train => Local Epoch: 4 	Acc: 97.712 	Loss: 0.0696
#  Client8 Test =>                   	Acc: 39.062 	Loss: 3.2846
#  Client2 Train => Local Epoch: 0 	Acc: 81.771 	Loss: 0.6666
#  Client2 Train => Local Epoch: 1 	Acc: 96.824 	Loss: 0.1037
#  Client2 Train => Local Epoch: 2 	Acc: 97.716 	Loss: 0.0772
#  Client2 Train => Local Epoch: 3 	Acc: 98.035 	Loss: 0.0638
#  Client2 Train => Local Epoch: 4 	Acc: 98.215 	Loss: 0.0584
#  Client2 Test =>                   	Acc: 41.235 	Loss: 2.3225
#  Client3 Train => Local Epoch: 0 	Acc: 33.105 	Loss: 2.3940
#  Client3 Train => Local Epoch: 1 	Acc: 89.834 	Loss: 0.7742
#  Client3 Train => Local Epoch: 2 	Acc: 92.476 	Loss: 0.5112
#  Client3 Train => Local Epoch: 3 	Acc: 92.800 	Loss: 0.3781
#  Client3 Train => Local Epoch: 4 	Acc: 93.070 	Loss: 0.3202
#  Client3 Test =>                   	Acc: 20.272 	Loss: 3.4253
#  Client0 Train => Local Epoch: 0 	Acc: 14.401 	Loss: 3.3989
#  Client0 Train => Local Epoch: 1 	Acc: 38.207 	Loss: 1.7734
#  Client0 Train => Local Epoch: 2 	Acc: 76.967 	Loss: 0.7582
#  Client0 Train => Local Epoch: 3 	Acc: 87.671 	Loss: 0.4690
#  Client0 Train => Local Epoch: 4 	Acc: 90.542 	Loss: 0.3595
#  Client0 Test =>                   	Acc: 28.549 	Loss: 3.0693
#  Client9 Train => Local Epoch: 0 	Acc: 66.139 	Loss: 1.2243
#  Client9 Train => Local Epoch: 1 	Acc: 91.994 	Loss: 0.2374
#  Client9 Train => Local Epoch: 2 	Acc: 94.931 	Loss: 0.1524
#  Client9 Train => Local Epoch: 3 	Acc: 95.902 	Loss: 0.1230
#  Client9 Train => Local Epoch: 4 	Acc: 96.090 	Loss: 0.1122
#  Client9 Test =>                   	Acc: 54.408 	Loss: 2.3841
#  Client4 Train => Local Epoch: 0 	Acc: 59.089 	Loss: 1.5379
#  Client4 Train => Local Epoch: 1 	Acc: 90.775 	Loss: 0.3173
#  Client4 Train => Local Epoch: 2 	Acc: 94.241 	Loss: 0.1799
#  Client4 Train => Local Epoch: 3 	Acc: 95.923 	Loss: 0.1302
#  Client4 Train => Local Epoch: 4 	Acc: 95.829 	Loss: 0.1290
#  Client4 Test =>                   	Acc: 60.170 	Loss: 1.7130
#  Client7 Train => Local Epoch: 0 	Acc: 79.113 	Loss: 0.7981
#  Client7 Train => Local Epoch: 1 	Acc: 98.209 	Loss: 0.0616
#  Client7 Train => Local Epoch: 2 	Acc: 98.719 	Loss: 0.0448
#  Client7 Train => Local Epoch: 3 	Acc: 98.847 	Loss: 0.0395
#  Client7 Train => Local Epoch: 4 	Acc: 99.155 	Loss: 0.0349
#  Client7 Test =>                   	Acc: 20.376 	Loss: 4.7608
#  Client1 Train => Local Epoch: 0 	Acc: 70.115 	Loss: 1.3994
#  Client1 Train => Local Epoch: 1 	Acc: 98.075 	Loss: 0.0897
#  Client1 Train => Local Epoch: 2 	Acc: 98.958 	Loss: 0.0425
#  Client1 Train => Local Epoch: 3 	Acc: 99.057 	Loss: 0.0382
#  Client1 Train => Local Epoch: 4 	Acc: 99.384 	Loss: 0.0242
#  Client1 Test =>                   	Acc: 23.010 	Loss: 4.5656
#  Client5 Train => Local Epoch: 0 	Acc: 59.294 	Loss: 1.5116
#  Client5 Train => Local Epoch: 1 	Acc: 91.373 	Loss: 0.2637
#  Client5 Train => Local Epoch: 2 	Acc: 94.326 	Loss: 0.1682
#  Client5 Train => Local Epoch: 3 	Acc: 95.466 	Loss: 0.1395
#  Client5 Train => Local Epoch: 4 	Acc: 96.359 	Loss: 0.1206
#  Client5 Test =>                   	Acc: 41.450 	Loss: 3.2083
#  Client6 Train => Local Epoch: 0 	Acc: 81.676 	Loss: 0.7836
#  Client6 Train => Local Epoch: 1 	Acc: 95.214 	Loss: 0.1782
#  Client6 Train => Local Epoch: 2 	Acc: 96.437 	Loss: 0.1301
#  Client6 Train => Local Epoch: 3 	Acc: 97.072 	Loss: 0.1081
#  Client6 Train => Local Epoch: 4 	Acc: 97.308 	Loss: 0.0965
#  Client6 Test =>                   	Acc: 32.543 	Loss: 3.1158
# ====================== SERVER V1==========================
#  Train: Round  99, Avg Accuracy 96.366 | Avg Loss 0.133
#  Test: Round  99, Avg Accuracy 36.108 | Avg Loss 3.185
# Forgetting : Round 99, mean_forgetting : -0.069
# ==========================================================
# Training and Evaluation completed!
# Saved: SL - CIFAR-10 α=0.1.csv
