# %% [markdown]
# # Split Federated Learning V2:
# ### ResNet18 on CIFAR-100 + α = 0.1 - LATE-Cut (After Layer 6 + AvgPool)

# %%
#=============================================================================
# SplitfedV2 (SFLV2) learning: ResNet18 on CIFAR-100
# Version2: with using socket but no DP+PixelDP
# ==============================================================================
import torch
from torch import nn
from torchvision import transforms
from torch.utils.data import DataLoader, Dataset
import torch.nn.functional as F
import math
import os.path
import pandas as pd
from sklearn.model_selection import train_test_split
from PIL import Image
from glob import glob
from pandas import DataFrame
import random
import numpy as np
import os


import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import copy
import time


#===================================================================
program = "SFLV2 - CIFAR-100 α=0.1 - LATE-Cut (6 + AvgPool)"
DATASET_NAME = "CIFAR100"            # Set toggle between CIFAR-10 and CIFAR-100
DATA_ROOT = "data"                   # Set where torchvision stores CIFAR data


print(f"---------{program}----------")              # this is to identify the program in the slurm outputs files


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
pin = torch.cuda.is_available()


# To print in color -------test/train of the client side
def prRed(skk): print("\033[91m {}\033[00m" .format(skk)) 
def prGreen(skk): print("\033[92m {}\033[00m" .format(skk))     


#===================================================================
# No. of users
NUM_CLIENTS = 10
EPOCHS = 100
LOCAL_EPOCHS = 5
FRAC = 1        # participation of clients; if 1 then 100% clients participate in SFLV2
ALPHA = 0.1   # requested alpha


# ----------------------------- Optimization ------------------------------ #
BATCH_SIZE = 256
LR_BASE = 0.01  
WARMUP_ROUNDS = 0
MOMENTUM = 0.9                     # Smoothing/Accelerating SGD undates
WEIGHT_DECAY = 5e-4                # L2 Regularization
LABEL_SMOOTH = 0.0
NUM_WORKERS = 4
SEED = 1234



def _sync_cuda():
    if torch.cuda.is_available():
        torch.cuda.synchronize()


SEED = 1234
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
if torch.cuda.is_available():
    torch.backends.cudnn.deterministic = True
    print(torch.cuda.get_device_name(0))    




#=====================================================================================================
#                                  Baseblock
#=====================================================================================================
class Baseblock(nn.Module):
    expansion = 1
    def __init__(self, input_planes, planes, stride = 1, dim_change = None):
        super(Baseblock, self).__init__()
        self.conv1 = nn.Conv2d(input_planes, planes, stride =  stride, kernel_size = 3, padding = 1)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, stride = 1, kernel_size = 3, padding = 1)
        self.bn2 = nn.BatchNorm2d(planes)
        self.dim_change = dim_change
        
    def forward(self, x):
        res = x
        output = F.relu(self.bn1(self.conv1(x)))
        output = self.bn2(self.conv2(output))
        
        if self.dim_change is not None:
            res =self.dim_change(res)
            
        output += res
        output = F.relu(output)
        
        return output
        
#=====================================================================================================
#                           Client-side Model definition
#=====================================================================================================
# Model at client side
class ResNet18_client_side(nn.Module):
    def __init__(self, block, num_layers):
        super().__init__()
        self.layer1 = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False),  # 3x3 s=1
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            # no maxpool for 32x32
        )
        self.layer2 = nn.Sequential(
            nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(64),
        )

        # add layer 3-6 + avg-pool (copied from Client)
        self.layer3 = nn.Sequential (
                nn.Conv2d(64, 64, kernel_size = 3, stride = 1, padding = 1),
                nn.BatchNorm2d(64),
                nn.ReLU (inplace = True),
                nn.Conv2d(64, 64, kernel_size = 3, stride = 1, padding = 1),
                nn.BatchNorm2d(64),       
                )   

        # self.input_planes is only used inside _layer()
        self.input_planes = 64

        self.layer4 = self._layer(block, 128, num_layers[0], stride = 2)
        self.layer5 = self._layer(block, 256, num_layers[1], stride = 2)
        self.layer6 = self._layer(block, 512, num_layers[2], stride = 2)

        # self. averagePool = nn.AvgPool2d(kernel_size = 7, stride = 1)
        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))


        # Weights into loop (the same thing as SERVER)
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                m.weight.data.normal_(0, math.sqrt(2. / n))
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()
                

    # a helper function to build deeper ResNet blocks (layer4–6) using Baseblock
    def _layer(self, block, planes, num_layers, stride = 2):
        dim_change = None
        if stride != 1 or planes != self.input_planes * block.expansion:
            dim_change = nn.Sequential(nn.Conv2d(self.input_planes, planes*block.expansion, kernel_size = 1, stride = stride),
                                       nn.BatchNorm2d(planes*block.expansion))
        netLayers = []
        netLayers.append(block(self.input_planes, planes, stride = stride, dim_change = dim_change))
        self.input_planes = planes * block.expansion
        for i in range(1, num_layers):
            netLayers.append(block(self.input_planes, planes))
            self.input_planes = planes * block.expansion
            
        return nn.Sequential(*netLayers)
        
        
    def forward(self, x):
        resudial1 = F.relu(self.layer1(x))
        out1 = self.layer2(resudial1)
        out1 = out1 + resudial1 # adding the resudial inputs -- downsampling not required in this layer
        x = F.relu(out1)

        out2 = self.layer3(x)
        out2 = out2 + x
        x = F.relu(out2)
        
        x = self.layer4(x)                    # channels = 128
        x = self.layer5(x)                    # channels = 256
        x = self.layer6(x)                    # channels = 512
        x = self.avgpool(x)                   # Shape [B, 512, H', W']

        # LATE CUT: send x to server
        return x    # shape [B, 512, H', W']
 

net_glob_client = ResNet18_client_side(Baseblock, [2, 2, 2])
if torch.cuda.device_count() > 1:
    print("We use",torch.cuda.device_count(), "GPUs")
    net_glob_client = nn.DataParallel(net_glob_client)   # to use the multiple GPUs; later we can change this to CPUs only 

net_glob_client.to(device)
print(net_glob_client)    

#=====================================================================================================
#                           Server-side Model definition
#=====================================================================================================
# Model at server side
class ResNet18_server_side(nn.Module):
    def __init__(self, block ,classes):
        super(ResNet18_server_side, self).__init__()
        self.fc = nn.Linear(512 * block.expansion, classes)

        
        # Weights into loop
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                m.weight.data.normal_(0, math.sqrt(2. / n))
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()
    
        
    
    def forward(self, x):
        x = x.view(x.size(0), -1)     # [B, 512]
        y_hat = self.fc(x)            # [B, num_classes]
        return y_hat
        

if DATASET_NAME == "CIFAR10":
    net_glob_server = ResNet18_server_side(Baseblock, 10)
else:
    net_glob_server = ResNet18_server_side(Baseblock, 100)
    

if torch.cuda.device_count() > 1:
    print("We use",torch.cuda.device_count(), "GPUs")
    net_glob_server = nn.DataParallel(net_glob_server)   # to use the multiple GPUs 


net_glob_server.to(device)
print(net_glob_server)      

#===================================================================================
# For Server Side Loss and Accuracy 
loss_train_collect = []
acc_train_collect = []
loss_test_collect = []
acc_test_collect = []
batch_acc_train = []
batch_loss_train = []
batch_acc_test = []
batch_loss_test = []
round_time_collect = [] # Stores seconds per global round

criterion = nn.CrossEntropyLoss()
count1 = 0
count2 = 0

#====================================================================================================
#                                  Server Side Programs
#====================================================================================================
# Federated averaging: FedAvg
def FedAvg(w):
    w_avg = copy.deepcopy(w[0])
    for k in w_avg.keys():
        for i in range(1, len(w)):
            w_avg[k] += w[i][k]
        w_avg[k] = torch.div(w_avg[k], len(w))
    return w_avg

def calculate_accuracy(fx, y):
    preds = fx.max(1, keepdim=True)[1]
    correct = preds.eq(y.view_as(preds)).sum()
    acc = 100.00 *correct.float()/preds.shape[0]
    return acc

# to print train - test together in each round-- these are made global
acc_avg_all_user_train = 0
loss_avg_all_user_train = 0
loss_train_collect_user = []
acc_train_collect_user = []
loss_test_collect_user = []
acc_test_collect_user = []


#client idx collector
idx_collect = []
l_epoch_check = False
fed_check = False

# Server-side function associated with Training 
def train_server(fx_client, y, l_epoch_count, l_epoch, idx, len_batch):
    global net_glob_server, criterion, device, batch_acc_train, batch_loss_train, l_epoch_check, fed_check
    global loss_train_collect, acc_train_collect, count1, acc_avg_all_user_train, loss_avg_all_user_train, idx_collect
    global loss_train_collect_user, acc_train_collect_user, LR_BASE
    
    net_glob_server.train()
    optimizer_server = torch.optim.SGD(
        net_glob_server.parameters(), 
        lr = LR_BASE,
        momentum=MOMENTUM,
        weight_decay=WEIGHT_DECAY
    )

    
    # train and update
    optimizer_server.zero_grad()
    
    fx_client = fx_client.to(device)
    y = y.to(device)
    
    #---------forward prop-------------
    fx_server = net_glob_server(fx_client)
    
    # calculate loss
    loss = criterion(fx_server, y)
    # calculate accuracy
    acc = calculate_accuracy(fx_server, y)
    
    #--------backward prop--------------
    loss.backward()
    dfx_client = fx_client.grad.clone().detach()
    optimizer_server.step()
    
    batch_loss_train.append(loss.item())
    batch_acc_train.append(acc.item())
    
    
    # server-side model net_glob_server is global so it is updated automatically in each pass to this function
    # count1: to track the completion of the local batch associated with one client
    count1 += 1
    if count1 == len_batch:
        acc_avg_train = sum(batch_acc_train)/len(batch_acc_train)           # it has accuracy for one batch
        loss_avg_train = sum(batch_loss_train)/len(batch_loss_train)
        
        batch_acc_train = []
        batch_loss_train = []
        count1 = 0
        
        prRed('Client{} Train => Local Epoch: {} \tAcc: {:.3f} \tLoss: {:.4f}'.format(idx, l_epoch_count, acc_avg_train, loss_avg_train))
        
                
        # If one local epoch is completed, after this a new client will come
        if l_epoch_count == l_epoch-1:
            
            l_epoch_check = True                # to evaluate_server function - to check local epoch has completed or not
                       
            # we store the last accuracy in the last batch of the epoch and it is not the average of all local epochs
            # this is because we work on the last trained model and its accuracy (not earlier cases)
            
            #print("accuracy = ", acc_avg_train)
            acc_avg_train_all = acc_avg_train
            loss_avg_train_all = loss_avg_train
                        
            # accumulate accuracy and loss for each new user
            loss_train_collect_user.append(loss_avg_train_all)
            acc_train_collect_user.append(acc_avg_train_all)
            
            # collect the id of each new user                        
            if idx not in idx_collect:
                idx_collect.append(idx) 
                #print(idx_collect)
        
        # This is to check if all users are served for one round --------------------
        if len(idx_collect) == NUM_CLIENTS:
            fed_check = True                                                  # to evaluate_server function  - to check fed check has hitted
            # all users served for one round ------------------------- output print and update is done in evaluate_server()
            # for nicer display 
                        
            idx_collect = []
            
            acc_avg_all_user_train = sum(acc_train_collect_user)/len(acc_train_collect_user)
            loss_avg_all_user_train = sum(loss_train_collect_user)/len(loss_train_collect_user)
            
            loss_train_collect.append(loss_avg_all_user_train)
            acc_train_collect.append(acc_avg_all_user_train)
            
            acc_train_collect_user = []
            loss_train_collect_user = []
            
    # send gradients to the client               
    return dfx_client

# Server-side functions associated with Testing
def evaluate_server(fx_client, y, idx, len_batch, ell):
    global net_glob_server, criterion, batch_acc_test, batch_loss_test
    global loss_test_collect, acc_test_collect, count2, NUM_CLIENTS, acc_avg_train_all, loss_avg_train_all, l_epoch_check, fed_check
    global loss_test_collect_user, acc_test_collect_user, acc_avg_all_user_train, loss_avg_all_user_train
    
    net_glob_server.eval()
  
    with torch.no_grad():
        fx_client = fx_client.to(device)
        y = y.to(device) 
        #---------forward prop-------------
        fx_server = net_glob_server(fx_client)
        
        # calculate loss
        loss = criterion(fx_server, y)
        # calculate accuracy
        acc = calculate_accuracy(fx_server, y)
        
        
        batch_loss_test.append(loss.item())
        batch_acc_test.append(acc.item())
        
               
        count2 += 1
        if count2 == len_batch:
            acc_avg_test = sum(batch_acc_test)/len(batch_acc_test)
            loss_avg_test = sum(batch_loss_test)/len(batch_loss_test)
            
            batch_acc_test = []
            batch_loss_test = []
            count2 = 0
            
            prGreen('Client{} Test =>                   \tAcc: {:.3f} \tLoss: {:.4f}'.format(idx, acc_avg_test, loss_avg_test))
            
            # if a local epoch is completed   
            if l_epoch_check:
                l_epoch_check = False
                
                # Store the last accuracy and loss
                acc_avg_test_all = acc_avg_test
                loss_avg_test_all = loss_avg_test
                        
                loss_test_collect_user.append(loss_avg_test_all)
                acc_test_collect_user.append(acc_avg_test_all)
                
            # if all users are served for one round ----------                    
            if fed_check:
                fed_check = False
                                
                acc_avg_all_user = sum(acc_test_collect_user)/len(acc_test_collect_user)
                loss_avg_all_user = sum(loss_test_collect_user)/len(loss_test_collect_user)
            
                loss_test_collect.append(loss_avg_all_user)
                acc_test_collect.append(acc_avg_all_user)
                acc_test_collect_user = []
                loss_test_collect_user= []
                              
                print("====================== SERVER V1==========================")
                print(' Train: Round {:3d}, Avg Accuracy {:.3f} | Avg Loss {:.3f}'.format(ell, acc_avg_all_user_train, loss_avg_all_user_train))
                print(' Test: Round {:3d}, Avg Accuracy {:.3f} | Avg Loss {:.3f}'.format(ell, acc_avg_all_user, loss_avg_all_user))
                # print("==========================================================")
         
    return 

#==============================================================================================================
#                                       Clients Side Program
#==============================================================================================================
class DatasetSplit(Dataset):
    def __init__(self, dataset, idxs):
        self.dataset = dataset
        self.idxs = list(idxs)

    def __len__(self):
        return len(self.idxs)

    def __getitem__(self, item):
        image, label = self.dataset[self.idxs[item]]
        return image, label

# Client-side functions associated with Training and Testing
class Client(object):
    def __init__(self, net_client_model, idx, LR_BASE, device, dataset_train = None, dataset_test = None, idxs = None, idxs_test = None):
        self.idx = idx
        self.device = device
        self.LR_BASE = LR_BASE
        self.local_ep = LOCAL_EPOCHS
        #self.selected_clients = []
        self.ldr_train = DataLoader(
            DatasetSplit(
                dataset_train, 
                idxs), 
            batch_size = BATCH_SIZE, 
            shuffle = True,
            num_workers=NUM_WORKERS,
            pin_memory=pin
        )
        self.ldr_test = DataLoader(
            DatasetSplit(
                dataset_test, 
                idxs_test), 
            batch_size = BATCH_SIZE, 
            shuffle = True,
            num_workers=NUM_WORKERS,
            pin_memory=pin
        )
        

    def train(self, net):
        net.train()
        optimizer_client = torch.optim.SGD(
            net.parameters(),
            lr = self.LR_BASE,
            momentum=MOMENTUM,
            weight_decay=WEIGHT_DECAY
        ) 
        
        for iter in range(self.local_ep):
            len_batch = len(self.ldr_train)
            for batch_idx, (images, labels) in enumerate(self.ldr_train):
                images, labels = images.to(self.device), labels.to(self.device)
                optimizer_client.zero_grad()
                #---------forward prop-------------
                fx = net(images)
                client_fx = fx.clone().detach().requires_grad_(True)
                
                # Sending activations to server and receiving gradients from server
                dfx = train_server(client_fx, labels, iter, self.local_ep, self.idx, len_batch)
                
                #--------backward prop -------------
                fx.backward(dfx)
                optimizer_client.step()
                            
            
            #prRed('Client{} Train => Epoch: {}'.format(self.idx, ell))
           
        return net.state_dict() 
    
    def evaluate(self, net, ell):
        net.eval()
           
        with torch.no_grad():
            len_batch = len(self.ldr_test)
            for batch_idx, (images, labels) in enumerate(self.ldr_test):
                images, labels = images.to(self.device), labels.to(self.device)
                #---------forward prop-------------
                fx = net(images)
                
                # Sending activations to server 
                evaluate_server(fx, labels, self.idx, len_batch, ell)
            
            #prRed('Client{} Test => Epoch: {}'.format(self.idx, ell))
            
        return          

#=====================================================================================================
# dataset_iid() will create a dictionary to collect the indices of the data samples randomly for each client
def dataset_iid(dataset, NUM_CLIENTS):
    
    num_items = int(len(dataset)/NUM_CLIENTS)
    dict_users, all_idxs = {}, [i for i in range(len(dataset))]
    for i in range(NUM_CLIENTS):
        dict_users[i] = set(np.random.choice(all_idxs, num_items, replace = False))
        all_idxs = list(set(all_idxs) - dict_users[i])
    return dict_users   

# Non-IID partition using Dirichlet distribution
def dataset_noniid_dirichlet(dataset, NUM_CLIENTS, alpha=0.1, seed=SEED):
    """
    Return dict_users: {client_id -> set(sample_indices)} using Dirichlet(α).
    Lower α → higher imbalance across clients.
    """
    rng = np.random.default_rng(seed)
    # CIFAR-100 and other torchvision datasets store labels in .targets
    labels = np.array(dataset.targets if hasattr(dataset, 'targets') else dataset.df['target'].values)
    n_classes = len(np.unique(labels))
    dict_users = {i: set() for i in range(NUM_CLIENTS)}

    for c in range(n_classes):
        idxs = np.where(labels == c)[0]
        rng.shuffle(idxs)

        # Draw class proportions for each client
        proportions = rng.dirichlet([alpha] * NUM_CLIENTS)

        # Compute index splits
        cuts = (np.cumsum(proportions) * len(idxs)).astype(int)[:-1]
        splits = np.split(idxs, cuts)

        for client_id, split in enumerate(splits):
            dict_users[client_id].update(split.tolist())

    return dict_users

#=============================================================================
#                         Data loading 
#============================================================================= 
from torchvision import datasets, transforms

# CIFAR-10/100 transforms
CIFAR_MEAN = {
    "CIFAR10":  [0.4914, 0.4822, 0.4465],
    "CIFAR100": [0.5071, 0.4867, 0.4408],
}[DATASET_NAME]
CIFAR_STD = {
    "CIFAR10":  [0.2470, 0.2435, 0.2616],
    "CIFAR100": [0.2675, 0.2565, 0.2761],
}[DATASET_NAME]
    

train_transforms = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(32, padding=4),
    transforms.ToTensor(),
    transforms.Normalize(CIFAR_MEAN, CIFAR_STD)
])

test_transforms = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(CIFAR_MEAN, CIFAR_STD)
])

# Download CIFAR datasets
if DATASET_NAME == "CIFAR10":
    dataset_train = datasets.CIFAR10(root=DATA_ROOT, train=True,  download=True, transform=train_transforms)
    dataset_test  = datasets.CIFAR10(root=DATA_ROOT, train=False, download=True, transform=test_transforms)
    NUM_CLASSES = 10
else:
    dataset_train = datasets.CIFAR100(root=DATA_ROOT, train=True,  download=True, transform=train_transforms)
    dataset_test  = datasets.CIFAR100(root=DATA_ROOT, train=False, download=True, transform=test_transforms)
    NUM_CLASSES = 100



print("Train samples:", len(dataset_train), " Test samples:", len(dataset_test))
print("Example train label:", dataset_train.targets[0])

#=============================================================================
#                         Forgetting metric setup 
#============================================================================= 

from collections import defaultdict

# Treat each global round as a window (quick baseline).
# If you want true distribution shifts, predefine your own windows and fill `val_loaders`.
T = EPOCHS
class DatasetSplit(Dataset):  # (you already have this in both scripts; keep just one copy)
    def __init__(self, dataset, idxs):
        self.dataset, self.idxs = dataset, list(idxs)
    def __len__(self): return len(self.idxs)
    def __getitem__(self, i): return self.dataset[self.idxs[i]]

val_loaders = {}
# Deterministic, disjoint slices of the test set: window t gets items t, t+T, t+2T, ...
rng_idx = np.arange(len(dataset_test))
for t in range(T):
    idxs = rng_idx[t::T]
    val_loaders[t] = DataLoader(
        DatasetSplit(
            dataset_test, 
            idxs),
        batch_size=BATCH_SIZE, 
        shuffle=False, 
        drop_last=False,
        num_workers=NUM_WORKERS,
        pin_memory=pin
    )

best_loss_per_window = defaultdict(lambda: float('inf'))  # stores min historical loss per window
forgetting_log = []  # per round dicts: {"round": t, "mean_forgetting": x, "per_window": {...}}
# ============================================================================

def _eval_loss_on_loader(model_client, model_server, loader, device, criterion):
    """Evaluate mean loss on a loader using split models."""
    # Handle DataParallel transparently
    mc = model_client.module if isinstance(model_client, nn.DataParallel) else model_client
    ms = model_server.module if isinstance(model_server, nn.DataParallel) else model_server
    mc.eval(); ms.eval()
    loss_sum, n = 0.0, 0
    with torch.no_grad():
        for images, labels in loader:
            images, labels = images.to(device), labels.to(device)
            fx = mc(images)
            logits = ms(fx)
            loss = criterion(logits, labels)
            bs = labels.size(0)
            loss_sum += loss.item() * bs
            n += bs
    return loss_sum / max(1, n)


#=============================================================================
#                         Dirichlet non-IID partition
#=============================================================================
dict_users = dataset_noniid_dirichlet(dataset_train, NUM_CLIENTS, alpha=ALPHA, seed=SEED)
dict_users_test = dataset_iid(dataset_test, NUM_CLIENTS)  # keep test IID


#------------ Training And Testing -----------------
net_glob_client.train()
#copy weights
w_glob_client = net_glob_client.state_dict()

#=============================================================================

# Federation takes place after certain local epochs in train() client-side
# this epoch is global epoch, also known as rounds
for iter in range(EPOCHS):
    # ---- START TIMER (train + test + FedAvg only) ----
    _sync_cuda()
    t_start = time.perf_counter()
    # --------------------------------------------------

    m = max(int(FRAC * NUM_CLIENTS), 1)
    idxs_users = np.random.choice(range(NUM_CLIENTS), m, replace=False)
    w_locals_client = []

    for idx in idxs_users:
        local = Client(net_glob_client, idx, LR_BASE, device,
                       dataset_train=dataset_train, dataset_test=dataset_test,
                       idxs=dict_users[idx], idxs_test=dict_users_test[idx])
        # Training
        w_client = local.train(net=copy.deepcopy(net_glob_client).to(device))
        w_locals_client.append(copy.deepcopy(w_client))

        # Testing
        local.evaluate(net=copy.deepcopy(net_glob_client).to(device), ell=iter)

    # ---------- Federation at client side ----------
    print("------------------------------------------------------------")
    print("------ Fed Server: Federation process at Client-Side -------")
    print("------------------------------------------------------------")
    w_glob_client = FedAvg(w_locals_client)
    net_glob_client.load_state_dict(w_glob_client)

    # ---- STOP TIMER & LOG ----
    _sync_cuda()
    dt = time.perf_counter() - t_start
    round_time_collect.append(dt)
    # ---------------------------

    # === Forgetting update at end of round `iter` (post-FedAvg, not timed) ===
    t = iter  # current window id

    # 1) Update the "best so far" for the CURRENT window using the current model
    L_cur_t = _eval_loss_on_loader(net_glob_client, net_glob_server,
                                   val_loaders[t], device, criterion)
    best_loss_per_window[t] = min(best_loss_per_window[t], L_cur_t)

    # 2) Compute forgetting on all PAST windows t_prev < t
    per_win_fgt = {}
    for t_prev in range(t):
        L_now = _eval_loss_on_loader(net_glob_client, net_glob_server,
                                     val_loaders[t_prev], device, criterion)
        Fgt = L_now - best_loss_per_window[t_prev]
        per_win_fgt[t_prev] = Fgt

    mean_fgt = float(np.mean(list(per_win_fgt.values()))) if per_win_fgt else 0.0
    forgetting_log.append({"round": t, "mean_forgetting": mean_fgt, "per_window": per_win_fgt})
    print(f"Forgetting : Round {t}, mean_forgetting : {mean_fgt:.3f}")
    print("==========================================================")

    
#===================================================================================     

print("Training and Evaluation completed!")    

#===============================================================================
# Save output data to .excel file (we use for comparision plots)
n = min(len(acc_train_collect), len(acc_test_collect), len(round_time_collect), len(forgetting_log))
round_process = [i for i in range(1, len(acc_train_collect)+1)]
mean_fgt_series = [d["mean_forgetting"] for d in forgetting_log[:n]]

df = DataFrame({
    'round': round_process,
    'acc_train': acc_train_collect[:n],
    'acc_test':  acc_test_collect[:n],
    'round_time_sec': round_time_collect[:n],
    'mean_FgT_loss': mean_fgt_series,
})


# write CSV — easier for scripting/comparison tools
file_name_csv = program + ".csv"
df.to_csv(file_name_csv, index=False)

print("Saved:", file_name_csv)

#=============================================================================
#                         Program Completed
#=============================================================================
# Out:
# ---------SFLV2 - CIFAR-100 α=0.1 - LATE-Cut (6 + AvgPool)----------
# NVIDIA H200
# ResNet18_client_side(
#   (layer1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (layer2): Sequential(
#     (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (layer3): Sequential(
#     (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (layer4): Sequential(
#     (0): Baseblock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dim_change): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2))
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Baseblock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer5): Sequential(
#     (0): Baseblock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dim_change): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2))
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Baseblock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer6): Sequential(
#     (0): Baseblock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dim_change): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2))
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Baseblock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
# )
# ResNet18_server_side(
#   (fc): Linear(in_features=512, out_features=100, bias=True)
# )
# Train samples: 50000  Test samples: 10000
# Example train label: 19
#  Client3 Train => Local Epoch: 0 	Acc: 12.005 	Loss: 3.8134
#  Client3 Train => Local Epoch: 1 	Acc: 19.245 	Loss: 3.1409
#  Client3 Train => Local Epoch: 2 	Acc: 27.266 	Loss: 2.8368
#  Client3 Train => Local Epoch: 3 	Acc: 31.146 	Loss: 2.5686
#  Client3 Train => Local Epoch: 4 	Acc: 34.583 	Loss: 2.4096
#  Client3 Test =>                   	Acc: 0.899 	Loss: 6.5935
#  Client1 Train => Local Epoch: 0 	Acc: 10.153 	Loss: 4.3311
#  Client1 Train => Local Epoch: 1 	Acc: 26.476 	Loss: 3.0037
#  Client1 Train => Local Epoch: 2 	Acc: 30.988 	Loss: 2.6709
#  Client1 Train => Local Epoch: 3 	Acc: 34.642 	Loss: 2.4767
#  Client1 Train => Local Epoch: 4 	Acc: 37.738 	Loss: 2.3406
#  Client1 Test =>                   	Acc: 0.586 	Loss: 5.9418
#  Client2 Train => Local Epoch: 0 	Acc: 15.585 	Loss: 3.7655
#  Client2 Train => Local Epoch: 1 	Acc: 33.594 	Loss: 2.6197
#  Client2 Train => Local Epoch: 2 	Acc: 41.753 	Loss: 2.3046
#  Client2 Train => Local Epoch: 3 	Acc: 45.492 	Loss: 2.1208
#  Client2 Train => Local Epoch: 4 	Acc: 48.186 	Loss: 1.9848
#  Client2 Test =>                   	Acc: 1.222 	Loss: 5.7577
#  Client0 Train => Local Epoch: 0 	Acc: 11.911 	Loss: 4.1685
#  Client0 Train => Local Epoch: 1 	Acc: 28.134 	Loss: 2.7660
#  Client0 Train => Local Epoch: 2 	Acc: 36.364 	Loss: 2.3773
#  Client0 Train => Local Epoch: 3 	Acc: 40.823 	Loss: 2.1547
#  Client0 Train => Local Epoch: 4 	Acc: 44.034 	Loss: 2.0170
#  Client0 Test =>                   	Acc: 0.987 	Loss: 5.8068
#  Client8 Train => Local Epoch: 0 	Acc: 11.182 	Loss: 4.2719
#  Client8 Train => Local Epoch: 1 	Acc: 21.308 	Loss: 3.0565
#  Client8 Train => Local Epoch: 2 	Acc: 25.598 	Loss: 2.7296
#  Client8 Train => Local Epoch: 3 	Acc: 28.627 	Loss: 2.5817
#  Client8 Train => Local Epoch: 4 	Acc: 32.681 	Loss: 2.4359
#  Client8 Test =>                   	Acc: 1.310 	Loss: 5.8699
#  Client7 Train => Local Epoch: 0 	Acc: 9.861 	Loss: 4.3143
#  Client7 Train => Local Epoch: 1 	Acc: 24.827 	Loss: 3.0021
#  Client7 Train => Local Epoch: 2 	Acc: 29.140 	Loss: 2.7009
#  Client7 Train => Local Epoch: 3 	Acc: 31.701 	Loss: 2.5159
#  Client7 Train => Local Epoch: 4 	Acc: 34.153 	Loss: 2.3917
#  Client7 Test =>                   	Acc: 0.704 	Loss: 6.2145
#  Client6 Train => Local Epoch: 0 	Acc: 11.355 	Loss: 4.3311
#  Client6 Train => Local Epoch: 1 	Acc: 25.286 	Loss: 2.9855
#  Client6 Train => Local Epoch: 2 	Acc: 31.354 	Loss: 2.6043
#  Client6 Train => Local Epoch: 3 	Acc: 36.166 	Loss: 2.4040
#  Client6 Train => Local Epoch: 4 	Acc: 40.736 	Loss: 2.2226
#  Client6 Test =>                   	Acc: 0.997 	Loss: 5.7208
#  Client9 Train => Local Epoch: 0 	Acc: 13.977 	Loss: 4.0978
#  Client9 Train => Local Epoch: 1 	Acc: 29.065 	Loss: 2.8023
#  Client9 Train => Local Epoch: 2 	Acc: 32.183 	Loss: 2.5139
#  Client9 Train => Local Epoch: 3 	Acc: 36.274 	Loss: 2.3412
#  Client9 Train => Local Epoch: 4 	Acc: 38.407 	Loss: 2.2399
#  Client9 Test =>                   	Acc: 0.586 	Loss: 5.7745
#  Client5 Train => Local Epoch: 0 	Acc: 9.834 	Loss: 4.4459
#  Client5 Train => Local Epoch: 1 	Acc: 24.662 	Loss: 2.9752
#  Client5 Train => Local Epoch: 2 	Acc: 29.369 	Loss: 2.6331
#  Client5 Train => Local Epoch: 3 	Acc: 33.487 	Loss: 2.4208
#  Client5 Train => Local Epoch: 4 	Acc: 35.689 	Loss: 2.2748
#  Client5 Test =>                   	Acc: 0.791 	Loss: 6.0933
#  Client4 Train => Local Epoch: 0 	Acc: 11.012 	Loss: 4.2784
#  Client4 Train => Local Epoch: 1 	Acc: 24.339 	Loss: 3.1342
#  Client4 Train => Local Epoch: 2 	Acc: 30.349 	Loss: 2.7703
#  Client4 Train => Local Epoch: 3 	Acc: 34.065 	Loss: 2.5529
#  Client4 Train => Local Epoch: 4 	Acc: 36.406 	Loss: 2.4168
#  Client4 Test =>                   	Acc: 1.680 	Loss: 5.7106
# ====================== SERVER V1==========================
#  Train: Round   0, Avg Accuracy 38.261 | Avg Loss 2.273
#  Test: Round   0, Avg Accuracy 0.976 | Avg Loss 5.948
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Forgetting : Round 0, mean_forgetting : 0.000
# ==========================================================
#  Client3 Train => Local Epoch: 0 	Acc: 19.062 	Loss: 3.5808
#  Client3 Train => Local Epoch: 1 	Acc: 30.807 	Loss: 2.6450
#  Client3 Train => Local Epoch: 2 	Acc: 38.516 	Loss: 2.3323
#  Client3 Train => Local Epoch: 3 	Acc: 38.333 	Loss: 2.2755
#  Client3 Train => Local Epoch: 4 	Acc: 41.250 	Loss: 2.1023
#  Client3 Test =>                   	Acc: 1.094 	Loss: 5.3644
#  Client4 Train => Local Epoch: 0 	Acc: 22.653 	Loss: 3.1741
#  Client4 Train => Local Epoch: 1 	Acc: 34.540 	Loss: 2.5422
#  Client4 Train => Local Epoch: 2 	Acc: 37.658 	Loss: 2.3592
#  Client4 Train => Local Epoch: 3 	Acc: 40.407 	Loss: 2.2384
#  Client4 Train => Local Epoch: 4 	Acc: 41.812 	Loss: 2.1626
#  Client4 Test =>                   	Acc: 1.886 	Loss: 5.1734
#  Client2 Train => Local Epoch: 0 	Acc: 21.899 	Loss: 4.0922
#  Client2 Train => Local Epoch: 1 	Acc: 39.632 	Loss: 2.6298
#  Client2 Train => Local Epoch: 2 	Acc: 42.985 	Loss: 2.2930
#  Client2 Train => Local Epoch: 3 	Acc: 45.875 	Loss: 2.1146
#  Client2 Train => Local Epoch: 4 	Acc: 47.983 	Loss: 1.9948
#  Client2 Test =>                   	Acc: 1.680 	Loss: 4.9726
#  Client9 Train => Local Epoch: 0 	Acc: 23.217 	Loss: 3.3320
#  Client9 Train => Local Epoch: 1 	Acc: 34.252 	Loss: 2.4730
#  Client9 Train => Local Epoch: 2 	Acc: 37.201 	Loss: 2.2794
#  Client9 Train => Local Epoch: 3 	Acc: 40.709 	Loss: 2.1701
#  Client9 Train => Local Epoch: 4 	Acc: 42.001 	Loss: 2.0897
#  Client9 Test =>                   	Acc: 1.583 	Loss: 5.0068
#  Client5 Train => Local Epoch: 0 	Acc: 16.630 	Loss: 3.7893
#  Client5 Train => Local Epoch: 1 	Acc: 31.588 	Loss: 2.5706
#  Client5 Train => Local Epoch: 2 	Acc: 35.154 	Loss: 2.3247
#  Client5 Train => Local Epoch: 3 	Acc: 37.935 	Loss: 2.1832
#  Client5 Train => Local Epoch: 4 	Acc: 40.471 	Loss: 2.0829
#  Client5 Test =>                   	Acc: 1.994 	Loss: 5.1524
#  Client1 Train => Local Epoch: 0 	Acc: 18.532 	Loss: 3.7974
#  Client1 Train => Local Epoch: 1 	Acc: 32.607 	Loss: 2.6406
#  Client1 Train => Local Epoch: 2 	Acc: 36.576 	Loss: 2.3863
#  Client1 Train => Local Epoch: 3 	Acc: 39.572 	Loss: 2.2447
#  Client1 Train => Local Epoch: 4 	Acc: 41.652 	Loss: 2.1438
#  Client1 Test =>                   	Acc: 1.192 	Loss: 5.0666
#  Client8 Train => Local Epoch: 0 	Acc: 15.844 	Loss: 3.8371
#  Client8 Train => Local Epoch: 1 	Acc: 27.480 	Loss: 2.6926
#  Client8 Train => Local Epoch: 2 	Acc: 30.628 	Loss: 2.4845
#  Client8 Train => Local Epoch: 3 	Acc: 33.938 	Loss: 2.3442
#  Client8 Train => Local Epoch: 4 	Acc: 36.308 	Loss: 2.2745
#  Client8 Test =>                   	Acc: 0.889 	Loss: 5.1760
#  Client0 Train => Local Epoch: 0 	Acc: 21.530 	Loss: 3.5881
#  Client0 Train => Local Epoch: 1 	Acc: 38.103 	Loss: 2.3326
#  Client0 Train => Local Epoch: 2 	Acc: 42.834 	Loss: 2.0865
#  Client0 Train => Local Epoch: 3 	Acc: 45.153 	Loss: 1.9665
#  Client0 Train => Local Epoch: 4 	Acc: 48.726 	Loss: 1.8531
#  Client0 Test =>                   	Acc: 1.788 	Loss: 4.8819
#  Client6 Train => Local Epoch: 0 	Acc: 19.641 	Loss: 3.5246
#  Client6 Train => Local Epoch: 1 	Acc: 34.735 	Loss: 2.4945
#  Client6 Train => Local Epoch: 2 	Acc: 40.698 	Loss: 2.2258
#  Client6 Train => Local Epoch: 3 	Acc: 43.861 	Loss: 2.0933
#  Client6 Train => Local Epoch: 4 	Acc: 47.156 	Loss: 1.9780
#  Client6 Test =>                   	Acc: 2.590 	Loss: 4.9358
#  Client7 Train => Local Epoch: 0 	Acc: 18.460 	Loss: 3.8601
#  Client7 Train => Local Epoch: 1 	Acc: 30.752 	Loss: 2.7026
#  Client7 Train => Local Epoch: 2 	Acc: 32.870 	Loss: 2.4549
#  Client7 Train => Local Epoch: 3 	Acc: 34.435 	Loss: 2.3292
#  Client7 Train => Local Epoch: 4 	Acc: 37.485 	Loss: 2.2199
#  Client7 Test =>                   	Acc: 1.788 	Loss: 5.0394
# ====================== SERVER V1==========================
#  Train: Round   1, Avg Accuracy 42.484 | Avg Loss 2.090
#  Test: Round   1, Avg Accuracy 1.648 | Avg Loss 5.077
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Forgetting : Round 1, mean_forgetting : -0.253
# ==========================================================
#  Client0 Train => Local Epoch: 0 	Acc: 32.991 	Loss: 2.7060
#  Client0 Train => Local Epoch: 1 	Acc: 44.502 	Loss: 2.0573
#  Client0 Train => Local Epoch: 2 	Acc: 47.378 	Loss: 1.8838
#  Client0 Train => Local Epoch: 3 	Acc: 50.153 	Loss: 1.7772
#  Client0 Train => Local Epoch: 4 	Acc: 51.799 	Loss: 1.6891
#  Client0 Test =>                   	Acc: 5.405 	Loss: 4.8379
#  Client2 Train => Local Epoch: 0 	Acc: 31.087 	Loss: 3.1438
#  Client2 Train => Local Epoch: 1 	Acc: 46.209 	Loss: 2.1638
#  Client2 Train => Local Epoch: 2 	Acc: 49.502 	Loss: 1.9397
#  Client2 Train => Local Epoch: 3 	Acc: 51.363 	Loss: 1.8291
#  Client2 Train => Local Epoch: 4 	Acc: 53.512 	Loss: 1.7354
#  Client2 Test =>                   	Acc: 4.290 	Loss: 4.8034
#  Client5 Train => Local Epoch: 0 	Acc: 21.301 	Loss: 3.5575
#  Client5 Train => Local Epoch: 1 	Acc: 35.539 	Loss: 2.3860
#  Client5 Train => Local Epoch: 2 	Acc: 39.028 	Loss: 2.1671
#  Client5 Train => Local Epoch: 3 	Acc: 42.111 	Loss: 2.0417
#  Client5 Train => Local Epoch: 4 	Acc: 44.241 	Loss: 1.9326
#  Client5 Test =>                   	Acc: 4.701 	Loss: 4.6457
#  Client7 Train => Local Epoch: 0 	Acc: 25.175 	Loss: 3.2655
#  Client7 Train => Local Epoch: 1 	Acc: 33.464 	Loss: 2.4681
#  Client7 Train => Local Epoch: 2 	Acc: 37.479 	Loss: 2.2809
#  Client7 Train => Local Epoch: 3 	Acc: 38.890 	Loss: 2.1865
#  Client7 Train => Local Epoch: 4 	Acc: 40.748 	Loss: 2.0916
#  Client7 Test =>                   	Acc: 3.879 	Loss: 4.8665
#  Client1 Train => Local Epoch: 0 	Acc: 24.199 	Loss: 3.3356
#  Client1 Train => Local Epoch: 1 	Acc: 37.287 	Loss: 2.3991
#  Client1 Train => Local Epoch: 2 	Acc: 40.648 	Loss: 2.1941
#  Client1 Train => Local Epoch: 3 	Acc: 42.985 	Loss: 2.0807
#  Client1 Train => Local Epoch: 4 	Acc: 45.582 	Loss: 1.9793
#  Client1 Test =>                   	Acc: 4.368 	Loss: 4.7427
#  Client8 Train => Local Epoch: 0 	Acc: 21.472 	Loss: 3.3684
#  Client8 Train => Local Epoch: 1 	Acc: 32.331 	Loss: 2.4475
#  Client8 Train => Local Epoch: 2 	Acc: 35.278 	Loss: 2.3137
#  Client8 Train => Local Epoch: 3 	Acc: 37.487 	Loss: 2.2036
#  Client8 Train => Local Epoch: 4 	Acc: 38.689 	Loss: 2.1391
#  Client8 Test =>                   	Acc: 4.408 	Loss: 4.7997
#  Client9 Train => Local Epoch: 0 	Acc: 27.878 	Loss: 3.2475
#  Client9 Train => Local Epoch: 1 	Acc: 38.670 	Loss: 2.3097
#  Client9 Train => Local Epoch: 2 	Acc: 40.758 	Loss: 2.1558
#  Client9 Train => Local Epoch: 3 	Acc: 43.263 	Loss: 2.0519
#  Client9 Train => Local Epoch: 4 	Acc: 45.291 	Loss: 1.9599
#  Client9 Test =>                   	Acc: 5.543 	Loss: 4.5992
#  Client6 Train => Local Epoch: 0 	Acc: 27.460 	Loss: 3.1054
#  Client6 Train => Local Epoch: 1 	Acc: 40.684 	Loss: 2.2377
#  Client6 Train => Local Epoch: 2 	Acc: 44.666 	Loss: 2.0520
#  Client6 Train => Local Epoch: 3 	Acc: 49.017 	Loss: 1.8987
#  Client6 Train => Local Epoch: 4 	Acc: 51.351 	Loss: 1.7880
#  Client6 Test =>                   	Acc: 4.613 	Loss: 4.5987
#  Client3 Train => Local Epoch: 0 	Acc: 23.411 	Loss: 3.5420
#  Client3 Train => Local Epoch: 1 	Acc: 39.818 	Loss: 2.3878
#  Client3 Train => Local Epoch: 2 	Acc: 35.938 	Loss: 2.3691
#  Client3 Train => Local Epoch: 3 	Acc: 38.385 	Loss: 2.2256
#  Client3 Train => Local Epoch: 4 	Acc: 41.276 	Loss: 2.1180
#  Client3 Test =>                   	Acc: 3.236 	Loss: 4.6549
#  Client4 Train => Local Epoch: 0 	Acc: 27.231 	Loss: 3.1573
#  Client4 Train => Local Epoch: 1 	Acc: 38.224 	Loss: 2.3801
#  Client4 Train => Local Epoch: 2 	Acc: 41.540 	Loss: 2.2027
#  Client4 Train => Local Epoch: 3 	Acc: 43.311 	Loss: 2.1041
#  Client4 Train => Local Epoch: 4 	Acc: 46.291 	Loss: 1.9942
#  Client4 Test =>                   	Acc: 6.351 	Loss: 4.5203
# ====================== SERVER V1==========================
#  Train: Round   2, Avg Accuracy 45.878 | Avg Loss 1.943
#  Test: Round   2, Avg Accuracy 4.679 | Avg Loss 4.707
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Forgetting : Round 2, mean_forgetting : -0.560
# ==========================================================
#  Client5 Train => Local Epoch: 0 	Acc: 25.077 	Loss: 3.1490
#  Client5 Train => Local Epoch: 1 	Acc: 40.269 	Loss: 2.1569
#  Client5 Train => Local Epoch: 2 	Acc: 43.338 	Loss: 1.9703
#  Client5 Train => Local Epoch: 3 	Acc: 47.115 	Loss: 1.8616
#  Client5 Train => Local Epoch: 4 	Acc: 48.625 	Loss: 1.7635
#  Client5 Test =>                   	Acc: 5.462 	Loss: 4.5795
#  Client4 Train => Local Epoch: 0 	Acc: 35.533 	Loss: 2.6158
#  Client4 Train => Local Epoch: 1 	Acc: 42.583 	Loss: 2.1625
#  Client4 Train => Local Epoch: 2 	Acc: 45.080 	Loss: 2.0353
#  Client4 Train => Local Epoch: 3 	Acc: 47.442 	Loss: 1.9415
#  Client4 Train => Local Epoch: 4 	Acc: 48.998 	Loss: 1.8583
#  Client4 Test =>                   	Acc: 5.826 	Loss: 4.6442
#  Client7 Train => Local Epoch: 0 	Acc: 25.847 	Loss: 3.3519
#  Client7 Train => Local Epoch: 1 	Acc: 36.834 	Loss: 2.3284
#  Client7 Train => Local Epoch: 2 	Acc: 39.752 	Loss: 2.1470
#  Client7 Train => Local Epoch: 3 	Acc: 41.537 	Loss: 2.0621
#  Client7 Train => Local Epoch: 4 	Acc: 42.006 	Loss: 2.0154
#  Client7 Test =>                   	Acc: 5.102 	Loss: 4.6132
#  Client1 Train => Local Epoch: 0 	Acc: 28.056 	Loss: 3.3517
#  Client1 Train => Local Epoch: 1 	Acc: 40.658 	Loss: 2.2925
#  Client1 Train => Local Epoch: 2 	Acc: 44.562 	Loss: 2.0823
#  Client1 Train => Local Epoch: 3 	Acc: 46.689 	Loss: 1.9549
#  Client1 Train => Local Epoch: 4 	Acc: 49.164 	Loss: 1.8631
#  Client1 Test =>                   	Acc: 5.893 	Loss: 4.4761
#  Client3 Train => Local Epoch: 0 	Acc: 32.161 	Loss: 2.8932
#  Client3 Train => Local Epoch: 1 	Acc: 41.953 	Loss: 2.2148
#  Client3 Train => Local Epoch: 2 	Acc: 42.552 	Loss: 2.1057
#  Client3 Train => Local Epoch: 3 	Acc: 48.307 	Loss: 1.8902
#  Client3 Train => Local Epoch: 4 	Acc: 47.318 	Loss: 1.8626
#  Client3 Test =>                   	Acc: 3.401 	Loss: 4.7197
#  Client9 Train => Local Epoch: 0 	Acc: 31.052 	Loss: 2.8839
#  Client9 Train => Local Epoch: 1 	Acc: 41.382 	Loss: 2.1424
#  Client9 Train => Local Epoch: 2 	Acc: 44.645 	Loss: 1.9928
#  Client9 Train => Local Epoch: 3 	Acc: 47.117 	Loss: 1.8936
#  Client9 Train => Local Epoch: 4 	Acc: 49.483 	Loss: 1.8152
#  Client9 Test =>                   	Acc: 5.940 	Loss: 4.4680
#  Client8 Train => Local Epoch: 0 	Acc: 24.296 	Loss: 3.2215
#  Client8 Train => Local Epoch: 1 	Acc: 36.007 	Loss: 2.3386
#  Client8 Train => Local Epoch: 2 	Acc: 37.870 	Loss: 2.1978
#  Client8 Train => Local Epoch: 3 	Acc: 39.760 	Loss: 2.0893
#  Client8 Train => Local Epoch: 4 	Acc: 43.387 	Loss: 1.9982
#  Client8 Test =>                   	Acc: 6.176 	Loss: 4.4737
#  Client0 Train => Local Epoch: 0 	Acc: 35.294 	Loss: 2.7423
#  Client0 Train => Local Epoch: 1 	Acc: 47.215 	Loss: 1.9612
#  Client0 Train => Local Epoch: 2 	Acc: 50.468 	Loss: 1.7909
#  Client0 Train => Local Epoch: 3 	Acc: 52.378 	Loss: 1.6729
#  Client0 Train => Local Epoch: 4 	Acc: 54.171 	Loss: 1.5926
#  Client0 Test =>                   	Acc: 5.337 	Loss: 4.4546
#  Client2 Train => Local Epoch: 0 	Acc: 35.431 	Loss: 2.8278
#  Client2 Train => Local Epoch: 1 	Acc: 50.379 	Loss: 1.9376
#  Client2 Train => Local Epoch: 2 	Acc: 52.467 	Loss: 1.7995
#  Client2 Train => Local Epoch: 3 	Acc: 54.931 	Loss: 1.6759
#  Client2 Train => Local Epoch: 4 	Acc: 57.310 	Loss: 1.5703
#  Client2 Test =>                   	Acc: 5.836 	Loss: 4.5118
#  Client6 Train => Local Epoch: 0 	Acc: 32.214 	Loss: 2.8504
#  Client6 Train => Local Epoch: 1 	Acc: 46.137 	Loss: 2.0489
#  Client6 Train => Local Epoch: 2 	Acc: 49.826 	Loss: 1.8667
#  Client6 Train => Local Epoch: 3 	Acc: 52.973 	Loss: 1.7360
#  Client6 Train => Local Epoch: 4 	Acc: 55.210 	Loss: 1.6484
#  Client6 Test =>                   	Acc: 6.199 	Loss: 4.4171
# ====================== SERVER V1==========================
#  Train: Round   3, Avg Accuracy 49.567 | Avg Loss 1.799
#  Test: Round   3, Avg Accuracy 5.517 | Avg Loss 4.536
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Forgetting : Round 3, mean_forgetting : -0.617
# ==========================================================
#  Client2 Train => Local Epoch: 0 	Acc: 42.427 	Loss: 2.3342
#  Client2 Train => Local Epoch: 1 	Acc: 54.680 	Loss: 1.7660
#  Client2 Train => Local Epoch: 2 	Acc: 56.665 	Loss: 1.6103
#  Client2 Train => Local Epoch: 3 	Acc: 59.196 	Loss: 1.5059
#  Client2 Train => Local Epoch: 4 	Acc: 61.591 	Loss: 1.4213
#  Client2 Test =>                   	Acc: 7.563 	Loss: 4.3533
#  Client8 Train => Local Epoch: 0 	Acc: 29.039 	Loss: 2.9095
#  Client8 Train => Local Epoch: 1 	Acc: 38.039 	Loss: 2.2295
#  Client8 Train => Local Epoch: 2 	Acc: 41.751 	Loss: 2.0750
#  Client8 Train => Local Epoch: 3 	Acc: 43.090 	Loss: 1.9869
#  Client8 Train => Local Epoch: 4 	Acc: 46.096 	Loss: 1.8970
#  Client8 Test =>                   	Acc: 7.604 	Loss: 4.3279
#  Client5 Train => Local Epoch: 0 	Acc: 30.799 	Loss: 2.8637
#  Client5 Train => Local Epoch: 1 	Acc: 43.837 	Loss: 1.9970
#  Client5 Train => Local Epoch: 2 	Acc: 48.395 	Loss: 1.8118
#  Client5 Train => Local Epoch: 3 	Acc: 50.168 	Loss: 1.7210
#  Client5 Train => Local Epoch: 4 	Acc: 52.780 	Loss: 1.6314
#  Client5 Test =>                   	Acc: 6.950 	Loss: 4.2746
#  Client0 Train => Local Epoch: 0 	Acc: 38.420 	Loss: 2.5623
#  Client0 Train => Local Epoch: 1 	Acc: 49.932 	Loss: 1.8310
#  Client0 Train => Local Epoch: 2 	Acc: 54.132 	Loss: 1.6510
#  Client0 Train => Local Epoch: 3 	Acc: 55.662 	Loss: 1.5466
#  Client0 Train => Local Epoch: 4 	Acc: 57.463 	Loss: 1.4651
#  Client0 Test =>                   	Acc: 8.375 	Loss: 4.1801
#  Client6 Train => Local Epoch: 0 	Acc: 39.049 	Loss: 2.4869
#  Client6 Train => Local Epoch: 1 	Acc: 50.156 	Loss: 1.8681
#  Client6 Train => Local Epoch: 2 	Acc: 53.880 	Loss: 1.7132
#  Client6 Train => Local Epoch: 3 	Acc: 55.424 	Loss: 1.6267
#  Client6 Train => Local Epoch: 4 	Acc: 57.246 	Loss: 1.5449
#  Client6 Test =>                   	Acc: 8.462 	Loss: 4.2608
#  Client4 Train => Local Epoch: 0 	Acc: 34.227 	Loss: 2.9427
#  Client4 Train => Local Epoch: 1 	Acc: 44.403 	Loss: 2.1386
#  Client4 Train => Local Epoch: 2 	Acc: 47.625 	Loss: 1.9418
#  Client4 Train => Local Epoch: 3 	Acc: 49.404 	Loss: 1.8483
#  Client4 Train => Local Epoch: 4 	Acc: 51.640 	Loss: 1.7444
#  Client4 Test =>                   	Acc: 8.873 	Loss: 4.0114
#  Client3 Train => Local Epoch: 0 	Acc: 37.812 	Loss: 2.5621
#  Client3 Train => Local Epoch: 1 	Acc: 42.135 	Loss: 2.2387
#  Client3 Train => Local Epoch: 2 	Acc: 49.427 	Loss: 1.8471
#  Client3 Train => Local Epoch: 3 	Acc: 50.859 	Loss: 1.7957
#  Client3 Train => Local Epoch: 4 	Acc: 48.047 	Loss: 1.8669
#  Client3 Test =>                   	Acc: 7.260 	Loss: 4.2706
#  Client7 Train => Local Epoch: 0 	Acc: 29.537 	Loss: 3.0048
#  Client7 Train => Local Epoch: 1 	Acc: 40.862 	Loss: 2.1734
#  Client7 Train => Local Epoch: 2 	Acc: 45.414 	Loss: 1.9714
#  Client7 Train => Local Epoch: 3 	Acc: 48.266 	Loss: 1.8630
#  Client7 Train => Local Epoch: 4 	Acc: 47.685 	Loss: 1.8365
#  Client7 Test =>                   	Acc: 8.493 	Loss: 4.2271
#  Client9 Train => Local Epoch: 0 	Acc: 33.975 	Loss: 2.7228
#  Client9 Train => Local Epoch: 1 	Acc: 45.303 	Loss: 2.0265
#  Client9 Train => Local Epoch: 2 	Acc: 48.417 	Loss: 1.8647
#  Client9 Train => Local Epoch: 3 	Acc: 50.280 	Loss: 1.7801
#  Client9 Train => Local Epoch: 4 	Acc: 52.176 	Loss: 1.7066
#  Client9 Test =>                   	Acc: 8.816 	Loss: 4.0541
#  Client1 Train => Local Epoch: 0 	Acc: 31.878 	Loss: 2.9495
#  Client1 Train => Local Epoch: 1 	Acc: 45.252 	Loss: 2.1051
#  Client1 Train => Local Epoch: 2 	Acc: 48.540 	Loss: 1.9247
#  Client1 Train => Local Epoch: 3 	Acc: 51.535 	Loss: 1.7883
#  Client1 Train => Local Epoch: 4 	Acc: 52.344 	Loss: 1.7111
#  Client1 Test =>                   	Acc: 8.806 	Loss: 4.1077
# ====================== SERVER V1==========================
#  Train: Round   4, Avg Accuracy 52.707 | Avg Loss 1.683
#  Test: Round   4, Avg Accuracy 8.120 | Avg Loss 4.207
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Forgetting : Round 4, mean_forgetting : -0.779
# ==========================================================
#  Client7 Train => Local Epoch: 0 	Acc: 35.114 	Loss: 2.5640
#  Client7 Train => Local Epoch: 1 	Acc: 44.869 	Loss: 1.9761
#  Client7 Train => Local Epoch: 2 	Acc: 48.469 	Loss: 1.8209
#  Client7 Train => Local Epoch: 3 	Acc: 51.643 	Loss: 1.7330
#  Client7 Train => Local Epoch: 4 	Acc: 52.139 	Loss: 1.6721
#  Client7 Test =>                   	Acc: 7.947 	Loss: 4.1470
#  Client2 Train => Local Epoch: 0 	Acc: 40.338 	Loss: 2.5586
#  Client2 Train => Local Epoch: 1 	Acc: 56.374 	Loss: 1.7127
#  Client2 Train => Local Epoch: 2 	Acc: 58.869 	Loss: 1.5405
#  Client2 Train => Local Epoch: 3 	Acc: 61.384 	Loss: 1.4428
#  Client2 Train => Local Epoch: 4 	Acc: 62.588 	Loss: 1.3392
#  Client2 Test =>                   	Acc: 8.395 	Loss: 4.0737
#  Client6 Train => Local Epoch: 0 	Acc: 40.765 	Loss: 2.4979
#  Client6 Train => Local Epoch: 1 	Acc: 52.319 	Loss: 1.7896
#  Client6 Train => Local Epoch: 2 	Acc: 56.424 	Loss: 1.6345
#  Client6 Train => Local Epoch: 3 	Acc: 58.655 	Loss: 1.5337
#  Client6 Train => Local Epoch: 4 	Acc: 59.911 	Loss: 1.4659
#  Client6 Test =>                   	Acc: 14.561 	Loss: 3.7167
#  Client3 Train => Local Epoch: 0 	Acc: 39.089 	Loss: 2.4965
#  Client3 Train => Local Epoch: 1 	Acc: 52.188 	Loss: 1.8404
#  Client3 Train => Local Epoch: 2 	Acc: 50.964 	Loss: 1.8015
#  Client3 Train => Local Epoch: 3 	Acc: 51.536 	Loss: 1.7234
#  Client3 Train => Local Epoch: 4 	Acc: 53.307 	Loss: 1.6651
#  Client3 Test =>                   	Acc: 9.648 	Loss: 3.9439
#  Client8 Train => Local Epoch: 0 	Acc: 31.691 	Loss: 2.7769
#  Client8 Train => Local Epoch: 1 	Acc: 42.372 	Loss: 2.0886
#  Client8 Train => Local Epoch: 2 	Acc: 44.340 	Loss: 1.9505
#  Client8 Train => Local Epoch: 3 	Acc: 46.594 	Loss: 1.8655
#  Client8 Train => Local Epoch: 4 	Acc: 48.819 	Loss: 1.7859
#  Client8 Test =>                   	Acc: 12.567 	Loss: 3.9292
#  Client9 Train => Local Epoch: 0 	Acc: 36.856 	Loss: 2.5737
#  Client9 Train => Local Epoch: 1 	Acc: 48.394 	Loss: 1.8874
#  Client9 Train => Local Epoch: 2 	Acc: 51.752 	Loss: 1.7489
#  Client9 Train => Local Epoch: 3 	Acc: 53.837 	Loss: 1.6557
#  Client9 Train => Local Epoch: 4 	Acc: 55.749 	Loss: 1.5723
#  Client9 Test =>                   	Acc: 11.668 	Loss: 3.8176
#  Client4 Train => Local Epoch: 0 	Acc: 37.381 	Loss: 2.5959
#  Client4 Train => Local Epoch: 1 	Acc: 48.571 	Loss: 1.9511
#  Client4 Train => Local Epoch: 2 	Acc: 50.968 	Loss: 1.7981
#  Client4 Train => Local Epoch: 3 	Acc: 52.329 	Loss: 1.7084
#  Client4 Train => Local Epoch: 4 	Acc: 54.724 	Loss: 1.6248
#  Client4 Test =>                   	Acc: 11.806 	Loss: 3.7854
#  Client5 Train => Local Epoch: 0 	Acc: 34.430 	Loss: 2.6972
#  Client5 Train => Local Epoch: 1 	Acc: 48.125 	Loss: 1.8548
#  Client5 Train => Local Epoch: 2 	Acc: 51.113 	Loss: 1.6942
#  Client5 Train => Local Epoch: 3 	Acc: 54.454 	Loss: 1.5885
#  Client5 Train => Local Epoch: 4 	Acc: 56.078 	Loss: 1.4945
#  Client5 Test =>                   	Acc: 9.722 	Loss: 3.9156
#  Client0 Train => Local Epoch: 0 	Acc: 41.367 	Loss: 2.4015
#  Client0 Train => Local Epoch: 1 	Acc: 52.955 	Loss: 1.7132
#  Client0 Train => Local Epoch: 2 	Acc: 56.348 	Loss: 1.5553
#  Client0 Train => Local Epoch: 3 	Acc: 58.999 	Loss: 1.4389
#  Client0 Train => Local Epoch: 4 	Acc: 59.639 	Loss: 1.3815
#  Client0 Test =>                   	Acc: 11.719 	Loss: 3.7704
#  Client1 Train => Local Epoch: 0 	Acc: 35.075 	Loss: 2.7228
#  Client1 Train => Local Epoch: 1 	Acc: 48.241 	Loss: 1.9573
#  Client1 Train => Local Epoch: 2 	Acc: 51.439 	Loss: 1.7659
#  Client1 Train => Local Epoch: 3 	Acc: 54.124 	Loss: 1.6587
#  Client1 Train => Local Epoch: 4 	Acc: 55.904 	Loss: 1.5621
#  Client1 Test =>                   	Acc: 12.099 	Loss: 3.8816
# ====================== SERVER V1==========================
#  Train: Round   5, Avg Accuracy 55.886 | Avg Loss 1.556
#  Test: Round   5, Avg Accuracy 11.013 | Avg Loss 3.898
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Forgetting : Round 5, mean_forgetting : -0.764
# ==========================================================
#  Client6 Train => Local Epoch: 0 	Acc: 43.576 	Loss: 2.2704
#  Client6 Train => Local Epoch: 1 	Acc: 55.399 	Loss: 1.6689
#  Client6 Train => Local Epoch: 2 	Acc: 58.268 	Loss: 1.5162
#  Client6 Train => Local Epoch: 3 	Acc: 61.175 	Loss: 1.4165
#  Client6 Train => Local Epoch: 4 	Acc: 61.960 	Loss: 1.3529
#  Client6 Test =>                   	Acc: 13.547 	Loss: 3.6809
#  Client0 Train => Local Epoch: 0 	Acc: 47.845 	Loss: 1.9597
#  Client0 Train => Local Epoch: 1 	Acc: 57.229 	Loss: 1.5303
#  Client0 Train => Local Epoch: 2 	Acc: 59.067 	Loss: 1.4231
#  Client0 Train => Local Epoch: 3 	Acc: 61.383 	Loss: 1.3307
#  Client0 Train => Local Epoch: 4 	Acc: 62.911 	Loss: 1.2596
#  Client0 Test =>                   	Acc: 11.847 	Loss: 3.9209
#  Client3 Train => Local Epoch: 0 	Acc: 42.656 	Loss: 2.4682
#  Client3 Train => Local Epoch: 1 	Acc: 51.562 	Loss: 1.7914
#  Client3 Train => Local Epoch: 2 	Acc: 52.969 	Loss: 1.6618
#  Client3 Train => Local Epoch: 3 	Acc: 50.807 	Loss: 1.6612
#  Client3 Train => Local Epoch: 4 	Acc: 52.161 	Loss: 1.8084
#  Client3 Test =>                   	Acc: 9.900 	Loss: 3.9539
#  Client4 Train => Local Epoch: 0 	Acc: 40.007 	Loss: 2.4107
#  Client4 Train => Local Epoch: 1 	Acc: 50.456 	Loss: 1.8387
#  Client4 Train => Local Epoch: 2 	Acc: 54.621 	Loss: 1.6632
#  Client4 Train => Local Epoch: 3 	Acc: 56.032 	Loss: 1.5770
#  Client4 Train => Local Epoch: 4 	Acc: 58.304 	Loss: 1.4919
#  Client4 Test =>                   	Acc: 15.372 	Loss: 3.7103
#  Client5 Train => Local Epoch: 0 	Acc: 37.046 	Loss: 2.5097
#  Client5 Train => Local Epoch: 1 	Acc: 50.682 	Loss: 1.7524
#  Client5 Train => Local Epoch: 2 	Acc: 54.336 	Loss: 1.5891
#  Client5 Train => Local Epoch: 3 	Acc: 55.972 	Loss: 1.5049
#  Client5 Train => Local Epoch: 4 	Acc: 58.162 	Loss: 1.4286
#  Client5 Test =>                   	Acc: 12.315 	Loss: 3.8148
#  Client7 Train => Local Epoch: 0 	Acc: 35.603 	Loss: 2.7728
#  Client7 Train => Local Epoch: 1 	Acc: 47.291 	Loss: 1.9360
#  Client7 Train => Local Epoch: 2 	Acc: 51.081 	Loss: 1.7196
#  Client7 Train => Local Epoch: 3 	Acc: 51.783 	Loss: 1.7129
#  Client7 Train => Local Epoch: 4 	Acc: 54.098 	Loss: 1.6079
#  Client7 Test =>                   	Acc: 13.628 	Loss: 3.7411
#  Client9 Train => Local Epoch: 0 	Acc: 39.939 	Loss: 2.4249
#  Client9 Train => Local Epoch: 1 	Acc: 50.903 	Loss: 1.8059
#  Client9 Train => Local Epoch: 2 	Acc: 54.378 	Loss: 1.6499
#  Client9 Train => Local Epoch: 3 	Acc: 57.082 	Loss: 1.5411
#  Client9 Train => Local Epoch: 4 	Acc: 59.122 	Loss: 1.4566
#  Client9 Test =>                   	Acc: 14.746 	Loss: 3.6226
#  Client1 Train => Local Epoch: 0 	Acc: 38.756 	Loss: 2.5364
#  Client1 Train => Local Epoch: 1 	Acc: 50.696 	Loss: 1.8158
#  Client1 Train => Local Epoch: 2 	Acc: 54.180 	Loss: 1.6517
#  Client1 Train => Local Epoch: 3 	Acc: 56.776 	Loss: 1.5469
#  Client1 Train => Local Epoch: 4 	Acc: 59.025 	Loss: 1.4580
#  Client1 Test =>                   	Acc: 12.396 	Loss: 3.7442
#  Client8 Train => Local Epoch: 0 	Acc: 31.959 	Loss: 2.7423
#  Client8 Train => Local Epoch: 1 	Acc: 44.578 	Loss: 1.9836
#  Client8 Train => Local Epoch: 2 	Acc: 48.183 	Loss: 1.8466
#  Client8 Train => Local Epoch: 3 	Acc: 49.518 	Loss: 1.7433
#  Client8 Train => Local Epoch: 4 	Acc: 50.601 	Loss: 1.6796
#  Client8 Test =>                   	Acc: 12.813 	Loss: 3.7115
#  Client2 Train => Local Epoch: 0 	Acc: 45.914 	Loss: 2.3045
#  Client2 Train => Local Epoch: 1 	Acc: 58.789 	Loss: 1.5613
#  Client2 Train => Local Epoch: 2 	Acc: 61.217 	Loss: 1.4271
#  Client2 Train => Local Epoch: 3 	Acc: 63.995 	Loss: 1.3154
#  Client2 Train => Local Epoch: 4 	Acc: 65.637 	Loss: 1.2282
#  Client2 Test =>                   	Acc: 11.483 	Loss: 3.8199
# ====================== SERVER V1==========================
#  Train: Round   6, Avg Accuracy 58.198 | Avg Loss 1.477
#  Test: Round   6, Avg Accuracy 12.805 | Avg Loss 3.772
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Forgetting : Round 6, mean_forgetting : -0.617
# ==========================================================
#  Client4 Train => Local Epoch: 0 	Acc: 39.999 	Loss: 2.4054
#  Client4 Train => Local Epoch: 1 	Acc: 53.799 	Loss: 1.7148
#  Client4 Train => Local Epoch: 2 	Acc: 55.947 	Loss: 1.6016
#  Client4 Train => Local Epoch: 3 	Acc: 58.154 	Loss: 1.4941
#  Client4 Train => Local Epoch: 4 	Acc: 61.097 	Loss: 1.3874
#  Client4 Test =>                   	Acc: 18.366 	Loss: 3.4506
#  Client1 Train => Local Epoch: 0 	Acc: 43.506 	Loss: 2.2656
#  Client1 Train => Local Epoch: 1 	Acc: 54.055 	Loss: 1.6967
#  Client1 Train => Local Epoch: 2 	Acc: 57.184 	Loss: 1.5400
#  Client1 Train => Local Epoch: 3 	Acc: 60.131 	Loss: 1.4297
#  Client1 Train => Local Epoch: 4 	Acc: 60.752 	Loss: 1.3664
#  Client1 Test =>                   	Acc: 13.625 	Loss: 3.6668
#  Client2 Train => Local Epoch: 0 	Acc: 53.930 	Loss: 1.8310
#  Client2 Train => Local Epoch: 1 	Acc: 62.265 	Loss: 1.4057
#  Client2 Train => Local Epoch: 2 	Acc: 64.959 	Loss: 1.2776
#  Client2 Train => Local Epoch: 3 	Acc: 67.144 	Loss: 1.2064
#  Client2 Train => Local Epoch: 4 	Acc: 67.881 	Loss: 1.1202
#  Client2 Test =>                   	Acc: 11.638 	Loss: 3.9356
#  Client9 Train => Local Epoch: 0 	Acc: 41.840 	Loss: 2.2919
#  Client9 Train => Local Epoch: 1 	Acc: 53.686 	Loss: 1.6974
#  Client9 Train => Local Epoch: 2 	Acc: 57.007 	Loss: 1.5407
#  Client9 Train => Local Epoch: 3 	Acc: 58.626 	Loss: 1.4581
#  Client9 Train => Local Epoch: 4 	Acc: 60.831 	Loss: 1.3778
#  Client9 Test =>                   	Acc: 14.884 	Loss: 3.5967
#  Client5 Train => Local Epoch: 0 	Acc: 40.538 	Loss: 2.3566
#  Client5 Train => Local Epoch: 1 	Acc: 54.124 	Loss: 1.6461
#  Client5 Train => Local Epoch: 2 	Acc: 56.510 	Loss: 1.5152
#  Client5 Train => Local Epoch: 3 	Acc: 59.375 	Loss: 1.3974
#  Client5 Train => Local Epoch: 4 	Acc: 60.955 	Loss: 1.3232
#  Client5 Test =>                   	Acc: 13.039 	Loss: 3.6360
#  Client7 Train => Local Epoch: 0 	Acc: 37.482 	Loss: 2.5265
#  Client7 Train => Local Epoch: 1 	Acc: 48.916 	Loss: 1.8218
#  Client7 Train => Local Epoch: 2 	Acc: 51.659 	Loss: 1.7017
#  Client7 Train => Local Epoch: 3 	Acc: 56.187 	Loss: 1.5670
#  Client7 Train => Local Epoch: 4 	Acc: 58.178 	Loss: 1.4708
#  Client7 Test =>                   	Acc: 12.783 	Loss: 3.6343
#  Client6 Train => Local Epoch: 0 	Acc: 45.449 	Loss: 2.2422
#  Client6 Train => Local Epoch: 1 	Acc: 57.704 	Loss: 1.5867
#  Client6 Train => Local Epoch: 2 	Acc: 61.171 	Loss: 1.4447
#  Client6 Train => Local Epoch: 3 	Acc: 62.951 	Loss: 1.3460
#  Client6 Train => Local Epoch: 4 	Acc: 64.848 	Loss: 1.2676
#  Client6 Test =>                   	Acc: 19.518 	Loss: 3.3372
#  Client3 Train => Local Epoch: 0 	Acc: 47.865 	Loss: 2.1305
#  Client3 Train => Local Epoch: 1 	Acc: 56.146 	Loss: 1.6728
#  Client3 Train => Local Epoch: 2 	Acc: 52.057 	Loss: 1.7775
#  Client3 Train => Local Epoch: 3 	Acc: 54.297 	Loss: 1.6644
#  Client3 Train => Local Epoch: 4 	Acc: 53.516 	Loss: 1.6819
#  Client3 Test =>                   	Acc: 15.228 	Loss: 3.5276
#  Client0 Train => Local Epoch: 0 	Acc: 48.926 	Loss: 2.0629
#  Client0 Train => Local Epoch: 1 	Acc: 57.929 	Loss: 1.4938
#  Client0 Train => Local Epoch: 2 	Acc: 61.725 	Loss: 1.3275
#  Client0 Train => Local Epoch: 3 	Acc: 63.289 	Loss: 1.2491
#  Client0 Train => Local Epoch: 4 	Acc: 65.149 	Loss: 1.1910
#  Client0 Test =>                   	Acc: 16.426 	Loss: 3.4382
#  Client8 Train => Local Epoch: 0 	Acc: 36.427 	Loss: 2.5231
#  Client8 Train => Local Epoch: 1 	Acc: 47.665 	Loss: 1.8668
#  Client8 Train => Local Epoch: 2 	Acc: 50.240 	Loss: 1.7106
#  Client8 Train => Local Epoch: 3 	Acc: 52.018 	Loss: 1.6348
#  Client8 Train => Local Epoch: 4 	Acc: 54.574 	Loss: 1.5610
#  Client8 Test =>                   	Acc: 14.894 	Loss: 3.5941
# ====================== SERVER V1==========================
#  Train: Round   7, Avg Accuracy 60.778 | Avg Loss 1.375
#  Test: Round   7, Avg Accuracy 15.040 | Avg Loss 3.582
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Forgetting : Round 7, mean_forgetting : -0.743
# ==========================================================
#  Client8 Train => Local Epoch: 0 	Acc: 47.993 	Loss: 1.8565
#  Client8 Train => Local Epoch: 1 	Acc: 51.215 	Loss: 1.6790
#  Client8 Train => Local Epoch: 2 	Acc: 53.466 	Loss: 1.5736
#  Client8 Train => Local Epoch: 3 	Acc: 56.125 	Loss: 1.4901
#  Client8 Train => Local Epoch: 4 	Acc: 56.903 	Loss: 1.4318
#  Client8 Test =>                   	Acc: 14.005 	Loss: 3.9373
#  Client9 Train => Local Epoch: 0 	Acc: 43.162 	Loss: 2.3399
#  Client9 Train => Local Epoch: 1 	Acc: 56.237 	Loss: 1.5965
#  Client9 Train => Local Epoch: 2 	Acc: 59.453 	Loss: 1.4450
#  Client9 Train => Local Epoch: 3 	Acc: 61.653 	Loss: 1.3535
#  Client9 Train => Local Epoch: 4 	Acc: 63.483 	Loss: 1.2839
#  Client9 Test =>                   	Acc: 18.659 	Loss: 3.3852
#  Client5 Train => Local Epoch: 0 	Acc: 43.726 	Loss: 2.2151
#  Client5 Train => Local Epoch: 1 	Acc: 56.051 	Loss: 1.5560
#  Client5 Train => Local Epoch: 2 	Acc: 60.350 	Loss: 1.3975
#  Client5 Train => Local Epoch: 3 	Acc: 62.479 	Loss: 1.3007
#  Client5 Train => Local Epoch: 4 	Acc: 63.895 	Loss: 1.2339
#  Client5 Test =>                   	Acc: 15.332 	Loss: 3.5152
#  Client6 Train => Local Epoch: 0 	Acc: 49.355 	Loss: 2.0101
#  Client6 Train => Local Epoch: 1 	Acc: 60.855 	Loss: 1.4762
#  Client6 Train => Local Epoch: 2 	Acc: 62.711 	Loss: 1.3613
#  Client6 Train => Local Epoch: 3 	Acc: 64.637 	Loss: 1.2779
#  Client6 Train => Local Epoch: 4 	Acc: 67.248 	Loss: 1.1906
#  Client6 Test =>                   	Acc: 18.834 	Loss: 3.3230
#  Client7 Train => Local Epoch: 0 	Acc: 40.830 	Loss: 2.3912
#  Client7 Train => Local Epoch: 1 	Acc: 51.512 	Loss: 1.7450
#  Client7 Train => Local Epoch: 2 	Acc: 54.933 	Loss: 1.5999
#  Client7 Train => Local Epoch: 3 	Acc: 57.149 	Loss: 1.5115
#  Client7 Train => Local Epoch: 4 	Acc: 60.057 	Loss: 1.3755
#  Client7 Test =>                   	Acc: 18.295 	Loss: 3.3595
#  Client4 Train => Local Epoch: 0 	Acc: 46.343 	Loss: 2.1613
#  Client4 Train => Local Epoch: 1 	Acc: 55.922 	Loss: 1.6116
#  Client4 Train => Local Epoch: 2 	Acc: 58.977 	Loss: 1.4766
#  Client4 Train => Local Epoch: 3 	Acc: 61.403 	Loss: 1.3625
#  Client4 Train => Local Epoch: 4 	Acc: 62.742 	Loss: 1.3049
#  Client4 Test =>                   	Acc: 19.888 	Loss: 3.2650
#  Client1 Train => Local Epoch: 0 	Acc: 43.046 	Loss: 2.3465
#  Client1 Train => Local Epoch: 1 	Acc: 56.267 	Loss: 1.6322
#  Client1 Train => Local Epoch: 2 	Acc: 59.768 	Loss: 1.4545
#  Client1 Train => Local Epoch: 3 	Acc: 61.845 	Loss: 1.3502
#  Client1 Train => Local Epoch: 4 	Acc: 63.015 	Loss: 1.2635
#  Client1 Test =>                   	Acc: 17.551 	Loss: 3.3488
#  Client3 Train => Local Epoch: 0 	Acc: 49.740 	Loss: 2.0386
#  Client3 Train => Local Epoch: 1 	Acc: 48.438 	Loss: 2.0455
#  Client3 Train => Local Epoch: 2 	Acc: 56.120 	Loss: 1.6513
#  Client3 Train => Local Epoch: 3 	Acc: 57.188 	Loss: 1.5506
#  Client3 Train => Local Epoch: 4 	Acc: 58.464 	Loss: 1.4592
#  Client3 Test =>                   	Acc: 15.073 	Loss: 3.4753
#  Client2 Train => Local Epoch: 0 	Acc: 49.494 	Loss: 2.0948
#  Client2 Train => Local Epoch: 1 	Acc: 62.400 	Loss: 1.3942
#  Client2 Train => Local Epoch: 2 	Acc: 65.816 	Loss: 1.2302
#  Client2 Train => Local Epoch: 3 	Acc: 68.519 	Loss: 1.1256
#  Client2 Train => Local Epoch: 4 	Acc: 69.723 	Loss: 1.0777
#  Client2 Test =>                   	Acc: 15.645 	Loss: 3.4216
#  Client0 Train => Local Epoch: 0 	Acc: 51.624 	Loss: 1.8790
#  Client0 Train => Local Epoch: 1 	Acc: 61.625 	Loss: 1.3717
#  Client0 Train => Local Epoch: 2 	Acc: 63.679 	Loss: 1.2498
#  Client0 Train => Local Epoch: 3 	Acc: 65.997 	Loss: 1.1615
#  Client0 Train => Local Epoch: 4 	Acc: 68.042 	Loss: 1.0915
#  Client0 Test =>                   	Acc: 17.807 	Loss: 3.3894
# ====================== SERVER V1==========================
#  Train: Round   8, Avg Accuracy 63.357 | Avg Loss 1.271
#  Test: Round   8, Avg Accuracy 17.109 | Avg Loss 3.442
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Forgetting : Round 8, mean_forgetting : -0.840
# ==========================================================
#  Client2 Train => Local Epoch: 0 	Acc: 57.402 	Loss: 1.6036
#  Client2 Train => Local Epoch: 1 	Acc: 65.721 	Loss: 1.2210
#  Client2 Train => Local Epoch: 2 	Acc: 68.220 	Loss: 1.1008
#  Client2 Train => Local Epoch: 3 	Acc: 69.846 	Loss: 1.0417
#  Client2 Train => Local Epoch: 4 	Acc: 71.811 	Loss: 0.9609
#  Client2 Test =>                   	Acc: 12.978 	Loss: 3.7430
#  Client5 Train => Local Epoch: 0 	Acc: 43.737 	Loss: 2.2133
#  Client5 Train => Local Epoch: 1 	Acc: 58.258 	Loss: 1.4901
#  Client5 Train => Local Epoch: 2 	Acc: 61.363 	Loss: 1.3410
#  Client5 Train => Local Epoch: 3 	Acc: 64.726 	Loss: 1.2191
#  Client5 Train => Local Epoch: 4 	Acc: 67.207 	Loss: 1.1335
#  Client5 Test =>                   	Acc: 18.188 	Loss: 3.3826
#  Client1 Train => Local Epoch: 0 	Acc: 48.331 	Loss: 1.9964
#  Client1 Train => Local Epoch: 1 	Acc: 59.016 	Loss: 1.4619
#  Client1 Train => Local Epoch: 2 	Acc: 63.470 	Loss: 1.3086
#  Client1 Train => Local Epoch: 3 	Acc: 64.613 	Loss: 1.2255
#  Client1 Train => Local Epoch: 4 	Acc: 66.641 	Loss: 1.1447
#  Client1 Test =>                   	Acc: 15.803 	Loss: 3.5552
#  Client6 Train => Local Epoch: 0 	Acc: 50.478 	Loss: 2.0031
#  Client6 Train => Local Epoch: 1 	Acc: 62.306 	Loss: 1.3895
#  Client6 Train => Local Epoch: 2 	Acc: 65.137 	Loss: 1.2591
#  Client6 Train => Local Epoch: 3 	Acc: 66.658 	Loss: 1.1908
#  Client6 Train => Local Epoch: 4 	Acc: 68.802 	Loss: 1.1009
#  Client6 Test =>                   	Acc: 21.511 	Loss: 3.2108
#  Client4 Train => Local Epoch: 0 	Acc: 48.222 	Loss: 2.0910
#  Client4 Train => Local Epoch: 1 	Acc: 58.084 	Loss: 1.5378
#  Client4 Train => Local Epoch: 2 	Acc: 61.539 	Loss: 1.3862
#  Client4 Train => Local Epoch: 3 	Acc: 63.826 	Loss: 1.2794
#  Client4 Train => Local Epoch: 4 	Acc: 66.578 	Loss: 1.1939
#  Client4 Test =>                   	Acc: 23.501 	Loss: 3.1239
#  Client0 Train => Local Epoch: 0 	Acc: 55.141 	Loss: 1.6960
#  Client0 Train => Local Epoch: 1 	Acc: 63.003 	Loss: 1.2788
#  Client0 Train => Local Epoch: 2 	Acc: 66.175 	Loss: 1.1662
#  Client0 Train => Local Epoch: 3 	Acc: 67.740 	Loss: 1.0867
#  Client0 Train => Local Epoch: 4 	Acc: 69.753 	Loss: 1.0110
#  Client0 Test =>                   	Acc: 17.501 	Loss: 3.3484
#  Client3 Train => Local Epoch: 0 	Acc: 51.354 	Loss: 1.9193
#  Client3 Train => Local Epoch: 1 	Acc: 54.271 	Loss: 1.7089
#  Client3 Train => Local Epoch: 2 	Acc: 58.698 	Loss: 1.4886
#  Client3 Train => Local Epoch: 3 	Acc: 56.276 	Loss: 1.5128
#  Client3 Train => Local Epoch: 4 	Acc: 61.979 	Loss: 1.3347
#  Client3 Test =>                   	Acc: 13.399 	Loss: 3.5513
#  Client8 Train => Local Epoch: 0 	Acc: 39.057 	Loss: 2.4726
#  Client8 Train => Local Epoch: 1 	Acc: 51.304 	Loss: 1.7446
#  Client8 Train => Local Epoch: 2 	Acc: 54.652 	Loss: 1.5804
#  Client8 Train => Local Epoch: 3 	Acc: 57.680 	Loss: 1.4624
#  Client8 Train => Local Epoch: 4 	Acc: 60.422 	Loss: 1.3725
#  Client8 Test =>                   	Acc: 19.791 	Loss: 3.2944
#  Client9 Train => Local Epoch: 0 	Acc: 46.223 	Loss: 2.1244
#  Client9 Train => Local Epoch: 1 	Acc: 57.799 	Loss: 1.4906
#  Client9 Train => Local Epoch: 2 	Acc: 61.672 	Loss: 1.3610
#  Client9 Train => Local Epoch: 3 	Acc: 63.054 	Loss: 1.2692
#  Client9 Train => Local Epoch: 4 	Acc: 65.823 	Loss: 1.2021
#  Client9 Test =>                   	Acc: 20.868 	Loss: 3.1794
#  Client7 Train => Local Epoch: 0 	Acc: 46.109 	Loss: 2.1607
#  Client7 Train => Local Epoch: 1 	Acc: 56.362 	Loss: 1.5575
#  Client7 Train => Local Epoch: 2 	Acc: 57.795 	Loss: 1.4544
#  Client7 Train => Local Epoch: 3 	Acc: 60.388 	Loss: 1.3743
#  Client7 Train => Local Epoch: 4 	Acc: 63.055 	Loss: 1.2729
#  Client7 Test =>                   	Acc: 19.528 	Loss: 3.2484
# ====================== SERVER V1==========================
#  Train: Round   9, Avg Accuracy 66.207 | Avg Loss 1.173
#  Test: Round   9, Avg Accuracy 18.307 | Avg Loss 3.364
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Forgetting : Round 9, mean_forgetting : -0.936
# ==========================================================
#  Client3 Train => Local Epoch: 0 	Acc: 57.422 	Loss: 1.6794
#  Client3 Train => Local Epoch: 1 	Acc: 56.667 	Loss: 1.4708
#  Client3 Train => Local Epoch: 2 	Acc: 51.693 	Loss: 1.7649
#  Client3 Train => Local Epoch: 3 	Acc: 55.443 	Loss: 1.6112
#  Client3 Train => Local Epoch: 4 	Acc: 54.974 	Loss: 1.5598
#  Client3 Test =>                   	Acc: 20.952 	Loss: 3.3166
#  Client1 Train => Local Epoch: 0 	Acc: 48.532 	Loss: 2.1126
#  Client1 Train => Local Epoch: 1 	Acc: 60.211 	Loss: 1.4760
#  Client1 Train => Local Epoch: 2 	Acc: 64.241 	Loss: 1.2740
#  Client1 Train => Local Epoch: 3 	Acc: 66.491 	Loss: 1.1778
#  Client1 Train => Local Epoch: 4 	Acc: 68.112 	Loss: 1.0964
#  Client1 Test =>                   	Acc: 19.871 	Loss: 3.1618
#  Client7 Train => Local Epoch: 0 	Acc: 52.733 	Loss: 1.7917
#  Client7 Train => Local Epoch: 1 	Acc: 59.892 	Loss: 1.4419
#  Client7 Train => Local Epoch: 2 	Acc: 59.613 	Loss: 1.4139
#  Client7 Train => Local Epoch: 3 	Acc: 62.822 	Loss: 1.2664
#  Client7 Train => Local Epoch: 4 	Acc: 64.908 	Loss: 1.1842
#  Client7 Test =>                   	Acc: 17.992 	Loss: 3.3163
#  Client9 Train => Local Epoch: 0 	Acc: 50.960 	Loss: 1.8663
#  Client9 Train => Local Epoch: 1 	Acc: 61.113 	Loss: 1.3834
#  Client9 Train => Local Epoch: 2 	Acc: 64.102 	Loss: 1.2662
#  Client9 Train => Local Epoch: 3 	Acc: 66.326 	Loss: 1.1706
#  Client9 Train => Local Epoch: 4 	Acc: 68.512 	Loss: 1.1016
#  Client9 Test =>                   	Acc: 22.831 	Loss: 3.1595
#  Client4 Train => Local Epoch: 0 	Acc: 50.060 	Loss: 1.9554
#  Client4 Train => Local Epoch: 1 	Acc: 60.321 	Loss: 1.4442
#  Client4 Train => Local Epoch: 2 	Acc: 63.492 	Loss: 1.2902
#  Client4 Train => Local Epoch: 3 	Acc: 64.836 	Loss: 1.2178
#  Client4 Train => Local Epoch: 4 	Acc: 67.922 	Loss: 1.1221
#  Client4 Test =>                   	Acc: 23.448 	Loss: 3.0784
#  Client5 Train => Local Epoch: 0 	Acc: 48.488 	Loss: 2.0398
#  Client5 Train => Local Epoch: 1 	Acc: 59.657 	Loss: 1.4013
#  Client5 Train => Local Epoch: 2 	Acc: 64.304 	Loss: 1.2440
#  Client5 Train => Local Epoch: 3 	Acc: 66.182 	Loss: 1.1611
#  Client5 Train => Local Epoch: 4 	Acc: 69.075 	Loss: 1.0725
#  Client5 Test =>                   	Acc: 21.343 	Loss: 3.1575
#  Client2 Train => Local Epoch: 0 	Acc: 50.311 	Loss: 2.0104
#  Client2 Train => Local Epoch: 1 	Acc: 66.283 	Loss: 1.2459
#  Client2 Train => Local Epoch: 2 	Acc: 68.539 	Loss: 1.1065
#  Client2 Train => Local Epoch: 3 	Acc: 69.786 	Loss: 1.0549
#  Client2 Train => Local Epoch: 4 	Acc: 72.592 	Loss: 0.9722
#  Client2 Test =>                   	Acc: 19.282 	Loss: 3.1560
#  Client0 Train => Local Epoch: 0 	Acc: 53.989 	Loss: 1.7612
#  Client0 Train => Local Epoch: 1 	Acc: 64.547 	Loss: 1.2399
#  Client0 Train => Local Epoch: 2 	Acc: 67.555 	Loss: 1.1213
#  Client0 Train => Local Epoch: 3 	Acc: 68.909 	Loss: 1.0293
#  Client0 Train => Local Epoch: 4 	Acc: 71.192 	Loss: 0.9571
#  Client0 Test =>                   	Acc: 21.663 	Loss: 3.0204
#  Client6 Train => Local Epoch: 0 	Acc: 54.827 	Loss: 1.7979
# ...
#  Client4 Train => Local Epoch: 1 	Acc: 98.365 	Loss: 0.0719
#  Client4 Train => Local Epoch: 2 	Acc: 99.202 	Loss: 0.0447
#  Client4 Train => Local Epoch: 3 	Acc: 99.355 	Loss: 0.0344
#  Client4 Train => Local Epoch: 4 	Acc: 99.677 	Loss: 0.0265
#  Client4 Test =>                   	Acc: 59.500 	Loss: 1.4514
#  Client8 Train => Local Epoch: 0 	Acc: 95.409 	Loss: 0.1786
#  Client8 Train => Local Epoch: 1 	Acc: 96.790 	Loss: 0.1147
#  Client8 Train => Local Epoch: 2 	Acc: 97.132 	Loss: 0.1022
#  Client8 Train => Local Epoch: 3 	Acc: 97.909 	Loss: 0.0785
#  Client8 Train => Local Epoch: 4 	Acc: 98.419 	Loss: 0.0607
#  Client8 Test =>                   	Acc: 60.486 	Loss: 1.5020
#  Client6 Train => Local Epoch: 0 	Acc: 96.590 	Loss: 0.1474
#  Client6 Train => Local Epoch: 1 	Acc: 98.768 	Loss: 0.0581
#  Client6 Train => Local Epoch: 2 	Acc: 99.166 	Loss: 0.0388
#  Client6 Train => Local Epoch: 3 	Acc: 99.557 	Loss: 0.0286
#  Client6 Train => Local Epoch: 4 	Acc: 99.624 	Loss: 0.0249
#  Client6 Test =>                   	Acc: 60.645 	Loss: 1.4439
#  Client0 Train => Local Epoch: 0 	Acc: 94.923 	Loss: 0.1725
#  Client0 Train => Local Epoch: 1 	Acc: 97.678 	Loss: 0.0881
#  Client0 Train => Local Epoch: 2 	Acc: 98.675 	Loss: 0.0591
#  Client0 Train => Local Epoch: 3 	Acc: 99.430 	Loss: 0.0366
#  Client0 Train => Local Epoch: 4 	Acc: 99.216 	Loss: 0.0343
#  Client0 Test =>                   	Acc: 61.806 	Loss: 1.4257
#  Client3 Train => Local Epoch: 0 	Acc: 94.870 	Loss: 0.2292
#  Client3 Train => Local Epoch: 1 	Acc: 88.464 	Loss: 0.4739
#  Client3 Train => Local Epoch: 2 	Acc: 77.969 	Loss: 0.8014
#  Client3 Train => Local Epoch: 3 	Acc: 74.479 	Loss: 0.8054
#  Client3 Train => Local Epoch: 4 	Acc: 72.760 	Loss: 0.9297
#  Client3 Test =>                   	Acc: 57.957 	Loss: 1.5061
#  Client5 Train => Local Epoch: 0 	Acc: 93.649 	Loss: 0.2174
#  Client5 Train => Local Epoch: 1 	Acc: 97.910 	Loss: 0.0817
#  Client5 Train => Local Epoch: 2 	Acc: 98.785 	Loss: 0.0535
#  Client5 Train => Local Epoch: 3 	Acc: 99.434 	Loss: 0.0330
#  Client5 Train => Local Epoch: 4 	Acc: 99.588 	Loss: 0.0252
#  Client5 Test =>                   	Acc: 59.230 	Loss: 1.5004
#  Client1 Train => Local Epoch: 0 	Acc: 94.136 	Loss: 0.2017
#  Client1 Train => Local Epoch: 1 	Acc: 97.890 	Loss: 0.0859
#  Client1 Train => Local Epoch: 2 	Acc: 98.757 	Loss: 0.0519
#  Client1 Train => Local Epoch: 3 	Acc: 99.380 	Loss: 0.0352
#  Client1 Train => Local Epoch: 4 	Acc: 99.626 	Loss: 0.0234
#  Client1 Test =>                   	Acc: 60.028 	Loss: 1.4576
#  Client7 Train => Local Epoch: 0 	Acc: 96.202 	Loss: 0.1522
#  Client7 Train => Local Epoch: 1 	Acc: 98.109 	Loss: 0.0799
#  Client7 Train => Local Epoch: 2 	Acc: 98.177 	Loss: 0.0764
#  Client7 Train => Local Epoch: 3 	Acc: 97.976 	Loss: 0.0904
#  Client7 Train => Local Epoch: 4 	Acc: 95.307 	Loss: 0.1553
#  Client7 Test =>                   	Acc: 58.072 	Loss: 1.4906
#  Client2 Train => Local Epoch: 0 	Acc: 93.678 	Loss: 0.2241
#  Client2 Train => Local Epoch: 1 	Acc: 97.919 	Loss: 0.0837
#  Client2 Train => Local Epoch: 2 	Acc: 98.398 	Loss: 0.0551
#  Client2 Train => Local Epoch: 3 	Acc: 99.219 	Loss: 0.0361
#  Client2 Train => Local Epoch: 4 	Acc: 99.581 	Loss: 0.0237
#  Client2 Test =>                   	Acc: 60.008 	Loss: 1.4618
# ====================== SERVER V1==========================
#  Train: Round  96, Avg Accuracy 96.327 | Avg Loss 0.134
#  Test: Round  96, Avg Accuracy 59.864 | Avg Loss 1.470
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Forgetting : Round 96, mean_forgetting : -0.470
# ==========================================================
#  Client9 Train => Local Epoch: 0 	Acc: 94.910 	Loss: 0.1796
#  Client9 Train => Local Epoch: 1 	Acc: 97.701 	Loss: 0.0824
#  Client9 Train => Local Epoch: 2 	Acc: 98.625 	Loss: 0.0583
#  Client9 Train => Local Epoch: 3 	Acc: 99.046 	Loss: 0.0435
#  Client9 Train => Local Epoch: 4 	Acc: 99.076 	Loss: 0.0354
#  Client9 Test =>                   	Acc: 59.197 	Loss: 1.5776
#  Client1 Train => Local Epoch: 0 	Acc: 95.567 	Loss: 0.1732
#  Client1 Train => Local Epoch: 1 	Acc: 98.579 	Loss: 0.0601
#  Client1 Train => Local Epoch: 2 	Acc: 99.430 	Loss: 0.0367
#  Client1 Train => Local Epoch: 3 	Acc: 99.770 	Loss: 0.0235
#  Client1 Train => Local Epoch: 4 	Acc: 99.839 	Loss: 0.0203
#  Client1 Test =>                   	Acc: 57.634 	Loss: 1.5627
#  Client7 Train => Local Epoch: 0 	Acc: 95.654 	Loss: 0.1717
#  Client7 Train => Local Epoch: 1 	Acc: 95.084 	Loss: 0.1553
#  Client7 Train => Local Epoch: 2 	Acc: 94.566 	Loss: 0.1730
#  Client7 Train => Local Epoch: 3 	Acc: 93.964 	Loss: 0.2087
#  Client7 Train => Local Epoch: 4 	Acc: 97.266 	Loss: 0.1044
#  Client7 Test =>                   	Acc: 55.843 	Loss: 1.5773
#  Client6 Train => Local Epoch: 0 	Acc: 95.399 	Loss: 0.1661
#  Client6 Train => Local Epoch: 1 	Acc: 98.464 	Loss: 0.0625
#  Client6 Train => Local Epoch: 2 	Acc: 99.339 	Loss: 0.0379
#  Client6 Train => Local Epoch: 3 	Acc: 99.561 	Loss: 0.0277
#  Client6 Train => Local Epoch: 4 	Acc: 99.591 	Loss: 0.0270
#  Client6 Test =>                   	Acc: 57.732 	Loss: 1.5457
#  Client0 Train => Local Epoch: 0 	Acc: 94.668 	Loss: 0.1862
#  Client0 Train => Local Epoch: 1 	Acc: 97.705 	Loss: 0.0754
#  Client0 Train => Local Epoch: 2 	Acc: 98.842 	Loss: 0.0519
#  Client0 Train => Local Epoch: 3 	Acc: 99.043 	Loss: 0.0410
#  Client0 Train => Local Epoch: 4 	Acc: 99.440 	Loss: 0.0323
#  Client0 Test =>                   	Acc: 58.119 	Loss: 1.5389
#  Client2 Train => Local Epoch: 0 	Acc: 93.758 	Loss: 0.2354
#  Client2 Train => Local Epoch: 1 	Acc: 97.473 	Loss: 0.0849
#  Client2 Train => Local Epoch: 2 	Acc: 98.932 	Loss: 0.0511
#  Client2 Train => Local Epoch: 3 	Acc: 99.294 	Loss: 0.0305
#  Client2 Train => Local Epoch: 4 	Acc: 99.733 	Loss: 0.0191
#  Client2 Test =>                   	Acc: 58.941 	Loss: 1.5347
#  Client8 Train => Local Epoch: 0 	Acc: 93.910 	Loss: 0.2135
#  Client8 Train => Local Epoch: 1 	Acc: 96.905 	Loss: 0.1111
#  Client8 Train => Local Epoch: 2 	Acc: 97.403 	Loss: 0.0963
#  Client8 Train => Local Epoch: 3 	Acc: 97.582 	Loss: 0.0937
#  Client8 Train => Local Epoch: 4 	Acc: 98.378 	Loss: 0.0683
#  Client8 Test =>                   	Acc: 59.641 	Loss: 1.5685
#  Client5 Train => Local Epoch: 0 	Acc: 93.377 	Loss: 0.2402
#  Client5 Train => Local Epoch: 1 	Acc: 97.340 	Loss: 0.0925
#  Client5 Train => Local Epoch: 2 	Acc: 98.886 	Loss: 0.0524
#  Client5 Train => Local Epoch: 3 	Acc: 99.240 	Loss: 0.0395
#  Client5 Train => Local Epoch: 4 	Acc: 99.649 	Loss: 0.0263
#  Client5 Test =>                   	Acc: 57.223 	Loss: 1.5739
#  Client3 Train => Local Epoch: 0 	Acc: 92.188 	Loss: 0.2481
#  Client3 Train => Local Epoch: 1 	Acc: 91.979 	Loss: 0.2782
#  Client3 Train => Local Epoch: 2 	Acc: 84.740 	Loss: 0.5504
#  Client3 Train => Local Epoch: 3 	Acc: 73.307 	Loss: 0.9358
#  Client3 Train => Local Epoch: 4 	Acc: 67.161 	Loss: 1.2004
#  Client3 Test =>                   	Acc: 56.711 	Loss: 1.6207
#  Client4 Train => Local Epoch: 0 	Acc: 93.784 	Loss: 0.2224
#  Client4 Train => Local Epoch: 1 	Acc: 97.855 	Loss: 0.0834
#  Client4 Train => Local Epoch: 2 	Acc: 98.780 	Loss: 0.0543
#  Client4 Train => Local Epoch: 3 	Acc: 99.083 	Loss: 0.0414
#  Client4 Train => Local Epoch: 4 	Acc: 99.728 	Loss: 0.0274
#  Client4 Test =>                   	Acc: 58.594 	Loss: 1.5438
# ====================== SERVER V1==========================
#  Train: Round  97, Avg Accuracy 95.986 | Avg Loss 0.156
#  Test: Round  97, Avg Accuracy 57.963 | Avg Loss 1.564
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Forgetting : Round 97, mean_forgetting : -0.486
# ==========================================================
#  Client8 Train => Local Epoch: 0 	Acc: 94.870 	Loss: 0.1915
#  Client8 Train => Local Epoch: 1 	Acc: 97.980 	Loss: 0.0840
#  Client8 Train => Local Epoch: 2 	Acc: 97.489 	Loss: 0.0938
#  Client8 Train => Local Epoch: 3 	Acc: 98.270 	Loss: 0.0683
#  Client8 Train => Local Epoch: 4 	Acc: 99.014 	Loss: 0.0421
#  Client8 Test =>                   	Acc: 58.604 	Loss: 1.5678
#  Client3 Train => Local Epoch: 0 	Acc: 95.521 	Loss: 0.1916
#  Client3 Train => Local Epoch: 1 	Acc: 94.792 	Loss: 0.1946
#  Client3 Train => Local Epoch: 2 	Acc: 84.167 	Loss: 0.5500
#  Client3 Train => Local Epoch: 3 	Acc: 74.271 	Loss: 0.9036
#  Client3 Train => Local Epoch: 4 	Acc: 76.510 	Loss: 0.7306
#  Client3 Test =>                   	Acc: 55.435 	Loss: 1.5990
#  Client9 Train => Local Epoch: 0 	Acc: 94.227 	Loss: 0.1900
#  Client9 Train => Local Epoch: 1 	Acc: 97.172 	Loss: 0.0929
#  Client9 Train => Local Epoch: 2 	Acc: 98.558 	Loss: 0.0619
#  Client9 Train => Local Epoch: 3 	Acc: 99.038 	Loss: 0.0417
#  Client9 Train => Local Epoch: 4 	Acc: 99.343 	Loss: 0.0348
#  Client9 Test =>                   	Acc: 59.052 	Loss: 1.5258
#  Client0 Train => Local Epoch: 0 	Acc: 94.191 	Loss: 0.1987
#  Client0 Train => Local Epoch: 1 	Acc: 97.423 	Loss: 0.0902
#  Client0 Train => Local Epoch: 2 	Acc: 98.527 	Loss: 0.0573
#  Client0 Train => Local Epoch: 3 	Acc: 99.060 	Loss: 0.0399
#  Client0 Train => Local Epoch: 4 	Acc: 99.260 	Loss: 0.0310
#  Client0 Test =>                   	Acc: 59.665 	Loss: 1.5049
#  Client5 Train => Local Epoch: 0 	Acc: 92.582 	Loss: 0.2403
#  Client5 Train => Local Epoch: 1 	Acc: 97.626 	Loss: 0.0846
#  Client5 Train => Local Epoch: 2 	Acc: 99.078 	Loss: 0.0502
#  Client5 Train => Local Epoch: 3 	Acc: 99.342 	Loss: 0.0356
#  Client5 Train => Local Epoch: 4 	Acc: 99.740 	Loss: 0.0227
#  Client5 Test =>                   	Acc: 58.146 	Loss: 1.5604
#  Client1 Train => Local Epoch: 0 	Acc: 94.174 	Loss: 0.2105
#  Client1 Train => Local Epoch: 1 	Acc: 98.254 	Loss: 0.0725
#  Client1 Train => Local Epoch: 2 	Acc: 98.999 	Loss: 0.0468
#  Client1 Train => Local Epoch: 3 	Acc: 99.793 	Loss: 0.0277
#  Client1 Train => Local Epoch: 4 	Acc: 99.833 	Loss: 0.0179
#  Client1 Test =>                   	Acc: 57.136 	Loss: 1.5739
#  Client7 Train => Local Epoch: 0 	Acc: 94.615 	Loss: 0.1939
#  Client7 Train => Local Epoch: 1 	Acc: 96.522 	Loss: 0.1132
#  Client7 Train => Local Epoch: 2 	Acc: 96.547 	Loss: 0.1223
#  Client7 Train => Local Epoch: 3 	Acc: 97.786 	Loss: 0.0885
#  Client7 Train => Local Epoch: 4 	Acc: 98.020 	Loss: 0.0669
#  Client7 Test =>                   	Acc: 56.728 	Loss: 1.5247
#  Client4 Train => Local Epoch: 0 	Acc: 94.095 	Loss: 0.2087
#  Client4 Train => Local Epoch: 1 	Acc: 97.608 	Loss: 0.0976
#  Client4 Train => Local Epoch: 2 	Acc: 98.241 	Loss: 0.0687
#  Client4 Train => Local Epoch: 3 	Acc: 99.146 	Loss: 0.0466
#  Client4 Train => Local Epoch: 4 	Acc: 99.558 	Loss: 0.0331
#  Client4 Test =>                   	Acc: 59.139 	Loss: 1.5356
#  Client6 Train => Local Epoch: 0 	Acc: 95.152 	Loss: 0.1702
#  Client6 Train => Local Epoch: 1 	Acc: 97.942 	Loss: 0.0772
#  Client6 Train => Local Epoch: 2 	Acc: 99.001 	Loss: 0.0477
#  Client6 Train => Local Epoch: 3 	Acc: 99.227 	Loss: 0.0345
#  Client6 Train => Local Epoch: 4 	Acc: 99.534 	Loss: 0.0274
#  Client6 Test =>                   	Acc: 59.345 	Loss: 1.5159
#  Client2 Train => Local Epoch: 0 	Acc: 93.363 	Loss: 0.2405
#  Client2 Train => Local Epoch: 1 	Acc: 97.389 	Loss: 0.0990
#  Client2 Train => Local Epoch: 2 	Acc: 98.569 	Loss: 0.0540
#  Client2 Train => Local Epoch: 3 	Acc: 99.203 	Loss: 0.0357
#  Client2 Train => Local Epoch: 4 	Acc: 99.498 	Loss: 0.0283
#  Client2 Test =>                   	Acc: 59.473 	Loss: 1.5141
# ====================== SERVER V1==========================
#  Train: Round  98, Avg Accuracy 97.031 | Avg Loss 0.103
#  Test: Round  98, Avg Accuracy 58.272 | Avg Loss 1.542
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Forgetting : Round 98, mean_forgetting : -0.502
# ==========================================================
#  Client8 Train => Local Epoch: 0 	Acc: 93.832 	Loss: 0.2057
#  Client8 Train => Local Epoch: 1 	Acc: 97.787 	Loss: 0.0886
#  Client8 Train => Local Epoch: 2 	Acc: 97.950 	Loss: 0.0770
#  Client8 Train => Local Epoch: 3 	Acc: 97.947 	Loss: 0.0696
#  Client8 Train => Local Epoch: 4 	Acc: 97.798 	Loss: 0.0792
#  Client8 Test =>                   	Acc: 58.826 	Loss: 1.5415
#  Client2 Train => Local Epoch: 0 	Acc: 94.766 	Loss: 0.1941
#  Client2 Train => Local Epoch: 1 	Acc: 98.214 	Loss: 0.0660
#  Client2 Train => Local Epoch: 2 	Acc: 99.111 	Loss: 0.0383
#  Client2 Train => Local Epoch: 3 	Acc: 99.665 	Loss: 0.0255
#  Client2 Train => Local Epoch: 4 	Acc: 99.749 	Loss: 0.0231
#  Client2 Test =>                   	Acc: 57.634 	Loss: 1.5272
#  Client3 Train => Local Epoch: 0 	Acc: 91.667 	Loss: 0.3258
#  Client3 Train => Local Epoch: 1 	Acc: 81.927 	Loss: 0.6177
#  Client3 Train => Local Epoch: 2 	Acc: 77.396 	Loss: 0.8225
#  Client3 Train => Local Epoch: 3 	Acc: 83.021 	Loss: 0.5425
#  Client3 Train => Local Epoch: 4 	Acc: 83.490 	Loss: 0.5641
#  Client3 Test =>                   	Acc: 56.243 	Loss: 1.5713
#  Client0 Train => Local Epoch: 0 	Acc: 94.738 	Loss: 0.1794
#  Client0 Train => Local Epoch: 1 	Acc: 98.045 	Loss: 0.0760
#  Client0 Train => Local Epoch: 2 	Acc: 98.744 	Loss: 0.0528
#  Client0 Train => Local Epoch: 3 	Acc: 99.070 	Loss: 0.0414
#  Client0 Train => Local Epoch: 4 	Acc: 99.490 	Loss: 0.0278
#  Client0 Test =>                   	Acc: 58.439 	Loss: 1.5007
#  Client9 Train => Local Epoch: 0 	Acc: 93.986 	Loss: 0.1959
#  Client9 Train => Local Epoch: 1 	Acc: 97.498 	Loss: 0.0922
#  Client9 Train => Local Epoch: 2 	Acc: 98.422 	Loss: 0.0606
#  Client9 Train => Local Epoch: 3 	Acc: 98.963 	Loss: 0.0457
#  Client9 Train => Local Epoch: 4 	Acc: 99.072 	Loss: 0.0401
#  Client9 Test =>                   	Acc: 60.412 	Loss: 1.4829
#  Client4 Train => Local Epoch: 0 	Acc: 94.507 	Loss: 0.1988
#  Client4 Train => Local Epoch: 1 	Acc: 98.258 	Loss: 0.0809
#  Client4 Train => Local Epoch: 2 	Acc: 99.243 	Loss: 0.0435
#  Client4 Train => Local Epoch: 3 	Acc: 99.503 	Loss: 0.0327
#  Client4 Train => Local Epoch: 4 	Acc: 99.406 	Loss: 0.0330
#  Client4 Test =>                   	Acc: 58.641 	Loss: 1.5321
#  Client7 Train => Local Epoch: 0 	Acc: 96.311 	Loss: 0.1529
#  Client7 Train => Local Epoch: 1 	Acc: 97.737 	Loss: 0.0811
#  Client7 Train => Local Epoch: 2 	Acc: 96.633 	Loss: 0.1306
#  Client7 Train => Local Epoch: 3 	Acc: 95.871 	Loss: 0.1278
#  Client7 Train => Local Epoch: 4 	Acc: 96.571 	Loss: 0.1140
#  Client7 Test =>                   	Acc: 55.297 	Loss: 1.5608
#  Client1 Train => Local Epoch: 0 	Acc: 94.084 	Loss: 0.2048
#  Client1 Train => Local Epoch: 1 	Acc: 98.022 	Loss: 0.0726
#  Client1 Train => Local Epoch: 2 	Acc: 99.229 	Loss: 0.0430
#  Client1 Train => Local Epoch: 3 	Acc: 99.764 	Loss: 0.0247
#  Client1 Train => Local Epoch: 4 	Acc: 99.626 	Loss: 0.0226
#  Client1 Test =>                   	Acc: 57.701 	Loss: 1.5401
#  Client5 Train => Local Epoch: 0 	Acc: 92.738 	Loss: 0.2433
#  Client5 Train => Local Epoch: 1 	Acc: 97.409 	Loss: 0.0870
#  Client5 Train => Local Epoch: 2 	Acc: 98.611 	Loss: 0.0561
#  Client5 Train => Local Epoch: 3 	Acc: 99.128 	Loss: 0.0415
#  Client5 Train => Local Epoch: 4 	Acc: 99.566 	Loss: 0.0259
#  Client5 Test =>                   	Acc: 57.907 	Loss: 1.5243
#  Client6 Train => Local Epoch: 0 	Acc: 95.767 	Loss: 0.1562
#  Client6 Train => Local Epoch: 1 	Acc: 98.325 	Loss: 0.0665
#  Client6 Train => Local Epoch: 2 	Acc: 99.193 	Loss: 0.0444
#  Client6 Train => Local Epoch: 3 	Acc: 99.317 	Loss: 0.0364
#  Client6 Train => Local Epoch: 4 	Acc: 99.362 	Loss: 0.0291
#  Client6 Test =>                   	Acc: 59.089 	Loss: 1.5035
# ====================== SERVER V1==========================
#  Train: Round  99, Avg Accuracy 97.413 | Avg Loss 0.096
#  Test: Round  99, Avg Accuracy 58.019 | Avg Loss 1.528
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Forgetting : Round 99, mean_forgetting : -0.489
# ==========================================================
# Training and Evaluation completed!
# Saved: SFLV2 - CIFAR-100 α=0.1 - LATE-Cut (6 + AvgPool).csv
