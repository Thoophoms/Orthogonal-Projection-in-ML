# %% [markdown]
# # Split Federated Learning V2:
# ### ResNet18 on CIFAR-10 + α = 0.5

# %%
#=============================================================================
# SplitfedV2 (SFLV2) learning: ResNet18 on CIFAR-10
# Version2: with using socket but no DP+PixelDP
# ==============================================================================
import torch
from torch import nn
from torchvision import transforms
from torch.utils.data import DataLoader, Dataset
import torch.nn.functional as F
import math
import os.path
import pandas as pd
from sklearn.model_selection import train_test_split
from PIL import Image
from glob import glob
from pandas import DataFrame
import random
import numpy as np
import os


import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import copy
import time


#===================================================================
program = "SFLV2 - CIFAR-10 α=0.5"
DATASET_NAME = "CIFAR10"            # Set toggle between CIFAR-10 and CIFAR-100
DATA_ROOT = "data"                  # Set where torchvision stores CIFAR data


print(f"---------{program}----------")              # this is to identify the program in the slurm outputs files


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
pin = torch.cuda.is_available()


# To print in color -------test/train of the client side
def prRed(skk): print("\033[91m {}\033[00m" .format(skk)) 
def prGreen(skk): print("\033[92m {}\033[00m" .format(skk))     


#===================================================================
# No. of users
NUM_CLIENTS = 10
EPOCHS = 100
LOCAL_EPOCHS = 5
FRAC = 1        # participation of clients; if 1 then 100% clients participate in SFLV2
ALPHA = 0.5   # requested alpha


# ----------------------------- Optimization ------------------------------ #
BATCH_SIZE = 256
LR_BASE = 0.01  
WARMUP_ROUNDS = 0
MOMENTUM = 0.9                     # Smoothing/Accelerating SGD undates
WEIGHT_DECAY = 5e-4                # L2 Regularization
LABEL_SMOOTH = 0.0
NUM_WORKERS = 4
SEED = 1234



def _sync_cuda():
    if torch.cuda.is_available():
        torch.cuda.synchronize()


SEED = 1234
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
if torch.cuda.is_available():
    torch.backends.cudnn.deterministic = True
    print(torch.cuda.get_device_name(0))    




#=====================================================================================================
#                                  Baseblock
#=====================================================================================================
class Baseblock(nn.Module):
    expansion = 1
    def __init__(self, input_planes, planes, stride = 1, dim_change = None):
        super(Baseblock, self).__init__()
        self.conv1 = nn.Conv2d(input_planes, planes, stride =  stride, kernel_size = 3, padding = 1)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, stride = 1, kernel_size = 3, padding = 1)
        self.bn2 = nn.BatchNorm2d(planes)
        self.dim_change = dim_change
        
    def forward(self, x):
        res = x
        output = F.relu(self.bn1(self.conv1(x)))
        output = self.bn2(self.conv2(output))
        
        if self.dim_change is not None:
            res =self.dim_change(res)
            
        output += res
        output = F.relu(output)
        
        return output
        
#=====================================================================================================
#                           Client-side Model definition
#=====================================================================================================
# Model at client side
class ResNet18_client_side(nn.Module):
    def __init__(self, block, num_layers):
        super().__init__()
        self.layer1 = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False),  # 3x3 s=1
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            # no maxpool for 32x32
        )
        self.layer2 = nn.Sequential(
            nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(64),
        )

        # add layer 3-6 + avg-pool (copied from Client)
        self.layer3 = nn.Sequential (
                nn.Conv2d(64, 64, kernel_size = 3, stride = 1, padding = 1),
                nn.BatchNorm2d(64),
                nn.ReLU (inplace = True),
                nn.Conv2d(64, 64, kernel_size = 3, stride = 1, padding = 1),
                nn.BatchNorm2d(64),       
                )   

        self.input_planes = 64
        
        self.layer4 = self._layer(block, 128, num_layers[0], stride = 2)
        self.layer5 = self._layer(block, 256, num_layers[1], stride = 2)
        self.layer6 = self._layer(block, 512, num_layers[2], stride = 2)
        
        # self. averagePool = nn.AvgPool2d(kernel_size = 7, stride = 1)
        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))


        # Weights into loop (the same thing as SERVER)
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                m.weight.data.normal_(0, math.sqrt(2. / n))
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()

        
        
        
    def _layer(self, block, planes, num_layers, stride = 2):
        dim_change = None
        if stride != 1 or planes != self.input_planes * block.expansion:
            dim_change = nn.Sequential(nn.Conv2d(self.input_planes, planes*block.expansion, kernel_size = 1, stride = stride),
                                       nn.BatchNorm2d(planes*block.expansion))
        netLayers = []
        netLayers.append(block(self.input_planes, planes, stride = stride, dim_change = dim_change))
        self.input_planes = planes * block.expansion
        for i in range(1, num_layers):
            netLayers.append(block(self.input_planes, planes))
            self.input_planes = planes * block.expansion
            
        return nn.Sequential(*netLayers)
        
        
    def forward(self, x):
        resudial1 = F.relu(self.layer1(x))
        out1 = self.layer2(resudial1)
        out1 = out1 + resudial1 # adding the resudial inputs -- downsampling not required in this layer
        x = F.relu(out1)

        out2 = self.layer3(x)
        out2 = out2 + x
        x = F.relu(out2)

        x = self.layer4(x)
        x = self.layer5(x)
        x = self.layer6(x)

        x = self.avgpool(x)                   # shape [B, 512, 1, 1]
        return x
 

net_glob_client = ResNet18_client_side(Baseblock, [2, 2, 2])
if torch.cuda.device_count() > 1:
    print("We use",torch.cuda.device_count(), "GPUs")
    net_glob_client = nn.DataParallel(net_glob_client)   # to use the multiple GPUs; later we can change this to CPUs only 

net_glob_client.to(device)
print(net_glob_client)    

#=====================================================================================================
#                           Server-side Model definition
#=====================================================================================================
# Model at server side
class ResNet18_server_side(nn.Module):
    def __init__(self, block, classes):
        super(ResNet18_server_side, self).__init__()
        self.fc = nn.Linear(512 * block.expansion, classes)
        
    
    def forward(self, x):
        # x = [B, 512, 1, 1] from the Client side
        x = x.view(x.size(0), -1)     # [B, 512] 
        y_hat =self.fc(x)
        
        return y_hat
        

if DATASET_NAME == "CIFAR10":
    net_glob_server = ResNet18_server_side(Baseblock, 10) #10 CIFAR-10
else:
    net_glob_server = ResNet18_server_side(Baseblock, 100) #100 CIFAR-100
    

if torch.cuda.device_count() > 1:
    print("We use",torch.cuda.device_count(), "GPUs")
    net_glob_server = nn.DataParallel(net_glob_server)   # to use the multiple GPUs 


net_glob_server.to(device)
print(net_glob_server)      

#===================================================================================
# For Server Side Loss and Accuracy 
loss_train_collect = []
acc_train_collect = []
loss_test_collect = []
acc_test_collect = []
batch_acc_train = []
batch_loss_train = []
batch_acc_test = []
batch_loss_test = []
round_time_collect = [] # Stores seconds per global round

criterion = nn.CrossEntropyLoss()
count1 = 0
count2 = 0

#====================================================================================================
#                                  Server Side Programs
#====================================================================================================
# Federated averaging: FedAvg
def FedAvg(w):
    w_avg = copy.deepcopy(w[0])
    for k in w_avg.keys():
        for i in range(1, len(w)):
            w_avg[k] += w[i][k]
        w_avg[k] = torch.div(w_avg[k], len(w))
    return w_avg

def calculate_accuracy(fx, y):
    preds = fx.max(1, keepdim=True)[1]
    correct = preds.eq(y.view_as(preds)).sum()
    acc = 100.00 *correct.float()/preds.shape[0]
    return acc

# to print train - test together in each round-- these are made global
acc_avg_all_user_train = 0
loss_avg_all_user_train = 0
loss_train_collect_user = []
acc_train_collect_user = []
loss_test_collect_user = []
acc_test_collect_user = []


#client idx collector
idx_collect = []
l_epoch_check = False
fed_check = False

# Server-side function associated with Training 
def train_server(fx_client, y, l_epoch_count, l_epoch, idx, len_batch):
    global net_glob_server, criterion, device, batch_acc_train, batch_loss_train, l_epoch_check, fed_check
    global loss_train_collect, acc_train_collect, count1, acc_avg_all_user_train, loss_avg_all_user_train, idx_collect
    global loss_train_collect_user, acc_train_collect_user, LR_BASE
    
    net_glob_server.train()
    optimizer_server = torch.optim.SGD(
        net_glob_server.parameters(), 
        lr = LR_BASE,
        momentum=MOMENTUM,
        weight_decay=WEIGHT_DECAY
    )

    
    # train and update
    optimizer_server.zero_grad()
    
    fx_client = fx_client.to(device)
    y = y.to(device)
    
    #---------forward prop-------------
    fx_server = net_glob_server(fx_client)
    
    # calculate loss
    loss = criterion(fx_server, y)
    # calculate accuracy
    acc = calculate_accuracy(fx_server, y)
    
    #--------backward prop--------------
    loss.backward()
    dfx_client = fx_client.grad.clone().detach()
    optimizer_server.step()
    
    batch_loss_train.append(loss.item())
    batch_acc_train.append(acc.item())
    
    
    # server-side model net_glob_server is global so it is updated automatically in each pass to this function
    # count1: to track the completion of the local batch associated with one client
    count1 += 1
    if count1 == len_batch:
        acc_avg_train = sum(batch_acc_train)/len(batch_acc_train)           # it has accuracy for one batch
        loss_avg_train = sum(batch_loss_train)/len(batch_loss_train)
        
        batch_acc_train = []
        batch_loss_train = []
        count1 = 0
        
        prRed('Client{} Train => Local Epoch: {} \tAcc: {:.3f} \tLoss: {:.4f}'.format(idx, l_epoch_count, acc_avg_train, loss_avg_train))
        
                
        # If one local epoch is completed, after this a new client will come
        if l_epoch_count == l_epoch-1:
            
            l_epoch_check = True                # to evaluate_server function - to check local epoch has completed or not
                       
            # we store the last accuracy in the last batch of the epoch and it is not the average of all local epochs
            # this is because we work on the last trained model and its accuracy (not earlier cases)
            
            #print("accuracy = ", acc_avg_train)
            acc_avg_train_all = acc_avg_train
            loss_avg_train_all = loss_avg_train
                        
            # accumulate accuracy and loss for each new user
            loss_train_collect_user.append(loss_avg_train_all)
            acc_train_collect_user.append(acc_avg_train_all)
            
            # collect the id of each new user                        
            if idx not in idx_collect:
                idx_collect.append(idx) 
                #print(idx_collect)
        
        # This is to check if all users are served for one round --------------------
        if len(idx_collect) == NUM_CLIENTS:
            fed_check = True                                                  # to evaluate_server function  - to check fed check has hitted
            # all users served for one round ------------------------- output print and update is done in evaluate_server()
            # for nicer display 
                        
            idx_collect = []
            
            acc_avg_all_user_train = sum(acc_train_collect_user)/len(acc_train_collect_user)
            loss_avg_all_user_train = sum(loss_train_collect_user)/len(loss_train_collect_user)
            
            loss_train_collect.append(loss_avg_all_user_train)
            acc_train_collect.append(acc_avg_all_user_train)
            
            acc_train_collect_user = []
            loss_train_collect_user = []
            
    # send gradients to the client               
    return dfx_client

# Server-side functions associated with Testing
def evaluate_server(fx_client, y, idx, len_batch, ell):
    global net_glob_server, criterion, batch_acc_test, batch_loss_test
    global loss_test_collect, acc_test_collect, count2, NUM_CLIENTS, acc_avg_train_all, loss_avg_train_all, l_epoch_check, fed_check
    global loss_test_collect_user, acc_test_collect_user, acc_avg_all_user_train, loss_avg_all_user_train
    
    net_glob_server.eval()
  
    with torch.no_grad():
        fx_client = fx_client.to(device)
        y = y.to(device) 
        #---------forward prop-------------
        fx_server = net_glob_server(fx_client)
        
        # calculate loss
        loss = criterion(fx_server, y)
        # calculate accuracy
        acc = calculate_accuracy(fx_server, y)
        
        
        batch_loss_test.append(loss.item())
        batch_acc_test.append(acc.item())
        
               
        count2 += 1
        if count2 == len_batch:
            acc_avg_test = sum(batch_acc_test)/len(batch_acc_test)
            loss_avg_test = sum(batch_loss_test)/len(batch_loss_test)
            
            batch_acc_test = []
            batch_loss_test = []
            count2 = 0
            
            prGreen('Client{} Test =>                   \tAcc: {:.3f} \tLoss: {:.4f}'.format(idx, acc_avg_test, loss_avg_test))
            
            # if a local epoch is completed   
            if l_epoch_check:
                l_epoch_check = False
                
                # Store the last accuracy and loss
                acc_avg_test_all = acc_avg_test
                loss_avg_test_all = loss_avg_test
                        
                loss_test_collect_user.append(loss_avg_test_all)
                acc_test_collect_user.append(acc_avg_test_all)
                
            # if all users are served for one round ----------                    
            if fed_check:
                fed_check = False
                                
                acc_avg_all_user = sum(acc_test_collect_user)/len(acc_test_collect_user)
                loss_avg_all_user = sum(loss_test_collect_user)/len(loss_test_collect_user)
            
                loss_test_collect.append(loss_avg_all_user)
                acc_test_collect.append(acc_avg_all_user)
                acc_test_collect_user = []
                loss_test_collect_user= []
                              
                print("====================== SERVER V1==========================")
                print(' Train: Round {:3d}, Avg Accuracy {:.3f} | Avg Loss {:.3f}'.format(ell, acc_avg_all_user_train, loss_avg_all_user_train))
                print(' Test: Round {:3d}, Avg Accuracy {:.3f} | Avg Loss {:.3f}'.format(ell, acc_avg_all_user, loss_avg_all_user))
                # print("==========================================================")
         
    return 

#==============================================================================================================
#                                       Clients Side Program
#==============================================================================================================
class DatasetSplit(Dataset):
    def __init__(self, dataset, idxs):
        self.dataset = dataset
        self.idxs = list(idxs)

    def __len__(self):
        return len(self.idxs)

    def __getitem__(self, item):
        image, label = self.dataset[self.idxs[item]]
        return image, label

# Client-side functions associated with Training and Testing
class Client(object):
    def __init__(self, net_client_model, idx, LR_BASE, device, dataset_train = None, dataset_test = None, idxs = None, idxs_test = None):
        self.idx = idx
        self.device = device
        self.LR_BASE = LR_BASE
        self.local_ep = LOCAL_EPOCHS
        #self.selected_clients = []
        self.ldr_train = DataLoader(
            DatasetSplit(
                dataset_train, 
                idxs), 
            batch_size = BATCH_SIZE, 
            shuffle = True,
            num_workers=NUM_WORKERS,
            pin_memory=pin
        )
        self.ldr_test = DataLoader(
            DatasetSplit(
                dataset_test, 
                idxs_test), 
            batch_size = BATCH_SIZE, 
            shuffle = True,
            num_workers=NUM_WORKERS,
            pin_memory=pin
        )
        

    def train(self, net):
        net.train()
        optimizer_client = torch.optim.SGD(
            net.parameters(),
            lr = self.LR_BASE,
            momentum=MOMENTUM,
            weight_decay=WEIGHT_DECAY
        ) 
        
        for iter in range(self.local_ep):
            len_batch = len(self.ldr_train)
            for batch_idx, (images, labels) in enumerate(self.ldr_train):
                images, labels = images.to(self.device), labels.to(self.device)
                optimizer_client.zero_grad()
                #---------forward prop-------------
                fx = net(images)
                client_fx = fx.clone().detach().requires_grad_(True)
                
                # Sending activations to server and receiving gradients from server
                dfx = train_server(client_fx, labels, iter, self.local_ep, self.idx, len_batch)
                
                #--------backward prop -------------
                fx.backward(dfx)
                optimizer_client.step()
                            
            
            #prRed('Client{} Train => Epoch: {}'.format(self.idx, ell))
           
        return net.state_dict() 
    
    def evaluate(self, net, ell):
        net.eval()
           
        with torch.no_grad():
            len_batch = len(self.ldr_test)
            for batch_idx, (images, labels) in enumerate(self.ldr_test):
                images, labels = images.to(self.device), labels.to(self.device)
                #---------forward prop-------------
                fx = net(images)
                
                # Sending activations to server 
                evaluate_server(fx, labels, self.idx, len_batch, ell)
            
            #prRed('Client{} Test => Epoch: {}'.format(self.idx, ell))
            
        return          

#=====================================================================================================
# dataset_iid() will create a dictionary to collect the indices of the data samples randomly for each client
def dataset_iid(dataset, NUM_CLIENTS):
    
    num_items = int(len(dataset)/NUM_CLIENTS)
    dict_users, all_idxs = {}, [i for i in range(len(dataset))]
    for i in range(NUM_CLIENTS):
        dict_users[i] = set(np.random.choice(all_idxs, num_items, replace = False))
        all_idxs = list(set(all_idxs) - dict_users[i])
    return dict_users   

# Non-IID partition using Dirichlet distribution
def dataset_noniid_dirichlet(dataset, NUM_CLIENTS, alpha=0.1, seed=SEED):
    """
    Return dict_users: {client_id -> set(sample_indices)} using Dirichlet(α).
    Lower α → higher imbalance across clients.
    """
    rng = np.random.default_rng(seed)
    # CIFAR-10 and other torchvision datasets store labels in .targets
    labels = np.array(dataset.targets if hasattr(dataset, 'targets') else dataset.df['target'].values)
    n_classes = len(np.unique(labels))
    dict_users = {i: set() for i in range(NUM_CLIENTS)}

    for c in range(n_classes):
        idxs = np.where(labels == c)[0]
        rng.shuffle(idxs)

        # Draw class proportions for each client
        proportions = rng.dirichlet([alpha] * NUM_CLIENTS)

        # Compute index splits
        cuts = (np.cumsum(proportions) * len(idxs)).astype(int)[:-1]
        splits = np.split(idxs, cuts)

        for client_id, split in enumerate(splits):
            dict_users[client_id].update(split.tolist())

    return dict_users

#=============================================================================
#                         Data loading 
#============================================================================= 
from torchvision import datasets, transforms

# CIFAR-10 transforms
CIFAR_MEAN = {
    "CIFAR10":  [0.4914, 0.4822, 0.4465],
    "CIFAR100": [0.5071, 0.4867, 0.4408],
}[DATASET_NAME]
CIFAR_STD = {
    "CIFAR10":  [0.2470, 0.2435, 0.2616],
    "CIFAR100": [0.2675, 0.2565, 0.2761],
}[DATASET_NAME]
    

train_transforms = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(32, padding=4),
    transforms.ToTensor(),
    transforms.Normalize(CIFAR_MEAN, CIFAR_STD)
])

test_transforms = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(CIFAR_MEAN, CIFAR_STD)
])

# Download CIFAR datasets
if DATASET_NAME == "CIFAR10":
    dataset_train = datasets.CIFAR10(root=DATA_ROOT, train=True,  download=True, transform=train_transforms)
    dataset_test  = datasets.CIFAR10(root=DATA_ROOT, train=False, download=True, transform=test_transforms)
    NUM_CLASSES = 10
else:
    dataset_train = datasets.CIFAR100(root=DATA_ROOT, train=True,  download=True, transform=train_transforms)
    dataset_test  = datasets.CIFAR100(root=DATA_ROOT, train=False, download=True, transform=test_transforms)
    NUM_CLASSES = 100



print("Train samples:", len(dataset_train), " Test samples:", len(dataset_test))
print("Example train label:", dataset_train.targets[0])

#=============================================================================
#                         Forgetting metric setup 
#============================================================================= 

from collections import defaultdict

# Treat each global round as a window (quick baseline).
# If you want true distribution shifts, predefine your own windows and fill `val_loaders`.
T = EPOCHS
class DatasetSplit(Dataset):  # (you already have this in both scripts; keep just one copy)
    def __init__(self, dataset, idxs):
        self.dataset, self.idxs = dataset, list(idxs)
    def __len__(self): return len(self.idxs)
    def __getitem__(self, i): return self.dataset[self.idxs[i]]

val_loaders = {}
# Deterministic, disjoint slices of the test set: window t gets items t, t+T, t+2T, ...
rng_idx = np.arange(len(dataset_test))
for t in range(T):
    idxs = rng_idx[t::T]
    val_loaders[t] = DataLoader(
        DatasetSplit(
            dataset_test, 
            idxs),
        batch_size=BATCH_SIZE, 
        shuffle=False, 
        drop_last=False,
        num_workers=NUM_WORKERS,
        pin_memory=pin
    )

best_loss_per_window = defaultdict(lambda: float('inf'))  # stores min historical loss per window
forgetting_log = []  # per round dicts: {"round": t, "mean_forgetting": x, "per_window": {...}}
# ============================================================================

def _eval_loss_on_loader(model_client, model_server, loader, device, criterion):
    """Evaluate mean loss on a loader using split models."""
    # Handle DataParallel transparently
    mc = model_client.module if isinstance(model_client, nn.DataParallel) else model_client
    ms = model_server.module if isinstance(model_server, nn.DataParallel) else model_server
    mc.eval(); ms.eval()
    loss_sum, n = 0.0, 0
    with torch.no_grad():
        for images, labels in loader:
            images, labels = images.to(device), labels.to(device)
            fx = mc(images)
            logits = ms(fx)
            loss = criterion(logits, labels)
            bs = labels.size(0)
            loss_sum += loss.item() * bs
            n += bs
    return loss_sum / max(1, n)


#=============================================================================
#                         Dirichlet non-IID partition
#=============================================================================
dict_users = dataset_noniid_dirichlet(dataset_train, NUM_CLIENTS, alpha=ALPHA, seed=SEED)
dict_users_test = dataset_iid(dataset_test, NUM_CLIENTS)  # keep test IID


#------------ Training And Testing -----------------
net_glob_client.train()
#copy weights
w_glob_client = net_glob_client.state_dict()

#=============================================================================

# Federation takes place after certain local epochs in train() client-side
# this epoch is global epoch, also known as rounds
for iter in range(EPOCHS):
    # ---- START TIMER (train + test + FedAvg only) ----
    _sync_cuda()
    t_start = time.perf_counter()
    # --------------------------------------------------

    m = max(int(FRAC * NUM_CLIENTS), 1)
    idxs_users = np.random.choice(range(NUM_CLIENTS), m, replace=False)
    w_locals_client = []

    for idx in idxs_users:
        local = Client(net_glob_client, idx, LR_BASE, device,
                       dataset_train=dataset_train, dataset_test=dataset_test,
                       idxs=dict_users[idx], idxs_test=dict_users_test[idx])
        # Training
        w_client = local.train(net=copy.deepcopy(net_glob_client).to(device))
        w_locals_client.append(copy.deepcopy(w_client))

        # Testing
        local.evaluate(net=copy.deepcopy(net_glob_client).to(device), ell=iter)

    # ---------- Federation at client side ----------
    print("------------------------------------------------------------")
    print("------ Fed Server: Federation process at Client-Side -------")
    print("------------------------------------------------------------")
    w_glob_client = FedAvg(w_locals_client)
    net_glob_client.load_state_dict(w_glob_client)

    # ---- STOP TIMER & LOG ----
    _sync_cuda()
    dt = time.perf_counter() - t_start
    round_time_collect.append(dt)
    # ---------------------------

    # === Forgetting update at end of round `iter` (post-FedAvg, not timed) ===
    t = iter  # current window id

    # 1) Update the "best so far" for the CURRENT window using the current model
    L_cur_t = _eval_loss_on_loader(net_glob_client, net_glob_server,
                                   val_loaders[t], device, criterion)
    best_loss_per_window[t] = min(best_loss_per_window[t], L_cur_t)

    # 2) Compute forgetting on all PAST windows t_prev < t
    per_win_fgt = {}
    for t_prev in range(t):
        L_now = _eval_loss_on_loader(net_glob_client, net_glob_server,
                                     val_loaders[t_prev], device, criterion)
        Fgt = L_now - best_loss_per_window[t_prev]
        per_win_fgt[t_prev] = Fgt

    mean_fgt = float(np.mean(list(per_win_fgt.values()))) if per_win_fgt else 0.0
    forgetting_log.append({"round": t, "mean_forgetting": mean_fgt, "per_window": per_win_fgt})
    print(f"Forgetting : Round {t}, mean_forgetting : {mean_fgt:.3f}")
    print("==========================================================")

    
#===================================================================================     

print("Training and Evaluation completed!")    

#===============================================================================
# Save output data to .excel file (we use for comparision plots)
n = min(len(acc_train_collect), len(acc_test_collect), len(round_time_collect), len(forgetting_log))
round_process = [i for i in range(1, len(acc_train_collect)+1)]
mean_fgt_series = [d["mean_forgetting"] for d in forgetting_log[:n]]

df = DataFrame({
    'round': round_process,
    'acc_train': acc_train_collect[:n],
    'acc_test':  acc_test_collect[:n],
    'round_time_sec': round_time_collect[:n],
    'mean_FgT_loss': mean_fgt_series,
})


# write CSV — easier for scripting/comparison tools
file_name_csv = program + ".csv"
df.to_csv(file_name_csv, index=False)

print("Saved:", file_name_csv)

#=============================================================================
#                         Program Completed
#=============================================================================
# Out:
# ---------SFLV2 - CIFAR-10 α=0.5----------
# NVIDIA H200
# ResNet18_client_side(
#   (layer1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (layer2): Sequential(
#     (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (layer3): Sequential(
#     (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (layer4): Sequential(
#     (0): Baseblock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dim_change): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2))
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Baseblock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer5): Sequential(
#     (0): Baseblock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dim_change): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2))
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Baseblock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer6): Sequential(
#     (0): Baseblock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dim_change): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2))
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Baseblock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
# )
# ResNet18_server_side(
#   (fc): Linear(in_features=512, out_features=10, bias=True)
# )
# Train samples: 50000  Test samples: 10000
# Example train label: 6
#  Client3 Train => Local Epoch: 0 	Acc: 44.561 	Loss: 1.6729
#  Client3 Train => Local Epoch: 1 	Acc: 50.743 	Loss: 1.4687
#  Client3 Train => Local Epoch: 2 	Acc: 52.375 	Loss: 1.4026
#  Client3 Train => Local Epoch: 3 	Acc: 55.603 	Loss: 1.3030
#  Client3 Train => Local Epoch: 4 	Acc: 58.517 	Loss: 1.2185
#  Client3 Test =>                   	Acc: 8.112 	Loss: 3.1058
#  Client1 Train => Local Epoch: 0 	Acc: 50.035 	Loss: 1.6710
#  Client1 Train => Local Epoch: 1 	Acc: 61.555 	Loss: 1.1613
#  Client1 Train => Local Epoch: 2 	Acc: 65.396 	Loss: 1.0620
#  Client1 Train => Local Epoch: 3 	Acc: 67.837 	Loss: 0.9891
#  Client1 Train => Local Epoch: 4 	Acc: 69.554 	Loss: 0.9329
#  Client1 Test =>                   	Acc: 9.489 	Loss: 3.6727
#  Client2 Train => Local Epoch: 0 	Acc: 43.673 	Loss: 1.7446
#  Client2 Train => Local Epoch: 1 	Acc: 53.209 	Loss: 1.3653
#  Client2 Train => Local Epoch: 2 	Acc: 55.890 	Loss: 1.2451
#  Client2 Train => Local Epoch: 3 	Acc: 58.624 	Loss: 1.1682
#  Client2 Train => Local Epoch: 4 	Acc: 61.183 	Loss: 1.1061
#  Client2 Test =>                   	Acc: 9.479 	Loss: 3.7205
#  Client0 Train => Local Epoch: 0 	Acc: 27.533 	Loss: 2.1449
#  Client0 Train => Local Epoch: 1 	Acc: 39.109 	Loss: 1.7235
#  Client0 Train => Local Epoch: 2 	Acc: 43.186 	Loss: 1.5713
#  Client0 Train => Local Epoch: 3 	Acc: 46.446 	Loss: 1.4729
#  Client0 Train => Local Epoch: 4 	Acc: 49.151 	Loss: 1.3925
#  Client0 Test =>                   	Acc: 10.836 	Loss: 2.9859
#  Client8 Train => Local Epoch: 0 	Acc: 35.512 	Loss: 1.8082
#  Client8 Train => Local Epoch: 1 	Acc: 48.466 	Loss: 1.3889
#  Client8 Train => Local Epoch: 2 	Acc: 53.074 	Loss: 1.2561
#  Client8 Train => Local Epoch: 3 	Acc: 55.253 	Loss: 1.1794
#  Client8 Train => Local Epoch: 4 	Acc: 57.503 	Loss: 1.1065
#  Client8 Test =>                   	Acc: 9.284 	Loss: 3.3597
#  Client7 Train => Local Epoch: 0 	Acc: 46.347 	Loss: 1.6074
#  Client7 Train => Local Epoch: 1 	Acc: 55.026 	Loss: 1.2630
#  Client7 Train => Local Epoch: 2 	Acc: 58.267 	Loss: 1.1725
#  Client7 Train => Local Epoch: 3 	Acc: 61.200 	Loss: 1.1012
#  Client7 Train => Local Epoch: 4 	Acc: 63.768 	Loss: 1.0420
#  Client7 Test =>                   	Acc: 11.699 	Loss: 3.2659
#  Client6 Train => Local Epoch: 0 	Acc: 41.122 	Loss: 1.7816
#  Client6 Train => Local Epoch: 1 	Acc: 52.959 	Loss: 1.3544
#  Client6 Train => Local Epoch: 2 	Acc: 56.889 	Loss: 1.2446
#  Client6 Train => Local Epoch: 3 	Acc: 59.916 	Loss: 1.1524
#  Client6 Train => Local Epoch: 4 	Acc: 61.409 	Loss: 1.1138
#  Client6 Test =>                   	Acc: 9.998 	Loss: 3.0266
#  Client9 Train => Local Epoch: 0 	Acc: 40.744 	Loss: 1.7454
#  Client9 Train => Local Epoch: 1 	Acc: 50.904 	Loss: 1.3785
#  Client9 Train => Local Epoch: 2 	Acc: 53.616 	Loss: 1.2634
#  Client9 Train => Local Epoch: 3 	Acc: 57.687 	Loss: 1.1888
#  Client9 Train => Local Epoch: 4 	Acc: 59.057 	Loss: 1.1281
#  Client9 Test =>                   	Acc: 9.958 	Loss: 3.0204
#  Client5 Train => Local Epoch: 0 	Acc: 29.168 	Loss: 1.9323
#  Client5 Train => Local Epoch: 1 	Acc: 40.863 	Loss: 1.6249
#  Client5 Train => Local Epoch: 2 	Acc: 48.335 	Loss: 1.4582
#  Client5 Train => Local Epoch: 3 	Acc: 51.131 	Loss: 1.3768
#  Client5 Train => Local Epoch: 4 	Acc: 53.914 	Loss: 1.3110
#  Client5 Test =>                   	Acc: 10.234 	Loss: 2.9612
#  Client4 Train => Local Epoch: 0 	Acc: 34.974 	Loss: 1.8307
#  Client4 Train => Local Epoch: 1 	Acc: 46.272 	Loss: 1.5026
#  Client4 Train => Local Epoch: 2 	Acc: 49.534 	Loss: 1.3958
#  Client4 Train => Local Epoch: 3 	Acc: 52.091 	Loss: 1.3267
#  Client4 Train => Local Epoch: 4 	Acc: 55.070 	Loss: 1.2626
#  Client4 Test =>                   	Acc: 9.139 	Loss: 2.9287
# ====================== SERVER V1==========================
#  Train: Round   0, Avg Accuracy 58.913 | Avg Loss 1.161
#  Test: Round   0, Avg Accuracy 9.823 | Avg Loss 3.205
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Forgetting : Round 0, mean_forgetting : 0.000
# ==========================================================
#  Client3 Train => Local Epoch: 0 	Acc: 49.461 	Loss: 1.4979
#  Client3 Train => Local Epoch: 1 	Acc: 55.831 	Loss: 1.2677
#  Client3 Train => Local Epoch: 2 	Acc: 58.031 	Loss: 1.1952
#  Client3 Train => Local Epoch: 3 	Acc: 61.574 	Loss: 1.1111
#  Client3 Train => Local Epoch: 4 	Acc: 62.628 	Loss: 1.0881
#  Client3 Test =>                   	Acc: 13.460 	Loss: 3.2780
#  Client4 Train => Local Epoch: 0 	Acc: 49.749 	Loss: 1.4782
#  Client4 Train => Local Epoch: 1 	Acc: 55.568 	Loss: 1.2558
#  Client4 Train => Local Epoch: 2 	Acc: 57.088 	Loss: 1.2052
#  Client4 Train => Local Epoch: 3 	Acc: 58.107 	Loss: 1.1597
#  Client4 Train => Local Epoch: 4 	Acc: 58.773 	Loss: 1.1331
#  Client4 Test =>                   	Acc: 19.157 	Loss: 3.1100
#  Client2 Train => Local Epoch: 0 	Acc: 54.087 	Loss: 1.3323
#  Client2 Train => Local Epoch: 1 	Acc: 59.547 	Loss: 1.1416
#  Client2 Train => Local Epoch: 2 	Acc: 61.820 	Loss: 1.0680
#  Client2 Train => Local Epoch: 3 	Acc: 64.924 	Loss: 0.9982
#  Client2 Train => Local Epoch: 4 	Acc: 65.956 	Loss: 0.9624
#  Client2 Test =>                   	Acc: 22.016 	Loss: 2.4251
#  Client9 Train => Local Epoch: 0 	Acc: 51.330 	Loss: 1.3598
#  Client9 Train => Local Epoch: 1 	Acc: 55.867 	Loss: 1.2168
#  Client9 Train => Local Epoch: 2 	Acc: 59.371 	Loss: 1.1210
#  Client9 Train => Local Epoch: 3 	Acc: 61.175 	Loss: 1.0792
#  Client9 Train => Local Epoch: 4 	Acc: 62.261 	Loss: 1.0437
#  Client9 Test =>                   	Acc: 23.845 	Loss: 2.4854
#  Client5 Train => Local Epoch: 0 	Acc: 47.078 	Loss: 1.4935
#  Client5 Train => Local Epoch: 1 	Acc: 52.023 	Loss: 1.3382
#  Client5 Train => Local Epoch: 2 	Acc: 55.063 	Loss: 1.2734
#  Client5 Train => Local Epoch: 3 	Acc: 56.584 	Loss: 1.2218
#  Client5 Train => Local Epoch: 4 	Acc: 56.993 	Loss: 1.1929
#  Client5 Test =>                   	Acc: 24.599 	Loss: 2.3217
#  Client1 Train => Local Epoch: 0 	Acc: 64.346 	Loss: 1.1347
#  Client1 Train => Local Epoch: 1 	Acc: 70.545 	Loss: 0.9209
#  Client1 Train => Local Epoch: 2 	Acc: 71.624 	Loss: 0.8727
#  Client1 Train => Local Epoch: 3 	Acc: 72.948 	Loss: 0.8314
#  Client1 Train => Local Epoch: 4 	Acc: 73.762 	Loss: 0.8153
#  Client1 Test =>                   	Acc: 15.100 	Loss: 3.5893
#  Client8 Train => Local Epoch: 0 	Acc: 49.570 	Loss: 1.3886
#  Client8 Train => Local Epoch: 1 	Acc: 59.442 	Loss: 1.1190
#  Client8 Train => Local Epoch: 2 	Acc: 59.776 	Loss: 1.0592
#  Client8 Train => Local Epoch: 3 	Acc: 61.489 	Loss: 1.0071
#  Client8 Train => Local Epoch: 4 	Acc: 63.698 	Loss: 0.9582
#  Client8 Test =>                   	Acc: 22.309 	Loss: 2.6238
#  Client0 Train => Local Epoch: 0 	Acc: 45.011 	Loss: 1.5630
#  Client0 Train => Local Epoch: 1 	Acc: 52.177 	Loss: 1.3436
#  Client0 Train => Local Epoch: 2 	Acc: 54.101 	Loss: 1.2616
#  Client0 Train => Local Epoch: 3 	Acc: 54.868 	Loss: 1.2136
#  Client0 Train => Local Epoch: 4 	Acc: 57.460 	Loss: 1.1664
#  Client0 Test =>                   	Acc: 21.276 	Loss: 2.6943
#  Client6 Train => Local Epoch: 0 	Acc: 54.092 	Loss: 1.3226
#  Client6 Train => Local Epoch: 1 	Acc: 59.155 	Loss: 1.1724
#  Client6 Train => Local Epoch: 2 	Acc: 61.239 	Loss: 1.1187
#  Client6 Train => Local Epoch: 3 	Acc: 62.387 	Loss: 1.0678
#  Client6 Train => Local Epoch: 4 	Acc: 64.798 	Loss: 1.0181
#  Client6 Test =>                   	Acc: 22.545 	Loss: 2.7126
#  Client7 Train => Local Epoch: 0 	Acc: 55.478 	Loss: 1.2946
#  Client7 Train => Local Epoch: 1 	Acc: 63.225 	Loss: 1.0638
#  Client7 Train => Local Epoch: 2 	Acc: 66.442 	Loss: 0.9787
#  Client7 Train => Local Epoch: 3 	Acc: 67.010 	Loss: 0.9434
#  Client7 Train => Local Epoch: 4 	Acc: 69.001 	Loss: 0.9013
#  Client7 Test =>                   	Acc: 15.736 	Loss: 3.2538
# ====================== SERVER V1==========================
#  Train: Round   1, Avg Accuracy 63.533 | Avg Loss 1.028
#  Test: Round   1, Avg Accuracy 20.004 | Avg Loss 2.849
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Forgetting : Round 1, mean_forgetting : -0.107
# ==========================================================
#  Client0 Train => Local Epoch: 0 	Acc: 52.986 	Loss: 1.3279
#  Client0 Train => Local Epoch: 1 	Acc: 58.547 	Loss: 1.1464
#  Client0 Train => Local Epoch: 2 	Acc: 59.897 	Loss: 1.1049
#  Client0 Train => Local Epoch: 3 	Acc: 61.537 	Loss: 1.0604
#  Client0 Train => Local Epoch: 4 	Acc: 62.823 	Loss: 1.0395
#  Client0 Test =>                   	Acc: 30.179 	Loss: 1.9574
#  Client2 Train => Local Epoch: 0 	Acc: 60.041 	Loss: 1.1411
#  Client2 Train => Local Epoch: 1 	Acc: 64.782 	Loss: 0.9940
#  Client2 Train => Local Epoch: 2 	Acc: 67.274 	Loss: 0.9327
#  Client2 Train => Local Epoch: 3 	Acc: 68.373 	Loss: 0.8991
#  Client2 Train => Local Epoch: 4 	Acc: 70.664 	Loss: 0.8463
#  Client2 Test =>                   	Acc: 38.527 	Loss: 1.6908
#  Client5 Train => Local Epoch: 0 	Acc: 53.887 	Loss: 1.3278
#  Client5 Train => Local Epoch: 1 	Acc: 56.791 	Loss: 1.2101
#  Client5 Train => Local Epoch: 2 	Acc: 58.854 	Loss: 1.1674
#  Client5 Train => Local Epoch: 3 	Acc: 60.232 	Loss: 1.1266
#  Client5 Train => Local Epoch: 4 	Acc: 61.238 	Loss: 1.0783
#  Client5 Test =>                   	Acc: 41.416 	Loss: 1.5274
#  Client7 Train => Local Epoch: 0 	Acc: 62.185 	Loss: 1.1426
#  Client7 Train => Local Epoch: 1 	Acc: 67.458 	Loss: 0.9445
#  Client7 Train => Local Epoch: 2 	Acc: 69.589 	Loss: 0.8877
#  Client7 Train => Local Epoch: 3 	Acc: 71.518 	Loss: 0.8433
#  Client7 Train => Local Epoch: 4 	Acc: 72.459 	Loss: 0.8070
#  Client7 Test =>                   	Acc: 24.683 	Loss: 2.5571
#  Client1 Train => Local Epoch: 0 	Acc: 65.852 	Loss: 1.1353
#  Client1 Train => Local Epoch: 1 	Acc: 74.496 	Loss: 0.7984
#  Client1 Train => Local Epoch: 2 	Acc: 76.439 	Loss: 0.7454
#  Client1 Train => Local Epoch: 3 	Acc: 76.761 	Loss: 0.7091
#  Client1 Train => Local Epoch: 4 	Acc: 77.958 	Loss: 0.6799
#  Client1 Test =>                   	Acc: 23.310 	Loss: 2.5978
#  Client8 Train => Local Epoch: 0 	Acc: 55.916 	Loss: 1.2573
#  Client8 Train => Local Epoch: 1 	Acc: 63.470 	Loss: 1.0029
#  Client8 Train => Local Epoch: 2 	Acc: 64.754 	Loss: 0.9387
#  Client8 Train => Local Epoch: 3 	Acc: 66.245 	Loss: 0.9021
#  Client8 Train => Local Epoch: 4 	Acc: 67.103 	Loss: 0.8838
#  Client8 Test =>                   	Acc: 30.102 	Loss: 2.1336
#  Client9 Train => Local Epoch: 0 	Acc: 56.512 	Loss: 1.1873
#  Client9 Train => Local Epoch: 1 	Acc: 59.665 	Loss: 1.1079
#  Client9 Train => Local Epoch: 2 	Acc: 61.991 	Loss: 1.0404
#  Client9 Train => Local Epoch: 3 	Acc: 65.024 	Loss: 0.9689
#  Client9 Train => Local Epoch: 4 	Acc: 65.828 	Loss: 0.9565
#  Client9 Test =>                   	Acc: 38.214 	Loss: 1.8532
#  Client6 Train => Local Epoch: 0 	Acc: 58.931 	Loss: 1.1738
#  Client6 Train => Local Epoch: 1 	Acc: 63.125 	Loss: 1.0616
#  Client6 Train => Local Epoch: 2 	Acc: 64.148 	Loss: 1.0088
#  Client6 Train => Local Epoch: 3 	Acc: 65.354 	Loss: 0.9604
#  Client6 Train => Local Epoch: 4 	Acc: 67.100 	Loss: 0.9385
#  Client6 Test =>                   	Acc: 32.819 	Loss: 1.9898
#  Client3 Train => Local Epoch: 0 	Acc: 53.627 	Loss: 1.3919
#  Client3 Train => Local Epoch: 1 	Acc: 61.657 	Loss: 1.1217
#  Client3 Train => Local Epoch: 2 	Acc: 63.949 	Loss: 1.0532
#  Client3 Train => Local Epoch: 3 	Acc: 63.782 	Loss: 1.0538
#  Client3 Train => Local Epoch: 4 	Acc: 65.096 	Loss: 1.0033
#  Client3 Test =>                   	Acc: 32.664 	Loss: 2.1043
#  Client4 Train => Local Epoch: 0 	Acc: 54.751 	Loss: 1.2807
#  Client4 Train => Local Epoch: 1 	Acc: 60.641 	Loss: 1.1065
#  Client4 Train => Local Epoch: 2 	Acc: 61.457 	Loss: 1.0706
#  Client4 Train => Local Epoch: 3 	Acc: 63.608 	Loss: 1.0149
#  Client4 Train => Local Epoch: 4 	Acc: 65.276 	Loss: 0.9786
#  Client4 Test =>                   	Acc: 31.735 	Loss: 2.2117
# ====================== SERVER V1==========================
#  Train: Round   2, Avg Accuracy 67.554 | Avg Loss 0.921
#  Test: Round   2, Avg Accuracy 32.365 | Avg Loss 2.062
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Forgetting : Round 2, mean_forgetting : -0.746
# ==========================================================
#  Client5 Train => Local Epoch: 0 	Acc: 57.039 	Loss: 1.2282
#  Client5 Train => Local Epoch: 1 	Acc: 60.923 	Loss: 1.1015
#  Client5 Train => Local Epoch: 2 	Acc: 62.470 	Loss: 1.0528
#  Client5 Train => Local Epoch: 3 	Acc: 64.678 	Loss: 1.0006
#  Client5 Train => Local Epoch: 4 	Acc: 65.038 	Loss: 0.9749
#  Client5 Test =>                   	Acc: 48.027 	Loss: 1.4031
#  Client4 Train => Local Epoch: 0 	Acc: 63.805 	Loss: 1.0587
#  Client4 Train => Local Epoch: 1 	Acc: 66.828 	Loss: 0.9577
#  Client4 Train => Local Epoch: 2 	Acc: 68.888 	Loss: 0.9128
#  Client4 Train => Local Epoch: 3 	Acc: 69.304 	Loss: 0.8831
#  Client4 Train => Local Epoch: 4 	Acc: 70.153 	Loss: 0.8579
#  Client4 Test =>                   	Acc: 38.810 	Loss: 1.8572
#  Client7 Train => Local Epoch: 0 	Acc: 66.615 	Loss: 0.9976
#  Client7 Train => Local Epoch: 1 	Acc: 71.594 	Loss: 0.8350
#  Client7 Train => Local Epoch: 2 	Acc: 72.880 	Loss: 0.7814
#  Client7 Train => Local Epoch: 3 	Acc: 74.014 	Loss: 0.7574
#  Client7 Train => Local Epoch: 4 	Acc: 75.767 	Loss: 0.7103
#  Client7 Test =>                   	Acc: 32.321 	Loss: 2.1689
#  Client1 Train => Local Epoch: 0 	Acc: 68.475 	Loss: 1.0082
#  Client1 Train => Local Epoch: 1 	Acc: 77.912 	Loss: 0.7146
#  Client1 Train => Local Epoch: 2 	Acc: 78.541 	Loss: 0.6735
#  Client1 Train => Local Epoch: 3 	Acc: 78.748 	Loss: 0.6477
#  Client1 Train => Local Epoch: 4 	Acc: 80.020 	Loss: 0.6133
#  Client1 Test =>                   	Acc: 31.469 	Loss: 2.1447
#  Client3 Train => Local Epoch: 0 	Acc: 58.525 	Loss: 1.1896
#  Client3 Train => Local Epoch: 1 	Acc: 65.103 	Loss: 1.0302
#  Client3 Train => Local Epoch: 2 	Acc: 65.370 	Loss: 0.9998
#  Client3 Train => Local Epoch: 3 	Acc: 67.237 	Loss: 0.9483
#  Client3 Train => Local Epoch: 4 	Acc: 68.864 	Loss: 0.8972
#  Client3 Test =>                   	Acc: 34.207 	Loss: 1.9804
#  Client9 Train => Local Epoch: 0 	Acc: 60.638 	Loss: 1.1116
#  Client9 Train => Local Epoch: 1 	Acc: 60.377 	Loss: 1.1101
#  Client9 Train => Local Epoch: 2 	Acc: 64.014 	Loss: 0.9943
#  Client9 Train => Local Epoch: 3 	Acc: 66.552 	Loss: 0.9181
#  Client9 Train => Local Epoch: 4 	Acc: 68.793 	Loss: 0.8697
#  Client9 Test =>                   	Acc: 43.932 	Loss: 1.5767
#  Client8 Train => Local Epoch: 0 	Acc: 62.274 	Loss: 1.0076
#  Client8 Train => Local Epoch: 1 	Acc: 66.760 	Loss: 0.8901
#  Client8 Train => Local Epoch: 2 	Acc: 68.626 	Loss: 0.8405
#  Client8 Train => Local Epoch: 3 	Acc: 68.699 	Loss: 0.8145
#  Client8 Train => Local Epoch: 4 	Acc: 69.604 	Loss: 0.8150
#  Client8 Test =>                   	Acc: 38.254 	Loss: 1.9698
#  Client0 Train => Local Epoch: 0 	Acc: 56.827 	Loss: 1.2622
#  Client0 Train => Local Epoch: 1 	Acc: 63.128 	Loss: 1.0432
#  Client0 Train => Local Epoch: 2 	Acc: 66.188 	Loss: 0.9832
#  Client0 Train => Local Epoch: 3 	Acc: 66.181 	Loss: 0.9478
#  Client0 Train => Local Epoch: 4 	Acc: 68.433 	Loss: 0.9029
#  Client0 Test =>                   	Acc: 39.965 	Loss: 1.6796
#  Client2 Train => Local Epoch: 0 	Acc: 65.128 	Loss: 1.0163
#  Client2 Train => Local Epoch: 1 	Acc: 68.972 	Loss: 0.8883
#  Client2 Train => Local Epoch: 2 	Acc: 70.865 	Loss: 0.8333
#  Client2 Train => Local Epoch: 3 	Acc: 72.256 	Loss: 0.7833
#  Client2 Train => Local Epoch: 4 	Acc: 73.473 	Loss: 0.7541
#  Client2 Test =>                   	Acc: 47.303 	Loss: 1.4914
#  Client6 Train => Local Epoch: 0 	Acc: 62.301 	Loss: 1.0948
#  Client6 Train => Local Epoch: 1 	Acc: 66.088 	Loss: 0.9744
#  Client6 Train => Local Epoch: 2 	Acc: 67.793 	Loss: 0.9143
#  Client6 Train => Local Epoch: 3 	Acc: 69.267 	Loss: 0.8737
#  Client6 Train => Local Epoch: 4 	Acc: 70.704 	Loss: 0.8332
#  Client6 Test =>                   	Acc: 42.656 	Loss: 1.6120
# ====================== SERVER V1==========================
#  Train: Round   3, Avg Accuracy 71.085 | Avg Loss 0.823
#  Test: Round   3, Avg Accuracy 39.694 | Avg Loss 1.788
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Forgetting : Round 3, mean_forgetting : -0.777
# ==========================================================
#  Client2 Train => Local Epoch: 0 	Acc: 67.154 	Loss: 0.9451
#  Client2 Train => Local Epoch: 1 	Acc: 71.709 	Loss: 0.8048
#  Client2 Train => Local Epoch: 2 	Acc: 74.063 	Loss: 0.7456
#  Client2 Train => Local Epoch: 3 	Acc: 75.561 	Loss: 0.7056
#  Client2 Train => Local Epoch: 4 	Acc: 76.600 	Loss: 0.6692
#  Client2 Test =>                   	Acc: 53.253 	Loss: 1.3021
#  Client8 Train => Local Epoch: 0 	Acc: 63.500 	Loss: 1.0419
#  Client8 Train => Local Epoch: 1 	Acc: 67.698 	Loss: 0.8472
#  Client8 Train => Local Epoch: 2 	Acc: 70.000 	Loss: 0.7946
#  Client8 Train => Local Epoch: 3 	Acc: 70.898 	Loss: 0.7616
#  Client8 Train => Local Epoch: 4 	Acc: 73.072 	Loss: 0.7092
#  Client8 Test =>                   	Acc: 44.417 	Loss: 1.6483
#  Client5 Train => Local Epoch: 0 	Acc: 61.014 	Loss: 1.1268
#  Client5 Train => Local Epoch: 1 	Acc: 65.208 	Loss: 0.9845
#  Client5 Train => Local Epoch: 2 	Acc: 66.628 	Loss: 0.9513
#  Client5 Train => Local Epoch: 3 	Acc: 68.317 	Loss: 0.8987
#  Client5 Train => Local Epoch: 4 	Acc: 70.117 	Loss: 0.8610
#  Client5 Test =>                   	Acc: 53.462 	Loss: 1.2923
#  Client0 Train => Local Epoch: 0 	Acc: 64.512 	Loss: 0.9744
#  Client0 Train => Local Epoch: 1 	Acc: 68.056 	Loss: 0.9058
#  Client0 Train => Local Epoch: 2 	Acc: 69.483 	Loss: 0.8435
#  Client0 Train => Local Epoch: 3 	Acc: 71.558 	Loss: 0.8216
#  Client0 Train => Local Epoch: 4 	Acc: 73.170 	Loss: 0.7754
#  Client0 Test =>                   	Acc: 47.724 	Loss: 1.4928
#  Client6 Train => Local Epoch: 0 	Acc: 64.895 	Loss: 0.9928
#  Client6 Train => Local Epoch: 1 	Acc: 68.098 	Loss: 0.8998
#  Client6 Train => Local Epoch: 2 	Acc: 71.043 	Loss: 0.8378
#  Client6 Train => Local Epoch: 3 	Acc: 72.152 	Loss: 0.8006
#  Client6 Train => Local Epoch: 4 	Acc: 72.686 	Loss: 0.7689
#  Client6 Test =>                   	Acc: 47.956 	Loss: 1.4721
#  Client4 Train => Local Epoch: 0 	Acc: 64.353 	Loss: 1.0563
#  Client4 Train => Local Epoch: 1 	Acc: 68.986 	Loss: 0.8834
#  Client4 Train => Local Epoch: 2 	Acc: 71.775 	Loss: 0.8410
#  Client4 Train => Local Epoch: 3 	Acc: 73.072 	Loss: 0.7873
#  Client4 Train => Local Epoch: 4 	Acc: 74.615 	Loss: 0.7582
#  Client4 Test =>                   	Acc: 45.077 	Loss: 1.6484
#  Client3 Train => Local Epoch: 0 	Acc: 62.231 	Loss: 1.1147
#  Client3 Train => Local Epoch: 1 	Acc: 67.746 	Loss: 0.9447
#  Client3 Train => Local Epoch: 2 	Acc: 68.691 	Loss: 0.9130
#  Client3 Train => Local Epoch: 3 	Acc: 70.332 	Loss: 0.8544
#  Client3 Train => Local Epoch: 4 	Acc: 71.567 	Loss: 0.8186
#  Client3 Test =>                   	Acc: 49.209 	Loss: 1.4881
#  Client7 Train => Local Epoch: 0 	Acc: 70.177 	Loss: 0.8739
#  Client7 Train => Local Epoch: 1 	Acc: 74.088 	Loss: 0.7602
#  Client7 Train => Local Epoch: 2 	Acc: 75.129 	Loss: 0.7094
#  Client7 Train => Local Epoch: 3 	Acc: 76.905 	Loss: 0.6688
#  Client7 Train => Local Epoch: 4 	Acc: 78.125 	Loss: 0.6466
#  Client7 Test =>                   	Acc: 38.682 	Loss: 1.9137
#  Client9 Train => Local Epoch: 0 	Acc: 64.932 	Loss: 1.0129
#  Client9 Train => Local Epoch: 1 	Acc: 65.869 	Loss: 0.9424
#  Client9 Train => Local Epoch: 2 	Acc: 68.447 	Loss: 0.8649
#  Client9 Train => Local Epoch: 3 	Acc: 69.224 	Loss: 0.8544
#  Client9 Train => Local Epoch: 4 	Acc: 72.164 	Loss: 0.7651
#  Client9 Test =>                   	Acc: 50.310 	Loss: 1.4897
#  Client1 Train => Local Epoch: 0 	Acc: 70.368 	Loss: 0.9582
#  Client1 Train => Local Epoch: 1 	Acc: 79.528 	Loss: 0.6482
#  Client1 Train => Local Epoch: 2 	Acc: 81.118 	Loss: 0.5904
#  Client1 Train => Local Epoch: 3 	Acc: 81.690 	Loss: 0.5626
#  Client1 Train => Local Epoch: 4 	Acc: 82.466 	Loss: 0.5451
#  Client1 Test =>                   	Acc: 38.834 	Loss: 1.7878
# ====================== SERVER V1==========================
#  Train: Round   4, Avg Accuracy 74.458 | Avg Loss 0.732
#  Test: Round   4, Avg Accuracy 46.892 | Avg Loss 1.554
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Forgetting : Round 4, mean_forgetting : -0.535
# ==========================================================
#  Client7 Train => Local Epoch: 0 	Acc: 71.694 	Loss: 0.8727
#  Client7 Train => Local Epoch: 1 	Acc: 76.366 	Loss: 0.6898
#  Client7 Train => Local Epoch: 2 	Acc: 77.382 	Loss: 0.6601
#  Client7 Train => Local Epoch: 3 	Acc: 79.347 	Loss: 0.6068
#  Client7 Train => Local Epoch: 4 	Acc: 79.534 	Loss: 0.5853
#  Client7 Test =>                   	Acc: 45.309 	Loss: 1.6825
#  Client2 Train => Local Epoch: 0 	Acc: 69.045 	Loss: 0.9332
#  Client2 Train => Local Epoch: 1 	Acc: 74.385 	Loss: 0.7347
#  Client2 Train => Local Epoch: 2 	Acc: 75.587 	Loss: 0.6950
#  Client2 Train => Local Epoch: 3 	Acc: 77.808 	Loss: 0.6452
#  Client2 Train => Local Epoch: 4 	Acc: 78.261 	Loss: 0.6087
#  Client2 Test =>                   	Acc: 57.964 	Loss: 1.1522
#  Client6 Train => Local Epoch: 0 	Acc: 67.423 	Loss: 0.9388
#  Client6 Train => Local Epoch: 1 	Acc: 71.796 	Loss: 0.8042
#  Client6 Train => Local Epoch: 2 	Acc: 73.294 	Loss: 0.7673
#  Client6 Train => Local Epoch: 3 	Acc: 74.426 	Loss: 0.7225
#  Client6 Train => Local Epoch: 4 	Acc: 75.690 	Loss: 0.6958
#  Client6 Test =>                   	Acc: 55.809 	Loss: 1.2174
#  Client3 Train => Local Epoch: 0 	Acc: 64.386 	Loss: 1.0774
#  Client3 Train => Local Epoch: 1 	Acc: 68.949 	Loss: 0.8913
#  Client3 Train => Local Epoch: 2 	Acc: 70.869 	Loss: 0.8364
#  Client3 Train => Local Epoch: 3 	Acc: 71.267 	Loss: 0.8183
#  Client3 Train => Local Epoch: 4 	Acc: 72.457 	Loss: 0.7776
#  Client3 Test =>                   	Acc: 51.573 	Loss: 1.3891
#  Client8 Train => Local Epoch: 0 	Acc: 66.461 	Loss: 0.9708
#  Client8 Train => Local Epoch: 1 	Acc: 70.761 	Loss: 0.7901
#  Client8 Train => Local Epoch: 2 	Acc: 71.910 	Loss: 0.7309
#  Client8 Train => Local Epoch: 3 	Acc: 73.630 	Loss: 0.6845
#  Client8 Train => Local Epoch: 4 	Acc: 75.375 	Loss: 0.6510
#  Client8 Test =>                   	Acc: 47.218 	Loss: 1.5948
#  Client9 Train => Local Epoch: 0 	Acc: 68.492 	Loss: 0.9141
#  Client9 Train => Local Epoch: 1 	Acc: 68.793 	Loss: 0.8695
#  Client9 Train => Local Epoch: 2 	Acc: 70.148 	Loss: 0.8157
#  Client9 Train => Local Epoch: 3 	Acc: 73.554 	Loss: 0.7426
#  Client9 Train => Local Epoch: 4 	Acc: 73.847 	Loss: 0.7332
#  Client9 Test =>                   	Acc: 53.839 	Loss: 1.3728
#  Client4 Train => Local Epoch: 0 	Acc: 65.571 	Loss: 1.0404
#  Client4 Train => Local Epoch: 1 	Acc: 72.712 	Loss: 0.8064
#  Client4 Train => Local Epoch: 2 	Acc: 74.564 	Loss: 0.7552
#  Client4 Train => Local Epoch: 3 	Acc: 76.412 	Loss: 0.6961
#  Client4 Train => Local Epoch: 4 	Acc: 76.998 	Loss: 0.6772
#  Client4 Test =>                   	Acc: 48.778 	Loss: 1.4857
#  Client5 Train => Local Epoch: 0 	Acc: 65.088 	Loss: 0.9929
#  Client5 Train => Local Epoch: 1 	Acc: 68.624 	Loss: 0.9003
#  Client5 Train => Local Epoch: 2 	Acc: 70.413 	Loss: 0.8380
#  Client5 Train => Local Epoch: 3 	Acc: 72.143 	Loss: 0.7956
#  Client5 Train => Local Epoch: 4 	Acc: 72.057 	Loss: 0.7776
#  Client5 Test =>                   	Acc: 57.728 	Loss: 1.1901
#  Client0 Train => Local Epoch: 0 	Acc: 69.399 	Loss: 0.8548
#  Client0 Train => Local Epoch: 1 	Acc: 71.600 	Loss: 0.8021
#  Client0 Train => Local Epoch: 2 	Acc: 74.654 	Loss: 0.7567
#  Client0 Train => Local Epoch: 3 	Acc: 75.634 	Loss: 0.7107
#  Client0 Train => Local Epoch: 4 	Acc: 76.806 	Loss: 0.6552
#  Client0 Test =>                   	Acc: 51.357 	Loss: 1.3595
#  Client1 Train => Local Epoch: 0 	Acc: 76.905 	Loss: 0.7261
#  Client1 Train => Local Epoch: 1 	Acc: 81.870 	Loss: 0.5667
#  Client1 Train => Local Epoch: 2 	Acc: 82.789 	Loss: 0.5222
#  Client1 Train => Local Epoch: 3 	Acc: 83.860 	Loss: 0.5027
#  Client1 Train => Local Epoch: 4 	Acc: 84.780 	Loss: 0.4697
#  Client1 Test =>                   	Acc: 42.208 	Loss: 1.7548
# ====================== SERVER V1==========================
#  Train: Round   5, Avg Accuracy 76.581 | Avg Loss 0.663
#  Test: Round   5, Avg Accuracy 51.178 | Avg Loss 1.420
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Forgetting : Round 5, mean_forgetting : -0.336
# ==========================================================
#  Client6 Train => Local Epoch: 0 	Acc: 68.848 	Loss: 0.8894
#  Client6 Train => Local Epoch: 1 	Acc: 73.613 	Loss: 0.7456
#  Client6 Train => Local Epoch: 2 	Acc: 74.638 	Loss: 0.7205
#  Client6 Train => Local Epoch: 3 	Acc: 75.536 	Loss: 0.6809
#  Client6 Train => Local Epoch: 4 	Acc: 76.882 	Loss: 0.6571
#  Client6 Test =>                   	Acc: 56.903 	Loss: 1.2092
#  Client0 Train => Local Epoch: 0 	Acc: 69.697 	Loss: 0.8462
#  Client0 Train => Local Epoch: 1 	Acc: 74.916 	Loss: 0.7419
#  Client0 Train => Local Epoch: 2 	Acc: 76.457 	Loss: 0.6758
#  Client0 Train => Local Epoch: 3 	Acc: 77.992 	Loss: 0.6485
#  Client0 Train => Local Epoch: 4 	Acc: 78.581 	Loss: 0.6112
#  Client0 Test =>                   	Acc: 57.297 	Loss: 1.1494
#  Client3 Train => Local Epoch: 0 	Acc: 65.946 	Loss: 1.0448
#  Client3 Train => Local Epoch: 1 	Acc: 70.380 	Loss: 0.8492
#  Client3 Train => Local Epoch: 2 	Acc: 72.498 	Loss: 0.7895
#  Client3 Train => Local Epoch: 3 	Acc: 73.276 	Loss: 0.7513
#  Client3 Train => Local Epoch: 4 	Acc: 75.012 	Loss: 0.7198
#  Client3 Test =>                   	Acc: 55.580 	Loss: 1.3034
#  Client4 Train => Local Epoch: 0 	Acc: 70.012 	Loss: 0.8754
#  Client4 Train => Local Epoch: 1 	Acc: 75.548 	Loss: 0.7301
#  Client4 Train => Local Epoch: 2 	Acc: 76.727 	Loss: 0.6945
#  Client4 Train => Local Epoch: 3 	Acc: 78.318 	Loss: 0.6262
#  Client4 Train => Local Epoch: 4 	Acc: 80.404 	Loss: 0.5880
#  Client4 Test =>                   	Acc: 53.452 	Loss: 1.4740
#  Client5 Train => Local Epoch: 0 	Acc: 67.347 	Loss: 0.9621
#  Client5 Train => Local Epoch: 1 	Acc: 70.242 	Loss: 0.8499
#  Client5 Train => Local Epoch: 2 	Acc: 72.517 	Loss: 0.7841
#  Client5 Train => Local Epoch: 3 	Acc: 73.330 	Loss: 0.7484
#  Client5 Train => Local Epoch: 4 	Acc: 74.467 	Loss: 0.7283
#  Client5 Test =>                   	Acc: 61.709 	Loss: 1.0957
#  Client7 Train => Local Epoch: 0 	Acc: 73.782 	Loss: 0.7972
#  Client7 Train => Local Epoch: 1 	Acc: 78.444 	Loss: 0.6312
#  Client7 Train => Local Epoch: 2 	Acc: 80.139 	Loss: 0.5805
#  Client7 Train => Local Epoch: 3 	Acc: 80.659 	Loss: 0.5557
#  Client7 Train => Local Epoch: 4 	Acc: 81.348 	Loss: 0.5340
#  Client7 Test =>                   	Acc: 49.667 	Loss: 1.5639
#  Client9 Train => Local Epoch: 0 	Acc: 69.637 	Loss: 0.8607
#  Client9 Train => Local Epoch: 1 	Acc: 70.752 	Loss: 0.8041
#  Client9 Train => Local Epoch: 2 	Acc: 71.861 	Loss: 0.7912
#  Client9 Train => Local Epoch: 3 	Acc: 70.906 	Loss: 0.8122
#  Client9 Train => Local Epoch: 4 	Acc: 73.860 	Loss: 0.7172
#  Client9 Test =>                   	Acc: 60.476 	Loss: 1.1817
#  Client1 Train => Local Epoch: 0 	Acc: 75.595 	Loss: 0.8271
#  Client1 Train => Local Epoch: 1 	Acc: 83.481 	Loss: 0.5337
#  Client1 Train => Local Epoch: 2 	Acc: 84.463 	Loss: 0.4801
#  Client1 Train => Local Epoch: 3 	Acc: 85.385 	Loss: 0.4577
#  Client1 Train => Local Epoch: 4 	Acc: 86.671 	Loss: 0.4170
#  Client1 Test =>                   	Acc: 48.387 	Loss: 1.4877
#  Client8 Train => Local Epoch: 0 	Acc: 68.927 	Loss: 0.8829
#  Client8 Train => Local Epoch: 1 	Acc: 73.666 	Loss: 0.7161
#  Client8 Train => Local Epoch: 2 	Acc: 75.820 	Loss: 0.6584
#  Client8 Train => Local Epoch: 3 	Acc: 75.695 	Loss: 0.6304
#  Client8 Train => Local Epoch: 4 	Acc: 77.275 	Loss: 0.5960
#  Client8 Test =>                   	Acc: 54.543 	Loss: 1.3780
#  Client2 Train => Local Epoch: 0 	Acc: 71.432 	Loss: 0.8464
#  Client2 Train => Local Epoch: 1 	Acc: 77.014 	Loss: 0.6590
#  Client2 Train => Local Epoch: 2 	Acc: 78.167 	Loss: 0.6188
#  Client2 Train => Local Epoch: 3 	Acc: 80.380 	Loss: 0.5670
#  Client2 Train => Local Epoch: 4 	Acc: 80.285 	Loss: 0.5523
#  Client2 Test =>                   	Acc: 62.645 	Loss: 1.0361
# ====================== SERVER V1==========================
#  Train: Round   6, Avg Accuracy 78.479 | Avg Loss 0.612
#  Test: Round   6, Avg Accuracy 56.066 | Avg Loss 1.288
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Forgetting : Round 6, mean_forgetting : -0.931
# ==========================================================
#  Client4 Train => Local Epoch: 0 	Acc: 74.827 	Loss: 0.7682
#  Client4 Train => Local Epoch: 1 	Acc: 77.984 	Loss: 0.6452
#  Client4 Train => Local Epoch: 2 	Acc: 79.992 	Loss: 0.6081
#  Client4 Train => Local Epoch: 3 	Acc: 80.877 	Loss: 0.5711
#  Client4 Train => Local Epoch: 4 	Acc: 81.733 	Loss: 0.5403
#  Client4 Test =>                   	Acc: 56.802 	Loss: 1.3221
#  Client1 Train => Local Epoch: 0 	Acc: 81.867 	Loss: 0.5585
#  Client1 Train => Local Epoch: 1 	Acc: 85.192 	Loss: 0.4517
#  Client1 Train => Local Epoch: 2 	Acc: 85.884 	Loss: 0.4225
#  Client1 Train => Local Epoch: 3 	Acc: 86.836 	Loss: 0.3996
#  Client1 Train => Local Epoch: 4 	Acc: 87.891 	Loss: 0.3669
#  Client1 Test =>                   	Acc: 51.401 	Loss: 1.6617
#  Client2 Train => Local Epoch: 0 	Acc: 75.763 	Loss: 0.7022
#  Client2 Train => Local Epoch: 1 	Acc: 78.770 	Loss: 0.6078
#  Client2 Train => Local Epoch: 2 	Acc: 79.921 	Loss: 0.5605
#  Client2 Train => Local Epoch: 3 	Acc: 81.812 	Loss: 0.5227
#  Client2 Train => Local Epoch: 4 	Acc: 83.035 	Loss: 0.4831
#  Client2 Test =>                   	Acc: 58.304 	Loss: 1.1583
#  Client9 Train => Local Epoch: 0 	Acc: 71.343 	Loss: 0.7915
#  Client9 Train => Local Epoch: 1 	Acc: 74.087 	Loss: 0.7157
#  Client9 Train => Local Epoch: 2 	Acc: 76.500 	Loss: 0.6566
#  Client9 Train => Local Epoch: 3 	Acc: 76.428 	Loss: 0.6474
#  Client9 Train => Local Epoch: 4 	Acc: 73.480 	Loss: 0.7475
#  Client9 Test =>                   	Acc: 66.487 	Loss: 0.9999
#  Client5 Train => Local Epoch: 0 	Acc: 71.362 	Loss: 0.8207
#  Client5 Train => Local Epoch: 1 	Acc: 73.642 	Loss: 0.7436
#  Client5 Train => Local Epoch: 2 	Acc: 74.051 	Loss: 0.7342
#  Client5 Train => Local Epoch: 3 	Acc: 75.638 	Loss: 0.6955
#  Client5 Train => Local Epoch: 4 	Acc: 76.853 	Loss: 0.6526
#  Client5 Test =>                   	Acc: 64.032 	Loss: 1.0236
#  Client7 Train => Local Epoch: 0 	Acc: 73.934 	Loss: 0.8100
#  Client7 Train => Local Epoch: 1 	Acc: 80.010 	Loss: 0.5883
#  Client7 Train => Local Epoch: 2 	Acc: 81.627 	Loss: 0.5436
#  Client7 Train => Local Epoch: 3 	Acc: 82.746 	Loss: 0.5175
#  Client7 Train => Local Epoch: 4 	Acc: 84.050 	Loss: 0.4760
#  Client7 Test =>                   	Acc: 55.297 	Loss: 1.3267
#  Client6 Train => Local Epoch: 0 	Acc: 70.573 	Loss: 0.8658
#  Client6 Train => Local Epoch: 1 	Acc: 75.104 	Loss: 0.6993
#  Client6 Train => Local Epoch: 2 	Acc: 76.568 	Loss: 0.6680
#  Client6 Train => Local Epoch: 3 	Acc: 77.873 	Loss: 0.6292
#  Client6 Train => Local Epoch: 4 	Acc: 78.483 	Loss: 0.5995
#  Client6 Test =>                   	Acc: 63.712 	Loss: 1.0217
#  Client3 Train => Local Epoch: 0 	Acc: 68.394 	Loss: 0.9415
#  Client3 Train => Local Epoch: 1 	Acc: 73.090 	Loss: 0.7709
#  Client3 Train => Local Epoch: 2 	Acc: 74.330 	Loss: 0.7132
#  Client3 Train => Local Epoch: 3 	Acc: 75.785 	Loss: 0.6896
#  Client3 Train => Local Epoch: 4 	Acc: 76.942 	Loss: 0.6683
#  Client3 Test =>                   	Acc: 58.937 	Loss: 1.2231
#  Client0 Train => Local Epoch: 0 	Acc: 70.414 	Loss: 0.8784
#  Client0 Train => Local Epoch: 1 	Acc: 75.819 	Loss: 0.6945
#  Client0 Train => Local Epoch: 2 	Acc: 78.020 	Loss: 0.6514
#  Client0 Train => Local Epoch: 3 	Acc: 79.731 	Loss: 0.5933
#  Client0 Train => Local Epoch: 4 	Acc: 81.074 	Loss: 0.5657
#  Client0 Test =>                   	Acc: 62.978 	Loss: 1.0318
#  Client8 Train => Local Epoch: 0 	Acc: 70.632 	Loss: 0.8337
#  Client8 Train => Local Epoch: 1 	Acc: 74.229 	Loss: 0.6833
#  Client8 Train => Local Epoch: 2 	Acc: 75.898 	Loss: 0.6299
#  Client8 Train => Local Epoch: 3 	Acc: 78.385 	Loss: 0.5791
#  Client8 Train => Local Epoch: 4 	Acc: 79.019 	Loss: 0.5567
#  Client8 Test =>                   	Acc: 58.308 	Loss: 1.1883
# ====================== SERVER V1==========================
#  Train: Round   7, Avg Accuracy 80.256 | Avg Loss 0.566
#  Test: Round   7, Avg Accuracy 59.626 | Avg Loss 1.196
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Forgetting : Round 7, mean_forgetting : -0.698
# ==========================================================
#  Client8 Train => Local Epoch: 0 	Acc: 76.755 	Loss: 0.6291
#  Client8 Train => Local Epoch: 1 	Acc: 78.321 	Loss: 0.5838
#  Client8 Train => Local Epoch: 2 	Acc: 78.265 	Loss: 0.5636
#  Client8 Train => Local Epoch: 3 	Acc: 80.096 	Loss: 0.5225
#  Client8 Train => Local Epoch: 4 	Acc: 81.651 	Loss: 0.5005
#  Client8 Test =>                   	Acc: 55.189 	Loss: 1.3790
#  Client9 Train => Local Epoch: 0 	Acc: 74.903 	Loss: 0.7131
#  Client9 Train => Local Epoch: 1 	Acc: 76.157 	Loss: 0.6524
#  Client9 Train => Local Epoch: 2 	Acc: 77.437 	Loss: 0.6331
#  Client9 Train => Local Epoch: 3 	Acc: 77.051 	Loss: 0.6400
#  Client9 Train => Local Epoch: 4 	Acc: 78.932 	Loss: 0.5804
#  Client9 Test =>                   	Acc: 63.551 	Loss: 1.1353
#  Client5 Train => Local Epoch: 0 	Acc: 71.385 	Loss: 0.8184
#  Client5 Train => Local Epoch: 1 	Acc: 73.728 	Loss: 0.7315
#  Client5 Train => Local Epoch: 2 	Acc: 75.452 	Loss: 0.6854
#  Client5 Train => Local Epoch: 3 	Acc: 76.545 	Loss: 0.6595
#  Client5 Train => Local Epoch: 4 	Acc: 77.999 	Loss: 0.6100
#  Client5 Test =>                   	Acc: 64.797 	Loss: 1.0403
#  Client6 Train => Local Epoch: 0 	Acc: 73.950 	Loss: 0.7405
#  Client6 Train => Local Epoch: 1 	Acc: 76.978 	Loss: 0.6564
#  Client6 Train => Local Epoch: 2 	Acc: 78.677 	Loss: 0.6042
#  Client6 Train => Local Epoch: 3 	Acc: 78.839 	Loss: 0.5968
#  Client6 Train => Local Epoch: 4 	Acc: 80.450 	Loss: 0.5570
#  Client6 Test =>                   	Acc: 64.504 	Loss: 1.0316
#  Client7 Train => Local Epoch: 0 	Acc: 76.595 	Loss: 0.7345
#  Client7 Train => Local Epoch: 1 	Acc: 81.235 	Loss: 0.5672
#  Client7 Train => Local Epoch: 2 	Acc: 83.406 	Loss: 0.4946
#  Client7 Train => Local Epoch: 3 	Acc: 83.363 	Loss: 0.4763
#  Client7 Train => Local Epoch: 4 	Acc: 83.608 	Loss: 0.4628
#  Client7 Test =>                   	Acc: 59.971 	Loss: 1.1928
#  Client4 Train => Local Epoch: 0 	Acc: 73.360 	Loss: 0.8302
#  Client4 Train => Local Epoch: 1 	Acc: 79.099 	Loss: 0.6204
#  Client4 Train => Local Epoch: 2 	Acc: 81.364 	Loss: 0.5558
#  Client4 Train => Local Epoch: 3 	Acc: 82.725 	Loss: 0.5194
#  Client4 Train => Local Epoch: 4 	Acc: 83.703 	Loss: 0.4886
#  Client4 Test =>                   	Acc: 61.981 	Loss: 1.1546
#  Client1 Train => Local Epoch: 0 	Acc: 80.996 	Loss: 0.5744
#  Client1 Train => Local Epoch: 1 	Acc: 84.815 	Loss: 0.4395
#  Client1 Train => Local Epoch: 2 	Acc: 86.826 	Loss: 0.3956
#  Client1 Train => Local Epoch: 3 	Acc: 87.561 	Loss: 0.3706
#  Client1 Train => Local Epoch: 4 	Acc: 89.255 	Loss: 0.3196
#  Client1 Test =>                   	Acc: 54.172 	Loss: 1.4523
#  Client3 Train => Local Epoch: 0 	Acc: 70.028 	Loss: 0.9075
#  Client3 Train => Local Epoch: 1 	Acc: 74.754 	Loss: 0.7435
#  Client3 Train => Local Epoch: 2 	Acc: 76.302 	Loss: 0.6855
#  Client3 Train => Local Epoch: 3 	Acc: 77.966 	Loss: 0.6380
#  Client3 Train => Local Epoch: 4 	Acc: 78.591 	Loss: 0.6193
#  Client3 Test =>                   	Acc: 60.018 	Loss: 1.1714
#  Client2 Train => Local Epoch: 0 	Acc: 75.701 	Loss: 0.7327
#  Client2 Train => Local Epoch: 1 	Acc: 79.809 	Loss: 0.5773
#  Client2 Train => Local Epoch: 2 	Acc: 81.938 	Loss: 0.5219
#  Client2 Train => Local Epoch: 3 	Acc: 83.490 	Loss: 0.4782
#  Client2 Train => Local Epoch: 4 	Acc: 83.709 	Loss: 0.4496
#  Client2 Test =>                   	Acc: 66.144 	Loss: 0.9385
#  Client0 Train => Local Epoch: 0 	Acc: 74.121 	Loss: 0.7426
#  Client0 Train => Local Epoch: 1 	Acc: 78.766 	Loss: 0.6227
#  Client0 Train => Local Epoch: 2 	Acc: 80.669 	Loss: 0.5659
#  Client0 Train => Local Epoch: 3 	Acc: 81.635 	Loss: 0.5345
#  Client0 Train => Local Epoch: 4 	Acc: 82.906 	Loss: 0.4987
#  Client0 Test =>                   	Acc: 65.820 	Loss: 0.9413
# ====================== SERVER V1==========================
#  Train: Round   8, Avg Accuracy 82.080 | Avg Loss 0.509
#  Test: Round   8, Avg Accuracy 61.615 | Avg Loss 1.144
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Forgetting : Round 8, mean_forgetting : -0.844
# ==========================================================
#  Client2 Train => Local Epoch: 0 	Acc: 80.659 	Loss: 0.5723
#  Client2 Train => Local Epoch: 1 	Acc: 82.451 	Loss: 0.5051
#  Client2 Train => Local Epoch: 2 	Acc: 84.104 	Loss: 0.4564
#  Client2 Train => Local Epoch: 3 	Acc: 84.771 	Loss: 0.4218
#  Client2 Train => Local Epoch: 4 	Acc: 85.527 	Loss: 0.4099
#  Client2 Test =>                   	Acc: 66.743 	Loss: 0.9168
#  Client5 Train => Local Epoch: 0 	Acc: 72.898 	Loss: 0.7629
#  Client5 Train => Local Epoch: 1 	Acc: 75.632 	Loss: 0.6696
#  Client5 Train => Local Epoch: 2 	Acc: 77.919 	Loss: 0.6222
#  Client5 Train => Local Epoch: 3 	Acc: 79.255 	Loss: 0.5816
#  Client5 Train => Local Epoch: 4 	Acc: 79.594 	Loss: 0.5709
#  Client5 Test =>                   	Acc: 70.966 	Loss: 0.8842
#  Client1 Train => Local Epoch: 0 	Acc: 80.532 	Loss: 0.6059
#  Client1 Train => Local Epoch: 1 	Acc: 86.060 	Loss: 0.4175
#  Client1 Train => Local Epoch: 2 	Acc: 87.788 	Loss: 0.3656
#  Client1 Train => Local Epoch: 3 	Acc: 88.293 	Loss: 0.3426
#  Client1 Train => Local Epoch: 4 	Acc: 90.105 	Loss: 0.3004
#  Client1 Test =>                   	Acc: 61.059 	Loss: 1.2100
#  Client6 Train => Local Epoch: 0 	Acc: 73.650 	Loss: 0.7702
#  Client6 Train => Local Epoch: 1 	Acc: 77.844 	Loss: 0.6274
#  Client6 Train => Local Epoch: 2 	Acc: 79.620 	Loss: 0.5853
#  Client6 Train => Local Epoch: 3 	Acc: 80.644 	Loss: 0.5490
#  Client6 Train => Local Epoch: 4 	Acc: 81.763 	Loss: 0.5195
#  Client6 Test =>                   	Acc: 67.437 	Loss: 0.9003
#  Client4 Train => Local Epoch: 0 	Acc: 76.515 	Loss: 0.6970
#  Client4 Train => Local Epoch: 1 	Acc: 81.512 	Loss: 0.5735
#  Client4 Train => Local Epoch: 2 	Acc: 82.301 	Loss: 0.5340
#  Client4 Train => Local Epoch: 3 	Acc: 84.076 	Loss: 0.4770
#  Client4 Train => Local Epoch: 4 	Acc: 85.356 	Loss: 0.4351
#  Client4 Test =>                   	Acc: 65.598 	Loss: 1.0136
#  Client0 Train => Local Epoch: 0 	Acc: 77.566 	Loss: 0.6338
#  Client0 Train => Local Epoch: 1 	Acc: 80.314 	Loss: 0.5592
#  Client0 Train => Local Epoch: 2 	Acc: 83.360 	Loss: 0.5096
#  Client0 Train => Local Epoch: 3 	Acc: 83.730 	Loss: 0.4776
#  Client0 Train => Local Epoch: 4 	Acc: 85.761 	Loss: 0.4282
#  Client0 Test =>                   	Acc: 66.517 	Loss: 0.8971
#  Client3 Train => Local Epoch: 0 	Acc: 71.333 	Loss: 0.8864
#  Client3 Train => Local Epoch: 1 	Acc: 76.246 	Loss: 0.6906
#  Client3 Train => Local Epoch: 2 	Acc: 76.959 	Loss: 0.6528
#  Client3 Train => Local Epoch: 3 	Acc: 78.252 	Loss: 0.6203
#  Client3 Train => Local Epoch: 4 	Acc: 80.233 	Loss: 0.5733
#  Client3 Test =>                   	Acc: 62.500 	Loss: 1.1540
#  Client8 Train => Local Epoch: 0 	Acc: 72.939 	Loss: 0.8044
#  Client8 Train => Local Epoch: 1 	Acc: 77.727 	Loss: 0.6211
#  Client8 Train => Local Epoch: 2 	Acc: 80.159 	Loss: 0.5398
#  Client8 Train => Local Epoch: 3 	Acc: 81.024 	Loss: 0.5099
#  Client8 Train => Local Epoch: 4 	Acc: 81.529 	Loss: 0.4730
#  Client8 Test =>                   	Acc: 64.160 	Loss: 1.0500
#  Client9 Train => Local Epoch: 0 	Acc: 76.920 	Loss: 0.6688
#  Client9 Train => Local Epoch: 1 	Acc: 78.052 	Loss: 0.6055
#  Client9 Train => Local Epoch: 2 	Acc: 78.800 	Loss: 0.5716
#  Client9 Train => Local Epoch: 3 	Acc: 76.611 	Loss: 0.6533
#  Client9 Train => Local Epoch: 4 	Acc: 78.110 	Loss: 0.6121
#  Client9 Test =>                   	Acc: 70.555 	Loss: 0.9054
#  Client7 Train => Local Epoch: 0 	Acc: 77.544 	Loss: 0.6924
#  Client7 Train => Local Epoch: 1 	Acc: 82.244 	Loss: 0.5111
#  Client7 Train => Local Epoch: 2 	Acc: 83.679 	Loss: 0.4706
#  Client7 Train => Local Epoch: 3 	Acc: 84.162 	Loss: 0.4484
#  Client7 Train => Local Epoch: 4 	Acc: 85.972 	Loss: 0.4110
#  Client7 Test =>                   	Acc: 61.362 	Loss: 1.1735
# ====================== SERVER V1==========================
#  Train: Round   9, Avg Accuracy 83.395 | Avg Loss 0.473
#  Test: Round   9, Avg Accuracy 65.690 | Avg Loss 1.010
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Forgetting : Round 9, mean_forgetting : -0.400
# ==========================================================
#  Client3 Train => Local Epoch: 0 	Acc: 72.182 	Loss: 0.7755
#  Client3 Train => Local Epoch: 1 	Acc: 77.558 	Loss: 0.6572
#  Client3 Train => Local Epoch: 2 	Acc: 79.044 	Loss: 0.6034
#  Client3 Train => Local Epoch: 3 	Acc: 80.483 	Loss: 0.5676
#  Client3 Train => Local Epoch: 4 	Acc: 81.168 	Loss: 0.5380
#  Client3 Test =>                   	Acc: 60.820 	Loss: 1.1675
#  Client1 Train => Local Epoch: 0 	Acc: 78.039 	Loss: 0.7272
#  Client1 Train => Local Epoch: 1 	Acc: 86.288 	Loss: 0.4421
#  Client1 Train => Local Epoch: 2 	Acc: 88.233 	Loss: 0.3635
#  Client1 Train => Local Epoch: 3 	Acc: 89.695 	Loss: 0.3166
#  Client1 Train => Local Epoch: 4 	Acc: 90.465 	Loss: 0.2873
#  Client1 Test =>                   	Acc: 60.544 	Loss: 1.1930
#  Client7 Train => Local Epoch: 0 	Acc: 79.994 	Loss: 0.6074
#  Client7 Train => Local Epoch: 1 	Acc: 83.837 	Loss: 0.4746
#  Client7 Train => Local Epoch: 2 	Acc: 84.686 	Loss: 0.4319
#  Client7 Train => Local Epoch: 3 	Acc: 86.699 	Loss: 0.3987
#  Client7 Train => Local Epoch: 4 	Acc: 87.681 	Loss: 0.3669
#  Client7 Test =>                   	Acc: 60.055 	Loss: 1.2635
#  Client9 Train => Local Epoch: 0 	Acc: 75.984 	Loss: 0.6978
#  Client9 Train => Local Epoch: 1 	Acc: 78.079 	Loss: 0.6160
#  Client9 Train => Local Epoch: 2 	Acc: 80.401 	Loss: 0.5381
#  Client9 Train => Local Epoch: 3 	Acc: 80.483 	Loss: 0.5555
#  Client9 Train => Local Epoch: 4 	Acc: 79.733 	Loss: 0.5659
#  Client9 Test =>                   	Acc: 72.138 	Loss: 0.8367
#  Client4 Train => Local Epoch: 0 	Acc: 77.922 	Loss: 0.6868
#  Client4 Train => Local Epoch: 1 	Acc: 81.587 	Loss: 0.5397
#  Client4 Train => Local Epoch: 2 	Acc: 82.972 	Loss: 0.4962
#  Client4 Train => Local Epoch: 3 	Acc: 86.672 	Loss: 0.4158
#  Client4 Train => Local Epoch: 4 	Acc: 86.730 	Loss: 0.3996
#  Client4 Test =>                   	Acc: 67.090 	Loss: 0.9737
#  Client5 Train => Local Epoch: 0 	Acc: 74.940 	Loss: 0.7119
#  Client5 Train => Local Epoch: 1 	Acc: 78.330 	Loss: 0.6190
#  Client5 Train => Local Epoch: 2 	Acc: 79.669 	Loss: 0.5696
#  Client5 Train => Local Epoch: 3 	Acc: 81.746 	Loss: 0.5237
#  Client5 Train => Local Epoch: 4 	Acc: 82.409 	Loss: 0.5073
#  Client5 Test =>                   	Acc: 68.545 	Loss: 0.8679
#  Client2 Train => Local Epoch: 0 	Acc: 80.492 	Loss: 0.5731
#  Client2 Train => Local Epoch: 1 	Acc: 83.642 	Loss: 0.4605
#  Client2 Train => Local Epoch: 2 	Acc: 84.767 	Loss: 0.4370
#  Client2 Train => Local Epoch: 3 	Acc: 86.240 	Loss: 0.3964
#  Client2 Train => Local Epoch: 4 	Acc: 86.695 	Loss: 0.3721
#  Client2 Test =>                   	Acc: 70.063 	Loss: 0.8054
#  Client0 Train => Local Epoch: 0 	Acc: 78.354 	Loss: 0.6091
#  Client0 Train => Local Epoch: 1 	Acc: 81.209 	Loss: 0.5466
#  Client0 Train => Local Epoch: 2 	Acc: 82.728 	Loss: 0.4952
#  Client0 Train => Local Epoch: 3 	Acc: 85.583 	Loss: 0.4397
#  Client0 Train => Local Epoch: 4 	Acc: 85.718 	Loss: 0.4174
#  Client0 Test =>                   	Acc: 68.588 	Loss: 0.8320
#  Client6 Train => Local Epoch: 0 	Acc: 76.268 	Loss: 0.6871
# ...
#  Client4 Train => Local Epoch: 1 	Acc: 99.219 	Loss: 0.0300
#  Client4 Train => Local Epoch: 2 	Acc: 99.544 	Loss: 0.0221
#  Client4 Train => Local Epoch: 3 	Acc: 99.665 	Loss: 0.0166
#  Client4 Train => Local Epoch: 4 	Acc: 99.707 	Loss: 0.0122
#  Client4 Test =>                   	Acc: 90.500 	Loss: 0.3274
#  Client8 Train => Local Epoch: 0 	Acc: 97.303 	Loss: 0.0900
#  Client8 Train => Local Epoch: 1 	Acc: 98.798 	Loss: 0.0407
#  Client8 Train => Local Epoch: 2 	Acc: 98.955 	Loss: 0.0365
#  Client8 Train => Local Epoch: 3 	Acc: 99.282 	Loss: 0.0283
#  Client8 Train => Local Epoch: 4 	Acc: 99.189 	Loss: 0.0243
#  Client8 Test =>                   	Acc: 88.261 	Loss: 0.4499
#  Client6 Train => Local Epoch: 0 	Acc: 97.366 	Loss: 0.0784
#  Client6 Train => Local Epoch: 1 	Acc: 98.617 	Loss: 0.0416
#  Client6 Train => Local Epoch: 2 	Acc: 99.249 	Loss: 0.0280
#  Client6 Train => Local Epoch: 3 	Acc: 99.110 	Loss: 0.0310
#  Client6 Train => Local Epoch: 4 	Acc: 99.365 	Loss: 0.0230
#  Client6 Test =>                   	Acc: 87.843 	Loss: 0.4641
#  Client0 Train => Local Epoch: 0 	Acc: 98.267 	Loss: 0.0537
#  Client0 Train => Local Epoch: 1 	Acc: 99.396 	Loss: 0.0273
#  Client0 Train => Local Epoch: 2 	Acc: 99.645 	Loss: 0.0181
#  Client0 Train => Local Epoch: 3 	Acc: 99.688 	Loss: 0.0163
#  Client0 Train => Local Epoch: 4 	Acc: 99.751 	Loss: 0.0124
#  Client0 Test =>                   	Acc: 89.652 	Loss: 0.3692
#  Client3 Train => Local Epoch: 0 	Acc: 95.843 	Loss: 0.1215
#  Client3 Train => Local Epoch: 1 	Acc: 97.577 	Loss: 0.0751
#  Client3 Train => Local Epoch: 2 	Acc: 97.835 	Loss: 0.0637
#  Client3 Train => Local Epoch: 3 	Acc: 98.516 	Loss: 0.0484
#  Client3 Train => Local Epoch: 4 	Acc: 98.976 	Loss: 0.0312
#  Client3 Test =>                   	Acc: 88.995 	Loss: 0.3555
#  Client5 Train => Local Epoch: 0 	Acc: 98.211 	Loss: 0.0546
#  Client5 Train => Local Epoch: 1 	Acc: 98.869 	Loss: 0.0386
#  Client5 Train => Local Epoch: 2 	Acc: 99.383 	Loss: 0.0254
#  Client5 Train => Local Epoch: 3 	Acc: 99.589 	Loss: 0.0201
#  Client5 Train => Local Epoch: 4 	Acc: 99.794 	Loss: 0.0130
#  Client5 Test =>                   	Acc: 89.221 	Loss: 0.4019
#  Client1 Train => Local Epoch: 0 	Acc: 95.305 	Loss: 0.1333
#  Client1 Train => Local Epoch: 1 	Acc: 98.359 	Loss: 0.0474
#  Client1 Train => Local Epoch: 2 	Acc: 99.544 	Loss: 0.0233
#  Client1 Train => Local Epoch: 3 	Acc: 99.674 	Loss: 0.0153
#  Client1 Train => Local Epoch: 4 	Acc: 99.674 	Loss: 0.0134
#  Client1 Test =>                   	Acc: 88.773 	Loss: 0.4142
#  Client7 Train => Local Epoch: 0 	Acc: 96.221 	Loss: 0.1129
#  Client7 Train => Local Epoch: 1 	Acc: 98.459 	Loss: 0.0472
#  Client7 Train => Local Epoch: 2 	Acc: 99.201 	Loss: 0.0253
#  Client7 Train => Local Epoch: 3 	Acc: 99.348 	Loss: 0.0215
#  Client7 Train => Local Epoch: 4 	Acc: 99.627 	Loss: 0.0140
#  Client7 Test =>                   	Acc: 90.423 	Loss: 0.3606
#  Client2 Train => Local Epoch: 0 	Acc: 98.206 	Loss: 0.0579
#  Client2 Train => Local Epoch: 1 	Acc: 99.369 	Loss: 0.0232
#  Client2 Train => Local Epoch: 2 	Acc: 99.618 	Loss: 0.0175
#  Client2 Train => Local Epoch: 3 	Acc: 99.738 	Loss: 0.0131
#  Client2 Train => Local Epoch: 4 	Acc: 99.835 	Loss: 0.0091
#  Client2 Test =>                   	Acc: 90.305 	Loss: 0.3720
# ====================== SERVER V1==========================
#  Train: Round  96, Avg Accuracy 98.851 | Avg Loss 0.036
#  Test: Round  96, Avg Accuracy 89.424 | Avg Loss 0.382
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Forgetting : Round 96, mean_forgetting : -0.237
# ==========================================================
#  Client9 Train => Local Epoch: 0 	Acc: 98.035 	Loss: 0.0628
#  Client9 Train => Local Epoch: 1 	Acc: 99.110 	Loss: 0.0307
#  Client9 Train => Local Epoch: 2 	Acc: 94.751 	Loss: 0.1617
#  Client9 Train => Local Epoch: 3 	Acc: 89.919 	Loss: 0.2972
#  Client9 Train => Local Epoch: 4 	Acc: 91.240 	Loss: 0.2648
#  Client9 Test =>                   	Acc: 89.699 	Loss: 0.3036
#  Client1 Train => Local Epoch: 0 	Acc: 96.438 	Loss: 0.1062
#  Client1 Train => Local Epoch: 1 	Acc: 98.652 	Loss: 0.0395
#  Client1 Train => Local Epoch: 2 	Acc: 99.674 	Loss: 0.0186
#  Client1 Train => Local Epoch: 3 	Acc: 99.740 	Loss: 0.0134
#  Client1 Train => Local Epoch: 4 	Acc: 99.837 	Loss: 0.0097
#  Client1 Test =>                   	Acc: 88.281 	Loss: 0.4225
#  Client7 Train => Local Epoch: 0 	Acc: 96.197 	Loss: 0.1132
#  Client7 Train => Local Epoch: 1 	Acc: 98.880 	Loss: 0.0356
#  Client7 Train => Local Epoch: 2 	Acc: 99.354 	Loss: 0.0250
#  Client7 Train => Local Epoch: 3 	Acc: 99.574 	Loss: 0.0174
#  Client7 Train => Local Epoch: 4 	Acc: 99.692 	Loss: 0.0136
#  Client7 Test =>                   	Acc: 89.992 	Loss: 0.3663
#  Client6 Train => Local Epoch: 0 	Acc: 97.260 	Loss: 0.0757
#  Client6 Train => Local Epoch: 1 	Acc: 98.467 	Loss: 0.0469
#  Client6 Train => Local Epoch: 2 	Acc: 98.989 	Loss: 0.0337
#  Client6 Train => Local Epoch: 3 	Acc: 99.320 	Loss: 0.0273
#  Client6 Train => Local Epoch: 4 	Acc: 99.354 	Loss: 0.0223
#  Client6 Test =>                   	Acc: 87.887 	Loss: 0.4396
#  Client0 Train => Local Epoch: 0 	Acc: 98.310 	Loss: 0.0523
#  Client0 Train => Local Epoch: 1 	Acc: 99.453 	Loss: 0.0250
#  Client0 Train => Local Epoch: 2 	Acc: 99.631 	Loss: 0.0191
#  Client0 Train => Local Epoch: 3 	Acc: 99.666 	Loss: 0.0169
#  Client0 Train => Local Epoch: 4 	Acc: 99.822 	Loss: 0.0114
#  Client0 Test =>                   	Acc: 89.817 	Loss: 0.3473
#  Client2 Train => Local Epoch: 0 	Acc: 98.038 	Loss: 0.0584
#  Client2 Train => Local Epoch: 1 	Acc: 99.159 	Loss: 0.0274
#  Client2 Train => Local Epoch: 2 	Acc: 99.558 	Loss: 0.0194
#  Client2 Train => Local Epoch: 3 	Acc: 99.693 	Loss: 0.0143
#  Client2 Train => Local Epoch: 4 	Acc: 99.760 	Loss: 0.0118
#  Client2 Test =>                   	Acc: 90.218 	Loss: 0.3360
#  Client8 Train => Local Epoch: 0 	Acc: 96.315 	Loss: 0.1072
#  Client8 Train => Local Epoch: 1 	Acc: 98.445 	Loss: 0.0419
#  Client8 Train => Local Epoch: 2 	Acc: 99.169 	Loss: 0.0300
#  Client8 Train => Local Epoch: 3 	Acc: 99.403 	Loss: 0.0234
#  Client8 Train => Local Epoch: 4 	Acc: 99.406 	Loss: 0.0226
#  Client8 Test =>                   	Acc: 87.901 	Loss: 0.4516
#  Client5 Train => Local Epoch: 0 	Acc: 98.231 	Loss: 0.0520
#  Client5 Train => Local Epoch: 1 	Acc: 99.279 	Loss: 0.0267
#  Client5 Train => Local Epoch: 2 	Acc: 99.444 	Loss: 0.0217
#  Client5 Train => Local Epoch: 3 	Acc: 99.527 	Loss: 0.0188
#  Client5 Train => Local Epoch: 4 	Acc: 99.773 	Loss: 0.0140
#  Client5 Test =>                   	Acc: 88.897 	Loss: 0.3768
#  Client3 Train => Local Epoch: 0 	Acc: 96.266 	Loss: 0.1131
#  Client3 Train => Local Epoch: 1 	Acc: 98.648 	Loss: 0.0409
#  Client3 Train => Local Epoch: 2 	Acc: 99.562 	Loss: 0.0228
#  Client3 Train => Local Epoch: 3 	Acc: 99.234 	Loss: 0.0298
#  Client3 Train => Local Epoch: 4 	Acc: 99.320 	Loss: 0.0214
#  Client3 Test =>                   	Acc: 90.039 	Loss: 0.3415
#  Client4 Train => Local Epoch: 0 	Acc: 97.571 	Loss: 0.0735
#  Client4 Train => Local Epoch: 1 	Acc: 98.818 	Loss: 0.0391
#  Client4 Train => Local Epoch: 2 	Acc: 99.534 	Loss: 0.0226
#  Client4 Train => Local Epoch: 3 	Acc: 99.837 	Loss: 0.0139
#  Client4 Train => Local Epoch: 4 	Acc: 99.892 	Loss: 0.0112
#  Client4 Test =>                   	Acc: 90.696 	Loss: 0.3134
# ====================== SERVER V1==========================
#  Train: Round  97, Avg Accuracy 98.810 | Avg Loss 0.040
#  Test: Round  97, Avg Accuracy 89.343 | Avg Loss 0.370
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Forgetting : Round 97, mean_forgetting : -0.222
# ==========================================================
#  Client8 Train => Local Epoch: 0 	Acc: 97.043 	Loss: 0.0803
#  Client8 Train => Local Epoch: 1 	Acc: 98.505 	Loss: 0.0421
#  Client8 Train => Local Epoch: 2 	Acc: 98.846 	Loss: 0.0365
#  Client8 Train => Local Epoch: 3 	Acc: 99.106 	Loss: 0.0318
#  Client8 Train => Local Epoch: 4 	Acc: 98.989 	Loss: 0.0307
#  Client8 Test =>                   	Acc: 87.618 	Loss: 0.4745
#  Client3 Train => Local Epoch: 0 	Acc: 97.250 	Loss: 0.0803
#  Client3 Train => Local Epoch: 1 	Acc: 98.859 	Loss: 0.0382
#  Client3 Train => Local Epoch: 2 	Acc: 99.125 	Loss: 0.0341
#  Client3 Train => Local Epoch: 3 	Acc: 99.266 	Loss: 0.0244
#  Client3 Train => Local Epoch: 4 	Acc: 99.500 	Loss: 0.0208
#  Client3 Test =>                   	Acc: 89.591 	Loss: 0.3720
#  Client9 Train => Local Epoch: 0 	Acc: 98.380 	Loss: 0.0562
#  Client9 Train => Local Epoch: 1 	Acc: 98.852 	Loss: 0.0415
#  Client9 Train => Local Epoch: 2 	Acc: 91.441 	Loss: 0.2714
#  Client9 Train => Local Epoch: 3 	Acc: 95.312 	Loss: 0.1315
#  Client9 Train => Local Epoch: 4 	Acc: 96.835 	Loss: 0.0856
#  Client9 Test =>                   	Acc: 90.305 	Loss: 0.2999
#  Client0 Train => Local Epoch: 0 	Acc: 97.742 	Loss: 0.0676
#  Client0 Train => Local Epoch: 1 	Acc: 99.077 	Loss: 0.0355
#  Client0 Train => Local Epoch: 2 	Acc: 99.396 	Loss: 0.0248
#  Client0 Train => Local Epoch: 3 	Acc: 99.631 	Loss: 0.0160
#  Client0 Train => Local Epoch: 4 	Acc: 99.858 	Loss: 0.0137
#  Client0 Test =>                   	Acc: 89.396 	Loss: 0.3785
#  Client5 Train => Local Epoch: 0 	Acc: 98.581 	Loss: 0.0484
#  Client5 Train => Local Epoch: 1 	Acc: 99.155 	Loss: 0.0308
#  Client5 Train => Local Epoch: 2 	Acc: 99.464 	Loss: 0.0223
#  Client5 Train => Local Epoch: 3 	Acc: 99.692 	Loss: 0.0175
#  Client5 Train => Local Epoch: 4 	Acc: 99.774 	Loss: 0.0131
#  Client5 Test =>                   	Acc: 88.419 	Loss: 0.4068
#  Client1 Train => Local Epoch: 0 	Acc: 95.443 	Loss: 0.1449
#  Client1 Train => Local Epoch: 1 	Acc: 98.066 	Loss: 0.0525
#  Client1 Train => Local Epoch: 2 	Acc: 99.382 	Loss: 0.0224
#  Client1 Train => Local Epoch: 3 	Acc: 99.647 	Loss: 0.0170
#  Client1 Train => Local Epoch: 4 	Acc: 99.740 	Loss: 0.0148
#  Client1 Test =>                   	Acc: 88.850 	Loss: 0.4256
#  Client7 Train => Local Epoch: 0 	Acc: 95.550 	Loss: 0.1375
#  Client7 Train => Local Epoch: 1 	Acc: 98.615 	Loss: 0.0467
#  Client7 Train => Local Epoch: 2 	Acc: 99.308 	Loss: 0.0251
#  Client7 Train => Local Epoch: 3 	Acc: 99.574 	Loss: 0.0187
#  Client7 Train => Local Epoch: 4 	Acc: 99.532 	Loss: 0.0142
#  Client7 Test =>                   	Acc: 90.083 	Loss: 0.3573
#  Client4 Train => Local Epoch: 0 	Acc: 97.812 	Loss: 0.0707
#  Client4 Train => Local Epoch: 1 	Acc: 98.743 	Loss: 0.0361
#  Client4 Train => Local Epoch: 2 	Acc: 99.382 	Loss: 0.0236
#  Client4 Train => Local Epoch: 3 	Acc: 99.609 	Loss: 0.0187
#  Client4 Train => Local Epoch: 4 	Acc: 99.772 	Loss: 0.0119
#  Client4 Test =>                   	Acc: 90.558 	Loss: 0.3187
#  Client6 Train => Local Epoch: 0 	Acc: 97.731 	Loss: 0.0634
#  Client6 Train => Local Epoch: 1 	Acc: 99.004 	Loss: 0.0342
#  Client6 Train => Local Epoch: 2 	Acc: 99.350 	Loss: 0.0237
#  Client6 Train => Local Epoch: 3 	Acc: 99.455 	Loss: 0.0221
#  Client6 Train => Local Epoch: 4 	Acc: 99.651 	Loss: 0.0155
#  Client6 Test =>                   	Acc: 87.722 	Loss: 0.4387
#  Client2 Train => Local Epoch: 0 	Acc: 98.341 	Loss: 0.0513
#  Client2 Train => Local Epoch: 1 	Acc: 99.287 	Loss: 0.0239
#  Client2 Train => Local Epoch: 2 	Acc: 99.657 	Loss: 0.0159
#  Client2 Train => Local Epoch: 3 	Acc: 99.747 	Loss: 0.0119
#  Client2 Train => Local Epoch: 4 	Acc: 99.760 	Loss: 0.0120
#  Client2 Test =>                   	Acc: 89.766 	Loss: 0.3416
# ====================== SERVER V1==========================
#  Train: Round  98, Avg Accuracy 99.341 | Avg Loss 0.023
#  Test: Round  98, Avg Accuracy 89.231 | Avg Loss 0.381
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Forgetting : Round 98, mean_forgetting : -0.221
# ==========================================================
#  Client8 Train => Local Epoch: 0 	Acc: 97.393 	Loss: 0.0757
#  Client8 Train => Local Epoch: 1 	Acc: 99.162 	Loss: 0.0333
#  Client8 Train => Local Epoch: 2 	Acc: 99.406 	Loss: 0.0232
#  Client8 Train => Local Epoch: 3 	Acc: 99.429 	Loss: 0.0210
#  Client8 Train => Local Epoch: 4 	Acc: 99.583 	Loss: 0.0177
#  Client8 Test =>                   	Acc: 88.477 	Loss: 0.4406
#  Client2 Train => Local Epoch: 0 	Acc: 98.575 	Loss: 0.0457
#  Client2 Train => Local Epoch: 1 	Acc: 99.242 	Loss: 0.0222
#  Client2 Train => Local Epoch: 2 	Acc: 99.581 	Loss: 0.0165
#  Client2 Train => Local Epoch: 3 	Acc: 99.777 	Loss: 0.0121
#  Client2 Train => Local Epoch: 4 	Acc: 99.760 	Loss: 0.0113
#  Client2 Test =>                   	Acc: 90.207 	Loss: 0.3648
#  Client3 Train => Local Epoch: 0 	Acc: 96.734 	Loss: 0.0979
#  Client3 Train => Local Epoch: 1 	Acc: 98.398 	Loss: 0.0522
#  Client3 Train => Local Epoch: 2 	Acc: 98.906 	Loss: 0.0376
#  Client3 Train => Local Epoch: 3 	Acc: 99.203 	Loss: 0.0334
#  Client3 Train => Local Epoch: 4 	Acc: 98.632 	Loss: 0.0396
#  Client3 Test =>                   	Acc: 89.965 	Loss: 0.3456
#  Client0 Train => Local Epoch: 0 	Acc: 98.423 	Loss: 0.0514
#  Client0 Train => Local Epoch: 1 	Acc: 98.992 	Loss: 0.0319
#  Client0 Train => Local Epoch: 2 	Acc: 99.453 	Loss: 0.0240
#  Client0 Train => Local Epoch: 3 	Acc: 99.595 	Loss: 0.0181
#  Client0 Train => Local Epoch: 4 	Acc: 99.858 	Loss: 0.0134
#  Client0 Test =>                   	Acc: 89.672 	Loss: 0.3691
#  Client9 Train => Local Epoch: 0 	Acc: 97.737 	Loss: 0.0722
#  Client9 Train => Local Epoch: 1 	Acc: 97.904 	Loss: 0.0567
#  Client9 Train => Local Epoch: 2 	Acc: 95.267 	Loss: 0.1417
#  Client9 Train => Local Epoch: 3 	Acc: 97.806 	Loss: 0.0666
#  Client9 Train => Local Epoch: 4 	Acc: 98.024 	Loss: 0.0604
#  Client9 Test =>                   	Acc: 90.972 	Loss: 0.2876
#  Client4 Train => Local Epoch: 0 	Acc: 98.115 	Loss: 0.0589
#  Client4 Train => Local Epoch: 1 	Acc: 99.296 	Loss: 0.0267
#  Client4 Train => Local Epoch: 2 	Acc: 99.589 	Loss: 0.0217
#  Client4 Train => Local Epoch: 3 	Acc: 99.609 	Loss: 0.0176
#  Client4 Train => Local Epoch: 4 	Acc: 99.850 	Loss: 0.0117
#  Client4 Test =>                   	Acc: 90.608 	Loss: 0.3212
#  Client7 Train => Local Epoch: 0 	Acc: 95.992 	Loss: 0.1231
#  Client7 Train => Local Epoch: 1 	Acc: 97.974 	Loss: 0.0578
#  Client7 Train => Local Epoch: 2 	Acc: 99.027 	Loss: 0.0339
#  Client7 Train => Local Epoch: 3 	Acc: 99.277 	Loss: 0.0250
#  Client7 Train => Local Epoch: 4 	Acc: 99.521 	Loss: 0.0181
#  Client7 Test =>                   	Acc: 90.073 	Loss: 0.3691
#  Client1 Train => Local Epoch: 0 	Acc: 95.787 	Loss: 0.1270
#  Client1 Train => Local Epoch: 1 	Acc: 98.470 	Loss: 0.0511
#  Client1 Train => Local Epoch: 2 	Acc: 99.303 	Loss: 0.0258
#  Client1 Train => Local Epoch: 3 	Acc: 99.406 	Loss: 0.0212
#  Client1 Train => Local Epoch: 4 	Acc: 99.577 	Loss: 0.0165
#  Client1 Test =>                   	Acc: 88.477 	Loss: 0.4449
#  Client5 Train => Local Epoch: 0 	Acc: 98.005 	Loss: 0.0590
#  Client5 Train => Local Epoch: 1 	Acc: 98.930 	Loss: 0.0387
#  Client5 Train => Local Epoch: 2 	Acc: 99.485 	Loss: 0.0244
#  Client5 Train => Local Epoch: 3 	Acc: 99.424 	Loss: 0.0223
#  Client5 Train => Local Epoch: 4 	Acc: 99.424 	Loss: 0.0191
#  Client5 Test =>                   	Acc: 87.823 	Loss: 0.3915
#  Client6 Train => Local Epoch: 0 	Acc: 97.442 	Loss: 0.0718
#  Client6 Train => Local Epoch: 1 	Acc: 99.140 	Loss: 0.0311
#  Client6 Train => Local Epoch: 2 	Acc: 99.245 	Loss: 0.0255
#  Client6 Train => Local Epoch: 3 	Acc: 99.440 	Loss: 0.0216
#  Client6 Train => Local Epoch: 4 	Acc: 99.654 	Loss: 0.0151
#  Client6 Test =>                   	Acc: 87.685 	Loss: 0.4400
# ====================== SERVER V1==========================
#  Train: Round  99, Avg Accuracy 99.388 | Avg Loss 0.022
#  Test: Round  99, Avg Accuracy 89.396 | Avg Loss 0.377
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Forgetting : Round 99, mean_forgetting : -0.222
# ==========================================================
# Training and Evaluation completed!
# Saved: SFLV2 - CIFAR-10 α=0.5.csv
