# %% [markdown]
# # Split Federated Learning V2 + Projected:
# ### CIFAR-10 + α = 0.5

# %%
# =============================================================================
# SFLV2 + Orthogonal Projection (Gated) on CIFAR-10 (Dirichlet α=0.1)
# - Warmup + alpha ramp + norm-preserving projection
# - Train-side feature reservoir (no test leakage)
# - Rebuild U every 3 rounds; clear buffer after rebuild
# - SGD + momentum + cosine LR (server); label smoothing
# - local_ep = 2; CIFAR-10 RandAug-lite; freeze client BN after warmup
# =============================================================================
import torch
from torch import nn
from torchvision import transforms
from torch.utils.data import DataLoader, Dataset
import torch.nn.functional as F
import math
import os.path
import pandas as pd
from sklearn.model_selection import train_test_split
from PIL import Image
from glob import glob
from pandas import DataFrame
import random
import numpy as np
import os


import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import copy
import time

# ----------------------------- Repro & Device --------------------------------
SEED = 1234
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
if torch.cuda.is_available():
    torch.backends.cudnn.deterministic = True
    print(torch.cuda.get_device_name(0))   
    

    
def _sync_cuda():
    if torch.cuda.is_available():
        torch.cuda.synchronize()

#====================Paremeters Change================================
program = "SFLV2 + Projected - CIFAR-10 α=0.5"
DATASET_NAME = "CIFAR10"
ALPHA = 0.5     # Non-IID split


DATA_ROOT = "data"
print(f"---------{program}----------")              # this is to identify the program in the slurm outputs files


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
pin = torch.cuda.is_available()


# To print in color -------test/train of the client side
def prRed(skk): print("\033[91m {}\033[00m" .format(skk)) 
def prGreen(skk): print("\033[92m {}\033[00m" .format(skk))     


#===================================================================
BATCH_SIZE = 256
LR_BASE = 0.01
MOMENTUM = 0.9
WEIGHT_DECAY = 5e-4
LABEL_SMOOTH = 0.0
NUM_WORKERS = 4


# No. of users
NUM_CLIENTS = 10
EPOCHS = 100
LOCAL_EPOCHS = 5
FRAC = 1        # participation of clients; if 1 then 100% clients participate in SFLV2



#=====================================================================================================
#                           Orthogonal Config
#=====================================================================================================
# Orthogonal projection config deque
ORTH = True
TOP_R = 8 # Smaller r to avoid over-pruning
rebuild_every = 3         # rebuild subspace cadence (rounds)
WARMUP_ROUNDS = 5         # no projection before this
alpha_max = 0.1           # target projection strength
alpha_min = 0.0
alpha_warm_len = 10       # rounds to ramp alpha after warmup

# total samples for building U_old
# Feature reservoir (train-side only)
FEATURE_MEM_CAP = 4096    # train-side feature reservoir
FEATURE_MEM = []
_seen = 0


U_old = None              # D x r matrix of principal directions at the cut
ell_global = 0            # current round index (for alpha schedule)


# ====================== Confirm =======================================
cut_at = "Late-cut at Layer 6 + AvgPool"
prRed(f"\tData:\t\t{DATASET_NAME}\n\tCut:\t\t{cut_at}\n\tGlobal Rounds:\t{EPOCHS}\n\tClients:\t{NUM_CLIENTS}\n\tLocal Epochs:\t{LOCAL_EPOCHS}\n\tα:\t\t{ALPHA}\n\tWarm-up:\t{WARMUP_ROUNDS}\n\tRebuild:\t{rebuild_every}")


#=====================================================================================================
#                       Round 4 New: Projection Gate
#=====================================================================================================

def proj_gate_strength(round_idx: int):
    """Alpha schedule for projection."""
    if round_idx < WARMUP_ROUNDS:
        return 0.0
    t = min(1.0, (round_idx - WARMUP_ROUNDS) / max(1, alpha_warm_len))
    return alpha_min + t * (alpha_max - alpha_min)

#=====================================================================================================
#                           Projection Help
#=====================================================================================================
def project_off_subspace_gated(grad_batch: torch.Tensor, U: torch.Tensor, alpha: float, preserve_norm=True):
    """g' = g - alpha * P_U(g), optionally rescale to preserve per-sample norm."""
    if (U is None) or (alpha <= 0.0):
        return grad_batch
    B = grad_batch.shape[0]
    g = grad_batch.view(B, -1)              # [B, D]
    comp = (g @ U) @ U.T                    # [B, D]
    if preserve_norm:
        n0 = g.norm(dim=1, keepdim=True).clamp_min(1e-12)
    g2 = g - alpha * comp
    if preserve_norm:
        n1 = g2.norm(dim=1, keepdim=True).clamp_min(1e-12)
        g2 = g2 * (n0 / n1)
    return g2.view_as(grad_batch)


def add_to_reservoir(rows_cpu_fp16: torch.Tensor):
    """Standard reservoir sampling to keep a fixed-size unbiased buffer."""
    global _seen, FEATURE_MEM
    for r in rows_cpu_fp16:
        _seen += 1
        if len(FEATURE_MEM) < FEATURE_MEM_CAP:
            FEATURE_MEM.append(r)
        else:
            j = np.random.randint(0, _seen)
            if j < FEATURE_MEM_CAP:
                FEATURE_MEM[j] = r

                
def collect_cut_feats_from_train(fx_client: torch.Tensor):
    """Collect a small subset of cut features from TRAIN forward passes only."""
    with torch.no_grad():
        feats = fx_client.detach().view(fx_client.shape[0], -1)  # [B, D]
        k = min(24, feats.shape[0])
        idx = torch.randperm(feats.shape[0], device=feats.device)[:k]
        add_to_reservoir(feats[idx].cpu().to(torch.float16))


#=====================================================================================================
#         Subspace builder (simple PCA/SVD on buffered features)
#=====================================================================================================
def build_U_old_from_memory(top_r=TOP_R, device='cpu'):
    """Build principal subspace from the reservoir via PCA (pca_lowrank)."""
    if len(FEATURE_MEM) == 0:
        return None
    X = torch.stack(FEATURE_MEM).to(torch.float32)     # [N, D]
    X = X - X.mean(dim=0, keepdim=True)
    U, S, V = torch.pca_lowrank(X.cpu(), q=min(top_r, X.shape[1]), center=False)
    return V[:, :top_r].to(device, dtype=torch.float32)

def clear_feature_mem():
    global FEATURE_MEM, _seen
    FEATURE_MEM.clear()
    _seen = 0

    
#=====================================================================================================
#                           Baseblock
#=====================================================================================================
class Baseblock(nn.Module):
    expansion = 1
    def __init__(self, input_planes, planes, stride = 1, dim_change = None):
        # super(Baseblock, self).__init__()
        super().__init__()
        self.conv1 = nn.Conv2d(input_planes, planes, stride =  stride, kernel_size = 3, padding = 1)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, stride = 1, kernel_size = 3, padding = 1)
        self.bn2 = nn.BatchNorm2d(planes)
        self.dim_change = dim_change
        
        
    def forward(self, x):
        res = x
        output = F.relu(self.bn1(self.conv1(x)))
        output = self.bn2(self.conv2(output))
        
        if self.dim_change is not None:
            res =self.dim_change(res)
            
        output += res
        output = F.relu(output)
        
        return output
        
    
#=====================================================================================================
#                           Client-side Model definition
#=====================================================================================================
# Model at client side
class ResNet18_client_side(nn.Module):
    def __init__(self, block, num_layers):
        super().__init__()
        self.layer1 = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False),  # 3x3 s=1
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            # no maxpool for 32x32
        )
        self.layer2 = nn.Sequential(
            nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(64),
        )

        # add layer 3-6 + avg-pool (copied from Client)
        self.layer3 = nn.Sequential (
                nn.Conv2d(64, 64, kernel_size = 3, stride = 1, padding = 1),
                nn.BatchNorm2d(64),
                nn.ReLU (inplace = True),
                nn.Conv2d(64, 64, kernel_size = 3, stride = 1, padding = 1),
                nn.BatchNorm2d(64),       
                )   


        # self.input_planes is only used inside _layer()
        self.input_planes = 64

        self.layer4 = self._layer(block, 128, num_layers[0], stride = 2)
        self.layer5 = self._layer(block, 256, num_layers[1], stride = 2)
        self.layer6 = self._layer(block, 512, num_layers[2], stride = 2)
        
        
        # self. averagePool = nn.AvgPool2d(kernel_size = 7, stride = 1)
        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))
        

        # Weights into loop (the same thing as SERVER)
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                m.weight.data.normal_(0, math.sqrt(2. / n))
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()
        

    # a helper function to build deeper ResNet blocks (layer4–6) using Baseblock
    def _layer(self, block, planes, num_layers, stride = 2):
        dim_change = None
        if stride != 1 or planes != self.input_planes * block.expansion:
            dim_change = nn.Sequential(nn.Conv2d(self.input_planes, planes*block.expansion, kernel_size = 1, stride = stride),
                                       nn.BatchNorm2d(planes*block.expansion))
        netLayers = []
        netLayers.append(block(self.input_planes, planes, stride = stride, dim_change = dim_change))
        self.input_planes = planes * block.expansion
        for i in range(1, num_layers):
            netLayers.append(block(self.input_planes, planes))
            self.input_planes = planes * block.expansion
            
        return nn.Sequential(*netLayers)

        
    def forward(self, x):
        resudial1 = F.relu(self.layer1(x))
        out1 = self.layer2(resudial1)
        out1 = out1 + resudial1 # adding the resudial inputs -- downsampling not required in this layer
        x = F.relu(out1)

        out2 = self.layer3(x)
        out2 = out2 + x
        x = F.relu(out2)

        x = self.layer4(x)                    # channels = 128
        x = self.layer5(x)                    # channels = 256
        x = self.layer6(x)                    # Channels = 512
        x = self.avgpool(x)                   # shape [B, 512, H', W']

        # MID-Cut: Send x to server
        return x            # [B, 512, H', W']


net_glob_client = ResNet18_client_side(Baseblock, [2, 2, 2])
if torch.cuda.device_count() > 1:
    print("We use",torch.cuda.device_count(), "GPUs")
    net_glob_client = nn.DataParallel(net_glob_client)   # to use the multiple GPUs; later we can change this to CPUs only 

net_glob_client.to(device)
print(net_glob_client)    


#=====================================================================================================
#                           Server-side Model definition
#=====================================================================================================
# Model at client side
class ResNet18_server_side(nn.Module):
    def __init__(self, block, classes):
        super(ResNet18_server_side, self).__init__()
        self.fc = nn.Linear(512 * block.expansion, classes)


        
        # Weights into loop
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                m.weight.data.normal_(0, math.sqrt(2. / n))
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()
    
        
    
    def forward(self, x):
        # x = [B, 512, 1, 1] from the Client side
        x = x.view(x.size(0), -1)            # [B, 512] 
        y_hat =self.fc(x)                    # [B, NUM_CLASSES]
        
        return y_hat

    
# === INSTANTIATE MODELS ===
if DATASET_NAME == "CIFAR10":
    net_glob_server = ResNet18_server_side(Baseblock, 10)
else:
    net_glob_server = ResNet18_server_side(Baseblock, 100)
    

if torch.cuda.device_count() > 1:
    print("We use",torch.cuda.device_count(), "GPUs")
    net_glob_server = nn.DataParallel(net_glob_server)   # to use the multiple GPUs 


net_glob_server.to(device)
print(net_glob_server)  


#===================================================================================
# For Server Side Loss and Accuracy 
loss_train_collect = []
acc_train_collect = []
loss_test_collect = []
acc_test_collect = []
batch_acc_train = []
batch_loss_train = []
batch_acc_test = []
batch_loss_test = []
round_time_collect = [] # Stores seconds per global round

criterion = nn.CrossEntropyLoss(label_smoothing=0.05)


# Persistent server optimizer & scheduler (like SL)
optimizer_server = torch.optim.SGD(net_glob_server.parameters(), lr=LR_BASE, momentum=MOMENTUM, weight_decay=WEIGHT_DECAY)
server_sched = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer_server, T_max=EPOCHS, eta_min=5e-4)


#====================================================================================================
#                                  Server Side Programs
#====================================================================================================
def calculate_accuracy(fx, y):
    preds = fx.max(1, keepdim=True)[1]
    correct = preds.eq(y.view_as(preds)).sum()
    acc = 100.00 *correct.float()/preds.shape[0]
    return acc

# to print train - test together in each round-- these are made global
acc_avg_all_user_train = 0
loss_avg_all_user_train = 0
loss_train_collect_user = []
acc_train_collect_user = []
loss_test_collect_user = []
acc_test_collect_user = []


#client idx collector
idx_collect = []
l_epoch_check = False
fed_check = False

count1 = 0
count2 = 0


# Server-side function associated with Training 
def train_server(fx_client, y, l_epoch_count, l_epoch, idx, len_batch):
    global net_glob_server, criterion, device
    global batch_acc_train, batch_loss_train, l_epoch_check, fed_check
    global loss_train_collect, acc_train_collect, count1
    global acc_avg_all_user_train, loss_avg_all_user_train, idx_collect
    global loss_train_collect_user, acc_train_collect_user
    global U_old, ell_global, optimizer_server  

    net_glob_server.train()
    # train and update
    optimizer_server.zero_grad()
    
    
    fx_client = fx_client.to(device)
    y = y.to(device)
    
    #---------forward prop-------------
    fx_server = net_glob_server(fx_client)
    
    # calculate loss
    loss = criterion(fx_server, y)
    # calculate accuracy
    acc = calculate_accuracy(fx_server, y)
    
    #--------backward prop--------------
    loss.backward()
    
    
    # ---- Projection on ∂L/∂f_c before returning to client ----
    dfx_client = fx_client.grad.clone().detach()
    if ORTH and (U_old is not None):
        alpha = proj_gate_strength(ell_global)
        dfx_client = project_off_subspace_gated(dfx_client, U_old.to(dfx_client.dtype), alpha, preserve_norm=True)
    # -----------------------------------------------------------
    
    
    optimizer_server.step()
    
    batch_loss_train.append(loss.item())
    batch_acc_train.append(acc.item())
    
    # server-side model net_glob_server is global so it is updated automatically in each pass to this function
    
    # count1: to track the completion of the local batch associated with one client
    count1 += 1
    if count1 == len_batch:
        acc_avg_train = sum(batch_acc_train)/len(batch_acc_train)           # it has accuracy for one batch
        loss_avg_train = sum(batch_loss_train)/len(batch_loss_train)
        
        batch_acc_train = []
        batch_loss_train = []
        count1 = 0
        
        prRed('Client{} Train => Local Epoch: {} \tAcc: {:.3f} \tLoss: {:.4f}'.format(idx, l_epoch_count, acc_avg_train, loss_avg_train))
        
                
        # If one local epoch is completed, after this a new client will come
        if l_epoch_count == l_epoch-1:
            
            l_epoch_check = True                # to evaluate_server function - to check local epoch has completed or not
                       
            # we store the last accuracy in the last batch of the epoch and it is not the average of all local epochs
            # this is because we work on the last trained model and its accuracy (not earlier cases)
            
            #print("accuracy = ", acc_avg_train)
            acc_avg_train_all = acc_avg_train
            loss_avg_train_all = loss_avg_train
                        
            # accumulate accuracy and loss for each new user
            loss_train_collect_user.append(loss_avg_train_all)
            acc_train_collect_user.append(acc_avg_train_all)
            
            # collect the id of each new user                        
            if idx not in idx_collect:
                idx_collect.append(idx) 
                #print(idx_collect)
        
        # This is to check if all users are served for one round --------------------
        if len(idx_collect) == NUM_CLIENTS:
            fed_check = True                                                  # to evaluate_server function  - to check fed check has hitted
            # all users served for one round ------------------------- output print and update is done in evaluate_server()
            # for nicer display 
                        
            idx_collect = []
            
            acc_avg_all_user_train = sum(acc_train_collect_user)/len(acc_train_collect_user)
            loss_avg_all_user_train = sum(loss_train_collect_user)/len(loss_train_collect_user)
            
            loss_train_collect.append(loss_avg_all_user_train)
            acc_train_collect.append(acc_avg_all_user_train)
            
            acc_train_collect_user = []
            loss_train_collect_user = []
            
    # send gradients to the client               
    return dfx_client

# Server-side functions associated with Testing
def evaluate_server(fx_client, y, idx, len_batch, ell):
    global net_glob_server, criterion, batch_acc_test, batch_loss_test
    global loss_test_collect, acc_test_collect, count2, NUM_CLIENTS, acc_avg_train_all, loss_avg_train_all, l_epoch_check, fed_check
    global loss_test_collect_user, acc_test_collect_user, acc_avg_all_user_train, loss_avg_all_user_train
    
    net_glob_server.eval()
  
    with torch.no_grad():
        fx_client = fx_client.to(device)
        y = y.to(device) 
        #---------forward prop-------------
        fx_server = net_glob_server(fx_client)
        
        # calculate loss
        loss = criterion(fx_server, y)
        # calculate accuracy
        acc = calculate_accuracy(fx_server, y)
        
        
        batch_loss_test.append(loss.item())
        batch_acc_test.append(acc.item())
        
               
        count2 += 1
        if count2 == len_batch:
            acc_avg_test = sum(batch_acc_test)/len(batch_acc_test)
            loss_avg_test = sum(batch_loss_test)/len(batch_loss_test)
            
            batch_acc_test = []
            batch_loss_test = []
            count2 = 0
            
            prGreen('Client{} Test =>                   \tAcc: {:.3f} \tLoss: {:.4f}'.format(idx, acc_avg_test, loss_avg_test))
            
            # if a local epoch is completed   
            if l_epoch_check:
                l_epoch_check = False
                
                # Store the last accuracy and loss
                acc_avg_test_all = acc_avg_test
                loss_avg_test_all = loss_avg_test
                        
                loss_test_collect_user.append(loss_avg_test_all)
                acc_test_collect_user.append(acc_avg_test_all)
                
            # if all users are served for one round ----------                    
            if fed_check:
                fed_check = False
                                
                acc_avg_all_user = sum(acc_test_collect_user)/len(acc_test_collect_user)
                loss_avg_all_user = sum(loss_test_collect_user)/len(loss_test_collect_user)
            
                loss_test_collect.append(loss_avg_all_user)
                acc_test_collect.append(acc_avg_all_user)
                acc_test_collect_user = []
                loss_test_collect_user= []
                              
                print("====================== SERVER V1==========================")
                print(' Train: Round {:3d}, Avg Accuracy {:.3f} | Avg Loss {:.3f}'.format(ell, acc_avg_all_user_train, loss_avg_all_user_train))
                print(' Test: Round {:3d}, Avg Accuracy {:.3f} | Avg Loss {:.3f}'.format(ell, acc_avg_all_user, loss_avg_all_user))
                # print("==========================================================")
                
                
            # Rebuild U on cadence (no feature collection here)
            if ORTH and (ell % rebuild_every == 1):
                global U_old
                U_old = build_U_old_from_memory(top_r=TOP_R, device=device)
                clear_feature_mem()
         
    return 


# ----------------------------- FedAvg (client) -------------------------------
def FedAvg(w_list):
    w_avg = copy.deepcopy(w_list[0])
    for k in w_avg.keys():
        for i in range(1, len(w_list)):
            w_avg[k] += w_list[i][k]
        w_avg[k] = torch.div(w_avg[k], len(w_list))
    return w_avg

#=============================================================================
#                         Data loading 
#============================================================================= 
from torchvision import datasets, transforms

# CIFAR-10 & CIFAR-100 transforms
cifar_mean = {
    "CIFAR10":  [0.4914, 0.4822, 0.4465],
    "CIFAR100": [0.5071, 0.4867, 0.4408],
}[DATASET_NAME]
cifar_std = {
    "CIFAR10":  [0.2470, 0.2435, 0.2616],
    "CIFAR100": [0.2675, 0.2565, 0.2761],
}[DATASET_NAME]

# Try RandAugment if available
try:
    from torchvision.transforms import RandAugment
    ra = [RandAugment(num_ops=2, magnitude=9)]
except Exception:
    ra = []

train_transforms = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(32, padding=4),
] + ra + [
    transforms.ToTensor(),
    transforms.Normalize(cifar_mean, cifar_std),
])

test_transforms = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(cifar_mean, cifar_std),
])

if DATASET_NAME == "CIFAR10":
    dataset_train = datasets.CIFAR10(root=DATA_ROOT, train=True,  download=True, transform=train_transforms)
    dataset_test  = datasets.CIFAR10(root=DATA_ROOT, train=False, download=True, transform=test_transforms)
else:
    dataset_train = datasets.CIFAR100(root=DATA_ROOT, train=True,  download=True, transform=train_transforms)
    dataset_test  = datasets.CIFAR100(root=DATA_ROOT, train=False, download=True, transform=test_transforms)

print("Train samples:", len(dataset_train), " Test samples:", len(dataset_test))
print("Example train label:", dataset_train.targets[0])

# ----------------------------- Partitions -----------------------------------
class DatasetSplit(Dataset):
    def __init__(self, dataset, idxs):
        self.dataset = dataset; self.idxs = list(idxs)
    def __len__(self): return len(self.idxs)
    def __getitem__(self, item): return self.dataset[self.idxs[item]]

def dataset_iid(dataset, NUM_CLIENTS):
    num_items = int(len(dataset)/NUM_CLIENTS)
    dict_users, all_idxs = {}, [i for i in range(len(dataset))]
    for i in range(NUM_CLIENTS):
        dict_users[i] = set(np.random.choice(all_idxs, num_items, replace=False))
        all_idxs = list(set(all_idxs) - dict_users[i])
    return dict_users

def dataset_noniid_dirichlet(dataset, NUM_CLIENTS, alpha=ALPHA, seed=SEED):
    rng = np.random.default_rng(seed)
    labels = np.array(dataset.targets)
    n_classes = len(np.unique(labels))
    dict_users = {i: set() for i in range(NUM_CLIENTS)}
    for c in range(n_classes):
        idxs = np.where(labels == c)[0]
        rng.shuffle(idxs)
        p = rng.dirichlet([alpha]*NUM_CLIENTS)
        cuts = (np.cumsum(p)*len(idxs)).astype(int)[:-1]
        splits = np.split(idxs, cuts)
        for client_id, split in enumerate(splits):
            dict_users[client_id].update(split.tolist())
    return dict_users

dict_users      = dataset_noniid_dirichlet(dataset_train, NUM_CLIENTS, alpha=ALPHA, seed=SEED)
dict_users_test = dataset_iid(dataset_test, NUM_CLIENTS)


#=============================================================================
#                         Forgetting metric setup 
#============================================================================= 

from collections import defaultdict

# Treat each global round as a window (quick baseline).
# If you want true distribution shifts, predefine your own windows and fill `val_loaders`.
T = EPOCHS

val_loaders = {}
# Deterministic, disjoint slices of the test set: window t gets items t, t+T, t+2T, ...
rng_idx = np.arange(len(dataset_test))
for t in range(T):
    idxs = rng_idx[t::T]
    val_loaders[t] = DataLoader(
        DatasetSplit(
            dataset_test, 
            idxs), 
        batch_size=BATCH_SIZE, 
        shuffle=False, 
        drop_last=False,
        num_workers=NUM_WORKERS,
        pin_memory=pin
    )

best_loss_per_window = defaultdict(lambda: float('inf'))  # stores min historical loss per window
forgetting_log = []  # per round dicts: {"round": t, "mean_forgetting": x, "per_window": {...}}
# ============================================================================

def _eval_loss_on_loader(model_client, model_server, loader, device, criterion):
    """Evaluate mean loss on a loader using split models."""
    # Handle DataParallel transparently
    mc = model_client.module if isinstance(model_client, nn.DataParallel) else model_client
    ms = model_server.module if isinstance(model_server, nn.DataParallel) else model_server
    mc.eval(); ms.eval()
    loss_sum, n = 0.0, 0
    with torch.no_grad():
        for images, labels in loader:
            images, labels = images.to(device), labels.to(device)
            fx = mc(images)
            logits = ms(fx)
            loss = criterion(logits, labels)
            bs = labels.size(0)
            loss_sum += loss.item() * bs
            n += bs
    return loss_sum / max(1, n)


# ------------------------------- Client --------------------------------------
def freeze_client_bn(net):
    for m in net.modules():
        if isinstance(m, nn.BatchNorm2d):
            m.eval()

class Client(object):
    def __init__(self, net_client_model, idx, lr, device,
                 dataset_train=None, dataset_test=None, idxs=None, idxs_test=None):
        self.idx = idx
        self.device = device
        self.lr = LR_BASE
        self.local_ep = LOCAL_EPOCHS
        self.ldr_train = DataLoader(
            DatasetSplit(
                dataset_train, 
                idxs), 
            batch_size=BATCH_SIZE, 
            shuffle=True, 
            drop_last=False,
            num_workers=NUM_WORKERS,
            pin_memory=pin
        )
        self.ldr_test  = DataLoader(
            DatasetSplit(
                dataset_test,  
                idxs_test), 
            batch_size=BATCH_SIZE, 
            shuffle=False, 
            drop_last=False,
            num_workers=NUM_WORKERS,
            pin_memory=pin
        )

    def train(self, net):
        net.train()
        optimizer_client = torch.optim.SGD(net.parameters(), lr=self.lr, momentum=MOMENTUM, weight_decay=WEIGHT_DECAY)
        for ep in range(self.local_ep):
            len_batch = len(self.ldr_train)
            for batch_idx, (images, labels) in enumerate(self.ldr_train):
                images, labels = images.to(self.device), labels.to(self.device)
                optimizer_client.zero_grad()
                fx = net(images)
                # collect train-side cut features into reservoir
                if ORTH:
                    collect_cut_feats_from_train(fx)
                client_fx = fx.clone().detach().requires_grad_(True)
                dfx = train_server(client_fx, labels, ep, self.local_ep, self.idx, len_batch)
                fx.backward(dfx)
                optimizer_client.step()
        return net.state_dict()

    def evaluate(self, net, ell):
        net.eval()
        with torch.no_grad():
            len_batch = len(self.ldr_test)
            for batch_idx, (images, labels) in enumerate(self.ldr_test):
                images, labels = images.to(self.device), labels.to(self.device)
                fx = net(images)
                evaluate_server(fx, labels, self.idx, len_batch, ell)
        return

# ------------------------------- Training ------------------------------------
net_glob_client.train()
w_glob_client = net_glob_client.state_dict()  # initial global client weights

acc_train_collect.clear(); loss_train_collect.clear()
acc_test_collect.clear();  loss_test_collect.clear()
round_time_collect.clear()

for iter in range(EPOCHS):
    ell_global = iter

    # Freeze BN (not timed)
    if iter == WARMUP_ROUNDS:
        if isinstance(net_glob_client, nn.DataParallel):
            freeze_client_bn(net_glob_client.module)
        else:
            freeze_client_bn(net_glob_client)

    # ---- START TIMER (training+testing+FedAvg only) ----
    _sync_cuda()
    t_start = time.perf_counter()
    # ----------------------------------------------------

    m = max(int(FRAC * NUM_CLIENTS), 1)
    idxs_users = np.random.choice(range(NUM_CLIENTS), m, replace=False)

    w_locals_client = []
    for idx in idxs_users:
        local = Client(net_glob_client, idx, LR_BASE, device,
                       dataset_train=dataset_train, dataset_test=dataset_test,
                       idxs=dict_users[idx], idxs_test=dict_users_test[idx])
        w_client = local.train(net=copy.deepcopy(net_glob_client).to(device))
        w_locals_client.append(copy.deepcopy(w_client))
        local.evaluate(net=copy.deepcopy(net_glob_client).to(device), ell=iter)

    # FedAvg
    w_glob_client = FedAvg(w_locals_client)
    net_glob_client.load_state_dict(w_glob_client)

    # ---- STOP TIMER & LOG ----
    _sync_cuda()
    dt = time.perf_counter() - t_start
    round_time_collect.append(dt)
    # --------------------------

    # === Forgetting metric update at end of round (not counted in time) ===
    t = iter
    L_cur_t = _eval_loss_on_loader(net_glob_client, net_glob_server, val_loaders[t], device, criterion)
    best_loss_per_window[t] = min(best_loss_per_window[t], L_cur_t)

    per_win_fgt = {}
    for t_prev in range(t):
        L_now = _eval_loss_on_loader(net_glob_client, net_glob_server, val_loaders[t_prev], device, criterion)
        Fgt = L_now - best_loss_per_window[t_prev]
        per_win_fgt[t_prev] = Fgt

    mean_fgt = float(np.mean(list(per_win_fgt.values()))) if per_win_fgt else 0.0
    forgetting_log.append({"round": t, "mean_forgetting": mean_fgt, "per_window": per_win_fgt})
    print(f"Forgetting : Round {t}, mean_forgetting : {mean_fgt:.3f}")
    print("==========================================================")


    # LR schedule (also outside timing)
    server_sched.step()

print("Training and Evaluation completed!")

# ----------------------------- Save outputs ----------------------------------
n = min(len(acc_train_collect), len(acc_test_collect), len(round_time_collect), len(forgetting_log))
if n == 0:
    # Safeguard: if per-round aggregates weren’t populated (e.g., single-user path),
    # still produce a minimal log so the files exist.
    n = len(round_time_collect)
round_process = list(range(1, n+1))
mean_fgt_series = [d["mean_forgetting"] for d in forgetting_log[:n]] if forgetting_log else [0.0]*n

df = DataFrame({
    'round': round_process,
    'acc_train': acc_train_collect[:n],
    'acc_test':  acc_test_collect[:n],
    'round_time_sec': round_time_collect[:n],
    'mean_FgT_loss': mean_fgt_series,
})

file_name_csv  = program + ".csv"
df.to_csv(file_name_csv, index=False)
print("Saved:", file_name_csv)

#=============================================================================
#                         Program Completed
#=============================================================================
# Out:
# NVIDIA H200
# ---------SFLV2 + Projected - CIFAR-10 α=0.5----------
#  	Data:		CIFAR10
# 	Cut:		Late-cut at Layer 6 + AvgPool
# 	Global Rounds:	100
# 	Clients:	10
# 	Local Epochs:	5
# 	α:		0.5
# 	Warm-up:	5
# 	Rebuild:	3
# ResNet18_client_side(
#   (layer1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (layer2): Sequential(
#     (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (layer3): Sequential(
#     (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (layer4): Sequential(
#     (0): Baseblock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dim_change): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2))
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Baseblock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer5): Sequential(
#     (0): Baseblock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dim_change): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2))
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Baseblock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer6): Sequential(
#     (0): Baseblock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dim_change): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2))
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Baseblock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
# )
# ResNet18_server_side(
#   (fc): Linear(in_features=512, out_features=10, bias=True)
# )
# Train samples: 50000  Test samples: 10000
# Example train label: 6
#  Client3 Train => Local Epoch: 0 	Acc: 42.124 	Loss: 1.8463
#  Client3 Train => Local Epoch: 1 	Acc: 47.304 	Loss: 1.6771
#  Client3 Train => Local Epoch: 2 	Acc: 48.220 	Loss: 1.6365
#  Client3 Train => Local Epoch: 3 	Acc: 50.858 	Loss: 1.5754
#  Client3 Train => Local Epoch: 4 	Acc: 52.321 	Loss: 1.5107
#  Client3 Test =>                   	Acc: 8.062 	Loss: 2.5541
#  Client1 Train => Local Epoch: 0 	Acc: 45.613 	Loss: 2.0860
#  Client1 Train => Local Epoch: 1 	Acc: 54.652 	Loss: 1.5631
#  Client1 Train => Local Epoch: 2 	Acc: 59.372 	Loss: 1.3744
#  Client1 Train => Local Epoch: 3 	Acc: 60.785 	Loss: 1.3156
#  Client1 Train => Local Epoch: 4 	Acc: 64.227 	Loss: 1.2426
#  Client1 Test =>                   	Acc: 10.480 	Loss: 3.5486
#  Client2 Train => Local Epoch: 0 	Acc: 38.983 	Loss: 1.8979
#  Client2 Train => Local Epoch: 1 	Acc: 48.528 	Loss: 1.5810
#  Client2 Train => Local Epoch: 2 	Acc: 51.667 	Loss: 1.5022
#  Client2 Train => Local Epoch: 3 	Acc: 53.331 	Loss: 1.4482
#  Client2 Train => Local Epoch: 4 	Acc: 55.394 	Loss: 1.4000
#  Client2 Test =>                   	Acc: 10.005 	Loss: 3.3198
#  Client0 Train => Local Epoch: 0 	Acc: 23.578 	Loss: 2.1821
#  Client0 Train => Local Epoch: 1 	Acc: 35.765 	Loss: 1.8849
#  Client0 Train => Local Epoch: 2 	Acc: 38.172 	Loss: 1.7589
#  Client0 Train => Local Epoch: 3 	Acc: 39.294 	Loss: 1.6951
#  Client0 Train => Local Epoch: 4 	Acc: 45.672 	Loss: 1.6102
#  Client0 Test =>                   	Acc: 13.594 	Loss: 2.8817
#  Client8 Train => Local Epoch: 0 	Acc: 32.014 	Loss: 2.0885
#  Client8 Train => Local Epoch: 1 	Acc: 42.679 	Loss: 1.6775
#  Client8 Train => Local Epoch: 2 	Acc: 47.746 	Loss: 1.4983
#  Client8 Train => Local Epoch: 3 	Acc: 49.314 	Loss: 1.4237
#  Client8 Train => Local Epoch: 4 	Acc: 51.138 	Loss: 1.3931
#  Client8 Test =>                   	Acc: 9.264 	Loss: 3.0000
#  Client7 Train => Local Epoch: 0 	Acc: 43.127 	Loss: 1.8250
#  Client7 Train => Local Epoch: 1 	Acc: 52.427 	Loss: 1.4753
#  Client7 Train => Local Epoch: 2 	Acc: 54.770 	Loss: 1.3901
#  Client7 Train => Local Epoch: 3 	Acc: 55.422 	Loss: 1.3545
#  Client7 Train => Local Epoch: 4 	Acc: 58.756 	Loss: 1.2928
#  Client7 Test =>                   	Acc: 11.699 	Loss: 3.0011
#  Client6 Train => Local Epoch: 0 	Acc: 35.679 	Loss: 2.1013
#  Client6 Train => Local Epoch: 1 	Acc: 46.788 	Loss: 1.5980
#  Client6 Train => Local Epoch: 2 	Acc: 51.092 	Loss: 1.5052
#  Client6 Train => Local Epoch: 3 	Acc: 53.164 	Loss: 1.4462
#  Client6 Train => Local Epoch: 4 	Acc: 54.210 	Loss: 1.4148
#  Client6 Test =>                   	Acc: 9.978 	Loss: 3.0080
#  Client9 Train => Local Epoch: 0 	Acc: 39.078 	Loss: 1.8602
#  Client9 Train => Local Epoch: 1 	Acc: 45.500 	Loss: 1.6171
#  Client9 Train => Local Epoch: 2 	Acc: 47.466 	Loss: 1.5394
#  Client9 Train => Local Epoch: 3 	Acc: 51.273 	Loss: 1.4797
#  Client9 Train => Local Epoch: 4 	Acc: 52.880 	Loss: 1.4143
#  Client9 Test =>                   	Acc: 10.368 	Loss: 2.7542
#  Client5 Train => Local Epoch: 0 	Acc: 28.875 	Loss: 2.0220
#  Client5 Train => Local Epoch: 1 	Acc: 40.029 	Loss: 1.7369
#  Client5 Train => Local Epoch: 2 	Acc: 42.489 	Loss: 1.6864
#  Client5 Train => Local Epoch: 3 	Acc: 46.196 	Loss: 1.6144
#  Client5 Train => Local Epoch: 4 	Acc: 47.967 	Loss: 1.5672
#  Client5 Test =>                   	Acc: 9.557 	Loss: 2.5447
#  Client4 Train => Local Epoch: 0 	Acc: 33.139 	Loss: 1.9468
#  Client4 Train => Local Epoch: 1 	Acc: 40.851 	Loss: 1.7186
#  Client4 Train => Local Epoch: 2 	Acc: 44.074 	Loss: 1.6261
#  Client4 Train => Local Epoch: 3 	Acc: 46.530 	Loss: 1.5749
#  Client4 Train => Local Epoch: 4 	Acc: 47.454 	Loss: 1.5396
#  Client4 Test =>                   	Acc: 13.672 	Loss: 2.6692
# ====================== SERVER V1==========================
#  Train: Round   0, Avg Accuracy 53.002 | Avg Loss 1.439
#  Test: Round   0, Avg Accuracy 10.668 | Avg Loss 2.928
# Forgetting : Round 0, mean_forgetting : 0.000
# ==========================================================
#  Client3 Train => Local Epoch: 0 	Acc: 45.304 	Loss: 1.7862
#  Client3 Train => Local Epoch: 1 	Acc: 50.234 	Loss: 1.5642
#  Client3 Train => Local Epoch: 2 	Acc: 53.500 	Loss: 1.4867
#  Client3 Train => Local Epoch: 3 	Acc: 55.110 	Loss: 1.4161
#  Client3 Train => Local Epoch: 4 	Acc: 56.939 	Loss: 1.3762
#  Client3 Test =>                   	Acc: 21.383 	Loss: 2.5499
#  Client9 Train => Local Epoch: 0 	Acc: 47.349 	Loss: 1.6562
#  Client9 Train => Local Epoch: 1 	Acc: 49.911 	Loss: 1.5012
#  Client9 Train => Local Epoch: 2 	Acc: 50.754 	Loss: 1.4951
#  Client9 Train => Local Epoch: 3 	Acc: 53.393 	Loss: 1.3952
#  Client9 Train => Local Epoch: 4 	Acc: 55.483 	Loss: 1.3619
#  Client9 Test =>                   	Acc: 26.778 	Loss: 2.3005
#  Client5 Train => Local Epoch: 0 	Acc: 40.169 	Loss: 1.7179
#  Client5 Train => Local Epoch: 1 	Acc: 45.390 	Loss: 1.5990
#  Client5 Train => Local Epoch: 2 	Acc: 48.581 	Loss: 1.5377
#  Client5 Train => Local Epoch: 3 	Acc: 51.010 	Loss: 1.5098
#  Client5 Train => Local Epoch: 4 	Acc: 51.027 	Loss: 1.4949
#  Client5 Test =>                   	Acc: 29.421 	Loss: 2.0031
#  Client0 Train => Local Epoch: 0 	Acc: 43.214 	Loss: 1.6365
#  Client0 Train => Local Epoch: 1 	Acc: 47.355 	Loss: 1.5820
#  Client0 Train => Local Epoch: 2 	Acc: 47.404 	Loss: 1.5272
#  Client0 Train => Local Epoch: 3 	Acc: 50.451 	Loss: 1.4843
#  Client0 Train => Local Epoch: 4 	Acc: 50.870 	Loss: 1.4576
#  Client0 Test =>                   	Acc: 24.353 	Loss: 2.2667
#  Client6 Train => Local Epoch: 0 	Acc: 46.939 	Loss: 1.6341
#  Client6 Train => Local Epoch: 1 	Acc: 53.024 	Loss: 1.4709
#  Client6 Train => Local Epoch: 2 	Acc: 54.992 	Loss: 1.4103
#  Client6 Train => Local Epoch: 3 	Acc: 57.626 	Loss: 1.3551
#  Client6 Train => Local Epoch: 4 	Acc: 58.795 	Loss: 1.3251
#  Client6 Test =>                   	Acc: 24.229 	Loss: 2.3873
#  Client2 Train => Local Epoch: 0 	Acc: 47.658 	Loss: 1.6672
#  Client2 Train => Local Epoch: 1 	Acc: 53.546 	Loss: 1.4507
#  Client2 Train => Local Epoch: 2 	Acc: 56.826 	Loss: 1.3703
#  Client2 Train => Local Epoch: 3 	Acc: 57.500 	Loss: 1.3309
#  Client2 Train => Local Epoch: 4 	Acc: 59.656 	Loss: 1.2912
#  Client2 Test =>                   	Acc: 33.843 	Loss: 2.0002
#  Client7 Train => Local Epoch: 0 	Acc: 47.499 	Loss: 1.7688
#  Client7 Train => Local Epoch: 1 	Acc: 55.268 	Loss: 1.3889
#  Client7 Train => Local Epoch: 2 	Acc: 58.945 	Loss: 1.2769
#  Client7 Train => Local Epoch: 3 	Acc: 60.843 	Loss: 1.2334
#  Client7 Train => Local Epoch: 4 	Acc: 62.996 	Loss: 1.2150
#  Client7 Test =>                   	Acc: 20.777 	Loss: 2.5588
#  Client4 Train => Local Epoch: 0 	Acc: 43.637 	Loss: 1.8419
#  Client4 Train => Local Epoch: 1 	Acc: 49.945 	Loss: 1.6704
#  Client4 Train => Local Epoch: 2 	Acc: 51.703 	Loss: 1.5027
#  Client4 Train => Local Epoch: 3 	Acc: 51.519 	Loss: 1.4492
#  Client4 Train => Local Epoch: 4 	Acc: 53.715 	Loss: 1.4016
#  Client4 Test =>                   	Acc: 25.178 	Loss: 2.5676
#  Client8 Train => Local Epoch: 0 	Acc: 45.173 	Loss: 1.6823
#  Client8 Train => Local Epoch: 1 	Acc: 52.909 	Loss: 1.4320
#  Client8 Train => Local Epoch: 2 	Acc: 54.997 	Loss: 1.3678
#  Client8 Train => Local Epoch: 3 	Acc: 56.692 	Loss: 1.3132
#  Client8 Train => Local Epoch: 4 	Acc: 57.111 	Loss: 1.2715
#  Client8 Test =>                   	Acc: 21.508 	Loss: 2.6073
#  Client1 Train => Local Epoch: 0 	Acc: 51.910 	Loss: 2.0319
#  Client1 Train => Local Epoch: 1 	Acc: 61.360 	Loss: 1.5086
#  Client1 Train => Local Epoch: 2 	Acc: 65.839 	Loss: 1.2794
#  Client1 Train => Local Epoch: 3 	Acc: 65.901 	Loss: 1.1941
#  Client1 Train => Local Epoch: 4 	Acc: 68.869 	Loss: 1.1260
#  Client1 Test =>                   	Acc: 19.403 	Loss: 2.9676
# ====================== SERVER V1==========================
#  Train: Round   1, Avg Accuracy 57.546 | Avg Loss 1.332
#  Test: Round   1, Avg Accuracy 24.687 | Avg Loss 2.421
# Forgetting : Round 1, mean_forgetting : -0.195
# ==========================================================
#  Client8 Train => Local Epoch: 0 	Acc: 51.610 	Loss: 1.5454
#  Client8 Train => Local Epoch: 1 	Acc: 57.521 	Loss: 1.3916
#  Client8 Train => Local Epoch: 2 	Acc: 58.967 	Loss: 1.3196
#  Client8 Train => Local Epoch: 3 	Acc: 59.055 	Loss: 1.2879
#  Client8 Train => Local Epoch: 4 	Acc: 59.976 	Loss: 1.2754
#  Client8 Test =>                   	Acc: 28.788 	Loss: 2.9924
#  Client1 Train => Local Epoch: 0 	Acc: 47.704 	Loss: 3.3643
#  Client1 Train => Local Epoch: 1 	Acc: 60.663 	Loss: 1.8330
#  Client1 Train => Local Epoch: 2 	Acc: 63.332 	Loss: 1.3808
#  Client1 Train => Local Epoch: 3 	Acc: 66.364 	Loss: 1.2128
#  Client1 Train => Local Epoch: 4 	Acc: 68.646 	Loss: 1.1597
#  Client1 Test =>                   	Acc: 21.494 	Loss: 3.6931
#  Client6 Train => Local Epoch: 0 	Acc: 47.647 	Loss: 1.9536
#  Client6 Train => Local Epoch: 1 	Acc: 54.570 	Loss: 1.4442
#  Client6 Train => Local Epoch: 2 	Acc: 58.233 	Loss: 1.3317
#  Client6 Train => Local Epoch: 3 	Acc: 59.515 	Loss: 1.2969
#  Client6 Train => Local Epoch: 4 	Acc: 60.922 	Loss: 1.2680
#  Client6 Test =>                   	Acc: 35.166 	Loss: 2.0386
#  Client4 Train => Local Epoch: 0 	Acc: 46.542 	Loss: 1.7449
#  Client4 Train => Local Epoch: 1 	Acc: 52.721 	Loss: 1.4613
#  Client4 Train => Local Epoch: 2 	Acc: 54.171 	Loss: 1.4039
#  Client4 Train => Local Epoch: 3 	Acc: 56.623 	Loss: 1.3523
#  Client4 Train => Local Epoch: 4 	Acc: 58.996 	Loss: 1.3155
#  Client4 Test =>                   	Acc: 36.180 	Loss: 2.0756
#  Client7 Train => Local Epoch: 0 	Acc: 51.654 	Loss: 1.5812
#  Client7 Train => Local Epoch: 1 	Acc: 61.138 	Loss: 1.2736
#  Client7 Train => Local Epoch: 2 	Acc: 63.480 	Loss: 1.1907
#  Client7 Train => Local Epoch: 3 	Acc: 65.625 	Loss: 1.1567
#  Client7 Train => Local Epoch: 4 	Acc: 65.999 	Loss: 1.1536
#  Client7 Test =>                   	Acc: 26.290 	Loss: 2.3547
#  Client9 Train => Local Epoch: 0 	Acc: 51.640 	Loss: 1.5914
#  Client9 Train => Local Epoch: 1 	Acc: 55.905 	Loss: 1.3754
#  Client9 Train => Local Epoch: 2 	Acc: 57.073 	Loss: 1.3399
#  Client9 Train => Local Epoch: 3 	Acc: 58.488 	Loss: 1.2946
#  Client9 Train => Local Epoch: 4 	Acc: 59.618 	Loss: 1.2741
#  Client9 Test =>                   	Acc: 38.584 	Loss: 1.8056
#  Client0 Train => Local Epoch: 0 	Acc: 48.363 	Loss: 1.6380
#  Client0 Train => Local Epoch: 1 	Acc: 52.049 	Loss: 1.5008
#  Client0 Train => Local Epoch: 2 	Acc: 51.992 	Loss: 1.4346
#  Client0 Train => Local Epoch: 3 	Acc: 53.647 	Loss: 1.4134
#  Client0 Train => Local Epoch: 4 	Acc: 55.685 	Loss: 1.3666
#  Client0 Test =>                   	Acc: 33.318 	Loss: 1.9776
#  Client3 Train => Local Epoch: 0 	Acc: 48.790 	Loss: 1.6797
#  Client3 Train => Local Epoch: 1 	Acc: 56.069 	Loss: 1.3876
#  Client3 Train => Local Epoch: 2 	Acc: 57.202 	Loss: 1.3576
#  Client3 Train => Local Epoch: 3 	Acc: 58.703 	Loss: 1.3348
#  Client3 Train => Local Epoch: 4 	Acc: 59.941 	Loss: 1.3048
#  Client3 Test =>                   	Acc: 32.341 	Loss: 2.0287
#  Client2 Train => Local Epoch: 0 	Acc: 52.123 	Loss: 1.5875
#  Client2 Train => Local Epoch: 1 	Acc: 58.281 	Loss: 1.3412
#  Client2 Train => Local Epoch: 2 	Acc: 59.277 	Loss: 1.3012
#  Client2 Train => Local Epoch: 3 	Acc: 61.745 	Loss: 1.2451
#  Client2 Train => Local Epoch: 4 	Acc: 63.550 	Loss: 1.1943
#  Client2 Test =>                   	Acc: 43.871 	Loss: 1.6749
#  Client5 Train => Local Epoch: 0 	Acc: 46.608 	Loss: 1.6010
#  Client5 Train => Local Epoch: 1 	Acc: 49.920 	Loss: 1.5203
#  Client5 Train => Local Epoch: 2 	Acc: 52.305 	Loss: 1.4549
#  Client5 Train => Local Epoch: 3 	Acc: 53.168 	Loss: 1.4205
#  Client5 Train => Local Epoch: 4 	Acc: 56.212 	Loss: 1.3785
#  Client5 Test =>                   	Acc: 41.059 	Loss: 1.7034
# ====================== SERVER V1==========================
#  Train: Round   2, Avg Accuracy 60.954 | Avg Loss 1.269
#  Test: Round   2, Avg Accuracy 33.709 | Avg Loss 2.234
# Forgetting : Round 2, mean_forgetting : -0.773
# ==========================================================
#  Client2 Train => Local Epoch: 0 	Acc: 57.585 	Loss: 1.3639
#  Client2 Train => Local Epoch: 1 	Acc: 62.852 	Loss: 1.2207
#  Client2 Train => Local Epoch: 2 	Acc: 63.823 	Loss: 1.1912
#  Client2 Train => Local Epoch: 3 	Acc: 65.037 	Loss: 1.1649
#  Client2 Train => Local Epoch: 4 	Acc: 65.615 	Loss: 1.1458
#  Client2 Test =>                   	Acc: 45.757 	Loss: 1.6405
#  Client0 Train => Local Epoch: 0 	Acc: 51.310 	Loss: 1.5266
#  Client0 Train => Local Epoch: 1 	Acc: 55.117 	Loss: 1.3902
#  Client0 Train => Local Epoch: 2 	Acc: 57.005 	Loss: 1.3408
#  Client0 Train => Local Epoch: 3 	Acc: 56.310 	Loss: 1.3435
#  Client0 Train => Local Epoch: 4 	Acc: 58.377 	Loss: 1.2883
#  Client0 Test =>                   	Acc: 37.685 	Loss: 1.7340
#  Client4 Train => Local Epoch: 0 	Acc: 57.491 	Loss: 1.3462
#  Client4 Train => Local Epoch: 1 	Acc: 57.256 	Loss: 1.3229
#  Client4 Train => Local Epoch: 2 	Acc: 61.207 	Loss: 1.2476
#  Client4 Train => Local Epoch: 3 	Acc: 61.713 	Loss: 1.2434
#  Client4 Train => Local Epoch: 4 	Acc: 61.705 	Loss: 1.2330
#  Client4 Test =>                   	Acc: 40.187 	Loss: 1.8654
#  Client7 Train => Local Epoch: 0 	Acc: 56.193 	Loss: 1.4594
#  Client7 Train => Local Epoch: 1 	Acc: 64.339 	Loss: 1.1846
#  Client7 Train => Local Epoch: 2 	Acc: 66.730 	Loss: 1.1362
#  Client7 Train => Local Epoch: 3 	Acc: 68.725 	Loss: 1.0842
#  Client7 Train => Local Epoch: 4 	Acc: 69.663 	Loss: 1.0647
#  Client7 Test =>                   	Acc: 34.823 	Loss: 1.9641
#  Client9 Train => Local Epoch: 0 	Acc: 54.851 	Loss: 1.4654
#  Client9 Train => Local Epoch: 1 	Acc: 56.430 	Loss: 1.3372
#  Client9 Train => Local Epoch: 2 	Acc: 60.038 	Loss: 1.2540
#  Client9 Train => Local Epoch: 3 	Acc: 60.641 	Loss: 1.2456
#  Client9 Train => Local Epoch: 4 	Acc: 61.015 	Loss: 1.2280
#  Client9 Test =>                   	Acc: 44.878 	Loss: 1.6269
#  Client8 Train => Local Epoch: 0 	Acc: 57.162 	Loss: 1.3513
#  Client8 Train => Local Epoch: 1 	Acc: 59.205 	Loss: 1.2855
#  Client8 Train => Local Epoch: 2 	Acc: 62.532 	Loss: 1.1781
#  Client8 Train => Local Epoch: 3 	Acc: 63.469 	Loss: 1.1645
#  Client8 Train => Local Epoch: 4 	Acc: 63.819 	Loss: 1.1281
#  Client8 Test =>                   	Acc: 36.793 	Loss: 1.8771
#  Client6 Train => Local Epoch: 0 	Acc: 58.185 	Loss: 1.3376
#  Client6 Train => Local Epoch: 1 	Acc: 59.761 	Loss: 1.2915
#  Client6 Train => Local Epoch: 2 	Acc: 61.545 	Loss: 1.2414
#  Client6 Train => Local Epoch: 3 	Acc: 62.551 	Loss: 1.2161
#  Client6 Train => Local Epoch: 4 	Acc: 63.344 	Loss: 1.2021
#  Client6 Test =>                   	Acc: 38.655 	Loss: 1.8009
#  Client3 Train => Local Epoch: 0 	Acc: 51.743 	Loss: 1.6021
#  Client3 Train => Local Epoch: 1 	Acc: 58.000 	Loss: 1.3425
#  Client3 Train => Local Epoch: 2 	Acc: 60.955 	Loss: 1.2889
#  Client3 Train => Local Epoch: 3 	Acc: 61.517 	Loss: 1.2400
#  Client3 Train => Local Epoch: 4 	Acc: 62.582 	Loss: 1.2302
#  Client3 Test =>                   	Acc: 40.228 	Loss: 1.7939
#  Client1 Train => Local Epoch: 0 	Acc: 61.764 	Loss: 1.4557
#  Client1 Train => Local Epoch: 1 	Acc: 67.471 	Loss: 1.1696
#  Client1 Train => Local Epoch: 2 	Acc: 70.496 	Loss: 1.1011
#  Client1 Train => Local Epoch: 3 	Acc: 72.034 	Loss: 1.0242
#  Client1 Train => Local Epoch: 4 	Acc: 72.153 	Loss: 1.0148
#  Client1 Test =>                   	Acc: 30.563 	Loss: 2.0747
#  Client5 Train => Local Epoch: 0 	Acc: 47.827 	Loss: 1.6769
#  Client5 Train => Local Epoch: 1 	Acc: 53.354 	Loss: 1.4268
#  Client5 Train => Local Epoch: 2 	Acc: 55.376 	Loss: 1.3927
#  Client5 Train => Local Epoch: 3 	Acc: 57.696 	Loss: 1.3423
#  Client5 Train => Local Epoch: 4 	Acc: 59.096 	Loss: 1.3096
#  Client5 Test =>                   	Acc: 50.216 	Loss: 1.4918
# ====================== SERVER V1==========================
#  Train: Round   3, Avg Accuracy 63.737 | Avg Loss 1.184
#  Test: Round   3, Avg Accuracy 39.978 | Avg Loss 1.787
# Forgetting : Round 3, mean_forgetting : -0.623
# ==========================================================
#  Client6 Train => Local Epoch: 0 	Acc: 57.341 	Loss: 1.3623
#  Client6 Train => Local Epoch: 1 	Acc: 62.336 	Loss: 1.2209
#  Client6 Train => Local Epoch: 2 	Acc: 64.437 	Loss: 1.1738
#  Client6 Train => Local Epoch: 3 	Acc: 65.156 	Loss: 1.1535
#  Client6 Train => Local Epoch: 4 	Acc: 65.432 	Loss: 1.1445
#  Client6 Test =>                   	Acc: 44.774 	Loss: 1.6448
#  Client4 Train => Local Epoch: 0 	Acc: 55.455 	Loss: 1.5293
#  Client4 Train => Local Epoch: 1 	Acc: 61.021 	Loss: 1.2889
#  Client4 Train => Local Epoch: 2 	Acc: 62.186 	Loss: 1.2235
#  Client4 Train => Local Epoch: 3 	Acc: 65.140 	Loss: 1.1754
#  Client4 Train => Local Epoch: 4 	Acc: 63.491 	Loss: 1.1735
#  Client4 Test =>                   	Acc: 46.589 	Loss: 1.6649
#  Client0 Train => Local Epoch: 0 	Acc: 57.808 	Loss: 1.2962
#  Client0 Train => Local Epoch: 1 	Acc: 61.310 	Loss: 1.2550
#  Client0 Train => Local Epoch: 2 	Acc: 63.149 	Loss: 1.2066
#  Client0 Train => Local Epoch: 3 	Acc: 61.516 	Loss: 1.2160
#  Client0 Train => Local Epoch: 4 	Acc: 63.227 	Loss: 1.1862
#  Client0 Test =>                   	Acc: 48.491 	Loss: 1.5371
#  Client3 Train => Local Epoch: 0 	Acc: 54.666 	Loss: 1.5194
#  Client3 Train => Local Epoch: 1 	Acc: 60.854 	Loss: 1.2629
#  Client3 Train => Local Epoch: 2 	Acc: 63.292 	Loss: 1.2281
#  Client3 Train => Local Epoch: 3 	Acc: 64.231 	Loss: 1.1862
#  Client3 Train => Local Epoch: 4 	Acc: 64.403 	Loss: 1.1730
#  Client3 Test =>                   	Acc: 45.437 	Loss: 1.6955
#  Client5 Train => Local Epoch: 0 	Acc: 53.171 	Loss: 1.5376
#  Client5 Train => Local Epoch: 1 	Acc: 57.345 	Loss: 1.3475
#  Client5 Train => Local Epoch: 2 	Acc: 60.244 	Loss: 1.2969
#  Client5 Train => Local Epoch: 3 	Acc: 60.963 	Loss: 1.2534
#  Client5 Train => Local Epoch: 4 	Acc: 63.310 	Loss: 1.2223
#  Client5 Test =>                   	Acc: 52.963 	Loss: 1.4256
#  Client7 Train => Local Epoch: 0 	Acc: 57.841 	Loss: 1.4497
#  Client7 Train => Local Epoch: 1 	Acc: 66.142 	Loss: 1.1507
#  Client7 Train => Local Epoch: 2 	Acc: 68.744 	Loss: 1.0673
#  Client7 Train => Local Epoch: 3 	Acc: 70.377 	Loss: 1.0490
#  Client7 Train => Local Epoch: 4 	Acc: 70.626 	Loss: 1.0217
#  Client7 Test =>                   	Acc: 43.521 	Loss: 1.7578
#  Client1 Train => Local Epoch: 0 	Acc: 63.096 	Loss: 1.4494
#  Client1 Train => Local Epoch: 1 	Acc: 71.372 	Loss: 1.1723
#  Client1 Train => Local Epoch: 2 	Acc: 72.758 	Loss: 1.0143
#  Client1 Train => Local Epoch: 3 	Acc: 75.148 	Loss: 0.9441
#  Client1 Train => Local Epoch: 4 	Acc: 75.918 	Loss: 0.9300
#  Client1 Test =>                   	Acc: 40.261 	Loss: 1.8259
#  Client8 Train => Local Epoch: 0 	Acc: 57.238 	Loss: 1.4434
#  Client8 Train => Local Epoch: 1 	Acc: 63.055 	Loss: 1.2441
#  Client8 Train => Local Epoch: 2 	Acc: 64.112 	Loss: 1.1897
#  Client8 Train => Local Epoch: 3 	Acc: 64.367 	Loss: 1.1532
#  Client8 Train => Local Epoch: 4 	Acc: 66.521 	Loss: 1.0978
#  Client8 Test =>                   	Acc: 42.979 	Loss: 2.2700
#  Client2 Train => Local Epoch: 0 	Acc: 53.928 	Loss: 1.6340
#  Client2 Train => Local Epoch: 1 	Acc: 63.475 	Loss: 1.2032
#  Client2 Train => Local Epoch: 2 	Acc: 66.817 	Loss: 1.1185
#  Client2 Train => Local Epoch: 3 	Acc: 68.360 	Loss: 1.0805
#  Client2 Train => Local Epoch: 4 	Acc: 69.493 	Loss: 1.0608
#  Client2 Test =>                   	Acc: 53.186 	Loss: 1.4523
#  Client9 Train => Local Epoch: 0 	Acc: 58.900 	Loss: 1.3240
#  Client9 Train => Local Epoch: 1 	Acc: 61.244 	Loss: 1.2477
#  Client9 Train => Local Epoch: 2 	Acc: 60.187 	Loss: 1.2619
#  Client9 Train => Local Epoch: 3 	Acc: 63.295 	Loss: 1.1841
#  Client9 Train => Local Epoch: 4 	Acc: 63.962 	Loss: 1.1772
#  Client9 Test =>                   	Acc: 51.623 	Loss: 1.5241
# ====================== SERVER V1==========================
#  Train: Round   4, Avg Accuracy 66.638 | Avg Loss 1.119
#  Test: Round   4, Avg Accuracy 46.982 | Avg Loss 1.680
# Forgetting : Round 4, mean_forgetting : -0.408
# ==========================================================
#  Client9 Train => Local Epoch: 0 	Acc: 63.681 	Loss: 1.1629
#  Client9 Train => Local Epoch: 1 	Acc: 62.857 	Loss: 1.1907
#  Client9 Train => Local Epoch: 2 	Acc: 64.278 	Loss: 1.1600
#  Client9 Train => Local Epoch: 3 	Acc: 63.221 	Loss: 1.1978
#  Client9 Train => Local Epoch: 4 	Acc: 65.483 	Loss: 1.1369
#  Client9 Test =>                   	Acc: 55.795 	Loss: 1.4055
#  Client4 Train => Local Epoch: 0 	Acc: 59.190 	Loss: 1.3736
#  Client4 Train => Local Epoch: 1 	Acc: 66.184 	Loss: 1.1983
#  Client4 Train => Local Epoch: 2 	Acc: 69.388 	Loss: 1.1318
#  Client4 Train => Local Epoch: 3 	Acc: 67.720 	Loss: 1.1259
#  Client4 Train => Local Epoch: 4 	Acc: 68.863 	Loss: 1.0728
#  Client4 Test =>                   	Acc: 47.458 	Loss: 1.7183
#  Client6 Train => Local Epoch: 0 	Acc: 58.168 	Loss: 1.3841
#  Client6 Train => Local Epoch: 1 	Acc: 64.797 	Loss: 1.1640
#  Client6 Train => Local Epoch: 2 	Acc: 66.039 	Loss: 1.1339
#  Client6 Train => Local Epoch: 3 	Acc: 66.328 	Loss: 1.1270
#  Client6 Train => Local Epoch: 4 	Acc: 69.073 	Loss: 1.0713
#  Client6 Test =>                   	Acc: 52.280 	Loss: 1.4515
#  Client7 Train => Local Epoch: 0 	Acc: 64.588 	Loss: 1.2382
#  Client7 Train => Local Epoch: 1 	Acc: 70.866 	Loss: 1.0510
#  Client7 Train => Local Epoch: 2 	Acc: 71.875 	Loss: 0.9980
#  Client7 Train => Local Epoch: 3 	Acc: 72.192 	Loss: 0.9927
#  Client7 Train => Local Epoch: 4 	Acc: 72.364 	Loss: 0.9744
#  Client7 Test =>                   	Acc: 46.609 	Loss: 1.6745
#  Client5 Train => Local Epoch: 0 	Acc: 57.001 	Loss: 1.4314
#  Client5 Train => Local Epoch: 1 	Acc: 62.078 	Loss: 1.2350
#  Client5 Train => Local Epoch: 2 	Acc: 63.067 	Loss: 1.2001
#  Client5 Train => Local Epoch: 3 	Acc: 63.828 	Loss: 1.1953
#  Client5 Train => Local Epoch: 4 	Acc: 64.216 	Loss: 1.1847
#  Client5 Test =>                   	Acc: 56.122 	Loss: 1.3613
#  Client1 Train => Local Epoch: 0 	Acc: 66.259 	Loss: 1.2615
#  Client1 Train => Local Epoch: 1 	Acc: 75.416 	Loss: 1.0341
#  Client1 Train => Local Epoch: 2 	Acc: 76.613 	Loss: 0.9457
#  Client1 Train => Local Epoch: 3 	Acc: 77.632 	Loss: 0.8863
#  Client1 Train => Local Epoch: 4 	Acc: 77.841 	Loss: 0.8690
#  Client1 Test =>                   	Acc: 41.881 	Loss: 1.7514
#  Client0 Train => Local Epoch: 0 	Acc: 57.233 	Loss: 1.3578
#  Client0 Train => Local Epoch: 1 	Acc: 60.450 	Loss: 1.2719
#  Client0 Train => Local Epoch: 2 	Acc: 65.116 	Loss: 1.1718
#  Client0 Train => Local Epoch: 3 	Acc: 65.649 	Loss: 1.1467
#  Client0 Train => Local Epoch: 4 	Acc: 67.396 	Loss: 1.1114
#  Client0 Test =>                   	Acc: 49.205 	Loss: 1.4928
#  Client8 Train => Local Epoch: 0 	Acc: 56.874 	Loss: 1.4489
#  Client8 Train => Local Epoch: 1 	Acc: 62.426 	Loss: 1.2117
#  Client8 Train => Local Epoch: 2 	Acc: 64.683 	Loss: 1.1400
#  Client8 Train => Local Epoch: 3 	Acc: 65.609 	Loss: 1.0755
#  Client8 Train => Local Epoch: 4 	Acc: 66.408 	Loss: 1.0640
#  Client8 Test =>                   	Acc: 42.167 	Loss: 1.8178
#  Client3 Train => Local Epoch: 0 	Acc: 54.100 	Loss: 1.5356
#  Client3 Train => Local Epoch: 1 	Acc: 63.230 	Loss: 1.2286
#  Client3 Train => Local Epoch: 2 	Acc: 64.907 	Loss: 1.1644
#  Client3 Train => Local Epoch: 3 	Acc: 65.018 	Loss: 1.1701
#  Client3 Train => Local Epoch: 4 	Acc: 65.634 	Loss: 1.1451
#  Client3 Test =>                   	Acc: 46.845 	Loss: 1.6671
#  Client2 Train => Local Epoch: 0 	Acc: 62.503 	Loss: 1.2893
#  Client2 Train => Local Epoch: 1 	Acc: 67.787 	Loss: 1.0999
#  Client2 Train => Local Epoch: 2 	Acc: 69.678 	Loss: 1.0447
#  Client2 Train => Local Epoch: 3 	Acc: 71.309 	Loss: 1.0130
#  Client2 Train => Local Epoch: 4 	Acc: 72.063 	Loss: 0.9955
#  Client2 Test =>                   	Acc: 54.698 	Loss: 1.4134
# ====================== SERVER V1==========================
#  Train: Round   5, Avg Accuracy 68.934 | Avg Loss 1.063
#  Test: Round   5, Avg Accuracy 49.306 | Avg Loss 1.575
# Forgetting : Round 5, mean_forgetting : -0.472
# ==========================================================
#  Client5 Train => Local Epoch: 0 	Acc: 59.849 	Loss: 1.3106
#  Client5 Train => Local Epoch: 1 	Acc: 63.521 	Loss: 1.1970
#  Client5 Train => Local Epoch: 2 	Acc: 66.279 	Loss: 1.1410
#  Client5 Train => Local Epoch: 3 	Acc: 66.401 	Loss: 1.1218
#  Client5 Train => Local Epoch: 4 	Acc: 68.050 	Loss: 1.1033
#  Client5 Test =>                   	Acc: 56.631 	Loss: 1.3365
#  Client9 Train => Local Epoch: 0 	Acc: 64.938 	Loss: 1.1530
#  Client9 Train => Local Epoch: 1 	Acc: 64.731 	Loss: 1.1448
#  Client9 Train => Local Epoch: 2 	Acc: 67.196 	Loss: 1.0982
#  Client9 Train => Local Epoch: 3 	Acc: 65.759 	Loss: 1.1244
#  Client9 Train => Local Epoch: 4 	Acc: 68.188 	Loss: 1.0647
#  Client9 Test =>                   	Acc: 60.035 	Loss: 1.2899
#  Client7 Train => Local Epoch: 0 	Acc: 66.076 	Loss: 1.1945
#  Client7 Train => Local Epoch: 1 	Acc: 71.985 	Loss: 1.0020
#  Client7 Train => Local Epoch: 2 	Acc: 72.910 	Loss: 0.9706
#  Client7 Train => Local Epoch: 3 	Acc: 74.030 	Loss: 0.9405
#  Client7 Train => Local Epoch: 4 	Acc: 74.869 	Loss: 0.9162
#  Client7 Test =>                   	Acc: 48.926 	Loss: 1.6235
#  Client6 Train => Local Epoch: 0 	Acc: 59.788 	Loss: 1.3831
#  Client6 Train => Local Epoch: 1 	Acc: 66.513 	Loss: 1.1331
#  Client6 Train => Local Epoch: 2 	Acc: 67.710 	Loss: 1.0933
#  Client6 Train => Local Epoch: 3 	Acc: 69.112 	Loss: 1.0664
#  Client6 Train => Local Epoch: 4 	Acc: 70.282 	Loss: 1.0306
#  Client6 Test =>                   	Acc: 54.566 	Loss: 1.4180
#  Client2 Train => Local Epoch: 0 	Acc: 65.096 	Loss: 1.2092
#  Client2 Train => Local Epoch: 1 	Acc: 70.650 	Loss: 1.0351
#  Client2 Train => Local Epoch: 2 	Acc: 71.419 	Loss: 1.0018
#  Client2 Train => Local Epoch: 3 	Acc: 72.786 	Loss: 0.9776
#  Client2 Train => Local Epoch: 4 	Acc: 73.593 	Loss: 0.9526
#  Client2 Test =>                   	Acc: 62.958 	Loss: 1.2186
#  Client0 Train => Local Epoch: 0 	Acc: 62.005 	Loss: 1.2113
#  Client0 Train => Local Epoch: 1 	Acc: 67.886 	Loss: 1.1195
#  Client0 Train => Local Epoch: 2 	Acc: 68.695 	Loss: 1.0538
#  Client0 Train => Local Epoch: 3 	Acc: 70.258 	Loss: 1.0482
#  Client0 Train => Local Epoch: 4 	Acc: 69.867 	Loss: 1.0551
#  Client0 Test =>                   	Acc: 53.273 	Loss: 1.4235
#  Client1 Train => Local Epoch: 0 	Acc: 72.470 	Loss: 1.0770
#  Client1 Train => Local Epoch: 1 	Acc: 76.483 	Loss: 0.9387
#  Client1 Train => Local Epoch: 2 	Acc: 79.208 	Loss: 0.8586
#  Client1 Train => Local Epoch: 3 	Acc: 78.777 	Loss: 0.8409
#  Client1 Train => Local Epoch: 4 	Acc: 78.853 	Loss: 0.8430
#  Client1 Test =>                   	Acc: 46.680 	Loss: 1.6831
#  Client3 Train => Local Epoch: 0 	Acc: 59.377 	Loss: 1.4386
#  Client3 Train => Local Epoch: 1 	Acc: 66.355 	Loss: 1.1309
#  Client3 Train => Local Epoch: 2 	Acc: 66.840 	Loss: 1.1263
#  Client3 Train => Local Epoch: 3 	Acc: 65.571 	Loss: 1.1345
#  Client3 Train => Local Epoch: 4 	Acc: 68.252 	Loss: 1.0985
#  Client3 Test =>                   	Acc: 53.236 	Loss: 1.5287
#  Client4 Train => Local Epoch: 0 	Acc: 62.883 	Loss: 1.3026
#  Client4 Train => Local Epoch: 1 	Acc: 67.829 	Loss: 1.1208
#  Client4 Train => Local Epoch: 2 	Acc: 68.963 	Loss: 1.0816
#  Client4 Train => Local Epoch: 3 	Acc: 70.809 	Loss: 1.0332
#  Client4 Train => Local Epoch: 4 	Acc: 71.197 	Loss: 1.0352
#  Client4 Test =>                   	Acc: 53.263 	Loss: 1.4763
#  Client8 Train => Local Epoch: 0 	Acc: 61.934 	Loss: 1.2576
#  Client8 Train => Local Epoch: 1 	Acc: 67.780 	Loss: 1.0870
#  Client8 Train => Local Epoch: 2 	Acc: 68.587 	Loss: 1.0488
#  Client8 Train => Local Epoch: 3 	Acc: 68.886 	Loss: 1.0233
#  Client8 Train => Local Epoch: 4 	Acc: 69.653 	Loss: 1.0109
#  Client8 Test =>                   	Acc: 50.623 	Loss: 1.6494
# ====================== SERVER V1==========================
#  Train: Round   6, Avg Accuracy 71.280 | Avg Loss 1.011
#  Test: Round   6, Avg Accuracy 54.019 | Avg Loss 1.465
# Forgetting : Round 6, mean_forgetting : -0.176
# ==========================================================
#  Client5 Train => Local Epoch: 0 	Acc: 62.099 	Loss: 1.3118
#  Client5 Train => Local Epoch: 1 	Acc: 65.343 	Loss: 1.1515
#  Client5 Train => Local Epoch: 2 	Acc: 67.220 	Loss: 1.1103
#  Client5 Train => Local Epoch: 3 	Acc: 68.598 	Loss: 1.0851
#  Client5 Train => Local Epoch: 4 	Acc: 69.237 	Loss: 1.0697
#  Client5 Test =>                   	Acc: 62.668 	Loss: 1.1929
#  Client3 Train => Local Epoch: 0 	Acc: 60.791 	Loss: 1.3582
#  Client3 Train => Local Epoch: 1 	Acc: 67.081 	Loss: 1.1168
#  Client3 Train => Local Epoch: 2 	Acc: 68.299 	Loss: 1.0856
#  Client3 Train => Local Epoch: 3 	Acc: 68.597 	Loss: 1.0661
#  Client3 Train => Local Epoch: 4 	Acc: 70.231 	Loss: 1.0603
#  Client3 Test =>                   	Acc: 57.173 	Loss: 1.4441
#  Client0 Train => Local Epoch: 0 	Acc: 65.726 	Loss: 1.2197
#  Client0 Train => Local Epoch: 1 	Acc: 68.390 	Loss: 1.1426
#  Client0 Train => Local Epoch: 2 	Acc: 71.543 	Loss: 1.0432
#  Client0 Train => Local Epoch: 3 	Acc: 71.778 	Loss: 1.0134
#  Client0 Train => Local Epoch: 4 	Acc: 72.488 	Loss: 0.9906
#  Client0 Test =>                   	Acc: 57.452 	Loss: 1.3116
#  Client8 Train => Local Epoch: 0 	Acc: 60.870 	Loss: 1.3518
#  Client8 Train => Local Epoch: 1 	Acc: 68.207 	Loss: 1.0687
#  Client8 Train => Local Epoch: 2 	Acc: 69.215 	Loss: 1.0009
#  Client8 Train => Local Epoch: 3 	Acc: 70.489 	Loss: 0.9898
#  Client8 Train => Local Epoch: 4 	Acc: 71.159 	Loss: 0.9633
#  Client8 Test =>                   	Acc: 51.795 	Loss: 1.5340
#  Client2 Train => Local Epoch: 0 	Acc: 65.124 	Loss: 1.2275
#  Client2 Train => Local Epoch: 1 	Acc: 72.228 	Loss: 0.9851
#  Client2 Train => Local Epoch: 2 	Acc: 73.149 	Loss: 0.9545
#  Client2 Train => Local Epoch: 3 	Acc: 75.059 	Loss: 0.9220
#  Client2 Train => Local Epoch: 4 	Acc: 76.036 	Loss: 0.8947
#  Client2 Test =>                   	Acc: 62.716 	Loss: 1.2280
#  Client6 Train => Local Epoch: 0 	Acc: 64.918 	Loss: 1.2070
#  Client6 Train => Local Epoch: 1 	Acc: 68.458 	Loss: 1.0655
#  Client6 Train => Local Epoch: 2 	Acc: 69.766 	Loss: 1.0346
#  Client6 Train => Local Epoch: 3 	Acc: 69.654 	Loss: 1.0362
#  Client6 Train => Local Epoch: 4 	Acc: 70.516 	Loss: 1.0107
#  Client6 Test =>                   	Acc: 58.873 	Loss: 1.3070
#  Client7 Train => Local Epoch: 0 	Acc: 69.362 	Loss: 1.1547
#  Client7 Train => Local Epoch: 1 	Acc: 73.509 	Loss: 0.9892
#  Client7 Train => Local Epoch: 2 	Acc: 75.266 	Loss: 0.9143
#  Client7 Train => Local Epoch: 3 	Acc: 75.705 	Loss: 0.9011
#  Client7 Train => Local Epoch: 4 	Acc: 76.022 	Loss: 0.8944
#  Client7 Test =>                   	Acc: 53.411 	Loss: 1.5015
#  Client4 Train => Local Epoch: 0 	Acc: 65.371 	Loss: 1.2431
#  Client4 Train => Local Epoch: 1 	Acc: 68.199 	Loss: 1.1726
#  Client4 Train => Local Epoch: 2 	Acc: 69.679 	Loss: 1.0530
#  Client4 Train => Local Epoch: 3 	Acc: 73.200 	Loss: 0.9974
#  Client4 Train => Local Epoch: 4 	Acc: 73.259 	Loss: 0.9783
#  Client4 Test =>                   	Acc: 54.933 	Loss: 1.5047
#  Client1 Train => Local Epoch: 0 	Acc: 74.469 	Loss: 0.9904
#  Client1 Train => Local Epoch: 1 	Acc: 78.029 	Loss: 0.8956
#  Client1 Train => Local Epoch: 2 	Acc: 80.139 	Loss: 0.8320
#  Client1 Train => Local Epoch: 3 	Acc: 80.508 	Loss: 0.7959
#  Client1 Train => Local Epoch: 4 	Acc: 82.095 	Loss: 0.7683
#  Client1 Test =>                   	Acc: 47.353 	Loss: 1.7187
#  Client9 Train => Local Epoch: 0 	Acc: 64.054 	Loss: 1.2729
#  Client9 Train => Local Epoch: 1 	Acc: 64.250 	Loss: 1.1846
#  Client9 Train => Local Epoch: 2 	Acc: 65.599 	Loss: 1.1381
#  Client9 Train => Local Epoch: 3 	Acc: 67.413 	Loss: 1.0906
#  Client9 Train => Local Epoch: 4 	Acc: 69.383 	Loss: 1.0422
#  Client9 Test =>                   	Acc: 63.338 	Loss: 1.2030
# ====================== SERVER V1==========================
#  Train: Round   7, Avg Accuracy 73.043 | Avg Loss 0.967
#  Test: Round   7, Avg Accuracy 56.971 | Avg Loss 1.395
# Forgetting : Round 7, mean_forgetting : -0.402
# ==========================================================
#  Client8 Train => Local Epoch: 0 	Acc: 65.450 	Loss: 1.1638
#  Client8 Train => Local Epoch: 1 	Acc: 69.332 	Loss: 1.0452
#  Client8 Train => Local Epoch: 2 	Acc: 71.836 	Loss: 0.9637
#  Client8 Train => Local Epoch: 3 	Acc: 73.141 	Loss: 0.9255
#  Client8 Train => Local Epoch: 4 	Acc: 72.126 	Loss: 0.9423
#  Client8 Test =>                   	Acc: 55.041 	Loss: 1.4324
#  Client4 Train => Local Epoch: 0 	Acc: 63.339 	Loss: 1.3592
#  Client4 Train => Local Epoch: 1 	Acc: 69.817 	Loss: 1.1034
#  Client4 Train => Local Epoch: 2 	Acc: 72.887 	Loss: 0.9851
#  Client4 Train => Local Epoch: 3 	Acc: 73.262 	Loss: 0.9864
#  Client4 Train => Local Epoch: 4 	Acc: 74.873 	Loss: 0.9515
#  Client4 Test =>                   	Acc: 57.681 	Loss: 1.4208
#  Client0 Train => Local Epoch: 0 	Acc: 68.816 	Loss: 1.0886
#  Client0 Train => Local Epoch: 1 	Acc: 71.408 	Loss: 1.0345
#  Client0 Train => Local Epoch: 2 	Acc: 73.333 	Loss: 0.9603
#  Client0 Train => Local Epoch: 3 	Acc: 74.391 	Loss: 0.9579
#  Client0 Train => Local Epoch: 4 	Acc: 75.130 	Loss: 0.9316
#  Client0 Test =>                   	Acc: 63.837 	Loss: 1.1995
#  Client2 Train => Local Epoch: 0 	Acc: 72.245 	Loss: 1.0075
#  Client2 Train => Local Epoch: 1 	Acc: 74.831 	Loss: 0.9457
#  Client2 Train => Local Epoch: 2 	Acc: 74.982 	Loss: 0.9214
#  Client2 Train => Local Epoch: 3 	Acc: 75.724 	Loss: 0.8998
#  Client2 Train => Local Epoch: 4 	Acc: 76.486 	Loss: 0.8849
#  Client2 Test =>                   	Acc: 64.093 	Loss: 1.1562
#  Client1 Train => Local Epoch: 0 	Acc: 73.878 	Loss: 1.0139
#  Client1 Train => Local Epoch: 1 	Acc: 78.218 	Loss: 0.8957
#  Client1 Train => Local Epoch: 2 	Acc: 80.437 	Loss: 0.8001
#  Client1 Train => Local Epoch: 3 	Acc: 82.081 	Loss: 0.7745
#  Client1 Train => Local Epoch: 4 	Acc: 82.477 	Loss: 0.7570
#  Client1 Test =>                   	Acc: 50.636 	Loss: 1.5702
#  Client3 Train => Local Epoch: 0 	Acc: 60.829 	Loss: 1.4008
#  Client3 Train => Local Epoch: 1 	Acc: 67.956 	Loss: 1.1105
#  Client3 Train => Local Epoch: 2 	Acc: 68.878 	Loss: 1.0789
#  Client3 Train => Local Epoch: 3 	Acc: 70.762 	Loss: 1.0392
#  Client3 Train => Local Epoch: 4 	Acc: 70.668 	Loss: 1.0323
#  Client3 Test =>                   	Acc: 53.724 	Loss: 1.5438
#  Client9 Train => Local Epoch: 0 	Acc: 67.645 	Loss: 1.1376
#  Client9 Train => Local Epoch: 1 	Acc: 67.821 	Loss: 1.0774
#  Client9 Train => Local Epoch: 2 	Acc: 71.279 	Loss: 1.0235
#  Client9 Train => Local Epoch: 3 	Acc: 69.793 	Loss: 1.0496
#  Client9 Train => Local Epoch: 4 	Acc: 69.861 	Loss: 1.0482
#  Client9 Test =>                   	Acc: 65.383 	Loss: 1.1692
#  Client5 Train => Local Epoch: 0 	Acc: 65.971 	Loss: 1.1318
#  Client5 Train => Local Epoch: 1 	Acc: 68.026 	Loss: 1.0855
#  Client5 Train => Local Epoch: 2 	Acc: 67.941 	Loss: 1.0821
#  Client5 Train => Local Epoch: 3 	Acc: 68.002 	Loss: 1.0834
#  Client5 Train => Local Epoch: 4 	Acc: 70.743 	Loss: 1.0332
#  Client5 Test =>                   	Acc: 66.733 	Loss: 1.1208
#  Client7 Train => Local Epoch: 0 	Acc: 69.486 	Loss: 1.1136
#  Client7 Train => Local Epoch: 1 	Acc: 75.071 	Loss: 0.9221
#  Client7 Train => Local Epoch: 2 	Acc: 76.033 	Loss: 0.8858
#  Client7 Train => Local Epoch: 3 	Acc: 76.401 	Loss: 0.8717
#  Client7 Train => Local Epoch: 4 	Acc: 77.226 	Loss: 0.8601
#  Client7 Test =>                   	Acc: 52.542 	Loss: 1.5453
#  Client6 Train => Local Epoch: 0 	Acc: 63.439 	Loss: 1.2878
#  Client6 Train => Local Epoch: 1 	Acc: 70.064 	Loss: 1.0297
#  Client6 Train => Local Epoch: 2 	Acc: 71.518 	Loss: 1.0001
#  Client6 Train => Local Epoch: 3 	Acc: 72.100 	Loss: 0.9919
#  Client6 Train => Local Epoch: 4 	Acc: 72.679 	Loss: 0.9725
#  Client6 Test =>                   	Acc: 61.571 	Loss: 1.2439
# ====================== SERVER V1==========================
#  Train: Round   8, Avg Accuracy 74.227 | Avg Loss 0.941
#  Test: Round   8, Avg Accuracy 59.124 | Avg Loss 1.340
# Forgetting : Round 8, mean_forgetting : -0.371
# ==========================================================
#  Client3 Train => Local Epoch: 0 	Acc: 63.886 	Loss: 1.2869
#  Client3 Train => Local Epoch: 1 	Acc: 69.262 	Loss: 1.0730
#  Client3 Train => Local Epoch: 2 	Acc: 71.190 	Loss: 1.0238
#  Client3 Train => Local Epoch: 3 	Acc: 71.313 	Loss: 1.0163
#  Client3 Train => Local Epoch: 4 	Acc: 72.371 	Loss: 0.9825
#  Client3 Test =>                   	Acc: 59.715 	Loss: 1.3216
#  Client4 Train => Local Epoch: 0 	Acc: 68.014 	Loss: 1.1289
#  Client4 Train => Local Epoch: 1 	Acc: 72.519 	Loss: 1.0127
#  Client4 Train => Local Epoch: 2 	Acc: 74.599 	Loss: 0.9510
#  Client4 Train => Local Epoch: 3 	Acc: 75.879 	Loss: 0.9101
#  Client4 Train => Local Epoch: 4 	Acc: 77.661 	Loss: 0.8869
#  Client4 Test =>                   	Acc: 59.968 	Loss: 1.3643
#  Client0 Train => Local Epoch: 0 	Acc: 70.834 	Loss: 1.0510
#  Client0 Train => Local Epoch: 1 	Acc: 74.142 	Loss: 0.9621
#  Client0 Train => Local Epoch: 2 	Acc: 74.249 	Loss: 0.9413
#  Client0 Train => Local Epoch: 3 	Acc: 77.452 	Loss: 0.9015
#  Client0 Train => Local Epoch: 4 	Acc: 75.442 	Loss: 0.9169
#  Client0 Test =>                   	Acc: 61.715 	Loss: 1.2137
#  Client2 Train => Local Epoch: 0 	Acc: 73.086 	Loss: 0.9926
#  Client2 Train => Local Epoch: 1 	Acc: 76.343 	Loss: 0.9077
#  Client2 Train => Local Epoch: 2 	Acc: 76.501 	Loss: 0.8871
#  Client2 Train => Local Epoch: 3 	Acc: 77.630 	Loss: 0.8582
#  Client2 Train => Local Epoch: 4 	Acc: 79.159 	Loss: 0.8374
#  Client2 Test =>                   	Acc: 67.972 	Loss: 1.0826
#  Client5 Train => Local Epoch: 0 	Acc: 67.041 	Loss: 1.1134
#  Client5 Train => Local Epoch: 1 	Acc: 69.894 	Loss: 1.0373
#  Client5 Train => Local Epoch: 2 	Acc: 70.282 	Loss: 1.0340
#  Client5 Train => Local Epoch: 3 	Acc: 71.562 	Loss: 1.0020
#  Client5 Train => Local Epoch: 4 	Acc: 72.266 	Loss: 0.9910
#  Client5 Test =>                   	Acc: 65.962 	Loss: 1.1290
#  Client9 Train => Local Epoch: 0 	Acc: 69.678 	Loss: 1.0386
#  Client9 Train => Local Epoch: 1 	Acc: 67.942 	Loss: 1.0728
#  Client9 Train => Local Epoch: 2 	Acc: 69.540 	Loss: 1.0399
#  Client9 Train => Local Epoch: 3 	Acc: 69.810 	Loss: 1.0266
#  Client9 Train => Local Epoch: 4 	Acc: 72.198 	Loss: 0.9897
#  Client9 Test =>                   	Acc: 67.120 	Loss: 1.1113
#  Client7 Train => Local Epoch: 0 	Acc: 69.161 	Loss: 1.1296
#  Client7 Train => Local Epoch: 1 	Acc: 75.925 	Loss: 0.9090
#  Client7 Train => Local Epoch: 2 	Acc: 77.553 	Loss: 0.8606
#  Client7 Train => Local Epoch: 3 	Acc: 78.023 	Loss: 0.8491
#  Client7 Train => Local Epoch: 4 	Acc: 79.017 	Loss: 0.8315
#  Client7 Test =>                   	Acc: 56.041 	Loss: 1.4499
#  Client1 Train => Local Epoch: 0 	Acc: 70.704 	Loss: 1.2799
#  Client1 Train => Local Epoch: 1 	Acc: 77.757 	Loss: 1.0109
#  Client1 Train => Local Epoch: 2 	Acc: 80.798 	Loss: 0.8199
#  Client1 Train => Local Epoch: 3 	Acc: 81.582 	Loss: 0.7679
#  Client1 Train => Local Epoch: 4 	Acc: 82.653 	Loss: 0.7389
#  Client1 Test =>                   	Acc: 57.536 	Loss: 1.3675
#  Client8 Train => Local Epoch: 0 	Acc: 65.282 	Loss: 1.1825
#  Client8 Train => Local Epoch: 1 	Acc: 71.900 	Loss: 1.0339
#  Client8 Train => Local Epoch: 2 	Acc: 72.750 	Loss: 0.9698
#  Client8 Train => Local Epoch: 3 	Acc: 73.724 	Loss: 0.9415
#  Client8 Train => Local Epoch: 4 	Acc: 76.002 	Loss: 0.9057
#  Client8 Test =>                   	Acc: 55.442 	Loss: 1.8233
#  Client6 Train => Local Epoch: 0 	Acc: 69.298 	Loss: 1.1004
#  Client6 Train => Local Epoch: 1 	Acc: 71.579 	Loss: 0.9987
#  Client6 Train => Local Epoch: 2 	Acc: 73.177 	Loss: 0.9725
#  Client6 Train => Local Epoch: 3 	Acc: 73.623 	Loss: 0.9556
#  Client6 Train => Local Epoch: 4 	Acc: 73.371 	Loss: 0.9534
#  Client6 Test =>                   	Acc: 61.328 	Loss: 1.2658
# ====================== SERVER V1==========================
#  Train: Round   9, Avg Accuracy 76.014 | Avg Loss 0.903
#  Test: Round   9, Avg Accuracy 61.280 | Avg Loss 1.313
# Forgetting : Round 9, mean_forgetting : -0.396
# ==========================================================
#  Client4 Train => Local Epoch: 0 	Acc: 69.244 	Loss: 1.1327
#  Client4 Train => Local Epoch: 1 	Acc: 73.893 	Loss: 0.9766
#  Client4 Train => Local Epoch: 2 	Acc: 75.726 	Loss: 0.9336
#  Client4 Train => Local Epoch: 3 	Acc: 76.457 	Loss: 0.8967
#  Client4 Train => Local Epoch: 4 	Acc: 77.522 	Loss: 0.8684
#  Client4 Test =>                   	Acc: 61.884 	Loss: 1.2644
#  Client2 Train => Local Epoch: 0 	Acc: 74.847 	Loss: 0.9601
#  Client2 Train => Local Epoch: 1 	Acc: 77.954 	Loss: 0.8593
#  Client2 Train => Local Epoch: 2 	Acc: 77.740 	Loss: 0.8548
#  Client2 Train => Local Epoch: 3 	Acc: 78.792 	Loss: 0.8321
#  Client2 Train => Local Epoch: 4 	Acc: 79.167 	Loss: 0.8166
#  Client2 Test =>                   	Acc: 68.188 	Loss: 1.0584
#  Client9 Train => Local Epoch: 0 	Acc: 70.208 	Loss: 1.0371
#  Client9 Train => Local Epoch: 1 	Acc: 69.781 	Loss: 1.0251
#  Client9 Train => Local Epoch: 2 	Acc: 70.573 	Loss: 1.0142
#  Client9 Train => Local Epoch: 3 	Acc: 72.107 	Loss: 0.9802
#  Client9 Train => Local Epoch: 4 	Acc: 72.790 	Loss: 0.9604
#  Client9 Test =>                   	Acc: 66.164 	Loss: 1.1159
#  Client0 Train => Local Epoch: 0 	Acc: 70.464 	Loss: 1.0682
#  Client0 Train => Local Epoch: 1 	Acc: 73.454 	Loss: 0.9834
#  Client0 Train => Local Epoch: 2 	Acc: 76.657 	Loss: 0.9113
#  Client0 Train => Local Epoch: 3 	Acc: 77.168 	Loss: 0.8839
#  Client0 Train => Local Epoch: 4 	Acc: 77.260 	Loss: 0.8920
#  Client0 Test =>                   	Acc: 66.612 	Loss: 1.1171
#  Client7 Train => Local Epoch: 0 	Acc: 73.977 	Loss: 0.9872
#  Client7 Train => Local Epoch: 1 	Acc: 77.617 	Loss: 0.8677
#  Client7 Train => Local Epoch: 2 	Acc: 79.169 	Loss: 0.8218
#  Client7 Train => Local Epoch: 3 	Acc: 78.749 	Loss: 0.8309
#  Client7 Train => Local Epoch: 4 	Acc: 79.702 	Loss: 0.8029
#  Client7 Test =>                   	Acc: 57.967 	Loss: 1.3631
#  Client6 Train => Local Epoch: 0 	Acc: 66.516 	Loss: 1.1814
#  Client6 Train => Local Epoch: 1 	Acc: 72.505 	Loss: 0.9816
#  Client6 Train => Local Epoch: 2 	Acc: 73.090 	Loss: 0.9609
#  Client6 Train => Local Epoch: 3 	Acc: 74.214 	Loss: 0.9323
#  Client6 Train => Local Epoch: 4 	Acc: 74.981 	Loss: 0.9146
#  Client6 Test =>                   	Acc: 66.703 	Loss: 1.1599
#  Client3 Train => Local Epoch: 0 	Acc: 64.433 	Loss: 1.2875
#  Client3 Train => Local Epoch: 1 	Acc: 70.426 	Loss: 1.0396
#  Client3 Train => Local Epoch: 2 	Acc: 71.315 	Loss: 1.0134
#  Client3 Train => Local Epoch: 3 	Acc: 72.653 	Loss: 0.9704
#  Client3 Train => Local Epoch: 4 	Acc: 73.857 	Loss: 0.9355
#  Client3 Test =>                   	Acc: 61.574 	Loss: 1.3044
#  Client8 Train => Local Epoch: 0 	Acc: 66.671 	Loss: 1.1535
#  Client8 Train => Local Epoch: 1 	Acc: 71.702 	Loss: 1.0010
#  Client8 Train => Local Epoch: 2 	Acc: 74.282 	Loss: 0.9208
#  Client8 Train => Local Epoch: 3 	Acc: 75.230 	Loss: 0.8789
#  Client8 Train => Local Epoch: 4 	Acc: 75.774 	Loss: 0.8714
#  Client8 Test =>                   	Acc: 58.968 	Loss: 1.3367
#  Client1 Train => Local Epoch: 0 	Acc: 69.755 	Loss: 1.3714
#  Client1 Train => Local Epoch: 1 	Acc: 75.750 	Loss: 1.0030
#  Client1 Train => Local Epoch: 2 	Acc: 79.995 	Loss: 0.8405
#  Client1 Train => Local Epoch: 3 	Acc: 81.487 	Loss: 0.7794
#  Client1 Train => Local Epoch: 4 	Acc: 83.435 	Loss: 0.7433
#  Client1 Test =>                   	Acc: 59.207 	Loss: 1.3475
#  Client5 Train => Local Epoch: 0 	Acc: 64.303 	Loss: 1.2140
#  Client5 Train => Local Epoch: 1 	Acc: 70.642 	Loss: 1.0431
#  Client5 Train => Local Epoch: 2 	Acc: 72.178 	Loss: 0.9965
#  Client5 Train => Local Epoch: 3 	Acc: 73.082 	Loss: 0.9695
#  Client5 Train => Local Epoch: 4 	Acc: 73.662 	Loss: 0.9529
#  Client5 Test =>                   	Acc: 67.073 	Loss: 1.1648
# ====================== SERVER V1==========================
#  Train: Round  10, Avg Accuracy 76.815 | Avg Loss 0.876
#  Test: Round  10, Avg Accuracy 63.434 | Avg Loss 1.223
# Forgetting : Round 10, mean_forgetting : -0.453
# ==========================================================
#  Client9 Train => Local Epoch: 0 	Acc: 74.146 	Loss: 0.9502
#  Client9 Train => Local Epoch: 1 	Acc: 73.260 	Loss: 0.9614
#  Client9 Train => Local Epoch: 2 	Acc: 76.086 	Loss: 0.8878
#  Client9 Train => Local Epoch: 3 	Acc: 76.237 	Loss: 0.8910
#  Client9 Train => Local Epoch: 4 	Acc: 75.047 	Loss: 0.9195
#  Client9 Test =>                   	Acc: 68.070 	Loss: 1.1273
#  Client4 Train => Local Epoch: 0 	Acc: 70.325 	Loss: 1.1055
#  Client4 Train => Local Epoch: 1 	Acc: 76.340 	Loss: 0.9452
#  Client4 Train => Local Epoch: 2 	Acc: 77.196 	Loss: 0.9009
#  Client4 Train => Local Epoch: 3 	Acc: 78.921 	Loss: 0.8518
#  Client4 Train => Local Epoch: 4 	Acc: 78.498 	Loss: 0.8414
#  Client4 Test =>                   	Acc: 64.736 	Loss: 1.1945
# ...
# ====================== SERVER V1==========================
#  Train: Round  95, Avg Accuracy 95.830 | Avg Loss 0.416
#  Test: Round  95, Avg Accuracy 90.498 | Avg Loss 0.542
# Forgetting : Round 95, mean_forgetting : -0.288
# ==========================================================
#  Client9 Train => Local Epoch: 0 	Acc: 93.991 	Loss: 0.4627
#  Client9 Train => Local Epoch: 1 	Acc: 94.101 	Loss: 0.4534
#  Client9 Train => Local Epoch: 2 	Acc: 93.469 	Loss: 0.4666
#  Client9 Train => Local Epoch: 3 	Acc: 92.865 	Loss: 0.4877
#  Client9 Train => Local Epoch: 4 	Acc: 94.083 	Loss: 0.4490
#  Client9 Test =>                   	Acc: 91.719 	Loss: 0.4951
#  Client3 Train => Local Epoch: 0 	Acc: 89.914 	Loss: 0.5773
#  Client3 Train => Local Epoch: 1 	Acc: 93.013 	Loss: 0.4789
#  Client3 Train => Local Epoch: 2 	Acc: 94.108 	Loss: 0.4662
#  Client3 Train => Local Epoch: 3 	Acc: 94.506 	Loss: 0.4488
#  Client3 Train => Local Epoch: 4 	Acc: 94.164 	Loss: 0.4533
#  Client3 Test =>                   	Acc: 90.726 	Loss: 0.5484
#  Client8 Train => Local Epoch: 0 	Acc: 90.717 	Loss: 0.5431
#  Client8 Train => Local Epoch: 1 	Acc: 93.495 	Loss: 0.4580
#  Client8 Train => Local Epoch: 2 	Acc: 95.093 	Loss: 0.4416
#  Client8 Train => Local Epoch: 3 	Acc: 95.968 	Loss: 0.4128
#  Client8 Train => Local Epoch: 4 	Acc: 95.503 	Loss: 0.4168
#  Client8 Test =>                   	Acc: 89.100 	Loss: 0.5699
#  Client4 Train => Local Epoch: 0 	Acc: 92.932 	Loss: 0.4981
#  Client4 Train => Local Epoch: 1 	Acc: 94.825 	Loss: 0.4402
#  Client4 Train => Local Epoch: 2 	Acc: 96.179 	Loss: 0.4164
#  Client4 Train => Local Epoch: 3 	Acc: 96.450 	Loss: 0.4074
#  Client4 Train => Local Epoch: 4 	Acc: 97.161 	Loss: 0.3881
#  Client4 Test =>                   	Acc: 90.588 	Loss: 0.5329
#  Client7 Train => Local Epoch: 0 	Acc: 89.796 	Loss: 0.5746
#  Client7 Train => Local Epoch: 1 	Acc: 94.467 	Loss: 0.4488
#  Client7 Train => Local Epoch: 2 	Acc: 96.333 	Loss: 0.4110
#  Client7 Train => Local Epoch: 3 	Acc: 96.672 	Loss: 0.3971
#  Client7 Train => Local Epoch: 4 	Acc: 96.941 	Loss: 0.3876
#  Client7 Test =>                   	Acc: 91.379 	Loss: 0.5335
#  Client2 Train => Local Epoch: 0 	Acc: 94.645 	Loss: 0.4486
#  Client2 Train => Local Epoch: 1 	Acc: 96.297 	Loss: 0.4060
#  Client2 Train => Local Epoch: 2 	Acc: 96.688 	Loss: 0.3948
#  Client2 Train => Local Epoch: 3 	Acc: 96.943 	Loss: 0.3878
#  Client2 Train => Local Epoch: 4 	Acc: 97.210 	Loss: 0.3805
#  Client2 Test =>                   	Acc: 90.470 	Loss: 0.5178
#  Client1 Train => Local Epoch: 0 	Acc: 90.544 	Loss: 0.5640
#  Client1 Train => Local Epoch: 1 	Acc: 95.082 	Loss: 0.4265
#  Client1 Train => Local Epoch: 2 	Acc: 95.739 	Loss: 0.4049
#  Client1 Train => Local Epoch: 3 	Acc: 97.499 	Loss: 0.3804
#  Client1 Train => Local Epoch: 4 	Acc: 97.825 	Loss: 0.3672
#  Client1 Test =>                   	Acc: 90.238 	Loss: 0.5478
#  Client0 Train => Local Epoch: 0 	Acc: 93.942 	Loss: 0.4565
#  Client0 Train => Local Epoch: 1 	Acc: 96.151 	Loss: 0.4103
#  Client0 Train => Local Epoch: 2 	Acc: 96.165 	Loss: 0.4057
#  Client0 Train => Local Epoch: 3 	Acc: 96.570 	Loss: 0.4016
#  Client0 Train => Local Epoch: 4 	Acc: 96.769 	Loss: 0.3967
#  Client0 Test =>                   	Acc: 90.979 	Loss: 0.5242
#  Client5 Train => Local Epoch: 0 	Acc: 93.888 	Loss: 0.4618
#  Client5 Train => Local Epoch: 1 	Acc: 95.266 	Loss: 0.4313
#  Client5 Train => Local Epoch: 2 	Acc: 95.371 	Loss: 0.4279
#  Client5 Train => Local Epoch: 3 	Acc: 95.801 	Loss: 0.4174
#  Client5 Train => Local Epoch: 4 	Acc: 95.679 	Loss: 0.4200
#  Client5 Test =>                   	Acc: 90.140 	Loss: 0.5584
#  Client6 Train => Local Epoch: 0 	Acc: 92.155 	Loss: 0.5015
#  Client6 Train => Local Epoch: 1 	Acc: 95.157 	Loss: 0.4347
#  Client6 Train => Local Epoch: 2 	Acc: 95.292 	Loss: 0.4314
#  Client6 Train => Local Epoch: 3 	Acc: 95.123 	Loss: 0.4337
#  Client6 Train => Local Epoch: 4 	Acc: 95.810 	Loss: 0.4212
#  Client6 Test =>                   	Acc: 89.140 	Loss: 0.5527
# ====================== SERVER V1==========================
#  Train: Round  96, Avg Accuracy 96.114 | Avg Loss 0.408
#  Test: Round  96, Avg Accuracy 90.448 | Avg Loss 0.538
# Forgetting : Round 96, mean_forgetting : -0.285
# ==========================================================
#  Client5 Train => Local Epoch: 0 	Acc: 93.680 	Loss: 0.4634
#  Client5 Train => Local Epoch: 1 	Acc: 95.245 	Loss: 0.4316
#  Client5 Train => Local Epoch: 2 	Acc: 95.492 	Loss: 0.4232
#  Client5 Train => Local Epoch: 3 	Acc: 95.821 	Loss: 0.4135
#  Client5 Train => Local Epoch: 4 	Acc: 96.419 	Loss: 0.4080
#  Client5 Test =>                   	Acc: 91.029 	Loss: 0.5495
#  Client7 Train => Local Epoch: 0 	Acc: 90.856 	Loss: 0.5390
#  Client7 Train => Local Epoch: 1 	Acc: 95.261 	Loss: 0.4265
#  Client7 Train => Local Epoch: 2 	Acc: 96.669 	Loss: 0.3946
#  Client7 Train => Local Epoch: 3 	Acc: 96.533 	Loss: 0.3945
#  Client7 Train => Local Epoch: 4 	Acc: 96.795 	Loss: 0.3869
#  Client7 Test =>                   	Acc: 91.282 	Loss: 0.5337
#  Client8 Train => Local Epoch: 0 	Acc: 90.781 	Loss: 0.5384
#  Client8 Train => Local Epoch: 1 	Acc: 94.947 	Loss: 0.4367
#  Client8 Train => Local Epoch: 2 	Acc: 96.058 	Loss: 0.4122
#  Client8 Train => Local Epoch: 3 	Acc: 96.389 	Loss: 0.4041
#  Client8 Train => Local Epoch: 4 	Acc: 96.108 	Loss: 0.4028
#  Client8 Test =>                   	Acc: 88.544 	Loss: 0.5678
#  Client6 Train => Local Epoch: 0 	Acc: 93.526 	Loss: 0.4664
#  Client6 Train => Local Epoch: 1 	Acc: 94.698 	Loss: 0.4399
#  Client6 Train => Local Epoch: 2 	Acc: 95.303 	Loss: 0.4258
#  Client6 Train => Local Epoch: 3 	Acc: 95.548 	Loss: 0.4231
#  Client6 Train => Local Epoch: 4 	Acc: 95.818 	Loss: 0.4192
#  Client6 Test =>                   	Acc: 90.127 	Loss: 0.5601
#  Client2 Train => Local Epoch: 0 	Acc: 94.754 	Loss: 0.4433
#  Client2 Train => Local Epoch: 1 	Acc: 96.132 	Loss: 0.4028
#  Client2 Train => Local Epoch: 2 	Acc: 96.229 	Loss: 0.3993
#  Client2 Train => Local Epoch: 3 	Acc: 96.667 	Loss: 0.3873
#  Client2 Train => Local Epoch: 4 	Acc: 96.984 	Loss: 0.3861
#  Client2 Test =>                   	Acc: 90.881 	Loss: 0.5179
#  Client1 Train => Local Epoch: 0 	Acc: 90.568 	Loss: 0.5623
#  Client1 Train => Local Epoch: 1 	Acc: 94.933 	Loss: 0.4322
#  Client1 Train => Local Epoch: 2 	Acc: 96.873 	Loss: 0.3916
#  Client1 Train => Local Epoch: 3 	Acc: 96.989 	Loss: 0.3831
#  Client1 Train => Local Epoch: 4 	Acc: 97.518 	Loss: 0.3751
#  Client1 Test =>                   	Acc: 90.228 	Loss: 0.5483
#  Client0 Train => Local Epoch: 0 	Acc: 94.702 	Loss: 0.4457
#  Client0 Train => Local Epoch: 1 	Acc: 95.746 	Loss: 0.4175
#  Client0 Train => Local Epoch: 2 	Acc: 96.059 	Loss: 0.4130
#  Client0 Train => Local Epoch: 3 	Acc: 96.712 	Loss: 0.4000
#  Client0 Train => Local Epoch: 4 	Acc: 96.897 	Loss: 0.3927
#  Client0 Test =>                   	Acc: 90.891 	Loss: 0.5239
#  Client4 Train => Local Epoch: 0 	Acc: 93.032 	Loss: 0.4784
#  Client4 Train => Local Epoch: 1 	Acc: 95.206 	Loss: 0.4263
#  Client4 Train => Local Epoch: 2 	Acc: 95.926 	Loss: 0.4149
#  Client4 Train => Local Epoch: 3 	Acc: 96.876 	Loss: 0.3979
#  Client4 Train => Local Epoch: 4 	Acc: 97.571 	Loss: 0.3833
#  Client4 Test =>                   	Acc: 90.958 	Loss: 0.5332
#  Client3 Train => Local Epoch: 0 	Acc: 90.406 	Loss: 0.5644
#  Client3 Train => Local Epoch: 1 	Acc: 93.326 	Loss: 0.4761
#  Client3 Train => Local Epoch: 2 	Acc: 94.265 	Loss: 0.4607
#  Client3 Train => Local Epoch: 3 	Acc: 94.437 	Loss: 0.4528
#  Client3 Train => Local Epoch: 4 	Acc: 94.648 	Loss: 0.4458
#  Client3 Test =>                   	Acc: 90.756 	Loss: 0.5520
#  Client9 Train => Local Epoch: 0 	Acc: 91.821 	Loss: 0.5199
#  Client9 Train => Local Epoch: 1 	Acc: 92.142 	Loss: 0.5107
#  Client9 Train => Local Epoch: 2 	Acc: 93.290 	Loss: 0.4842
#  Client9 Train => Local Epoch: 3 	Acc: 93.333 	Loss: 0.4705
#  Client9 Train => Local Epoch: 4 	Acc: 89.029 	Loss: 0.5729
#  Client9 Test =>                   	Acc: 92.012 	Loss: 0.4914
# ====================== SERVER V1==========================
#  Train: Round  97, Avg Accuracy 95.779 | Avg Loss 0.417
#  Test: Round  97, Avg Accuracy 90.671 | Avg Loss 0.538
# Forgetting : Round 97, mean_forgetting : -0.281
# ==========================================================
#  Client1 Train => Local Epoch: 0 	Acc: 91.304 	Loss: 0.5393
#  Client1 Train => Local Epoch: 1 	Acc: 95.277 	Loss: 0.4174
#  Client1 Train => Local Epoch: 2 	Acc: 96.951 	Loss: 0.3862
#  Client1 Train => Local Epoch: 3 	Acc: 96.965 	Loss: 0.3859
#  Client1 Train => Local Epoch: 4 	Acc: 97.662 	Loss: 0.3709
#  Client1 Test =>                   	Acc: 90.511 	Loss: 0.5453
#  Client4 Train => Local Epoch: 0 	Acc: 93.588 	Loss: 0.4717
#  Client4 Train => Local Epoch: 1 	Acc: 95.839 	Loss: 0.4139
#  Client4 Train => Local Epoch: 2 	Acc: 96.412 	Loss: 0.4132
#  Client4 Train => Local Epoch: 3 	Acc: 96.542 	Loss: 0.3942
#  Client4 Train => Local Epoch: 4 	Acc: 97.359 	Loss: 0.3850
#  Client4 Test =>                   	Acc: 90.958 	Loss: 0.5318
#  Client7 Train => Local Epoch: 0 	Acc: 90.808 	Loss: 0.5495
#  Client7 Train => Local Epoch: 1 	Acc: 95.238 	Loss: 0.4359
#  Client7 Train => Local Epoch: 2 	Acc: 96.209 	Loss: 0.4067
#  Client7 Train => Local Epoch: 3 	Acc: 96.817 	Loss: 0.3904
#  Client7 Train => Local Epoch: 4 	Acc: 96.925 	Loss: 0.3823
#  Client7 Test =>                   	Acc: 91.477 	Loss: 0.5394
#  Client2 Train => Local Epoch: 0 	Acc: 95.029 	Loss: 0.4338
#  Client2 Train => Local Epoch: 1 	Acc: 96.220 	Loss: 0.4049
#  Client2 Train => Local Epoch: 2 	Acc: 96.868 	Loss: 0.3873
#  Client2 Train => Local Epoch: 3 	Acc: 96.662 	Loss: 0.3918
#  Client2 Train => Local Epoch: 4 	Acc: 97.051 	Loss: 0.3814
#  Client2 Test =>                   	Acc: 90.548 	Loss: 0.5237
#  Client6 Train => Local Epoch: 0 	Acc: 92.873 	Loss: 0.4908
#  Client6 Train => Local Epoch: 1 	Acc: 94.871 	Loss: 0.4415
#  Client6 Train => Local Epoch: 2 	Acc: 95.187 	Loss: 0.4265
#  Client6 Train => Local Epoch: 3 	Acc: 95.648 	Loss: 0.4166
#  Client6 Train => Local Epoch: 4 	Acc: 95.976 	Loss: 0.4124
#  Client6 Test =>                   	Acc: 90.204 	Loss: 0.5532
#  Client0 Train => Local Epoch: 0 	Acc: 93.949 	Loss: 0.4575
#  Client0 Train => Local Epoch: 1 	Acc: 95.483 	Loss: 0.4249
#  Client0 Train => Local Epoch: 2 	Acc: 96.790 	Loss: 0.4045
#  Client0 Train => Local Epoch: 3 	Acc: 96.478 	Loss: 0.4055
#  Client0 Train => Local Epoch: 4 	Acc: 96.577 	Loss: 0.4025
#  Client0 Test =>                   	Acc: 90.568 	Loss: 0.5258
#  Client8 Train => Local Epoch: 0 	Acc: 90.917 	Loss: 0.5310
#  Client8 Train => Local Epoch: 1 	Acc: 94.747 	Loss: 0.4430
#  Client8 Train => Local Epoch: 2 	Acc: 95.060 	Loss: 0.4350
#  Client8 Train => Local Epoch: 3 	Acc: 96.074 	Loss: 0.4084
#  Client8 Train => Local Epoch: 4 	Acc: 96.205 	Loss: 0.4049
#  Client8 Test =>                   	Acc: 88.221 	Loss: 0.5766
#  Client3 Train => Local Epoch: 0 	Acc: 90.344 	Loss: 0.5609
#  Client3 Train => Local Epoch: 1 	Acc: 93.874 	Loss: 0.4617
#  Client3 Train => Local Epoch: 2 	Acc: 94.641 	Loss: 0.4510
#  Client3 Train => Local Epoch: 3 	Acc: 94.124 	Loss: 0.4574
#  Client3 Train => Local Epoch: 4 	Acc: 94.428 	Loss: 0.4444
#  Client3 Test =>                   	Acc: 90.248 	Loss: 0.5542
#  Client5 Train => Local Epoch: 0 	Acc: 93.807 	Loss: 0.4693
#  Client5 Train => Local Epoch: 1 	Acc: 95.081 	Loss: 0.4307
#  Client5 Train => Local Epoch: 2 	Acc: 95.618 	Loss: 0.4216
#  Client5 Train => Local Epoch: 3 	Acc: 95.945 	Loss: 0.4124
#  Client5 Train => Local Epoch: 4 	Acc: 96.482 	Loss: 0.4037
#  Client5 Test =>                   	Acc: 90.578 	Loss: 0.5471
#  Client9 Train => Local Epoch: 0 	Acc: 92.510 	Loss: 0.4859
#  Client9 Train => Local Epoch: 1 	Acc: 92.676 	Loss: 0.4875
#  Client9 Train => Local Epoch: 2 	Acc: 92.320 	Loss: 0.5014
#  Client9 Train => Local Epoch: 3 	Acc: 91.603 	Loss: 0.4972
#  Client9 Train => Local Epoch: 4 	Acc: 91.585 	Loss: 0.5106
#  Client9 Test =>                   	Acc: 92.208 	Loss: 0.4950
# ====================== SERVER V1==========================
#  Train: Round  98, Avg Accuracy 96.025 | Avg Loss 0.410
#  Test: Round  98, Avg Accuracy 90.552 | Avg Loss 0.539
# Forgetting : Round 98, mean_forgetting : -0.282
# ==========================================================
#  Client2 Train => Local Epoch: 0 	Acc: 95.130 	Loss: 0.4324
#  Client2 Train => Local Epoch: 1 	Acc: 96.630 	Loss: 0.4010
#  Client2 Train => Local Epoch: 2 	Acc: 96.881 	Loss: 0.3880
#  Client2 Train => Local Epoch: 3 	Acc: 97.051 	Loss: 0.3844
#  Client2 Train => Local Epoch: 4 	Acc: 97.047 	Loss: 0.3806
#  Client2 Test =>                   	Acc: 91.184 	Loss: 0.5163
#  Client3 Train => Local Epoch: 0 	Acc: 91.428 	Loss: 0.5373
#  Client3 Train => Local Epoch: 1 	Acc: 93.875 	Loss: 0.4684
#  Client3 Train => Local Epoch: 2 	Acc: 94.460 	Loss: 0.4570
#  Client3 Train => Local Epoch: 3 	Acc: 94.804 	Loss: 0.4385
#  Client3 Train => Local Epoch: 4 	Acc: 94.999 	Loss: 0.4383
#  Client3 Test =>                   	Acc: 90.346 	Loss: 0.5501
#  Client0 Train => Local Epoch: 0 	Acc: 94.198 	Loss: 0.4568
#  Client0 Train => Local Epoch: 1 	Acc: 95.412 	Loss: 0.4254
#  Client0 Train => Local Epoch: 2 	Acc: 96.620 	Loss: 0.4101
#  Client0 Train => Local Epoch: 3 	Acc: 96.811 	Loss: 0.3973
#  Client0 Train => Local Epoch: 4 	Acc: 97.252 	Loss: 0.3877
#  Client0 Test =>                   	Acc: 91.447 	Loss: 0.5238
#  Client1 Train => Local Epoch: 0 	Acc: 91.938 	Loss: 0.5265
#  Client1 Train => Local Epoch: 1 	Acc: 95.193 	Loss: 0.4232
#  Client1 Train => Local Epoch: 2 	Acc: 97.220 	Loss: 0.3848
#  Client1 Train => Local Epoch: 3 	Acc: 97.296 	Loss: 0.3796
#  Client1 Train => Local Epoch: 4 	Acc: 97.909 	Loss: 0.3721
#  Client1 Test =>                   	Acc: 90.696 	Loss: 0.5423
#  Client4 Train => Local Epoch: 0 	Acc: 93.653 	Loss: 0.4746
#  Client4 Train => Local Epoch: 1 	Acc: 95.724 	Loss: 0.4222
#  Client4 Train => Local Epoch: 2 	Acc: 95.721 	Loss: 0.4224
#  Client4 Train => Local Epoch: 3 	Acc: 96.868 	Loss: 0.3926
#  Client4 Train => Local Epoch: 4 	Acc: 96.545 	Loss: 0.3907
#  Client4 Test =>                   	Acc: 90.537 	Loss: 0.5277
#  Client6 Train => Local Epoch: 0 	Acc: 92.338 	Loss: 0.4860
#  Client6 Train => Local Epoch: 1 	Acc: 94.653 	Loss: 0.4432
#  Client6 Train => Local Epoch: 2 	Acc: 94.909 	Loss: 0.4392
#  Client6 Train => Local Epoch: 3 	Acc: 95.589 	Loss: 0.4217
#  Client6 Train => Local Epoch: 4 	Acc: 95.773 	Loss: 0.4093
#  Client6 Test =>                   	Acc: 90.039 	Loss: 0.5438
#  Client8 Train => Local Epoch: 0 	Acc: 91.862 	Loss: 0.5080
#  Client8 Train => Local Epoch: 1 	Acc: 94.894 	Loss: 0.4371
#  Client8 Train => Local Epoch: 2 	Acc: 95.601 	Loss: 0.4219
#  Client8 Train => Local Epoch: 3 	Acc: 95.901 	Loss: 0.4086
#  Client8 Train => Local Epoch: 4 	Acc: 95.852 	Loss: 0.4114
#  Client8 Test =>                   	Acc: 88.699 	Loss: 0.5754
#  Client7 Train => Local Epoch: 0 	Acc: 91.111 	Loss: 0.5461
#  Client7 Train => Local Epoch: 1 	Acc: 95.159 	Loss: 0.4336
#  Client7 Train => Local Epoch: 2 	Acc: 96.133 	Loss: 0.4088
#  Client7 Train => Local Epoch: 3 	Acc: 96.601 	Loss: 0.3949
#  Client7 Train => Local Epoch: 4 	Acc: 96.783 	Loss: 0.3860
#  Client7 Test =>                   	Acc: 91.107 	Loss: 0.5297
#  Client9 Train => Local Epoch: 0 	Acc: 92.401 	Loss: 0.4969
#  Client9 Train => Local Epoch: 1 	Acc: 92.302 	Loss: 0.4911
#  Client9 Train => Local Epoch: 2 	Acc: 94.158 	Loss: 0.4525
#  Client9 Train => Local Epoch: 3 	Acc: 92.854 	Loss: 0.4846
#  Client9 Train => Local Epoch: 4 	Acc: 93.476 	Loss: 0.4607
#  Client9 Test =>                   	Acc: 92.326 	Loss: 0.4880
#  Client5 Train => Local Epoch: 0 	Acc: 93.272 	Loss: 0.4614
#  Client5 Train => Local Epoch: 1 	Acc: 95.367 	Loss: 0.4274
#  Client5 Train => Local Epoch: 2 	Acc: 96.008 	Loss: 0.4168
#  Client5 Train => Local Epoch: 3 	Acc: 96.092 	Loss: 0.4082
#  Client5 Train => Local Epoch: 4 	Acc: 95.987 	Loss: 0.4087
#  Client5 Test =>                   	Acc: 89.884 	Loss: 0.5526
# ====================== SERVER V1==========================
#  Train: Round  99, Avg Accuracy 96.162 | Avg Loss 0.405
#  Test: Round  99, Avg Accuracy 90.626 | Avg Loss 0.535
# Forgetting : Round 99, mean_forgetting : -0.281
# ==========================================================
# Training and Evaluation completed!
# Saved: SFLV2 + Projected - CIFAR-10 α=0.5.csv
