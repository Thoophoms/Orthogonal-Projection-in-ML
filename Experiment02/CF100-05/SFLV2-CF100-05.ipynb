# %% [markdown]
# # Split Federated Learning V2:
# ### ResNet18 on CIFAR-100 + α = 0.5 - LATE-Cut (After Layer 6 + AvgPool)

# %%
#=============================================================================
# SplitfedV2 (SFLV2) learning: ResNet18 on CIFAR-100
# Version2: with using socket but no DP+PixelDP
# ==============================================================================
import torch
from torch import nn
from torchvision import transforms
from torch.utils.data import DataLoader, Dataset
import torch.nn.functional as F
import math
import os.path
import pandas as pd
from sklearn.model_selection import train_test_split
from PIL import Image
from glob import glob
from pandas import DataFrame
import random
import numpy as np
import os


import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import copy
import time


#===================================================================
program = "SFLV2 - CIFAR-100 α=0.5 - LATE-Cut (6 + AvgPool)"
DATASET_NAME = "CIFAR100"            # Set toggle between CIFAR-10 and CIFAR-100
DATA_ROOT = "data"                   # Set where torchvision stores CIFAR data
cut_at = "Late Cut at Layer 6 + AvgPool"
ALPHA = 0.5   # requested alpha


print(f"---------{program}----------")              # this is to identify the program in the slurm outputs files


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
pin = torch.cuda.is_available()


# To print in color -------test/train of the client side
def prRed(skk): print("\033[91m {}\033[00m" .format(skk)) 
def prGreen(skk): print("\033[92m {}\033[00m" .format(skk))     


#===================================================================
# No. of users
NUM_CLIENTS = 10
EPOCHS = 100
LOCAL_EPOCHS = 5
FRAC = 1        # participation of clients; if 1 then 100% clients participate in SFLV2


# ----------------------------- Optimization ------------------------------ #
BATCH_SIZE = 256
LR_BASE = 0.01  
WARMUP_ROUNDS = 0
MOMENTUM = 0.9                     # Smoothing/Accelerating SGD undates
WEIGHT_DECAY = 5e-4                # L2 Regularization
LABEL_SMOOTH = 0.0
NUM_WORKERS = 4
SEED = 1234


# ====================== Confirm =======================================
prRed(f"\tData:\t\t{DATASET_NAME}\n\tCut:\t\t{cut_at}\n\tGlobal Rounds:\t{EPOCHS}\n\tClients:\t{NUM_CLIENTS}\n\tLocal Epochs:\t{LOCAL_EPOCHS}\n\tα:\t\t{ALPHA}\n\tWarm-up:\t{WARMUP_ROUNDS}\n\tRebuild:\tN/A")


def _sync_cuda():
    if torch.cuda.is_available():
        torch.cuda.synchronize()


SEED = 1234
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
if torch.cuda.is_available():
    torch.backends.cudnn.deterministic = True
    print(torch.cuda.get_device_name(0))    




#=====================================================================================================
#                                  Baseblock
#=====================================================================================================
class Baseblock(nn.Module):
    expansion = 1
    def __init__(self, input_planes, planes, stride = 1, dim_change = None):
        super(Baseblock, self).__init__()
        self.conv1 = nn.Conv2d(input_planes, planes, stride =  stride, kernel_size = 3, padding = 1)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, stride = 1, kernel_size = 3, padding = 1)
        self.bn2 = nn.BatchNorm2d(planes)
        self.dim_change = dim_change
        
    def forward(self, x):
        res = x
        output = F.relu(self.bn1(self.conv1(x)))
        output = self.bn2(self.conv2(output))
        
        if self.dim_change is not None:
            res =self.dim_change(res)
            
        output += res
        output = F.relu(output)
        
        return output
        
#=====================================================================================================
#                           Client-side Model definition
#=====================================================================================================
# Model at client side
class ResNet18_client_side(nn.Module):
    def __init__(self, block, num_layers):
        super().__init__()
        self.layer1 = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False),  # 3x3 s=1
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            # no maxpool for 32x32
        )
        self.layer2 = nn.Sequential(
            nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(64),
        )

        # add layer 3-6 + avg-pool (copied from Client)
        self.layer3 = nn.Sequential (
                nn.Conv2d(64, 64, kernel_size = 3, stride = 1, padding = 1),
                nn.BatchNorm2d(64),
                nn.ReLU (inplace = True),
                nn.Conv2d(64, 64, kernel_size = 3, stride = 1, padding = 1),
                nn.BatchNorm2d(64),       
                )   

        # self.input_planes is only used inside _layer()
        self.input_planes = 64

        self.layer4 = self._layer(block, 128, num_layers[0], stride = 2)
        self.layer5 = self._layer(block, 256, num_layers[1], stride = 2)
        self.layer6 = self._layer(block, 512, num_layers[2], stride = 2)

        # self. averagePool = nn.AvgPool2d(kernel_size = 7, stride = 1)
        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))


        # Weights into loop (the same thing as SERVER)
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                m.weight.data.normal_(0, math.sqrt(2. / n))
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()
                

    # a helper function to build deeper ResNet blocks (layer4–6) using Baseblock
    def _layer(self, block, planes, num_layers, stride = 2):
        dim_change = None
        if stride != 1 or planes != self.input_planes * block.expansion:
            dim_change = nn.Sequential(nn.Conv2d(self.input_planes, planes*block.expansion, kernel_size = 1, stride = stride),
                                       nn.BatchNorm2d(planes*block.expansion))
        netLayers = []
        netLayers.append(block(self.input_planes, planes, stride = stride, dim_change = dim_change))
        self.input_planes = planes * block.expansion
        for i in range(1, num_layers):
            netLayers.append(block(self.input_planes, planes))
            self.input_planes = planes * block.expansion
            
        return nn.Sequential(*netLayers)
        
        
    def forward(self, x):
        resudial1 = F.relu(self.layer1(x))
        out1 = self.layer2(resudial1)
        out1 = out1 + resudial1 # adding the resudial inputs -- downsampling not required in this layer
        x = F.relu(out1)

        out2 = self.layer3(x)
        out2 = out2 + x
        x = F.relu(out2)
        
        x = self.layer4(x)                    # channels = 128
        x = self.layer5(x)                    # channels = 256
        x = self.layer6(x)                    # channels = 512
        x = self.avgpool(x)                   # Shape [B, 512, H', W']

        # LATE CUT: send x to server
        return x    # shape [B, 512, H', W']
 

net_glob_client = ResNet18_client_side(Baseblock, [2, 2, 2])
if torch.cuda.device_count() > 1:
    print("We use",torch.cuda.device_count(), "GPUs")
    net_glob_client = nn.DataParallel(net_glob_client)   # to use the multiple GPUs; later we can change this to CPUs only 

net_glob_client.to(device)
print(net_glob_client)    

#=====================================================================================================
#                           Server-side Model definition
#=====================================================================================================
# Model at server side
class ResNet18_server_side(nn.Module):
    def __init__(self, block ,classes):
        super(ResNet18_server_side, self).__init__()
        self.fc = nn.Linear(512 * block.expansion, classes)

        
        # Weights into loop
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                m.weight.data.normal_(0, math.sqrt(2. / n))
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()
    
        
    
    def forward(self, x):
        x = x.view(x.size(0), -1)     # [B, 512]
        y_hat = self.fc(x)            # [B, num_classes]
        return y_hat
        

if DATASET_NAME == "CIFAR10":
    net_glob_server = ResNet18_server_side(Baseblock, 10)
else:
    net_glob_server = ResNet18_server_side(Baseblock, 100)
    

if torch.cuda.device_count() > 1:
    print("We use",torch.cuda.device_count(), "GPUs")
    net_glob_server = nn.DataParallel(net_glob_server)   # to use the multiple GPUs 


net_glob_server.to(device)
print(net_glob_server)      

#===================================================================================
# For Server Side Loss and Accuracy 
loss_train_collect = []
acc_train_collect = []
loss_test_collect = []
acc_test_collect = []
batch_acc_train = []
batch_loss_train = []
batch_acc_test = []
batch_loss_test = []
round_time_collect = [] # Stores seconds per global round

criterion = nn.CrossEntropyLoss()
count1 = 0
count2 = 0

#====================================================================================================
#                                  Server Side Programs
#====================================================================================================
# Federated averaging: FedAvg
def FedAvg(w):
    w_avg = copy.deepcopy(w[0])
    for k in w_avg.keys():
        for i in range(1, len(w)):
            w_avg[k] += w[i][k]
        w_avg[k] = torch.div(w_avg[k], len(w))
    return w_avg

def calculate_accuracy(fx, y):
    preds = fx.max(1, keepdim=True)[1]
    correct = preds.eq(y.view_as(preds)).sum()
    acc = 100.00 *correct.float()/preds.shape[0]
    return acc

# to print train - test together in each round-- these are made global
acc_avg_all_user_train = 0
loss_avg_all_user_train = 0
loss_train_collect_user = []
acc_train_collect_user = []
loss_test_collect_user = []
acc_test_collect_user = []


#client idx collector
idx_collect = []
l_epoch_check = False
fed_check = False

# Server-side function associated with Training 
def train_server(fx_client, y, l_epoch_count, l_epoch, idx, len_batch):
    global net_glob_server, criterion, device, batch_acc_train, batch_loss_train, l_epoch_check, fed_check
    global loss_train_collect, acc_train_collect, count1, acc_avg_all_user_train, loss_avg_all_user_train, idx_collect
    global loss_train_collect_user, acc_train_collect_user, LR_BASE
    
    net_glob_server.train()
    optimizer_server = torch.optim.SGD(
        net_glob_server.parameters(), 
        lr = LR_BASE,
        momentum=MOMENTUM,
        weight_decay=WEIGHT_DECAY
    )

    
    # train and update
    optimizer_server.zero_grad()
    
    fx_client = fx_client.to(device)
    y = y.to(device)
    
    #---------forward prop-------------
    fx_server = net_glob_server(fx_client)
    
    # calculate loss
    loss = criterion(fx_server, y)
    # calculate accuracy
    acc = calculate_accuracy(fx_server, y)
    
    #--------backward prop--------------
    loss.backward()
    dfx_client = fx_client.grad.clone().detach()
    optimizer_server.step()
    
    batch_loss_train.append(loss.item())
    batch_acc_train.append(acc.item())
    
    
    # server-side model net_glob_server is global so it is updated automatically in each pass to this function
    # count1: to track the completion of the local batch associated with one client
    count1 += 1
    if count1 == len_batch:
        acc_avg_train = sum(batch_acc_train)/len(batch_acc_train)           # it has accuracy for one batch
        loss_avg_train = sum(batch_loss_train)/len(batch_loss_train)
        
        batch_acc_train = []
        batch_loss_train = []
        count1 = 0
        
        prRed('Client{} Train => Local Epoch: {} \tAcc: {:.3f} \tLoss: {:.4f}'.format(idx, l_epoch_count, acc_avg_train, loss_avg_train))
        
                
        # If one local epoch is completed, after this a new client will come
        if l_epoch_count == l_epoch-1:
            
            l_epoch_check = True                # to evaluate_server function - to check local epoch has completed or not
                       
            # we store the last accuracy in the last batch of the epoch and it is not the average of all local epochs
            # this is because we work on the last trained model and its accuracy (not earlier cases)
            
            #print("accuracy = ", acc_avg_train)
            acc_avg_train_all = acc_avg_train
            loss_avg_train_all = loss_avg_train
                        
            # accumulate accuracy and loss for each new user
            loss_train_collect_user.append(loss_avg_train_all)
            acc_train_collect_user.append(acc_avg_train_all)
            
            # collect the id of each new user                        
            if idx not in idx_collect:
                idx_collect.append(idx) 
                #print(idx_collect)
        
        # This is to check if all users are served for one round --------------------
        if len(idx_collect) == NUM_CLIENTS:
            fed_check = True                                                  # to evaluate_server function  - to check fed check has hitted
            # all users served for one round ------------------------- output print and update is done in evaluate_server()
            # for nicer display 
                        
            idx_collect = []
            
            acc_avg_all_user_train = sum(acc_train_collect_user)/len(acc_train_collect_user)
            loss_avg_all_user_train = sum(loss_train_collect_user)/len(loss_train_collect_user)
            
            loss_train_collect.append(loss_avg_all_user_train)
            acc_train_collect.append(acc_avg_all_user_train)
            
            acc_train_collect_user = []
            loss_train_collect_user = []
            
    # send gradients to the client               
    return dfx_client

# Server-side functions associated with Testing
def evaluate_server(fx_client, y, idx, len_batch, ell):
    global net_glob_server, criterion, batch_acc_test, batch_loss_test
    global loss_test_collect, acc_test_collect, count2, NUM_CLIENTS, acc_avg_train_all, loss_avg_train_all, l_epoch_check, fed_check
    global loss_test_collect_user, acc_test_collect_user, acc_avg_all_user_train, loss_avg_all_user_train
    
    net_glob_server.eval()
  
    with torch.no_grad():
        fx_client = fx_client.to(device)
        y = y.to(device) 
        #---------forward prop-------------
        fx_server = net_glob_server(fx_client)
        
        # calculate loss
        loss = criterion(fx_server, y)
        # calculate accuracy
        acc = calculate_accuracy(fx_server, y)
        
        
        batch_loss_test.append(loss.item())
        batch_acc_test.append(acc.item())
        
               
        count2 += 1
        if count2 == len_batch:
            acc_avg_test = sum(batch_acc_test)/len(batch_acc_test)
            loss_avg_test = sum(batch_loss_test)/len(batch_loss_test)
            
            batch_acc_test = []
            batch_loss_test = []
            count2 = 0
            
            prGreen('Client{} Test =>                   \tAcc: {:.3f} \tLoss: {:.4f}'.format(idx, acc_avg_test, loss_avg_test))
            
            # if a local epoch is completed   
            if l_epoch_check:
                l_epoch_check = False
                
                # Store the last accuracy and loss
                acc_avg_test_all = acc_avg_test
                loss_avg_test_all = loss_avg_test
                        
                loss_test_collect_user.append(loss_avg_test_all)
                acc_test_collect_user.append(acc_avg_test_all)
                
            # if all users are served for one round ----------                    
            if fed_check:
                fed_check = False
                                
                acc_avg_all_user = sum(acc_test_collect_user)/len(acc_test_collect_user)
                loss_avg_all_user = sum(loss_test_collect_user)/len(loss_test_collect_user)
            
                loss_test_collect.append(loss_avg_all_user)
                acc_test_collect.append(acc_avg_all_user)
                acc_test_collect_user = []
                loss_test_collect_user= []
                              
                print("====================== SERVER V1==========================")
                print(' Train: Round {:3d}, Avg Accuracy {:.3f} | Avg Loss {:.3f}'.format(ell, acc_avg_all_user_train, loss_avg_all_user_train))
                print(' Test: Round {:3d}, Avg Accuracy {:.3f} | Avg Loss {:.3f}'.format(ell, acc_avg_all_user, loss_avg_all_user))
                # print("==========================================================")
         
    return 

#==============================================================================================================
#                                       Clients Side Program
#==============================================================================================================
class DatasetSplit(Dataset):
    def __init__(self, dataset, idxs):
        self.dataset = dataset
        self.idxs = list(idxs)

    def __len__(self):
        return len(self.idxs)

    def __getitem__(self, item):
        image, label = self.dataset[self.idxs[item]]
        return image, label

# Client-side functions associated with Training and Testing
class Client(object):
    def __init__(self, net_client_model, idx, LR_BASE, device, dataset_train = None, dataset_test = None, idxs = None, idxs_test = None):
        self.idx = idx
        self.device = device
        self.LR_BASE = LR_BASE
        self.local_ep = LOCAL_EPOCHS
        #self.selected_clients = []
        self.ldr_train = DataLoader(
            DatasetSplit(
                dataset_train, 
                idxs), 
            batch_size = BATCH_SIZE, 
            shuffle = True,
            num_workers=NUM_WORKERS,
            pin_memory=pin
        )
        self.ldr_test = DataLoader(
            DatasetSplit(
                dataset_test, 
                idxs_test), 
            batch_size = BATCH_SIZE, 
            shuffle = True,
            num_workers=NUM_WORKERS,
            pin_memory=pin
        )
        

    def train(self, net):
        net.train()
        optimizer_client = torch.optim.SGD(
            net.parameters(),
            lr = self.LR_BASE,
            momentum=MOMENTUM,
            weight_decay=WEIGHT_DECAY
        ) 
        
        for iter in range(self.local_ep):
            len_batch = len(self.ldr_train)
            for batch_idx, (images, labels) in enumerate(self.ldr_train):
                images, labels = images.to(self.device), labels.to(self.device)
                optimizer_client.zero_grad()
                #---------forward prop-------------
                fx = net(images)
                client_fx = fx.clone().detach().requires_grad_(True)
                
                # Sending activations to server and receiving gradients from server
                dfx = train_server(client_fx, labels, iter, self.local_ep, self.idx, len_batch)
                
                #--------backward prop -------------
                fx.backward(dfx)
                optimizer_client.step()
                            
            
            #prRed('Client{} Train => Epoch: {}'.format(self.idx, ell))
           
        return net.state_dict() 
    
    def evaluate(self, net, ell):
        net.eval()
           
        with torch.no_grad():
            len_batch = len(self.ldr_test)
            for batch_idx, (images, labels) in enumerate(self.ldr_test):
                images, labels = images.to(self.device), labels.to(self.device)
                #---------forward prop-------------
                fx = net(images)
                
                # Sending activations to server 
                evaluate_server(fx, labels, self.idx, len_batch, ell)
            
            #prRed('Client{} Test => Epoch: {}'.format(self.idx, ell))
            
        return          

#=====================================================================================================
# dataset_iid() will create a dictionary to collect the indices of the data samples randomly for each client
def dataset_iid(dataset, NUM_CLIENTS):
    
    num_items = int(len(dataset)/NUM_CLIENTS)
    dict_users, all_idxs = {}, [i for i in range(len(dataset))]
    for i in range(NUM_CLIENTS):
        dict_users[i] = set(np.random.choice(all_idxs, num_items, replace = False))
        all_idxs = list(set(all_idxs) - dict_users[i])
    return dict_users   

# Non-IID partition using Dirichlet distribution
def dataset_noniid_dirichlet(dataset, NUM_CLIENTS, alpha=0.1, seed=SEED):
    """
    Return dict_users: {client_id -> set(sample_indices)} using Dirichlet(α).
    Lower α → higher imbalance across clients.
    """
    rng = np.random.default_rng(seed)
    # CIFAR-100 and other torchvision datasets store labels in .targets
    labels = np.array(dataset.targets if hasattr(dataset, 'targets') else dataset.df['target'].values)
    n_classes = len(np.unique(labels))
    dict_users = {i: set() for i in range(NUM_CLIENTS)}

    for c in range(n_classes):
        idxs = np.where(labels == c)[0]
        rng.shuffle(idxs)

        # Draw class proportions for each client
        proportions = rng.dirichlet([alpha] * NUM_CLIENTS)

        # Compute index splits
        cuts = (np.cumsum(proportions) * len(idxs)).astype(int)[:-1]
        splits = np.split(idxs, cuts)

        for client_id, split in enumerate(splits):
            dict_users[client_id].update(split.tolist())

    return dict_users

#=============================================================================
#                         Data loading 
#============================================================================= 
from torchvision import datasets, transforms

# CIFAR-10/100 transforms
CIFAR_MEAN = {
    "CIFAR10":  [0.4914, 0.4822, 0.4465],
    "CIFAR100": [0.5071, 0.4867, 0.4408],
}[DATASET_NAME]
CIFAR_STD = {
    "CIFAR10":  [0.2470, 0.2435, 0.2616],
    "CIFAR100": [0.2675, 0.2565, 0.2761],
}[DATASET_NAME]
    

train_transforms = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(32, padding=4),
    transforms.ToTensor(),
    transforms.Normalize(CIFAR_MEAN, CIFAR_STD)
])

test_transforms = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(CIFAR_MEAN, CIFAR_STD)
])

# Download CIFAR datasets
if DATASET_NAME == "CIFAR10":
    dataset_train = datasets.CIFAR10(root=DATA_ROOT, train=True,  download=True, transform=train_transforms)
    dataset_test  = datasets.CIFAR10(root=DATA_ROOT, train=False, download=True, transform=test_transforms)
    NUM_CLASSES = 10
else:
    dataset_train = datasets.CIFAR100(root=DATA_ROOT, train=True,  download=True, transform=train_transforms)
    dataset_test  = datasets.CIFAR100(root=DATA_ROOT, train=False, download=True, transform=test_transforms)
    NUM_CLASSES = 100



print("Train samples:", len(dataset_train), " Test samples:", len(dataset_test))
print("Example train label:", dataset_train.targets[0])

#=============================================================================
#                         Forgetting metric setup 
#============================================================================= 

from collections import defaultdict

# Treat each global round as a window (quick baseline).
# If you want true distribution shifts, predefine your own windows and fill `val_loaders`.
T = EPOCHS
class DatasetSplit(Dataset):  # (you already have this in both scripts; keep just one copy)
    def __init__(self, dataset, idxs):
        self.dataset, self.idxs = dataset, list(idxs)
    def __len__(self): return len(self.idxs)
    def __getitem__(self, i): return self.dataset[self.idxs[i]]

val_loaders = {}
# Deterministic, disjoint slices of the test set: window t gets items t, t+T, t+2T, ...
rng_idx = np.arange(len(dataset_test))
for t in range(T):
    idxs = rng_idx[t::T]
    val_loaders[t] = DataLoader(
        DatasetSplit(
            dataset_test, 
            idxs),
        batch_size=BATCH_SIZE, 
        shuffle=False, 
        drop_last=False,
        num_workers=NUM_WORKERS,
        pin_memory=pin
    )

best_loss_per_window = defaultdict(lambda: float('inf'))  # stores min historical loss per window
forgetting_log = []  # per round dicts: {"round": t, "mean_forgetting": x, "per_window": {...}}
# ============================================================================

def _eval_loss_on_loader(model_client, model_server, loader, device, criterion):
    """Evaluate mean loss on a loader using split models."""
    # Handle DataParallel transparently
    mc = model_client.module if isinstance(model_client, nn.DataParallel) else model_client
    ms = model_server.module if isinstance(model_server, nn.DataParallel) else model_server
    mc.eval(); ms.eval()
    loss_sum, n = 0.0, 0
    with torch.no_grad():
        for images, labels in loader:
            images, labels = images.to(device), labels.to(device)
            fx = mc(images)
            logits = ms(fx)
            loss = criterion(logits, labels)
            bs = labels.size(0)
            loss_sum += loss.item() * bs
            n += bs
    return loss_sum / max(1, n)


#=============================================================================
#                         Dirichlet non-IID partition
#=============================================================================
dict_users = dataset_noniid_dirichlet(dataset_train, NUM_CLIENTS, alpha=ALPHA, seed=SEED)
dict_users_test = dataset_iid(dataset_test, NUM_CLIENTS)  # keep test IID


#------------ Training And Testing -----------------
net_glob_client.train()
#copy weights
w_glob_client = net_glob_client.state_dict()

#=============================================================================

# Federation takes place after certain local epochs in train() client-side
# this epoch is global epoch, also known as rounds
for iter in range(EPOCHS):
    # ---- START TIMER (train + test + FedAvg only) ----
    _sync_cuda()
    t_start = time.perf_counter()
    # --------------------------------------------------

    m = max(int(FRAC * NUM_CLIENTS), 1)
    idxs_users = np.random.choice(range(NUM_CLIENTS), m, replace=False)
    w_locals_client = []

    for idx in idxs_users:
        local = Client(net_glob_client, idx, LR_BASE, device,
                       dataset_train=dataset_train, dataset_test=dataset_test,
                       idxs=dict_users[idx], idxs_test=dict_users_test[idx])
        # Training
        w_client = local.train(net=copy.deepcopy(net_glob_client).to(device))
        w_locals_client.append(copy.deepcopy(w_client))

        # Testing
        local.evaluate(net=copy.deepcopy(net_glob_client).to(device), ell=iter)

    # ---------- Federation at client side ----------
    print("------------------------------------------------------------")
    print("------ Fed Server: Federation process at Client-Side -------")
    print("------------------------------------------------------------")
    w_glob_client = FedAvg(w_locals_client)
    net_glob_client.load_state_dict(w_glob_client)

    # ---- STOP TIMER & LOG ----
    _sync_cuda()
    dt = time.perf_counter() - t_start
    round_time_collect.append(dt)
    # ---------------------------

    # === Forgetting update at end of round `iter` (post-FedAvg, not timed) ===
    t = iter  # current window id

    # 1) Update the "best so far" for the CURRENT window using the current model
    L_cur_t = _eval_loss_on_loader(net_glob_client, net_glob_server,
                                   val_loaders[t], device, criterion)
    best_loss_per_window[t] = min(best_loss_per_window[t], L_cur_t)

    # 2) Compute forgetting on all PAST windows t_prev < t
    per_win_fgt = {}
    for t_prev in range(t):
        L_now = _eval_loss_on_loader(net_glob_client, net_glob_server,
                                     val_loaders[t_prev], device, criterion)
        Fgt = L_now - best_loss_per_window[t_prev]
        per_win_fgt[t_prev] = Fgt

    mean_fgt = float(np.mean(list(per_win_fgt.values()))) if per_win_fgt else 0.0
    forgetting_log.append({"round": t, "mean_forgetting": mean_fgt, "per_window": per_win_fgt})
    print(f"Forgetting : Round {t}, mean_forgetting : {mean_fgt:.3f}")
    print("==========================================================")

    
#===================================================================================     

print("Training and Evaluation completed!")    

#===============================================================================
# Save output data to .excel file (we use for comparision plots)
n = min(len(acc_train_collect), len(acc_test_collect), len(round_time_collect), len(forgetting_log))
round_process = [i for i in range(1, len(acc_train_collect)+1)]
mean_fgt_series = [d["mean_forgetting"] for d in forgetting_log[:n]]

df = DataFrame({
    'round': round_process,
    'acc_train': acc_train_collect[:n],
    'acc_test':  acc_test_collect[:n],
    'round_time_sec': round_time_collect[:n],
    'mean_FgT_loss': mean_fgt_series,
})


# write CSV — easier for scripting/comparison tools
file_name_csv = program + ".csv"
df.to_csv(file_name_csv, index=False)

print("Saved:", file_name_csv)

#=============================================================================
#                         Program Completed
#=============================================================================
# Out:
# ---------SFLV2 - CIFAR-100 α=0.5 - LATE-Cut (6 + AvgPool)----------
#  	Data:		CIFAR100
# 	Cut:		Late Cut at Layer 6 + AvgPool
# 	Global Rounds:	100
# 	Clients:	10
# 	Local Epochs:	5
# 	α:		0.5
# 	Warm-up:	0
# 	Rebuild:	N/A
# NVIDIA H200
# ResNet18_client_side(
#   (layer1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (layer2): Sequential(
#     (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (layer3): Sequential(
#     (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (layer4): Sequential(
#     (0): Baseblock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dim_change): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2))
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Baseblock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer5): Sequential(
#     (0): Baseblock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dim_change): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2))
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Baseblock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer6): Sequential(
#     (0): Baseblock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dim_change): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2))
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Baseblock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
# )
# ResNet18_server_side(
#   (fc): Linear(in_features=512, out_features=100, bias=True)
# )
# Train samples: 50000  Test samples: 10000
# Example train label: 19
#  Client3 Train => Local Epoch: 0 	Acc: 6.662 	Loss: 4.2425
#  Client3 Train => Local Epoch: 1 	Acc: 13.351 	Loss: 3.7949
#  Client3 Train => Local Epoch: 2 	Acc: 18.520 	Loss: 3.5228
#  Client3 Train => Local Epoch: 3 	Acc: 21.231 	Loss: 3.3469
#  Client3 Train => Local Epoch: 4 	Acc: 22.873 	Loss: 3.1926
#  Client3 Test =>                   	Acc: 0.812 	Loss: 5.0480
#  Client1 Train => Local Epoch: 0 	Acc: 6.263 	Loss: 4.4117
#  Client1 Train => Local Epoch: 1 	Acc: 11.543 	Loss: 3.8774
#  Client1 Train => Local Epoch: 2 	Acc: 16.309 	Loss: 3.5828
#  Client1 Train => Local Epoch: 3 	Acc: 18.856 	Loss: 3.4147
#  Client1 Train => Local Epoch: 4 	Acc: 21.872 	Loss: 3.2772
#  Client1 Test =>                   	Acc: 1.515 	Loss: 5.1523
#  Client2 Train => Local Epoch: 0 	Acc: 5.744 	Loss: 4.5518
#  Client2 Train => Local Epoch: 1 	Acc: 12.874 	Loss: 3.8336
#  Client2 Train => Local Epoch: 2 	Acc: 15.245 	Loss: 3.5795
#  Client2 Train => Local Epoch: 3 	Acc: 17.644 	Loss: 3.4146
#  Client2 Train => Local Epoch: 4 	Acc: 20.336 	Loss: 3.3022
#  Client2 Test =>                   	Acc: 1.212 	Loss: 5.0419
#  Client0 Train => Local Epoch: 0 	Acc: 6.077 	Loss: 4.4497
#  Client0 Train => Local Epoch: 1 	Acc: 14.355 	Loss: 3.7878
#  Client0 Train => Local Epoch: 2 	Acc: 16.893 	Loss: 3.5306
#  Client0 Train => Local Epoch: 3 	Acc: 20.513 	Loss: 3.3335
#  Client0 Train => Local Epoch: 4 	Acc: 22.721 	Loss: 3.1788
#  Client0 Test =>                   	Acc: 0.812 	Loss: 5.1700
#  Client8 Train => Local Epoch: 0 	Acc: 8.149 	Loss: 4.3490
#  Client8 Train => Local Epoch: 1 	Acc: 15.999 	Loss: 3.6441
#  Client8 Train => Local Epoch: 2 	Acc: 20.106 	Loss: 3.3820
#  Client8 Train => Local Epoch: 3 	Acc: 22.367 	Loss: 3.2184
#  Client8 Train => Local Epoch: 4 	Acc: 23.978 	Loss: 3.1126
#  Client8 Test =>                   	Acc: 1.886 	Loss: 5.3841
#  Client7 Train => Local Epoch: 0 	Acc: 8.580 	Loss: 4.2541
#  Client7 Train => Local Epoch: 1 	Acc: 16.690 	Loss: 3.6993
#  Client7 Train => Local Epoch: 2 	Acc: 19.102 	Loss: 3.4665
#  Client7 Train => Local Epoch: 3 	Acc: 20.891 	Loss: 3.3287
#  Client7 Train => Local Epoch: 4 	Acc: 22.618 	Loss: 3.2463
#  Client7 Test =>                   	Acc: 0.889 	Loss: 5.2024
#  Client6 Train => Local Epoch: 0 	Acc: 8.986 	Loss: 4.4312
#  Client6 Train => Local Epoch: 1 	Acc: 21.103 	Loss: 3.4897
#  Client6 Train => Local Epoch: 2 	Acc: 25.643 	Loss: 3.1368
#  Client6 Train => Local Epoch: 3 	Acc: 27.990 	Loss: 2.9552
#  Client6 Train => Local Epoch: 4 	Acc: 30.446 	Loss: 2.8382
#  Client6 Test =>                   	Acc: 1.105 	Loss: 5.2772
#  Client9 Train => Local Epoch: 0 	Acc: 9.204 	Loss: 4.3975
#  Client9 Train => Local Epoch: 1 	Acc: 20.131 	Loss: 3.6138
#  Client9 Train => Local Epoch: 2 	Acc: 24.168 	Loss: 3.3154
#  Client9 Train => Local Epoch: 3 	Acc: 26.707 	Loss: 3.1585
#  Client9 Train => Local Epoch: 4 	Acc: 28.346 	Loss: 3.0298
#  Client9 Test =>                   	Acc: 1.377 	Loss: 5.3246
#  Client5 Train => Local Epoch: 0 	Acc: 5.522 	Loss: 4.4424
#  Client5 Train => Local Epoch: 1 	Acc: 14.290 	Loss: 3.7355
#  Client5 Train => Local Epoch: 2 	Acc: 17.664 	Loss: 3.4600
#  Client5 Train => Local Epoch: 3 	Acc: 19.788 	Loss: 3.3077
#  Client5 Train => Local Epoch: 4 	Acc: 22.078 	Loss: 3.1916
#  Client5 Test =>                   	Acc: 1.408 	Loss: 5.1829
#  Client4 Train => Local Epoch: 0 	Acc: 7.080 	Loss: 4.3406
#  Client4 Train => Local Epoch: 1 	Acc: 14.307 	Loss: 3.7366
#  Client4 Train => Local Epoch: 2 	Acc: 16.585 	Loss: 3.4627
#  Client4 Train => Local Epoch: 3 	Acc: 20.605 	Loss: 3.3064
#  Client4 Train => Local Epoch: 4 	Acc: 20.296 	Loss: 3.2777
#  Client4 Test =>                   	Acc: 0.606 	Loss: 5.2708
# ====================== SERVER V1==========================
#  Train: Round   0, Avg Accuracy 23.556 | Avg Loss 3.165
#  Test: Round   0, Avg Accuracy 1.162 | Avg Loss 5.205
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Forgetting : Round 0, mean_forgetting : 0.000
# ==========================================================
#  Client3 Train => Local Epoch: 0 	Acc: 15.335 	Loss: 3.7524
#  Client3 Train => Local Epoch: 1 	Acc: 20.545 	Loss: 3.3044
#  Client3 Train => Local Epoch: 2 	Acc: 24.212 	Loss: 3.1098
#  Client3 Train => Local Epoch: 3 	Acc: 25.167 	Loss: 3.0131
#  Client3 Train => Local Epoch: 4 	Acc: 27.634 	Loss: 2.8945
#  Client3 Test =>                   	Acc: 5.775 	Loss: 4.3267
#  Client4 Train => Local Epoch: 0 	Acc: 14.827 	Loss: 3.7048
#  Client4 Train => Local Epoch: 1 	Acc: 18.376 	Loss: 3.3524
#  Client4 Train => Local Epoch: 2 	Acc: 20.231 	Loss: 3.2256
#  Client4 Train => Local Epoch: 3 	Acc: 22.396 	Loss: 3.1493
#  Client4 Train => Local Epoch: 4 	Acc: 24.447 	Loss: 3.0528
#  Client4 Test =>                   	Acc: 4.866 	Loss: 4.4004
#  Client2 Train => Local Epoch: 0 	Acc: 13.403 	Loss: 3.8606
#  Client2 Train => Local Epoch: 1 	Acc: 19.960 	Loss: 3.3458
#  Client2 Train => Local Epoch: 2 	Acc: 21.596 	Loss: 3.1855
#  Client2 Train => Local Epoch: 3 	Acc: 23.498 	Loss: 3.0910
#  Client2 Train => Local Epoch: 4 	Acc: 24.869 	Loss: 3.0201
#  Client2 Test =>                   	Acc: 2.590 	Loss: 4.3717
#  Client9 Train => Local Epoch: 0 	Acc: 18.112 	Loss: 3.6193
#  Client9 Train => Local Epoch: 1 	Acc: 25.588 	Loss: 3.1103
#  Client9 Train => Local Epoch: 2 	Acc: 28.377 	Loss: 2.9412
#  Client9 Train => Local Epoch: 3 	Acc: 31.101 	Loss: 2.8338
#  Client9 Train => Local Epoch: 4 	Acc: 31.504 	Loss: 2.7513
#  Client9 Test =>                   	Acc: 2.933 	Loss: 4.4218
#  Client5 Train => Local Epoch: 0 	Acc: 14.003 	Loss: 3.7581
#  Client5 Train => Local Epoch: 1 	Acc: 21.471 	Loss: 3.2797
#  Client5 Train => Local Epoch: 2 	Acc: 24.182 	Loss: 3.0959
#  Client5 Train => Local Epoch: 3 	Acc: 26.002 	Loss: 2.9984
#  Client5 Train => Local Epoch: 4 	Acc: 27.781 	Loss: 2.9067
#  Client5 Test =>                   	Acc: 4.465 	Loss: 4.4554
#  Client1 Train => Local Epoch: 0 	Acc: 13.721 	Loss: 3.8405
#  Client1 Train => Local Epoch: 1 	Acc: 20.839 	Loss: 3.2793
#  Client1 Train => Local Epoch: 2 	Acc: 23.890 	Loss: 3.1024
#  Client1 Train => Local Epoch: 3 	Acc: 25.655 	Loss: 3.0036
#  Client1 Train => Local Epoch: 4 	Acc: 27.492 	Loss: 2.9051
#  Client1 Test =>                   	Acc: 5.081 	Loss: 4.4639
#  Client8 Train => Local Epoch: 0 	Acc: 17.130 	Loss: 3.6892
#  Client8 Train => Local Epoch: 1 	Acc: 24.570 	Loss: 3.1454
#  Client8 Train => Local Epoch: 2 	Acc: 27.148 	Loss: 2.9688
#  Client8 Train => Local Epoch: 3 	Acc: 29.077 	Loss: 2.8577
#  Client8 Train => Local Epoch: 4 	Acc: 29.913 	Loss: 2.7823
#  Client8 Test =>                   	Acc: 5.112 	Loss: 4.3973
#  Client0 Train => Local Epoch: 0 	Acc: 14.336 	Loss: 3.7303
#  Client0 Train => Local Epoch: 1 	Acc: 22.608 	Loss: 3.1845
#  Client0 Train => Local Epoch: 2 	Acc: 25.971 	Loss: 2.9940
#  Client0 Train => Local Epoch: 3 	Acc: 27.116 	Loss: 2.8877
#  Client0 Train => Local Epoch: 4 	Acc: 29.046 	Loss: 2.7986
#  Client0 Test =>                   	Acc: 3.714 	Loss: 4.4068
#  Client6 Train => Local Epoch: 0 	Acc: 18.926 	Loss: 3.5786
#  Client6 Train => Local Epoch: 1 	Acc: 29.284 	Loss: 2.9468
#  Client6 Train => Local Epoch: 2 	Acc: 31.053 	Loss: 2.7642
#  Client6 Train => Local Epoch: 3 	Acc: 33.654 	Loss: 2.6630
#  Client6 Train => Local Epoch: 4 	Acc: 35.343 	Loss: 2.5585
#  Client6 Test =>                   	Acc: 5.482 	Loss: 4.4267
#  Client7 Train => Local Epoch: 0 	Acc: 15.288 	Loss: 3.7059
#  Client7 Train => Local Epoch: 1 	Acc: 22.994 	Loss: 3.2521
#  Client7 Train => Local Epoch: 2 	Acc: 23.852 	Loss: 3.1428
#  Client7 Train => Local Epoch: 3 	Acc: 26.321 	Loss: 3.0143
#  Client7 Train => Local Epoch: 4 	Acc: 27.559 	Loss: 2.9390
#  Client7 Test =>                   	Acc: 3.997 	Loss: 4.4291
# ====================== SERVER V1==========================
#  Train: Round   1, Avg Accuracy 28.559 | Avg Loss 2.861
#  Test: Round   1, Avg Accuracy 4.402 | Avg Loss 4.410
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Forgetting : Round 1, mean_forgetting : -0.472
# ==========================================================
#  Client0 Train => Local Epoch: 0 	Acc: 20.680 	Loss: 3.3690
#  Client0 Train => Local Epoch: 1 	Acc: 28.186 	Loss: 2.8943
#  Client0 Train => Local Epoch: 2 	Acc: 29.688 	Loss: 2.7761
#  Client0 Train => Local Epoch: 3 	Acc: 31.618 	Loss: 2.6850
#  Client0 Train => Local Epoch: 4 	Acc: 33.109 	Loss: 2.6274
#  Client0 Test =>                   	Acc: 8.169 	Loss: 4.1506
#  Client2 Train => Local Epoch: 0 	Acc: 18.760 	Loss: 3.4913
#  Client2 Train => Local Epoch: 1 	Acc: 24.106 	Loss: 3.0967
#  Client2 Train => Local Epoch: 2 	Acc: 25.519 	Loss: 2.9752
#  Client2 Train => Local Epoch: 3 	Acc: 27.665 	Loss: 2.8916
#  Client2 Train => Local Epoch: 4 	Acc: 29.144 	Loss: 2.8070
#  Client2 Test =>                   	Acc: 8.143 	Loss: 4.1129
#  Client5 Train => Local Epoch: 0 	Acc: 19.083 	Loss: 3.4635
#  Client5 Train => Local Epoch: 1 	Acc: 25.658 	Loss: 3.0327
#  Client5 Train => Local Epoch: 2 	Acc: 27.355 	Loss: 2.8913
#  Client5 Train => Local Epoch: 3 	Acc: 30.315 	Loss: 2.7829
#  Client5 Train => Local Epoch: 4 	Acc: 32.769 	Loss: 2.6841
#  Client5 Test =>                   	Acc: 8.004 	Loss: 4.1652
#  Client7 Train => Local Epoch: 0 	Acc: 19.246 	Loss: 3.4916
#  Client7 Train => Local Epoch: 1 	Acc: 26.918 	Loss: 3.0284
#  Client7 Train => Local Epoch: 2 	Acc: 28.395 	Loss: 2.9167
#  Client7 Train => Local Epoch: 3 	Acc: 29.820 	Loss: 2.8141
#  Client7 Train => Local Epoch: 4 	Acc: 31.229 	Loss: 2.7562
#  Client7 Test =>                   	Acc: 7.701 	Loss: 4.1871
#  Client1 Train => Local Epoch: 0 	Acc: 19.014 	Loss: 3.5221
#  Client1 Train => Local Epoch: 1 	Acc: 26.306 	Loss: 3.0373
#  Client1 Train => Local Epoch: 2 	Acc: 28.122 	Loss: 2.9009
#  Client1 Train => Local Epoch: 3 	Acc: 30.406 	Loss: 2.7680
#  Client1 Train => Local Epoch: 4 	Acc: 32.656 	Loss: 2.6861
#  Client1 Test =>                   	Acc: 8.540 	Loss: 4.1571
#  Client8 Train => Local Epoch: 0 	Acc: 21.316 	Loss: 3.3452
#  Client8 Train => Local Epoch: 1 	Acc: 28.907 	Loss: 2.8747
#  Client8 Train => Local Epoch: 2 	Acc: 31.304 	Loss: 2.7349
#  Client8 Train => Local Epoch: 3 	Acc: 32.796 	Loss: 2.6374
#  Client8 Train => Local Epoch: 4 	Acc: 34.841 	Loss: 2.5693
#  Client8 Test =>                   	Acc: 10.496 	Loss: 4.0342
#  Client9 Train => Local Epoch: 0 	Acc: 22.790 	Loss: 3.3369
#  Client9 Train => Local Epoch: 1 	Acc: 30.624 	Loss: 2.8450
#  Client9 Train => Local Epoch: 2 	Acc: 33.870 	Loss: 2.6784
#  Client9 Train => Local Epoch: 3 	Acc: 34.595 	Loss: 2.6242
#  Client9 Train => Local Epoch: 4 	Acc: 37.385 	Loss: 2.5236
#  Client9 Test =>                   	Acc: 7.809 	Loss: 4.0723
#  Client6 Train => Local Epoch: 0 	Acc: 25.907 	Loss: 3.1840
#  Client6 Train => Local Epoch: 1 	Acc: 33.466 	Loss: 2.6984
#  Client6 Train => Local Epoch: 2 	Acc: 36.049 	Loss: 2.5329
#  Client6 Train => Local Epoch: 3 	Acc: 38.093 	Loss: 2.4323
#  Client6 Train => Local Epoch: 4 	Acc: 39.377 	Loss: 2.3750
#  Client6 Test =>                   	Acc: 10.604 	Loss: 4.1059
#  Client3 Train => Local Epoch: 0 	Acc: 21.459 	Loss: 3.3164
#  Client3 Train => Local Epoch: 1 	Acc: 25.791 	Loss: 2.9909
#  Client3 Train => Local Epoch: 2 	Acc: 29.023 	Loss: 2.8146
#  Client3 Train => Local Epoch: 3 	Acc: 29.629 	Loss: 2.7569
#  Client3 Train => Local Epoch: 4 	Acc: 31.591 	Loss: 2.6747
#  Client3 Test =>                   	Acc: 9.422 	Loss: 4.0922
#  Client4 Train => Local Epoch: 0 	Acc: 19.531 	Loss: 3.4217
#  Client4 Train => Local Epoch: 1 	Acc: 23.454 	Loss: 3.1178
#  Client4 Train => Local Epoch: 2 	Acc: 26.530 	Loss: 2.9538
#  Client4 Train => Local Epoch: 3 	Acc: 27.588 	Loss: 2.8954
#  Client4 Train => Local Epoch: 4 	Acc: 29.118 	Loss: 2.7895
#  Client4 Test =>                   	Acc: 10.183 	Loss: 4.1032
# ====================== SERVER V1==========================
#  Train: Round   2, Avg Accuracy 33.122 | Avg Loss 2.649
#  Test: Round   2, Avg Accuracy 8.907 | Avg Loss 4.118
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Forgetting : Round 2, mean_forgetting : -0.536
# ==========================================================
#  Client5 Train => Local Epoch: 0 	Acc: 22.670 	Loss: 3.3195
#  Client5 Train => Local Epoch: 1 	Acc: 30.304 	Loss: 2.8353
#  Client5 Train => Local Epoch: 2 	Acc: 32.936 	Loss: 2.6660
#  Client5 Train => Local Epoch: 3 	Acc: 34.636 	Loss: 2.5740
#  Client5 Train => Local Epoch: 4 	Acc: 36.325 	Loss: 2.4832
#  Client5 Test =>                   	Acc: 12.433 	Loss: 3.7631
#  Client4 Train => Local Epoch: 0 	Acc: 23.079 	Loss: 3.1283
#  Client4 Train => Local Epoch: 1 	Acc: 26.400 	Loss: 2.9247
#  Client4 Train => Local Epoch: 2 	Acc: 29.150 	Loss: 2.7944
#  Client4 Train => Local Epoch: 3 	Acc: 29.948 	Loss: 2.7592
#  Client4 Train => Local Epoch: 4 	Acc: 32.764 	Loss: 2.6655
#  Client4 Test =>                   	Acc: 12.032 	Loss: 3.7928
#  Client7 Train => Local Epoch: 0 	Acc: 21.850 	Loss: 3.3038
#  Client7 Train => Local Epoch: 1 	Acc: 30.667 	Loss: 2.8346
#  Client7 Train => Local Epoch: 2 	Acc: 31.958 	Loss: 2.7212
#  Client7 Train => Local Epoch: 3 	Acc: 32.750 	Loss: 2.6556
#  Client7 Train => Local Epoch: 4 	Acc: 34.330 	Loss: 2.5486
#  Client7 Test =>                   	Acc: 11.237 	Loss: 3.8263
#  Client1 Train => Local Epoch: 0 	Acc: 24.402 	Loss: 3.2627
#  Client1 Train => Local Epoch: 1 	Acc: 30.400 	Loss: 2.8279
#  Client1 Train => Local Epoch: 2 	Acc: 32.237 	Loss: 2.6724
#  Client1 Train => Local Epoch: 3 	Acc: 34.456 	Loss: 2.5819
#  Client1 Train => Local Epoch: 4 	Acc: 35.478 	Loss: 2.5101
#  Client1 Test =>                   	Acc: 12.931 	Loss: 3.7864
#  Client3 Train => Local Epoch: 0 	Acc: 25.047 	Loss: 3.0826
#  Client3 Train => Local Epoch: 1 	Acc: 29.873 	Loss: 2.7621
#  Client3 Train => Local Epoch: 2 	Acc: 32.033 	Loss: 2.6564
#  Client3 Train => Local Epoch: 3 	Acc: 34.297 	Loss: 2.5598
#  Client3 Train => Local Epoch: 4 	Acc: 35.086 	Loss: 2.4992
#  Client3 Test =>                   	Acc: 13.830 	Loss: 3.7565
#  Client9 Train => Local Epoch: 0 	Acc: 27.121 	Loss: 3.1066
#  Client9 Train => Local Epoch: 1 	Acc: 35.258 	Loss: 2.6450
#  Client9 Train => Local Epoch: 2 	Acc: 36.820 	Loss: 2.5203
#  Client9 Train => Local Epoch: 3 	Acc: 38.752 	Loss: 2.4273
#  Client9 Train => Local Epoch: 4 	Acc: 39.934 	Loss: 2.3685
#  Client9 Test =>                   	Acc: 13.749 	Loss: 3.6684
#  Client8 Train => Local Epoch: 0 	Acc: 25.921 	Loss: 3.1144
#  Client8 Train => Local Epoch: 1 	Acc: 32.557 	Loss: 2.6918
#  Client8 Train => Local Epoch: 2 	Acc: 35.258 	Loss: 2.5466
#  Client8 Train => Local Epoch: 3 	Acc: 37.356 	Loss: 2.4422
#  Client8 Train => Local Epoch: 4 	Acc: 38.673 	Loss: 2.3697
#  Client8 Test =>                   	Acc: 14.056 	Loss: 3.6622
#  Client0 Train => Local Epoch: 0 	Acc: 23.529 	Loss: 3.1659
#  Client0 Train => Local Epoch: 1 	Acc: 31.346 	Loss: 2.7076
#  Client0 Train => Local Epoch: 2 	Acc: 33.111 	Loss: 2.5760
#  Client0 Train => Local Epoch: 3 	Acc: 34.960 	Loss: 2.4816
#  Client0 Train => Local Epoch: 4 	Acc: 37.494 	Loss: 2.3991
#  Client0 Test =>                   	Acc: 14.083 	Loss: 3.7010
#  Client2 Train => Local Epoch: 0 	Acc: 22.610 	Loss: 3.2784
#  Client2 Train => Local Epoch: 1 	Acc: 27.756 	Loss: 2.9018
#  Client2 Train => Local Epoch: 2 	Acc: 30.404 	Loss: 2.7516
#  Client2 Train => Local Epoch: 3 	Acc: 32.065 	Loss: 2.6650
#  Client2 Train => Local Epoch: 4 	Acc: 33.230 	Loss: 2.6014
#  Client2 Test =>                   	Acc: 13.820 	Loss: 3.6825
#  Client6 Train => Local Epoch: 0 	Acc: 29.900 	Loss: 2.8986
#  Client6 Train => Local Epoch: 1 	Acc: 37.105 	Loss: 2.4799
#  Client6 Train => Local Epoch: 2 	Acc: 39.597 	Loss: 2.3385
#  Client6 Train => Local Epoch: 3 	Acc: 41.336 	Loss: 2.2617
#  Client6 Train => Local Epoch: 4 	Acc: 43.399 	Loss: 2.1995
#  Client6 Test =>                   	Acc: 11.965 	Loss: 3.7889
# ====================== SERVER V1==========================
#  Train: Round   3, Avg Accuracy 36.671 | Avg Loss 2.464
#  Test: Round   3, Avg Accuracy 13.014 | Avg Loss 3.743
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Forgetting : Round 3, mean_forgetting : -0.535
# ==========================================================
#  Client2 Train => Local Epoch: 0 	Acc: 26.289 	Loss: 2.9627
#  Client2 Train => Local Epoch: 1 	Acc: 31.430 	Loss: 2.7005
#  Client2 Train => Local Epoch: 2 	Acc: 32.863 	Loss: 2.5978
#  Client2 Train => Local Epoch: 3 	Acc: 34.297 	Loss: 2.5152
#  Client2 Train => Local Epoch: 4 	Acc: 36.287 	Loss: 2.4307
#  Client2 Test =>                   	Acc: 15.002 	Loss: 3.6526
#  Client8 Train => Local Epoch: 0 	Acc: 28.120 	Loss: 2.9239
#  Client8 Train => Local Epoch: 1 	Acc: 36.332 	Loss: 2.5090
#  Client8 Train => Local Epoch: 2 	Acc: 38.995 	Loss: 2.3769
#  Client8 Train => Local Epoch: 3 	Acc: 40.569 	Loss: 2.2782
#  Client8 Train => Local Epoch: 4 	Acc: 41.948 	Loss: 2.2174
#  Client8 Test =>                   	Acc: 17.191 	Loss: 3.4814
#  Client5 Train => Local Epoch: 0 	Acc: 26.267 	Loss: 3.0428
#  Client5 Train => Local Epoch: 1 	Acc: 33.900 	Loss: 2.6309
#  Client5 Train => Local Epoch: 2 	Acc: 36.526 	Loss: 2.5153
#  Client5 Train => Local Epoch: 3 	Acc: 37.822 	Loss: 2.4133
#  Client5 Train => Local Epoch: 4 	Acc: 40.134 	Loss: 2.3092
#  Client5 Test =>                   	Acc: 17.720 	Loss: 3.5577
#  Client0 Train => Local Epoch: 0 	Acc: 26.291 	Loss: 3.0681
#  Client0 Train => Local Epoch: 1 	Acc: 34.651 	Loss: 2.5577
#  Client0 Train => Local Epoch: 2 	Acc: 36.573 	Loss: 2.4258
#  Client0 Train => Local Epoch: 3 	Acc: 37.853 	Loss: 2.3354
#  Client0 Train => Local Epoch: 4 	Acc: 40.122 	Loss: 2.2614
#  Client0 Test =>                   	Acc: 17.046 	Loss: 3.4738
#  Client6 Train => Local Epoch: 0 	Acc: 33.090 	Loss: 2.7710
#  Client6 Train => Local Epoch: 1 	Acc: 40.656 	Loss: 2.3560
#  Client6 Train => Local Epoch: 2 	Acc: 43.091 	Loss: 2.2076
#  Client6 Train => Local Epoch: 3 	Acc: 44.321 	Loss: 2.1301
#  Client6 Train => Local Epoch: 4 	Acc: 45.102 	Loss: 2.0566
#  Client6 Test =>                   	Acc: 15.383 	Loss: 3.6211
#  Client4 Train => Local Epoch: 0 	Acc: 26.302 	Loss: 2.9953
#  Client4 Train => Local Epoch: 1 	Acc: 29.281 	Loss: 2.7908
#  Client4 Train => Local Epoch: 2 	Acc: 31.787 	Loss: 2.6987
#  Client4 Train => Local Epoch: 3 	Acc: 30.550 	Loss: 2.6914
#  Client4 Train => Local Epoch: 4 	Acc: 34.863 	Loss: 2.5462
#  Client4 Test =>                   	Acc: 18.460 	Loss: 3.4659
#  Client3 Train => Local Epoch: 0 	Acc: 28.250 	Loss: 2.9366
#  Client3 Train => Local Epoch: 1 	Acc: 34.059 	Loss: 2.6364
#  Client3 Train => Local Epoch: 2 	Acc: 35.660 	Loss: 2.4909
#  Client3 Train => Local Epoch: 3 	Acc: 36.522 	Loss: 2.4106
#  Client3 Train => Local Epoch: 4 	Acc: 38.166 	Loss: 2.3241
#  Client3 Test =>                   	Acc: 17.289 	Loss: 3.5207
#  Client7 Train => Local Epoch: 0 	Acc: 27.874 	Loss: 3.0225
#  Client7 Train => Local Epoch: 1 	Acc: 33.188 	Loss: 2.6735
#  Client7 Train => Local Epoch: 2 	Acc: 35.316 	Loss: 2.5578
#  Client7 Train => Local Epoch: 3 	Acc: 36.423 	Loss: 2.4553
#  Client7 Train => Local Epoch: 4 	Acc: 38.006 	Loss: 2.3909
#  Client7 Test =>                   	Acc: 15.911 	Loss: 3.5452
#  Client9 Train => Local Epoch: 0 	Acc: 30.961 	Loss: 2.9155
#  Client9 Train => Local Epoch: 1 	Acc: 37.927 	Loss: 2.4631
#  Client9 Train => Local Epoch: 2 	Acc: 39.946 	Loss: 2.3348
#  Client9 Train => Local Epoch: 3 	Acc: 41.574 	Loss: 2.2579
#  Client9 Train => Local Epoch: 4 	Acc: 43.461 	Loss: 2.1827
#  Client9 Test =>                   	Acc: 17.016 	Loss: 3.4191
#  Client1 Train => Local Epoch: 0 	Acc: 27.852 	Loss: 3.0182
#  Client1 Train => Local Epoch: 1 	Acc: 34.912 	Loss: 2.6194
#  Client1 Train => Local Epoch: 2 	Acc: 37.091 	Loss: 2.4779
#  Client1 Train => Local Epoch: 3 	Acc: 38.183 	Loss: 2.3890
#  Client1 Train => Local Epoch: 4 	Acc: 40.300 	Loss: 2.3000
#  Client1 Test =>                   	Acc: 17.093 	Loss: 3.5120
# ====================== SERVER V1==========================
#  Train: Round   4, Avg Accuracy 39.839 | Avg Loss 2.302
#  Test: Round   4, Avg Accuracy 16.811 | Avg Loss 3.525
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Forgetting : Round 4, mean_forgetting : -0.641
# ==========================================================
#  Client7 Train => Local Epoch: 0 	Acc: 30.800 	Loss: 2.8176
#  Client7 Train => Local Epoch: 1 	Acc: 36.868 	Loss: 2.5017
#  Client7 Train => Local Epoch: 2 	Acc: 38.568 	Loss: 2.4055
#  Client7 Train => Local Epoch: 3 	Acc: 39.407 	Loss: 2.3094
#  Client7 Train => Local Epoch: 4 	Acc: 41.593 	Loss: 2.2209
#  Client7 Test =>                   	Acc: 16.918 	Loss: 3.4415
#  Client2 Train => Local Epoch: 0 	Acc: 26.751 	Loss: 2.9963
#  Client2 Train => Local Epoch: 1 	Acc: 33.375 	Loss: 2.6035
#  Client2 Train => Local Epoch: 2 	Acc: 36.182 	Loss: 2.4450
#  Client2 Train => Local Epoch: 3 	Acc: 38.385 	Loss: 2.3650
#  Client2 Train => Local Epoch: 4 	Acc: 40.493 	Loss: 2.2798
#  Client2 Test =>                   	Acc: 17.703 	Loss: 3.3512
#  Client6 Train => Local Epoch: 0 	Acc: 36.146 	Loss: 2.6139
#  Client6 Train => Local Epoch: 1 	Acc: 43.334 	Loss: 2.1960
#  Client6 Train => Local Epoch: 2 	Acc: 45.453 	Loss: 2.0670
#  Client6 Train => Local Epoch: 3 	Acc: 47.251 	Loss: 1.9867
#  Client6 Train => Local Epoch: 4 	Acc: 48.702 	Loss: 1.9123
#  Client6 Test =>                   	Acc: 16.565 	Loss: 3.3756
#  Client3 Train => Local Epoch: 0 	Acc: 31.853 	Loss: 2.7173
#  Client3 Train => Local Epoch: 1 	Acc: 35.902 	Loss: 2.4480
#  Client3 Train => Local Epoch: 2 	Acc: 37.625 	Loss: 2.3508
#  Client3 Train => Local Epoch: 3 	Acc: 39.714 	Loss: 2.2654
#  Client3 Train => Local Epoch: 4 	Acc: 41.763 	Loss: 2.1712
#  Client3 Test =>                   	Acc: 19.723 	Loss: 3.3643
#  Client8 Train => Local Epoch: 0 	Acc: 31.911 	Loss: 2.7670
#  Client8 Train => Local Epoch: 1 	Acc: 39.104 	Loss: 2.3661
#  Client8 Train => Local Epoch: 2 	Acc: 41.990 	Loss: 2.2354
#  Client8 Train => Local Epoch: 3 	Acc: 44.175 	Loss: 2.1225
#  Client8 Train => Local Epoch: 4 	Acc: 45.635 	Loss: 2.0641
#  Client8 Test =>                   	Acc: 22.565 	Loss: 3.2730
#  Client9 Train => Local Epoch: 0 	Acc: 33.186 	Loss: 2.7732
#  Client9 Train => Local Epoch: 1 	Acc: 41.063 	Loss: 2.2993
#  Client9 Train => Local Epoch: 2 	Acc: 43.233 	Loss: 2.2076
#  Client9 Train => Local Epoch: 3 	Acc: 45.307 	Loss: 2.0970
#  Client9 Train => Local Epoch: 4 	Acc: 47.509 	Loss: 2.0008
#  Client9 Test =>                   	Acc: 20.838 	Loss: 3.2305
#  Client4 Train => Local Epoch: 0 	Acc: 31.624 	Loss: 2.7640
#  Client4 Train => Local Epoch: 1 	Acc: 32.878 	Loss: 2.6252
#  Client4 Train => Local Epoch: 2 	Acc: 34.180 	Loss: 2.5501
#  Client4 Train => Local Epoch: 3 	Acc: 35.482 	Loss: 2.4794
#  Client4 Train => Local Epoch: 4 	Acc: 38.704 	Loss: 2.3931
#  Client4 Test =>                   	Acc: 20.360 	Loss: 3.2809
#  Client5 Train => Local Epoch: 0 	Acc: 31.353 	Loss: 2.8672
#  Client5 Train => Local Epoch: 1 	Acc: 38.137 	Loss: 2.4690
#  Client5 Train => Local Epoch: 2 	Acc: 39.802 	Loss: 2.3500
#  Client5 Train => Local Epoch: 3 	Acc: 42.111 	Loss: 2.2462
#  Client5 Train => Local Epoch: 4 	Acc: 43.314 	Loss: 2.1600
#  Client5 Test =>                   	Acc: 20.797 	Loss: 3.3295
#  Client0 Train => Local Epoch: 0 	Acc: 29.109 	Loss: 2.8963
#  Client0 Train => Local Epoch: 1 	Acc: 38.379 	Loss: 2.3837
#  Client0 Train => Local Epoch: 2 	Acc: 40.477 	Loss: 2.2501
#  Client0 Train => Local Epoch: 3 	Acc: 42.455 	Loss: 2.1631
#  Client0 Train => Local Epoch: 4 	Acc: 44.249 	Loss: 2.0878
#  Client0 Test =>                   	Acc: 21.548 	Loss: 3.2578
#  Client1 Train => Local Epoch: 0 	Acc: 32.178 	Loss: 2.7890
#  Client1 Train => Local Epoch: 1 	Acc: 37.010 	Loss: 2.4657
#  Client1 Train => Local Epoch: 2 	Acc: 39.824 	Loss: 2.3477
#  Client1 Train => Local Epoch: 3 	Acc: 41.307 	Loss: 2.2414
#  Client1 Train => Local Epoch: 4 	Acc: 43.773 	Loss: 2.1559
#  Client1 Test =>                   	Acc: 19.117 	Loss: 3.3773
# ====================== SERVER V1==========================
#  Train: Round   5, Avg Accuracy 43.574 | Avg Loss 2.145
#  Test: Round   5, Avg Accuracy 19.613 | Avg Loss 3.328
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Forgetting : Round 5, mean_forgetting : -0.675
# ==========================================================
#  Client6 Train => Local Epoch: 0 	Acc: 37.586 	Loss: 2.5324
#  Client6 Train => Local Epoch: 1 	Acc: 45.634 	Loss: 2.0939
#  Client6 Train => Local Epoch: 2 	Acc: 48.007 	Loss: 1.9543
#  Client6 Train => Local Epoch: 3 	Acc: 49.903 	Loss: 1.8667
#  Client6 Train => Local Epoch: 4 	Acc: 51.617 	Loss: 1.7937
#  Client6 Test =>                   	Acc: 20.515 	Loss: 3.2716
#  Client0 Train => Local Epoch: 0 	Acc: 34.377 	Loss: 2.6192
#  Client0 Train => Local Epoch: 1 	Acc: 40.650 	Loss: 2.2480
#  Client0 Train => Local Epoch: 2 	Acc: 44.093 	Loss: 2.1011
#  Client0 Train => Local Epoch: 3 	Acc: 46.065 	Loss: 2.0146
#  Client0 Train => Local Epoch: 4 	Acc: 47.201 	Loss: 1.9356
#  Client0 Test =>                   	Acc: 22.215 	Loss: 3.1664
#  Client3 Train => Local Epoch: 0 	Acc: 34.061 	Loss: 2.6187
#  Client3 Train => Local Epoch: 1 	Acc: 38.280 	Loss: 2.3238
#  Client3 Train => Local Epoch: 2 	Acc: 40.994 	Loss: 2.2326
#  Client3 Train => Local Epoch: 3 	Acc: 42.782 	Loss: 2.1442
#  Client3 Train => Local Epoch: 4 	Acc: 45.207 	Loss: 2.0511
#  Client3 Test =>                   	Acc: 21.865 	Loss: 3.2066
#  Client4 Train => Local Epoch: 0 	Acc: 32.210 	Loss: 2.7591
#  Client4 Train => Local Epoch: 1 	Acc: 34.863 	Loss: 2.5439
#  Client4 Train => Local Epoch: 2 	Acc: 38.802 	Loss: 2.4038
#  Client4 Train => Local Epoch: 3 	Acc: 38.590 	Loss: 2.3994
#  Client4 Train => Local Epoch: 4 	Acc: 39.128 	Loss: 2.3510
#  Client4 Test =>                   	Acc: 23.330 	Loss: 3.1350
#  Client5 Train => Local Epoch: 0 	Acc: 32.728 	Loss: 2.7724
#  Client5 Train => Local Epoch: 1 	Acc: 40.248 	Loss: 2.3572
#  Client5 Train => Local Epoch: 2 	Acc: 42.184 	Loss: 2.2279
#  Client5 Train => Local Epoch: 3 	Acc: 44.728 	Loss: 2.1311
#  Client5 Train => Local Epoch: 4 	Acc: 46.350 	Loss: 2.0461
#  Client5 Test =>                   	Acc: 22.882 	Loss: 3.1743
#  Client7 Train => Local Epoch: 0 	Acc: 32.681 	Loss: 2.7993
#  Client7 Train => Local Epoch: 1 	Acc: 38.195 	Loss: 2.4318
#  Client7 Train => Local Epoch: 2 	Acc: 40.857 	Loss: 2.3010
#  Client7 Train => Local Epoch: 3 	Acc: 43.118 	Loss: 2.1701
#  Client7 Train => Local Epoch: 4 	Acc: 45.420 	Loss: 2.0785
#  Client7 Test =>                   	Acc: 22.353 	Loss: 3.2214
#  Client9 Train => Local Epoch: 0 	Acc: 36.386 	Loss: 2.5878
#  Client9 Train => Local Epoch: 1 	Acc: 43.679 	Loss: 2.1805
#  Client9 Train => Local Epoch: 2 	Acc: 46.011 	Loss: 2.0850
#  Client9 Train => Local Epoch: 3 	Acc: 48.780 	Loss: 1.9673
#  Client9 Train => Local Epoch: 4 	Acc: 49.713 	Loss: 1.9000
#  Client9 Test =>                   	Acc: 24.101 	Loss: 3.0706
#  Client1 Train => Local Epoch: 0 	Acc: 34.362 	Loss: 2.6904
#  Client1 Train => Local Epoch: 1 	Acc: 39.694 	Loss: 2.3587
#  Client1 Train => Local Epoch: 2 	Acc: 42.138 	Loss: 2.2085
#  Client1 Train => Local Epoch: 3 	Acc: 44.482 	Loss: 2.1281
#  Client1 Train => Local Epoch: 4 	Acc: 46.651 	Loss: 2.0419
#  Client1 Test =>                   	Acc: 22.225 	Loss: 3.2111
#  Client8 Train => Local Epoch: 0 	Acc: 34.890 	Loss: 2.5824
#  Client8 Train => Local Epoch: 1 	Acc: 43.009 	Loss: 2.1973
#  Client8 Train => Local Epoch: 2 	Acc: 45.374 	Loss: 2.0865
#  Client8 Train => Local Epoch: 3 	Acc: 46.532 	Loss: 2.0077
#  Client8 Train => Local Epoch: 4 	Acc: 48.546 	Loss: 1.9366
#  Client8 Test =>                   	Acc: 24.805 	Loss: 3.1641
#  Client2 Train => Local Epoch: 0 	Acc: 29.391 	Loss: 2.8175
#  Client2 Train => Local Epoch: 1 	Acc: 36.980 	Loss: 2.4306
#  Client2 Train => Local Epoch: 2 	Acc: 39.167 	Loss: 2.3028
#  Client2 Train => Local Epoch: 3 	Acc: 41.576 	Loss: 2.2095
#  Client2 Train => Local Epoch: 4 	Acc: 42.614 	Loss: 2.1431
#  Client2 Test =>                   	Acc: 23.788 	Loss: 3.1761
# ====================== SERVER V1==========================
#  Train: Round   6, Avg Accuracy 46.245 | Avg Loss 2.028
#  Test: Round   6, Avg Accuracy 22.808 | Avg Loss 3.180
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Forgetting : Round 6, mean_forgetting : -0.783
# ==========================================================
#  Client4 Train => Local Epoch: 0 	Acc: 35.710 	Loss: 2.5530
#  Client4 Train => Local Epoch: 1 	Acc: 36.963 	Loss: 2.4267
#  Client4 Train => Local Epoch: 2 	Acc: 39.876 	Loss: 2.3455
#  Client4 Train => Local Epoch: 3 	Acc: 41.732 	Loss: 2.2592
#  Client4 Train => Local Epoch: 4 	Acc: 41.943 	Loss: 2.1680
#  Client4 Test =>                   	Acc: 25.155 	Loss: 2.9799
#  Client1 Train => Local Epoch: 0 	Acc: 36.098 	Loss: 2.5535
#  Client1 Train => Local Epoch: 1 	Acc: 43.035 	Loss: 2.2165
#  Client1 Train => Local Epoch: 2 	Acc: 46.180 	Loss: 2.0431
#  Client1 Train => Local Epoch: 3 	Acc: 47.664 	Loss: 1.9638
#  Client1 Train => Local Epoch: 4 	Acc: 49.400 	Loss: 1.8885
#  Client1 Test =>                   	Acc: 24.784 	Loss: 3.0565
#  Client2 Train => Local Epoch: 0 	Acc: 33.109 	Loss: 2.6384
#  Client2 Train => Local Epoch: 1 	Acc: 40.169 	Loss: 2.2899
#  Client2 Train => Local Epoch: 2 	Acc: 42.456 	Loss: 2.1830
#  Client2 Train => Local Epoch: 3 	Acc: 44.525 	Loss: 2.0829
#  Client2 Train => Local Epoch: 4 	Acc: 45.955 	Loss: 2.0036
#  Client2 Test =>                   	Acc: 23.572 	Loss: 3.0811
#  Client9 Train => Local Epoch: 0 	Acc: 39.816 	Loss: 2.4368
#  Client9 Train => Local Epoch: 1 	Acc: 46.240 	Loss: 2.0602
#  Client9 Train => Local Epoch: 2 	Acc: 49.376 	Loss: 1.9408
#  Client9 Train => Local Epoch: 3 	Acc: 50.993 	Loss: 1.8514
#  Client9 Train => Local Epoch: 4 	Acc: 52.502 	Loss: 1.7799
#  Client9 Test =>                   	Acc: 24.872 	Loss: 2.9498
#  Client5 Train => Local Epoch: 0 	Acc: 36.712 	Loss: 2.5544
#  Client5 Train => Local Epoch: 1 	Acc: 42.751 	Loss: 2.2117
#  Client5 Train => Local Epoch: 2 	Acc: 44.488 	Loss: 2.0890
#  Client5 Train => Local Epoch: 3 	Acc: 47.708 	Loss: 1.9809
#  Client5 Train => Local Epoch: 4 	Acc: 48.999 	Loss: 1.9035
#  Client5 Test =>                   	Acc: 24.825 	Loss: 3.0606
#  Client7 Train => Local Epoch: 0 	Acc: 34.343 	Loss: 2.6415
#  Client7 Train => Local Epoch: 1 	Acc: 41.268 	Loss: 2.2883
#  Client7 Train => Local Epoch: 2 	Acc: 44.777 	Loss: 2.1230
#  Client7 Train => Local Epoch: 3 	Acc: 45.576 	Loss: 2.0491
#  Client7 Train => Local Epoch: 4 	Acc: 48.580 	Loss: 1.9435
#  Client7 Test =>                   	Acc: 24.865 	Loss: 3.0392
#  Client6 Train => Local Epoch: 0 	Acc: 40.310 	Loss: 2.3629
#  Client6 Train => Local Epoch: 1 	Acc: 48.325 	Loss: 1.9751
#  Client6 Train => Local Epoch: 2 	Acc: 50.785 	Loss: 1.8308
#  Client6 Train => Local Epoch: 3 	Acc: 51.443 	Loss: 1.7508
#  Client6 Train => Local Epoch: 4 	Acc: 54.630 	Loss: 1.6750
#  Client6 Test =>                   	Acc: 24.825 	Loss: 3.0125
#  Client3 Train => Local Epoch: 0 	Acc: 38.128 	Loss: 2.4202
#  Client3 Train => Local Epoch: 1 	Acc: 40.705 	Loss: 2.2252
#  Client3 Train => Local Epoch: 2 	Acc: 42.313 	Loss: 2.1111
#  Client3 Train => Local Epoch: 3 	Acc: 46.559 	Loss: 1.9751
#  Client3 Train => Local Epoch: 4 	Acc: 47.630 	Loss: 1.9308
#  Client3 Test =>                   	Acc: 23.778 	Loss: 3.0459
#  Client0 Train => Local Epoch: 0 	Acc: 35.582 	Loss: 2.5944
#  Client0 Train => Local Epoch: 1 	Acc: 43.740 	Loss: 2.1351
#  Client0 Train => Local Epoch: 2 	Acc: 46.570 	Loss: 1.9923
#  Client0 Train => Local Epoch: 3 	Acc: 48.600 	Loss: 1.9084
#  Client0 Train => Local Epoch: 4 	Acc: 50.203 	Loss: 1.7936
#  Client0 Test =>                   	Acc: 26.791 	Loss: 2.9140
#  Client8 Train => Local Epoch: 0 	Acc: 37.951 	Loss: 2.4305
#  Client8 Train => Local Epoch: 1 	Acc: 44.831 	Loss: 2.0833
#  Client8 Train => Local Epoch: 2 	Acc: 47.615 	Loss: 1.9628
#  Client8 Train => Local Epoch: 3 	Acc: 49.845 	Loss: 1.8625
#  Client8 Train => Local Epoch: 4 	Acc: 50.501 	Loss: 1.8127
#  Client8 Test =>                   	Acc: 29.065 	Loss: 2.9501
# ====================== SERVER V1==========================
#  Train: Round   7, Avg Accuracy 49.034 | Avg Loss 1.890
#  Test: Round   7, Avg Accuracy 25.253 | Avg Loss 3.009
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Forgetting : Round 7, mean_forgetting : -0.832
# ==========================================================
#  Client8 Train => Local Epoch: 0 	Acc: 44.887 	Loss: 2.0605
#  Client8 Train => Local Epoch: 1 	Acc: 48.359 	Loss: 1.9068
#  Client8 Train => Local Epoch: 2 	Acc: 50.924 	Loss: 1.8172
#  Client8 Train => Local Epoch: 3 	Acc: 53.360 	Loss: 1.7333
#  Client8 Train => Local Epoch: 4 	Acc: 54.947 	Loss: 1.6595
#  Client8 Test =>                   	Acc: 26.845 	Loss: 3.0557
#  Client9 Train => Local Epoch: 0 	Acc: 39.035 	Loss: 2.4435
#  Client9 Train => Local Epoch: 1 	Acc: 48.985 	Loss: 1.9838
#  Client9 Train => Local Epoch: 2 	Acc: 52.100 	Loss: 1.8287
#  Client9 Train => Local Epoch: 3 	Acc: 53.934 	Loss: 1.7451
#  Client9 Train => Local Epoch: 4 	Acc: 55.953 	Loss: 1.6529
#  Client9 Test =>                   	Acc: 28.064 	Loss: 2.8074
#  Client5 Train => Local Epoch: 0 	Acc: 38.094 	Loss: 2.5025
#  Client5 Train => Local Epoch: 1 	Acc: 45.809 	Loss: 2.1003
#  Client5 Train => Local Epoch: 2 	Acc: 47.312 	Loss: 1.9664
#  Client5 Train => Local Epoch: 3 	Acc: 49.249 	Loss: 1.8968
#  Client5 Train => Local Epoch: 4 	Acc: 52.097 	Loss: 1.7831
#  Client5 Test =>                   	Acc: 28.388 	Loss: 2.9045
#  Client6 Train => Local Epoch: 0 	Acc: 43.192 	Loss: 2.2133
#  Client6 Train => Local Epoch: 1 	Acc: 50.220 	Loss: 1.8703
#  Client6 Train => Local Epoch: 2 	Acc: 53.168 	Loss: 1.7203
#  Client6 Train => Local Epoch: 3 	Acc: 54.927 	Loss: 1.6287
#  Client6 Train => Local Epoch: 4 	Acc: 57.118 	Loss: 1.5576
#  Client6 Test =>                   	Acc: 27.502 	Loss: 2.8967
#  Client7 Train => Local Epoch: 0 	Acc: 37.752 	Loss: 2.4485
#  Client7 Train => Local Epoch: 1 	Acc: 45.047 	Loss: 2.0897
#  Client7 Train => Local Epoch: 2 	Acc: 46.507 	Loss: 1.9987
#  Client7 Train => Local Epoch: 3 	Acc: 47.275 	Loss: 1.9234
#  Client7 Train => Local Epoch: 4 	Acc: 49.642 	Loss: 1.8693
#  Client7 Test =>                   	Acc: 29.044 	Loss: 2.8863
#  Client4 Train => Local Epoch: 0 	Acc: 37.972 	Loss: 2.4386
#  Client4 Train => Local Epoch: 1 	Acc: 41.276 	Loss: 2.2875
#  Client4 Train => Local Epoch: 2 	Acc: 40.316 	Loss: 2.2605
#  Client4 Train => Local Epoch: 3 	Acc: 43.359 	Loss: 2.1622
#  Client4 Train => Local Epoch: 4 	Acc: 43.555 	Loss: 2.1401
#  Client4 Test =>                   	Acc: 30.092 	Loss: 2.8177
#  Client1 Train => Local Epoch: 0 	Acc: 38.616 	Loss: 2.4160
#  Client1 Train => Local Epoch: 1 	Acc: 46.231 	Loss: 2.0635
#  Client1 Train => Local Epoch: 2 	Acc: 49.313 	Loss: 1.9215
#  Client1 Train => Local Epoch: 3 	Acc: 50.074 	Loss: 1.8578
#  Client1 Train => Local Epoch: 4 	Acc: 51.947 	Loss: 1.7788
#  Client1 Test =>                   	Acc: 26.515 	Loss: 2.9111
#  Client3 Train => Local Epoch: 0 	Acc: 38.779 	Loss: 2.3566
#  Client3 Train => Local Epoch: 1 	Acc: 42.558 	Loss: 2.1297
#  Client3 Train => Local Epoch: 2 	Acc: 45.306 	Loss: 2.0348
#  Client3 Train => Local Epoch: 3 	Acc: 47.067 	Loss: 1.9225
#  Client3 Train => Local Epoch: 4 	Acc: 48.110 	Loss: 1.8825
#  Client3 Test =>                   	Acc: 27.798 	Loss: 2.8846
#  Client2 Train => Local Epoch: 0 	Acc: 35.424 	Loss: 2.5507
#  Client2 Train => Local Epoch: 1 	Acc: 42.979 	Loss: 2.1727
#  Client2 Train => Local Epoch: 2 	Acc: 44.438 	Loss: 2.0657
#  Client2 Train => Local Epoch: 3 	Acc: 48.110 	Loss: 1.9493
#  Client2 Train => Local Epoch: 4 	Acc: 49.350 	Loss: 1.8620
#  Client2 Test =>                   	Acc: 29.395 	Loss: 2.8747
#  Client0 Train => Local Epoch: 0 	Acc: 38.400 	Loss: 2.4227
#  Client0 Train => Local Epoch: 1 	Acc: 46.768 	Loss: 2.0003
#  Client0 Train => Local Epoch: 2 	Acc: 48.912 	Loss: 1.8609
#  Client0 Train => Local Epoch: 3 	Acc: 52.281 	Loss: 1.7521
#  Client0 Train => Local Epoch: 4 	Acc: 54.057 	Loss: 1.6675
#  Client0 Test =>                   	Acc: 28.950 	Loss: 2.7651
# ====================== SERVER V1==========================
#  Train: Round   8, Avg Accuracy 51.677 | Avg Loss 1.785
#  Test: Round   8, Avg Accuracy 28.259 | Avg Loss 2.880
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Forgetting : Round 8, mean_forgetting : -0.826
# ==========================================================
#  Client2 Train => Local Epoch: 0 	Acc: 40.636 	Loss: 2.2738
#  Client2 Train => Local Epoch: 1 	Acc: 45.731 	Loss: 2.0228
#  Client2 Train => Local Epoch: 2 	Acc: 48.208 	Loss: 1.9102
#  Client2 Train => Local Epoch: 3 	Acc: 50.701 	Loss: 1.8170
#  Client2 Train => Local Epoch: 4 	Acc: 52.217 	Loss: 1.7455
#  Client2 Test =>                   	Acc: 29.172 	Loss: 2.8733
#  Client5 Train => Local Epoch: 0 	Acc: 40.559 	Loss: 2.3620
#  Client5 Train => Local Epoch: 1 	Acc: 47.628 	Loss: 1.9992
#  Client5 Train => Local Epoch: 2 	Acc: 50.503 	Loss: 1.8559
#  Client5 Train => Local Epoch: 3 	Acc: 53.456 	Loss: 1.7457
#  Client5 Train => Local Epoch: 4 	Acc: 54.612 	Loss: 1.6706
#  Client5 Test =>                   	Acc: 28.186 	Loss: 2.8481
#  Client1 Train => Local Epoch: 0 	Acc: 41.046 	Loss: 2.3431
#  Client1 Train => Local Epoch: 1 	Acc: 47.316 	Loss: 1.9843
#  Client1 Train => Local Epoch: 2 	Acc: 51.043 	Loss: 1.8539
#  Client1 Train => Local Epoch: 3 	Acc: 53.356 	Loss: 1.7350
#  Client1 Train => Local Epoch: 4 	Acc: 54.514 	Loss: 1.6693
#  Client1 Test =>                   	Acc: 29.543 	Loss: 2.8525
#  Client6 Train => Local Epoch: 0 	Acc: 45.663 	Loss: 2.1366
#  Client6 Train => Local Epoch: 1 	Acc: 51.982 	Loss: 1.7660
#  Client6 Train => Local Epoch: 2 	Acc: 55.332 	Loss: 1.6368
#  Client6 Train => Local Epoch: 3 	Acc: 57.401 	Loss: 1.5318
#  Client6 Train => Local Epoch: 4 	Acc: 58.840 	Loss: 1.4675
#  Client6 Test =>                   	Acc: 27.866 	Loss: 2.8507
#  Client4 Train => Local Epoch: 0 	Acc: 39.469 	Loss: 2.3599
#  Client4 Train => Local Epoch: 1 	Acc: 38.916 	Loss: 2.3748
#  Client4 Train => Local Epoch: 2 	Acc: 42.269 	Loss: 2.2049
#  Client4 Train => Local Epoch: 3 	Acc: 44.906 	Loss: 2.0767
#  Client4 Train => Local Epoch: 4 	Acc: 45.638 	Loss: 1.9841
#  Client4 Test =>                   	Acc: 33.217 	Loss: 2.7326
#  Client0 Train => Local Epoch: 0 	Acc: 40.479 	Loss: 2.3185
#  Client0 Train => Local Epoch: 1 	Acc: 50.205 	Loss: 1.8580
#  Client0 Train => Local Epoch: 2 	Acc: 52.216 	Loss: 1.7432
#  Client0 Train => Local Epoch: 3 	Acc: 54.917 	Loss: 1.6372
#  Client0 Train => Local Epoch: 4 	Acc: 57.075 	Loss: 1.5517
#  Client0 Test =>                   	Acc: 31.294 	Loss: 2.6561
#  Client3 Train => Local Epoch: 0 	Acc: 41.385 	Loss: 2.2218
#  Client3 Train => Local Epoch: 1 	Acc: 45.748 	Loss: 2.0223
#  Client3 Train => Local Epoch: 2 	Acc: 47.217 	Loss: 1.9105
#  Client3 Train => Local Epoch: 3 	Acc: 48.281 	Loss: 1.8461
#  Client3 Train => Local Epoch: 4 	Acc: 51.749 	Loss: 1.7196
#  Client3 Test =>                   	Acc: 29.980 	Loss: 2.7687
#  Client8 Train => Local Epoch: 0 	Acc: 41.443 	Loss: 2.2303
#  Client8 Train => Local Epoch: 1 	Acc: 49.651 	Loss: 1.8885
#  Client8 Train => Local Epoch: 2 	Acc: 52.128 	Loss: 1.7404
#  Client8 Train => Local Epoch: 3 	Acc: 55.084 	Loss: 1.6548
#  Client8 Train => Local Epoch: 4 	Acc: 57.158 	Loss: 1.5790
#  Client8 Test =>                   	Acc: 33.611 	Loss: 2.7369
#  Client9 Train => Local Epoch: 0 	Acc: 44.494 	Loss: 2.1968
#  Client9 Train => Local Epoch: 1 	Acc: 51.101 	Loss: 1.8594
#  Client9 Train => Local Epoch: 2 	Acc: 54.194 	Loss: 1.7312
#  Client9 Train => Local Epoch: 3 	Acc: 56.669 	Loss: 1.6119
#  Client9 Train => Local Epoch: 4 	Acc: 58.176 	Loss: 1.5365
#  Client9 Test =>                   	Acc: 31.920 	Loss: 2.6350
#  Client7 Train => Local Epoch: 0 	Acc: 42.868 	Loss: 2.2414
#  Client7 Train => Local Epoch: 1 	Acc: 46.791 	Loss: 2.0232
#  Client7 Train => Local Epoch: 2 	Acc: 48.580 	Loss: 1.9180
#  Client7 Train => Local Epoch: 3 	Acc: 51.338 	Loss: 1.7806
#  Client7 Train => Local Epoch: 4 	Acc: 52.455 	Loss: 1.7288
#  Client7 Test =>                   	Acc: 28.526 	Loss: 2.7990
# ====================== SERVER V1==========================
#  Train: Round   9, Avg Accuracy 54.243 | Avg Loss 1.665
#  Test: Round   9, Avg Accuracy 30.331 | Avg Loss 2.775
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Forgetting : Round 9, mean_forgetting : -0.855
# ==========================================================
#  Client3 Train => Local Epoch: 0 	Acc: 45.192 	Loss: 2.0599
#  Client3 Train => Local Epoch: 1 	Acc: 49.574 	Loss: 1.8416
#  Client3 Train => Local Epoch: 2 	Acc: 51.788 	Loss: 1.7453
#  Client3 Train => Local Epoch: 3 	Acc: 51.808 	Loss: 1.6738
#  Client3 Train => Local Epoch: 4 	Acc: 53.763 	Loss: 1.6429
#  Client3 Test =>                   	Acc: 34.958 	Loss: 2.6628
#  Client1 Train => Local Epoch: 0 	Acc: 44.127 	Loss: 2.1939
#  Client1 Train => Local Epoch: 1 	Acc: 51.028 	Loss: 1.8775
#  Client1 Train => Local Epoch: 2 	Acc: 53.038 	Loss: 1.7380
#  Client1 Train => Local Epoch: 3 	Acc: 55.518 	Loss: 1.6464
#  Client1 Train => Local Epoch: 4 	Acc: 58.397 	Loss: 1.5280
#  Client1 Test =>                   	Acc: 33.473 	Loss: 2.6448
#  Client7 Train => Local Epoch: 0 	Acc: 44.893 	Loss: 2.1163
#  Client7 Train => Local Epoch: 1 	Acc: 50.495 	Loss: 1.8523
#  Client7 Train => Local Epoch: 2 	Acc: 52.304 	Loss: 1.7577
#  Client7 Train => Local Epoch: 3 	Acc: 54.169 	Loss: 1.6591
#  Client7 Train => Local Epoch: 4 	Acc: 56.882 	Loss: 1.6004
#  Client7 Test =>                   	Acc: 31.011 	Loss: 2.7134
#  Client9 Train => Local Epoch: 0 	Acc: 46.936 	Loss: 2.0611
#  Client9 Train => Local Epoch: 1 	Acc: 54.596 	Loss: 1.7281
#  Client9 Train => Local Epoch: 2 	Acc: 55.788 	Loss: 1.6379
#  Client9 Train => Local Epoch: 3 	Acc: 59.425 	Loss: 1.5026
#  Client9 Train => Local Epoch: 4 	Acc: 59.923 	Loss: 1.4493
#  Client9 Test =>                   	Acc: 33.988 	Loss: 2.5708
#  Client4 Train => Local Epoch: 0 	Acc: 43.164 	Loss: 2.1602
#  Client4 Train => Local Epoch: 1 	Acc: 42.188 	Loss: 2.2325
#  Client4 Train => Local Epoch: 2 	Acc: 46.029 	Loss: 2.0582
#  Client4 Train => Local Epoch: 3 	Acc: 43.604 	Loss: 2.1214
#  Client4 Train => Local Epoch: 4 	Acc: 48.177 	Loss: 1.9087
#  Client4 Test =>                   	Acc: 33.590 	Loss: 2.6126
#  Client5 Train => Local Epoch: 0 	Acc: 43.017 	Loss: 2.2633
#  Client5 Train => Local Epoch: 1 	Acc: 50.017 	Loss: 1.9023
#  Client5 Train => Local Epoch: 2 	Acc: 52.126 	Loss: 1.7748
#  Client5 Train => Local Epoch: 3 	Acc: 56.203 	Loss: 1.6491
#  Client5 Train => Local Epoch: 4 	Acc: 56.930 	Loss: 1.5850
#  Client5 Test =>                   	Acc: 32.779 	Loss: 2.6262
#  Client2 Train => Local Epoch: 0 	Acc: 42.158 	Loss: 2.2566
#  Client2 Train => Local Epoch: 1 	Acc: 48.188 	Loss: 1.9261
#  Client2 Train => Local Epoch: 2 	Acc: 51.292 	Loss: 1.8006
#  Client2 Train => Local Epoch: 3 	Acc: 53.557 	Loss: 1.7122
#  Client2 Train => Local Epoch: 4 	Acc: 54.633 	Loss: 1.6573
#  Client2 Test =>                   	Acc: 32.351 	Loss: 2.6373
#  Client0 Train => Local Epoch: 0 	Acc: 42.369 	Loss: 2.1940
#  Client0 Train => Local Epoch: 1 	Acc: 51.523 	Loss: 1.7606
#  Client0 Train => Local Epoch: 2 	Acc: 54.364 	Loss: 1.6267
#  Client0 Train => Local Epoch: 3 	Acc: 56.941 	Loss: 1.5218
#  Client0 Train => Local Epoch: 4 	Acc: 59.162 	Loss: 1.4567
# ...
#  Client4 Train => Local Epoch: 1 	Acc: 90.348 	Loss: 0.3558
#  Client4 Train => Local Epoch: 2 	Acc: 89.339 	Loss: 0.3692
#  Client4 Train => Local Epoch: 3 	Acc: 87.435 	Loss: 0.4632
#  Client4 Train => Local Epoch: 4 	Acc: 85.124 	Loss: 0.5262
#  Client4 Test =>                   	Acc: 64.921 	Loss: 1.4542
#  Client8 Train => Local Epoch: 0 	Acc: 94.727 	Loss: 0.1811
#  Client8 Train => Local Epoch: 1 	Acc: 98.043 	Loss: 0.0919
#  Client8 Train => Local Epoch: 2 	Acc: 99.199 	Loss: 0.0539
#  Client8 Train => Local Epoch: 3 	Acc: 99.473 	Loss: 0.0362
#  Client8 Train => Local Epoch: 4 	Acc: 99.824 	Loss: 0.0257
#  Client8 Test =>                   	Acc: 62.207 	Loss: 1.5436
#  Client6 Train => Local Epoch: 0 	Acc: 94.650 	Loss: 0.1828
#  Client6 Train => Local Epoch: 1 	Acc: 98.018 	Loss: 0.0879
#  Client6 Train => Local Epoch: 2 	Acc: 98.531 	Loss: 0.0615
#  Client6 Train => Local Epoch: 3 	Acc: 98.955 	Loss: 0.0469
#  Client6 Train => Local Epoch: 4 	Acc: 99.515 	Loss: 0.0303
#  Client6 Test =>                   	Acc: 62.843 	Loss: 1.4305
#  Client0 Train => Local Epoch: 0 	Acc: 94.761 	Loss: 0.1937
#  Client0 Train => Local Epoch: 1 	Acc: 98.429 	Loss: 0.0856
#  Client0 Train => Local Epoch: 2 	Acc: 99.116 	Loss: 0.0510
#  Client0 Train => Local Epoch: 3 	Acc: 99.678 	Loss: 0.0306
#  Client0 Train => Local Epoch: 4 	Acc: 99.783 	Loss: 0.0230
#  Client0 Test =>                   	Acc: 62.274 	Loss: 1.4951
#  Client3 Train => Local Epoch: 0 	Acc: 97.266 	Loss: 0.1147
#  Client3 Train => Local Epoch: 1 	Acc: 99.189 	Loss: 0.0617
#  Client3 Train => Local Epoch: 2 	Acc: 98.040 	Loss: 0.0824
#  Client3 Train => Local Epoch: 3 	Acc: 94.765 	Loss: 0.1855
#  Client3 Train => Local Epoch: 4 	Acc: 95.159 	Loss: 0.1764
#  Client3 Test =>                   	Acc: 62.187 	Loss: 1.5559
#  Client5 Train => Local Epoch: 0 	Acc: 95.308 	Loss: 0.1752
#  Client5 Train => Local Epoch: 1 	Acc: 98.406 	Loss: 0.0793
#  Client5 Train => Local Epoch: 2 	Acc: 99.521 	Loss: 0.0476
#  Client5 Train => Local Epoch: 3 	Acc: 99.671 	Loss: 0.0320
#  Client5 Train => Local Epoch: 4 	Acc: 99.915 	Loss: 0.0215
#  Client5 Test =>                   	Acc: 63.658 	Loss: 1.5795
#  Client1 Train => Local Epoch: 0 	Acc: 95.364 	Loss: 0.1710
#  Client1 Train => Local Epoch: 1 	Acc: 98.279 	Loss: 0.0864
#  Client1 Train => Local Epoch: 2 	Acc: 99.327 	Loss: 0.0488
#  Client1 Train => Local Epoch: 3 	Acc: 99.537 	Loss: 0.0356
#  Client1 Train => Local Epoch: 4 	Acc: 99.667 	Loss: 0.0293
#  Client1 Test =>                   	Acc: 62.005 	Loss: 1.5056
#  Client7 Train => Local Epoch: 0 	Acc: 97.002 	Loss: 0.1274
#  Client7 Train => Local Epoch: 1 	Acc: 98.581 	Loss: 0.0838
#  Client7 Train => Local Epoch: 2 	Acc: 98.774 	Loss: 0.0579
#  Client7 Train => Local Epoch: 3 	Acc: 98.993 	Loss: 0.0569
#  Client7 Train => Local Epoch: 4 	Acc: 98.609 	Loss: 0.0643
#  Client7 Test =>                   	Acc: 64.201 	Loss: 1.4987
#  Client2 Train => Local Epoch: 0 	Acc: 95.292 	Loss: 0.1765
#  Client2 Train => Local Epoch: 1 	Acc: 98.208 	Loss: 0.0853
#  Client2 Train => Local Epoch: 2 	Acc: 99.066 	Loss: 0.0552
#  Client2 Train => Local Epoch: 3 	Acc: 99.545 	Loss: 0.0355
#  Client2 Train => Local Epoch: 4 	Acc: 99.853 	Loss: 0.0233
#  Client2 Test =>                   	Acc: 61.544 	Loss: 1.5644
# ====================== SERVER V1==========================
#  Train: Round  96, Avg Accuracy 97.711 | Avg Loss 0.095
#  Test: Round  96, Avg Accuracy 63.106 | Avg Loss 1.509
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Forgetting : Round 96, mean_forgetting : -0.323
# ==========================================================
#  Client9 Train => Local Epoch: 0 	Acc: 96.180 	Loss: 0.1511
#  Client9 Train => Local Epoch: 1 	Acc: 98.492 	Loss: 0.0838
#  Client9 Train => Local Epoch: 2 	Acc: 98.340 	Loss: 0.0780
#  Client9 Train => Local Epoch: 3 	Acc: 99.012 	Loss: 0.0491
#  Client9 Train => Local Epoch: 4 	Acc: 98.578 	Loss: 0.0594
#  Client9 Test =>                   	Acc: 66.224 	Loss: 1.4343
#  Client1 Train => Local Epoch: 0 	Acc: 96.376 	Loss: 0.1462
#  Client1 Train => Local Epoch: 1 	Acc: 98.872 	Loss: 0.0694
#  Client1 Train => Local Epoch: 2 	Acc: 99.392 	Loss: 0.0453
#  Client1 Train => Local Epoch: 3 	Acc: 99.718 	Loss: 0.0271
#  Client1 Train => Local Epoch: 4 	Acc: 99.711 	Loss: 0.0229
#  Client1 Test =>                   	Acc: 63.547 	Loss: 1.4855
#  Client7 Train => Local Epoch: 0 	Acc: 97.043 	Loss: 0.1343
#  Client7 Train => Local Epoch: 1 	Acc: 97.078 	Loss: 0.1165
#  Client7 Train => Local Epoch: 2 	Acc: 95.824 	Loss: 0.1594
#  Client7 Train => Local Epoch: 3 	Acc: 95.731 	Loss: 0.1586
#  Client7 Train => Local Epoch: 4 	Acc: 96.104 	Loss: 0.1512
#  Client7 Test =>                   	Acc: 64.621 	Loss: 1.4564
#  Client6 Train => Local Epoch: 0 	Acc: 95.551 	Loss: 0.1595
#  Client6 Train => Local Epoch: 1 	Acc: 98.014 	Loss: 0.0821
#  Client6 Train => Local Epoch: 2 	Acc: 98.868 	Loss: 0.0507
#  Client6 Train => Local Epoch: 3 	Acc: 99.584 	Loss: 0.0336
#  Client6 Train => Local Epoch: 4 	Acc: 99.805 	Loss: 0.0218
#  Client6 Test =>                   	Acc: 64.925 	Loss: 1.4060
#  Client0 Train => Local Epoch: 0 	Acc: 95.166 	Loss: 0.1778
#  Client0 Train => Local Epoch: 1 	Acc: 98.120 	Loss: 0.0817
#  Client0 Train => Local Epoch: 2 	Acc: 99.346 	Loss: 0.0497
#  Client0 Train => Local Epoch: 3 	Acc: 99.747 	Loss: 0.0288
#  Client0 Train => Local Epoch: 4 	Acc: 99.862 	Loss: 0.0204
#  Client0 Test =>                   	Acc: 64.406 	Loss: 1.4665
#  Client2 Train => Local Epoch: 0 	Acc: 96.098 	Loss: 0.1557
#  Client2 Train => Local Epoch: 1 	Acc: 98.830 	Loss: 0.0714
#  Client2 Train => Local Epoch: 2 	Acc: 99.556 	Loss: 0.0421
#  Client2 Train => Local Epoch: 3 	Acc: 99.734 	Loss: 0.0301
#  Client2 Train => Local Epoch: 4 	Acc: 99.799 	Loss: 0.0228
#  Client2 Test =>                   	Acc: 62.557 	Loss: 1.5746
#  Client8 Train => Local Epoch: 0 	Acc: 95.369 	Loss: 0.1672
#  Client8 Train => Local Epoch: 1 	Acc: 98.075 	Loss: 0.0886
#  Client8 Train => Local Epoch: 2 	Acc: 99.453 	Loss: 0.0476
#  Client8 Train => Local Epoch: 3 	Acc: 99.707 	Loss: 0.0335
#  Client8 Train => Local Epoch: 4 	Acc: 99.785 	Loss: 0.0232
#  Client8 Test =>                   	Acc: 63.588 	Loss: 1.5410
#  Client5 Train => Local Epoch: 0 	Acc: 95.830 	Loss: 0.1651
#  Client5 Train => Local Epoch: 1 	Acc: 98.837 	Loss: 0.0790
#  Client5 Train => Local Epoch: 2 	Acc: 99.231 	Loss: 0.0505
#  Client5 Train => Local Epoch: 3 	Acc: 99.542 	Loss: 0.0349
#  Client5 Train => Local Epoch: 4 	Acc: 99.918 	Loss: 0.0230
#  Client5 Test =>                   	Acc: 62.439 	Loss: 1.5725
#  Client3 Train => Local Epoch: 0 	Acc: 97.319 	Loss: 0.1092
#  Client3 Train => Local Epoch: 1 	Acc: 97.097 	Loss: 0.1214
#  Client3 Train => Local Epoch: 2 	Acc: 97.382 	Loss: 0.1081
#  Client3 Train => Local Epoch: 3 	Acc: 97.037 	Loss: 0.1181
#  Client3 Train => Local Epoch: 4 	Acc: 97.878 	Loss: 0.0852
#  Client3 Test =>                   	Acc: 63.318 	Loss: 1.5195
#  Client4 Train => Local Epoch: 0 	Acc: 96.810 	Loss: 0.1238
#  Client4 Train => Local Epoch: 1 	Acc: 90.202 	Loss: 0.3310
#  Client4 Train => Local Epoch: 2 	Acc: 87.223 	Loss: 0.4368
#  Client4 Train => Local Epoch: 3 	Acc: 89.111 	Loss: 0.3816
#  Client4 Train => Local Epoch: 4 	Acc: 89.111 	Loss: 0.3919
#  Client4 Test =>                   	Acc: 64.790 	Loss: 1.4684
# ====================== SERVER V1==========================
#  Train: Round  97, Avg Accuracy 98.055 | Avg Loss 0.082
#  Test: Round  97, Avg Accuracy 64.042 | Avg Loss 1.492
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Forgetting : Round 97, mean_forgetting : -0.321
# ==========================================================
#  Client8 Train => Local Epoch: 0 	Acc: 96.200 	Loss: 0.1497
#  Client8 Train => Local Epoch: 1 	Acc: 98.700 	Loss: 0.0721
#  Client8 Train => Local Epoch: 2 	Acc: 99.434 	Loss: 0.0414
#  Client8 Train => Local Epoch: 3 	Acc: 99.785 	Loss: 0.0273
#  Client8 Train => Local Epoch: 4 	Acc: 99.980 	Loss: 0.0181
#  Client8 Test =>                   	Acc: 63.184 	Loss: 1.5214
#  Client3 Train => Local Epoch: 0 	Acc: 97.860 	Loss: 0.0952
#  Client3 Train => Local Epoch: 1 	Acc: 96.358 	Loss: 0.1444
#  Client3 Train => Local Epoch: 2 	Acc: 94.777 	Loss: 0.1976
#  Client3 Train => Local Epoch: 3 	Acc: 92.091 	Loss: 0.2789
#  Client3 Train => Local Epoch: 4 	Acc: 92.692 	Loss: 0.2514
#  Client3 Test =>                   	Acc: 63.914 	Loss: 1.5224
#  Client9 Train => Local Epoch: 0 	Acc: 96.582 	Loss: 0.1377
#  Client9 Train => Local Epoch: 1 	Acc: 98.828 	Loss: 0.0695
#  Client9 Train => Local Epoch: 2 	Acc: 99.338 	Loss: 0.0471
#  Client9 Train => Local Epoch: 3 	Acc: 99.761 	Loss: 0.0282
#  Client9 Train => Local Epoch: 4 	Acc: 99.663 	Loss: 0.0239
#  Client9 Test =>                   	Acc: 65.561 	Loss: 1.4467
#  Client0 Train => Local Epoch: 0 	Acc: 94.199 	Loss: 0.1936
#  Client0 Train => Local Epoch: 1 	Acc: 98.153 	Loss: 0.0821
#  Client0 Train => Local Epoch: 2 	Acc: 98.910 	Loss: 0.0549
#  Client0 Train => Local Epoch: 3 	Acc: 99.724 	Loss: 0.0319
#  Client0 Train => Local Epoch: 4 	Acc: 99.586 	Loss: 0.0273
#  Client0 Test =>                   	Acc: 63.056 	Loss: 1.4877
#  Client5 Train => Local Epoch: 0 	Acc: 95.683 	Loss: 0.1667
#  Client5 Train => Local Epoch: 1 	Acc: 98.837 	Loss: 0.0713
#  Client5 Train => Local Epoch: 2 	Acc: 99.521 	Loss: 0.0427
#  Client5 Train => Local Epoch: 3 	Acc: 99.665 	Loss: 0.0307
#  Client5 Train => Local Epoch: 4 	Acc: 99.833 	Loss: 0.0216
#  Client5 Test =>                   	Acc: 63.598 	Loss: 1.5464
#  Client1 Train => Local Epoch: 0 	Acc: 96.608 	Loss: 0.1455
#  Client1 Train => Local Epoch: 1 	Acc: 98.843 	Loss: 0.0634
#  Client1 Train => Local Epoch: 2 	Acc: 99.320 	Loss: 0.0439
#  Client1 Train => Local Epoch: 3 	Acc: 99.588 	Loss: 0.0333
#  Client1 Train => Local Epoch: 4 	Acc: 99.819 	Loss: 0.0236
#  Client1 Test =>                   	Acc: 63.184 	Loss: 1.4753
#  Client7 Train => Local Epoch: 0 	Acc: 96.985 	Loss: 0.1207
#  Client7 Train => Local Epoch: 1 	Acc: 97.680 	Loss: 0.1084
#  Client7 Train => Local Epoch: 2 	Acc: 97.376 	Loss: 0.1029
#  Client7 Train => Local Epoch: 3 	Acc: 98.355 	Loss: 0.0849
#  Client7 Train => Local Epoch: 4 	Acc: 98.951 	Loss: 0.0571
#  Client7 Test =>                   	Acc: 63.857 	Loss: 1.4995
#  Client4 Train => Local Epoch: 0 	Acc: 98.014 	Loss: 0.0950
#  Client4 Train => Local Epoch: 1 	Acc: 96.289 	Loss: 0.1427
#  Client4 Train => Local Epoch: 2 	Acc: 79.150 	Loss: 0.7210
#  Client4 Train => Local Epoch: 3 	Acc: 80.094 	Loss: 0.6758
#  Client4 Train => Local Epoch: 4 	Acc: 82.015 	Loss: 0.6386
#  Client4 Test =>                   	Acc: 65.716 	Loss: 1.4587
#  Client6 Train => Local Epoch: 0 	Acc: 95.236 	Loss: 0.1713
#  Client6 Train => Local Epoch: 1 	Acc: 98.535 	Loss: 0.0731
#  Client6 Train => Local Epoch: 2 	Acc: 99.150 	Loss: 0.0464
#  Client6 Train => Local Epoch: 3 	Acc: 99.631 	Loss: 0.0291
#  Client6 Train => Local Epoch: 4 	Acc: 99.316 	Loss: 0.0300
#  Client6 Test =>                   	Acc: 64.335 	Loss: 1.3904
#  Client2 Train => Local Epoch: 0 	Acc: 95.707 	Loss: 0.1627
#  Client2 Train => Local Epoch: 1 	Acc: 98.439 	Loss: 0.0804
#  Client2 Train => Local Epoch: 2 	Acc: 99.409 	Loss: 0.0455
#  Client2 Train => Local Epoch: 3 	Acc: 99.680 	Loss: 0.0320
#  Client2 Train => Local Epoch: 4 	Acc: 99.799 	Loss: 0.0247
#  Client2 Test =>                   	Acc: 62.439 	Loss: 1.5733
# ====================== SERVER V1==========================
#  Train: Round  98, Avg Accuracy 97.166 | Avg Loss 0.112
#  Test: Round  98, Avg Accuracy 63.884 | Avg Loss 1.492
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Forgetting : Round 98, mean_forgetting : -0.308
# ==========================================================
#  Client8 Train => Local Epoch: 0 	Acc: 95.560 	Loss: 0.1619
#  Client8 Train => Local Epoch: 1 	Acc: 98.442 	Loss: 0.0754
#  Client8 Train => Local Epoch: 2 	Acc: 99.278 	Loss: 0.0481
#  Client8 Train => Local Epoch: 3 	Acc: 99.688 	Loss: 0.0300
#  Client8 Train => Local Epoch: 4 	Acc: 99.785 	Loss: 0.0225
#  Client8 Test =>                   	Acc: 63.015 	Loss: 1.5327
#  Client2 Train => Local Epoch: 0 	Acc: 96.232 	Loss: 0.1579
#  Client2 Train => Local Epoch: 1 	Acc: 98.545 	Loss: 0.0744
#  Client2 Train => Local Epoch: 2 	Acc: 99.314 	Loss: 0.0496
#  Client2 Train => Local Epoch: 3 	Acc: 99.787 	Loss: 0.0312
#  Client2 Train => Local Epoch: 4 	Acc: 99.893 	Loss: 0.0220
#  Client2 Test =>                   	Acc: 61.123 	Loss: 1.5899
#  Client3 Train => Local Epoch: 0 	Acc: 97.578 	Loss: 0.1047
#  Client3 Train => Local Epoch: 1 	Acc: 97.007 	Loss: 0.1171
#  Client3 Train => Local Epoch: 2 	Acc: 97.499 	Loss: 0.0996
#  Client3 Train => Local Epoch: 3 	Acc: 95.494 	Loss: 0.1828
#  Client3 Train => Local Epoch: 4 	Acc: 91.809 	Loss: 0.2858
#  Client3 Test =>                   	Acc: 62.635 	Loss: 1.5603
#  Client0 Train => Local Epoch: 0 	Acc: 94.485 	Loss: 0.1963
#  Client0 Train => Local Epoch: 1 	Acc: 98.325 	Loss: 0.0785
#  Client0 Train => Local Epoch: 2 	Acc: 99.334 	Loss: 0.0473
#  Client0 Train => Local Epoch: 3 	Acc: 99.599 	Loss: 0.0335
#  Client0 Train => Local Epoch: 4 	Acc: 99.632 	Loss: 0.0273
#  Client0 Test =>                   	Acc: 63.598 	Loss: 1.4688
#  Client9 Train => Local Epoch: 0 	Acc: 96.126 	Loss: 0.1569
#  Client9 Train => Local Epoch: 1 	Acc: 98.589 	Loss: 0.0768
#  Client9 Train => Local Epoch: 2 	Acc: 99.403 	Loss: 0.0482
#  Client9 Train => Local Epoch: 3 	Acc: 99.446 	Loss: 0.0384
#  Client9 Train => Local Epoch: 4 	Acc: 99.740 	Loss: 0.0298
#  Client9 Test =>                   	Acc: 65.423 	Loss: 1.4137
#  Client4 Train => Local Epoch: 0 	Acc: 97.445 	Loss: 0.1022
#  Client4 Train => Local Epoch: 1 	Acc: 95.264 	Loss: 0.1829
#  Client4 Train => Local Epoch: 2 	Acc: 92.806 	Loss: 0.2764
#  Client4 Train => Local Epoch: 3 	Acc: 95.589 	Loss: 0.1760
#  Client4 Train => Local Epoch: 4 	Acc: 96.468 	Loss: 0.1376
#  Client4 Test =>                   	Acc: 65.059 	Loss: 1.4691
#  Client7 Train => Local Epoch: 0 	Acc: 96.676 	Loss: 0.1329
#  Client7 Train => Local Epoch: 1 	Acc: 97.478 	Loss: 0.1056
#  Client7 Train => Local Epoch: 2 	Acc: 97.841 	Loss: 0.1174
#  Client7 Train => Local Epoch: 3 	Acc: 98.277 	Loss: 0.0795
#  Client7 Train => Local Epoch: 4 	Acc: 98.321 	Loss: 0.0832
#  Client7 Test =>                   	Acc: 63.918 	Loss: 1.4669
#  Client1 Train => Local Epoch: 0 	Acc: 95.942 	Loss: 0.1601
#  Client1 Train => Local Epoch: 1 	Acc: 98.459 	Loss: 0.0797
#  Client1 Train => Local Epoch: 2 	Acc: 99.089 	Loss: 0.0479
#  Client1 Train => Local Epoch: 3 	Acc: 99.631 	Loss: 0.0347
#  Client1 Train => Local Epoch: 4 	Acc: 99.805 	Loss: 0.0225
#  Client1 Test =>                   	Acc: 62.264 	Loss: 1.4978
#  Client5 Train => Local Epoch: 0 	Acc: 95.572 	Loss: 0.1621
#  Client5 Train => Local Epoch: 1 	Acc: 98.858 	Loss: 0.0717
#  Client5 Train => Local Epoch: 2 	Acc: 99.527 	Loss: 0.0455
#  Client5 Train => Local Epoch: 3 	Acc: 99.648 	Loss: 0.0290
#  Client5 Train => Local Epoch: 4 	Acc: 99.836 	Loss: 0.0203
#  Client5 Test =>                   	Acc: 62.254 	Loss: 1.5714
#  Client6 Train => Local Epoch: 0 	Acc: 95.717 	Loss: 0.1658
#  Client6 Train => Local Epoch: 1 	Acc: 98.846 	Loss: 0.0663
#  Client6 Train => Local Epoch: 2 	Acc: 99.208 	Loss: 0.0473
#  Client6 Train => Local Epoch: 3 	Acc: 99.631 	Loss: 0.0313
#  Client6 Train => Local Epoch: 4 	Acc: 99.736 	Loss: 0.0219
#  Client6 Test =>                   	Acc: 63.217 	Loss: 1.4006
# ====================== SERVER V1==========================
#  Train: Round  99, Avg Accuracy 98.502 | Avg Loss 0.067
#  Test: Round  99, Avg Accuracy 63.251 | Avg Loss 1.497
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Forgetting : Round 99, mean_forgetting : -0.336
# ==========================================================
# Training and Evaluation completed!
# Saved: SFLV2 - CIFAR-100 α=0.5 - LATE-Cut (6 + AvgPool).csv
